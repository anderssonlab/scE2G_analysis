# %%
library(cicero)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
# Loading required package: monocle3
#
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘monocle3’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     exprs, fData, fData<-, pData, pData<-
#
#
# Loading required package: Gviz
#
# Loading required package: grid
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'sp'
#
#
# The following object is masked from 'package:IRanges':
#
#     %over%
#
#
# 'SeuratObject' was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall 'SeuratObject' as the ABI
# for R may have changed
#
# 'SeuratObject' was built with package 'Matrix' 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     intersect
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following object is masked from 'package:IRanges':
#
#     intersect
#
#
# The following object is masked from 'package:S4Vectors':
#
#     intersect
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     intersect
#
#
# The following object is masked from 'package:base':
#
#     intersect
#
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     subtract
#
#
# Warning message:
# "replacing previous import 'Biostrings::pattern' by 'grid::pattern' when loading 'genomation'"
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_IGVF/1.prepare_data/2.Filter_out_low_quality_cells.240614/obj.seurat.qc.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240610/sc-E2G/test/results/K562_IGVF_filter/K562/Kendall/atac_matrix.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240610/sc-E2G/test/results/K562_IGVF_filter/K562/Kendall/Pairs.tsv.gz"
path.TSS1kb = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_IGVF/K562/Neighborhoods//GeneList.TSS1kb.bed"
path.chrom.sizes = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/ENCODE_rE2G/ABC/reference/hg38/GRCh38_EBV.chrom.sizes.tsv"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_IGVF/3.Genome_wide_prediction/Cicero/Cicero.240615/"

# %%
distance_constraint = 1000000 
window = 2000000

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac_count = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac_count)
rm(matrix.atac_count)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import TSS1kb regions

# %%
bed.TSS1kb = readGeneric(path.TSS1kb,
                         header = F,
                         keep.all.metadata = T)
bed.TSS1kb
# Out:
# GRanges object with 20666 ranges and 3 metadata columns:
#           seqnames            ranges strand |          V4        V5          V6
#              <Rle>         <IRanges>  <Rle> | <character> <integer> <character>
#       [1]     chr1       35581-36581      * |     FAM138A         0           -
#       [2]     chr1       35581-36581      * |     FAM138F         0           -
#       [3]     chr1       68590-69590      * |       OR4F5         0           +
#       [4]     chr1     816870-817870      * |      FAM87B         0           +
#       [5]     chr1     827022-828022      * |   LINC00115         0           -
#       ...      ...               ...    ... .         ...       ...         ...
#   [20662]     chrY 21385860-21386860      * |       PRORY         0           -
#   [20663]     chrY 21594166-21595166      * |      TTTY13         0           -
#   [20664]     chrY 22298376-22299376      * |       TTTY5         0           -
#   [20665]     chrY 23198592-23199592      * |        DAZ1         0           -
#   [20666]     chrY 23218956-23219956      * |        DAZ2         0           +
#   -------
#   seqinfo: 24 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Create a Cicero CDS

# %%
cellinfo = obj.seurat@meta.data
cellinfo[,"cell"] = rownames(cellinfo)
cellinfo
# Out:
#                          orig.ident    nCount_RNA nFeature_RNA nCount_ATAC
# e10l1_AAACCAGGTCACAGGG-1 SeuratProject 13033      4205         15412
# e10l1_AAACCGCCAAGGAATA-1 SeuratProject 16605      4976          6217
# e10l1_AAACCGCCAGCCGGTA-1 SeuratProject  8953      3654          1819
# e10l1_AAACCGGTCAAGGAAG-1 SeuratProject  6886      3325          1511
# e10l1_AAACGAACAACGTGGT-1 SeuratProject 22478      5638         18765
# e10l1_AAACGGGCAAGGGAGC-1 SeuratProject 10625      3496          4354
# e10l1_AAACTAGTCCTGTGAC-1 SeuratProject  7365      3128          9659
# e10l1_AAACTAGTCGAAGCAT-1 SeuratProject 10650      3718          7689
# e10l1_AAACTAGTCGCTTGAC-1 SeuratProject 10031      3977          9560
# e10l1_AAACTCGCAAGCGCTG-1 SeuratProject 14714      4453          8300
# e10l1_AAACTCGCAGCAAGTC-1 SeuratProject 12288      3801         12342
# e10l1_AAAGCCAGTTAGCTAC-1 SeuratProject  9592      3941          4147
# e10l1_AAAGCCAGTTAGTTTG-1 SeuratProject 19576      5255          3343
# e10l1_AAAGCGAAGACTCCTA-1 SeuratProject 14304      4690          7353
# e10l1_AAAGCGAAGCTTATCG-1 SeuratProject 15916      4829          3733
# e10l1_AAAGCGAAGGCTAGCA-1 SeuratProject  7450      3359          5900
# e10l1_AAAGCGAAGTGCACCT-1 SeuratProject 10455      4032         15235
# e10l1_AAAGGCGCACTGGGAT-1 SeuratProject 10041      3890          2066
# e10l1_AAAGGCGCAGCTCGAG-1 SeuratProject 15041      4416          8285
# e10l1_AAAGGCTTCCACTAAT-1 SeuratProject 15536      4710          7020
# e10l1_AAAGCGAAGCTTATCG-1 0               1    ⋯ k562_crispri
# e10l1_AAAGCGAAGGCTAGCA-1 3               1    ⋯ k562_crispri
# e10l1_AAAGCGAAGTGCACCT-1 1               1    ⋯ k562_crispri
# e10l1_AAAGGCGCACTGGGAT-1 2               1    ⋯ k562_crispri
# e10l1_AAAGGCGCAGCTCGAG-1 3               1    ⋯ k562_crispri
# e10l1_AAAGGCTTCCACTAAT-1 0               1    ⋯ k562_crispri
# e10l1_AAAGGCTTCCTAAATC-1 0               1    ⋯ k562_crispri
# e10l1_AAAGGGATCGCTCAAC-1 0               1    ⋯ k562_crispri
# e10l1_AAAGTCATCCAGCTAC-1 0               1    ⋯ k562_crispri
# e10l1_AAAGTCATCGAAGTTA-1 1               1    ⋯ k562_crispri
# e10l1_AAAGTCATCGCTAATT-1 4               1    ⋯ k562_crispri
# e10l1_AAATCCTTCATTCAGT-1 1               1    ⋯ k562_crispri
# e10l1_AACAACATCAGGATCG-1 4               1    ⋯ k562_crispri
# e10l1_AACAAGTGTACGCACC-1 4               1    ⋯ k562_crispri
# e10l1_AACAAGTGTGAAACAT-1 3               1    ⋯ k562_crispri
# e10l1_AACACTAAGGCCTTGT-1 1               1    ⋯ k562_crispri
# ⋮                        ⋮               ⋮    ⋱ ⋮
# e10l2_TTGTGTCCAACATAGT-1 1               2    ⋯ k562_crispri
# e10l2_TTGTTGAGTACCGTGC-1 4               2    ⋯ k562_crispri
# e10l2_TTGTTGAGTATTCGGT-1 3               2    ⋯ k562_crispri
# e10l2_TTGTTGTAGCTTAGTT-1 0               2    ⋯ k562_crispri
# e10l2_TTTAACCAGAATCACA-1 2               2    ⋯ k562_crispri
# e10l2_TTTAACGGTGTCCACA-1 4               2    ⋯ k562_crispri
# e10l2_TTTAACGGTTACGAAG-1 3               2    ⋯ k562_crispri
# e10l2_TTTAAGCTCATTGAGA-1 3               2    ⋯ k562_crispri
# e10l2_TTTAAGGAGGCCTTGT-1 0               2    ⋯ k562_crispri
# e10l2_TTTAAGGAGTCAATTC-1 3               2    ⋯ k562_crispri
# e10l2_TTTACTGCAGTATTGG-1 5               2    ⋯ k562_crispri
# e10l2_TTTAGCTAGTTGCAGG-1 0               2    ⋯ k562_crispri
# e10l2_TTTAGGCGTGCACGCT-1 7               2    ⋯ k562_crispri
# e10l2_TTTATCCGTTAAGGAT-1 5               2    ⋯ k562_crispri
# e10l2_TTTCAAGGTGAAACAT-1 7               2    ⋯ k562_crispri
# e10l2_TTTCAGTAGATGAAGG-1 7               2    ⋯ k562_crispri
# e10l2_TTTCAGTAGCTATCGC-1 3               2    ⋯ k562_crispri
# e10l2_TTTCAGTAGTTACATC-1 7               2    ⋯ k562_crispri
# e10l2_TTTCCGGCAGGCAACT-1 2               2    ⋯ k562_crispri
# e10l2_TTTCCTGGTCGTAATC-1 1               2    ⋯ k562_crispri
# e10l2_TTTCCTGGTGCGTAAA-1 0               2    ⋯ k562_crispri
# e10l2_TTTCTCATCACATTAC-1 6               2    ⋯ k562_crispri
# e10l2_TTTCTCATCGCCTAAC-1 4               2    ⋯ k562_crispri
# e10l1_AAAGCCAGTTAGTTTG-1 0.05           8               1
# e10l1_AAAGCGAAGACTCCTA-1 0.97           0               3
# e10l1_AAAGCGAAGCTTATCG-1 0.97           12              0
# e10l1_AAAGCGAAGGCTAGCA-1 0.91           4               3
# e10l1_AAAGCGAAGTGCACCT-1 0.14           3               1
# e10l1_AAAGGCGCACTGGGAT-1 0.24           11              2
# e10l1_AAAGGCGCAGCTCGAG-1 0.44           0               3
# e10l1_AAAGGCTTCCACTAAT-1 0.45           3               0
# e10l1_AAAGGCTTCCTAAATC-1 0.77           2               0
# e10l1_AAAGGGATCGCTCAAC-1 0.06           12              0
# e10l1_AAAGTCATCCAGCTAC-1 0.83           4               0
# e10l1_AAAGTCATCGAAGTTA-1 0.31           1               1
# e10l1_AAAGTCATCGCTAATT-1 0.31           6               4
# e10l1_AAATCCTTCATTCAGT-1 0.45           3               1
# e10l1_AACAACATCAGGATCG-1 0.93           1               4
# e10l1_AACAAGTGTACGCACC-1 1.00           1               4
# e10l1_AACAAGTGTGAAACAT-1 0.87           0               3
# e10l1_AACACTAAGGCCTTGT-1 0.85           2               1
# ⋮                        ⋮              ⋮               ⋮
# e10l2_TTGTGTCCAACATAGT-1 0.32           12              1
# e10l2_TTGTTGAGTACCGTGC-1 0.66           6               4
# e10l2_TTGTTGAGTATTCGGT-1 0.98           0               3
# e10l2_TTGTTGTAGCTTAGTT-1 0.67           1               0
# e10l2_TTTAACCAGAATCACA-1 0.38           2               2
# e10l2_TTTAACGGTGTCCACA-1 0.01           6               4
# e10l2_TTTAACGGTTACGAAG-1 0.97           0               3
# e10l2_TTTAAGCTCATTGAGA-1 0.39           0               3
# e10l2_TTTAAGGAGGCCTTGT-1 0.18           3               0
# e10l2_TTTAAGGAGTCAATTC-1 0.63           0               3
# e10l2_TTTACTGCAGTATTGG-1 0.67           12              5
# e10l2_TTTAGCTAGTTGCAGG-1 0.26           2               0
# e10l2_TTTAGGCGTGCACGCT-1 0.85           8               7
# e10l2_TTTATCCGTTAAGGAT-1 0.94           0               5
# e10l2_TTTCAAGGTGAAACAT-1 0.95           2               7
# e10l2_TTTCAGTAGATGAAGG-1 0.52           8               7
# e10l2_TTTCAGTAGCTATCGC-1 0.69           0               3
# e10l2_TTTCAGTAGTTACATC-1 0.13           5               7
# e10l2_TTTCCGGCAGGCAACT-1 0.57           5               2
# e10l2_TTTCCTGGTCGTAATC-1 0.06           10              1
# e10l2_TTTCCTGGTGCGTAAA-1 0.88           2               0
# e10l2_TTTCTCATCACATTAC-1 0.39           4               6
# e10l2_TTTCTCATCGCCTAAC-1 0.76           6               4
# e10l2_TTTCTTGTCGCGAGTA-1 0.83           3               1
# e10l2_TTTGGAGCACGGATCG-1 0.90           10              0
# e10l2_TTTGGAGCATGCTCCA-1 0.54           6               4
# e10l2_TTTGTCGAGGATGCGC-1 0.78           3               0
# e10l2_TTTGTGAGTATAGCTC-1 0.65           5               7
# e10l2_TTTGTGAGTTAGCGTT-1 0.49           8               7
# e10l2_TTTGTGAGTTCCGGAC-1 0.35           0               3
# e10l2_TTTCAAGGTGAAACAT-1 TTTCAAGGTGAAACAT-1 27.9122850 e10l2_TTTCAAGGTGAAACAT-1
# e10l2_TTTCAGTAGATGAAGG-1 TTTCAGTAGATGAAGG-1 25.8156028 e10l2_TTTCAGTAGATGAAGG-1
# e10l2_TTTCAGTAGCTATCGC-1 TTTCAGTAGCTATCGC-1 20.4648934 e10l2_TTTCAGTAGCTATCGC-1
# e10l2_TTTCAGTAGTTACATC-1 TTTCAGTAGTTACATC-1  0.8924145 e10l2_TTTCAGTAGTTACATC-1
# e10l2_TTTCCGGCAGGCAACT-1 TTTCCGGCAGGCAACT-1 17.3553719 e10l2_TTTCCGGCAGGCAACT-1
# e10l2_TTTCCTGGTCGTAATC-1 TTTCCTGGTCGTAATC-1  4.4559912 e10l2_TTTCCTGGTCGTAATC-1
# e10l2_TTTCCTGGTGCGTAAA-1 TTTCCTGGTGCGTAAA-1  1.4516745 e10l2_TTTCCTGGTGCGTAAA-1
# e10l2_TTTCTCATCACATTAC-1 TTTCTCATCACATTAC-1 28.2125000 e10l2_TTTCTCATCACATTAC-1
# e10l2_TTTCTCATCGCCTAAC-1 TTTCTCATCGCCTAAC-1  1.5193370 e10l2_TTTCTCATCGCCTAAC-1
# e10l2_TTTCTTGTCGCGAGTA-1 TTTCTTGTCGCGAGTA-1 17.0618971 e10l2_TTTCTTGTCGCGAGTA-1
# e10l2_TTTGGAGCACGGATCG-1 TTTGGAGCACGGATCG-1  5.0496824 e10l2_TTTGGAGCACGGATCG-1
# e10l2_TTTGGAGCATGCTCCA-1 TTTGGAGCATGCTCCA-1  3.5298334 e10l2_TTTGGAGCATGCTCCA-1
# e10l2_TTTGTCGAGGATGCGC-1 TTTGTCGAGGATGCGC-1 20.0530370 e10l2_TTTGTCGAGGATGCGC-1
# e10l2_TTTGTGAGTATAGCTC-1 TTTGTGAGTATAGCTC-1 27.2514620 e10l2_TTTGTGAGTATAGCTC-1
# e10l2_TTTGTGAGTTAGCGTT-1 TTTGTGAGTTAGCGTT-1  2.1152443 e10l2_TTTGTGAGTTAGCGTT-1
# e10l2_TTTGTGAGTTCCGGAC-1 TTTGTGAGTTCCGGAC-1 18.1946766 e10l2_TTTGTGAGTTCCGGAC-1

# %%
peakinfo = do.call(rbind,
                   strsplit(rownames(matrix.atac),"-"))
peakinfo = as.data.frame(peakinfo)
names(peakinfo) <- c("chr", "bp1", "bp2")
peakinfo$site_name <- paste(peakinfo$chr, peakinfo$bp1, peakinfo$bp2, sep="-")
row.names(peakinfo) <- peakinfo$site_name                   
peakinfo
# Out:
#                          chr  bp1       bp2       site_name
# chr1-10002642-10003186   chr1 10002642  10003186  chr1-10002642-10003186
# chr1-100028297-100029654 chr1 100028297 100029654 chr1-100028297-100029654
# chr1-10003425-10004218   chr1 10003425  10004218  chr1-10003425-10004218
# chr1-100036849-100037340 chr1 100036849 100037340 chr1-100036849-100037340
# chr1-100037744-100039006 chr1 100037744 100039006 chr1-100037744-100039006
# chr1-100044692-100045575 chr1 100044692 100045575 chr1-100044692-100045575
# chr1-100046070-100046583 chr1 100046070 100046583 chr1-100046070-100046583
# chrX-98573455-98574099   chrX 98573455  98574099  chrX-98573455-98574099
# chrX-9864063-9864409     chrX 9864063   9864409   chrX-9864063-9864409
# chrX-9873736-9874287     chrX 9873736   9874287   chrX-9873736-9874287
# chrX-9882537-9883461     chrX 9882537   9883461   chrX-9882537-9883461
# chrX-9885199-9885463     chrX 9885199   9885463   chrX-9885199-9885463
# chrX-9894528-9895196     chrX 9894528   9895196   chrX-9894528-9895196
# chrX-989766-990603       chrX 989766    990603    chrX-989766-990603
# chrX-99372004-99372431   chrX 99372004  99372431  chrX-99372004-99372431
# chrX-9940388-9940708     chrX 9940388   9940708   chrX-9940388-9940708
# chrX-9966874-9967060     chrX 9966874   9967060   chrX-9966874-9967060
# chrX-9995829-9996183     chrX 9995829   9996183   chrX-9995829-9996183

# %%
input_cds <-  suppressWarnings(new_cell_data_set(matrix.atac,
                               cell_metadata = cellinfo,
                               gene_metadata = peakinfo))

# %%
input_cds <- monocle3::detect_genes(input_cds)
#Ensure there are no peaks included with zero reads
input_cds <- input_cds[Matrix::rowSums(exprs(input_cds)) != 0,]

# %%
set.seed(2017)
input_cds <- detect_genes(input_cds)
input_cds <- estimate_size_factors(input_cds)
input_cds <- preprocess_cds(input_cds, method = "LSI")
input_cds <- reduce_dimension(input_cds, reduction_method = 'UMAP', 
                              preprocess_method = "LSI")
# Out:
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'

# %%
plot_cells(input_cds)
# Out:
# No trajectory to plot. Has learn_graph() been called yet?
#
# cluster not found in colData(cds), cells will not be colored
#
# cluster_cells() has not been called yet, can't color cells by cluster
# plot without title

# %%
umap_coords <- reducedDims(input_cds)$UMAP
cicero_cds <- make_cicero_cds(input_cds, reduced_coordinates = umap_coords)
# Out:
# Overlap QC metrics:
# Cells per bin: 50
# Maximum shared cells bin-bin: 44
# Mean shared cells bin-bin: 0.569141663664591
# Median shared cells bin-bin: 0

# %% [markdown]
# Run Cicero

# %%
human.hg38.genome = read.table(path.chrom.sizes,
                               header = F)
human.hg38.genome
# Out:
#     V1                     V2
# 1   chr1                   248956422
# 2   chr2                   242193529
# 3   chr3                   198295559
# 4   chr4                   190214555
# 5   chr5                   181538259
# 6   chr6                   170805979
# 7   chr7                   159345973
# 8   chr8                   145138636
# 9   chr9                   138394717
# 10  chr10                  133797422
# 11  chr11                  135086622
# 12  chr12                  133275309
# 13  chr13                  114364328
# 14  chr14                  107043718
# 15  chr15                  101991189
# 16  chr16                   90338345
# 17  chr17                   83257441
# 18  chr18                   80373285
# 19  chr19                   58617616
# 20  chr20                   64444167
# 21  chr21                   46709983
# 22  chr22                   50818468
# 23  chrX                   156040895
# 24  chrY                    57227415
# 25  chrM                       16569
# 26  chr1_GL383518v1_alt       182439
# 27  chr1_GL383519v1_alt       110268
# 28  chr1_GL383520v2_alt       366580
# 29  chr1_KI270706v1_random    175055
# 30  chr1_KI270707v1_random     32032
# ⋮   ⋮                      ⋮
# 427 chrUn_KI270579v1        31033
# 428 chrUn_KI270580v1         1553
# 429 chrUn_KI270581v1         7046
# 430 chrUn_KI270582v1         6504
# 431 chrUn_KI270583v1         1400
# 432 chrUn_KI270584v1         4513
# 433 chrUn_KI270587v1         2969
# 434 chrUn_KI270588v1         6158
# 435 chrUn_KI270589v1        44474
# 436 chrUn_KI270590v1         4685
# 437 chrUn_KI270591v1         5796
# 438 chrUn_KI270593v1         3041
# 439 chrUn_KI270741v1       157432
# 440 chrUn_KI270742v1       186739
# 441 chrUn_KI270743v1       210658
# 442 chrUn_KI270744v1       168472
# 443 chrUn_KI270745v1        41891
# 444 chrUn_KI270746v1        66486
# 445 chrUn_KI270747v1       198735
# 446 chrUn_KI270748v1        93321
# 447 chrUn_KI270749v1       158759
# 448 chrUn_KI270750v1       148850
# 449 chrUn_KI270751v1       150742
# 450 chrUn_KI270752v1        27745
# 451 chrUn_KI270753v1        62944
# 452 chrUn_KI270754v1        40191
# 453 chrUn_KI270755v1        36723
# 454 chrUn_KI270756v1        79590
# 455 chrUn_KI270757v1        71251
# 456 chrEBV                 171823

# %%
start_time <- Sys.time()
distance_parameters <- estimate_distance_parameter(cicero_cds, 
                                                   window = window, 
                                                   maxit = 100, 
                                                   sample_num = 100, 
                                                   distance_constraint = distance_constraint,
                                                   distance_parameter_convergence = 1e-22, 
                                                   genomic_coords = human.hg38.genome)
mean_distance_parameter <- mean(unlist(distance_parameters))
end_time <- Sys.time()
execution_time1 <- end_time - start_time

# %%
mean_distance_parameter
# Out:
# [1] 0.365302

# %%
execution_time1
# Out:
# Time difference of 9.280348 mins

# %%
start_time <- Sys.time()
cicero_out <- generate_cicero_models(cicero_cds, 
                                     distance_parameter = mean_distance_parameter, 
                                     window = window, 
                                     genomic_coords = human.hg38.genome)
end_time <- Sys.time()
execution_time2 <- end_time - start_time

# %%
execution_time2
# Out:
# Time difference of 1.970366 hours

# %%
start_time <- Sys.time()
all_cons <- assemble_connections(cicero_out, 
                                 silent = FALSE)
end_time <- Sys.time()
execution_time3 <- end_time - start_time
# Out:
# [1] "Successful cicero models:  2290"
# [1] "Other models: "
#
#   Too many elements in range Zero or one element in range
#                          489                          805
# [1] "Models with errors:  0"

# %%
execution_time3
# Out:
# Time difference of 1.991349 mins

# %% [markdown]
# Assign coaccess to E2G pairs

# %%
all_cons0 = all_cons
all_cons0[is.na(all_cons0[,"coaccess"]),"coaccess"] = 0
bed.peakinfo <- makeGRangesFromDataFrame(peakinfo, 
                                         keep.extra.columns = TRUE,
                                         start.field="bp1",
                                         end.field="bp2")
overlap.res = findOverlaps(bed.peakinfo[all_cons0[,"Peak1"]],
                           bed.TSS1kb)
df.overlap = as.data.frame(overlap.res)
all_cons0.E2G = all_cons0[df.overlap$queryHits,]
all_cons0.E2G[,"Gene"] = bed.TSS1kb[df.overlap$subjectHits]$V4
all_cons0.E2G[,"PairName"] = paste(all_cons0.E2G[,"Peak2"],all_cons0.E2G[,"Gene"],sep = "_")
all_cons0.E2G.sort = all_cons0.E2G[order(all_cons0.E2G[,"coaccess"],decreasing = T),]
all_cons0.E2G.uniq = all_cons0.E2G.sort[!duplicated(all_cons0.E2G.sort$PairName),]
rownames(all_cons0.E2G.uniq) = all_cons0.E2G.uniq$PairName
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% all_cons0.E2G.uniq$PairName]
pairs.E2G.res$coaccess = all_cons0.E2G.uniq[pairs.E2G.res$PairName,"coaccess"]

# %% [markdown]
# Save results

# %%
dir.create(dir.output,recursive = T)
saveRDS(all_cons,
        paste(dir.output,"all_cons.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "coaccess")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 1228679 ranges and 4 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028297-100029654      * |         AGL
#         [2]     chr1 100028297-100029654      * |      CDC14A
#         [3]     chr1 100028297-100029654      * |         DBT
#         [4]     chr1 100028297-100029654      * |        DPH5
#         [5]     chr1 100028297-100029654      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [1228675]     chrX     9995829-9996183      * |       CLCN4
#   [1228676]     chrX     9995829-9996183      * |      CLDN34
#   [1228677]     chrX     9995829-9996183      * |       FAM9B
#   [1228678]     chrX     9995829-9996183      * |       TBL1X
#   [1228679]     chrX     9995829-9996183      * |        WWC3
#                           PeakName               PairName     coaccess
#                        <character>            <character>    <numeric>
#         [1] chr1-100028297-10002.. chr1-100028297-10002..  0.000177423
#         [2] chr1-100028297-10002.. chr1-100028297-10002..  0.012707041
#         [3] chr1-100028297-10002.. chr1-100028297-10002..  0.104389822
#         [4] chr1-100028297-10002.. chr1-100028297-10002..  0.006980769
#         [5] chr1-100028297-10002.. chr1-100028297-10002.. -0.002123763
#         ...                    ...                    ...          ...
#   [1228675]   chrX-9995829-9996183 chrX-9995829-9996183.. -0.001882885
#   [1228676]   chrX-9995829-9996183 chrX-9995829-9996183..  0.000000000
#   [1228677]   chrX-9995829-9996183 chrX-9995829-9996183..  0.000107149
#   [1228678]   chrX-9995829-9996183 chrX-9995829-9996183..  0.002612209
#   [1228679]   chrX-9995829-9996183 chrX-9995829-9996183..  0.005568223
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType coaccess
# 1       chr1 100028297 100029654 AGL        K562      1.774228e-04
# 2       chr1 100028297 100029654 CDC14A     K562      1.270704e-02
# 3       chr1 100028297 100029654 DBT        K562      1.043898e-01
# 4       chr1 100028297 100029654 DPH5       K562      6.980769e-03
# 5       chr1 100028297 100029654 EXTL2      K562     -2.123763e-03
# 6       chr1 100028297 100029654 FRRS1      K562     -1.822109e-03
# 7       chr1 100028297 100029654 LRRC39     K562      0.000000e+00
# 1228673 chrX  9966874   9967060  TBL1X      K562      0.0000000000
# 1228674 chrX  9966874   9967060  WWC3       K562      0.0000000000
# 1228675 chrX  9995829   9996183  CLCN4      K562     -0.0018828850
# 1228676 chrX  9995829   9996183  CLDN34     K562      0.0000000000
# 1228677 chrX  9995829   9996183  FAM9B      K562      0.0001071491
# 1228678 chrX  9995829   9996183  TBL1X      K562      0.0026122089
# 1228679 chrX  9995829   9996183  WWC3       K562      0.0055682226

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ggplot2_3.5.1               Matrix_1.6-5
#  [3] genomation_1.34.0           magrittr_2.0.3
#  [5] Signac_1.13.0               Seurat_5.0.3
#  [7] SeuratObject_5.0.1          sp_2.1-4
#  [9] cicero_1.3.9                Gviz_1.44.2
# [11] monocle3_1.3.7              SingleCellExperiment_1.22.0
# [13] SummarizedExperiment_1.30.2 GenomicRanges_1.54.1
# [15] GenomeInfoDb_1.38.1         IRanges_2.36.0
# [17] S4Vectors_0.40.2            MatrixGenerics_1.12.3
# [19] matrixStats_1.3.0           Biobase_2.60.0
# [21] BiocGenerics_0.48.1
#
# loaded via a namespace (and not attached):
#   [1] ProtGenerics_1.32.0      spatstat.sparse_3.0-3    bitops_1.0-7
#   [4] httr_1.4.7               RColorBrewer_1.1-3       repr_1.1.7
#   [7] tools_4.3.3              sctransform_0.4.1        backports_1.4.1
#  [10] utf8_1.2.4               R6_2.5.1                 uwot_0.1.16
#  [13] lazyeval_0.2.2           withr_3.0.0              prettyunits_1.2.0
#  [16] gridExtra_2.3            progressr_0.14.0         cli_3.6.2
#  [19] Cairo_1.6-2              spatstat.explore_3.2-6   fastDummies_1.7.3
#  [22] labeling_0.4.3           spatstat.data_3.0-4      readr_2.1.5
#  [25] ggridges_0.5.6           pbapply_1.7-2            Rsamtools_2.18.0
#  [28] pbdZMQ_0.3-11            foreign_0.8-86           dichromat_2.0-0.1
#  [31] parallelly_1.37.1        plotrix_3.8-4            BSgenome_1.68.0
#  [34] impute_1.76.0            VGAM_1.1-10              rstudioapi_0.16.0
#  [37] RSQLite_2.3.6            FNN_1.1.4                generics_0.1.3
#  [40] BiocIO_1.10.0            vroom_1.6.5              ica_1.0-3
#  [43] spatstat.random_3.2-3    dplyr_1.1.4              interp_1.1-6
#  [46] fansi_1.0.6              abind_1.4-5              lifecycle_1.0.4
#  [49] yaml_2.3.8               BiocFileCache_2.8.0      Rtsne_0.17
#  [52] blob_1.2.4               promises_1.3.0           crayon_1.5.2
#  [55] miniUI_0.1.1.1           lattice_0.22-6           cowplot_1.1.3
#  [58] GenomicFeatures_1.52.2   KEGGREST_1.40.1          pillar_1.9.0
#  [61] knitr_1.46               rjson_0.2.21             boot_1.3-30
#  [64] future.apply_1.11.2      codetools_0.2-20         fastmatch_1.1-4
#  [67] leiden_0.4.3.1           glue_1.7.0               data.table_1.15.2
#  [70] vctrs_0.6.5              png_0.1-8                spam_2.10-0
#  [73] gtable_0.3.5             assertthat_0.2.1         cachem_1.0.8
#  [76] xfun_0.43                S4Arrays_1.2.1           mime_0.12
#  [79] survival_3.6-4           RcppRoll_0.3.0           fitdistrplus_1.1-11
#  [82] ROCR_1.0-11              nlme_3.1-164             bit64_4.0.5
#  [85] progress_1.2.3           filelock_1.0.3           RcppAnnoy_0.0.22
#  [88] irlba_2.3.5.1            KernSmooth_2.23-22       rpart_4.1.23
#  [91] colorspace_2.1-0         DBI_1.2.2                Hmisc_5.1-2
#  [94] seqPattern_1.34.0        nnet_7.3-19              tidyselect_1.2.1
#  [97] bit_4.0.5                compiler_4.3.3           curl_5.1.0
# [100] htmlTable_2.4.2          xml2_1.3.6               DelayedArray_0.26.7
# [103] plotly_4.10.4            rtracklayer_1.60.1       checkmate_2.3.1
# [106] scales_1.3.0             lmtest_0.9-40            rappdirs_0.3.3
# [109] goftest_1.2-3            stringr_1.5.1            digest_0.6.35
# [112] spatstat.utils_3.0-4     minqa_1.2.6              rmarkdown_2.26
# [115] XVector_0.42.0           htmltools_0.5.8.1        pkgconfig_2.0.3
# [118] jpeg_0.1-10              base64enc_0.1-3          lme4_1.1-35.3
# [121] dbplyr_2.5.0             fastmap_1.1.1            ensembldb_2.24.1
# [124] rlang_1.1.3              htmlwidgets_1.6.4        shiny_1.8.1.1
# [127] farver_2.1.1             zoo_1.8-12               jsonlite_1.8.8
# [130] BiocParallel_1.36.0      VariantAnnotation_1.46.0 RCurl_1.98-1.14
# [133] Formula_1.2-5            GenomeInfoDbData_1.2.11  dotCall64_1.1-1
# [136] patchwork_1.2.0          IRkernel_1.3.2           munsell_0.5.1
# [139] Rcpp_1.0.12              reticulate_1.36.1        stringi_1.8.3
# [142] zlibbioc_1.48.0          MASS_7.3-60              plyr_1.8.9
# [145] parallel_4.3.3           listenv_0.9.1            ggrepel_0.9.5
# [148] deldir_2.0-4             Biostrings_2.70.1        IRdisplay_1.1
# [151] splines_4.3.3            tensor_1.5               hms_1.1.3
# [154] igraph_2.0.3             uuid_1.2-0               spatstat.geom_3.2-9
# [157] RcppHNSW_0.6.0           reshape2_1.4.4           biomaRt_2.56.1
# [160] XML_3.99-0.16.1          evaluate_0.23            latticeExtra_0.6-30
# [163] biovizBase_1.48.0        tzdb_0.4.0               nloptr_2.0.3
# [166] httpuv_1.6.15            RANN_2.6.1               tidyr_1.3.1
# [169] purrr_1.0.2              polyclip_1.10-6          future_1.33.2
# [172] scattermore_1.2          gridBase_0.4-7           xtable_1.8-4
# [175] restfulr_0.0.15          AnnotationFilter_1.24.0  RSpectra_0.16-1
# [178] later_1.3.2              glasso_1.11              viridisLite_0.4.2
# [181] tibble_3.2.1             memoise_2.0.1            AnnotationDbi_1.64.1
# [184] GenomicAlignments_1.36.0 cluster_2.1.6            globals_0.16.3
