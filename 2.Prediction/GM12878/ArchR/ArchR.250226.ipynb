# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/1.prepare_data/1.seurat_pipeline.240615/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/ArchR_250226/ArchR.250226/"

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_240614/GM12878/cellranger_res/"| __truncated__
#   .. ..@ hash : chr [1:2] "a5984ec1fe8d8e28c00a2146ef41d26d" "6e3871eeb1cd823c9aaa4c7bb93361fd"
#   .. ..@ cells: Named chr [1:3050] "AAACAGCCACTAAGAA-1" "AAACAGCCATAATCAC-1" "AAACATGCACTTGTTC-1" "AAACATGCATAATCAC-1" ...
#   .. .. ..- attr(*, "names")= chr [1:3050] "GM12878_AAACAGCCACTAAGAA-1" "GM12878_AAACAGCCATAATCAC-1" "GM12878_AAACATGCACTTGTTC-1" "GM12878_AAACATGCATAATCAC-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("GM12878"),
  validBarcodes = list(GM12878 = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-2a915716ecc94e-Date-2025-02-26_Time-14-54-23.95099.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2025-02-26 14:54:24.464124 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (GM12878 : 1 of 1) Determining Arrow Method to use!
#
# 2025-02-26 14:54:24.528878 : (GM12878 : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.001 mins elapsed.
#
# 2025-02-26 14:54:24.537632 : (GM12878 : 1 of 1) Tabix Bed To Temporary File, 0.001 mins elapsed.
#
# 2025-02-26 14:55:20.567719 : (GM12878 : 1 of 1) Successful creation of Temporary File, 0.935 mins elapsed.
#
# 2025-02-26 14:55:20.575225 : (GM12878 : 1 of 1) Creating ArrowFile From Temporary File, 0.935 mins elapsed.
#
# 2025-02-26 14:55:47.069499 : (GM12878 : 1 of 1) Successful creation of Arrow File, 1.377 mins elapsed.
#
# 2025-02-26 14:56:05.539683 : Continuing through after error ggplot for Fragment Size Distribution, 1.685 mins elapsed.
#
#
#
#
# 2025-02-26 14:56:36.059578 : (GM12878 : 1 of 1) CellStats : Number of Cells Pass Filter = 3032 , 2.193 mins elapsed.
#
# 2025-02-26 14:56:36.064623 : (GM12878 : 1 of 1) CellStats : Median Frags = 14044.5 , 2.193 mins elapsed.
#
# 2025-02-26 14:56:36.069814 : (GM12878 : 1 of 1) CellStats : Median TSS Enrichment = 15.2195 , 2.193 mins elapsed.
#
# 2025-02-26 14:56:36.802024 : Continuing through after error ggplot for TSS by Frags, 2.206 mins elapsed.
#
#
#
#
# 2025-02-26 14:56:40.302992 : (GM12878 : 1 of 1) Adding Additional Feature Counts!, 2.264 mins elapsed.
#
# 2025-02-26 14:57:03.240424 : (GM12878 : 1 of 1) Removing Fragments from Filtered Cells, 2.646 mins elapsed.
#
# 2025-02-26 14:57:03.251744 : (GM12878 : 1 of 1) Creating Filtered Arrow File, 2.646 mins elapsed.
#
# 2025-02-26 14:58:28.179487 : (GM12878 : 1 of 1) Finished Constructing Filtered Arrow File!, 4.062 mins elapsed.
#
# 2025-02-26 14:58:28.400719 : (GM12878 : 1 of 1) Adding TileMatrix!, 4.066 mins elapsed.
#
# 2025-02-26 15:02:43.376103 : (GM12878 : 1 of 1) Finished Creating Arrow File, 8.315 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-2a915716ecc94e-Date-2025-02-26_Time-14-54-23.95099.log

# %%
ArrowFiles
# Out:
# [1] "GM12878.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/ArchR_250226/ArchR.250226/ArchR
# samples(1): GM12878
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 3032
# medianTSS(1): 15.2195
# medianFrags(1): 14044.5

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-2a915759d0365e-Date-2025-02-26_Time-15-02-49.477491.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 15:02:50.053065 : Computing Total Across All Features, 0 mins elapsed.
#
# 2025-02-26 15:02:51.096116 : Computing Top Features, 0.018 mins elapsed.
#
# ###########
# 2025-02-26 15:02:53.487774 : Running LSI (1 of 2) on Top Features, 0.058 mins elapsed.
# ###########
#
# 2025-02-26 15:02:53.500573 : Creating Partial Matrix, 0.058 mins elapsed.
#
# 2025-02-26 15:03:02.760445 : Computing LSI, 0.212 mins elapsed.
#
# 2025-02-26 15:03:27.511592 : Identifying Clusters, 0.625 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2025-02-26 15:03:31.249812 : Identified 6 Clusters, 0.687 mins elapsed.
#
# 2025-02-26 15:03:31.267457 : Saving LSI Iteration, 0.687 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2025-02-26 15:03:42.850188 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-2a915759d0365e-Date-2025-02-26_Time-15-02-49.477491.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2025-02-26 15:03:42.85221 : Creating Cluster Matrix on the total Group Features, 0.88 mins elapsed.
#
# 2025-02-26 15:03:59.316927 : Computing Variable Features, 1.155 mins elapsed.
#
# ###########
# 2025-02-26 15:03:59.467777 : Running LSI (2 of 2) on Variable Features, 1.157 mins elapsed.
# ###########
#
# 2025-02-26 15:03:59.481074 : Creating Partial Matrix, 1.158 mins elapsed.
#
# 2025-02-26 15:04:10.491966 : Computing LSI, 1.341 mins elapsed.
#
# 2025-02-26 15:04:39.924722 : Finished Running IterativeLSI, 1.832 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-2a91571392b5fe-Date-2025-02-26_Time-15-04-43.86654.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 15:04:44.112888 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 15:04:44.916435 : Adding GM12878 to PeakMatrix for Chr (1 of 23)!, 0.012 mins elapsed.
#
# 2025-02-26 15:04:54.316475 : Adding GM12878 to PeakMatrix for Chr (2 of 23)!, 0.169 mins elapsed.
#
# 2025-02-26 15:05:01.402203 : Adding GM12878 to PeakMatrix for Chr (3 of 23)!, 0.287 mins elapsed.
#
# 2025-02-26 15:05:08.317939 : Adding GM12878 to PeakMatrix for Chr (4 of 23)!, 0.403 mins elapsed.
#
# 2025-02-26 15:05:12.910614 : Adding GM12878 to PeakMatrix for Chr (5 of 23)!, 0.479 mins elapsed.
#
# 2025-02-26 15:05:18.254376 : Adding GM12878 to PeakMatrix for Chr (6 of 23)!, 0.568 mins elapsed.
#
# 2025-02-26 15:05:23.521483 : Adding GM12878 to PeakMatrix for Chr (7 of 23)!, 0.656 mins elapsed.
#
# 2025-02-26 15:05:28.261906 : Adding GM12878 to PeakMatrix for Chr (8 of 23)!, 0.735 mins elapsed.
#
# 2025-02-26 15:05:33.146007 : Adding GM12878 to PeakMatrix for Chr (9 of 23)!, 0.816 mins elapsed.
#
# 2025-02-26 15:05:37.855247 : Adding GM12878 to PeakMatrix for Chr (10 of 23)!, 0.895 mins elapsed.
#
# 2025-02-26 15:05:44.043865 : Adding GM12878 to PeakMatrix for Chr (11 of 23)!, 0.998 mins elapsed.
#
# 2025-02-26 15:05:51.002447 : Adding GM12878 to PeakMatrix for Chr (12 of 23)!, 1.114 mins elapsed.
#
# 2025-02-26 15:05:57.368225 : Adding GM12878 to PeakMatrix for Chr (13 of 23)!, 1.22 mins elapsed.
#
# 2025-02-26 15:06:03.130856 : Adding GM12878 to PeakMatrix for Chr (14 of 23)!, 1.316 mins elapsed.
#
# 2025-02-26 15:06:09.237327 : Adding GM12878 to PeakMatrix for Chr (15 of 23)!, 1.418 mins elapsed.
#
# 2025-02-26 15:06:15.678652 : Adding GM12878 to PeakMatrix for Chr (16 of 23)!, 1.525 mins elapsed.
#
# 2025-02-26 15:06:21.547006 : Adding GM12878 to PeakMatrix for Chr (17 of 23)!, 1.623 mins elapsed.
#
# 2025-02-26 15:06:26.856956 : Adding GM12878 to PeakMatrix for Chr (18 of 23)!, 1.712 mins elapsed.
#
# 2025-02-26 15:06:30.935669 : Adding GM12878 to PeakMatrix for Chr (19 of 23)!, 1.779 mins elapsed.
#
# 2025-02-26 15:06:37.194748 : Adding GM12878 to PeakMatrix for Chr (20 of 23)!, 1.884 mins elapsed.
#
# 2025-02-26 15:06:41.571336 : Adding GM12878 to PeakMatrix for Chr (21 of 23)!, 1.957 mins elapsed.
#
# 2025-02-26 15:06:45.702896 : Adding GM12878 to PeakMatrix for Chr (22 of 23)!, 2.026 mins elapsed.
#
# 2025-02-26 15:06:49.98816 : Adding GM12878 to PeakMatrix for Chr (23 of 23)!, 2.097 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-2a91571392b5fe-Date-2025-02-26_Time-15-04-43.86654.log

# %%
seRNA.Xu = ArchR:::.importFM(featureMatrix = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5",
                             name = "K562_Xu",
                             featureType = "Gene Expression")
rowdata.Xu = rowData(seRNA.Xu)

# %%
gene.intersect = intersect(rownames(obj.seurat@assays$RNA$counts),
                           rowdata.Xu$name)
rowdata.intersect = rowdata.Xu[gene.intersect,]

# %%
rr = GRanges(paste0(rowdata.intersect$interval))
mcols(rr) <- rowdata.intersect

# %%
count.rna = obj.seurat@assays$RNA$counts[gene.intersect,]
colnames(count.rna) = gsub("GM12878_","GM12878#",colnames(count.rna))

# %%
seRNA <- SummarizedExperiment(assays = SimpleList(counts = count.rna), 
                              rowRanges = rr)
seRNA = sort.GenomicRanges(sortSeqlevels(seRNA), 
                           ignore.strand = TRUE)

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61214 3050
# metadata(0):
# assays(1): counts
# rownames(61214): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(3050): GM12878#AAACAGCCACTAAGAA-1 GM12878#AAACAGCCATAATCAC-1
#   ... GM12878#TTTGTTGGTCACAAAT-1 GM12878#TTTGTTGGTTGGTGAC-1
# colData names(0):

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
    library(dplyr)
    library(data.table)
    
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
seRNA.rename = map_gene_names(seRNA,gene_gtf_path, abc_genes_path)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:Biostrings’:
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA.rename,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a9157af66a61-Date-2025-02-26_Time-15-07-43.791545.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2025-02-26 15:07:44.153276 :
#
# Overlap Per Sample w/ scATAC : GM12878=3032
#
# 2025-02-26 15:07:44.162591 :
#
# 2025-02-26 15:07:45.122836 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 15:07:45.71278 : Adding GM12878 to GeneExpressionMatrix for Chr (1 of 23)!, 0.01 mins elapsed.
#
# 2025-02-26 15:07:51.564012 : Adding GM12878 to GeneExpressionMatrix for Chr (2 of 23)!, 0.107 mins elapsed.
#
# 2025-02-26 15:07:55.451348 : Adding GM12878 to GeneExpressionMatrix for Chr (3 of 23)!, 0.172 mins elapsed.
#
# 2025-02-26 15:08:01.19988 : Adding GM12878 to GeneExpressionMatrix for Chr (4 of 23)!, 0.268 mins elapsed.
#
# 2025-02-26 15:08:06.11187 : Adding GM12878 to GeneExpressionMatrix for Chr (5 of 23)!, 0.35 mins elapsed.
#
# 2025-02-26 15:08:10.343095 : Adding GM12878 to GeneExpressionMatrix for Chr (6 of 23)!, 0.42 mins elapsed.
#
# 2025-02-26 15:08:15.942293 : Adding GM12878 to GeneExpressionMatrix for Chr (7 of 23)!, 0.514 mins elapsed.
#
# 2025-02-26 15:08:20.100099 : Adding GM12878 to GeneExpressionMatrix for Chr (8 of 23)!, 0.583 mins elapsed.
#
# 2025-02-26 15:08:24.631925 : Adding GM12878 to GeneExpressionMatrix for Chr (9 of 23)!, 0.658 mins elapsed.
#
# 2025-02-26 15:08:32.331074 : Adding GM12878 to GeneExpressionMatrix for Chr (10 of 23)!, 0.787 mins elapsed.
#
# 2025-02-26 15:08:37.481727 : Adding GM12878 to GeneExpressionMatrix for Chr (11 of 23)!, 0.873 mins elapsed.
#
# 2025-02-26 15:08:42.526609 : Adding GM12878 to GeneExpressionMatrix for Chr (12 of 23)!, 0.957 mins elapsed.
#
# 2025-02-26 15:08:50.109278 : Adding GM12878 to GeneExpressionMatrix for Chr (13 of 23)!, 1.083 mins elapsed.
#
# 2025-02-26 15:08:59.420269 : Adding GM12878 to GeneExpressionMatrix for Chr (14 of 23)!, 1.238 mins elapsed.
#
# 2025-02-26 15:09:04.801277 : Adding GM12878 to GeneExpressionMatrix for Chr (15 of 23)!, 1.328 mins elapsed.
#
# 2025-02-26 15:09:12.357201 : Adding GM12878 to GeneExpressionMatrix for Chr (16 of 23)!, 1.454 mins elapsed.
#
# 2025-02-26 15:09:17.59419 : Adding GM12878 to GeneExpressionMatrix for Chr (17 of 23)!, 1.541 mins elapsed.
#
# 2025-02-26 15:09:23.052462 : Adding GM12878 to GeneExpressionMatrix for Chr (18 of 23)!, 1.632 mins elapsed.
#
# 2025-02-26 15:09:31.249243 : Adding GM12878 to GeneExpressionMatrix for Chr (19 of 23)!, 1.769 mins elapsed.
#
# 2025-02-26 15:09:36.937898 : Adding GM12878 to GeneExpressionMatrix for Chr (20 of 23)!, 1.864 mins elapsed.
#
# 2025-02-26 15:09:42.593445 : Adding GM12878 to GeneExpressionMatrix for Chr (21 of 23)!, 1.958 mins elapsed.
#
# 2025-02-26 15:09:50.0072 : Adding GM12878 to GeneExpressionMatrix for Chr (22 of 23)!, 2.081 mins elapsed.
#
# 2025-02-26 15:09:56.424115 : Adding GM12878 to GeneExpressionMatrix for Chr (23 of 23)!, 2.188 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a9157af66a61-Date-2025-02-26_Time-15-07-43.791545.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-2a9157196e4fff-Date-2025-02-26_Time-15-10-04.278177.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 15:10:04.64529 : Getting Available Matrices, 0.006 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2025-02-26 15:10:05.021225 : Filtered Low Prediction Score Cells (0 of 3032, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2025-02-26 15:10:05.119867 : Computing KNN, 0.002 mins elapsed.
#
# 2025-02-26 15:10:05.389711 : Identifying Non-Overlapping KNN pairs, 0.006 mins elapsed.
#
# 2025-02-26 15:10:07.170779 : Identified 499 Groupings!, 0.036 mins elapsed.
#
# 2025-02-26 15:10:07.208972 : Getting Group RNA Matrix, 0.037 mins elapsed.
#
# 2025-02-26 15:10:27.417978 : Getting Group ATAC Matrix, 0.374 mins elapsed.
#
# 2025-02-26 15:10:52.171213 : Normalizing Group Matrices, 0.786 mins elapsed.
#
# 2025-02-26 15:10:58.616725 : Finding Peak Gene Pairings, 0.894 mins elapsed.
#
# 2025-02-26 15:10:59.415321 : Computing Correlations, 0.907 mins elapsed.
#
# 2025-02-26 15:11:14.792764 : Completed Peak2Gene Correlations!, 1.163 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-2a9157196e4fff-Date-2025-02-26_Time-15-10-04.278177.log

# %%
execution_time
# Out:
# Time difference of 1.175743 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 3417150 rows and 7 columns
#                                 idxATAC    idxRNA Correlation       FDR
#                               <integer> <integer>   <numeric> <numeric>
# chr1-180700-181061_FAM138A            1         1         NaN       NaN
# chr1-181282-181914_FAM138A            2         1         NaN       NaN
# chr1-267886-268118_FAM138A            3         1         NaN       NaN
# chr1-586095-586295_FAM138A            4         1         NaN       NaN
# chr1-778328-779254_FAM138A            5         1         NaN       NaN
# ...                                 ...       ...         ...       ...
# chrX-155981990-155982304_IL9R    155266     20493  -0.0474404  0.376047
# chrX-155997270-155998098_IL9R    155267     20493  -0.0829243  0.103852
# chrX-156000622-156000826_IL9R    155268     20493   0.0152770  0.793101
# chrX-156004204-156004495_IL9R    155269     20493  -0.0259362  0.645091
# chrX-156030527-156030695_IL9R    155270     20493   0.0245413  0.664273
#                                VarQATAC   VarQRNA               PairName
#                               <numeric> <numeric>            <character>
# chr1-180700-181061_FAM138A     0.222226 0.0639243 chr1-180700-181061_F..
# chr1-181282-181914_FAM138A     0.615637 0.0639243 chr1-181282-181914_F..
# chr1-267886-268118_FAM138A     0.447234 0.0639243 chr1-267886-268118_F..
# chr1-586095-586295_FAM138A     0.213338 0.0639243 chr1-586095-586295_F..
# chr1-778328-779254_FAM138A     0.988446 0.0639243 chr1-778328-779254_F..
# ...                                 ...       ...                    ...
# chrX-155981990-155982304_IL9R 0.0518516  0.390377 chrX-155981990-15598..
# chrX-155997270-155998098_IL9R 0.7083918  0.390377 chrX-155997270-15599..
# chrX-156000622-156000826_IL9R 0.0232241  0.390377 chrX-156000622-15600..
# chrX-156004204-156004495_IL9R 0.0555033  0.390377 chrX-156004204-15600..
# chrX-156030527-156030695_IL9R 0.0943518  0.390377 chrX-156030527-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 2628622 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028533-100029101      * |         AGL
#         [2]     chr1 100028533-100029101      * |      CDC14A
#         [3]     chr1 100028533-100029101      * |         DBT
#         [4]     chr1 100028533-100029101      * |        DPH5
#         [5]     chr1 100028533-100029101      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2628618]     chrX     9995654-9996249      * |       TBL1X
#   [2628619]     chrX     9995654-9996249      * |        WWC3
#   [2628620]     chrX     9997430-9997980      * |       CLCN4
#   [2628621]     chrX     9997430-9997980      * |       TBL1X
#   [2628622]     chrX     9997430-9997980      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028533-10002.. chr1-100028533-10002..   0.2390602
#         [2] chr1-100028533-10002.. chr1-100028533-10002..   0.2506110
#         [3] chr1-100028533-10002.. chr1-100028533-10002..  -0.0063773
#         [4] chr1-100028533-10002.. chr1-100028533-10002..   0.1091928
#         [5] chr1-100028533-10002.. chr1-100028533-10002..   0.2977003
#         ...                    ...                    ...         ...
#   [2628618]   chrX-9995654-9996249 chrX-9995654-9996249..   -0.122068
#   [2628619]   chrX-9995654-9996249 chrX-9995654-9996249..   -0.114240
#   [2628620]   chrX-9997430-9997980 chrX-9997430-9997980..    0.104033
#   [2628621]   chrX-9997430-9997980 chrX-9997430-9997980..   -0.373740
#   [2628622]   chrX-9997430-9997980 chrX-9997430-9997980..   -0.109514
#                     FDR  VarQATAC   VarQRNA
#               <numeric> <numeric> <numeric>
#         [1] 3.12426e-07  0.250042  0.798029
#         [2] 7.28251e-08  0.250042  0.928951
#         [3] 9.15741e-01  0.250042  0.679256
#         [4] 2.82710e-02  0.250042  0.853413
#         [5] 8.38844e-11  0.250042  0.962768
#         ...         ...       ...       ...
#   [2628618] 1.33149e-02  0.705513  0.950471
#   [2628619] 2.12402e-02  0.705513  0.811106
#   [2628620] 3.74134e-02  0.831764  0.378178
#   [2628621] 7.04057e-17  0.831764  0.950471
#   [2628622] 2.77710e-02  0.831764  0.811106
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 2628622 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028533-100029101      * |         AGL
#         [2]     chr1 100028533-100029101      * |      CDC14A
#         [3]     chr1 100028533-100029101      * |         DBT
#         [4]     chr1 100028533-100029101      * |        DPH5
#         [5]     chr1 100028533-100029101      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2628618]     chrX     9995654-9996249      * |       TBL1X
#   [2628619]     chrX     9995654-9996249      * |        WWC3
#   [2628620]     chrX     9997430-9997980      * |       CLCN4
#   [2628621]     chrX     9997430-9997980      * |       TBL1X
#   [2628622]     chrX     9997430-9997980      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028533-10002.. chr1-100028533-10002..   0.2390602
#         [2] chr1-100028533-10002.. chr1-100028533-10002..   0.2506110
#         [3] chr1-100028533-10002.. chr1-100028533-10002..  -0.0063773
#         [4] chr1-100028533-10002.. chr1-100028533-10002..   0.1091928
#         [5] chr1-100028533-10002.. chr1-100028533-10002..   0.2977003
#         ...                    ...                    ...         ...
#   [2628618]   chrX-9995654-9996249 chrX-9995654-9996249..   -0.122068
#   [2628619]   chrX-9995654-9996249 chrX-9995654-9996249..   -0.114240
#   [2628620]   chrX-9997430-9997980 chrX-9997430-9997980..    0.104033
#   [2628621]   chrX-9997430-9997980 chrX-9997430-9997980..   -0.373740
#   [2628622]   chrX-9997430-9997980 chrX-9997430-9997980..   -0.109514
#                     FDR  VarQATAC   VarQRNA
#               <numeric> <numeric> <numeric>
#         [1] 3.12426e-07  0.250042  0.798029
#         [2] 7.28251e-08  0.250042  0.928951
#         [3] 9.15741e-01  0.250042  0.679256
#         [4] 2.82710e-02  0.250042  0.853413
#         [5] 8.38844e-11  0.250042  0.962768
#         ...         ...       ...       ...
#   [2628618] 1.33149e-02  0.705513  0.950471
#   [2628619] 2.12402e-02  0.705513  0.811106
#   [2628620] 3.74134e-02  0.831764  0.378178
#   [2628621] 7.04057e-17  0.831764  0.950471
#   [2628622] 2.77710e-02  0.831764  0.811106
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType Correlation  FDR
# 1       chr1 100028533 100029101 AGL        K562      0.239060154 3.124260e-07
# 2       chr1 100028533 100029101 CDC14A     K562      0.250611041 7.282513e-08
# 3       chr1 100028533 100029101 DBT        K562     -0.006377297 9.157406e-01
# 4       chr1 100028533 100029101 DPH5       K562      0.109192839 2.827099e-02
# 5       chr1 100028533 100029101 EXTL2      K562      0.297700272 8.388435e-11
# 6       chr1 100028533 100029101 FRRS1      K562      0.052411707 3.238124e-01
# 7       chr1 100028533 100029101 MFSD14A    K562      0.259727933 2.182599e-08
# 8       chr1 100028533 100029101 RTCA       K562     -0.093778868 6.298193e-02
# 9       chr1 100028533 100029101 RTCA-AS1   K562     -0.094458669 6.092956e-02
# 10      chr1 100028533 100029101 SASS6      K562     -0.247961866 1.023916e-07
# 11      chr1 100028533 100029101 SLC30A7    K562     -0.073527423 1.536087e-01
# 12      chr1 100028533 100029101 SLC35A3    K562     -0.180999641 1.518199e-04
# 13      chr1 100028533 100029101 TRMT13     K562     -0.121284659 1.397065e-02
# 14      chr1 100028533 100029101 VCAM1      K562      0.275252877 2.502730e-09
# 15      chr1 100029136 100029435 AGL        K562      0.096239802 5.582017e-02
# 16      chr1 100029136 100029435 CDC14A     K562     -0.120592021 1.457354e-02
# 17      chr1 100029136 100029435 DBT        K562     -0.017272916 7.652039e-01
# 18      chr1 100029136 100029435 DPH5       K562     -0.011982116 8.388946e-01
# 19      chr1 100029136 100029435 EXTL2      K562     -0.012492951 8.317856e-01
# 20      chr1 100029136 100029435 FRRS1      K562      0.048695609 3.624027e-01
# 21      chr1 100029136 100029435 MFSD14A    K562      0.060060088 2.524295e-01
# 22      chr1 100029136 100029435 RTCA       K562      0.004180552 9.451665e-01
# 23      chr1 100029136 100029435 RTCA-AS1   K562      0.143387096 3.219733e-03
# 24      chr1 100029136 100029435 SASS6      K562      0.031613771 5.686221e-01
# 25      chr1 100029136 100029435 SLC30A7    K562     -0.072689798 1.587742e-01
# 26      chr1 100029136 100029435 SLC35A3    K562     -0.119545915 1.552624e-02
# 27      chr1 100029136 100029435 TRMT13     K562      0.097198135 5.321544e-02
# 28      chr1 100029136 100029435 VCAM1      K562     -0.043401535 4.216773e-01
# 29      chr1 100034578 100034758 AGL        K562     -0.177137591 2.147535e-04
# 30      chr1 100034578 100034758 CDC14A     K562     -0.242069051 2.153961e-07
# ⋮       ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 2628593 chrX  997541    998270   ASMT       K562      0.107038452 3.182215e-02
# 2628594 chrX  997541    998270   ASMTL      K562      0.121607580 1.369742e-02
# 2628595 chrX  997541    998270   CSF2RA     K562      0.001336011 9.827104e-01
# 2628596 chrX  997541    998270   GTPBP6     K562      0.350798315 7.352820e-15
# 2628597 chrX  997541    998270   IL3RA      K562      0.286757362 4.568795e-10
# 2628598 chrX  997541    998270   LINC00106  K562     -0.332056590 2.476046e-13
# 2628599 chrX  997541    998270   P2RY8      K562     -0.351017308 7.045703e-15
# 2628600 chrX  997541    998270   PLCXD1     K562      0.511510173 4.779843e-33
# 2628601 chrX  997541    998270   PPP2R3B    K562      0.287686214 3.968925e-10
# 2628602 chrX  997541    998270   SLC25A6    K562      0.303317090 3.412362e-11
# 2628603 chrX 9988858   9989079   CLCN4      K562      0.317437877 3.249789e-12
# 2628604 chrX 9988858   9989079   TBL1X      K562     -0.052752862 3.203807e-01
# 2628605 chrX 9988858   9989079   WWC3       K562      0.154254665 1.433381e-03
# 2628606 chrX  999293    999875   AKAP17A    K562      0.374751807 5.685914e-17
# 2628607 chrX  999293    999875   ASMT       K562     -0.022216379 6.963897e-01
# 2628608 chrX  999293    999875   ASMTL      K562     -0.524880732 4.695757e-35
# 2628609 chrX  999293    999875   CSF2RA     K562     -0.217192594 3.994496e-06
# 2628610 chrX  999293    999875   GTPBP6     K562     -0.056599936 2.833746e-01
# 2628611 chrX  999293    999875   IL3RA      K562     -0.568482053 2.836953e-42
# 2628612 chrX  999293    999875   LINC00106  K562     -0.350804221 7.344386e-15
# 2628613 chrX  999293    999875   P2RY8      K562      0.546970181 1.406170e-38
# 2628614 chrX  999293    999875   PLCXD1     K562      0.167609106 4.890576e-04
# 2628615 chrX  999293    999875   PPP2R3B    K562     -0.214487248 5.372700e-06
# 2628616 chrX  999293    999875   SLC25A6    K562      0.402618679 1.149283e-19
# 2628617 chrX 9995654   9996249   CLCN4      K562     -0.017752707 7.584762e-01
# 2628618 chrX 9995654   9996249   TBL1X      K562     -0.122068385 1.331493e-02
# 2628619 chrX 9995654   9996249   WWC3       K562     -0.114239506 2.124022e-02
# 2628620 chrX 9997430   9997980   CLCN4      K562      0.104033205 3.741343e-02
# 2628621 chrX 9997430   9997980   TBL1X      K562     -0.373740032 7.040567e-17
# 2628622 chrX 9997430   9997980   WWC3       K562     -0.109513741 2.777099e-02
#         VarQATAC   VarQRNA
# 1       0.25004186 0.7980286
# 2       0.25004186 0.9289513
# 3       0.25004186 0.6792563
# 4       0.25004186 0.8534134
# 5       0.25004186 0.9627678
# 6       0.25004186 0.8201337
# 7       0.25004186 0.4436149
# 8       0.25004186 0.6899917
# 9       0.25004186 0.6208949
# 10      0.25004186 0.9006490
# 11      0.25004186 0.8160347
# 12      0.25004186 0.6425609
# 13      0.25004186 0.7007271
# 14      0.25004186 0.6057678
# 15      0.02579378 0.7980286
# 16      0.02579378 0.9289513
# 17      0.02579378 0.6792563
# 18      0.02579378 0.8534134
# 19      0.02579378 0.9627678
# 20      0.02579378 0.8201337
# 21      0.02579378 0.4436149
# 22      0.02579378 0.6899917
# 23      0.02579378 0.6208949
# 24      0.02579378 0.9006490
# 25      0.02579378 0.8160347
# 26      0.02579378 0.6425609
# 27      0.02579378 0.7007271
# 28      0.02579378 0.6057678
# 29      0.47476654 0.7980286
# 30      0.47476654 0.9289513
# ⋮       ⋮          ⋮
# 2628593 0.82948412 0.3051774
# 2628594 0.82948412 0.8825453
# 2628595 0.82948412 0.3498268
# 2628596 0.82948412 0.6354853
# 2628597 0.82948412 0.9442737
# 2628598 0.82948412 0.6546626
# 2628599 0.82948412 0.9853609
# 2628600 0.82948412 0.7444005
# 2628601 0.82948412 0.5513590
# 2628602 0.82948412 0.8978676
# 2628603 0.09842854 0.3781779
# 2628604 0.09842854 0.9504709
# 2628605 0.09842854 0.8111062
# 2628606 0.87065756 0.9154833
# 2628607 0.87065756 0.3051774
# 2628608 0.87065756 0.8825453
# 2628609 0.87065756 0.3498268
# 2628610 0.87065756 0.6354853
# 2628611 0.87065756 0.9442737
# 2628612 0.87065756 0.6546626
# 2628613 0.87065756 0.9853609
# 2628614 0.87065756 0.7444005
# 2628615 0.87065756 0.5513590
# 2628616 0.87065756 0.8978676
# 2628617 0.70551298 0.3781779
# 2628618 0.70551298 0.9504709
# 2628619 0.70551298 0.8111062
# 2628620 0.83176402 0.3781779
# 2628621 0.83176402 0.9504709
# 2628622 0.83176402 0.8111062

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       dplyr_1.1.4
#  [3] uwot_0.1.16                       Rsamtools_2.18.0
#  [5] BSgenome.Hsapiens.UCSC.hg38_1.4.5 BSgenome_1.68.0
#  [7] rtracklayer_1.60.1                Biostrings_2.70.1
#  [9] XVector_0.42.0                    genomation_1.34.0
# [11] Signac_1.13.0                     Seurat_5.0.3
# [13] SeuratObject_5.0.1                sp_2.1-4
# [15] rhdf5_2.44.0                      SummarizedExperiment_1.30.2
# [17] Biobase_2.60.0                    MatrixGenerics_1.12.3
# [19] Rcpp_1.0.12                       Matrix_1.6-5
# [21] GenomicRanges_1.54.1              GenomeInfoDb_1.38.1
# [23] IRanges_2.36.0                    S4Vectors_0.40.2
# [25] BiocGenerics_0.48.1               matrixStats_1.3.0
# [27] data.table_1.15.2                 stringr_1.5.1
# [29] plyr_1.8.9                        magrittr_2.0.3
# [31] ggplot2_3.5.1                     gtable_0.3.5
# [33] gtools_3.9.5                      gridExtra_2.3
# [35] ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            withr_3.0.0              fastmap_1.1.1
#  [61] rhdf5filters_1.12.1      fansi_1.0.6              digest_0.6.35
#  [64] R6_2.5.1                 mime_0.12                seqPattern_1.34.0
#  [67] colorspace_2.1-0         Cairo_1.6-2              scattermore_1.2
#  [70] tensor_1.5               spatstat.data_3.0-4      utf8_1.2.4
#  [73] tidyr_1.3.1              generics_0.1.3           httr_1.4.7
#  [76] htmlwidgets_1.6.4        S4Arrays_1.2.1           pkgconfig_2.0.3
#  [79] impute_1.76.0            lmtest_0.9-40            htmltools_0.5.8.1
#  [82] dotCall64_1.1-1          scales_1.3.0             png_0.1-8
#  [85] tzdb_0.4.0               reshape2_1.4.4           rjson_0.2.21
#  [88] uuid_1.2-0               nlme_3.1-164             repr_1.1.7
#  [91] zoo_1.8-12               KernSmooth_2.23-22       miniUI_0.1.1.1
#  [94] restfulr_0.0.15          pillar_1.9.0             vctrs_0.6.5
#  [97] RANN_2.6.1               promises_1.3.0           xtable_1.8-4
# [100] cluster_2.1.6            evaluate_0.23            readr_2.1.5
# [103] cli_3.6.2                compiler_4.3.3           rlang_1.1.3
# [106] crayon_1.5.2             future.apply_1.11.2      labeling_0.4.3
# [109] stringi_1.8.3            gridBase_0.4-7           viridisLite_0.4.2
# [112] deldir_2.0-4             BiocParallel_1.36.0      munsell_0.5.1
# [115] lazyeval_0.2.2           spatstat.geom_3.2-9      IRkernel_1.3.2
# [118] RcppHNSW_0.6.0           hms_1.1.3                patchwork_1.2.0
# [121] bit64_4.0.5              future_1.33.2            Rhdf5lib_1.22.1
# [124] shiny_1.8.1.1            ROCR_1.0-11              igraph_2.0.3
# [127] fastmatch_1.1-4          bit_4.0.5
