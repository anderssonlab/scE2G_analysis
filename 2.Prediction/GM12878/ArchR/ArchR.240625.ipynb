# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/1.prepare_data/1.seurat_pipeline.240615/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/ArchR/ArchR.240625/"

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_240614/GM12878/cellranger_res/"| __truncated__
#   .. ..@ hash : chr [1:2] "a5984ec1fe8d8e28c00a2146ef41d26d" "6e3871eeb1cd823c9aaa4c7bb93361fd"
#   .. ..@ cells: Named chr [1:3050] "AAACAGCCACTAAGAA-1" "AAACAGCCATAATCAC-1" "AAACATGCACTTGTTC-1" "AAACATGCATAATCAC-1" ...
#   .. .. ..- attr(*, "names")= chr [1:3050] "GM12878_AAACAGCCACTAAGAA-1" "GM12878_AAACAGCCATAATCAC-1" "GM12878_AAACATGCACTTGTTC-1" "GM12878_AAACATGCATAATCAC-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("GM12878"),
  validBarcodes = list(GM12878 = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-35cc641263fc3-Date-2024-06-25_Time-13-27-08.916718.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2024-06-25 13:27:10.104111 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (GM12878 : 1 of 1) Checking if completed file exists!
#
# 2024-06-25 13:27:10.183488 : (GM12878 : 1 of 1) Arrow Exists! Overriding since force = TRUE!, 0.001 mins elapsed.
#
# (GM12878 : 1 of 1) Determining Arrow Method to use!
#
# 2024-06-25 13:27:10.34584 : (GM12878 : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.004 mins elapsed.
#
# 2024-06-25 13:27:10.355684 : (GM12878 : 1 of 1) Tabix Bed To Temporary File, 0.004 mins elapsed.
#
# 2024-06-25 13:28:21.715038 : (GM12878 : 1 of 1) Successful creation of Temporary File, 1.194 mins elapsed.
#
# 2024-06-25 13:28:21.862386 : (GM12878 : 1 of 1) Creating ArrowFile From Temporary File, 1.196 mins elapsed.
#
# 2024-06-25 13:28:56.641499 : (GM12878 : 1 of 1) Successful creation of Arrow File, 1.776 mins elapsed.
#
# 2024-06-25 13:29:21.732003 : Continuing through after error ggplot for Fragment Size Distribution, 2.194 mins elapsed.
#
#
#
#
# 2024-06-25 13:29:58.861759 : (GM12878 : 1 of 1) CellStats : Number of Cells Pass Filter = 3032 , 2.813 mins elapsed.
#
# 2024-06-25 13:29:58.914675 : (GM12878 : 1 of 1) CellStats : Median Frags = 14044.5 , 2.814 mins elapsed.
#
# 2024-06-25 13:29:59.136229 : (GM12878 : 1 of 1) CellStats : Median TSS Enrichment = 15.2195 , 2.817 mins elapsed.
#
# 2024-06-25 13:30:00.19685 : Continuing through after error ggplot for TSS by Frags, 2.835 mins elapsed.
#
#
#
#
# 2024-06-25 13:30:04.192076 : (GM12878 : 1 of 1) Adding Additional Feature Counts!, 2.901 mins elapsed.
#
# 2024-06-25 13:30:31.177917 : (GM12878 : 1 of 1) Removing Fragments from Filtered Cells, 3.351 mins elapsed.
#
# 2024-06-25 13:30:31.187353 : (GM12878 : 1 of 1) Creating Filtered Arrow File, 3.351 mins elapsed.
#
# 2024-06-25 13:31:58.723563 : (GM12878 : 1 of 1) Finished Constructing Filtered Arrow File!, 4.81 mins elapsed.
#
# 2024-06-25 13:31:58.863007 : (GM12878 : 1 of 1) Adding TileMatrix!, 4.813 mins elapsed.
#
# 2024-06-25 13:36:23.739444 : (GM12878 : 1 of 1) Finished Creating Arrow File, 9.227 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-35cc641263fc3-Date-2024-06-25_Time-13-27-08.916718.log

# %%
ArrowFiles
# Out:
# [1] "GM12878.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "ArchR", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/ArchR/ArchR.240625//ArchR' already exists”

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/ArchR/ArchR.240625/ArchR
# samples(1): GM12878
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 3032
# medianTSS(1): 15.2195
# medianFrags(1): 14044.5

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-35cc6426a396df-Date-2024-06-25_Time-13-36-30.690028.log
# If there is an issue, please report to github with logFile!
#
# 2024-06-25 13:36:31.23978 : Computing Total Across All Features, 0 mins elapsed.
#
# 2024-06-25 13:36:32.250376 : Computing Top Features, 0.017 mins elapsed.
#
# ###########
# 2024-06-25 13:36:34.923731 : Running LSI (1 of 2) on Top Features, 0.062 mins elapsed.
# ###########
#
# 2024-06-25 13:36:34.940605 : Creating Partial Matrix, 0.062 mins elapsed.
#
# 2024-06-25 13:36:48.020571 : Computing LSI, 0.28 mins elapsed.
#
# 2024-06-25 13:37:13.533605 : Identifying Clusters, 0.705 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2024-06-25 13:37:18.710526 : Identified 6 Clusters, 0.792 mins elapsed.
#
# 2024-06-25 13:37:18.72603 : Saving LSI Iteration, 0.792 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2024-06-25 13:37:30.354725 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-35cc6426a396df-Date-2024-06-25_Time-13-36-30.690028.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2024-06-25 13:37:30.357136 : Creating Cluster Matrix on the total Group Features, 0.986 mins elapsed.
#
# 2024-06-25 13:37:49.788725 : Computing Variable Features, 1.309 mins elapsed.
#
# ###########
# 2024-06-25 13:37:49.988034 : Running LSI (2 of 2) on Variable Features, 1.313 mins elapsed.
# ###########
#
# 2024-06-25 13:37:50.001458 : Creating Partial Matrix, 1.313 mins elapsed.
#
# 2024-06-25 13:38:01.459062 : Computing LSI, 1.504 mins elapsed.
#
# 2024-06-25 13:38:23.008416 : Finished Running IterativeLSI, 1.863 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-35cc646a80423c-Date-2024-06-25_Time-13-38-26.331674.log
# If there is an issue, please report to github with logFile!
#
# 2024-06-25 13:38:26.62199 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-06-25 13:38:27.472147 : Adding GM12878 to PeakMatrix for Chr (1 of 23)!, 0.014 mins elapsed.
#
# 2024-06-25 13:38:36.959518 : Adding GM12878 to PeakMatrix for Chr (2 of 23)!, 0.172 mins elapsed.
#
# 2024-06-25 13:38:45.396499 : Adding GM12878 to PeakMatrix for Chr (3 of 23)!, 0.312 mins elapsed.
#
# 2024-06-25 13:38:51.924284 : Adding GM12878 to PeakMatrix for Chr (4 of 23)!, 0.421 mins elapsed.
#
# 2024-06-25 13:38:59.811466 : Adding GM12878 to PeakMatrix for Chr (5 of 23)!, 0.553 mins elapsed.
#
# 2024-06-25 13:39:06.878126 : Adding GM12878 to PeakMatrix for Chr (6 of 23)!, 0.67 mins elapsed.
#
# 2024-06-25 13:39:13.145498 : Adding GM12878 to PeakMatrix for Chr (7 of 23)!, 0.775 mins elapsed.
#
# 2024-06-25 13:39:19.699338 : Adding GM12878 to PeakMatrix for Chr (8 of 23)!, 0.884 mins elapsed.
#
# 2024-06-25 13:39:26.120085 : Adding GM12878 to PeakMatrix for Chr (9 of 23)!, 0.991 mins elapsed.
#
# 2024-06-25 13:39:32.104066 : Adding GM12878 to PeakMatrix for Chr (10 of 23)!, 1.091 mins elapsed.
#
# 2024-06-25 13:39:38.330349 : Adding GM12878 to PeakMatrix for Chr (11 of 23)!, 1.194 mins elapsed.
#
# 2024-06-25 13:39:46.223357 : Adding GM12878 to PeakMatrix for Chr (12 of 23)!, 1.326 mins elapsed.
#
# 2024-06-25 13:39:54.145643 : Adding GM12878 to PeakMatrix for Chr (13 of 23)!, 1.458 mins elapsed.
#
# 2024-06-25 13:39:59.3756 : Adding GM12878 to PeakMatrix for Chr (14 of 23)!, 1.545 mins elapsed.
#
# 2024-06-25 13:40:06.865929 : Adding GM12878 to PeakMatrix for Chr (15 of 23)!, 1.67 mins elapsed.
#
# 2024-06-25 13:40:14.523677 : Adding GM12878 to PeakMatrix for Chr (16 of 23)!, 1.798 mins elapsed.
#
# 2024-06-25 13:40:23.77866 : Adding GM12878 to PeakMatrix for Chr (17 of 23)!, 1.952 mins elapsed.
#
# 2024-06-25 13:40:36.793298 : Adding GM12878 to PeakMatrix for Chr (18 of 23)!, 2.169 mins elapsed.
#
# 2024-06-25 13:40:46.07776 : Adding GM12878 to PeakMatrix for Chr (19 of 23)!, 2.324 mins elapsed.
#
# 2024-06-25 13:40:53.120045 : Adding GM12878 to PeakMatrix for Chr (20 of 23)!, 2.441 mins elapsed.
#
# 2024-06-25 13:40:58.519106 : Adding GM12878 to PeakMatrix for Chr (21 of 23)!, 2.531 mins elapsed.
#
# 2024-06-25 13:41:04.476985 : Adding GM12878 to PeakMatrix for Chr (22 of 23)!, 2.63 mins elapsed.
#
# 2024-06-25 13:41:09.632542 : Adding GM12878 to PeakMatrix for Chr (23 of 23)!, 2.716 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-35cc646a80423c-Date-2024-06-25_Time-13-38-26.331674.log

# %%
seRNA.Xu = ArchR:::.importFM(featureMatrix = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5",
                             name = "K562_Xu",
                             featureType = "Gene Expression")
rowdata.Xu = rowData(seRNA.Xu)

# %%
gene.intersect = intersect(rownames(obj.seurat@assays$RNA$counts),
                           rowdata.Xu$name)
rowdata.intersect = rowdata.Xu[gene.intersect,]

# %%
rr = GRanges(paste0(rowdata.intersect$interval))
mcols(rr) <- rowdata.intersect

# %%
count.rna = obj.seurat@assays$RNA$counts[gene.intersect,]
colnames(count.rna) = gsub("GM12878_","GM12878#",colnames(count.rna))

# %%
seRNA <- SummarizedExperiment(assays = SimpleList(counts = count.rna), 
                              rowRanges = rr)
seRNA = sort.GenomicRanges(sortSeqlevels(seRNA), 
                           ignore.strand = TRUE)

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61214 3050
# metadata(0):
# assays(1): counts
# rownames(61214): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(3050): GM12878#AAACAGCCACTAAGAA-1 GM12878#AAACAGCCATAATCAC-1
#   ... GM12878#TTTGTTGGTCACAAAT-1 GM12878#TTTGTTGGTTGGTGAC-1
# colData names(0):

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-35cc6458b2b020-Date-2024-06-25_Time-13-41-54.528176.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2024-06-25 13:41:55.181055 :
#
# Overlap Per Sample w/ scATAC : GM12878=3032
#
# 2024-06-25 13:41:55.19265 :
#
# 2024-06-25 13:41:57.077192 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-06-25 13:41:58.795964 : Adding GM12878 to GeneExpressionMatrix for Chr (1 of 23)!, 0.029 mins elapsed.
#
# 2024-06-25 13:42:07.145231 : Adding GM12878 to GeneExpressionMatrix for Chr (2 of 23)!, 0.168 mins elapsed.
#
# 2024-06-25 13:42:13.005605 : Adding GM12878 to GeneExpressionMatrix for Chr (3 of 23)!, 0.265 mins elapsed.
#
# 2024-06-25 13:42:22.003324 : Adding GM12878 to GeneExpressionMatrix for Chr (4 of 23)!, 0.415 mins elapsed.
#
# 2024-06-25 13:42:27.181044 : Adding GM12878 to GeneExpressionMatrix for Chr (5 of 23)!, 0.502 mins elapsed.
#
# 2024-06-25 13:42:32.803717 : Adding GM12878 to GeneExpressionMatrix for Chr (6 of 23)!, 0.595 mins elapsed.
#
# 2024-06-25 13:42:41.550823 : Adding GM12878 to GeneExpressionMatrix for Chr (7 of 23)!, 0.741 mins elapsed.
#
# 2024-06-25 13:42:48.573644 : Adding GM12878 to GeneExpressionMatrix for Chr (8 of 23)!, 0.858 mins elapsed.
#
# 2024-06-25 13:42:57.297585 : Adding GM12878 to GeneExpressionMatrix for Chr (9 of 23)!, 1.004 mins elapsed.
#
# 2024-06-25 13:43:04.821326 : Adding GM12878 to GeneExpressionMatrix for Chr (10 of 23)!, 1.129 mins elapsed.
#
# 2024-06-25 13:43:10.440031 : Adding GM12878 to GeneExpressionMatrix for Chr (11 of 23)!, 1.223 mins elapsed.
#
# 2024-06-25 13:43:15.564446 : Adding GM12878 to GeneExpressionMatrix for Chr (12 of 23)!, 1.308 mins elapsed.
#
# 2024-06-25 13:43:23.699285 : Adding GM12878 to GeneExpressionMatrix for Chr (13 of 23)!, 1.444 mins elapsed.
#
# 2024-06-25 13:43:29.589326 : Adding GM12878 to GeneExpressionMatrix for Chr (14 of 23)!, 1.542 mins elapsed.
#
# 2024-06-25 13:43:36.312743 : Adding GM12878 to GeneExpressionMatrix for Chr (15 of 23)!, 1.654 mins elapsed.
#
# 2024-06-25 13:43:44.335872 : Adding GM12878 to GeneExpressionMatrix for Chr (16 of 23)!, 1.788 mins elapsed.
#
# 2024-06-25 13:43:49.774234 : Adding GM12878 to GeneExpressionMatrix for Chr (17 of 23)!, 1.878 mins elapsed.
#
# 2024-06-25 13:43:55.216904 : Adding GM12878 to GeneExpressionMatrix for Chr (18 of 23)!, 1.969 mins elapsed.
#
# 2024-06-25 13:44:01.978369 : Adding GM12878 to GeneExpressionMatrix for Chr (19 of 23)!, 2.082 mins elapsed.
#
# 2024-06-25 13:44:06.602415 : Adding GM12878 to GeneExpressionMatrix for Chr (20 of 23)!, 2.159 mins elapsed.
#
# 2024-06-25 13:44:11.476933 : Adding GM12878 to GeneExpressionMatrix for Chr (21 of 23)!, 2.24 mins elapsed.
#
# 2024-06-25 13:44:18.201168 : Adding GM12878 to GeneExpressionMatrix for Chr (22 of 23)!, 2.352 mins elapsed.
#
# 2024-06-25 13:44:22.679292 : Adding GM12878 to GeneExpressionMatrix for Chr (23 of 23)!, 2.427 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-35cc6458b2b020-Date-2024-06-25_Time-13-41-54.528176.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-35cc64745d0b8d-Date-2024-06-25_Time-13-44-30.920799.log
# If there is an issue, please report to github with logFile!
#
# 2024-06-25 13:44:32.488818 : Getting Available Matrices, 0.026 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2024-06-25 13:44:32.866099 : Filtered Low Prediction Score Cells (0 of 3032, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2024-06-25 13:44:33.06601 : Computing KNN, 0.004 mins elapsed.
#
# 2024-06-25 13:44:33.50364 : Identifying Non-Overlapping KNN pairs, 0.011 mins elapsed.
#
# 2024-06-25 13:44:35.228306 : Identified 499 Groupings!, 0.04 mins elapsed.
#
# 2024-06-25 13:44:35.278798 : Getting Group RNA Matrix, 0.04 mins elapsed.
#
# 2024-06-25 13:44:54.772631 : Getting Group ATAC Matrix, 0.365 mins elapsed.
#
# 2024-06-25 13:45:22.584987 : Normalizing Group Matrices, 0.829 mins elapsed.
#
# 2024-06-25 13:45:30.744961 : Finding Peak Gene Pairings, 0.965 mins elapsed.
#
# 2024-06-25 13:45:32.601272 : Computing Correlations, 0.996 mins elapsed.
#
# 2024-06-25 13:46:19.773261 : Completed Peak2Gene Correlations!, 1.782 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-35cc64745d0b8d-Date-2024-06-25_Time-13-44-30.920799.log

# %%
execution_time
# Out:
# Time difference of 1.816291 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 8771125 rows and 7 columns
#                                   idxATAC    idxRNA Correlation         FDR
#                                 <integer> <integer>   <numeric>   <numeric>
# chr1-180700-181061_DDX11L1              1         1         NaN         NaN
# chr1-181282-181914_DDX11L1              2         1         NaN         NaN
# chr1-267886-268118_DDX11L1              3         1         NaN         NaN
# chr1-586095-586295_DDX11L1              4         1         NaN         NaN
# chr1-778328-779254_DDX11L1              5         1         NaN         NaN
# ...                                   ...       ...         ...         ...
# chrX-155981990-155982304_WASH6P    155266     60637    0.249031 1.17733e-07
# chrX-155997270-155998098_WASH6P    155267     60637    0.181218 1.83855e-04
# chrX-156000622-156000826_WASH6P    155268     60637   -0.328591 6.42281e-13
# chrX-156004204-156004495_WASH6P    155269     60637    0.187915 9.95324e-05
# chrX-156030527-156030695_WASH6P    155270     60637   -0.143765 3.70707e-03
#                                  VarQATAC   VarQRNA               PairName
#                                 <numeric> <numeric>            <character>
# chr1-180700-181061_DDX11L1       0.239100  0.199218 chr1-180700-181061_D..
# chr1-181282-181914_DDX11L1       0.608553  0.199218 chr1-181282-181914_D..
# chr1-267886-268118_DDX11L1       0.426425  0.199218 chr1-267886-268118_D..
# chr1-586095-586295_DDX11L1       0.219231  0.199218 chr1-586095-586295_D..
# chr1-778328-779254_DDX11L1       0.986862  0.199218 chr1-778328-779254_D..
# ...                                   ...       ...                    ...
# chrX-155981990-155982304_WASH6P 0.0676241  0.683757 chrX-155981990-15598..
# chrX-155997270-155998098_WASH6P 0.6945321  0.683757 chrX-155997270-15599..
# chrX-156000622-156000826_WASH6P 0.0529400  0.683757 chrX-156000622-15600..
# chrX-156004204-156004495_WASH6P 0.0526889  0.683757 chrX-156004204-15600..
# chrX-156030527-156030695_WASH6P 0.0675211  0.683757 chrX-156030527-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 2513716 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028533-100029101      * |         AGL
#         [2]     chr1 100028533-100029101      * |      CDC14A
#         [3]     chr1 100028533-100029101      * |         DBT
#         [4]     chr1 100028533-100029101      * |        DPH5
#         [5]     chr1 100028533-100029101      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2513712]     chrX     9995654-9996249      * |       TBL1X
#   [2513713]     chrX     9995654-9996249      * |        WWC3
#   [2513714]     chrX     9997430-9997980      * |       CLCN4
#   [2513715]     chrX     9997430-9997980      * |       TBL1X
#   [2513716]     chrX     9997430-9997980      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028533-10002.. chr1-100028533-10002..   0.2848537
#         [2] chr1-100028533-10002.. chr1-100028533-10002..   0.3289842
#         [3] chr1-100028533-10002.. chr1-100028533-10002..   0.0718081
#         [4] chr1-100028533-10002.. chr1-100028533-10002..   0.1567433
#         [5] chr1-100028533-10002.. chr1-100028533-10002..   0.3813759
#         ...                    ...                    ...         ...
#   [2513712]   chrX-9995654-9996249 chrX-9995654-9996249..  -0.0730499
#   [2513713]   chrX-9995654-9996249 chrX-9995654-9996249..  -0.0530663
#   [2513714]   chrX-9997430-9997980 chrX-9997430-9997980..  -0.0018111
#   [2513715]   chrX-9997430-9997980 chrX-9997430-9997980..  -0.3834368
#   [2513716]   chrX-9997430-9997980 chrX-9997430-9997980..   0.0284566
#                     FDR  VarQATAC   VarQRNA
#               <numeric> <numeric> <numeric>
#         [1] 8.24388e-10  0.306853  0.927618
#         [2] 5.98794e-13  0.306853  0.977275
#         [3] 1.77429e-01  0.306853  0.886060
#         [4] 1.41961e-03  0.306853  0.946996
#         [5] 1.95473e-17  0.306853  0.988110
#         ...         ...       ...       ...
#   [2513712] 1.69260e-01  0.704753  0.982981
#   [2513713] 3.34723e-01  0.704753  0.920197
#   [2513714] 9.77926e-01  0.835925  0.712073
#   [2513715] 1.24909e-17  0.835925  0.982981
#   [2513716] 6.26569e-01  0.835925  0.920197
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 2513716 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028533-100029101      * |         AGL
#         [2]     chr1 100028533-100029101      * |      CDC14A
#         [3]     chr1 100028533-100029101      * |         DBT
#         [4]     chr1 100028533-100029101      * |        DPH5
#         [5]     chr1 100028533-100029101      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2513712]     chrX     9995654-9996249      * |       TBL1X
#   [2513713]     chrX     9995654-9996249      * |        WWC3
#   [2513714]     chrX     9997430-9997980      * |       CLCN4
#   [2513715]     chrX     9997430-9997980      * |       TBL1X
#   [2513716]     chrX     9997430-9997980      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028533-10002.. chr1-100028533-10002..   0.2848537
#         [2] chr1-100028533-10002.. chr1-100028533-10002..   0.3289842
#         [3] chr1-100028533-10002.. chr1-100028533-10002..   0.0718081
#         [4] chr1-100028533-10002.. chr1-100028533-10002..   0.1567433
#         [5] chr1-100028533-10002.. chr1-100028533-10002..   0.3813759
#         ...                    ...                    ...         ...
#   [2513712]   chrX-9995654-9996249 chrX-9995654-9996249..  -0.0730499
#   [2513713]   chrX-9995654-9996249 chrX-9995654-9996249..  -0.0530663
#   [2513714]   chrX-9997430-9997980 chrX-9997430-9997980..  -0.0018111
#   [2513715]   chrX-9997430-9997980 chrX-9997430-9997980..  -0.3834368
#   [2513716]   chrX-9997430-9997980 chrX-9997430-9997980..   0.0284566
#                     FDR  VarQATAC   VarQRNA
#               <numeric> <numeric> <numeric>
#         [1] 8.24388e-10  0.306853  0.927618
#         [2] 5.98794e-13  0.306853  0.977275
#         [3] 1.77429e-01  0.306853  0.886060
#         [4] 1.41961e-03  0.306853  0.946996
#         [5] 1.95473e-17  0.306853  0.988110
#         ...         ...       ...       ...
#   [2513712] 1.69260e-01  0.704753  0.982981
#   [2513713] 3.34723e-01  0.704753  0.920197
#   [2513714] 9.77926e-01  0.835925  0.712073
#   [2513715] 1.24909e-17  0.835925  0.982981
#   [2513716] 6.26569e-01  0.835925  0.920197
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType Correlation  FDR
# 1       chr1 100028533 100029101 AGL        K562      0.284853741 8.243878e-10
# 2       chr1 100028533 100029101 CDC14A     K562      0.328984179 5.987939e-13
# 3       chr1 100028533 100029101 DBT        K562      0.071808078 1.774288e-01
# 4       chr1 100028533 100029101 DPH5       K562      0.156743343 1.419607e-03
# 5       chr1 100028533 100029101 EXTL2      K562      0.381375856 1.954729e-17
# 6       chr1 100028533 100029101 FRRS1      K562     -0.054004679 3.253500e-01
# 7       chr1 100028533 100029101 MFSD14A    K562      0.274427925 3.787000e-09
# 8       chr1 100028533 100029101 RTCA       K562     -0.105225608 3.954769e-02
# 9       chr1 100028533 100029101 RTCA-AS1   K562     -0.215846066 5.925808e-06
# 10      chr1 100028533 100029101 SASS6      K562     -0.158213070 1.266497e-03
# 11      chr1 100028533 100029101 SLC30A7    K562     -0.003540864 9.565045e-01
# 12      chr1 100028533 100029101 SLC35A3    K562     -0.135256821 6.648412e-03
# 13      chr1 100028533 100029101 TRMT13     K562     -0.110501216 2.981516e-02
# 14      chr1 100028533 100029101 VCAM1      K562      0.400591837 2.636342e-19
# 15      chr1 100029136 100029435 AGL        K562      0.136326908 6.189733e-03
# 16      chr1 100029136 100029435 CDC14A     K562     -0.036105000 5.279213e-01
# 17      chr1 100029136 100029435 DBT        K562      0.065973355 2.195423e-01
# 18      chr1 100029136 100029435 DPH5       K562      0.057069912 2.957503e-01
# 19      chr1 100029136 100029435 EXTL2      K562      0.023694142 6.900479e-01
# 20      chr1 100029136 100029435 FRRS1      K562     -0.004484065 9.446231e-01
# 21      chr1 100029136 100029435 MFSD14A    K562      0.143498508 3.777886e-03
# 22      chr1 100029136 100029435 RTCA       K562      0.083568503 1.105951e-01
# 23      chr1 100029136 100029435 RTCA-AS1   K562      0.021450388 7.201974e-01
# 24      chr1 100029136 100029435 SASS6      K562      0.047197232 3.967271e-01
# 25      chr1 100029136 100029435 SLC30A7    K562     -0.072171361 1.750097e-01
# 26      chr1 100029136 100029435 SLC35A3    K562     -0.009475548 8.802512e-01
# 27      chr1 100029136 100029435 TRMT13     K562      0.110611488 2.963584e-02
# 28      chr1 100029136 100029435 VCAM1      K562     -0.023526482 6.922768e-01
# 29      chr1 100034578 100034758 AGL        K562     -0.241548480 3.011215e-07
# 30      chr1 100034578 100034758 CDC14A     K562     -0.254209922 6.025778e-08
# ⋮       ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 2513687 chrX  997541    998270   ASMT       K562      0.115322838 2.276656e-02
# 2513688 chrX  997541    998270   ASMTL      K562      0.150615977 2.257349e-03
# 2513689 chrX  997541    998270   CSF2RA     K562     -0.022939653 7.001363e-01
# 2513690 chrX  997541    998270   GTPBP6     K562      0.382944219 1.390690e-17
# 2513691 chrX  997541    998270   IL3RA      K562      0.264878616 1.443359e-08
# 2513692 chrX  997541    998270   LINC00106  K562     -0.272724697 4.827873e-09
# 2513693 chrX  997541    998270   P2RY8      K562     -0.298637316 9.892163e-11
# 2513694 chrX  997541    998270   PLCXD1     K562      0.505884524 4.590465e-32
# 2513695 chrX  997541    998270   PPP2R3B    K562      0.288399802 4.831186e-10
# 2513696 chrX  997541    998270   SLC25A6    K562      0.355585790 4.053317e-15
# 2513697 chrX 9988858   9989079   CLCN4      K562      0.339381223 9.016555e-14
# 2513698 chrX 9988858   9989079   TBL1X      K562     -0.006516291 9.186652e-01
# 2513699 chrX 9988858   9989079   WWC3       K562      0.190741281 7.627582e-05
# 2513700 chrX  999293    999875   AKAP17A    K562      0.319698001 3.050720e-12
# 2513701 chrX  999293    999875   ASMT       K562      0.004550612 9.437768e-01
# 2513702 chrX  999293    999875   ASMTL      K562     -0.503109103 1.148410e-31
# 2513703 chrX  999293    999875   CSF2RA     K562     -0.244502915 2.086309e-07
# 2513704 chrX  999293    999875   GTPBP6     K562      0.018742414 7.567248e-01
# 2513705 chrX  999293    999875   IL3RA      K562     -0.542062010 1.323015e-37
# 2513706 chrX  999293    999875   LINC00106  K562     -0.492821758 3.183864e-30
# 2513707 chrX  999293    999875   P2RY8      K562      0.516580851 1.240740e-33
# 2513708 chrX  999293    999875   PLCXD1     K562      0.148830080 2.574179e-03
# 2513709 chrX  999293    999875   PPP2R3B    K562     -0.208490550 1.298196e-05
# 2513710 chrX  999293    999875   SLC25A6    K562      0.372018981 1.434578e-16
# 2513711 chrX 9995654   9996249   CLCN4      K562      0.002714168 9.668057e-01
# 2513712 chrX 9995654   9996249   TBL1X      K562     -0.073049930 1.692598e-01
# 2513713 chrX 9995654   9996249   WWC3       K562     -0.053066275 3.347233e-01
# 2513714 chrX 9997430   9997980   CLCN4      K562     -0.001811101 9.779257e-01
# 2513715 chrX 9997430   9997980   TBL1X      K562     -0.383436845 1.249085e-17
# 2513716 chrX 9997430   9997980   WWC3       K562      0.028456646 6.265693e-01
#         VarQATAC  VarQRNA
# 1       0.3068526 0.9276185
# 2       0.3068526 0.9772746
# 3       0.3068526 0.8860597
# 4       0.3068526 0.9469961
# 5       0.3068526 0.9881096
# 6       0.3068526 0.9274370
# 7       0.3068526 0.7644672
# 8       0.3068526 0.8887148
# 9       0.3068526 0.8494978
# 10      0.3068526 0.9607500
# 11      0.3068526 0.9231822
# 12      0.3068526 0.8725531
# 13      0.3068526 0.8910731
# 14      0.3068526 0.8634662
# 15      0.0212533 0.9276185
# 16      0.0212533 0.9772746
# 17      0.0212533 0.8860597
# 18      0.0212533 0.9469961
# 19      0.0212533 0.9881096
# 20      0.0212533 0.9274370
# 21      0.0212533 0.7644672
# 22      0.0212533 0.8887148
# 23      0.0212533 0.8494978
# 24      0.0212533 0.9607500
# 25      0.0212533 0.9231822
# 26      0.0212533 0.8725531
# 27      0.0212533 0.8910731
# 28      0.0212533 0.8634662
# 29      0.4688736 0.9276185
# 30      0.4688736 0.9772746
# ⋮       ⋮         ⋮
# 2513687 0.8158949 0.6388674
# 2513688 0.8158949 0.9546482
# 2513689 0.8158949 0.6812507
# 2513690 0.8158949 0.8713987
# 2513691 0.8158949 0.9808533
# 2513692 0.8158949 0.8785395
# 2513693 0.8158949 0.9946073
# 2513694 0.8158949 0.9108135
# 2513695 0.8158949 0.8297574
# 2513696 0.8158949 0.9614922
# 2513697 0.1029497 0.7120735
# 2513698 0.1029497 0.9829807
# 2513699 0.1029497 0.9201972
# 2513700 0.8720745 0.9605192
# 2513701 0.8720745 0.6388674
# 2513702 0.8720745 0.9546482
# 2513703 0.8720745 0.6812507
# 2513704 0.8720745 0.8713987
# 2513705 0.8720745 0.9808533
# 2513706 0.8720745 0.8785395
# 2513707 0.8720745 0.9946073
# 2513708 0.8720745 0.9108135
# 2513709 0.8720745 0.8297574
# 2513710 0.8720745 0.9614922
# 2513711 0.7047530 0.7120735
# 2513712 0.7047530 0.9829807
# 2513713 0.7047530 0.9201972
# 2513714 0.8359245 0.7120735
# 2513715 0.8359245 0.9829807
# 2513716 0.8359245 0.9201972

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       uwot_0.1.16
#  [3] Rsamtools_2.18.0                  BSgenome.Hsapiens.UCSC.hg38_1.4.5
#  [5] BSgenome_1.68.0                   rtracklayer_1.60.1
#  [7] Biostrings_2.70.1                 XVector_0.42.0
#  [9] genomation_1.34.0                 Signac_1.13.0
# [11] Seurat_5.0.3                      SeuratObject_5.0.1
# [13] sp_2.1-4                          rhdf5_2.44.0
# [15] SummarizedExperiment_1.30.2       Biobase_2.60.0
# [17] MatrixGenerics_1.12.3             Rcpp_1.0.12
# [19] Matrix_1.6-5                      GenomicRanges_1.54.1
# [21] GenomeInfoDb_1.38.1               IRanges_2.36.0
# [23] S4Vectors_0.40.2                  BiocGenerics_0.48.1
# [25] matrixStats_1.3.0                 data.table_1.15.2
# [27] stringr_1.5.1                     plyr_1.8.9
# [29] magrittr_2.0.3                    ggplot2_3.5.1
# [31] gtable_0.3.5                      gtools_3.9.5
# [33] gridExtra_2.3                     ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            dplyr_1.1.4              withr_3.0.0
#  [61] fastmap_1.1.1            rhdf5filters_1.12.1      fansi_1.0.6
#  [64] digest_0.6.35            R6_2.5.1                 mime_0.12
#  [67] seqPattern_1.34.0        colorspace_2.1-0         Cairo_1.6-2
#  [70] scattermore_1.2          tensor_1.5               spatstat.data_3.0-4
#  [73] utf8_1.2.4               tidyr_1.3.1              generics_0.1.3
#  [76] httr_1.4.7               htmlwidgets_1.6.4        S4Arrays_1.2.1
#  [79] pkgconfig_2.0.3          impute_1.76.0            lmtest_0.9-40
#  [82] htmltools_0.5.8.1        dotCall64_1.1-1          scales_1.3.0
#  [85] png_0.1-8                tzdb_0.4.0               reshape2_1.4.4
#  [88] rjson_0.2.21             uuid_1.2-0               nlme_3.1-164
#  [91] repr_1.1.7               zoo_1.8-12               KernSmooth_2.23-22
#  [94] miniUI_0.1.1.1           restfulr_0.0.15          pillar_1.9.0
#  [97] vctrs_0.6.5              RANN_2.6.1               promises_1.3.0
# [100] xtable_1.8-4             cluster_2.1.6            evaluate_0.23
# [103] readr_2.1.5              cli_3.6.2                compiler_4.3.3
# [106] rlang_1.1.3              crayon_1.5.2             future.apply_1.11.2
# [109] labeling_0.4.3           stringi_1.8.3            gridBase_0.4-7
# [112] viridisLite_0.4.2        deldir_2.0-4             BiocParallel_1.36.0
# [115] munsell_0.5.1            lazyeval_0.2.2           spatstat.geom_3.2-9
# [118] IRkernel_1.3.2           RcppHNSW_0.6.0           hms_1.1.3
# [121] patchwork_1.2.0          bit64_4.0.5              future_1.33.2
# [124] Rhdf5lib_1.22.1          shiny_1.8.1.1            ROCR_1.0-11
# [127] igraph_2.0.3             fastmatch_1.1-4          bit_4.0.5
