# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/1.prepare_data/1.seurat_pipeline.240615/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/SCENT/SCENT_500.250204/"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 1M

# %%
pairs.ABC.1M = pairs.ABC[pairs.ABC$distance < 10^6]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.1M

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.1M.chr_rename = as.data.frame(pairs.ABC.1M)[,1:3]
df.pairs.ABC.1M.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.1M),
                                                mcols(pairs.ABC.1M)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.1M.chr_rename = GRanges(df.pairs.ABC.1M.chr_rename)
rm(df.pairs.ABC.1M.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.1M.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.1M.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 2637980 ranges and 3 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028533-100029101      * |         AGL
#         [2]     chr1 100028533-100029101      * |      CDC14A
#         [3]     chr1 100028533-100029101      * |         DBT
#         [4]     chr1 100028533-100029101      * |        DPH5
#         [5]     chr1 100028533-100029101      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2637976]     chrX     9995654-9996249      * |       TBL1X
#   [2637977]     chrX     9995654-9996249      * |        WWC3
#   [2637978]     chrX     9997430-9997980      * |       CLCN4
#   [2637979]     chrX     9997430-9997980      * |       TBL1X
#   [2637980]     chrX     9997430-9997980      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-100028533-10002.. chr1-100028533-10002..
#         [2] chr1-100028533-10002.. chr1-100028533-10002..
#         [3] chr1-100028533-10002.. chr1-100028533-10002..
#         [4] chr1-100028533-10002.. chr1-100028533-10002..
#         [5] chr1-100028533-10002.. chr1-100028533-10002..
#         ...                    ...                    ...
#   [2637976]   chrX-9995654-9996249 chrX-9995654-9996249..
#   [2637977]   chrX-9995654-9996249 chrX-9995654-9996249..
#   [2637978]   chrX-9997430-9997980 chrX-9997430-9997980..
#   [2637979]   chrX-9997430-9997980 chrX-9997430-9997980..
#   [2637980]   chrX-9997430-9997980 chrX-9997430-9997980..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna.rename) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI   nMito celltype
# GM12878_AAACAGCCACTAAGAA-1 GM12878_AAACAGCCACTAAGAA-1 12231   2282 K562
# GM12878_AAACAGCCATAATCAC-1 GM12878_AAACAGCCATAATCAC-1  7295   1201 K562
# GM12878_AAACATGCACTTGTTC-1 GM12878_AAACATGCACTTGTTC-1 41269   8494 K562
# GM12878_AAACATGCATAATCAC-1 GM12878_AAACATGCATAATCAC-1 20273   2434 K562
# GM12878_AAACCAACATTAGCGC-1 GM12878_AAACCAACATTAGCGC-1 14614   2538 K562
# GM12878_AAACCGAAGCAAGGAC-1 GM12878_AAACCGAAGCAAGGAC-1 10407   1670 K562
# GM12878_AAACCGCGTAACTACG-1 GM12878_AAACCGCGTAACTACG-1 40454   8623 K562
# GM12878_AAACCGGCAGTAAGTA-1 GM12878_AAACCGGCAGTAAGTA-1  7334   1757 K562
# GM12878_AAACCGGCATTAAACC-1 GM12878_AAACCGGCATTAAACC-1 20950   2776 K562
# GM12878_AAACGGATCTGTAATG-1 GM12878_AAACGGATCTGTAATG-1 24078   1488 K562
# GM12878_AAAGCAAGTCATGCAA-1 GM12878_AAAGCAAGTCATGCAA-1 27877   6930 K562
# GM12878_AAAGCAAGTTGTTGGA-1 GM12878_AAAGCAAGTTGTTGGA-1 15236   2732 K562
# GM12878_AAAGCACCAAACAACA-1 GM12878_AAAGCACCAAACAACA-1 12756   1160 K562
# GM12878_AAAGCACCAATAATGG-1 GM12878_AAAGCACCAATAATGG-1 14808   2775 K562
# GM12878_AAAGCACCACCTAATG-1 GM12878_AAAGCACCACCTAATG-1 30289   4379 K562
# GM12878_AAAGCCCGTATTTGGG-1 GM12878_AAAGCCCGTATTTGGG-1 19116   3909 K562
# GM12878_AAAGCCCGTTTCAGGA-1 GM12878_AAAGCCCGTTTCAGGA-1  5586    505 K562
# GM12878_AAAGCCGCAGGAACAT-1 GM12878_AAAGCCGCAGGAACAT-1  5968    112 K562
# GM12878_AAAGCCGCATTGTGCA-1 GM12878_AAAGCCGCATTGTGCA-1  5332    140 K562
# GM12878_AAAGCGGGTAACGTGC-1 GM12878_AAAGCGGGTAACGTGC-1 17303   2070 K562
# GM12878_AAAGCGGGTCAAAGGG-1 GM12878_AAAGCGGGTCAAAGGG-1  5885    288 K562
# GM12878_AAAGCGGGTTCGCTCA-1 GM12878_AAAGCGGGTTCGCTCA-1 16029   1554 K562
# GM12878_AAAGCTTGTACGGTAC-1 GM12878_AAAGCTTGTACGGTAC-1 24931   3652 K562
# GM12878_AAAGCTTGTTAAGGTT-1 GM12878_AAAGCTTGTTAAGGTT-1 33596   8537 K562
# GM12878_AAAGGACGTTAAGCGC-1 GM12878_AAAGGACGTTAAGCGC-1 13597   1644 K562
# GM12878_AAAGGAGCAAGGTATA-1 GM12878_AAAGGAGCAAGGTATA-1  7298   1024 K562
# GM12878_AAAGGAGCAATAAGCA-1 GM12878_AAAGGAGCAATAAGCA-1 24390   3393 K562
# GM12878_AAAGGCTCAAGGATTA-1 GM12878_AAAGGCTCAAGGATTA-1 19970   2871 K562
# GM12878_AAAGGCTCAGGCTTCG-1 GM12878_AAAGGCTCAGGCTTCG-1 16615   3014 K562
# GM12878_AAAGGCTCATAAGTCT-1 GM12878_AAAGGCTCATAAGTCT-1 49112  10206 K562
# ⋮                          ⋮                          ⋮      ⋮     ⋮
# GM12878_TTTGACTTCAAGACTC-1 GM12878_TTTGACTTCAAGACTC-1   7823   403 K562
# GM12878_TTTGACTTCATTACAG-1 GM12878_TTTGACTTCATTACAG-1  18743   159 K562
# GM12878_TTTGACTTCTCAATGA-1 GM12878_TTTGACTTCTCAATGA-1 105555 26097 K562
# GM12878_TTTGAGTCATCCTAGA-1 GM12878_TTTGAGTCATCCTAGA-1  12166  1998 K562
# GM12878_TTTGAGTCATGCTATG-1 GM12878_TTTGAGTCATGCTATG-1  15790  2611 K562
# GM12878_TTTGCATTCAATGAGG-1 GM12878_TTTGCATTCAATGAGG-1  25877  3841 K562
# GM12878_TTTGCATTCATAACTG-1 GM12878_TTTGCATTCATAACTG-1  66451 12580 K562
# GM12878_TTTGCATTCCTAAGAC-1 GM12878_TTTGCATTCCTAAGAC-1  11981  1520 K562
# GM12878_TTTGCATTCGCTAAGT-1 GM12878_TTTGCATTCGCTAAGT-1   6852    89 K562
# GM12878_TTTGCATTCTAGCGTG-1 GM12878_TTTGCATTCTAGCGTG-1   9531  1070 K562
# GM12878_TTTGCGACACAGAAAC-1 GM12878_TTTGCGACACAGAAAC-1  10584  2013 K562
# GM12878_TTTGCGACACCTATAG-1 GM12878_TTTGCGACACCTATAG-1  12526   916 K562
# GM12878_TTTGCGACACGTGCTG-1 GM12878_TTTGCGACACGTGCTG-1  21549  2697 K562
# GM12878_TTTGCGACAGGGAGCT-1 GM12878_TTTGCGACAGGGAGCT-1   9638  1314 K562
# GM12878_TTTGCGGAGTGCACGC-1 GM12878_TTTGCGGAGTGCACGC-1   7814    19 K562
# GM12878_TTTGGCTGTCCTAACT-1 GM12878_TTTGGCTGTCCTAACT-1  18983  3361 K562
# GM12878_TTTGGCTGTTGGCCGA-1 GM12878_TTTGGCTGTTGGCCGA-1  10957   955 K562
# GM12878_TTTGTCCCACATAGCC-1 GM12878_TTTGTCCCACATAGCC-1  21573  3060 K562
# GM12878_TTTGTGAAGCGCATTG-1 GM12878_TTTGTGAAGCGCATTG-1   8913   123 K562
# GM12878_TTTGTGAAGCTTTGTT-1 GM12878_TTTGTGAAGCTTTGTT-1  17678  2941 K562
# GM12878_TTTGTGGCAAACCTAT-1 GM12878_TTTGTGGCAAACCTAT-1  21927  4168 K562
# GM12878_TTTGTGGCAAAGGTAC-1 GM12878_TTTGTGGCAAAGGTAC-1   7312   599 K562
# GM12878_TTTGTGGCAAGGACCA-1 GM12878_TTTGTGGCAAGGACCA-1  17793  2588 K562
# GM12878_TTTGTGGCACTTAACG-1 GM12878_TTTGTGGCACTTAACG-1  11882   598 K562
# GM12878_TTTGTGTTCCAAACAC-1 GM12878_TTTGTGTTCCAAACAC-1  11987  1440 K562
# GM12878_TTTGTGTTCCAAGTTA-1 GM12878_TTTGTGTTCCAAGTTA-1  27044  2222 K562
# GM12878_TTTGTGTTCCTCAGCT-1 GM12878_TTTGTGTTCCTCAGCT-1  37531  3515 K562
# GM12878_TTTGTGTTCGCCTAAG-1 GM12878_TTTGTGTTCGCCTAAG-1  24189  3039 K562
# GM12878_TTTGTTGGTCACAAAT-1 GM12878_TTTGTTGGTCACAAAT-1  11429  2155 K562
# GM12878_TTTGTTGGTTGGTGAC-1 GM12878_TTTGTTGGTTGGTGAC-1  31774   479 K562
#                            log.nUMI  percent.mito
# GM12878_AAACAGCCACTAAGAA-1  9.411729 0.18657510
# GM12878_AAACAGCCATAATCAC-1  8.894944 0.16463331
# GM12878_AAACATGCACTTGTTC-1 10.627867 0.20582035
# GM12878_AAACATGCATAATCAC-1  9.917045 0.12006117
# GM12878_AAACCAACATTAGCGC-1  9.589735 0.17366908
# GM12878_AAACCGAAGCAAGGAC-1  9.250234 0.16046892
# GM12878_AAACCGCGTAACTACG-1 10.607921 0.21315568
# GM12878_AAACCGGCAGTAAGTA-1  8.900276 0.23956913
# GM12878_AAACCGGCATTAAACC-1  9.949894 0.13250597
# GM12878_AAACGGATCTGTAATG-1 10.089054 0.06179915
# GM12878_AAAGCAAGTCATGCAA-1 10.235557 0.24859203
# GM12878_AAAGCAAGTTGTTGGA-1  9.631416 0.17931216
# GM12878_AAAGCACCAAACAACA-1  9.453757 0.09093760
# GM12878_AAAGCACCAATAATGG-1  9.602923 0.18739870
# GM12878_AAAGCACCACCTAATG-1 10.318540 0.14457394
# GM12878_AAAGCCCGTATTTGGG-1  9.858281 0.20448839
# GM12878_AAAGCCCGTTTCAGGA-1  8.628019 0.09040458
# GM12878_AAAGCCGCAGGAACAT-1  8.694167 0.01876676
# GM12878_AAAGCCGCATTGTGCA-1  8.581482 0.02625656
# GM12878_AAAGCGGGTAACGTGC-1  9.758635 0.11963243
# GM12878_AAAGCGGGTCAAAGGG-1  8.680162 0.04893798
# GM12878_AAAGCGGGTTCGCTCA-1  9.682155 0.09694928
# GM12878_AAAGCTTGTACGGTAC-1 10.123867 0.14648430
# GM12878_AAAGCTTGTTAAGGTT-1 10.422162 0.25410763
# GM12878_AAAGGACGTTAAGCGC-1  9.517604 0.12090902
# GM12878_AAAGGAGCAAGGTATA-1  8.895356 0.14031241
# GM12878_AAAGGAGCAATAAGCA-1 10.101928 0.13911439
# GM12878_AAAGGCTCAAGGATTA-1  9.901986 0.14376565
# GM12878_AAAGGCTCAGGCTTCG-1  9.718061 0.18140235
# GM12878_AAAGGCTCATAAGTCT-1 10.801859 0.20781072
# ⋮                          ⋮         ⋮
# GM12878_TTTGACTTCAAGACTC-1  8.964823 0.051514764
# GM12878_TTTGACTTCATTACAG-1  9.838576 0.008483167
# GM12878_TTTGACTTCTCAATGA-1 11.566987 0.247236038
# GM12878_TTTGAGTCATCCTAGA-1  9.406400 0.164228177
# GM12878_TTTGAGTCATGCTATG-1  9.667132 0.165357821
# GM12878_TTTGCATTCAATGAGG-1 10.161110 0.148432971
# GM12878_TTTGCATTCATAACTG-1 11.104220 0.189312426
# GM12878_TTTGCATTCCTAAGAC-1  9.391077 0.126867540
# GM12878_TTTGCATTCGCTAAGT-1  8.832296 0.012988908
# GM12878_TTTGCATTCTAGCGTG-1  9.162305 0.112265240
# GM12878_TTTGCGACACAGAAAC-1  9.267099 0.190192744
# GM12878_TTTGCGACACCTATAG-1  9.435562 0.073127894
# GM12878_TTTGCGACACGTGCTG-1  9.978085 0.125156620
# GM12878_TTTGCGACAGGGAGCT-1  9.173469 0.136335339
# GM12878_TTTGCGGAGTGCACGC-1  8.963672 0.002431533
# GM12878_TTTGGCTGTCCTAACT-1  9.851299 0.177053153
# GM12878_TTTGGCTGTTGGCCGA-1  9.301734 0.087158894
# GM12878_TTTGTCCCACATAGCC-1  9.979198 0.141843972
# GM12878_TTTGTGAAGCGCATTG-1  9.095266 0.013800067
# GM12878_TTTGTGAAGCTTTGTT-1  9.780076 0.166364973
# GM12878_TTTGTGGCAAACCTAT-1  9.995474 0.190085283
# GM12878_TTTGTGGCAAAGGTAC-1  8.897272 0.081920131
# GM12878_TTTGTGGCAAGGACCA-1  9.786560 0.145450458
# GM12878_TTTGTGGCACTTAACG-1  9.382780 0.050328228
# GM12878_TTTGTGTTCCAAACAC-1  9.391578 0.120130141
# GM12878_TTTGTGTTCCAAGTTA-1 10.205220 0.082162402
# GM12878_TTTGTGTTCCTCAGCT-1 10.532923 0.093655911
# GM12878_TTTGTGTTCGCCTAAG-1 10.093653 0.125635619
# GM12878_TTTGTTGGTCACAAAT-1  9.343909 0.188555429
# GM12878_TTTGTTGGTTGGTGAC-1 10.366404 0.015075219

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            bs = boot::boot(df2, assoc, R = 100, formula = formula, 
                stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            if (p0 < 0.1) {
                bs = boot::boot(df2, assoc, R = 500, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/SCENT/SCENT_500.250204//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  saveRDS(pairs.E2G.chr.res,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.res)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 581313 ranges and 11 metadata columns:
#        seqnames              ranges strand |  TargetGene               PeakName
#           <Rle>           <IRanges>  <Rle> | <character>            <character>
#   chr1     chr1 100037728-100039259      * |         AGL chr1-100037728-10003..
#   chr1     chr1 100037728-100039259      * |      CDC14A chr1-100037728-10003..
#   chr1     chr1 100037728-100039259      * |         DBT chr1-100037728-10003..
#   chr1     chr1 100037728-100039259      * |        DPH5 chr1-100037728-10003..
#   chr1     chr1 100037728-100039259      * |       EXTL2 chr1-100037728-10003..
#    ...      ...                 ...    ... .         ...                    ...
#   chrX     chrX       999293-999875      * |     SLC25A6     chrX-999293-999875
#   chrX     chrX     9995654-9996249      * |       TBL1X   chrX-9995654-9996249
#   chrX     chrX     9995654-9996249      * |        WWC3   chrX-9995654-9996249
#   chrX     chrX     9997430-9997980      * |       TBL1X   chrX-9997430-9997980
#   chrX     chrX     9997430-9997980      * |        WWC3   chrX-9997430-9997980
#                      PairName       beta        se         z         p
#                   <character>  <numeric> <numeric> <numeric> <numeric>
#   chr1 chr1-100037728-10003.. -0.0510110 0.0374305  -1.36282 0.1729395
#   chr1 chr1-100037728-10003..  0.0982059 0.0378121   2.59721 0.0093985
#   chr1 chr1-100037728-10003..  0.0836199 0.0454760   1.83877 0.0659487
#   chr1 chr1-100037728-10003..  0.0561535 0.0472437   1.18859 0.2346003
#   chr1 chr1-100037728-10003..  0.0589771 0.0387244   1.52300 0.1277595
#    ...                    ...        ...       ...       ...       ...
#   chrX chrX-999293-999875_S.. -0.0235187 0.0356677 -0.659385 0.5096486
#   chrX chrX-9995654-9996249.. -0.0550948 0.0558408 -0.986641 0.3238185
#   chrX chrX-9995654-9996249.. -0.2163902 0.1912503 -1.131450 0.2578657
#   chrX chrX-9997430-9997980..  0.0311106 0.0508343  0.612001 0.5405372
#   chrX chrX-9997430-9997980..  0.3456278 0.1430991  2.415304 0.0157221
#        boot_basic_p boot_basic_p.log10      sign boot_basic_p.log10.signed
#           <numeric>          <numeric> <numeric>                 <numeric>
#   chr1         0.38           0.420216        -1                 -0.420216
#   chr1         0.06           1.221849         1                  1.221849
#   chr1         0.10           1.000000         1                  1.000000
#   chr1         0.30           0.522879         1                  0.522879
#   chr1         0.16           0.795880         1                  0.795880
#    ...          ...                ...       ...                       ...
#   chrX        0.460          0.3372422        -1                -0.3372422
#   chrX        0.540          0.2676062        -1                -0.2676062
#   chrX        0.520          0.2839967        -1                -0.2839967
#   chrX        0.820          0.0861861         1                 0.0861861
#   chrX        0.032          1.4948500         1                 1.4948500
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta         se
# 1      chr1 100037728 100039259 AGL        K562     -0.051011012 0.03743051
# 2      chr1 100037728 100039259 CDC14A     K562      0.098205866 0.03781209
# 3      chr1 100037728 100039259 DBT        K562      0.083619945 0.04547596
# 4      chr1 100037728 100039259 DPH5       K562      0.056153526 0.04724374
# 5      chr1 100037728 100039259 EXTL2      K562      0.058977138 0.03872440
# 6      chr1 100037728 100039259 FRRS1      K562      0.052989554 0.03618094
# 7      chr1 100037728 100039259 RTCA       K562     -0.002747563 0.03731804
# 8      chr1 100037728 100039259 RTCA-AS1   K562      0.029540633 0.11992235
# 9      chr1 100037728 100039259 SASS6      K562     -0.010772036 0.03696560
# 10     chr1 100037728 100039259 SLC30A7    K562      0.023351456 0.02516450
# 11     chr1 100037728 100039259 SLC35A3    K562     -0.074035548 0.05665815
# 12     chr1 100037728 100039259 TRMT13     K562     -0.009350523 0.04930115
# 13     chr1 100037728 100039259 VCAM1      K562      0.027714203 0.15176449
# 14     chr1 100046135 100047262 AGL        K562     -0.005794189 0.05135737
# 15     chr1 100046135 100047262 CDC14A     K562      0.170270139 0.04882479
# 16     chr1 100046135 100047262 DBT        K562      0.069547750 0.06158027
# 17     chr1 100046135 100047262 DPH5       K562      0.032526430 0.06434037
# 18     chr1 100046135 100047262 EXTL2      K562      0.178088314 0.05019724
# 19     chr1 100046135 100047262 FRRS1      K562      0.045708419 0.04957302
# 20     chr1 100046135 100047262 RTCA       K562      0.075025058 0.05016598
# 21     chr1 100046135 100047262 RTCA-AS1   K562     -0.142579860 0.17925341
# 22     chr1 100046135 100047262 SASS6      K562     -0.079097072 0.05193947
# 23     chr1 100046135 100047262 SLC30A7    K562      0.044140436 0.03426260
# 24     chr1 100046135 100047262 SLC35A3    K562     -0.053113787 0.07898132
# 25     chr1 100046135 100047262 TRMT13     K562     -0.037982808 0.06877333
# 26     chr1 100046135 100047262 VCAM1      K562      0.452212398 0.18034132
# 27     chr1 100075645 100076196 AGL        K562      0.129447542 0.04830264
# 28     chr1 100075645 100076196 CDC14A     K562      0.147207074 0.04857821
# 29     chr1 100075645 100076196 DBT        K562      0.003074430 0.06198249
# 30     chr1 100075645 100076196 DPH5       K562      0.023011089 0.06349402
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 581284 chrX  989874    990570   IL3RA      K562     -0.019212795 0.04779410
# 581285 chrX  989874    990570   LINC00106  K562      0.188413736 0.07003877
# 581286 chrX  989874    990570   P2RY8      K562     -0.030407725 0.02728335
# 581287 chrX  989874    990570   PLCXD1     K562     -0.039368195 0.06487043
# 581288 chrX  989874    990570   PPP2R3B    K562      0.040621433 0.11723042
# 581289 chrX  989874    990570   SLC25A6    K562     -0.077432922 0.02423090
# 581290 chrX 9941864   9942678   TBL1X      K562     -0.198791213 0.05228985
# 581291 chrX 9941864   9942678   WWC3       K562      0.511654808 0.12804585
# 581292 chrX  997541    998270   AKAP17A    K562     -0.181644151 0.09535221
# 581293 chrX  997541    998270   ASMTL      K562      0.015634887 0.07951233
# 581294 chrX  997541    998270   GTPBP6     K562     -0.174671853 0.12787846
# 581295 chrX  997541    998270   IL3RA      K562     -0.107190281 0.08616189
# 581296 chrX  997541    998270   LINC00106  K562     -0.183650207 0.13514700
# 581297 chrX  997541    998270   P2RY8      K562      0.005215335 0.04702911
# 581298 chrX  997541    998270   PLCXD1     K562      0.058650482 0.10865880
# 581299 chrX  997541    998270   PPP2R3B    K562      0.094970338 0.19262544
# 581300 chrX  997541    998270   SLC25A6    K562      0.072360379 0.03995299
# 581301 chrX  999293    999875   AKAP17A    K562     -0.020489537 0.07549337
# 581302 chrX  999293    999875   ASMTL      K562     -0.012929519 0.06876580
# 581303 chrX  999293    999875   GTPBP6     K562      0.144542199 0.09633264
# 581304 chrX  999293    999875   IL3RA      K562      0.014804823 0.07018499
# 581305 chrX  999293    999875   LINC00106  K562     -0.004969321 0.10705495
# 581306 chrX  999293    999875   P2RY8      K562     -0.013042382 0.04036715
# 581307 chrX  999293    999875   PLCXD1     K562     -0.122223297 0.09993607
# 581308 chrX  999293    999875   PPP2R3B    K562      0.126850591 0.16521267
# 581309 chrX  999293    999875   SLC25A6    K562     -0.023518746 0.03566771
# 581310 chrX 9995654   9996249   TBL1X      K562     -0.055094811 0.05584077
# 581311 chrX 9995654   9996249   WWC3       K562     -0.216390156 0.19125029
# 581312 chrX 9997430   9997980   TBL1X      K562      0.031110605 0.05083425
# 581313 chrX 9997430   9997980   WWC3       K562      0.345627820 0.14309907
#        z           p            boot_basic_p boot_basic_p.log10 sign
# 1      -1.36281913 0.1729395212 0.380        0.420216403        -1
# 2       2.59720806 0.0093984976 0.060        1.221848750         1
# 3       1.83877243 0.0659486656 0.100        1.000000000         1
# 4       1.18859179 0.2346003390 0.300        0.522878745         1
# 5       1.52299683 0.1277594974 0.160        0.795880017         1
# 6       1.46457115 0.1430379568 0.100        1.000000000         1
# 7      -0.07362560 0.9413083010 0.980        0.008773924        -1
# 8       0.24633133 0.8054257569 0.680        0.167491087         1
# 9      -0.29140702 0.7707400456 0.920        0.036212173        -1
# 10      0.92795247 0.3534322237 0.540        0.267606240         1
# 11     -1.30670617 0.1913125233 0.180        0.744727495        -1
# 12     -0.18966137 0.8495744959 0.800        0.096910013        -1
# 13      0.18261322 0.8551015089 0.740        0.130768280         1
# 14     -0.11282099 0.9101724808 0.880        0.055517328        -1
# 15      3.48737092 0.0004877943 0.004        2.397940009         1
# 16      1.12938375 0.2587359857 0.280        0.552841969         1
# 17      0.50553688 0.6131818025 0.700        0.154901960         1
# 18      3.54777120 0.0003885056 0.012        1.920818754         1
# 19      0.92204218 0.3565065761 0.400        0.397940009         1
# 20      1.49553660 0.1347744558 0.180        0.744727495         1
# 21     -0.79540945 0.4263753638 0.600        0.221848750        -1
# 22     -1.52287008 0.1277912115 0.120        0.920818754        -1
# 23      1.28829799 0.1976422518 0.200        0.698970004         1
# 24     -0.67248540 0.5012747332 0.540        0.267606240        -1
# 25     -0.55228983 0.5807498005 0.660        0.180456064        -1
# 26      2.50753624 0.0121576113 0.008        2.096910013         1
# 27      2.67992692 0.0073638235 0.020        1.698970004         1
# 28      3.03031086 0.0024430215 0.036        1.443697499         1
# 29      0.04960159 0.9604398790 0.960        0.017728767         1
# 30      0.36241349 0.7170430604 0.740        0.130768280         1
# ⋮      ⋮           ⋮            ⋮            ⋮                  ⋮
# 581284 -0.40199094 6.876907e-01 0.680        0.167491087        -1
# 581285  2.69013473 7.142318e-03 0.012        1.920818754         1
# 581286 -1.11451594 2.650579e-01 0.660        0.180456064        -1
# 581287 -0.60687427 5.439344e-01 0.700        0.154901960        -1
# 581288  0.34650933 7.289600e-01 0.820        0.086186148         1
# 581289 -3.19562697 1.395274e-03 0.036        1.443697499        -1
# 581290 -3.80171665 1.436970e-04 0.020        1.698970004        -1
# 581291  3.99587188 6.445659e-05 0.004        2.397940009         1
# 581292 -1.90498095 5.678255e-02 0.120        0.920818754        -1
# 581293  0.19663475 8.441134e-01 0.880        0.055517328         1
# 581294 -1.36592080 1.719638e-01 0.240        0.619788758        -1
# 581295 -1.24405676 2.134787e-01 0.540        0.267606240        -1
# 581296 -1.35889221 1.741807e-01 0.360        0.443697499        -1
# 581297  0.11089589 9.116989e-01 0.980        0.008773924         1
# 581298  0.53976742 5.893574e-01 0.500        0.301029996         1
# 581299  0.49303112 6.219906e-01 0.700        0.154901960         1
# 581300  1.81113793 7.011950e-02 0.340        0.468521083         1
# 581301 -0.27140842 7.860769e-01 0.920        0.036212173        -1
# 581302 -0.18802251 8.508590e-01 0.900        0.045757491        -1
# 581303  1.50044883 1.334982e-01 0.108        0.966576245         1
# 581304  0.21094002 8.329341e-01 0.900        0.045757491         1
# 581305 -0.04641842 9.629768e-01 0.780        0.107905397        -1
# 581306 -0.32309397 7.466241e-01 0.840        0.075720714        -1
# 581307 -1.22301485 2.213241e-01 0.400        0.397940009        -1
# 581308  0.76780185 4.426049e-01 0.480        0.318758763         1
# 581309 -0.65938488 5.096486e-01 0.460        0.337242168        -1
# 581310 -0.98664137 3.238185e-01 0.540        0.267606240        -1
# 581311 -1.13145006 2.578657e-01 0.520        0.283996656        -1
# 581312  0.61200085 5.405372e-01 0.820        0.086186148         1
# 581313  2.41530438 1.572206e-02 0.032        1.494850022         1
#        boot_basic_p.log10.signed
# 1      -0.420216403
# 2       1.221848750
# 3       1.000000000
# 4       0.522878745
# 5       0.795880017
# 6       1.000000000
# 7      -0.008773924
# 8       0.167491087
# 9      -0.036212173
# 10      0.267606240
# 11     -0.744727495
# 12     -0.096910013
# 13      0.130768280
# 14     -0.055517328
# 15      2.397940009
# 16      0.552841969
# 17      0.154901960
# 18      1.920818754
# 19      0.397940009
# 20      0.744727495
# 21     -0.221848750
# 22     -0.920818754
# 23      0.698970004
# 24     -0.267606240
# 25     -0.180456064
# 26      2.096910013
# 27      1.698970004
# 28      1.443697499
# 29      0.017728767
# 30      0.130768280
# ⋮      ⋮
# 581284 -0.167491087
# 581285  1.920818754
# 581286 -0.180456064
# 581287 -0.154901960
# 581288  0.086186148
# 581289 -1.443697499
# 581290 -1.698970004
# 581291  2.397940009
# 581292 -0.920818754
# 581293  0.055517328
# 581294 -0.619788758
# 581295 -0.267606240
# 581296 -0.443697499
# 581297  0.008773924
# 581298  0.301029996
# 581299  0.154901960
# 581300  0.468521083
# 581301 -0.036212173
# 581302 -0.045757491
# 581303  0.966576245
# 581304  0.045757491
# 581305 -0.107905397
# 581306 -0.075720714
# 581307 -0.397940009
# 581308  0.318758763
# 581309 -0.337242168
# 581310 -0.267606240
# 581311 -0.283996656
# 581312  0.086186148
# 581313  1.494850022

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 bit64_4.0.5
#  [43] htmlTable_2.4.2             backports_1.4.1
#  [45] BiocParallel_1.36.0         R.utils_2.12.3
#  [47] MASS_7.3-60                 DelayedArray_0.26.7
#  [49] rjson_0.2.21                tools_4.3.3
#  [51] foreign_0.8-86              future.apply_1.11.2
#  [53] nnet_7.3-19                 R.oo_1.26.0
#  [55] glue_1.7.0                  restfulr_0.0.15
#  [57] nlme_3.1-164                pbdZMQ_0.3-11
#  [59] checkmate_2.3.1             gridBase_0.4-7
#  [61] cluster_2.1.6               reshape2_1.4.4
#  [63] generics_0.1.3              gtable_0.3.5
#  [65] BSgenome_1.68.0             tzdb_0.4.0
#  [67] R.methodsS3_1.8.2           tidyr_1.3.1
#  [69] seqPattern_1.34.0           hms_1.1.3
#  [71] sp_2.1-4                    utf8_1.2.4
#  [73] XVector_0.42.0              pillar_1.9.0
#  [75] stringr_1.5.1               vroom_1.6.5
#  [77] spam_2.10-0                 IRdisplay_1.1
#  [79] splines_4.3.3               lattice_0.22-6
#  [81] bit_4.0.5                   rtracklayer_1.60.1
#  [83] tidyselect_1.2.1            Biostrings_2.70.1
#  [85] pbapply_1.7-2               knitr_1.46
#  [87] gridExtra_2.3               SummarizedExperiment_1.30.2
#  [89] RhpcBLASctl_0.23-42         xfun_0.43
#  [91] Biobase_2.60.0              matrixStats_1.3.0
#  [93] stringi_1.8.3               yaml_2.3.8
#  [95] boot_1.3-30                 evaluate_0.23
#  [97] codetools_0.2-20            tibble_3.2.1
#  [99] cli_3.6.2                   IRkernel_1.3.2
# [101] rpart_4.1.23                repr_1.1.7
# [103] munsell_0.5.1               Rcpp_1.0.12
# [105] globals_0.16.3              XML_3.99-0.16.1
# [107] ggplot2_3.5.1               readr_2.1.5
# [109] dotCall64_1.1-1             bitops_1.0-7
# [111] lme4_1.1-35.3               listenv_0.9.1
# [113] scales_1.3.0                SeuratObject_5.0.1
# [115] purrr_1.0.2                 crayon_1.5.2
# [117] rlang_1.1.3                 fastmatch_1.1-4
