# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/SCENT/SCENT_2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/SCENT/SCENT_25000.240628/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/GM12878/GM12878.multiome_7features/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/1.prepare_data/1.seurat_pipeline.240615/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/GM12878/2.Genome_wide_prediction/SCENT/SCENT_25000.250329/"
celltype = "GM12878"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI   nMito celltype
# GM12878_AAACAGCCACTAAGAA-1 GM12878_AAACAGCCACTAAGAA-1 12231   2282 GM12878
# GM12878_AAACAGCCATAATCAC-1 GM12878_AAACAGCCATAATCAC-1  7295   1201 GM12878
# GM12878_AAACATGCACTTGTTC-1 GM12878_AAACATGCACTTGTTC-1 41269   8494 GM12878
# GM12878_AAACATGCATAATCAC-1 GM12878_AAACATGCATAATCAC-1 20273   2434 GM12878
# GM12878_AAACCAACATTAGCGC-1 GM12878_AAACCAACATTAGCGC-1 14614   2538 GM12878
# GM12878_AAACCGAAGCAAGGAC-1 GM12878_AAACCGAAGCAAGGAC-1 10407   1670 GM12878
# GM12878_AAACCGCGTAACTACG-1 GM12878_AAACCGCGTAACTACG-1 40454   8623 GM12878
# GM12878_AAACCGGCAGTAAGTA-1 GM12878_AAACCGGCAGTAAGTA-1  7334   1757 GM12878
# GM12878_AAACCGGCATTAAACC-1 GM12878_AAACCGGCATTAAACC-1 20950   2776 GM12878
# GM12878_AAACGGATCTGTAATG-1 GM12878_AAACGGATCTGTAATG-1 24078   1488 GM12878
# GM12878_AAAGCAAGTCATGCAA-1 GM12878_AAAGCAAGTCATGCAA-1 27877   6930 GM12878
# GM12878_AAAGCAAGTTGTTGGA-1 GM12878_AAAGCAAGTTGTTGGA-1 15236   2732 GM12878
# GM12878_AAAGCACCAAACAACA-1 GM12878_AAAGCACCAAACAACA-1 12756   1160 GM12878
# GM12878_AAAGCACCAATAATGG-1 GM12878_AAAGCACCAATAATGG-1 14808   2775 GM12878
# GM12878_AAAGCACCACCTAATG-1 GM12878_AAAGCACCACCTAATG-1 30289   4379 GM12878
# GM12878_AAAGCCCGTATTTGGG-1 GM12878_AAAGCCCGTATTTGGG-1 19116   3909 GM12878
# GM12878_AAAGCCCGTTTCAGGA-1 GM12878_AAAGCCCGTTTCAGGA-1  5586    505 GM12878
# GM12878_AAAGCCGCAGGAACAT-1 GM12878_AAAGCCGCAGGAACAT-1  5968    112 GM12878
# GM12878_AAAGCCGCATTGTGCA-1 GM12878_AAAGCCGCATTGTGCA-1  5332    140 GM12878
# GM12878_AAAGCGGGTAACGTGC-1 GM12878_AAAGCGGGTAACGTGC-1 17303   2070 GM12878
# GM12878_AAAGCGGGTCAAAGGG-1 GM12878_AAAGCGGGTCAAAGGG-1  5885    288 GM12878
# GM12878_AAAGCGGGTTCGCTCA-1 GM12878_AAAGCGGGTTCGCTCA-1 16029   1554 GM12878
# GM12878_AAAGCTTGTACGGTAC-1 GM12878_AAAGCTTGTACGGTAC-1 24931   3652 GM12878
# GM12878_AAAGCTTGTTAAGGTT-1 GM12878_AAAGCTTGTTAAGGTT-1 33596   8537 GM12878
# GM12878_AAAGGACGTTAAGCGC-1 GM12878_AAAGGACGTTAAGCGC-1 13597   1644 GM12878
# GM12878_AAAGGAGCAAGGTATA-1 GM12878_AAAGGAGCAAGGTATA-1  7298   1024 GM12878
# GM12878_AAAGGAGCAATAAGCA-1 GM12878_AAAGGAGCAATAAGCA-1 24390   3393 GM12878
# GM12878_AAAGGCTCAAGGATTA-1 GM12878_AAAGGCTCAAGGATTA-1 19970   2871 GM12878
# GM12878_AAAGGCTCAGGCTTCG-1 GM12878_AAAGGCTCAGGCTTCG-1 16615   3014 GM12878
# GM12878_AAAGGCTCATAAGTCT-1 GM12878_AAAGGCTCATAAGTCT-1 49112  10206 GM12878
# ⋮                          ⋮                          ⋮      ⋮     ⋮
# GM12878_TTTGACTTCAAGACTC-1 GM12878_TTTGACTTCAAGACTC-1   7823   403 GM12878
# GM12878_TTTGACTTCATTACAG-1 GM12878_TTTGACTTCATTACAG-1  18743   159 GM12878
# GM12878_TTTGACTTCTCAATGA-1 GM12878_TTTGACTTCTCAATGA-1 105555 26097 GM12878
# GM12878_TTTGAGTCATCCTAGA-1 GM12878_TTTGAGTCATCCTAGA-1  12166  1998 GM12878
# GM12878_TTTGAGTCATGCTATG-1 GM12878_TTTGAGTCATGCTATG-1  15790  2611 GM12878
# GM12878_TTTGCATTCAATGAGG-1 GM12878_TTTGCATTCAATGAGG-1  25877  3841 GM12878
# GM12878_TTTGCATTCATAACTG-1 GM12878_TTTGCATTCATAACTG-1  66451 12580 GM12878
# GM12878_TTTGCATTCCTAAGAC-1 GM12878_TTTGCATTCCTAAGAC-1  11981  1520 GM12878
# GM12878_TTTGCATTCGCTAAGT-1 GM12878_TTTGCATTCGCTAAGT-1   6852    89 GM12878
# GM12878_TTTGCATTCTAGCGTG-1 GM12878_TTTGCATTCTAGCGTG-1   9531  1070 GM12878
# GM12878_TTTGCGACACAGAAAC-1 GM12878_TTTGCGACACAGAAAC-1  10584  2013 GM12878
# GM12878_TTTGCGACACCTATAG-1 GM12878_TTTGCGACACCTATAG-1  12526   916 GM12878
# GM12878_TTTGCGACACGTGCTG-1 GM12878_TTTGCGACACGTGCTG-1  21549  2697 GM12878
# GM12878_TTTGCGACAGGGAGCT-1 GM12878_TTTGCGACAGGGAGCT-1   9638  1314 GM12878
# GM12878_TTTGCGGAGTGCACGC-1 GM12878_TTTGCGGAGTGCACGC-1   7814    19 GM12878
# GM12878_TTTGGCTGTCCTAACT-1 GM12878_TTTGGCTGTCCTAACT-1  18983  3361 GM12878
# GM12878_TTTGGCTGTTGGCCGA-1 GM12878_TTTGGCTGTTGGCCGA-1  10957   955 GM12878
# GM12878_TTTGTCCCACATAGCC-1 GM12878_TTTGTCCCACATAGCC-1  21573  3060 GM12878
# GM12878_TTTGTGAAGCGCATTG-1 GM12878_TTTGTGAAGCGCATTG-1   8913   123 GM12878
# GM12878_TTTGTGAAGCTTTGTT-1 GM12878_TTTGTGAAGCTTTGTT-1  17678  2941 GM12878
# GM12878_TTTGTGGCAAACCTAT-1 GM12878_TTTGTGGCAAACCTAT-1  21927  4168 GM12878
# GM12878_TTTGTGGCAAAGGTAC-1 GM12878_TTTGTGGCAAAGGTAC-1   7312   599 GM12878
# GM12878_TTTGTGGCAAGGACCA-1 GM12878_TTTGTGGCAAGGACCA-1  17793  2588 GM12878
# GM12878_TTTGTGGCACTTAACG-1 GM12878_TTTGTGGCACTTAACG-1  11882   598 GM12878
# GM12878_TTTGTGTTCCAAACAC-1 GM12878_TTTGTGTTCCAAACAC-1  11987  1440 GM12878
# GM12878_TTTGTGTTCCAAGTTA-1 GM12878_TTTGTGTTCCAAGTTA-1  27044  2222 GM12878
# GM12878_TTTGTGTTCCTCAGCT-1 GM12878_TTTGTGTTCCTCAGCT-1  37531  3515 GM12878
# GM12878_TTTGTGTTCGCCTAAG-1 GM12878_TTTGTGTTCGCCTAAG-1  24189  3039 GM12878
# GM12878_TTTGTTGGTCACAAAT-1 GM12878_TTTGTTGGTCACAAAT-1  11429  2155 GM12878
# GM12878_TTTGTTGGTTGGTGAC-1 GM12878_TTTGTTGGTTGGTGAC-1  31774   479 GM12878
#                            log.nUMI  percent.mito
# GM12878_AAACAGCCACTAAGAA-1  9.411729 0.18657510
# GM12878_AAACAGCCATAATCAC-1  8.894944 0.16463331
# GM12878_AAACATGCACTTGTTC-1 10.627867 0.20582035
# GM12878_AAACATGCATAATCAC-1  9.917045 0.12006117
# GM12878_AAACCAACATTAGCGC-1  9.589735 0.17366908
# GM12878_AAACCGAAGCAAGGAC-1  9.250234 0.16046892
# GM12878_AAACCGCGTAACTACG-1 10.607921 0.21315568
# GM12878_AAACCGGCAGTAAGTA-1  8.900276 0.23956913
# GM12878_AAACCGGCATTAAACC-1  9.949894 0.13250597
# GM12878_AAACGGATCTGTAATG-1 10.089054 0.06179915
# GM12878_AAAGCAAGTCATGCAA-1 10.235557 0.24859203
# GM12878_AAAGCAAGTTGTTGGA-1  9.631416 0.17931216
# GM12878_AAAGCACCAAACAACA-1  9.453757 0.09093760
# GM12878_AAAGCACCAATAATGG-1  9.602923 0.18739870
# GM12878_AAAGCACCACCTAATG-1 10.318540 0.14457394
# GM12878_AAAGCCCGTATTTGGG-1  9.858281 0.20448839
# GM12878_AAAGCCCGTTTCAGGA-1  8.628019 0.09040458
# GM12878_AAAGCCGCAGGAACAT-1  8.694167 0.01876676
# GM12878_AAAGCCGCATTGTGCA-1  8.581482 0.02625656
# GM12878_AAAGCGGGTAACGTGC-1  9.758635 0.11963243
# GM12878_AAAGCGGGTCAAAGGG-1  8.680162 0.04893798
# GM12878_AAAGCGGGTTCGCTCA-1  9.682155 0.09694928
# GM12878_AAAGCTTGTACGGTAC-1 10.123867 0.14648430
# GM12878_AAAGCTTGTTAAGGTT-1 10.422162 0.25410763
# GM12878_AAAGGACGTTAAGCGC-1  9.517604 0.12090902
# GM12878_AAAGGAGCAAGGTATA-1  8.895356 0.14031241
# GM12878_AAAGGAGCAATAAGCA-1 10.101928 0.13911439
# GM12878_AAAGGCTCAAGGATTA-1  9.901986 0.14376565
# GM12878_AAAGGCTCAGGCTTCG-1  9.718061 0.18140235
# GM12878_AAAGGCTCATAAGTCT-1 10.801859 0.20781072
# ⋮                          ⋮         ⋮
# GM12878_TTTGACTTCAAGACTC-1  8.964823 0.051514764
# GM12878_TTTGACTTCATTACAG-1  9.838576 0.008483167
# GM12878_TTTGACTTCTCAATGA-1 11.566987 0.247236038
# GM12878_TTTGAGTCATCCTAGA-1  9.406400 0.164228177
# GM12878_TTTGAGTCATGCTATG-1  9.667132 0.165357821
# GM12878_TTTGCATTCAATGAGG-1 10.161110 0.148432971
# GM12878_TTTGCATTCATAACTG-1 11.104220 0.189312426
# GM12878_TTTGCATTCCTAAGAC-1  9.391077 0.126867540
# GM12878_TTTGCATTCGCTAAGT-1  8.832296 0.012988908
# GM12878_TTTGCATTCTAGCGTG-1  9.162305 0.112265240
# GM12878_TTTGCGACACAGAAAC-1  9.267099 0.190192744
# GM12878_TTTGCGACACCTATAG-1  9.435562 0.073127894
# GM12878_TTTGCGACACGTGCTG-1  9.978085 0.125156620
# GM12878_TTTGCGACAGGGAGCT-1  9.173469 0.136335339
# GM12878_TTTGCGGAGTGCACGC-1  8.963672 0.002431533
# GM12878_TTTGGCTGTCCTAACT-1  9.851299 0.177053153
# GM12878_TTTGGCTGTTGGCCGA-1  9.301734 0.087158894
# GM12878_TTTGTCCCACATAGCC-1  9.979198 0.141843972
# GM12878_TTTGTGAAGCGCATTG-1  9.095266 0.013800067
# GM12878_TTTGTGAAGCTTTGTT-1  9.780076 0.166364973
# GM12878_TTTGTGGCAAACCTAT-1  9.995474 0.190085283
# GM12878_TTTGTGGCAAAGGTAC-1  8.897272 0.081920131
# GM12878_TTTGTGGCAAGGACCA-1  9.786560 0.145450458
# GM12878_TTTGTGGCACTTAACG-1  9.382780 0.050328228
# GM12878_TTTGTGTTCCAAACAC-1  9.391578 0.120130141
# GM12878_TTTGTGTTCCAAGTTA-1 10.205220 0.082162402
# GM12878_TTTGTGTTCCTCAGCT-1 10.532923 0.093655911
# GM12878_TTTGTGTTCGCCTAAG-1 10.093653 0.125635619
# GM12878_TTTGTTGGTCACAAAT-1  9.343909 0.188555429
# GM12878_TTTGTTGGTTGGTGAC-1 10.366404 0.015075219

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 24824 ranges and 11 metadata columns:
#                                    seqnames              ranges strand |
#                                       <Rle>           <IRanges>  <Rle> |
#    chr1-100046135-100047262_CDC14A     chr1 100046135-100047262      * |
#     chr1-100076765-100077110_VCAM1     chr1 100076765-100077110      * |
#   chr1-100130541-100130939_SLC30A7     chr1 100130541-100130939      * |
#    chr1-10018560-10019420_MIR34AHG     chr1   10018560-10019420      * |
#         chr1-1002214-1002764_PUSL1     chr1     1002214-1002764      * |
#                                ...      ...                 ...    ... .
#     chrX-79144082-79144805_CYSLTR1     chrX   79144082-79144805      * |
#       chrX-80808038-80808500_BRWD3     chrX   80808038-80808500      * |
#       chrX-81120893-81121373_BRWD3     chrX   81120893-81121373      * |
#     chrX-81201586-81202380_SH3BGRL     chrX   81201586-81202380      * |
#          chrX-9941864-9942678_WWC3     chrX     9941864-9942678      * |
#                                     TargetGene               PeakName
#                                    <character>            <character>
#    chr1-100046135-100047262_CDC14A      CDC14A chr1-100046135-10004..
#     chr1-100076765-100077110_VCAM1       VCAM1 chr1-100076765-10007..
#   chr1-100130541-100130939_SLC30A7     SLC30A7 chr1-100130541-10013..
#    chr1-10018560-10019420_MIR34AHG    MIR34AHG chr1-10018560-10019420
#         chr1-1002214-1002764_PUSL1       PUSL1   chr1-1002214-1002764
#                                ...         ...                    ...
#     chrX-79144082-79144805_CYSLTR1     CYSLTR1 chrX-79144082-79144805
#       chrX-80808038-80808500_BRWD3       BRWD3 chrX-80808038-80808500
#       chrX-81120893-81121373_BRWD3       BRWD3 chrX-81120893-81121373
#     chrX-81201586-81202380_SH3BGRL     SH3BGRL chrX-81201586-81202380
#          chrX-9941864-9942678_WWC3        WWC3   chrX-9941864-9942678
#                                                  PairName      beta        se
#                                               <character> <numeric> <numeric>
#    chr1-100046135-100047262_CDC14A chr1-100046135-10004..  0.170270 0.0488248
#     chr1-100076765-100077110_VCAM1 chr1-100076765-10007..  0.737066 0.1968919
#   chr1-100130541-100130939_SLC30A7 chr1-100130541-10013..  0.158513 0.0423747
#    chr1-10018560-10019420_MIR34AHG chr1-10018560-100194..  0.280014 0.0504886
#         chr1-1002214-1002764_PUSL1 chr1-1002214-1002764..  0.570481 0.2142683
#                                ...                    ...       ...       ...
#     chrX-79144082-79144805_CYSLTR1 chrX-79144082-791448.. 0.3491315 0.0744344
#       chrX-80808038-80808500_BRWD3 chrX-80808038-808085.. 0.1396710 0.0329538
#       chrX-81120893-81121373_BRWD3 chrX-81120893-811213.. 0.1372708 0.0380777
#     chrX-81201586-81202380_SH3BGRL chrX-81201586-812023.. 0.0979234 0.0272100
#          chrX-9941864-9942678_WWC3 chrX-9941864-9942678.. 0.5116548 0.1280458
#                                            z           p boot_basic_p
#                                    <numeric>   <numeric>    <numeric>
#    chr1-100046135-100047262_CDC14A   3.48737 4.87794e-04      0.00976
#     chr1-100076765-100077110_VCAM1   3.74351 1.81469e-04      0.00024
#   chr1-100130541-100130939_SLC30A7   3.74074 1.83476e-04      0.00152
#    chr1-10018560-10019420_MIR34AHG   5.54608 2.92143e-08      0.00008
#         chr1-1002214-1002764_PUSL1   2.66246 7.75713e-03      0.00304
#                                ...       ...         ...          ...
#     chrX-79144082-79144805_CYSLTR1   4.69046 2.72592e-06      0.00360
#       chrX-80808038-80808500_BRWD3   4.23839 2.25128e-05      0.00280
#       chrX-81120893-81121373_BRWD3   3.60501 3.12136e-04      0.00928
#     chrX-81201586-81202380_SH3BGRL   3.59880 3.19686e-04      0.00944
#          chrX-9941864-9942678_WWC3   3.99587 6.44566e-05      0.00016
#                                    boot_basic_p.log10      sign
#                                             <numeric> <numeric>
#    chr1-100046135-100047262_CDC14A            2.01055         1
#     chr1-100076765-100077110_VCAM1            3.61979         1
#   chr1-100130541-100130939_SLC30A7            2.81816         1
#    chr1-10018560-10019420_MIR34AHG            4.09691         1
#         chr1-1002214-1002764_PUSL1            2.51713         1
#                                ...                ...       ...
#     chrX-79144082-79144805_CYSLTR1            2.44370         1
#       chrX-80808038-80808500_BRWD3            2.55284         1
#       chrX-81120893-81121373_BRWD3            2.03245         1
#     chrX-81201586-81202380_SH3BGRL            2.02503         1
#          chrX-9941864-9942678_WWC3            3.79588         1
#                                    boot_basic_p.log10.signed
#                                                    <numeric>
#    chr1-100046135-100047262_CDC14A                   2.01055
#     chr1-100076765-100077110_VCAM1                   3.61979
#   chr1-100130541-100130939_SLC30A7                   2.81816
#    chr1-10018560-10019420_MIR34AHG                   4.09691
#         chr1-1002214-1002764_PUSL1                   2.51713
#                                ...                       ...
#     chrX-79144082-79144805_CYSLTR1                   2.44370
#       chrX-80808038-80808500_BRWD3                   2.55284
#       chrX-81120893-81121373_BRWD3                   2.03245
#     chrX-81201586-81202380_SH3BGRL                   2.02503
#          chrX-9941864-9942678_WWC3                   3.79588
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  3636 23904

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 581313 ranges and 11 metadata columns:
#                                       seqnames              ranges strand |
#                                          <Rle>           <IRanges>  <Rle> |
#                        chr1.chr1.chr1     chr1   10018560-10019420      * |
#                        chr1.chr1.chr1     chr1 100351099-100353005      * |
#                        chr1.chr1.chr1     chr1 101293198-101294049      * |
#                        chr1.chr1.chr1     chr1   10173472-10174051      * |
#                        chr1.chr1.chr1     chr1   10283112-10283967      * |
#                                   ...      ...                 ...    ... .
#     chrX.chrX-78957089-78958373_ITM2A     chrX   78957089-78958373      * |
#   chrX.chrX-79144082-79144805_CYSLTR1     chrX   79144082-79144805      * |
#     chrX.chrX-80808038-80808500_BRWD3     chrX   80808038-80808500      * |
#   chrX.chrX-81201586-81202380_SH3BGRL     chrX   81201586-81202380      * |
#        chrX.chrX-9941864-9942678_WWC3     chrX     9941864-9942678      * |
#                                        TargetGene               PeakName
#                                       <character>            <character>
#                        chr1.chr1.chr1   LINC01759 chr1-10018560-10019420
#                        chr1.chr1.chr1         DBT chr1-100351099-10035..
#                        chr1.chr1.chr1       VCAM1 chr1-101293198-10129..
#                        chr1.chr1.chr1      CLSTN1 chr1-10173472-10174051
#                        chr1.chr1.chr1      CLSTN1 chr1-10283112-10283967
#                                   ...         ...                    ...
#     chrX.chrX-78957089-78958373_ITM2A       ITM2A chrX-78957089-78958373
#   chrX.chrX-79144082-79144805_CYSLTR1     CYSLTR1 chrX-79144082-79144805
#     chrX.chrX-80808038-80808500_BRWD3       BRWD3 chrX-80808038-80808500
#   chrX.chrX-81201586-81202380_SH3BGRL     SH3BGRL chrX-81201586-81202380
#        chrX.chrX-9941864-9942678_WWC3        WWC3   chrX-9941864-9942678
#                                                     PairName       beta
#                                                  <character>  <numeric>
#                        chr1.chr1.chr1 chr1-10018560-100194..   0.512265
#                        chr1.chr1.chr1 chr1-100351099-10035..   0.125985
#                        chr1.chr1.chr1 chr1-101293198-10129..   0.467674
#                        chr1.chr1.chr1 chr1-10173472-101740..  -0.133140
#                        chr1.chr1.chr1 chr1-10283112-102839..  -0.173677
#                                   ...                    ...        ...
#     chrX.chrX-78957089-78958373_ITM2A chrX-78957089-789583.. -0.2059413
#   chrX.chrX-79144082-79144805_CYSLTR1 chrX-79144082-791448..  0.3491315
#     chrX.chrX-80808038-80808500_BRWD3 chrX-80808038-808085..  0.1396710
#   chrX.chrX-81201586-81202380_SH3BGRL chrX-81201586-812023..  0.0979234
#        chrX.chrX-9941864-9942678_WWC3 chrX-9941864-9942678..  0.5116548
#                                              se         z           p
#                                       <numeric> <numeric>   <numeric>
#                        chr1.chr1.chr1 0.1532936   3.34172 0.000832596
#                        chr1.chr1.chr1 0.0445794   2.82608 0.004712166
#                        chr1.chr1.chr1 0.1609444   2.90581 0.003663011
#                        chr1.chr1.chr1 0.0407248  -3.26925 0.001078330
#                        chr1.chr1.chr1 0.0538400  -3.22579 0.001256234
#                                   ...       ...       ...         ...
#     chrX.chrX-78957089-78958373_ITM2A 0.0464231  -4.43618 9.15682e-06
#   chrX.chrX-79144082-79144805_CYSLTR1 0.0744344   4.69046 2.72592e-06
#     chrX.chrX-80808038-80808500_BRWD3 0.0329538   4.23839 2.25128e-05
#   chrX.chrX-81201586-81202380_SH3BGRL 0.0272100   3.59880 3.19686e-04
#        chrX.chrX-9941864-9942678_WWC3 0.1280458   3.99587 6.44566e-05
#                                       boot_basic_p boot_basic_p.log10      sign
#                                          <numeric>          <numeric> <numeric>
#                        chr1.chr1.chr1      0.00056            3.25181         1
#                        chr1.chr1.chr1      0.01096            1.96019         1
#                        chr1.chr1.chr1      0.00760            2.11919         1
#                        chr1.chr1.chr1      0.00688            2.16241        -1
#                        chr1.chr1.chr1      0.01128            1.94769        -1
#                                   ...          ...                ...       ...
#     chrX.chrX-78957089-78958373_ITM2A      0.00120            2.92082        -1
#   chrX.chrX-79144082-79144805_CYSLTR1      0.00360            2.44370         1
#     chrX.chrX-80808038-80808500_BRWD3      0.00280            2.55284         1
#   chrX.chrX-81201586-81202380_SH3BGRL      0.00944            2.02503         1
#        chrX.chrX-9941864-9942678_WWC3      0.00016            3.79588         1
#                                       boot_basic_p.log10.signed
#                                                       <numeric>
#                        chr1.chr1.chr1                   3.25181
#                        chr1.chr1.chr1                   1.96019
#                        chr1.chr1.chr1                   2.11919
#                        chr1.chr1.chr1                  -2.16241
#                        chr1.chr1.chr1                  -1.94769
#                                   ...                       ...
#     chrX.chrX-78957089-78958373_ITM2A                  -2.92082
#   chrX.chrX-79144082-79144805_CYSLTR1                   2.44370
#     chrX.chrX-80808038-80808500_BRWD3                   2.55284
#   chrX.chrX-81201586-81202380_SH3BGRL                   2.02503
#        chrX.chrX-9941864-9942678_WWC3                   3.79588
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta        se
# 1      chr1  10018560  10019420 LINC01759  GM12878   0.51226502 0.15329360
# 2      chr1 100351099 100353005 DBT        GM12878   0.12598501 0.04457944
# 3      chr1 101293198 101294049 VCAM1      GM12878   0.46767426 0.16094442
# 4      chr1  10173472  10174051 CLSTN1     GM12878  -0.13313952 0.04072479
# 5      chr1  10283112  10283967 CLSTN1     GM12878  -0.17367679 0.05384000
# 6      chr1   1040556   1041310 AGRN       GM12878   0.24811687 0.09705450
# 7      chr1   1040556   1041310 NOC2L      GM12878   0.14858030 0.05649194
# 8      chr1  10494571  10495722 PEX14      GM12878   0.10124624 0.02801731
# 9      chr1  10516148  10516725 MTOR       GM12878   0.15655726 0.05683372
# 10     chr1 109483316 109484492 FAM102B    GM12878   0.19724943 0.04935370
# 11     chr1 110243275 110244146 CSF1       GM12878   0.33011210 0.10803891
# 12     chr1 110619220 110620095 ATP5F1     GM12878  -0.15002553 0.03571826
# 13     chr1 110726476 110727679 RBM15      GM12878  -0.28921040 0.09783742
# 14     chr1 110787213 110788290 LAMTOR5    GM12878  -0.17131729 0.05986303
# 15     chr1 110903123 110904650 FAM212B    GM12878   0.30956270 0.07983789
# 16     chr1 111199896 111200766 ATP5F1     GM12878  -0.13803542 0.02990323
# 17     chr1 111221555 111222404 CD53       GM12878  -0.06563360 0.01394669
# 18     chr1 111454771 111455542 FAM212B    GM12878   0.21549816 0.07046334
# 19     chr1 111616294 111616850 FAM212B    GM12878   0.20154106 0.06331720
# 20     chr1 112507909 112509494 MAGI3      GM12878  -0.21094438 0.05530931
# 21     chr1  11335244  11336005 SRM        GM12878  -0.21666951 0.05493548
# 22     chr1 114757228 114758298 TRIM33     GM12878   0.07365504 0.02615997
# 23     chr1 116373892 116374266 ATP1A1     GM12878  -0.12700235 0.02942977
# 24     chr1 116738660 116739341 ATP1A1     GM12878   0.12588770 0.02886693
# 25     chr1  11893754  11894406 VPS13D     GM12878   0.15636926 0.05024461
# 26     chr1  11914789  11915715 AGTRAP     GM12878   0.33897118 0.13275558
# 27     chr1  11982086  11982292 FBXO6      GM12878   0.30800025 0.13275971
# 28     chr1  12051948  12052587 TNFRSF8    GM12878   0.12931800 0.02622123
# 29     chr1  12054279  12054529 KIAA2013   GM12878  -0.37625215 0.12527149
# 30     chr1  12153191  12153773 CLCN6      GM12878   0.17662813 0.05808545
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮           ⋮
# 581284 chrX 56813252  56813924  SPIN3      GM12878   0.38311143 0.09810211
# 581285 chrX 63101430  63102720  LINC01278  GM12878   0.20065556 0.05487318
# 581286 chrX 65697885  65698806  EDA2R      GM12878   0.21692285 0.06418536
# 581287 chrX 65871727  65872533  LAS1L      GM12878   0.24620735 0.08382505
# 581288 chrX 70176667  70177553  DGAT2L6    GM12878   0.87063137 0.15429396
# 581289 chrX 71068023  71068945  TAF1       GM12878   0.10347672 0.03146262
# 581290 chrX 71103367  71103971  DGAT2L6    GM12878   0.68818004 0.17088566
# 581291 chrX 71111258  71112374  SNX12      GM12878   0.42854738 0.12905388
# 581292 chrX 71253882  71254876  OGT        GM12878   0.08156112 0.02411674
# 581293 chrX 71365627  71366477  RPS4X      GM12878  -0.07520800 0.01024907
# 581294 chrX 71365627  71366477  TAF1       GM12878   0.10728760 0.03167283
# 581295 chrX 71532528  71533410  CXCR3      GM12878   0.26291826 0.08293380
# 581296 chrX 72018428  72019067  SNX12      GM12878   0.53186068 0.16821622
# 581297 chrX 72100760  72101422  ZMYM3      GM12878   0.39699999 0.12861293
# 581298 chrX 72181037  72182014  RPS4X      GM12878  -0.08978767 0.01064545
# 581299 chrX 72276800  72277541  RPS4X      GM12878  -0.08085573 0.01034644
# 581300 chrX 72572295  72573447  RPS4X      GM12878  -0.14579976 0.01589422
# 581301 chrX 73943871  73944629  JPX        GM12878   0.07232859 0.02004551
# 581302 chrX 73943871  73944629  XIST       GM12878   0.09658280 0.01231921
# 581303 chrX 75273730  75274727  FTX        GM12878   0.09726051 0.01757109
# 581304 chrX 78064768  78065691  P2RY10     GM12878  -0.19201087 0.03065135
# 581305 chrX 78517122  78517702  ITM2A      GM12878  -0.29874243 0.07684440
# 581306 chrX 78650645  78651521  CYSLTR1    GM12878   0.27510755 0.07633077
# 581307 chrX 78650645  78651521  TAF9B      GM12878   0.54163281 0.17089594
# 581308 chrX 78687184  78688163  ATRX       GM12878   0.14601369 0.02646383
# 581309 chrX 78957089  78958373  ITM2A      GM12878  -0.20594133 0.04642310
# 581310 chrX 79144082  79144805  CYSLTR1    GM12878   0.34913145 0.07443438
# 581311 chrX 80808038  80808500  BRWD3      GM12878   0.13967095 0.03295377
# 581312 chrX 81201586  81202380  SH3BGRL    GM12878   0.09792338 0.02720999
# 581313 chrX  9941864   9942678  WWC3       GM12878   0.51165481 0.12804585
#        z         p            boot_basic_p boot_basic_p.log10 sign
# 1       3.341725 8.325960e-04 0.00056      3.251812            1
# 2       2.826079 4.712166e-03 0.01096      1.960189            1
# 3       2.905812 3.663011e-03 0.00760      2.119186            1
# 4      -3.269250 1.078330e-03 0.00688      2.162412           -1
# 5      -3.225795 1.256234e-03 0.01128      1.947691           -1
# 6       2.556470 1.057403e-02 0.00760      2.119186            1
# 7       2.630115 8.535596e-03 0.01048      1.979639            1
# 8       3.613703 3.018550e-04 0.01192      1.923724            1
# 9       2.754655 5.875410e-03 0.01088      1.963371            1
# 10      3.996650 6.424530e-05 0.01008      1.996539            1
# 11      3.055493 2.246911e-03 0.01128      1.947691            1
# 12     -4.200247 2.666234e-05 0.00152      2.818156           -1
# 13     -2.956030 3.116263e-03 0.01520      1.818156           -1
# 14     -2.861821 4.212147e-03 0.01040      1.982967           -1
# 15      3.877391 1.055827e-04 0.00016      3.795880            1
# 16     -4.616070 3.910749e-06 0.00016      3.795880           -1
# 17     -4.706033 2.525835e-06 0.01064      1.973058           -1
# 18      3.058302 2.225951e-03 0.00504      2.297569            1
# 19      3.183038 1.457385e-03 0.00344      2.463442            1
# 20     -3.813904 1.367887e-04 0.00984      2.007005           -1
# 21     -3.944072 8.010951e-05 0.00768      2.114639           -1
# 22      2.815563 4.869182e-03 0.01488      1.827397            1
# 23     -4.315439 1.592863e-05 0.00984      2.007005           -1
# 24      4.360967 1.294891e-05 0.01024      1.989700            1
# 25      3.112160 1.857241e-03 0.01024      1.989700            1
# 26      2.553348 1.066928e-02 0.00800      2.096910            1
# 27      2.319983 2.034180e-02 0.01048      1.979639            1
# 28      4.931805 8.147314e-07 0.00824      2.084073            1
# 29     -3.003494 2.668991e-03 0.00832      2.079877           -1
# 30      3.040832 2.359250e-03 0.00888      2.051587            1
# ⋮      ⋮         ⋮            ⋮            ⋮                  ⋮
# 581284  3.905231 9.413533e-05 0.00104      2.982967            1
# 581285  3.656715 2.554684e-04 0.00320      2.494850            1
# 581286  3.379631 7.258319e-04 0.00672      2.172631            1
# 581287  2.937157 3.312363e-03 0.00464      2.333482            1
# 581288  5.642679 1.674239e-08 0.00008      4.096910            1
# 581289  3.288878 1.005877e-03 0.00816      2.088310            1
# 581290  4.027138 5.646001e-05 0.00568      2.245652            1
# 581291  3.320686 8.979662e-04 0.00008      4.096910            1
# 581292  3.381930 7.197854e-04 0.00624      2.204815            1
# 581293 -7.338030 2.167610e-13 0.00440      2.356547           -1
# 581294  3.387370 7.056608e-04 0.00472      2.326058            1
# 581295  3.170218 1.523245e-03 0.00776      2.110138            1
# 581296  3.161768 1.568144e-03 0.00024      3.619789            1
# 581297  3.086781 2.023364e-03 0.00224      2.649752            1
# 581298 -8.434372 3.329857e-17 0.00176      2.754487           -1
# 581299 -7.814838 5.503387e-15 0.00288      2.540608           -1
# 581300 -9.173128 4.594863e-20 0.00016      3.795880           -1
# 581301  3.608218 3.083068e-04 0.00888      2.051587            1
# 581302  7.840014 4.504958e-15 0.00024      3.619789            1
# 581303  5.535256 3.107737e-08 0.00328      2.484126            1
# 581304 -6.264352 3.743791e-10 0.00008      4.096910           -1
# 581305 -3.887628 1.012288e-04 0.00176      2.754487           -1
# 581306  3.604150 3.131758e-04 0.00480      2.318759            1
# 581307  3.169372 1.527687e-03 0.00112      2.950782            1
# 581308  5.517481 3.438939e-08 0.00032      3.494850            1
# 581309 -4.436183 9.156818e-06 0.00120      2.920819           -1
# 581310  4.690459 2.725925e-06 0.00360      2.443697            1
# 581311  4.238390 2.251280e-05 0.00280      2.552842            1
# 581312  3.598802 3.196863e-04 0.00944      2.025028            1
# 581313  3.995872 6.445659e-05 0.00016      3.795880            1
#        boot_basic_p.log10.signed FDR
# 1       3.251812                 0.03790142
# 2       1.960189                 0.22775854
# 3       2.119186                 0.18804711
# 4      -2.162412                 0.17738993
# 5      -1.947691                 0.22912089
# 6       2.119186                 0.18804711
# 7       1.979639                 0.22372972
# 8       1.923724                 0.23364670
# 9       1.963371                 0.22775854
# 10      1.996539                 0.22240574
# 11      1.947691                 0.22912089
# 12     -2.818156                 0.07378054
# 13     -1.818156                 0.25676220
# 14     -1.982967                 0.22240574
# 15      3.795880                 0.01497024
# 16     -3.795880                 0.01497024
# 17     -1.973058                 0.22662112
# 18      2.297569                 0.14891824
# 19      2.463442                 0.12064656
# 20     -2.007005                 0.22139257
# 21     -2.114639                 0.18914099
# 22      1.827397                 0.25676220
# 23     -2.007005                 0.22139257
# 24      1.989700                 0.22240574
# 25      1.989700                 0.22240574
# 26      2.096910                 0.19357742
# 27      1.979639                 0.22372972
# 28      2.084073                 0.19738005
# 29     -2.079877                 0.19855184
# 30      2.051587                 0.20704554
# ⋮      ⋮                         ⋮
# 581284  2.982967                 0.057914122
# 581285  2.494850                 0.115958210
# 581286  2.172631                 0.175058183
# 581287  2.333482                 0.142563019
# 581288  4.096910                 0.008494071
# 581289  2.088310                 0.196215681
# 581290  2.245652                 0.159049029
# 581291  4.096910                 0.008494071
# 581292  2.204815                 0.167639945
# 581293 -2.356547                 0.138400368
# 581294  2.326058                 0.143767218
# 581295  2.110138                 0.190240759
# 581296  3.619789                 0.020574417
# 581297  2.649752                 0.093969916
# 581298 -2.754487                 0.080865545
# 581299 -2.540608                 0.108833221
# 581300 -3.795880                 0.014970237
# 581301  2.051587                 0.207045541
# 581302  3.619789                 0.020574417
# 581303  2.484126                 0.117596314
# 581304 -4.096910                 0.008494071
# 581305 -2.754487                 0.080865545
# 581306  2.318759                 0.145056269
# 581307  2.950782                 0.060768206
# 581308  3.494850                 0.025513669
# 581309 -2.920819                 0.063595186
# 581310  2.443697                 0.123859304
# 581311  2.552842                 0.107126260
# 581312  2.025028                 0.215107002
# 581313  3.795880                 0.014970237

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
