# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR.default_250226/ArchR.250226/"

# %%
inputFiles = c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/atac_fragments.tsv.gz")
names(inputFiles) = c("K562_Xu")

# %%
addArchRThreads(threads = 16) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger"| __truncated__
#   .. ..@ hash : chr [1:2] "c8366071805c37835af9f47f43ae7435" "af5268737bf82cc3e7978e6407c893ea"
#   .. ..@ cells: Named chr [1:7821] "AAACAGCCAAGCGATG-1" "AAACAGCCACATGCTA-1" "AAACAGCCACGGTACT-1" "AAACAGCCATAAAGCA-1" ...
#   .. .. ..- attr(*, "names")= chr [1:7821] "K562_Xu_AAACAGCCAAGCGATG-1" "K562_Xu_AAACAGCCACATGCTA-1" "K562_Xu_AAACAGCCACGGTACT-1" "K562_Xu_AAACAGCCATAAAGCA-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Xu"),
  validBarcodes = list(K562_Xu = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-2a42fe7164eacd-Date-2025-02-26_Time-14-31-16.56323.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2025-02-26 14:31:16.988444 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Xu : 1 of 1) Determining Arrow Method to use!
#
# 2025-02-26 14:31:17.057429 : (K562_Xu : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.001 mins elapsed.
#
# 2025-02-26 14:31:17.067606 : (K562_Xu : 1 of 1) Tabix Bed To Temporary File, 0.001 mins elapsed.
#
# 2025-02-26 14:33:21.372063 : (K562_Xu : 1 of 1) Successful creation of Temporary File, 2.073 mins elapsed.
#
# 2025-02-26 14:33:21.382462 : (K562_Xu : 1 of 1) Creating ArrowFile From Temporary File, 2.073 mins elapsed.
#
# 2025-02-26 14:34:05.06408 : (K562_Xu : 1 of 1) Successful creation of Arrow File, 2.801 mins elapsed.
#
# 2025-02-26 14:34:51.917733 : Continuing through after error ggplot for Fragment Size Distribution, 3.582 mins elapsed.
#
#
#
#
# 2025-02-26 14:35:26.36141 : (K562_Xu : 1 of 1) CellStats : Number of Cells Pass Filter = 7699 , 4.156 mins elapsed.
#
# 2025-02-26 14:35:26.372603 : (K562_Xu : 1 of 1) CellStats : Median Frags = 31472 , 4.156 mins elapsed.
#
# 2025-02-26 14:35:26.378604 : (K562_Xu : 1 of 1) CellStats : Median TSS Enrichment = 9.17 , 4.157 mins elapsed.
#
# 2025-02-26 14:35:27.267224 : Continuing through after error ggplot for TSS by Frags, 4.171 mins elapsed.
#
#
#
#
# 2025-02-26 14:35:30.283615 : (K562_Xu : 1 of 1) Adding Additional Feature Counts!, 4.222 mins elapsed.
#
# 2025-02-26 14:35:56.743878 : (K562_Xu : 1 of 1) Removing Fragments from Filtered Cells, 4.663 mins elapsed.
#
# 2025-02-26 14:35:56.753065 : (K562_Xu : 1 of 1) Creating Filtered Arrow File, 4.663 mins elapsed.
#
# 2025-02-26 14:37:51.165371 : (K562_Xu : 1 of 1) Finished Constructing Filtered Arrow File!, 6.57 mins elapsed.
#
# 2025-02-26 14:37:51.399408 : (K562_Xu : 1 of 1) Adding TileMatrix!, 6.574 mins elapsed.
#
# 2025-02-26 14:47:00.026733 : (K562_Xu : 1 of 1) Finished Creating Arrow File, 15.717 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-2a42fe7164eacd-Date-2025-02-26_Time-14-31-16.56323.log

# %%
ArrowFiles
# Out:
# [1] "K562_Xu.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR.default_250226/ArchR.250226/ArchR
# samples(1): K562_Xu
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 7699
# medianTSS(1): 9.17
# medianFrags(1): 31472

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-2a42fe179ee1e6-Date-2025-02-26_Time-14-47-13.251495.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 14:47:13.805352 : Computing Total Across All Features, 0 mins elapsed.
#
# 2025-02-26 14:47:14.776077 : Computing Top Features, 0.017 mins elapsed.
#
# ###########
# 2025-02-26 14:47:18.441121 : Running LSI (1 of 2) on Top Features, 0.078 mins elapsed.
# ###########
#
# 2025-02-26 14:47:18.459857 : Creating Partial Matrix, 0.078 mins elapsed.
#
# 2025-02-26 14:47:58.966594 : Computing LSI, 0.753 mins elapsed.
#
# 2025-02-26 14:49:09.498015 : Identifying Clusters, 1.929 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2025-02-26 14:49:17.458746 : Identified 6 Clusters, 2.061 mins elapsed.
#
# 2025-02-26 14:49:17.476054 : Saving LSI Iteration, 2.062 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2025-02-26 14:49:34.885082 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-2a42fe179ee1e6-Date-2025-02-26_Time-14-47-13.251495.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2025-02-26 14:49:34.887272 : Creating Cluster Matrix on the total Group Features, 2.352 mins elapsed.
#
# 2025-02-26 14:49:55.456003 : Computing Variable Features, 2.695 mins elapsed.
#
# ###########
# 2025-02-26 14:49:55.636307 : Running LSI (2 of 2) on Variable Features, 2.698 mins elapsed.
# ###########
#
# 2025-02-26 14:49:55.653011 : Creating Partial Matrix, 2.698 mins elapsed.
#
# 2025-02-26 14:50:33.607482 : Computing LSI, 3.33 mins elapsed.
#
# 2025-02-26 14:51:17.665385 : Finished Running IterativeLSI, 4.065 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-2a42fe367fdd1d-Date-2025-02-26_Time-14-51-20.671696.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 14:51:20.946418 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 14:51:22.124906 : Adding K562_Xu to PeakMatrix for Chr (1 of 23)!, 0.019 mins elapsed.
#
# 2025-02-26 14:51:45.504779 : Adding K562_Xu to PeakMatrix for Chr (2 of 23)!, 0.409 mins elapsed.
#
# 2025-02-26 14:51:59.962287 : Adding K562_Xu to PeakMatrix for Chr (3 of 23)!, 0.65 mins elapsed.
#
# 2025-02-26 14:52:13.080742 : Adding K562_Xu to PeakMatrix for Chr (4 of 23)!, 0.868 mins elapsed.
#
# 2025-02-26 14:52:22.20224 : Adding K562_Xu to PeakMatrix for Chr (5 of 23)!, 1.02 mins elapsed.
#
# 2025-02-26 14:52:32.892949 : Adding K562_Xu to PeakMatrix for Chr (6 of 23)!, 1.198 mins elapsed.
#
# 2025-02-26 14:52:46.066713 : Adding K562_Xu to PeakMatrix for Chr (7 of 23)!, 1.418 mins elapsed.
#
# 2025-02-26 14:52:59.28871 : Adding K562_Xu to PeakMatrix for Chr (8 of 23)!, 1.638 mins elapsed.
#
# 2025-02-26 14:53:09.227687 : Adding K562_Xu to PeakMatrix for Chr (9 of 23)!, 1.804 mins elapsed.
#
# 2025-02-26 14:53:18.622673 : Adding K562_Xu to PeakMatrix for Chr (10 of 23)!, 1.961 mins elapsed.
#
# 2025-02-26 14:53:28.392098 : Adding K562_Xu to PeakMatrix for Chr (11 of 23)!, 2.123 mins elapsed.
#
# 2025-02-26 14:53:40.699184 : Adding K562_Xu to PeakMatrix for Chr (12 of 23)!, 2.328 mins elapsed.
#
# 2025-02-26 14:53:51.231041 : Adding K562_Xu to PeakMatrix for Chr (13 of 23)!, 2.504 mins elapsed.
#
# 2025-02-26 14:53:58.012377 : Adding K562_Xu to PeakMatrix for Chr (14 of 23)!, 2.617 mins elapsed.
#
# 2025-02-26 14:54:05.799448 : Adding K562_Xu to PeakMatrix for Chr (15 of 23)!, 2.747 mins elapsed.
#
# 2025-02-26 14:54:14.594033 : Adding K562_Xu to PeakMatrix for Chr (16 of 23)!, 2.893 mins elapsed.
#
# 2025-02-26 14:54:24.744309 : Adding K562_Xu to PeakMatrix for Chr (17 of 23)!, 3.063 mins elapsed.
#
# 2025-02-26 14:54:35.79237 : Adding K562_Xu to PeakMatrix for Chr (18 of 23)!, 3.247 mins elapsed.
#
# 2025-02-26 14:54:42.850349 : Adding K562_Xu to PeakMatrix for Chr (19 of 23)!, 3.364 mins elapsed.
#
# 2025-02-26 14:54:57.324894 : Adding K562_Xu to PeakMatrix for Chr (20 of 23)!, 3.606 mins elapsed.
#
# 2025-02-26 14:55:04.955812 : Adding K562_Xu to PeakMatrix for Chr (21 of 23)!, 3.733 mins elapsed.
#
# 2025-02-26 14:55:12.033195 : Adding K562_Xu to PeakMatrix for Chr (22 of 23)!, 3.851 mins elapsed.
#
# 2025-02-26 14:55:21.156521 : Adding K562_Xu to PeakMatrix for Chr (23 of 23)!, 4.003 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-2a42fe367fdd1d-Date-2025-02-26_Time-14-51-20.671696.log

# %%
seRNA = import10xFeatureMatrix(c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5"),
                               c("K562_Xu"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61218 7699
# metadata(0):
# assays(1): counts
# rownames(61218): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(7699): K562_Xu#GTCATGCCAGGATGGC-1 K562_Xu#TATCGCGAGGTTAGAG-1
#   ... K562_Xu#CGTGTTACAGTCTATG-1 K562_Xu#AAGTGAAGTTGCCTCA-1
# colData names(0):

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
    library(dplyr)
    library(data.table)
    
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
seRNA.rename = map_gene_names(seRNA,gene_gtf_path, abc_genes_path)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:Biostrings’:
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA.rename,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a42fe1ab7da03-Date-2025-02-26_Time-14-56-20.678465.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2025-02-26 14:56:21.189126 :
#
# Overlap Per Sample w/ scATAC : K562_Xu=7699
#
# 2025-02-26 14:56:21.204276 :
#
# 2025-02-26 14:56:25.181516 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 14:56:26.355954 : Adding K562_Xu to GeneExpressionMatrix for Chr (1 of 23)!, 0.02 mins elapsed.
#
# 2025-02-26 14:56:32.295981 : Adding K562_Xu to GeneExpressionMatrix for Chr (2 of 23)!, 0.119 mins elapsed.
#
# 2025-02-26 14:56:38.094322 : Adding K562_Xu to GeneExpressionMatrix for Chr (3 of 23)!, 0.215 mins elapsed.
#
# 2025-02-26 14:56:45.98266 : Adding K562_Xu to GeneExpressionMatrix for Chr (4 of 23)!, 0.347 mins elapsed.
#
# 2025-02-26 14:56:51.2469 : Adding K562_Xu to GeneExpressionMatrix for Chr (5 of 23)!, 0.434 mins elapsed.
#
# 2025-02-26 14:56:57.002897 : Adding K562_Xu to GeneExpressionMatrix for Chr (6 of 23)!, 0.53 mins elapsed.
#
# 2025-02-26 14:57:04.704926 : Adding K562_Xu to GeneExpressionMatrix for Chr (7 of 23)!, 0.659 mins elapsed.
#
# 2025-02-26 14:57:10.007952 : Adding K562_Xu to GeneExpressionMatrix for Chr (8 of 23)!, 0.747 mins elapsed.
#
# 2025-02-26 14:57:15.437362 : Adding K562_Xu to GeneExpressionMatrix for Chr (9 of 23)!, 0.838 mins elapsed.
#
# 2025-02-26 14:57:23.475986 : Adding K562_Xu to GeneExpressionMatrix for Chr (10 of 23)!, 0.972 mins elapsed.
#
# 2025-02-26 14:57:28.700785 : Adding K562_Xu to GeneExpressionMatrix for Chr (11 of 23)!, 1.059 mins elapsed.
#
# 2025-02-26 14:57:34.231045 : Adding K562_Xu to GeneExpressionMatrix for Chr (12 of 23)!, 1.151 mins elapsed.
#
# 2025-02-26 14:57:42.061548 : Adding K562_Xu to GeneExpressionMatrix for Chr (13 of 23)!, 1.281 mins elapsed.
#
# 2025-02-26 14:57:47.418448 : Adding K562_Xu to GeneExpressionMatrix for Chr (14 of 23)!, 1.371 mins elapsed.
#
# 2025-02-26 14:57:52.70455 : Adding K562_Xu to GeneExpressionMatrix for Chr (15 of 23)!, 1.459 mins elapsed.
#
# 2025-02-26 14:58:00.46584 : Adding K562_Xu to GeneExpressionMatrix for Chr (16 of 23)!, 1.588 mins elapsed.
#
# 2025-02-26 14:58:06.10817 : Adding K562_Xu to GeneExpressionMatrix for Chr (17 of 23)!, 1.682 mins elapsed.
#
# 2025-02-26 14:58:11.711151 : Adding K562_Xu to GeneExpressionMatrix for Chr (18 of 23)!, 1.775 mins elapsed.
#
# 2025-02-26 14:58:19.474494 : Adding K562_Xu to GeneExpressionMatrix for Chr (19 of 23)!, 1.905 mins elapsed.
#
# 2025-02-26 14:58:24.988593 : Adding K562_Xu to GeneExpressionMatrix for Chr (20 of 23)!, 1.997 mins elapsed.
#
# 2025-02-26 14:58:30.428879 : Adding K562_Xu to GeneExpressionMatrix for Chr (21 of 23)!, 2.087 mins elapsed.
#
# 2025-02-26 14:58:38.023578 : Adding K562_Xu to GeneExpressionMatrix for Chr (22 of 23)!, 2.214 mins elapsed.
#
# 2025-02-26 14:58:43.230867 : Adding K562_Xu to GeneExpressionMatrix for Chr (23 of 23)!, 2.301 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a42fe1ab7da03-Date-2025-02-26_Time-14-56-20.678465.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = 250000,
    threads = 16
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-2a42fe4f1f3eff-Date-2025-02-26_Time-14-58-50.970028.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 14:58:51.341342 : Getting Available Matrices, 0.006 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2025-02-26 14:58:51.688836 : Filtered Low Prediction Score Cells (0 of 7699, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2025-02-26 14:58:51.786633 : Computing KNN, 0.002 mins elapsed.
#
# 2025-02-26 14:58:52.130786 : Identifying Non-Overlapping KNN pairs, 0.008 mins elapsed.
#
# 2025-02-26 14:58:53.797663 : Identified 494 Groupings!, 0.036 mins elapsed.
#
# 2025-02-26 14:58:53.847038 : Getting Group RNA Matrix, 0.036 mins elapsed.
#
# 2025-02-26 14:59:15.326424 : Getting Group ATAC Matrix, 0.394 mins elapsed.
#
# 2025-02-26 14:59:48.08897 : Normalizing Group Matrices, 0.94 mins elapsed.
#
# 2025-02-26 14:59:54.352564 : Finding Peak Gene Pairings, 1.045 mins elapsed.
#
# 2025-02-26 14:59:54.81347 : Computing Correlations, 1.053 mins elapsed.
#
# 2025-02-26 15:00:05.611723 : Completed Peak2Gene Correlations!, 1.232 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-2a42fe4f1f3eff-Date-2025-02-26_Time-14-58-50.970028.log

# %%
execution_time
# Out:
# Time difference of 1.244431 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 1113182 rows and 7 columns
#                                 idxATAC    idxRNA Correlation         FDR
#                               <integer> <integer>   <numeric>   <numeric>
# chr1-9926-10618_FAM138A               1         1         NaN         NaN
# chr1-15894-16509_FAM138A              2         1         NaN         NaN
# chr1-17271-17713_FAM138A              3         1         NaN         NaN
# chr1-29230-29495_FAM138A              4         1         NaN         NaN
# chr1-115493-115961_FAM138A            5         1         NaN         NaN
# ...                                 ...       ...         ...         ...
# chrX-156009722-156010137_IL9R    157596     20493   0.0787222 0.139159667
# chrX-156016191-156016823_IL9R    157597     20493   0.0747140 0.162911793
# chrX-156019811-156020191_IL9R    157598     20493   0.0323247 0.581744450
# chrX-156025028-156025591_IL9R    157599     20493  -0.1003445 0.052806442
# chrX-156030021-156030865_IL9R    157600     20493   0.1683037 0.000617572
#                                VarQATAC   VarQRNA               PairName
#                               <numeric> <numeric>            <character>
# chr1-9926-10618_FAM138A        0.780032 0.0597765 chr1-9926-10618_FAM1..
# chr1-15894-16509_FAM138A       0.274651 0.0597765 chr1-15894-16509_FAM..
# chr1-17271-17713_FAM138A       0.338503 0.0597765 chr1-17271-17713_FAM..
# chr1-29230-29495_FAM138A       0.222716 0.0597765 chr1-29230-29495_FAM..
# chr1-115493-115961_FAM138A     0.843997 0.0597765 chr1-115493-115961_F..
# ...                                 ...       ...                    ...
# chrX-156009722-156010137_IL9R 0.0590863  0.349485 chrX-156009722-15601..
# chrX-156016191-156016823_IL9R 0.5508439  0.349485 chrX-156016191-15601..
# chrX-156019811-156020191_IL9R 0.1883376  0.349485 chrX-156019811-15602..
# chrX-156025028-156025591_IL9R 0.4855330  0.349485 chrX-156025028-15602..
# chrX-156030021-156030865_IL9R 0.8127475  0.349485 chrX-156030021-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 933499 ranges and 7 metadata columns:
#            seqnames            ranges strand |  TargetGene
#               <Rle>         <IRanges>  <Rle> | <character>
#        [1]     chr1 10001196-10001745      * |      CLSTN1
#        [2]     chr1 10001196-10001745      * |    CTNNBIP1
#        [3]     chr1 10001196-10001745      * |       KIF1B
#        [4]     chr1 10001196-10001745      * |        LZIC
#        [5]     chr1 10001196-10001745      * |      NMNAT1
#        ...      ...               ...    ... .         ...
#   [933495]     chrX   9882635-9883318      * |        WWC3
#   [933496]     chrX   9885160-9885475      * |        WWC3
#   [933497]     chrX   9894484-9895274      * |        WWC3
#   [933498]     chrX   9995827-9996208      * |       CLCN4
#   [933499]     chrX   9995827-9996208      * |        WWC3
#                          PeakName               PairName Correlation        FDR
#                       <character>            <character>   <numeric>  <numeric>
#        [1] chr1-10001196-10001745 chr1-10001196-100017.. -0.00856967 0.89392649
#        [2] chr1-10001196-10001745 chr1-10001196-100017..  0.10927651 0.03331330
#        [3] chr1-10001196-10001745 chr1-10001196-100017.. -0.08571135 0.10397671
#        [4] chr1-10001196-10001745 chr1-10001196-100017.. -0.15389096 0.00191243
#        [5] chr1-10001196-10001745 chr1-10001196-100017..  0.00880569 0.89091627
#        ...                    ...                    ...         ...        ...
#   [933495]   chrX-9882635-9883318 chrX-9882635-9883318..  0.01862477   0.762186
#   [933496]   chrX-9885160-9885475 chrX-9885160-9885475..  0.00286508   0.965457
#   [933497]   chrX-9894484-9895274 chrX-9894484-9895274..  0.00195320   0.976592
#   [933498]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02470933   0.681096
#   [933499]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03551510   0.541243
#             VarQATAC   VarQRNA
#            <numeric> <numeric>
#        [1]  0.121796  0.664959
#        [2]  0.121796  0.695311
#        [3]  0.121796  0.859171
#        [4]  0.121796  0.706876
#        [5]  0.121796  0.713512
#        ...       ...       ...
#   [933495]  0.471237  0.461231
#   [933496]  0.101599  0.461231
#   [933497]  0.317132  0.461231
#   [933498]  0.339911  0.425365
#   [933499]  0.339911  0.461231
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 933499 ranges and 7 metadata columns:
#            seqnames            ranges strand |  TargetGene
#               <Rle>         <IRanges>  <Rle> | <character>
#        [1]     chr1 10001196-10001745      * |      CLSTN1
#        [2]     chr1 10001196-10001745      * |    CTNNBIP1
#        [3]     chr1 10001196-10001745      * |       KIF1B
#        [4]     chr1 10001196-10001745      * |        LZIC
#        [5]     chr1 10001196-10001745      * |      NMNAT1
#        ...      ...               ...    ... .         ...
#   [933495]     chrX   9882635-9883318      * |        WWC3
#   [933496]     chrX   9885160-9885475      * |        WWC3
#   [933497]     chrX   9894484-9895274      * |        WWC3
#   [933498]     chrX   9995827-9996208      * |       CLCN4
#   [933499]     chrX   9995827-9996208      * |        WWC3
#                          PeakName               PairName Correlation        FDR
#                       <character>            <character>   <numeric>  <numeric>
#        [1] chr1-10001196-10001745 chr1-10001196-100017.. -0.00856967 0.89392649
#        [2] chr1-10001196-10001745 chr1-10001196-100017..  0.10927651 0.03331330
#        [3] chr1-10001196-10001745 chr1-10001196-100017.. -0.08571135 0.10397671
#        [4] chr1-10001196-10001745 chr1-10001196-100017.. -0.15389096 0.00191243
#        [5] chr1-10001196-10001745 chr1-10001196-100017..  0.00880569 0.89091627
#        ...                    ...                    ...         ...        ...
#   [933495]   chrX-9882635-9883318 chrX-9882635-9883318..  0.01862477   0.762186
#   [933496]   chrX-9885160-9885475 chrX-9885160-9885475..  0.00286508   0.965457
#   [933497]   chrX-9894484-9895274 chrX-9894484-9895274..  0.00195320   0.976592
#   [933498]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02470933   0.681096
#   [933499]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03551510   0.541243
#             VarQATAC   VarQRNA
#            <numeric> <numeric>
#        [1]  0.121796  0.664959
#        [2]  0.121796  0.695311
#        [3]  0.121796  0.859171
#        [4]  0.121796  0.706876
#        [5]  0.121796  0.713512
#        ...       ...       ...
#   [933495]  0.471237  0.461231
#   [933496]  0.101599  0.461231
#   [933497]  0.317132  0.461231
#   [933498]  0.339911  0.425365
#   [933499]  0.339911  0.461231
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#        chr  start     end       TargetGene CellType Correlation  FDR
# 1      chr1  10001196  10001745 CLSTN1     K562     -0.008569671 8.939265e-01
# 2      chr1  10001196  10001745 CTNNBIP1   K562      0.109276509 3.331330e-02
# 3      chr1  10001196  10001745 KIF1B      K562     -0.085711347 1.039767e-01
# 4      chr1  10001196  10001745 LZIC       K562     -0.153890963 1.912432e-03
# 5      chr1  10001196  10001745 NMNAT1     K562      0.008805695 8.909163e-01
# 6      chr1  10001196  10001745 RBP7       K562      0.055430425 3.168859e-01
# 7      chr1  10001196  10001745 UBE4B      K562      0.139513416 5.324126e-03
# 8      chr1 100027917 100029695 AGL        K562     -0.060843072 2.669373e-01
# 9      chr1 100027917 100029695 DBT        K562      0.113399517 2.660451e-02
# 10     chr1 100027917 100029695 MFSD14A    K562     -0.033765151 5.633475e-01
# 11     chr1 100027917 100029695 RTCA       K562     -0.296069972 2.140068e-10
# 12     chr1 100027917 100029695 RTCA-AS1   K562     -0.078206426 1.420580e-01
# 13     chr1 100027917 100029695 SASS6      K562     -0.005903034 9.277100e-01
# 14     chr1 100027917 100029695 SLC35A3    K562     -0.031298666 5.947948e-01
# 15     chr1 100027917 100029695 TRMT13     K562      0.051259410 3.588414e-01
# 16     chr1  10003541  10003870 CLSTN1     K562     -0.059352630 2.801764e-01
# 17     chr1  10003541  10003870 CTNNBIP1   K562     -0.082603548 1.186765e-01
# 18     chr1  10003541  10003870 KIF1B      K562     -0.057018137 3.017411e-01
# 19     chr1  10003541  10003870 LZIC       K562     -0.011783743 8.524567e-01
# 20     chr1  10003541  10003870 NMNAT1     K562     -0.039432846 4.929231e-01
# 21     chr1  10003541  10003870 RBP7       K562     -0.052121018 3.499480e-01
# 22     chr1  10003541  10003870 UBE4B      K562      0.056684970 3.048841e-01
# 23     chr1 100036824 100037384 AGL        K562     -0.174757022 3.599259e-04
# 24     chr1 100036824 100037384 DBT        K562     -0.084248849 1.106875e-01
# 25     chr1 100036824 100037384 MFSD14A    K562     -0.108289741 3.512104e-02
# 26     chr1 100036824 100037384 RTCA       K562      0.062065170 2.563674e-01
# 27     chr1 100036824 100037384 RTCA-AS1   K562     -0.159306953 1.265751e-03
# 28     chr1 100036824 100037384 SASS6      K562      0.277445564 3.357707e-09
# 29     chr1 100036824 100037384 SLC35A3    K562      0.001882806 9.774065e-01
# 30     chr1 100036824 100037384 TRMT13     K562      0.331370468 6.330091e-13
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 933470 chrX 9515603   9516754   TBL1X      K562      0.513764666 1.218433e-32
# 933471 chrX 9519003   9519166   TBL1X      K562      0.192456958 7.353360e-05
# 933472 chrX 9523396   9523614   TBL1X      K562      0.139923602 5.178057e-03
# 933473 chrX 9526743   9527004   TBL1X      K562      0.154020902 1.893822e-03
# 933474 chrX 9527097   9527256   TBL1X      K562      0.222023623 3.578773e-06
# 933475 chrX 9527473   9527741   TBL1X      K562      0.160792514 1.127579e-03
# 933476 chrX 9530658   9531443   TBL1X      K562      0.133005904 8.196805e-03
# 933477 chrX 9533720   9534013   TBL1X      K562      0.059816442 2.759620e-01
# 933478 chrX 9538535   9539381   TBL1X      K562      0.266441620 1.543532e-08
# 933479 chrX 9540026   9540401   TBL1X      K562      0.112173135 2.847067e-02
# 933480 chrX 9542740   9543112   TBL1X      K562      0.047767576 3.962190e-01
# 933481 chrX 9550938   9551425   TBL1X      K562      0.195457064 5.530382e-05
# 933482 chrX 9554809   9554981   TBL1X      K562     -0.015526458 8.033311e-01
# 933483 chrX 9555057   9556694   TBL1X      K562      0.123634939 1.471748e-02
# 933484 chrX 9569158   9569613   TBL1X      K562      0.089513403 8.796009e-02
# 933485 chrX 9586788   9586944   TBL1X      K562     -0.246656984 2.008704e-07
# 933486 chrX 9587015   9587399   TBL1X      K562      0.102109587 4.836585e-02
# 933487 chrX 9642694   9643219   TBL1X      K562     -0.062598490 2.518334e-01
# 933488 chrX 9646431   9647138   TBL1X      K562     -0.013798935 8.260575e-01
# 933489 chrX 9670192   9670610   TBL1X      K562      0.142847783 4.237276e-03
# 933490 chrX 9707468   9708164   TBL1X      K562      0.055507472 3.161291e-01
# 933491 chrX 9708493   9709582   TBL1X      K562      0.046906423 4.058372e-01
# 933492 chrX 9786114   9786869   WWC3       K562      0.145894223 3.421467e-03
# 933493 chrX 9864063   9864567   WWC3       K562      0.187272821 1.190708e-04
# 933494 chrX 9873821   9874426   WWC3       K562      0.075693801 1.568375e-01
# 933495 chrX 9882635   9883318   WWC3       K562      0.018624767 7.621862e-01
# 933496 chrX 9885160   9885475   WWC3       K562      0.002865084 9.654569e-01
# 933497 chrX 9894484   9895274   WWC3       K562      0.001953204 9.765916e-01
# 933498 chrX 9995827   9996208   CLCN4      K562     -0.024709327 6.810957e-01
# 933499 chrX 9995827   9996208   WWC3       K562     -0.035515096 5.412425e-01
#        VarQATAC    VarQRNA
# 1      0.12179569  0.6649588
# 2      0.12179569  0.6953106
# 3      0.12179569  0.8591714
# 4      0.12179569  0.7068755
# 5      0.12179569  0.7135119
# 6      0.12179569  0.2445713
# 7      0.12179569  0.8348216
# 8      0.66776015  0.7150734
# 9      0.66776015  0.6860391
# 10     0.66776015  0.4949983
# 11     0.66776015  0.7483531
# 12     0.66776015  0.6117211
# 13     0.66776015  0.9037232
# 14     0.66776015  0.6436344
# 15     0.66776015  0.7907090
# 16     0.03770939  0.6649588
# 17     0.03770939  0.6953106
# 18     0.03770939  0.8591714
# 19     0.03770939  0.7068755
# 20     0.03770939  0.7135119
# 21     0.03770939  0.2445713
# 22     0.03770939  0.8348216
# 23     0.73982234  0.7150734
# 24     0.73982234  0.6860391
# 25     0.73982234  0.4949983
# 26     0.73982234  0.7483531
# 27     0.73982234  0.6117211
# 28     0.73982234  0.9037232
# 29     0.73982234  0.6436344
# 30     0.73982234  0.7907090
# ⋮      ⋮           ⋮
# 933470 0.993857868 0.9171424
# 933471 0.076395939 0.9171424
# 933472 0.019790609 0.9171424
# 933473 0.036770305 0.9171424
# 933474 0.022461929 0.9171424
# 933475 0.063705584 0.9171424
# 933476 0.763521574 0.9171424
# 933477 0.035831218 0.9171424
# 933478 0.433432741 0.9171424
# 933479 0.036357868 0.9171424
# 933480 0.029961929 0.9171424
# 933481 0.037906091 0.9171424
# 933482 0.007722081 0.9171424
# 933483 0.584714467 0.9171424
# 933484 0.032595178 0.9171424
# 933485 0.003826142 0.9171424
# 933486 0.037290609 0.9171424
# 933487 0.048115482 0.9171424
# 933488 0.536230964 0.9171424
# 933489 0.089638325 0.9171424
# 933490 0.149505076 0.9171424
# 933491 0.659003807 0.9171424
# 933492 0.377214467 0.4612307
# 933493 0.270717005 0.4612307
# 933494 0.274917513 0.4612307
# 933495 0.471237310 0.4612307
# 933496 0.101598985 0.4612307
# 933497 0.317131980 0.4612307
# 933498 0.339911168 0.4253648
# 933499 0.339911168 0.4612307

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       dplyr_1.1.4
#  [3] uwot_0.1.16                       Rsamtools_2.18.0
#  [5] BSgenome.Hsapiens.UCSC.hg38_1.4.5 BSgenome_1.68.0
#  [7] rtracklayer_1.60.1                Biostrings_2.70.1
#  [9] XVector_0.42.0                    genomation_1.34.0
# [11] Signac_1.13.0                     Seurat_5.0.3
# [13] SeuratObject_5.0.1                sp_2.1-4
# [15] rhdf5_2.44.0                      SummarizedExperiment_1.30.2
# [17] Biobase_2.60.0                    MatrixGenerics_1.12.3
# [19] Rcpp_1.0.12                       Matrix_1.6-5
# [21] GenomicRanges_1.54.1              GenomeInfoDb_1.38.1
# [23] IRanges_2.36.0                    S4Vectors_0.40.2
# [25] BiocGenerics_0.48.1               matrixStats_1.3.0
# [27] data.table_1.15.2                 stringr_1.5.1
# [29] plyr_1.8.9                        magrittr_2.0.3
# [31] ggplot2_3.5.1                     gtable_0.3.5
# [33] gtools_3.9.5                      gridExtra_2.3
# [35] ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            withr_3.0.0              fastmap_1.1.1
#  [61] rhdf5filters_1.12.1      fansi_1.0.6              digest_0.6.35
#  [64] R6_2.5.1                 mime_0.12                seqPattern_1.34.0
#  [67] colorspace_2.1-0         Cairo_1.6-2              scattermore_1.2
#  [70] tensor_1.5               spatstat.data_3.0-4      utf8_1.2.4
#  [73] tidyr_1.3.1              generics_0.1.3           httr_1.4.7
#  [76] htmlwidgets_1.6.4        S4Arrays_1.2.1           pkgconfig_2.0.3
#  [79] impute_1.76.0            lmtest_0.9-40            htmltools_0.5.8.1
#  [82] dotCall64_1.1-1          scales_1.3.0             png_0.1-8
#  [85] tzdb_0.4.0               reshape2_1.4.4           rjson_0.2.21
#  [88] uuid_1.2-0               nlme_3.1-164             repr_1.1.7
#  [91] zoo_1.8-12               KernSmooth_2.23-22       miniUI_0.1.1.1
#  [94] restfulr_0.0.15          pillar_1.9.0             vctrs_0.6.5
#  [97] RANN_2.6.1               promises_1.3.0           xtable_1.8-4
# [100] cluster_2.1.6            evaluate_0.23            readr_2.1.5
# [103] cli_3.6.2                compiler_4.3.3           rlang_1.1.3
# [106] crayon_1.5.2             future.apply_1.11.2      labeling_0.4.3
# [109] stringi_1.8.3            gridBase_0.4-7           viridisLite_0.4.2
# [112] deldir_2.0-4             BiocParallel_1.36.0      munsell_0.5.1
# [115] lazyeval_0.2.2           spatstat.geom_3.2-9      IRkernel_1.3.2
# [118] RcppHNSW_0.6.0           hms_1.1.3                patchwork_1.2.0
# [121] bit64_4.0.5              future_1.33.2            Rhdf5lib_1.22.1
# [124] shiny_1.8.1.1            ROCR_1.0-11              igraph_2.0.3
# [127] fastmatch_1.1-4          bit_4.0.5
