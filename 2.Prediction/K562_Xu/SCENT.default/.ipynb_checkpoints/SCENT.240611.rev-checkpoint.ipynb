# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT.default/SCENT.240611/"

# %%
n.cores = 32

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 500kb

# %%
pairs.ABC.500kb = pairs.ABC[pairs.ABC$distance < 500000]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.500kb

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.500kb.chr_rename = as.data.frame(pairs.ABC.500kb)[,1:3]
df.pairs.ABC.500kb.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.500kb),
                                                mcols(pairs.ABC.500kb)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.500kb.chr_rename = GRanges(df.pairs.ABC.500kb.chr_rename)
rm(df.pairs.ABC.500kb.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.500kb.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.500kb.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 1734842 ranges and 3 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * | APITD1-CORT
#         [2]     chr1 10001196-10001745      * |       CENPS
#         [3]     chr1 10001196-10001745      * |      CLSTN1
#         [4]     chr1 10001196-10001745      * |        CORT
#         [5]     chr1 10001196-10001745      * |    CTNNBIP1
#         ...      ...               ...    ... .         ...
#   [1734838]     chrX     989754-991253      * |       IL3RA
#   [1734839]     chrX     989754-991253      * |   LINC00106
#   [1734840]     chrX     989754-991253      * |     SLC25A6
#   [1734841]     chrX   9995827-9996208      * |       CLCN4
#   [1734842]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..
#         [2] chr1-10001196-10001745 chr1-10001196-100017..
#         [3] chr1-10001196-10001745 chr1-10001196-100017..
#         [4] chr1-10001196-10001745 chr1-10001196-100017..
#         [5] chr1-10001196-10001745 chr1-10001196-100017..
#         ...                    ...                    ...
#   [1734838]     chrX-989754-991253 chrX-989754-991253_I..
#   [1734839]     chrX-989754-991253 chrX-989754-991253_L..
#   [1734840]     chrX-989754-991253 chrX-989754-991253_S..
#   [1734841]   chrX-9995827-9996208 chrX-9995827-9996208..
#   [1734842]   chrX-9995827-9996208 chrX-9995827-9996208..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI  nMito celltype
# K562_Xu_AAACAGCCAAGCGATG-1 K562_Xu_AAACAGCCAAGCGATG-1 11087 1001  K562
# K562_Xu_AAACAGCCACATGCTA-1 K562_Xu_AAACAGCCACATGCTA-1 17288 2295  K562
# K562_Xu_AAACAGCCACGGTACT-1 K562_Xu_AAACAGCCACGGTACT-1 18989 1411  K562
# K562_Xu_AAACAGCCATAAAGCA-1 K562_Xu_AAACAGCCATAAAGCA-1 10270 1109  K562
# K562_Xu_AAACATGCAACTCGCG-1 K562_Xu_AAACATGCAACTCGCG-1 10962 1785  K562
# K562_Xu_AAACATGCAATCCTAG-1 K562_Xu_AAACATGCAATCCTAG-1 22686 2486  K562
# K562_Xu_AAACATGCACATAACT-1 K562_Xu_AAACATGCACATAACT-1 10649  512  K562
# K562_Xu_AAACATGCACCTATAG-1 K562_Xu_AAACATGCACCTATAG-1 15716 2278  K562
# K562_Xu_AAACATGCAGGGAGCT-1 K562_Xu_AAACATGCAGGGAGCT-1 12360 1570  K562
# K562_Xu_AAACATGCAGTTTACG-1 K562_Xu_AAACATGCAGTTTACG-1 24704 3638  K562
# K562_Xu_AAACATGCATGCTATG-1 K562_Xu_AAACATGCATGCTATG-1 11736 2048  K562
# K562_Xu_TTTGTGTTCAGGTTTA-1  9.979383 0.08759327
# K562_Xu_TTTGTGTTCGATAACC-1 10.066796 0.16515203
# K562_Xu_TTTGTGTTCGCTAGAT-1 10.256747 0.13816113
# K562_Xu_TTTGTTGGTATTTGCC-1 10.008433 0.15058749
# K562_Xu_TTTGTTGGTCAATGTG-1  9.875037 0.16250836
# K562_Xu_TTTGTTGGTGTGAGAG-1  9.684834 0.10496516
# K562_Xu_TTTGTTGGTTGCCTCA-1  9.141526 0.10626674
# K562_Xu_TTTGTTGGTTTAACGG-1  9.724540 0.10769599
# K562_Xu_TTTGTTGGTTTATGGG-1 10.017129 0.14330343
# K562_Xu_TTTGTTGGTTTGTGGA-1  9.684461 0.13239139

# %% [markdown]
# RUN SCENT prediction

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  
  SCENT_obj.chr <- CreateSCENTObj(rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.chr$TargetGene,], 
                                  atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.chr$PeakName,], 
                                  meta.data = meta.data,
                                  peak.info = gene_peak.chr,
                                  covariates = c("log.nUMI","percent.mito"), 
                                  celltypes = "celltype")
  SCENT_obj.chr <- SCENT_algorithm(object = SCENT_obj.chr, 
                                   celltype = "K562", 
                                   ncores = n.cores, 
                                   regr = 'poisson', bin = TRUE)
  
  saveRDS(SCENT_obj.chr@SCENT.result,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (SCENT_obj.chr)
}

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 833632 ranges and 11 metadata columns:
#        seqnames              ranges strand |  TargetGene               PeakName
#           <Rle>           <IRanges>  <Rle> | <character>            <character>
#   chr1     chr1 100027917-100029695      * |         AGL chr1-100027917-10002..
#   chr1     chr1 100027917-100029695      * |      CDC14A chr1-100027917-10002..
#   chr1     chr1 100027917-100029695      * |         DBT chr1-100027917-10002..
#   chr1     chr1 100027917-100029695      * |        DPH5 chr1-100027917-10002..
#   chr1     chr1 100027917-100029695      * |       EXTL2 chr1-100027917-10002..
#    ...      ...                 ...    ... .         ...                    ...
#   chrX     chrX       989754-991253      * |      GTPBP6     chrX-989754-991253
#   chrX     chrX       989754-991253      * |   LINC00106     chrX-989754-991253
#   chrX     chrX       989754-991253      * |      PLCXD1     chrX-989754-991253
#   chrX     chrX       989754-991253      * |     PPP2R3B     chrX-989754-991253
#   chrX     chrX       989754-991253      * |     SLC25A6     chrX-989754-991253
#                      PairName         beta        se          z          p
#                   <character>    <numeric> <numeric>  <numeric>  <numeric>
#   chr1 chr1-100027917-10002..  0.105756375 0.0394130  2.6832835 0.00729032
#   chr1 chr1-100027917-10002..  0.031341771 0.0208237  1.5051016 0.13229795
#   chr1 chr1-100027917-10002..  0.118411510 0.0453162  2.6130071 0.00897494
#   chr1 chr1-100027917-10002..  0.079062069 0.0396960  1.9916886 0.04640524
#   chr1 chr1-100027917-10002.. -0.000454658 0.0575888 -0.0078949 0.99370085
#    ...                    ...          ...       ...        ...        ...
#   chrX chrX-989754-991253_G..   0.04466724 0.0454466  0.9828513  0.3256806
#   chrX chrX-989754-991253_L..   0.00572961 0.0807256  0.0709763  0.9434166
#   chrX chrX-989754-991253_P..   0.02160608 0.0304332  0.7099518  0.4777340
#   chrX chrX-989754-991253_P..   0.16933229 0.0661620  2.5593588  0.0104865
#   chrX chrX-989754-991253_S..  -0.01345272 0.0148386 -0.9066006  0.3646181
#        boot_basic_p boot_basic_p.log10      sign boot_basic_p.log10.signed
#           <numeric>          <numeric> <numeric>                 <numeric>
#   chr1         0.02          1.6989700         1                 1.6989700
#   chr1         0.40          0.3979400         1                 0.3979400
#   chr1         0.02          1.6989700         1                 1.6989700
#   chr1         0.02          1.6989700         1                 1.6989700
#   chr1         0.94          0.0268721        -1                -0.0268721
#    ...          ...                ...       ...                       ...
#   chrX         0.46          0.3372422         1                 0.3372422
#   chrX         0.86          0.0655015         1                 0.0655015
#   chrX         0.68          0.1674911         1                 0.1674911
#   chrX         0.02          1.6989700         1                 1.6989700
#   chrX         0.30          0.5228787        -1                -0.5228787
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta          se
# 1      chr1 100027917 100029695 AGL        K562      0.1057563753 0.03941305
# 2      chr1 100027917 100029695 CDC14A     K562      0.0313417711 0.02082369
# 3      chr1 100027917 100029695 DBT        K562      0.1184115095 0.04531618
# 4      chr1 100027917 100029695 DPH5       K562      0.0790620694 0.03969600
# 5      chr1 100027917 100029695 EXTL2      K562     -0.0004546578 0.05758882
# 6      chr1 100027917 100029695 FRRS1      K562     -0.0170938551 0.03614821
# 7      chr1 100027917 100029695 MFSD14A    K562      0.0195409422 0.12591022
# 8      chr1 100027917 100029695 PALMD      K562      0.0362131134 0.17555601
# 9      chr1 100027917 100029695 RTCA       K562      0.0275463706 0.03797991
# 10     chr1 100027917 100029695 RTCA-AS1   K562      0.1734366547 0.11266730
# 11     chr1 100027917 100029695 SASS6      K562      0.0181173365 0.03617309
# 12     chr1 100027917 100029695 SLC30A7    K562      0.0253870564 0.03263396
# 13     chr1 100027917 100029695 SLC35A3    K562      0.0391826210 0.04876596
# 14     chr1 100027917 100029695 TRMT13     K562      0.0665267846 0.03934518
# 833616  1.70547078  8.810666e-02 0.04         1.39794001          1
# 833617  2.07726056  3.777752e-02 0.12         0.92081875          1
# 833618  3.45284586  5.547059e-04 0.02         1.69897000          1
# 833619  5.03993643  4.656865e-07 0.02         1.69897000          1
# 833620  1.22605570  2.201777e-01 0.26         0.58502665          1
# 833621  0.26130471  7.938575e-01 0.88         0.05551733          1
# 833622  1.75766230  7.880499e-02 0.22         0.65757732          1
# 833623  5.68524054  1.306287e-08 0.02         1.69897000          1
# 833624  1.06208625  2.881965e-01 0.38         0.42021640          1
# 833625  0.34830962  7.276077e-01 0.78         0.10790540          1
# 833626 -0.90242922  3.668289e-01 0.44         0.35654732         -1
# 833627  3.00268253  2.676114e-03 0.02         1.69897000          1
# 833628  0.98285130  3.256806e-01 0.46         0.33724217          1
# 833629  0.07097635  9.434166e-01 0.86         0.06550155          1
# 833630  0.70995178  4.777340e-01 0.68         0.16749109          1
# 833631  2.55935878  1.048655e-02 0.02         1.69897000          1
# 833632 -0.90660056  3.646181e-01 0.30         0.52287875         -1
#        boot_basic_p.log10.signed
# 1       1.698970004
# 2       0.397940009
# 3       1.698970004
# 4       1.698970004
# 5      -0.026872146
# 6      -0.130768280
# 7       0.008773924
# 8       0.130768280
# 9       0.337242168
# 10      0.420216403
# 11      0.154901960
# 12      0.356547324
# 13      0.376750710
# 14      1.096910013
# 15      0.251811973
# 16      0.119186408
# 17     -0.008773924
# 18      0.026872146
# 19      0.468521083
# 20     -0.008773924
# 21      0.055517328
# 22      0.036212173
# 23      0.744727495
# 24      0.207608311
# 25      0.552841969
# 26      0.853871964
# 27      1.698970004
# 28     -0.657577319
# 29      0.180456064
# 30      1.698970004
# ⋮      ⋮
# 833603  1.69897000
# 833604  1.69897000
# 833605  0.46852108
# 833606  0.74472749
# 833607  1.69897000
# 833608  1.69897000
# 833609  1.69897000
# 833610 -0.23657201
# 833611 -0.20760831
# 833612 -0.55284197
# 833613  1.69897000
# 833614  0.52287875
# 833615  0.33724217
# 833616  1.39794001
# 833617  0.92081875
# 833618  1.69897000
# 833619  1.69897000
# 833620  0.58502665
# 833621  0.05551733
# 833622  0.65757732
# 833623  1.69897000
# 833624  0.42021640
# 833625  0.10790540
# 833626 -0.35654732
# 833627  1.69897000
# 833628  0.33724217
# 833629  0.06550155
# 833630  0.16749109
# 833631  1.69897000
# 833632 -0.52287875

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
# [1] Matrix_1.6-5         GenomicRanges_1.54.1 GenomeInfoDb_1.38.1
# [4] IRanges_2.36.0       S4Vectors_0.40.2     BiocGenerics_0.48.1
# [7] genomation_1.34.0    Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] bit64_4.0.5                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] data.table_1.15.2           hms_1.1.3
#  [71] sp_2.1-4                    utf8_1.2.4
#  [73] XVector_0.42.0              pillar_1.9.0
#  [75] stringr_1.5.1               vroom_1.6.5
#  [77] spam_2.10-0                 IRdisplay_1.1
#  [79] splines_4.3.3               dplyr_1.1.4
#  [81] lattice_0.22-6              bit_4.0.5
#  [83] rtracklayer_1.60.1          tidyselect_1.2.1
#  [85] Biostrings_2.70.1           pbapply_1.7-2
#  [87] knitr_1.46                  gridExtra_2.3
#  [89] SummarizedExperiment_1.30.2 xfun_0.43
#  [91] Biobase_2.60.0              matrixStats_1.3.0
#  [93] stringi_1.8.3               yaml_2.3.8
#  [95] boot_1.3-30                 evaluate_0.23
#  [97] codetools_0.2-20            tibble_3.2.1
#  [99] cli_3.6.2                   IRkernel_1.3.2
# [101] rpart_4.1.23                repr_1.1.7
# [103] munsell_0.5.1               Rcpp_1.0.12
# [105] globals_0.16.3              XML_3.99-0.16.1
# [107] ggplot2_3.5.1               readr_2.1.5
# [109] dotCall64_1.1-1             bitops_1.0-7
# [111] lme4_1.1-35.3               listenv_0.9.1
# [113] scales_1.3.0                SeuratObject_5.0.1
# [115] purrr_1.0.2                 crayon_1.5.2
# [117] rlang_1.1.3                 fastmatch_1.1-4
