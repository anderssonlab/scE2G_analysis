# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT.default/SCENT.240611/"

# %%
n.cores = 48

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 500kb

# %%
pairs.ABC.500kb = pairs.ABC[pairs.ABC$distance < 500000]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.500kb

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.500kb.chr_rename = as.data.frame(pairs.ABC.500kb)[,1:3]
df.pairs.ABC.500kb.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.500kb),
                                                mcols(pairs.ABC.500kb)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.500kb.chr_rename = GRanges(df.pairs.ABC.500kb.chr_rename)
rm(df.pairs.ABC.500kb.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.500kb.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.500kb.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 1734842 ranges and 3 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * | APITD1-CORT
#         [2]     chr1 10001196-10001745      * |       CENPS
#         [3]     chr1 10001196-10001745      * |      CLSTN1
#         [4]     chr1 10001196-10001745      * |        CORT
#         [5]     chr1 10001196-10001745      * |    CTNNBIP1
#         ...      ...               ...    ... .         ...
#   [1734838]     chrX     989754-991253      * |       IL3RA
#   [1734839]     chrX     989754-991253      * |   LINC00106
#   [1734840]     chrX     989754-991253      * |     SLC25A6
#   [1734841]     chrX   9995827-9996208      * |       CLCN4
#   [1734842]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..
#         [2] chr1-10001196-10001745 chr1-10001196-100017..
#         [3] chr1-10001196-10001745 chr1-10001196-100017..
#         [4] chr1-10001196-10001745 chr1-10001196-100017..
#         [5] chr1-10001196-10001745 chr1-10001196-100017..
#         ...                    ...                    ...
#   [1734838]     chrX-989754-991253 chrX-989754-991253_I..
#   [1734839]     chrX-989754-991253 chrX-989754-991253_L..
#   [1734840]     chrX-989754-991253 chrX-989754-991253_S..
#   [1734841]   chrX-9995827-9996208 chrX-9995827-9996208..
#   [1734842]   chrX-9995827-9996208 chrX-9995827-9996208..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI  nMito celltype
# K562_Xu_AAACAGCCAAGCGATG-1 K562_Xu_AAACAGCCAAGCGATG-1 11087 1001  K562
# K562_Xu_AAACAGCCACATGCTA-1 K562_Xu_AAACAGCCACATGCTA-1 17288 2295  K562
# K562_Xu_AAACAGCCACGGTACT-1 K562_Xu_AAACAGCCACGGTACT-1 18989 1411  K562
# K562_Xu_AAACAGCCATAAAGCA-1 K562_Xu_AAACAGCCATAAAGCA-1 10270 1109  K562
# K562_Xu_AAACATGCAACTCGCG-1 K562_Xu_AAACATGCAACTCGCG-1 10962 1785  K562
# K562_Xu_AAACATGCAATCCTAG-1 K562_Xu_AAACATGCAATCCTAG-1 22686 2486  K562
# K562_Xu_AAACATGCACATAACT-1 K562_Xu_AAACATGCACATAACT-1 10649  512  K562
# K562_Xu_AAACATGCACCTATAG-1 K562_Xu_AAACATGCACCTATAG-1 15716 2278  K562
# K562_Xu_AAACATGCAGGGAGCT-1 K562_Xu_AAACATGCAGGGAGCT-1 12360 1570  K562
# K562_Xu_AAACATGCAGTTTACG-1 K562_Xu_AAACATGCAGTTTACG-1 24704 3638  K562
# K562_Xu_AAACATGCATGCTATG-1 K562_Xu_AAACATGCATGCTATG-1 11736 2048  K562
# K562_Xu_AAACCAACAGGCCATT-1 K562_Xu_AAACCAACAGGCCATT-1 17161 1833  K562
# K562_Xu_AAACCAACAGGTTTGC-1 K562_Xu_AAACCAACAGGTTTGC-1 18127 1924  K562
# K562_Xu_AAACCAACATCAGCAC-1 K562_Xu_AAACCAACATCAGCAC-1 16621 2130  K562
# K562_Xu_AAACCAACATTGCGAC-1 K562_Xu_AAACCAACATTGCGAC-1 16198 1570  K562
# K562_Xu_AAACCGAAGGAAGTAT-1 K562_Xu_AAACCGAAGGAAGTAT-1 13659 1971  K562
# K562_Xu_AAACCGAAGGCAATAG-1 K562_Xu_AAACCGAAGGCAATAG-1 21563 1479  K562
# K562_Xu_AAACCGCGTCACACCC-1 K562_Xu_AAACCGCGTCACACCC-1 21853 2668  K562
# K562_Xu_AAACCGCGTCATGCCC-1 K562_Xu_AAACCGCGTCATGCCC-1  8998 1400  K562
# K562_Xu_AAACCGGCAAGACTCC-1 K562_Xu_AAACCGGCAAGACTCC-1 13284 1469  K562
# K562_Xu_AAACCGGCAGCAACAG-1 K562_Xu_AAACCGGCAGCAACAG-1 13770 2053  K562
# K562_Xu_AAACCGGCAGGCGATA-1 K562_Xu_AAACCGGCAGGCGATA-1 15215 1345  K562
# K562_Xu_AAACCGGCAGGCTACT-1 K562_Xu_AAACCGGCAGGCTACT-1 31766 4851  K562
# K562_Xu_AAACGCGCAAGATTCT-1 K562_Xu_AAACGCGCAAGATTCT-1 14390 1948  K562
# K562_Xu_AAACGCGCACAATACT-1 K562_Xu_AAACGCGCACAATACT-1 17804 2192  K562
# K562_Xu_AAACGCGCAGCCAGAA-1 K562_Xu_AAACGCGCAGCCAGAA-1 24404 3196  K562
# K562_Xu_AAACGCGCATAATGAG-1 K562_Xu_AAACGCGCATAATGAG-1 12990 1699  K562
# K562_Xu_AAACGCGCATGTTGCA-1 K562_Xu_AAACGCGCATGTTGCA-1 11159 1107  K562
# K562_Xu_AAACGTACAAACTCAT-1 K562_Xu_AAACGTACAAACTCAT-1 18703 1520  K562
# K562_Xu_AAACGTACAAGCCAGA-1 K562_Xu_AAACGTACAAGCCAGA-1 35627 5796  K562
# ⋮                          ⋮                          ⋮     ⋮     ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1 K562_Xu_TTTGGCTGTTGGTTCT-1 15179 2722  K562
# K562_Xu_TTTGGTAAGAAACTGG-1 K562_Xu_TTTGGTAAGAAACTGG-1 35434 5151  K562
# K562_Xu_TTTGGTAAGAAGGTGC-1 K562_Xu_TTTGGTAAGAAGGTGC-1 10222 1441  K562
# K562_Xu_TTTGGTAAGACAAGTG-1 K562_Xu_TTTGGTAAGACAAGTG-1 17243 1884  K562
# K562_Xu_TTTGGTAAGCCATCAG-1 K562_Xu_TTTGGTAAGCCATCAG-1 16919 1529  K562
# K562_Xu_TTTGGTAAGCTGTACG-1 K562_Xu_TTTGGTAAGCTGTACG-1 17502 2507  K562
# K562_Xu_TTTGGTGCAACCCTAA-1 K562_Xu_TTTGGTGCAACCCTAA-1  7294  900  K562
# K562_Xu_TTTGGTGCAGCAAGTG-1 K562_Xu_TTTGGTGCAGCAAGTG-1 19463 2439  K562
# K562_Xu_TTTGGTGCATGAGTTT-1 K562_Xu_TTTGGTGCATGAGTTT-1 15493 2012  K562
# K562_Xu_TTTGTCCCAACTCGCG-1 K562_Xu_TTTGTCCCAACTCGCG-1 17267 2002  K562
# K562_Xu_TTTGTCCCATAAGTCT-1 K562_Xu_TTTGTCCCATAAGTCT-1 34199 3882  K562
# K562_Xu_TTTGTCCCATTCCTGT-1 K562_Xu_TTTGTCCCATTCCTGT-1 15760 1359  K562
# K562_Xu_TTTGTCTAGCAGGTGG-1 K562_Xu_TTTGTCTAGCAGGTGG-1 37714 8163  K562
# K562_Xu_TTTGTCTAGCGCAATT-1 K562_Xu_TTTGTCTAGCGCAATT-1 13943 2221  K562
# K562_Xu_TTTGTCTAGGACCTGC-1 K562_Xu_TTTGTCTAGGACCTGC-1  9333  896  K562
# K562_Xu_TTTGTCTAGGCAGGTG-1 K562_Xu_TTTGTCTAGGCAGGTG-1 20515 1879  K562
# K562_Xu_TTTGTGGCAAACCTAT-1 K562_Xu_TTTGTGGCAAACCTAT-1 21320 2584  K562
# K562_Xu_TTTGTGGCAAGGTACG-1 K562_Xu_TTTGTGGCAAGGTACG-1 13998 2562  K562
# K562_Xu_TTTGTGGCACATTAAC-1 K562_Xu_TTTGTGGCACATTAAC-1 16924 2840  K562
# K562_Xu_TTTGTGTTCACTAGGT-1 K562_Xu_TTTGTGTTCACTAGGT-1 14050 1557  K562
# K562_Xu_TTTGTGTTCAGGTTTA-1 K562_Xu_TTTGTGTTCAGGTTTA-1 21577 1890  K562
# K562_Xu_TTTGTGTTCGATAACC-1 K562_Xu_TTTGTGTTCGATAACC-1 23548 3889  K562
# K562_Xu_TTTGTGTTCGCTAGAT-1 K562_Xu_TTTGTGTTCGCTAGAT-1 28474 3934  K562
# K562_Xu_TTTGTTGGTATTTGCC-1 K562_Xu_TTTGTTGGTATTTGCC-1 22213 3345  K562
# K562_Xu_TTTGTTGGTCAATGTG-1 K562_Xu_TTTGTTGGTCAATGTG-1 19439 3159  K562
# K562_Xu_TTTGTTGGTGTGAGAG-1 K562_Xu_TTTGTTGGTGTGAGAG-1 16072 1687  K562
# K562_Xu_TTTGTTGGTTGCCTCA-1 K562_Xu_TTTGTTGGTTGCCTCA-1  9335  992  K562
# K562_Xu_TTTGTTGGTTTAACGG-1 K562_Xu_TTTGTTGGTTTAACGG-1 16723 1801  K562
# K562_Xu_TTTGTTGGTTTATGGG-1 K562_Xu_TTTGTTGGTTTATGGG-1 22407 3211  K562
# K562_Xu_TTTGTTGGTTTGTGGA-1 K562_Xu_TTTGTTGGTTTGTGGA-1 16066 2127  K562
#                            log.nUMI  percent.mito
# K562_Xu_AAACAGCCAAGCGATG-1  9.313529 0.09028592
# K562_Xu_AAACAGCCACATGCTA-1  9.757768 0.13275104
# K562_Xu_AAACAGCCACGGTACT-1  9.851615 0.07430618
# K562_Xu_AAACAGCCATAAAGCA-1  9.236982 0.10798442
# K562_Xu_AAACATGCAACTCGCG-1  9.302190 0.16283525
# K562_Xu_AAACATGCAATCCTAG-1 10.029503 0.10958300
# K562_Xu_AAACATGCACATAACT-1  9.273221 0.04807963
# K562_Xu_AAACATGCACCTATAG-1  9.662435 0.14494782
# K562_Xu_AAACATGCAGGGAGCT-1  9.422221 0.12702265
# K562_Xu_AAACATGCAGTTTACG-1 10.114720 0.14726360
# K562_Xu_AAACATGCATGCTATG-1  9.370416 0.17450579
# K562_Xu_AAACCAACAGGCCATT-1  9.750395 0.10681196
# K562_Xu_AAACCAACAGGTTTGC-1  9.805158 0.10614001
# K562_Xu_AAACCAACATCAGCAC-1  9.718422 0.12815113
# K562_Xu_AAACCAACATTGCGAC-1  9.692643 0.09692555
# K562_Xu_AAACCGAAGGAAGTAT-1  9.522154 0.14430046
# K562_Xu_AAACCGAAGGCAATAG-1  9.978734 0.06858971
# K562_Xu_AAACCGCGTCACACCC-1  9.992093 0.12208850
# K562_Xu_AAACCGCGTCATGCCC-1  9.104758 0.15559013
# K562_Xu_AAACCGGCAAGACTCC-1  9.494316 0.11058416
# K562_Xu_AAACCGGCAGCAACAG-1  9.530248 0.14909223
# K562_Xu_AAACCGGCAGGCGATA-1  9.630037 0.08839961
# K562_Xu_AAACCGGCAGGCTACT-1 10.366152 0.15271045
# K562_Xu_AAACGCGCAAGATTCT-1  9.574289 0.13537179
# K562_Xu_AAACGCGCACAATACT-1  9.787178 0.12311840
# K562_Xu_AAACGCGCAGCCAGAA-1 10.102502 0.13096214
# K562_Xu_AAACGCGCATAATGAG-1  9.471935 0.13079292
# K562_Xu_AAACGCGCATGTTGCA-1  9.320002 0.09920244
# K562_Xu_AAACGTACAAACTCAT-1  9.836439 0.08127038
# K562_Xu_AAACGTACAAGCCAGA-1 10.480859 0.16268560
# ⋮                          ⋮         ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1  9.627668 0.17932670
# K562_Xu_TTTGGTAAGAAACTGG-1 10.475427 0.14536885
# K562_Xu_TTTGGTAAGAAGGTGC-1  9.232298 0.14097046
# K562_Xu_TTTGGTAAGACAAGTG-1  9.755162 0.10926173
# K562_Xu_TTTGGTAAGCCATCAG-1  9.736193 0.09037177
# K562_Xu_TTTGGTAAGCTGTACG-1  9.770070 0.14324077
# K562_Xu_TTTGGTGCAACCCTAA-1  8.894807 0.12338909
# K562_Xu_TTTGGTGCAGCAAGTG-1  9.876271 0.12531470
# K562_Xu_TTTGGTGCATGAGTTT-1  9.648144 0.12986510
# K562_Xu_TTTGTCCCAACTCGCG-1  9.756552 0.11594371
# K562_Xu_TTTGTCCCATAAGTCT-1 10.439952 0.11351209
# K562_Xu_TTTGTCCCATTCCTGT-1  9.665230 0.08623096
# K562_Xu_TTTGTCTAGCAGGTGG-1 10.537787 0.21644482
# K562_Xu_TTTGTCTAGCGCAATT-1  9.542733 0.15929140
# K562_Xu_TTTGTCTAGGACCTGC-1  9.141312 0.09600343
# K562_Xu_TTTGTCTAGGCAGGTG-1  9.928912 0.09159152
# K562_Xu_TTTGTGGCAAACCTAT-1  9.967401 0.12120075
# K562_Xu_TTTGTGGCAAGGTACG-1  9.546670 0.18302615
# K562_Xu_TTTGTGGCACATTAAC-1  9.736488 0.16780903
# K562_Xu_TTTGTGTTCACTAGGT-1  9.550378 0.11081851
# K562_Xu_TTTGTGTTCAGGTTTA-1  9.979383 0.08759327
# K562_Xu_TTTGTGTTCGATAACC-1 10.066796 0.16515203
# K562_Xu_TTTGTGTTCGCTAGAT-1 10.256747 0.13816113
# K562_Xu_TTTGTTGGTATTTGCC-1 10.008433 0.15058749
# K562_Xu_TTTGTTGGTCAATGTG-1  9.875037 0.16250836
# K562_Xu_TTTGTTGGTGTGAGAG-1  9.684834 0.10496516
# K562_Xu_TTTGTTGGTTGCCTCA-1  9.141526 0.10626674
# K562_Xu_TTTGTTGGTTTAACGG-1  9.724540 0.10769599
# K562_Xu_TTTGTTGGTTTATGGG-1 10.017129 0.14330343
# K562_Xu_TTTGTTGGTTTGTGGA-1  9.684461 0.13239139

# %% [markdown]
# RUN SCENT prediction

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT.default/SCENT.240611//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  
  SCENT_obj.chr <- CreateSCENTObj(rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.chr$TargetGene,], 
                                  atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.chr$PeakName,], 
                                  meta.data = meta.data,
                                  peak.info = gene_peak.chr,
                                  covariates = c("log.nUMI","percent.mito"), 
                                  celltypes = "celltype")
  SCENT_obj.chr <- SCENT_algorithm(object = SCENT_obj.chr, 
                                   celltype = "K562", 
                                   ncores = n.cores, 
                                   regr = 'poisson', bin = TRUE)
  
  saveRDS(SCENT_obj.chr@SCENT.result,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (SCENT_obj.chr)
}

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output

# %%
sessionInfo()
