# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_25000.240612/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_25000.250328.reuse/"
celltype = "K562"

# %%
n.cores = 48

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI  nMito celltype
# K562_Xu_AAACAGCCAAGCGATG-1 K562_Xu_AAACAGCCAAGCGATG-1 11087 1001  K562
# K562_Xu_AAACAGCCACATGCTA-1 K562_Xu_AAACAGCCACATGCTA-1 17288 2295  K562
# K562_Xu_AAACAGCCACGGTACT-1 K562_Xu_AAACAGCCACGGTACT-1 18989 1411  K562
# K562_Xu_AAACAGCCATAAAGCA-1 K562_Xu_AAACAGCCATAAAGCA-1 10270 1109  K562
# K562_Xu_AAACATGCAACTCGCG-1 K562_Xu_AAACATGCAACTCGCG-1 10962 1785  K562
# K562_Xu_AAACATGCAATCCTAG-1 K562_Xu_AAACATGCAATCCTAG-1 22686 2486  K562
# K562_Xu_AAACATGCACATAACT-1 K562_Xu_AAACATGCACATAACT-1 10649  512  K562
# K562_Xu_AAACATGCACCTATAG-1 K562_Xu_AAACATGCACCTATAG-1 15716 2278  K562
# K562_Xu_AAACATGCAGGGAGCT-1 K562_Xu_AAACATGCAGGGAGCT-1 12360 1570  K562
# K562_Xu_AAACATGCAGTTTACG-1 K562_Xu_AAACATGCAGTTTACG-1 24704 3638  K562
# K562_Xu_AAACATGCATGCTATG-1 K562_Xu_AAACATGCATGCTATG-1 11736 2048  K562
# K562_Xu_AAACCAACAGGCCATT-1 K562_Xu_AAACCAACAGGCCATT-1 17161 1833  K562
# K562_Xu_AAACCAACAGGTTTGC-1 K562_Xu_AAACCAACAGGTTTGC-1 18127 1924  K562
# K562_Xu_AAACCAACATCAGCAC-1 K562_Xu_AAACCAACATCAGCAC-1 16621 2130  K562
# K562_Xu_AAACCAACATTGCGAC-1 K562_Xu_AAACCAACATTGCGAC-1 16198 1570  K562
# K562_Xu_AAACCGAAGGAAGTAT-1 K562_Xu_AAACCGAAGGAAGTAT-1 13659 1971  K562
# K562_Xu_AAACCGAAGGCAATAG-1 K562_Xu_AAACCGAAGGCAATAG-1 21563 1479  K562
# K562_Xu_AAACCGCGTCACACCC-1 K562_Xu_AAACCGCGTCACACCC-1 21853 2668  K562
# K562_Xu_AAACCGCGTCATGCCC-1 K562_Xu_AAACCGCGTCATGCCC-1  8998 1400  K562
# K562_Xu_AAACCGGCAAGACTCC-1 K562_Xu_AAACCGGCAAGACTCC-1 13284 1469  K562
# K562_Xu_AAACCGGCAGCAACAG-1 K562_Xu_AAACCGGCAGCAACAG-1 13770 2053  K562
# K562_Xu_AAACCGGCAGGCGATA-1 K562_Xu_AAACCGGCAGGCGATA-1 15215 1345  K562
# K562_Xu_AAACCGGCAGGCTACT-1 K562_Xu_AAACCGGCAGGCTACT-1 31766 4851  K562
# K562_Xu_AAACGCGCAAGATTCT-1 K562_Xu_AAACGCGCAAGATTCT-1 14390 1948  K562
# K562_Xu_AAACGCGCACAATACT-1 K562_Xu_AAACGCGCACAATACT-1 17804 2192  K562
# K562_Xu_AAACGCGCAGCCAGAA-1 K562_Xu_AAACGCGCAGCCAGAA-1 24404 3196  K562
# K562_Xu_AAACGCGCATAATGAG-1 K562_Xu_AAACGCGCATAATGAG-1 12990 1699  K562
# K562_Xu_AAACGCGCATGTTGCA-1 K562_Xu_AAACGCGCATGTTGCA-1 11159 1107  K562
# K562_Xu_AAACGTACAAACTCAT-1 K562_Xu_AAACGTACAAACTCAT-1 18703 1520  K562
# K562_Xu_AAACGTACAAGCCAGA-1 K562_Xu_AAACGTACAAGCCAGA-1 35627 5796  K562
# ⋮                          ⋮                          ⋮     ⋮     ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1 K562_Xu_TTTGGCTGTTGGTTCT-1 15179 2722  K562
# K562_Xu_TTTGGTAAGAAACTGG-1 K562_Xu_TTTGGTAAGAAACTGG-1 35434 5151  K562
# K562_Xu_TTTGGTAAGAAGGTGC-1 K562_Xu_TTTGGTAAGAAGGTGC-1 10222 1441  K562
# K562_Xu_TTTGGTAAGACAAGTG-1 K562_Xu_TTTGGTAAGACAAGTG-1 17243 1884  K562
# K562_Xu_TTTGGTAAGCCATCAG-1 K562_Xu_TTTGGTAAGCCATCAG-1 16919 1529  K562
# K562_Xu_TTTGGTAAGCTGTACG-1 K562_Xu_TTTGGTAAGCTGTACG-1 17502 2507  K562
# K562_Xu_TTTGGTGCAACCCTAA-1 K562_Xu_TTTGGTGCAACCCTAA-1  7294  900  K562
# K562_Xu_TTTGGTGCAGCAAGTG-1 K562_Xu_TTTGGTGCAGCAAGTG-1 19463 2439  K562
# K562_Xu_TTTGGTGCATGAGTTT-1 K562_Xu_TTTGGTGCATGAGTTT-1 15493 2012  K562
# K562_Xu_TTTGTCCCAACTCGCG-1 K562_Xu_TTTGTCCCAACTCGCG-1 17267 2002  K562
# K562_Xu_TTTGTCCCATAAGTCT-1 K562_Xu_TTTGTCCCATAAGTCT-1 34199 3882  K562
# K562_Xu_TTTGTCCCATTCCTGT-1 K562_Xu_TTTGTCCCATTCCTGT-1 15760 1359  K562
# K562_Xu_TTTGTCTAGCAGGTGG-1 K562_Xu_TTTGTCTAGCAGGTGG-1 37714 8163  K562
# K562_Xu_TTTGTCTAGCGCAATT-1 K562_Xu_TTTGTCTAGCGCAATT-1 13943 2221  K562
# K562_Xu_TTTGTCTAGGACCTGC-1 K562_Xu_TTTGTCTAGGACCTGC-1  9333  896  K562
# K562_Xu_TTTGTCTAGGCAGGTG-1 K562_Xu_TTTGTCTAGGCAGGTG-1 20515 1879  K562
# K562_Xu_TTTGTGGCAAACCTAT-1 K562_Xu_TTTGTGGCAAACCTAT-1 21320 2584  K562
# K562_Xu_TTTGTGGCAAGGTACG-1 K562_Xu_TTTGTGGCAAGGTACG-1 13998 2562  K562
# K562_Xu_TTTGTGGCACATTAAC-1 K562_Xu_TTTGTGGCACATTAAC-1 16924 2840  K562
# K562_Xu_TTTGTGTTCACTAGGT-1 K562_Xu_TTTGTGTTCACTAGGT-1 14050 1557  K562
# K562_Xu_TTTGTGTTCAGGTTTA-1 K562_Xu_TTTGTGTTCAGGTTTA-1 21577 1890  K562
# K562_Xu_TTTGTGTTCGATAACC-1 K562_Xu_TTTGTGTTCGATAACC-1 23548 3889  K562
# K562_Xu_TTTGTGTTCGCTAGAT-1 K562_Xu_TTTGTGTTCGCTAGAT-1 28474 3934  K562
# K562_Xu_TTTGTTGGTATTTGCC-1 K562_Xu_TTTGTTGGTATTTGCC-1 22213 3345  K562
# K562_Xu_TTTGTTGGTCAATGTG-1 K562_Xu_TTTGTTGGTCAATGTG-1 19439 3159  K562
# K562_Xu_TTTGTTGGTGTGAGAG-1 K562_Xu_TTTGTTGGTGTGAGAG-1 16072 1687  K562
# K562_Xu_TTTGTTGGTTGCCTCA-1 K562_Xu_TTTGTTGGTTGCCTCA-1  9335  992  K562
# K562_Xu_TTTGTTGGTTTAACGG-1 K562_Xu_TTTGTTGGTTTAACGG-1 16723 1801  K562
# K562_Xu_TTTGTTGGTTTATGGG-1 K562_Xu_TTTGTTGGTTTATGGG-1 22407 3211  K562
# K562_Xu_TTTGTTGGTTTGTGGA-1 K562_Xu_TTTGTTGGTTTGTGGA-1 16066 2127  K562
#                            log.nUMI  percent.mito
# K562_Xu_AAACAGCCAAGCGATG-1  9.313529 0.09028592
# K562_Xu_AAACAGCCACATGCTA-1  9.757768 0.13275104
# K562_Xu_AAACAGCCACGGTACT-1  9.851615 0.07430618
# K562_Xu_AAACAGCCATAAAGCA-1  9.236982 0.10798442
# K562_Xu_AAACATGCAACTCGCG-1  9.302190 0.16283525
# K562_Xu_AAACATGCAATCCTAG-1 10.029503 0.10958300
# K562_Xu_AAACATGCACATAACT-1  9.273221 0.04807963
# K562_Xu_AAACATGCACCTATAG-1  9.662435 0.14494782
# K562_Xu_AAACATGCAGGGAGCT-1  9.422221 0.12702265
# K562_Xu_AAACATGCAGTTTACG-1 10.114720 0.14726360
# K562_Xu_AAACATGCATGCTATG-1  9.370416 0.17450579
# K562_Xu_AAACCAACAGGCCATT-1  9.750395 0.10681196
# K562_Xu_AAACCAACAGGTTTGC-1  9.805158 0.10614001
# K562_Xu_AAACCAACATCAGCAC-1  9.718422 0.12815113
# K562_Xu_AAACCAACATTGCGAC-1  9.692643 0.09692555
# K562_Xu_AAACCGAAGGAAGTAT-1  9.522154 0.14430046
# K562_Xu_AAACCGAAGGCAATAG-1  9.978734 0.06858971
# K562_Xu_AAACCGCGTCACACCC-1  9.992093 0.12208850
# K562_Xu_AAACCGCGTCATGCCC-1  9.104758 0.15559013
# K562_Xu_AAACCGGCAAGACTCC-1  9.494316 0.11058416
# K562_Xu_AAACCGGCAGCAACAG-1  9.530248 0.14909223
# K562_Xu_AAACCGGCAGGCGATA-1  9.630037 0.08839961
# K562_Xu_AAACCGGCAGGCTACT-1 10.366152 0.15271045
# K562_Xu_AAACGCGCAAGATTCT-1  9.574289 0.13537179
# K562_Xu_AAACGCGCACAATACT-1  9.787178 0.12311840
# K562_Xu_AAACGCGCAGCCAGAA-1 10.102502 0.13096214
# K562_Xu_AAACGCGCATAATGAG-1  9.471935 0.13079292
# K562_Xu_AAACGCGCATGTTGCA-1  9.320002 0.09920244
# K562_Xu_AAACGTACAAACTCAT-1  9.836439 0.08127038
# K562_Xu_AAACGTACAAGCCAGA-1 10.480859 0.16268560
# ⋮                          ⋮         ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1  9.627668 0.17932670
# K562_Xu_TTTGGTAAGAAACTGG-1 10.475427 0.14536885
# K562_Xu_TTTGGTAAGAAGGTGC-1  9.232298 0.14097046
# K562_Xu_TTTGGTAAGACAAGTG-1  9.755162 0.10926173
# K562_Xu_TTTGGTAAGCCATCAG-1  9.736193 0.09037177
# K562_Xu_TTTGGTAAGCTGTACG-1  9.770070 0.14324077
# K562_Xu_TTTGGTGCAACCCTAA-1  8.894807 0.12338909
# K562_Xu_TTTGGTGCAGCAAGTG-1  9.876271 0.12531470
# K562_Xu_TTTGGTGCATGAGTTT-1  9.648144 0.12986510
# K562_Xu_TTTGTCCCAACTCGCG-1  9.756552 0.11594371
# K562_Xu_TTTGTCCCATAAGTCT-1 10.439952 0.11351209
# K562_Xu_TTTGTCCCATTCCTGT-1  9.665230 0.08623096
# K562_Xu_TTTGTCTAGCAGGTGG-1 10.537787 0.21644482
# K562_Xu_TTTGTCTAGCGCAATT-1  9.542733 0.15929140
# K562_Xu_TTTGTCTAGGACCTGC-1  9.141312 0.09600343
# K562_Xu_TTTGTCTAGGCAGGTG-1  9.928912 0.09159152
# K562_Xu_TTTGTGGCAAACCTAT-1  9.967401 0.12120075
# K562_Xu_TTTGTGGCAAGGTACG-1  9.546670 0.18302615
# K562_Xu_TTTGTGGCACATTAAC-1  9.736488 0.16780903
# K562_Xu_TTTGTGTTCACTAGGT-1  9.550378 0.11081851
# K562_Xu_TTTGTGTTCAGGTTTA-1  9.979383 0.08759327
# K562_Xu_TTTGTGTTCGATAACC-1 10.066796 0.16515203
# K562_Xu_TTTGTGTTCGCTAGAT-1 10.256747 0.13816113
# K562_Xu_TTTGTTGGTATTTGCC-1 10.008433 0.15058749
# K562_Xu_TTTGTTGGTCAATGTG-1  9.875037 0.16250836
# K562_Xu_TTTGTTGGTGTGAGAG-1  9.684834 0.10496516
# K562_Xu_TTTGTTGGTTGCCTCA-1  9.141526 0.10626674
# K562_Xu_TTTGTTGGTTTAACGG-1  9.724540 0.10769599
# K562_Xu_TTTGTTGGTTTATGGG-1 10.017129 0.14330343
# K562_Xu_TTTGTTGGTTTGTGGA-1  9.684461 0.13239139

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_25000.250328.reuse//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 36851 ranges and 11 metadata columns:
#                                    seqnames              ranges strand |
#                                       <Rle>           <IRanges>  <Rle> |
#       chr1-100027917-100029695_DBT     chr1 100027917-100029695      * |
#   chr1-100036824-100037384_SLC35A3     chr1 100036824-100037384      * |
#    chr1-100037554-100039259_CDC14A     chr1 100037554-100039259      * |
#         chr1-1001483-1002126_CCNL2     chr1     1001483-1002126      * |
#          chr1-1001483-1002126_HES4     chr1     1001483-1002126      * |
#                                ...      ...                 ...    ... .
#      chrX-85243494-85245390_ZNF711     chrX   85243494-85245390      * |
#         chrX-9351583-9352288_TBL1X     chrX     9351583-9352288      * |
#         chrX-9352383-9353514_TBL1X     chrX     9352383-9353514      * |
#         chrX-9515603-9516754_TBL1X     chrX     9515603-9516754      * |
#           chrX-989754-991253_ASMTL     chrX       989754-991253      * |
#                                     TargetGene               PeakName
#                                    <character>            <character>
#       chr1-100027917-100029695_DBT         DBT chr1-100027917-10002..
#   chr1-100036824-100037384_SLC35A3     SLC35A3 chr1-100036824-10003..
#    chr1-100037554-100039259_CDC14A      CDC14A chr1-100037554-10003..
#         chr1-1001483-1002126_CCNL2       CCNL2   chr1-1001483-1002126
#          chr1-1001483-1002126_HES4        HES4   chr1-1001483-1002126
#                                ...         ...                    ...
#      chrX-85243494-85245390_ZNF711      ZNF711 chrX-85243494-85245390
#         chrX-9351583-9352288_TBL1X       TBL1X   chrX-9351583-9352288
#         chrX-9352383-9353514_TBL1X       TBL1X   chrX-9352383-9353514
#         chrX-9515603-9516754_TBL1X       TBL1X   chrX-9515603-9516754
#           chrX-989754-991253_ASMTL       ASMTL     chrX-989754-991253
#                                                  PairName      beta        se
#                                               <character> <numeric> <numeric>
#       chr1-100027917-100029695_DBT chr1-100027917-10002.. 0.1184115 0.0453162
#   chr1-100036824-100037384_SLC35A3 chr1-100036824-10003.. 0.1128333 0.0387054
#    chr1-100037554-100039259_CDC14A chr1-100037554-10003.. 0.0456389 0.0115316
#         chr1-1001483-1002126_CCNL2 chr1-1001483-1002126.. 0.0910519 0.0184171
#          chr1-1001483-1002126_HES4 chr1-1001483-1002126.. 0.2078311 0.0430076
#                                ...                    ...       ...       ...
#      chrX-85243494-85245390_ZNF711 chrX-85243494-852453.. 0.3831850 0.0956835
#         chrX-9351583-9352288_TBL1X chrX-9351583-9352288.. 0.0746632 0.0216237
#         chrX-9352383-9353514_TBL1X chrX-9352383-9353514.. 0.0918799 0.0182304
#         chrX-9515603-9516754_TBL1X chrX-9515603-9516754.. 0.0858850 0.0151067
#           chrX-989754-991253_ASMTL chrX-989754-991253_A.. 0.1844644 0.0614332
#                                            z           p boot_basic_p
#                                    <numeric>   <numeric>    <numeric>
#       chr1-100027917-100029695_DBT   2.61301 8.97494e-03      0.00904
#   chr1-100036824-100037384_SLC35A3   2.91518 3.55483e-03      0.00408
#    chr1-100037554-100039259_CDC14A   3.95774 7.56626e-05      0.00120
#         chr1-1001483-1002126_CCNL2   4.94387 7.65853e-07      0.00008
#          chr1-1001483-1002126_HES4   4.83242 1.34880e-06      0.00008
#                                ...       ...         ...          ...
#      chrX-85243494-85245390_ZNF711   4.00471 6.20926e-05      0.00008
#         chrX-9351583-9352288_TBL1X   3.45285 5.54706e-04      0.00992
#         chrX-9352383-9353514_TBL1X   5.03994 4.65687e-07      0.00040
#         chrX-9515603-9516754_TBL1X   5.68524 1.30629e-08      0.00008
#           chrX-989754-991253_ASMTL   3.00268 2.67611e-03      0.00448
#                                    boot_basic_p.log10      sign
#                                             <numeric> <numeric>
#       chr1-100027917-100029695_DBT            2.04383         1
#   chr1-100036824-100037384_SLC35A3            2.38934         1
#    chr1-100037554-100039259_CDC14A            2.92082         1
#         chr1-1001483-1002126_CCNL2            4.09691         1
#          chr1-1001483-1002126_HES4            4.09691         1
#                                ...                ...       ...
#      chrX-85243494-85245390_ZNF711            4.09691         1
#         chrX-9351583-9352288_TBL1X            2.00349         1
#         chrX-9352383-9353514_TBL1X            3.39794         1
#         chrX-9515603-9516754_TBL1X            4.09691         1
#           chrX-989754-991253_ASMTL            2.34872         1
#                                    boot_basic_p.log10.signed
#                                                    <numeric>
#       chr1-100027917-100029695_DBT                   2.04383
#   chr1-100036824-100037384_SLC35A3                   2.38934
#    chr1-100037554-100039259_CDC14A                   2.92082
#         chr1-1001483-1002126_CCNL2                   4.09691
#          chr1-1001483-1002126_HES4                   4.09691
#                                ...                       ...
#      chrX-85243494-85245390_ZNF711                   4.09691
#         chrX-9351583-9352288_TBL1X                   2.00349
#         chrX-9352383-9353514_TBL1X                   3.39794
#         chrX-9515603-9516754_TBL1X                   4.09691
#           chrX-989754-991253_ASMTL                   2.34872
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  6022 35393

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 870021 ranges and 11 metadata columns:
#                                      seqnames              ranges strand |
#                                         <Rle>           <IRanges>  <Rle> |
#                       chr1.chr1.chr1     chr1 100337700-100338540      * |
#                       chr1.chr1.chr1     chr1   10045169-10046781      * |
#                       chr1.chr1.chr1     chr1     1005000-1005582      * |
#                       chr1.chr1.chr1     chr1 100538093-100540269      * |
#                       chr1.chr1.chr1     chr1 100894566-100896989      * |
#                                  ...      ...                 ...    ... .
#    chrX.chrX-81201511-81203302_BRWD3     chrX   81201511-81203302      * |
#   chrX.chrX-85243494-85245390_ZNF711     chrX   85243494-85245390      * |
#      chrX.chrX-9352383-9353514_TBL1X     chrX     9352383-9353514      * |
#      chrX.chrX-9515603-9516754_TBL1X     chrX     9515603-9516754      * |
#        chrX.chrX-989754-991253_ASMTL     chrX       989754-991253      * |
#                                       TargetGene               PeakName
#                                      <character>            <character>
#                       chr1.chr1.chr1      TRMT13 chr1-100337700-10033..
#                       chr1.chr1.chr1    SLC25A33 chr1-10045169-10046781
#                       chr1.chr1.chr1     B3GALT6   chr1-1005000-1005582
#                       chr1.chr1.chr1       SASS6 chr1-100538093-10054..
#                       chr1.chr1.chr1       SASS6 chr1-100894566-10089..
#                                  ...         ...                    ...
#    chrX.chrX-81201511-81203302_BRWD3       BRWD3 chrX-81201511-81203302
#   chrX.chrX-85243494-85245390_ZNF711      ZNF711 chrX-85243494-85245390
#      chrX.chrX-9352383-9353514_TBL1X       TBL1X   chrX-9352383-9353514
#      chrX.chrX-9515603-9516754_TBL1X       TBL1X   chrX-9515603-9516754
#        chrX.chrX-989754-991253_ASMTL       ASMTL     chrX-989754-991253
#                                                    PairName      beta        se
#                                                 <character> <numeric> <numeric>
#                       chr1.chr1.chr1 chr1-100337700-10033.. 0.0884349 0.0355261
#                       chr1.chr1.chr1 chr1-10045169-100467.. 0.0729565 0.0254855
#                       chr1.chr1.chr1 chr1-1005000-1005582.. 0.1119904 0.0434573
#                       chr1.chr1.chr1 chr1-100538093-10054.. 0.1070973 0.0379428
#                       chr1.chr1.chr1 chr1-100894566-10089.. 0.0580644 0.0199267
#                                  ...                    ...       ...       ...
#    chrX.chrX-81201511-81203302_BRWD3 chrX-81201511-812033.. 0.1343815 0.0380570
#   chrX.chrX-85243494-85245390_ZNF711 chrX-85243494-852453.. 0.3831850 0.0956835
#      chrX.chrX-9352383-9353514_TBL1X chrX-9352383-9353514.. 0.0918799 0.0182304
#      chrX.chrX-9515603-9516754_TBL1X chrX-9515603-9516754.. 0.0858850 0.0151067
#        chrX.chrX-989754-991253_ASMTL chrX-989754-991253_A.. 0.1844644 0.0614332
#                                              z           p boot_basic_p
#                                      <numeric>   <numeric>    <numeric>
#                       chr1.chr1.chr1   2.48929  0.01279976      0.01216
#                       chr1.chr1.chr1   2.86266  0.00420095      0.01016
#                       chr1.chr1.chr1   2.57702  0.00996548      0.01320
#                       chr1.chr1.chr1   2.82260  0.00476357      0.01552
#                       chr1.chr1.chr1   2.91390  0.00356943      0.00984
#                                  ...       ...         ...          ...
#    chrX.chrX-81201511-81203302_BRWD3   3.53106 4.13904e-04      0.00272
#   chrX.chrX-85243494-85245390_ZNF711   4.00471 6.20926e-05      0.00008
#      chrX.chrX-9352383-9353514_TBL1X   5.03994 4.65687e-07      0.00040
#      chrX.chrX-9515603-9516754_TBL1X   5.68524 1.30629e-08      0.00008
#        chrX.chrX-989754-991253_ASMTL   3.00268 2.67611e-03      0.00448
#                                      boot_basic_p.log10      sign
#                                               <numeric> <numeric>
#                       chr1.chr1.chr1            1.91507         1
#                       chr1.chr1.chr1            1.99311         1
#                       chr1.chr1.chr1            1.87943         1
#                       chr1.chr1.chr1            1.80911         1
#                       chr1.chr1.chr1            2.00700         1
#                                  ...                ...       ...
#    chrX.chrX-81201511-81203302_BRWD3            2.56543         1
#   chrX.chrX-85243494-85245390_ZNF711            4.09691         1
#      chrX.chrX-9352383-9353514_TBL1X            3.39794         1
#      chrX.chrX-9515603-9516754_TBL1X            4.09691         1
#        chrX.chrX-989754-991253_ASMTL            2.34872         1
#                                      boot_basic_p.log10.signed
#                                                      <numeric>
#                       chr1.chr1.chr1                   1.91507
#                       chr1.chr1.chr1                   1.99311
#                       chr1.chr1.chr1                   1.87943
#                       chr1.chr1.chr1                   1.80911
#                       chr1.chr1.chr1                   2.00700
#                                  ...                       ...
#    chrX.chrX-81201511-81203302_BRWD3                   2.56543
#   chrX.chrX-85243494-85245390_ZNF711                   4.09691
#      chrX.chrX-9352383-9353514_TBL1X                   3.39794
#      chrX.chrX-9515603-9516754_TBL1X                   4.09691
#        chrX.chrX-989754-991253_ASMTL                   2.34872
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta        se
# 1      chr1 100337700 100338540 TRMT13     K562      0.08843491 0.03552613
# 2      chr1  10045169  10046781 SLC25A33   K562      0.07295646 0.02548551
# 3      chr1   1005000   1005582 B3GALT6    K562      0.11199041 0.04345725
# 4      chr1 100538093 100540269 SASS6      K562      0.10709729 0.03794276
# 5      chr1 100894566 100896989 SASS6      K562      0.05806443 0.01992670
# 6      chr1   1019151   1020996 DVL1       K562      0.08594838 0.03013080
# 7      chr1   1032480   1033769 ACAP3      K562      0.10023559 0.03745028
# 8      chr1   1058323   1059984 CCNL2      K562      0.05122077 0.01763273
# 9      chr1   1063870   1064538 CDK11B     K562      0.07481399 0.02722509
# 10     chr1   1068523   1070670 PRKCZ      K562      0.22432548 0.07878150
# 11     chr1 108016076 108017187 STXBP3     K562      0.08748108 0.02980412
# 12     chr1 108504360 108505800 PRPF38B    K562     -0.09797176 0.02973790
# 13     chr1 108691550 108693625 SORT1      K562      0.05989186 0.01623113
# 14     chr1 108708926 108709565 TAF13      K562      0.13555191 0.05097134
# 15     chr1 108746218 108747603 WDR47      K562      0.11586406 0.03965030
# 16     chr1 108816162 108817385 SARS       K562      0.11684006 0.02300766
# 17     chr1 108816162 108817385 WDR47      K562      0.13971575 0.05190952
# 18     chr1 108876526 108877729 PRPF38B    K562      0.04853065 0.01468916
# 19     chr1 108889022 108890522 STXBP3     K562      0.12499411 0.04271352
# 20     chr1 109089284 109089668 TAF13      K562      0.08791043 0.03326279
# 21     chr1 109134269 109135221 SLC25A24   K562     -0.08370371 0.02944531
# 22     chr1 109150983 109151785 CYB561D1   K562      0.22110763 0.08749470
# 23     chr1 109150983 109151785 SARS       K562      0.12824553 0.02712831
# 24     chr1 109180698 109181961 SARS       K562     -0.06390411 0.01936714
# 25     chr1 109193712 109194127 PSMA5      K562     -0.05546756 0.01941679
# 26     chr1 109214869 109215114 CSF1       K562      0.31697773 0.11084760
# 27     chr1 109253559 109255347 PSRC1      K562     -0.15088526 0.04301282
# 28     chr1 109275677 109276236 GPSM2      K562     -0.11844859 0.03854386
# 29     chr1 109389393 109390570 SARS       K562      0.05977862 0.01886332
# 30     chr1 109390673 109390888 TMEM167B   K562      0.13608573 0.05335710
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮           ⋮
# 869992 chrX 70422838  70425629  KIF4A      K562      0.19530126 0.030746127
# 869993 chrX 70454262  70455897  IGBP1      K562      0.09269408 0.030777935
# 869994 chrX 70454262  70455897  ZMYM3      K562      0.13412631 0.045639250
# 869995 chrX 70969484  70970910  ZMYM3      K562      0.18322365 0.060560348
# 869996 chrX 71067420  71068957  GCNA       K562      0.20727916 0.076325150
# 869997 chrX 71102755  71104118  PDZD11     K562      0.16723186 0.054013496
# 869998 chrX 71145553  71147270  ZMYM3      K562      0.16313310 0.050419104
# 869999 chrX 71532122  71534552  TAF1       K562      0.05694039 0.017426308
# 870000 chrX 72018159  72019193  RPS4X      K562     -0.05290068 0.006755461
# 870001 chrX 72018159  72019193  TAF1       K562      0.06490511 0.019719380
# 870002 chrX 72131530  72132528  ZMYM3      K562      0.20793985 0.072104029
# 870003 chrX 72181025  72182064  HDAC8      K562      0.23810941 0.047302700
# 870004 chrX 72269833  72271626  HDAC8      K562      0.17487287 0.063516569
# 870005 chrX 72308543  72309587  OGT        K562      0.08834193 0.022695139
# 870006 chrX 73850509  73851931  XIST       K562      0.05287100 0.012265026
# 870007 chrX 74293273  74293897  FTX        K562      0.07194236 0.015378070
# 870008 chrX 74293273  74293897  XIST       K562      0.06650267 0.014247603
# 870009 chrX 74324906  74326736  JPX        K562      0.08471308 0.027046890
# 870010 chrX 74343411  74344727  FTX        K562      0.08779828 0.020053116
# 870011 chrX 74343411  74344727  JPX        K562      0.07759685 0.024919278
# 870012 chrX 75155436  75156996  ABCB7      K562      0.14714791 0.034175730
# 870013 chrX 79366432  79367996  ITM2A      K562      0.08765707 0.029901023
# 870014 chrX 80809265  80810388  BRWD3      K562      0.17932734 0.030120869
# 870015 chrX 80809265  80810388  SH3BGRL    K562      0.11339801 0.033715447
# 870016 chrX 81120662  81122542  SH3BGRL    K562      0.10446222 0.036210331
# 870017 chrX 81201511  81203302  BRWD3      K562      0.13438149 0.038057024
# 870018 chrX 85243494  85245390  ZNF711     K562      0.38318496 0.095683483
# 870019 chrX  9352383   9353514  TBL1X      K562      0.09187993 0.018230375
# 870020 chrX  9515603   9516754  TBL1X      K562      0.08588495 0.015106652
# 870021 chrX   989754    991253  ASMTL      K562      0.18446440 0.061433203
#        z         p            boot_basic_p boot_basic_p.log10 sign
# 1       2.489292 1.279976e-02 0.01216      1.915066            1
# 2       2.862664 4.200953e-03 0.01016      1.993106            1
# 3       2.577025 9.965484e-03 0.01320      1.879426            1
# 4       2.822602 4.763572e-03 0.01552      1.809108            1
# 5       2.913901 3.569427e-03 0.00984      2.007005            1
# 6       2.852509 4.337563e-03 0.00888      2.051587            1
# 7       2.676498 7.439605e-03 0.01176      1.929593            1
# 8       2.904868 3.674075e-03 0.01304      1.884722            1
# 9       2.747980 5.996373e-03 0.00992      2.003488            1
# 10      2.847438 4.407262e-03 0.00976      2.010550            1
# 11      2.935201 3.333317e-03 0.00848      2.071604            1
# 12     -3.294508 9.859401e-04 0.01016      1.993106           -1
# 13      3.689937 2.243100e-04 0.00536      2.270835            1
# 14      2.659375 7.828581e-03 0.00824      2.084073            1
# 15      2.922148 3.476262e-03 0.00760      2.119186            1
# 16      5.078312 3.808024e-07 0.00008      4.096910            1
# 17      2.691525 7.112626e-03 0.01056      1.976336            1
# 18      3.303842 9.536955e-04 0.01000      2.000000            1
# 19      2.926336 3.429807e-03 0.01272      1.895513            1
# 20      2.642906 8.219785e-03 0.01144      1.941574            1
# 21     -2.842684 4.473536e-03 0.01040      1.982967           -1
# 22      2.527098 1.150095e-02 0.00752      2.123782            1
# 23      4.727368 2.274486e-06 0.00008      4.096910            1
# 24     -3.299616 9.681731e-04 0.00096      3.017729           -1
# 25     -2.856680 4.280969e-03 0.01200      1.920819           -1
# 26      2.859581 4.242008e-03 0.01256      1.901010            1
# 27     -3.507914 4.516351e-04 0.01256      1.901010           -1
# 28     -3.073086 2.118574e-03 0.00800      2.096910           -1
# 29      3.169040 1.529435e-03 0.00304      2.517126            1
# 30      2.550471 1.075775e-02 0.00912      2.040005            1
# ⋮      ⋮         ⋮            ⋮            ⋮                  ⋮
# 869992  6.352060 2.124498e-10 0.00008      4.096910            1
# 869993  3.011706 2.597844e-03 0.00488      2.311580            1
# 869994  2.938837 3.294464e-03 0.00416      2.380907            1
# 869995  3.025472 2.482453e-03 0.00224      2.649752            1
# 869996  2.715739 6.612809e-03 0.00888      2.051587            1
# 869997  3.096112 1.960760e-03 0.00200      2.698970            1
# 869998  3.235541 1.214123e-03 0.00112      2.950782            1
# 869999  3.267496 1.085034e-03 0.00496      2.304518            1
# 870000 -7.830801 4.847703e-15 0.00008      4.096910           -1
# 870001  3.291438 9.967665e-04 0.00592      2.227678            1
# 870002  2.883887 3.928000e-03 0.00512      2.290730            1
# 870003  5.033738 4.810064e-07 0.00008      4.096910            1
# 870004  2.753185 5.901853e-03 0.00496      2.304518            1
# 870005  3.892549 9.919659e-05 0.00024      3.619789            1
# 870006  4.310712 1.627296e-05 0.00216      2.665546            1
# 870007  4.678244 2.893423e-06 0.00024      3.619789            1
# 870008  4.667639 3.046809e-06 0.00064      3.193820            1
# 870009  3.132082 1.735713e-03 0.00224      2.649752            1
# 870010  4.378286 1.196162e-05 0.00104      2.982967            1
# 870011  3.113929 1.846142e-03 0.00536      2.270835            1
# 870012  4.305626 1.665142e-05 0.00016      3.795880            1
# 870013  2.931574 3.372486e-03 0.00840      2.075721            1
# 870014  5.953591 2.623218e-09 0.00008      4.096910            1
# 870015  3.363384 7.699308e-04 0.00320      2.494850            1
# 870016  2.884873 3.915713e-03 0.00944      2.025028            1
# 870017  3.531056 4.139037e-04 0.00272      2.565431            1
# 870018  4.004714 6.209261e-05 0.00008      4.096910            1
# 870019  5.039936 4.656865e-07 0.00040      3.397940            1
# 870020  5.685241 1.306287e-08 0.00008      4.096910            1
# 870021  3.002683 2.676114e-03 0.00448      2.348722            1
#        boot_basic_p.log10.signed FDR
# 1       1.915066                 0.23351113
# 2       1.993106                 0.22092534
# 3       1.879426                 0.24168731
# 4       1.809108                 0.25825732
# 5       2.007005                 0.22081523
# 6       2.051587                 0.20690376
# 7       1.929593                 0.23083093
# 8       1.884722                 0.24002610
# 9       2.003488                 0.22092534
# 10      2.010550                 0.21963749
# 11      2.071604                 0.20122676
# 12     -1.993106                 0.22092534
# 13      2.270835                 0.15613595
# 14      2.084073                 0.19773750
# 15      2.119186                 0.18883252
# 16      4.096910                 0.01051226
# 17      1.976336                 0.22371242
# 18      2.000000                 0.22092534
# 19      1.895513                 0.23605793
# 20      1.941574                 0.22990484
# 21     -1.982967                 0.22092534
# 22      2.123782                 0.18771864
# 23      4.096910                 0.01051226
# 24     -3.017729                 0.05976958
# 25     -1.920819                 0.23083093
# 26      1.901010                 0.23605793
# 27     -1.901010                 0.23605793
# 28     -2.096910                 0.19437466
# 29      2.517126                 0.11547103
# 30      2.040005                 0.21028255
# ⋮      ⋮                         ⋮
# 869992  4.096910                 0.01051226
# 869993  2.311580                 0.14877365
# 869994  2.380907                 0.13689199
# 869995  2.649752                 0.09792709
# 869996  2.051587                 0.20690376
# 869997  2.698970                 0.09184703
# 869998  2.950782                 0.06570624
# 869999  2.304518                 0.15004013
# 870000 -4.096910                 0.01051226
# 870001  2.227678                 0.16436969
# 870002  2.290730                 0.15254640
# 870003  4.096910                 0.01051226
# 870004  2.304518                 0.15004013
# 870005  3.619789                 0.02405034
# 870006  2.665546                 0.09596800
# 870007  3.619789                 0.02405034
# 870008  3.193820                 0.04636248
# 870009  2.649752                 0.09792709
# 870010  2.982967                 0.06275205
# 870011  2.270835                 0.15613595
# 870012  3.795880                 0.01788557
# 870013  2.075721                 0.20007053
# 870014  4.096910                 0.01051226
# 870015  2.494850                 0.11857186
# 870016  2.025028                 0.21496056
# 870017  2.565431                 0.10875762
# 870018  4.096910                 0.01051226
# 870019  3.397940                 0.03412516
# 870020  4.096910                 0.01051226
# 870021  2.348722                 0.14224123

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
