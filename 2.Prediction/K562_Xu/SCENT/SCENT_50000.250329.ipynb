# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_25000.250328.reuse/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_50000.250329/"
celltype = "K562"

# %%
n.cores = 48

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                            cell                       nUMI  nMito celltype
# K562_Xu_AAACAGCCAAGCGATG-1 K562_Xu_AAACAGCCAAGCGATG-1 11087 1001  K562
# K562_Xu_AAACAGCCACATGCTA-1 K562_Xu_AAACAGCCACATGCTA-1 17288 2295  K562
# K562_Xu_AAACAGCCACGGTACT-1 K562_Xu_AAACAGCCACGGTACT-1 18989 1411  K562
# K562_Xu_AAACAGCCATAAAGCA-1 K562_Xu_AAACAGCCATAAAGCA-1 10270 1109  K562
# K562_Xu_AAACATGCAACTCGCG-1 K562_Xu_AAACATGCAACTCGCG-1 10962 1785  K562
# K562_Xu_AAACATGCAATCCTAG-1 K562_Xu_AAACATGCAATCCTAG-1 22686 2486  K562
# K562_Xu_AAACATGCACATAACT-1 K562_Xu_AAACATGCACATAACT-1 10649  512  K562
# K562_Xu_AAACATGCACCTATAG-1 K562_Xu_AAACATGCACCTATAG-1 15716 2278  K562
# K562_Xu_AAACATGCAGGGAGCT-1 K562_Xu_AAACATGCAGGGAGCT-1 12360 1570  K562
# K562_Xu_AAACATGCAGTTTACG-1 K562_Xu_AAACATGCAGTTTACG-1 24704 3638  K562
# K562_Xu_AAACATGCATGCTATG-1 K562_Xu_AAACATGCATGCTATG-1 11736 2048  K562
# K562_Xu_AAACCAACAGGCCATT-1 K562_Xu_AAACCAACAGGCCATT-1 17161 1833  K562
# K562_Xu_AAACCAACAGGTTTGC-1 K562_Xu_AAACCAACAGGTTTGC-1 18127 1924  K562
# K562_Xu_AAACCAACATCAGCAC-1 K562_Xu_AAACCAACATCAGCAC-1 16621 2130  K562
# K562_Xu_AAACCAACATTGCGAC-1 K562_Xu_AAACCAACATTGCGAC-1 16198 1570  K562
# K562_Xu_AAACCGAAGGAAGTAT-1 K562_Xu_AAACCGAAGGAAGTAT-1 13659 1971  K562
# K562_Xu_AAACCGAAGGCAATAG-1 K562_Xu_AAACCGAAGGCAATAG-1 21563 1479  K562
# K562_Xu_AAACCGCGTCACACCC-1 K562_Xu_AAACCGCGTCACACCC-1 21853 2668  K562
# K562_Xu_AAACCGCGTCATGCCC-1 K562_Xu_AAACCGCGTCATGCCC-1  8998 1400  K562
# K562_Xu_AAACCGGCAAGACTCC-1 K562_Xu_AAACCGGCAAGACTCC-1 13284 1469  K562
# K562_Xu_AAACCGGCAGCAACAG-1 K562_Xu_AAACCGGCAGCAACAG-1 13770 2053  K562
# K562_Xu_AAACCGGCAGGCGATA-1 K562_Xu_AAACCGGCAGGCGATA-1 15215 1345  K562
# K562_Xu_AAACCGGCAGGCTACT-1 K562_Xu_AAACCGGCAGGCTACT-1 31766 4851  K562
# K562_Xu_AAACGCGCAAGATTCT-1 K562_Xu_AAACGCGCAAGATTCT-1 14390 1948  K562
# K562_Xu_AAACGCGCACAATACT-1 K562_Xu_AAACGCGCACAATACT-1 17804 2192  K562
# K562_Xu_AAACGCGCAGCCAGAA-1 K562_Xu_AAACGCGCAGCCAGAA-1 24404 3196  K562
# K562_Xu_AAACGCGCATAATGAG-1 K562_Xu_AAACGCGCATAATGAG-1 12990 1699  K562
# K562_Xu_AAACGCGCATGTTGCA-1 K562_Xu_AAACGCGCATGTTGCA-1 11159 1107  K562
# K562_Xu_AAACGTACAAACTCAT-1 K562_Xu_AAACGTACAAACTCAT-1 18703 1520  K562
# K562_Xu_AAACGTACAAGCCAGA-1 K562_Xu_AAACGTACAAGCCAGA-1 35627 5796  K562
# ⋮                          ⋮                          ⋮     ⋮     ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1 K562_Xu_TTTGGCTGTTGGTTCT-1 15179 2722  K562
# K562_Xu_TTTGGTAAGAAACTGG-1 K562_Xu_TTTGGTAAGAAACTGG-1 35434 5151  K562
# K562_Xu_TTTGGTAAGAAGGTGC-1 K562_Xu_TTTGGTAAGAAGGTGC-1 10222 1441  K562
# K562_Xu_TTTGGTAAGACAAGTG-1 K562_Xu_TTTGGTAAGACAAGTG-1 17243 1884  K562
# K562_Xu_TTTGGTAAGCCATCAG-1 K562_Xu_TTTGGTAAGCCATCAG-1 16919 1529  K562
# K562_Xu_TTTGGTAAGCTGTACG-1 K562_Xu_TTTGGTAAGCTGTACG-1 17502 2507  K562
# K562_Xu_TTTGGTGCAACCCTAA-1 K562_Xu_TTTGGTGCAACCCTAA-1  7294  900  K562
# K562_Xu_TTTGGTGCAGCAAGTG-1 K562_Xu_TTTGGTGCAGCAAGTG-1 19463 2439  K562
# K562_Xu_TTTGGTGCATGAGTTT-1 K562_Xu_TTTGGTGCATGAGTTT-1 15493 2012  K562
# K562_Xu_TTTGTCCCAACTCGCG-1 K562_Xu_TTTGTCCCAACTCGCG-1 17267 2002  K562
# K562_Xu_TTTGTCCCATAAGTCT-1 K562_Xu_TTTGTCCCATAAGTCT-1 34199 3882  K562
# K562_Xu_TTTGTCCCATTCCTGT-1 K562_Xu_TTTGTCCCATTCCTGT-1 15760 1359  K562
# K562_Xu_TTTGTCTAGCAGGTGG-1 K562_Xu_TTTGTCTAGCAGGTGG-1 37714 8163  K562
# K562_Xu_TTTGTCTAGCGCAATT-1 K562_Xu_TTTGTCTAGCGCAATT-1 13943 2221  K562
# K562_Xu_TTTGTCTAGGACCTGC-1 K562_Xu_TTTGTCTAGGACCTGC-1  9333  896  K562
# K562_Xu_TTTGTCTAGGCAGGTG-1 K562_Xu_TTTGTCTAGGCAGGTG-1 20515 1879  K562
# K562_Xu_TTTGTGGCAAACCTAT-1 K562_Xu_TTTGTGGCAAACCTAT-1 21320 2584  K562
# K562_Xu_TTTGTGGCAAGGTACG-1 K562_Xu_TTTGTGGCAAGGTACG-1 13998 2562  K562
# K562_Xu_TTTGTGGCACATTAAC-1 K562_Xu_TTTGTGGCACATTAAC-1 16924 2840  K562
# K562_Xu_TTTGTGTTCACTAGGT-1 K562_Xu_TTTGTGTTCACTAGGT-1 14050 1557  K562
# K562_Xu_TTTGTGTTCAGGTTTA-1 K562_Xu_TTTGTGTTCAGGTTTA-1 21577 1890  K562
# K562_Xu_TTTGTGTTCGATAACC-1 K562_Xu_TTTGTGTTCGATAACC-1 23548 3889  K562
# K562_Xu_TTTGTGTTCGCTAGAT-1 K562_Xu_TTTGTGTTCGCTAGAT-1 28474 3934  K562
# K562_Xu_TTTGTTGGTATTTGCC-1 K562_Xu_TTTGTTGGTATTTGCC-1 22213 3345  K562
# K562_Xu_TTTGTTGGTCAATGTG-1 K562_Xu_TTTGTTGGTCAATGTG-1 19439 3159  K562
# K562_Xu_TTTGTTGGTGTGAGAG-1 K562_Xu_TTTGTTGGTGTGAGAG-1 16072 1687  K562
# K562_Xu_TTTGTTGGTTGCCTCA-1 K562_Xu_TTTGTTGGTTGCCTCA-1  9335  992  K562
# K562_Xu_TTTGTTGGTTTAACGG-1 K562_Xu_TTTGTTGGTTTAACGG-1 16723 1801  K562
# K562_Xu_TTTGTTGGTTTATGGG-1 K562_Xu_TTTGTTGGTTTATGGG-1 22407 3211  K562
# K562_Xu_TTTGTTGGTTTGTGGA-1 K562_Xu_TTTGTTGGTTTGTGGA-1 16066 2127  K562
#                            log.nUMI  percent.mito
# K562_Xu_AAACAGCCAAGCGATG-1  9.313529 0.09028592
# K562_Xu_AAACAGCCACATGCTA-1  9.757768 0.13275104
# K562_Xu_AAACAGCCACGGTACT-1  9.851615 0.07430618
# K562_Xu_AAACAGCCATAAAGCA-1  9.236982 0.10798442
# K562_Xu_AAACATGCAACTCGCG-1  9.302190 0.16283525
# K562_Xu_AAACATGCAATCCTAG-1 10.029503 0.10958300
# K562_Xu_AAACATGCACATAACT-1  9.273221 0.04807963
# K562_Xu_AAACATGCACCTATAG-1  9.662435 0.14494782
# K562_Xu_AAACATGCAGGGAGCT-1  9.422221 0.12702265
# K562_Xu_AAACATGCAGTTTACG-1 10.114720 0.14726360
# K562_Xu_AAACATGCATGCTATG-1  9.370416 0.17450579
# K562_Xu_AAACCAACAGGCCATT-1  9.750395 0.10681196
# K562_Xu_AAACCAACAGGTTTGC-1  9.805158 0.10614001
# K562_Xu_AAACCAACATCAGCAC-1  9.718422 0.12815113
# K562_Xu_AAACCAACATTGCGAC-1  9.692643 0.09692555
# K562_Xu_AAACCGAAGGAAGTAT-1  9.522154 0.14430046
# K562_Xu_AAACCGAAGGCAATAG-1  9.978734 0.06858971
# K562_Xu_AAACCGCGTCACACCC-1  9.992093 0.12208850
# K562_Xu_AAACCGCGTCATGCCC-1  9.104758 0.15559013
# K562_Xu_AAACCGGCAAGACTCC-1  9.494316 0.11058416
# K562_Xu_AAACCGGCAGCAACAG-1  9.530248 0.14909223
# K562_Xu_AAACCGGCAGGCGATA-1  9.630037 0.08839961
# K562_Xu_AAACCGGCAGGCTACT-1 10.366152 0.15271045
# K562_Xu_AAACGCGCAAGATTCT-1  9.574289 0.13537179
# K562_Xu_AAACGCGCACAATACT-1  9.787178 0.12311840
# K562_Xu_AAACGCGCAGCCAGAA-1 10.102502 0.13096214
# K562_Xu_AAACGCGCATAATGAG-1  9.471935 0.13079292
# K562_Xu_AAACGCGCATGTTGCA-1  9.320002 0.09920244
# K562_Xu_AAACGTACAAACTCAT-1  9.836439 0.08127038
# K562_Xu_AAACGTACAAGCCAGA-1 10.480859 0.16268560
# ⋮                          ⋮         ⋮
# K562_Xu_TTTGGCTGTTGGTTCT-1  9.627668 0.17932670
# K562_Xu_TTTGGTAAGAAACTGG-1 10.475427 0.14536885
# K562_Xu_TTTGGTAAGAAGGTGC-1  9.232298 0.14097046
# K562_Xu_TTTGGTAAGACAAGTG-1  9.755162 0.10926173
# K562_Xu_TTTGGTAAGCCATCAG-1  9.736193 0.09037177
# K562_Xu_TTTGGTAAGCTGTACG-1  9.770070 0.14324077
# K562_Xu_TTTGGTGCAACCCTAA-1  8.894807 0.12338909
# K562_Xu_TTTGGTGCAGCAAGTG-1  9.876271 0.12531470
# K562_Xu_TTTGGTGCATGAGTTT-1  9.648144 0.12986510
# K562_Xu_TTTGTCCCAACTCGCG-1  9.756552 0.11594371
# K562_Xu_TTTGTCCCATAAGTCT-1 10.439952 0.11351209
# K562_Xu_TTTGTCCCATTCCTGT-1  9.665230 0.08623096
# K562_Xu_TTTGTCTAGCAGGTGG-1 10.537787 0.21644482
# K562_Xu_TTTGTCTAGCGCAATT-1  9.542733 0.15929140
# K562_Xu_TTTGTCTAGGACCTGC-1  9.141312 0.09600343
# K562_Xu_TTTGTCTAGGCAGGTG-1  9.928912 0.09159152
# K562_Xu_TTTGTGGCAAACCTAT-1  9.967401 0.12120075
# K562_Xu_TTTGTGGCAAGGTACG-1  9.546670 0.18302615
# K562_Xu_TTTGTGGCACATTAAC-1  9.736488 0.16780903
# K562_Xu_TTTGTGTTCACTAGGT-1  9.550378 0.11081851
# K562_Xu_TTTGTGTTCAGGTTTA-1  9.979383 0.08759327
# K562_Xu_TTTGTGTTCGATAACC-1 10.066796 0.16515203
# K562_Xu_TTTGTGTTCGCTAGAT-1 10.256747 0.13816113
# K562_Xu_TTTGTTGGTATTTGCC-1 10.008433 0.15058749
# K562_Xu_TTTGTTGGTCAATGTG-1  9.875037 0.16250836
# K562_Xu_TTTGTTGGTGTGAGAG-1  9.684834 0.10496516
# K562_Xu_TTTGTTGGTTGCCTCA-1  9.141526 0.10626674
# K562_Xu_TTTGTTGGTTTAACGG-1  9.724540 0.10769599
# K562_Xu_TTTGTTGGTTTATGGG-1 10.017129 0.14330343
# K562_Xu_TTTGTTGGTTTGTGGA-1  9.684461 0.13239139

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
                bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
               # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/SCENT/SCENT_50000.250329//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.001]
  pairs.E2G.chr.keep = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res$PairName]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 870021 ranges and 11 metadata columns:
#                                            seqnames              ranges strand
#                                               <Rle>           <IRanges>  <Rle>
#                        chr1.chr1.chr1.chr1     chr1 108816162-108817385      *
#                        chr1.chr1.chr1.chr1     chr1 109150983-109151785      *
#                        chr1.chr1.chr1.chr1     chr1 109180698-109181961      *
#                        chr1.chr1.chr1.chr1     chr1 109895498-109896712      *
#                        chr1.chr1.chr1.chr1     chr1 111747044-111747888      *
#                                        ...      ...                 ...    ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A     chrX   79366432-79367996      *
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL     chrX   80809265-80810388      *
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL     chrX   81120662-81122542      *
#     chrX.chrX.chrX-81201511-81203302_BRWD3     chrX   81201511-81203302      *
#         chrX.chrX.chrX-989754-991253_ASMTL     chrX       989754-991253      *
#                                            |  TargetGene               PeakName
#                                            | <character>            <character>
#                        chr1.chr1.chr1.chr1 |        SARS chr1-108816162-10881..
#                        chr1.chr1.chr1.chr1 |        SARS chr1-109150983-10915..
#                        chr1.chr1.chr1.chr1 |        SARS chr1-109180698-10918..
#                        chr1.chr1.chr1.chr1 |        SARS chr1-109895498-10989..
#                        chr1.chr1.chr1.chr1 |     FAM212B chr1-111747044-11174..
#                                        ... .         ...                    ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A |       ITM2A chrX-79366432-79367996
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL |     SH3BGRL chrX-80809265-80810388
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL |     SH3BGRL chrX-81120662-81122542
#     chrX.chrX.chrX-81201511-81203302_BRWD3 |       BRWD3 chrX-81201511-81203302
#         chrX.chrX.chrX-989754-991253_ASMTL |       ASMTL     chrX-989754-991253
#                                                          PairName       beta
#                                                       <character>  <numeric>
#                        chr1.chr1.chr1.chr1 chr1-108816162-10881..  0.1168401
#                        chr1.chr1.chr1.chr1 chr1-109150983-10915..  0.1282455
#                        chr1.chr1.chr1.chr1 chr1-109180698-10918.. -0.0639041
#                        chr1.chr1.chr1.chr1 chr1-109895498-10989..  0.0757898
#                        chr1.chr1.chr1.chr1 chr1-111747044-11174..  0.3248293
#                                        ...                    ...        ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A chrX-79366432-793679..  0.0876571
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL chrX-80809265-808103..  0.1133980
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL chrX-81120662-811225..  0.1044622
#     chrX.chrX.chrX-81201511-81203302_BRWD3 chrX-81201511-812033..  0.1343815
#         chrX.chrX.chrX-989754-991253_ASMTL chrX-989754-991253_A..  0.1844644
#                                                   se         z           p
#                                            <numeric> <numeric>   <numeric>
#                        chr1.chr1.chr1.chr1 0.0230077   5.07831 3.80802e-07
#                        chr1.chr1.chr1.chr1 0.0271283   4.72737 2.27449e-06
#                        chr1.chr1.chr1.chr1 0.0193671  -3.29962 9.68173e-04
#                        chr1.chr1.chr1.chr1 0.0194447   3.89771 9.71056e-05
#                        chr1.chr1.chr1.chr1 0.0948446   3.42486 6.15124e-04
#                                        ...       ...       ...         ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A 0.0299010   2.93157 0.003372486
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL 0.0337154   3.36338 0.000769931
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL 0.0362103   2.88487 0.003915713
#     chrX.chrX.chrX-81201511-81203302_BRWD3 0.0380570   3.53106 0.000413904
#         chrX.chrX.chrX-989754-991253_ASMTL 0.0614332   3.00268 0.002676114
#                                            boot_basic_p boot_basic_p.log10
#                                               <numeric>          <numeric>
#                        chr1.chr1.chr1.chr1      0.00004            4.39794
#                        chr1.chr1.chr1.chr1      0.00004            4.39794
#                        chr1.chr1.chr1.chr1      0.00204            2.69037
#                        chr1.chr1.chr1.chr1      0.00068            3.16749
#                        chr1.chr1.chr1.chr1      0.00044            3.35655
#                                        ...          ...                ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A      0.00840            2.07572
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL      0.00320            2.49485
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL      0.00944            2.02503
#     chrX.chrX.chrX-81201511-81203302_BRWD3      0.00272            2.56543
#         chrX.chrX.chrX-989754-991253_ASMTL      0.00448            2.34872
#                                                 sign boot_basic_p.log10.signed
#                                            <numeric>                 <numeric>
#                        chr1.chr1.chr1.chr1         1                   4.39794
#                        chr1.chr1.chr1.chr1         1                   4.39794
#                        chr1.chr1.chr1.chr1        -1                  -2.69037
#                        chr1.chr1.chr1.chr1         1                   3.16749
#                        chr1.chr1.chr1.chr1         1                   3.35655
#                                        ...       ...                       ...
#     chrX.chrX.chrX-79366432-79367996_ITM2A         1                   2.07572
#   chrX.chrX.chrX-80809265-80810388_SH3BGRL         1                   2.49485
#   chrX.chrX.chrX-81120662-81122542_SH3BGRL         1                   2.02503
#     chrX.chrX.chrX-81201511-81203302_BRWD3         1                   2.56543
#         chrX.chrX.chrX-989754-991253_ASMTL         1                   2.34872
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta        se
# 1      chr1 108816162 108817385 SARS       K562      0.11684006 0.02300766
# 2      chr1 109150983 109151785 SARS       K562      0.12824553 0.02712831
# 3      chr1 109180698 109181961 SARS       K562     -0.06390411 0.01936714
# 4      chr1 109895498 109896712 SARS       K562      0.07578982 0.01944469
# 5      chr1 111747044 111747888 FAM212B    K562      0.32482931 0.09484465
# 6      chr1 117674269 117675205 FAM46C     K562      0.20151778 0.04857057
# 7      chr1 149237627 149238291 HIST2H2AC  K562      0.20881662 0.05555762
# 8      chr1 149885311 149886029 HIST2H2BE  K562     -0.30504933 0.05630027
# 9      chr1 149886235 149887291 HIST2H2AC  K562      0.13136990 0.03431745
# 10     chr1 150514863 150516509 HIST2H2AC  K562      0.13963129 0.03399692
# 11     chr1 150545468 150546023 HIST2H2AC  K562      0.22935426 0.03439777
# 12     chr1 150567568 150569556 HIST2H2BF  K562      0.31067539 0.07735942
# 13     chr1 150615484 150615969 HIST2H2AC  K562      0.18669160 0.05011078
# 14     chr1 155910604 155912523 RRNAD1     K562      0.12006094 0.03426555
# 15     chr1 155938229 155938422 KIAA0907   K562      0.16465677 0.03254305
# 16     chr1 156105810 156107435 KIAA0907   K562      0.06742095 0.01735091
# 17     chr1 156616013 156617326 KIAA0907   K562      0.08475387 0.02140373
# 18     chr1 156755583 156755926 KIAA0907   K562      0.10087661 0.02548436
# 19     chr1 156816671 156817213 KIAA0907   K562      0.09250884 0.02450308
# 20     chr1 156920029 156920914 KIAA0907   K562      0.07223583 0.01874901
# 21     chr1 175480819 175482013 RFWD2      K562      0.08626207 0.01879186
# 22     chr1 175757234 175758062 RFWD2      K562      0.07978856 0.01712647
# 23     chr1 176853423 176854049 RFWD2      K562      0.06875709 0.01629811
# 24     chr1 176858372 176859137 RFWD2      K562      0.10653325 0.01580575
# 25     chr1 184031200 184032083 FAM129A    K562      0.17510703 0.02266410
# 26     chr1 184491332 184492468 FAM129A    K562      0.24781736 0.03337783
# 27     chr1 184929720 184931122 FAM129A    K562      0.47912341 0.03324898
# 28     chr1 184973175 184974825 FAM129A    K562      0.29915219 0.02120656
# 29     chr1 185262858 185264777 FAM129A    K562     -0.29412115 0.03653058
# 30     chr1 185862174 185863083 FAM129A    K562      0.35739319 0.03792481
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮           ⋮
# 869992 chrX 53683285  53684785  HUWE1      K562     0.04210058  0.01305141
# 869993 chrX 54439925  54441022  PHF8       K562     0.11900443  0.03464922
# 869994 chrX 54529545  54531406  ALAS2      K562     0.15581051  0.03548870
# 869995 chrX 55480020  55481333  GNL3L      K562     0.08675610  0.02497028
# 869996 chrX 55717281  55718501  ALAS2      K562     0.16944389  0.03977896
# 869997 chrX 55717281  55718501  UBQLN2     K562     0.12594665  0.04228733
# 869998 chrX 65697825  65698728  LAS1L      K562     0.11172777  0.03482564
# 869999 chrX 66008553  66009108  LAS1L      K562     0.09692332  0.03476169
# 870000 chrX 66009220  66009749  MSN        K562     0.06914938  0.01903394
# 870001 chrX 66021480  66023656  MSN        K562     0.06797215  0.01740920
# 870002 chrX 66046003  66047933  HEPH       K562     0.10454376  0.02435514
# 870003 chrX 70454262  70455897  IGBP1      K562     0.09269408  0.03077794
# 870004 chrX 70454262  70455897  ZMYM3      K562     0.13412631  0.04563925
# 870005 chrX 70969484  70970910  ZMYM3      K562     0.18322365  0.06056035
# 870006 chrX 71067420  71068957  GCNA       K562     0.20727916  0.07632515
# 870007 chrX 71102755  71104118  PDZD11     K562     0.16723186  0.05401350
# 870008 chrX 71145553  71147270  ZMYM3      K562     0.16313310  0.05041910
# 870009 chrX 71532122  71534552  TAF1       K562     0.05694039  0.01742631
# 870010 chrX 72018159  72019193  TAF1       K562     0.06490511  0.01971938
# 870011 chrX 72131530  72132528  ZMYM3      K562     0.20793985  0.07210403
# 870012 chrX 72269833  72271626  HDAC8      K562     0.17487287  0.06351657
# 870013 chrX 73850509  73851931  XIST       K562     0.05287100  0.01226503
# 870014 chrX 74324906  74326736  JPX        K562     0.08471308  0.02704689
# 870015 chrX 74343411  74344727  FTX        K562     0.08779828  0.02005312
# 870016 chrX 74343411  74344727  JPX        K562     0.07759685  0.02491928
# 870017 chrX 79366432  79367996  ITM2A      K562     0.08765707  0.02990102
# 870018 chrX 80809265  80810388  SH3BGRL    K562     0.11339801  0.03371545
# 870019 chrX 81120662  81122542  SH3BGRL    K562     0.10446222  0.03621033
# 870020 chrX 81201511  81203302  BRWD3      K562     0.13438149  0.03805702
# 870021 chrX   989754    991253  ASMTL      K562     0.18446440  0.06143320
#        z         p            boot_basic_p boot_basic_p.log10 sign
# 1       5.078312 3.808024e-07 0.00004      4.397940            1
# 2       4.727368 2.274486e-06 0.00004      4.397940            1
# 3      -3.299616 9.681731e-04 0.00204      2.690370           -1
# 4       3.897712 9.710563e-05 0.00068      3.167491            1
# 5       3.424857 6.151242e-04 0.00044      3.356547            1
# 6       4.148969 3.339762e-05 0.00024      3.619789            1
# 7       3.758560 1.708943e-04 0.00064      3.193820            1
# 8      -5.418257 6.018291e-08 0.00004      4.397940           -1
# 9       3.828079 1.291473e-04 0.00068      3.167491            1
# 10      4.107174 4.005291e-05 0.00036      3.443697            1
# 11      6.667708 2.598295e-11 0.00004      4.397940            1
# 12      4.016000 5.919438e-05 0.00092      3.036212            1
# 13      3.725578 1.948683e-04 0.00072      3.142668            1
# 14      3.503838 4.586048e-04 0.00148      2.829738            1
# 15      5.059660 4.200055e-07 0.00004      4.397940            1
# 16      3.885730 1.020229e-04 0.00044      3.356547            1
# 17      3.959770 7.502192e-05 0.00052      3.283997            1
# 18      3.958373 7.546190e-05 0.00008      4.096910            1
# 19      3.775397 1.597531e-04 0.00064      3.193820            1
# 20      3.852781 1.167840e-04 0.00040      3.397940            1
# 21      4.590395 4.424079e-06 0.00036      3.443697            1
# 22      4.658785 3.180816e-06 0.00012      3.920819            1
# 23      4.218716 2.456977e-05 0.00056      3.251812            1
# 24      6.740157 1.582156e-11 0.00004      4.397940            1
# 25      7.726184 1.108188e-14 0.00016      3.795880            1
# 26      7.424611 1.131122e-13 0.00060      3.221849            1
# 27     14.410171 4.466054e-47 0.00004      4.397940            1
# 28     14.106588 3.459140e-45 0.00004      4.397940            1
# 29     -8.051368 8.187395e-16 0.00004      4.397940           -1
# 30      9.423730 4.353416e-21 0.00004      4.397940            1
# ⋮      ⋮         ⋮            ⋮            ⋮                  ⋮
# 869992 3.225750  1.256429e-03 0.00376      2.424812           1
# 869993 3.434549  5.935413e-04 0.00336      2.473661           1
# 869994 4.390426  1.131288e-05 0.00248      2.605548           1
# 869995 3.474375  5.120450e-04 0.00136      2.866461           1
# 869996 4.259636  2.047597e-05 0.00376      2.424812           1
# 869997 2.978355  2.898005e-03 0.00424      2.372634           1
# 869998 3.208204  1.335665e-03 0.00168      2.774691           1
# 869999 2.788222  5.299818e-03 0.00704      2.152427           1
# 870000 3.632952  2.801967e-04 0.00320      2.494850           1
# 870001 3.904381  9.446670e-05 0.00168      2.774691           1
# 870002 4.292473  1.766940e-05 0.00496      2.304518           1
# 870003 3.011706  2.597844e-03 0.00488      2.311580           1
# 870004 2.938837  3.294464e-03 0.00416      2.380907           1
# 870005 3.025472  2.482453e-03 0.00224      2.649752           1
# 870006 2.715739  6.612809e-03 0.00888      2.051587           1
# 870007 3.096112  1.960760e-03 0.00200      2.698970           1
# 870008 3.235541  1.214123e-03 0.00112      2.950782           1
# 870009 3.267496  1.085034e-03 0.00496      2.304518           1
# 870010 3.291438  9.967665e-04 0.00592      2.227678           1
# 870011 2.883887  3.928000e-03 0.00512      2.290730           1
# 870012 2.753185  5.901853e-03 0.00496      2.304518           1
# 870013 4.310712  1.627296e-05 0.00216      2.665546           1
# 870014 3.132082  1.735713e-03 0.00224      2.649752           1
# 870015 4.378286  1.196162e-05 0.00104      2.982967           1
# 870016 3.113929  1.846142e-03 0.00536      2.270835           1
# 870017 2.931574  3.372486e-03 0.00840      2.075721           1
# 870018 3.363384  7.699308e-04 0.00320      2.494850           1
# 870019 2.884873  3.915713e-03 0.00944      2.025028           1
# 870020 3.531056  4.139037e-04 0.00272      2.565431           1
# 870021 3.002683  2.676114e-03 0.00448      2.348722           1
#        boot_basic_p.log10.signed FDR
# 1       4.397940                 0.006542741
# 2       4.397940                 0.006542741
# 3      -2.690370                 0.093713651
# 4       3.167491                 0.049627907
# 5       3.356547                 0.037380064
# 6       3.619789                 0.025075662
# 7       3.193820                 0.047574627
# 8      -4.397940                 0.006542741
# 9       3.167491                 0.049627907
# 10      3.443697                 0.032779441
# 11      4.397940                 0.006542741
# 12      3.036212                 0.061509208
# 13      3.142668                 0.051582273
# 14      2.829738                 0.078860306
# 15      4.397940                 0.006542741
# 16      3.356547                 0.037380064
# 17      3.283997                 0.041616311
# 18      4.096910                 0.011343168
# 19      3.193820                 0.047574627
# 20      3.397940                 0.035092104
# 21      3.443697                 0.032779441
# 22      3.920819                 0.015335270
# 23      3.251812                 0.043590566
# 24      4.397940                 0.006542741
# 25      3.795880                 0.018898094
# 26      3.221849                 0.045594602
# 27      4.397940                 0.006542741
# 28      4.397940                 0.006542741
# 29     -4.397940                 0.006542741
# 30      4.397940                 0.006542741
# ⋮      ⋮                         ⋮
# 869992 2.424812                  0.12974572
# 869993 2.473661                  0.12186895
# 869994 2.605548                  0.10346466
# 869995 2.866461                  0.07445435
# 869996 2.424812                  0.12974572
# 869997 2.372634                  0.13819687
# 869998 2.774691                  0.08355066
# 869999 2.152427                  0.18063430
# 870000 2.494850                  0.11857186
# 870001 2.774691                  0.08355066
# 870002 2.304518                  0.15004013
# 870003 2.311580                  0.14877365
# 870004 2.380907                  0.13689199
# 870005 2.649752                  0.09792709
# 870006 2.051587                  0.20690376
# 870007 2.698970                  0.09189068
# 870008 2.950782                  0.06781901
# 870009 2.304518                  0.15004013
# 870010 2.227678                  0.16436969
# 870011 2.290730                  0.15254640
# 870012 2.304518                  0.15004013
# 870013 2.665546                  0.09596800
# 870014 2.649752                  0.09792709
# 870015 2.982967                  0.06563815
# 870016 2.270835                  0.15613595
# 870017 2.075721                  0.20007053
# 870018 2.494850                  0.11857186
# 870019 2.025028                  0.21496056
# 870020 2.565431                  0.10875762
# 870021 2.348722                  0.14224123

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4

# %%
min(df.output$boot_basic_p.log10.signed)
# Out:
# [1] -4.39794

# %%
table(df.output$boot_basic_p.log10.signed == min(df.output$boot_basic_p.log10.signed))
# Out:
#  FALSE   TRUE
# 869383    638

# %%
set.seed(2025)
df.output$boot_basic_p.log10.signed.random = df.output$boot_basic_p.log10.signed
df.output[df.output$boot_basic_p.log10.signed == max(df.output$boot_basic_p.log10.signed), "boot_basic_p.log10.signed.random"] = 
    df.output[df.output$boot_basic_p.log10.signed == max(df.output$boot_basic_p.log10.signed), "boot_basic_p.log10.signed"] * runif(sum(df.output$boot_basic_p.log10.signed == max(df.output$boot_basic_p.log10.signed)), 1, 1.01)

# %%
df.output[df.output$boot_basic_p.log10.signed == min(df.output$boot_basic_p.log10.signed), c("boot_basic_p.log10.signed", "boot_basic_p.log10.signed.random")]
# Out:
#        boot_basic_p.log10.signed boot_basic_p.log10.signed.random
# 8      -4.39794                  -4.39794
# 29     -4.39794                  -4.39794
# 36     -4.39794                  -4.39794
# 85     -4.39794                  -4.39794
# 86     -4.39794                  -4.39794
# 105    -4.39794                  -4.39794
# 128    -4.39794                  -4.39794
# 133    -4.39794                  -4.39794
# 136    -4.39794                  -4.39794
# 138    -4.39794                  -4.39794
# 157    -4.39794                  -4.39794
# 158    -4.39794                  -4.39794
# 237    -4.39794                  -4.39794
# 256    -4.39794                  -4.39794
# 260    -4.39794                  -4.39794
# 261    -4.39794                  -4.39794
# 335    -4.39794                  -4.39794
# 346    -4.39794                  -4.39794
# 380    -4.39794                  -4.39794
# 383    -4.39794                  -4.39794
# 412    -4.39794                  -4.39794
# 414    -4.39794                  -4.39794
# 422    -4.39794                  -4.39794
# 453    -4.39794                  -4.39794
# 525    -4.39794                  -4.39794
# 526    -4.39794                  -4.39794
# 530    -4.39794                  -4.39794
# 544    -4.39794                  -4.39794
# 571    -4.39794                  -4.39794
# 583    -4.39794                  -4.39794
# ⋮      ⋮                         ⋮
# 750962 -4.39794                  -4.39794
# 750978 -4.39794                  -4.39794
# 793433 -4.39794                  -4.39794
# 793439 -4.39794                  -4.39794
# 793442 -4.39794                  -4.39794
# 793444 -4.39794                  -4.39794
# 793447 -4.39794                  -4.39794
# 793448 -4.39794                  -4.39794
# 793449 -4.39794                  -4.39794
# 793480 -4.39794                  -4.39794
# 793661 -4.39794                  -4.39794
# 793664 -4.39794                  -4.39794
# 793686 -4.39794                  -4.39794
# 793699 -4.39794                  -4.39794
# 815604 -4.39794                  -4.39794
# 815613 -4.39794                  -4.39794
# 815628 -4.39794                  -4.39794
# 815634 -4.39794                  -4.39794
# 815717 -4.39794                  -4.39794
# 815776 -4.39794                  -4.39794
# 815781 -4.39794                  -4.39794
# 815788 -4.39794                  -4.39794
# 815790 -4.39794                  -4.39794
# 815791 -4.39794                  -4.39794
# 815895 -4.39794                  -4.39794
# 815914 -4.39794                  -4.39794
# 816016 -4.39794                  -4.39794
# 816044 -4.39794                  -4.39794
# 855831 -4.39794                  -4.39794
# 855854 -4.39794                  -4.39794

# %%
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.random.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta        se
# 1      chr1 108816162 108817385 SARS       K562      0.11684006 0.02300766
# 2      chr1 109150983 109151785 SARS       K562      0.12824553 0.02712831
# 3      chr1 109180698 109181961 SARS       K562     -0.06390411 0.01936714
# 4      chr1 109895498 109896712 SARS       K562      0.07578982 0.01944469
# 5      chr1 111747044 111747888 FAM212B    K562      0.32482931 0.09484465
# 6      chr1 117674269 117675205 FAM46C     K562      0.20151778 0.04857057
# 7      chr1 149237627 149238291 HIST2H2AC  K562      0.20881662 0.05555762
# 8      chr1 149885311 149886029 HIST2H2BE  K562     -0.30504933 0.05630027
# 9      chr1 149886235 149887291 HIST2H2AC  K562      0.13136990 0.03431745
# 10     chr1 150514863 150516509 HIST2H2AC  K562      0.13963129 0.03399692
# 11     chr1 150545468 150546023 HIST2H2AC  K562      0.22935426 0.03439777
# 12     chr1 150567568 150569556 HIST2H2BF  K562      0.31067539 0.07735942
# 13     chr1 150615484 150615969 HIST2H2AC  K562      0.18669160 0.05011078
# 14     chr1 155910604 155912523 RRNAD1     K562      0.12006094 0.03426555
# 15     chr1 155938229 155938422 KIAA0907   K562      0.16465677 0.03254305
# 16     chr1 156105810 156107435 KIAA0907   K562      0.06742095 0.01735091
# 17     chr1 156616013 156617326 KIAA0907   K562      0.08475387 0.02140373
# 18     chr1 156755583 156755926 KIAA0907   K562      0.10087661 0.02548436
# 19     chr1 156816671 156817213 KIAA0907   K562      0.09250884 0.02450308
# 20     chr1 156920029 156920914 KIAA0907   K562      0.07223583 0.01874901
# 21     chr1 175480819 175482013 RFWD2      K562      0.08626207 0.01879186
# 22     chr1 175757234 175758062 RFWD2      K562      0.07978856 0.01712647
# 23     chr1 176853423 176854049 RFWD2      K562      0.06875709 0.01629811
# 24     chr1 176858372 176859137 RFWD2      K562      0.10653325 0.01580575
# 25     chr1 184031200 184032083 FAM129A    K562      0.17510703 0.02266410
# 26     chr1 184491332 184492468 FAM129A    K562      0.24781736 0.03337783
# 27     chr1 184929720 184931122 FAM129A    K562      0.47912341 0.03324898
# 28     chr1 184973175 184974825 FAM129A    K562      0.29915219 0.02120656
# 29     chr1 185262858 185264777 FAM129A    K562     -0.29412115 0.03653058
# 30     chr1 185862174 185863083 FAM129A    K562      0.35739319 0.03792481
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮           ⋮
# 869992 chrX 53683285  53684785  HUWE1      K562     0.04210058  0.01305141
# 869993 chrX 54439925  54441022  PHF8       K562     0.11900443  0.03464922
# 869994 chrX 54529545  54531406  ALAS2      K562     0.15581051  0.03548870
# 869995 chrX 55480020  55481333  GNL3L      K562     0.08675610  0.02497028
# 869996 chrX 55717281  55718501  ALAS2      K562     0.16944389  0.03977896
# 869997 chrX 55717281  55718501  UBQLN2     K562     0.12594665  0.04228733
# 869998 chrX 65697825  65698728  LAS1L      K562     0.11172777  0.03482564
# 869999 chrX 66008553  66009108  LAS1L      K562     0.09692332  0.03476169
# 870000 chrX 66009220  66009749  MSN        K562     0.06914938  0.01903394
# 870001 chrX 66021480  66023656  MSN        K562     0.06797215  0.01740920
# 870002 chrX 66046003  66047933  HEPH       K562     0.10454376  0.02435514
# 870003 chrX 70454262  70455897  IGBP1      K562     0.09269408  0.03077794
# 870004 chrX 70454262  70455897  ZMYM3      K562     0.13412631  0.04563925
# 870005 chrX 70969484  70970910  ZMYM3      K562     0.18322365  0.06056035
# 870006 chrX 71067420  71068957  GCNA       K562     0.20727916  0.07632515
# 870007 chrX 71102755  71104118  PDZD11     K562     0.16723186  0.05401350
# 870008 chrX 71145553  71147270  ZMYM3      K562     0.16313310  0.05041910
# 870009 chrX 71532122  71534552  TAF1       K562     0.05694039  0.01742631
# 870010 chrX 72018159  72019193  TAF1       K562     0.06490511  0.01971938
# 870011 chrX 72131530  72132528  ZMYM3      K562     0.20793985  0.07210403
# 870012 chrX 72269833  72271626  HDAC8      K562     0.17487287  0.06351657
# 870013 chrX 73850509  73851931  XIST       K562     0.05287100  0.01226503
# 870014 chrX 74324906  74326736  JPX        K562     0.08471308  0.02704689
# 870015 chrX 74343411  74344727  FTX        K562     0.08779828  0.02005312
# 870016 chrX 74343411  74344727  JPX        K562     0.07759685  0.02491928
# 870017 chrX 79366432  79367996  ITM2A      K562     0.08765707  0.02990102
# 870018 chrX 80809265  80810388  SH3BGRL    K562     0.11339801  0.03371545
# 870019 chrX 81120662  81122542  SH3BGRL    K562     0.10446222  0.03621033
# 870020 chrX 81201511  81203302  BRWD3      K562     0.13438149  0.03805702
# 870021 chrX   989754    991253  ASMTL      K562     0.18446440  0.06143320
#        z         p            boot_basic_p boot_basic_p.log10 sign
# 1       5.078312 3.808024e-07 0.00004      4.397940            1
# 2       4.727368 2.274486e-06 0.00004      4.397940            1
# 3      -3.299616 9.681731e-04 0.00204      2.690370           -1
# 4       3.897712 9.710563e-05 0.00068      3.167491            1
# 5       3.424857 6.151242e-04 0.00044      3.356547            1
# 6       4.148969 3.339762e-05 0.00024      3.619789            1
# 7       3.758560 1.708943e-04 0.00064      3.193820            1
# 8      -5.418257 6.018291e-08 0.00004      4.397940           -1
# 9       3.828079 1.291473e-04 0.00068      3.167491            1
# 10      4.107174 4.005291e-05 0.00036      3.443697            1
# 11      6.667708 2.598295e-11 0.00004      4.397940            1
# 12      4.016000 5.919438e-05 0.00092      3.036212            1
# 13      3.725578 1.948683e-04 0.00072      3.142668            1
# 14      3.503838 4.586048e-04 0.00148      2.829738            1
# 15      5.059660 4.200055e-07 0.00004      4.397940            1
# 16      3.885730 1.020229e-04 0.00044      3.356547            1
# 17      3.959770 7.502192e-05 0.00052      3.283997            1
# 18      3.958373 7.546190e-05 0.00008      4.096910            1
# 19      3.775397 1.597531e-04 0.00064      3.193820            1
# 20      3.852781 1.167840e-04 0.00040      3.397940            1
# 21      4.590395 4.424079e-06 0.00036      3.443697            1
# 22      4.658785 3.180816e-06 0.00012      3.920819            1
# 23      4.218716 2.456977e-05 0.00056      3.251812            1
# 24      6.740157 1.582156e-11 0.00004      4.397940            1
# 25      7.726184 1.108188e-14 0.00016      3.795880            1
# 26      7.424611 1.131122e-13 0.00060      3.221849            1
# 27     14.410171 4.466054e-47 0.00004      4.397940            1
# 28     14.106588 3.459140e-45 0.00004      4.397940            1
# 29     -8.051368 8.187395e-16 0.00004      4.397940           -1
# 30      9.423730 4.353416e-21 0.00004      4.397940            1
# ⋮      ⋮         ⋮            ⋮            ⋮                  ⋮
# 869992 3.225750  1.256429e-03 0.00376      2.424812           1
# 869993 3.434549  5.935413e-04 0.00336      2.473661           1
# 869994 4.390426  1.131288e-05 0.00248      2.605548           1
# 869995 3.474375  5.120450e-04 0.00136      2.866461           1
# 869996 4.259636  2.047597e-05 0.00376      2.424812           1
# 869997 2.978355  2.898005e-03 0.00424      2.372634           1
# 869998 3.208204  1.335665e-03 0.00168      2.774691           1
# 869999 2.788222  5.299818e-03 0.00704      2.152427           1
# 870000 3.632952  2.801967e-04 0.00320      2.494850           1
# 870001 3.904381  9.446670e-05 0.00168      2.774691           1
# 870002 4.292473  1.766940e-05 0.00496      2.304518           1
# 870003 3.011706  2.597844e-03 0.00488      2.311580           1
# 870004 2.938837  3.294464e-03 0.00416      2.380907           1
# 870005 3.025472  2.482453e-03 0.00224      2.649752           1
# 870006 2.715739  6.612809e-03 0.00888      2.051587           1
# 870007 3.096112  1.960760e-03 0.00200      2.698970           1
# 870008 3.235541  1.214123e-03 0.00112      2.950782           1
# 870009 3.267496  1.085034e-03 0.00496      2.304518           1
# 870010 3.291438  9.967665e-04 0.00592      2.227678           1
# 870011 2.883887  3.928000e-03 0.00512      2.290730           1
# 870012 2.753185  5.901853e-03 0.00496      2.304518           1
# 870013 4.310712  1.627296e-05 0.00216      2.665546           1
# 870014 3.132082  1.735713e-03 0.00224      2.649752           1
# 870015 4.378286  1.196162e-05 0.00104      2.982967           1
# 870016 3.113929  1.846142e-03 0.00536      2.270835           1
# 870017 2.931574  3.372486e-03 0.00840      2.075721           1
# 870018 3.363384  7.699308e-04 0.00320      2.494850           1
# 870019 2.884873  3.915713e-03 0.00944      2.025028           1
# 870020 3.531056  4.139037e-04 0.00272      2.565431           1
# 870021 3.002683  2.676114e-03 0.00448      2.348722           1
#        boot_basic_p.log10.signed FDR         boot_basic_p.log10.signed.random
# 1       4.397940                 0.006542741  4.430160
# 2       4.397940                 0.006542741  4.418864
# 3      -2.690370                 0.093713651 -2.690370
# 4       3.167491                 0.049627907  3.167491
# 5       3.356547                 0.037380064  3.356547
# 6       3.619789                 0.025075662  3.619789
# 7       3.193820                 0.047574627  3.193820
# 8      -4.397940                 0.006542741 -4.397940
# 9       3.167491                 0.049627907  3.167491
# 10      3.443697                 0.032779441  3.443697
# 11      4.397940                 0.006542741  4.420555
# 12      3.036212                 0.061509208  3.036212
# 13      3.142668                 0.051582273  3.142668
# 14      2.829738                 0.078860306  2.829738
# 15      4.397940                 0.006542741  4.419861
# 16      3.356547                 0.037380064  3.356547
# 17      3.283997                 0.041616311  3.283997
# 18      4.096910                 0.011343168  4.096910
# 19      3.193820                 0.047574627  3.193820
# 20      3.397940                 0.035092104  3.397940
# 21      3.443697                 0.032779441  3.443697
# 22      3.920819                 0.015335270  3.920819
# 23      3.251812                 0.043590566  3.251812
# 24      4.397940                 0.006542741  4.432256
# 25      3.795880                 0.018898094  3.795880
# 26      3.221849                 0.045594602  3.221849
# 27      4.397940                 0.006542741  4.420117
# 28      4.397940                 0.006542741  4.437451
# 29     -4.397940                 0.006542741 -4.397940
# 30      4.397940                 0.006542741  4.403563
# ⋮      ⋮                         ⋮           ⋮
# 869992 2.424812                  0.12974572  2.424812
# 869993 2.473661                  0.12186895  2.473661
# 869994 2.605548                  0.10346466  2.605548
# 869995 2.866461                  0.07445435  2.866461
# 869996 2.424812                  0.12974572  2.424812
# 869997 2.372634                  0.13819687  2.372634
# 869998 2.774691                  0.08355066  2.774691
# 869999 2.152427                  0.18063430  2.152427
# 870000 2.494850                  0.11857186  2.494850
# 870001 2.774691                  0.08355066  2.774691
# 870002 2.304518                  0.15004013  2.304518
# 870003 2.311580                  0.14877365  2.311580
# 870004 2.380907                  0.13689199  2.380907
# 870005 2.649752                  0.09792709  2.649752
# 870006 2.051587                  0.20690376  2.051587
# 870007 2.698970                  0.09189068  2.698970
# 870008 2.950782                  0.06781901  2.950782
# 870009 2.304518                  0.15004013  2.304518
# 870010 2.227678                  0.16436969  2.227678
# 870011 2.290730                  0.15254640  2.290730
# 870012 2.304518                  0.15004013  2.304518
# 870013 2.665546                  0.09596800  2.665546
# 870014 2.649752                  0.09792709  2.649752
# 870015 2.982967                  0.06563815  2.982967
# 870016 2.270835                  0.15613595  2.270835
# 870017 2.075721                  0.20007053  2.075721
# 870018 2.494850                  0.11857186  2.494850
# 870019 2.025028                  0.21496056  2.025028
# 870020 2.565431                  0.10875762  2.565431
# 870021 2.348722                  0.14224123  2.348722
