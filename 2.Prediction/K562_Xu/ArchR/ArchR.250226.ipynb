# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR_250226/ArchR_250226/"

# %%
inputFiles = c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/atac_fragments.tsv.gz")
names(inputFiles) = c("K562_Xu")

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger"| __truncated__
#   .. ..@ hash : chr [1:2] "c8366071805c37835af9f47f43ae7435" "af5268737bf82cc3e7978e6407c893ea"
#   .. ..@ cells: Named chr [1:7821] "AAACAGCCAAGCGATG-1" "AAACAGCCACATGCTA-1" "AAACAGCCACGGTACT-1" "AAACAGCCATAAAGCA-1" ...
#   .. .. ..- attr(*, "names")= chr [1:7821] "K562_Xu_AAACAGCCAAGCGATG-1" "K562_Xu_AAACAGCCACATGCTA-1" "K562_Xu_AAACAGCCACGGTACT-1" "K562_Xu_AAACAGCCATAAAGCA-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Xu"),
  validBarcodes = list(K562_Xu = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-29e71b59ad4ca4-Date-2025-02-26_Time-13-32-01.140829.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2025-02-26 13:32:01.569983 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Xu : 1 of 1) Determining Arrow Method to use!
#
# 2025-02-26 13:32:01.633727 : (K562_Xu : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.001 mins elapsed.
#
# 2025-02-26 13:32:01.644588 : (K562_Xu : 1 of 1) Tabix Bed To Temporary File, 0.001 mins elapsed.
#
# 2025-02-26 13:33:57.453146 : (K562_Xu : 1 of 1) Successful creation of Temporary File, 1.931 mins elapsed.
#
# 2025-02-26 13:33:57.46188 : (K562_Xu : 1 of 1) Creating ArrowFile From Temporary File, 1.932 mins elapsed.
#
# 2025-02-26 13:34:35.317216 : (K562_Xu : 1 of 1) Successful creation of Arrow File, 2.562 mins elapsed.
#
# 2025-02-26 13:35:21.15107 : Continuing through after error ggplot for Fragment Size Distribution, 3.326 mins elapsed.
#
#
#
#
# 2025-02-26 13:35:53.825384 : (K562_Xu : 1 of 1) CellStats : Number of Cells Pass Filter = 7699 , 3.871 mins elapsed.
#
# 2025-02-26 13:35:53.829247 : (K562_Xu : 1 of 1) CellStats : Median Frags = 31472 , 3.871 mins elapsed.
#
# 2025-02-26 13:35:53.834211 : (K562_Xu : 1 of 1) CellStats : Median TSS Enrichment = 9.17 , 3.871 mins elapsed.
#
# 2025-02-26 13:35:54.755789 : Continuing through after error ggplot for TSS by Frags, 3.886 mins elapsed.
#
#
#
#
# 2025-02-26 13:35:57.336609 : (K562_Xu : 1 of 1) Adding Additional Feature Counts!, 3.929 mins elapsed.
#
# 2025-02-26 13:36:24.112168 : (K562_Xu : 1 of 1) Removing Fragments from Filtered Cells, 4.376 mins elapsed.
#
# 2025-02-26 13:36:24.121519 : (K562_Xu : 1 of 1) Creating Filtered Arrow File, 4.376 mins elapsed.
#
# 2025-02-26 13:38:22.012406 : (K562_Xu : 1 of 1) Finished Constructing Filtered Arrow File!, 6.341 mins elapsed.
#
# 2025-02-26 13:38:22.206577 : (K562_Xu : 1 of 1) Adding TileMatrix!, 6.344 mins elapsed.
#
# 2025-02-26 13:47:58.55422 : (K562_Xu : 1 of 1) Finished Creating Arrow File, 15.95 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-29e71b59ad4ca4-Date-2025-02-26_Time-13-32-01.140829.log

# %%
ArrowFiles
# Out:
# [1] "K562_Xu.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR_250226/ArchR_250226/ArchR
# samples(1): K562_Xu
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 7699
# medianTSS(1): 9.17
# medianFrags(1): 31472

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-29e71b60652919-Date-2025-02-26_Time-13-48-12.167445.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 13:48:12.6913 : Computing Total Across All Features, 0 mins elapsed.
#
# 2025-02-26 13:48:13.629304 : Computing Top Features, 0.016 mins elapsed.
#
# ###########
# 2025-02-26 13:48:16.674102 : Running LSI (1 of 2) on Top Features, 0.067 mins elapsed.
# ###########
#
# 2025-02-26 13:48:16.688989 : Creating Partial Matrix, 0.067 mins elapsed.
#
# 2025-02-26 13:48:57.385737 : Computing LSI, 0.745 mins elapsed.
#
# 2025-02-26 13:49:58.707984 : Identifying Clusters, 1.767 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2025-02-26 13:50:06.67247 : Identified 6 Clusters, 1.9 mins elapsed.
#
# 2025-02-26 13:50:06.686766 : Saving LSI Iteration, 1.9 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2025-02-26 13:50:21.717164 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-29e71b60652919-Date-2025-02-26_Time-13-48-12.167445.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2025-02-26 13:50:21.720224 : Creating Cluster Matrix on the total Group Features, 2.151 mins elapsed.
#
# 2025-02-26 13:50:44.123919 : Computing Variable Features, 2.524 mins elapsed.
#
# ###########
# 2025-02-26 13:50:44.332517 : Running LSI (2 of 2) on Variable Features, 2.528 mins elapsed.
# ###########
#
# 2025-02-26 13:50:44.349766 : Creating Partial Matrix, 2.528 mins elapsed.
#
# 2025-02-26 13:51:15.491405 : Computing LSI, 3.047 mins elapsed.
#
# 2025-02-26 13:51:59.072084 : Finished Running IterativeLSI, 3.773 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-29e71b21129653-Date-2025-02-26_Time-13-52-02.21826.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 13:52:02.512289 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 13:52:03.726298 : Adding K562_Xu to PeakMatrix for Chr (1 of 23)!, 0.019 mins elapsed.
#
# 2025-02-26 13:52:24.774975 : Adding K562_Xu to PeakMatrix for Chr (2 of 23)!, 0.37 mins elapsed.
#
# 2025-02-26 13:52:37.187572 : Adding K562_Xu to PeakMatrix for Chr (3 of 23)!, 0.577 mins elapsed.
#
# 2025-02-26 13:52:49.231514 : Adding K562_Xu to PeakMatrix for Chr (4 of 23)!, 0.778 mins elapsed.
#
# 2025-02-26 13:52:57.890532 : Adding K562_Xu to PeakMatrix for Chr (5 of 23)!, 0.922 mins elapsed.
#
# 2025-02-26 13:53:07.718132 : Adding K562_Xu to PeakMatrix for Chr (6 of 23)!, 1.086 mins elapsed.
#
# 2025-02-26 13:53:20.299965 : Adding K562_Xu to PeakMatrix for Chr (7 of 23)!, 1.296 mins elapsed.
#
# 2025-02-26 13:53:32.594468 : Adding K562_Xu to PeakMatrix for Chr (8 of 23)!, 1.5 mins elapsed.
#
# 2025-02-26 13:53:41.316232 : Adding K562_Xu to PeakMatrix for Chr (9 of 23)!, 1.646 mins elapsed.
#
# 2025-02-26 13:53:50.618288 : Adding K562_Xu to PeakMatrix for Chr (10 of 23)!, 1.801 mins elapsed.
#
# 2025-02-26 13:54:00.455773 : Adding K562_Xu to PeakMatrix for Chr (11 of 23)!, 1.965 mins elapsed.
#
# 2025-02-26 13:54:11.800082 : Adding K562_Xu to PeakMatrix for Chr (12 of 23)!, 2.154 mins elapsed.
#
# 2025-02-26 13:54:21.53926 : Adding K562_Xu to PeakMatrix for Chr (13 of 23)!, 2.316 mins elapsed.
#
# 2025-02-26 13:54:27.930806 : Adding K562_Xu to PeakMatrix for Chr (14 of 23)!, 2.423 mins elapsed.
#
# 2025-02-26 13:54:35.42848 : Adding K562_Xu to PeakMatrix for Chr (15 of 23)!, 2.548 mins elapsed.
#
# 2025-02-26 13:54:44.424733 : Adding K562_Xu to PeakMatrix for Chr (16 of 23)!, 2.698 mins elapsed.
#
# 2025-02-26 13:54:53.912621 : Adding K562_Xu to PeakMatrix for Chr (17 of 23)!, 2.856 mins elapsed.
#
# 2025-02-26 13:55:04.387863 : Adding K562_Xu to PeakMatrix for Chr (18 of 23)!, 3.03 mins elapsed.
#
# 2025-02-26 13:55:11.051249 : Adding K562_Xu to PeakMatrix for Chr (19 of 23)!, 3.141 mins elapsed.
#
# 2025-02-26 13:55:23.279206 : Adding K562_Xu to PeakMatrix for Chr (20 of 23)!, 3.345 mins elapsed.
#
# 2025-02-26 13:55:30.968552 : Adding K562_Xu to PeakMatrix for Chr (21 of 23)!, 3.473 mins elapsed.
#
# 2025-02-26 13:55:37.316509 : Adding K562_Xu to PeakMatrix for Chr (22 of 23)!, 3.579 mins elapsed.
#
# 2025-02-26 13:55:45.453896 : Adding K562_Xu to PeakMatrix for Chr (23 of 23)!, 3.715 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-29e71b21129653-Date-2025-02-26_Time-13-52-02.21826.log

# %%
seRNA = import10xFeatureMatrix(c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5"),
                               c("K562_Xu"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
    library(dplyr)
    library(data.table)
    
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
seRNA.rename = map_gene_names(seRNA,gene_gtf_path, abc_genes_path)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:Biostrings’:
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
seRNA.rename
# Out:
# class: RangedSummarizedExperiment
# dim: 20532 7699
# metadata(0):
# assays(1): counts
# rownames(20532): FAM138A OR4F5 ... FAM231B PRODH
# rowData names(5): feature_type genome id interval name
# colnames(7699): K562_Xu#GTCATGCCAGGATGGC-1 K562_Xu#TATCGCGAGGTTAGAG-1
#   ... K562_Xu#CGTGTTACAGTCTATG-1 K562_Xu#AAGTGAAGTTGCCTCA-1
# colData names(0):

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA.rename,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-29e71b30d20752-Date-2025-02-26_Time-14-00-11.767381.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2025-02-26 14:02:24.845948 : Adding K562_Xu to GeneExpressionMatrix for Chr (22 of 23)!, 2.155 mins elapsed.
#
# 2025-02-26 14:02:30.094731 : Adding K562_Xu to GeneExpressionMatrix for Chr (23 of 23)!, 2.243 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-29e71b30d20752-Date-2025-02-26_Time-14-00-11.767381.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-29e71b2fb6054e-Date-2025-02-26_Time-14-02-37.506703.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 14:02:37.906859 : Getting Available Matrices, 0.007 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2025-02-26 14:02:38.248078 : Filtered Low Prediction Score Cells (0 of 7699, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2025-02-26 14:02:38.335571 : Computing KNN, 0.002 mins elapsed.
#
# 2025-02-26 14:02:38.670088 : Identifying Non-Overlapping KNN pairs, 0.007 mins elapsed.
#
# 2025-02-26 14:02:40.301665 : Identified 494 Groupings!, 0.035 mins elapsed.
#
# 2025-02-26 14:02:40.349501 : Getting Group RNA Matrix, 0.035 mins elapsed.
#
# 2025-02-26 14:02:58.447593 : Getting Group ATAC Matrix, 0.337 mins elapsed.
#
# 2025-02-26 14:03:29.133093 : Normalizing Group Matrices, 0.848 mins elapsed.
#
# 2025-02-26 14:03:36.012158 : Finding Peak Gene Pairings, 0.963 mins elapsed.
#
# 2025-02-26 14:03:37.165642 : Computing Correlations, 0.982 mins elapsed.
#
# 2025-02-26 14:03:52.930975 : Completed Peak2Gene Correlations!, 1.245 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-29e71b2fb6054e-Date-2025-02-26_Time-14-02-37.506703.log

# %%
execution_time
# Out:
# Time difference of 1.25748 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 3921433 rows and 7 columns
#                                 idxATAC    idxRNA Correlation         FDR
#                               <integer> <integer>   <numeric>   <numeric>
# chr1-9926-10618_FAM138A               1         1         NaN         NaN
# chr1-15894-16509_FAM138A              2         1         NaN         NaN
# chr1-17271-17713_FAM138A              3         1         NaN         NaN
# chr1-29230-29495_FAM138A              4         1         NaN         NaN
# chr1-115493-115961_FAM138A            5         1         NaN         NaN
# ...                                 ...       ...         ...         ...
# chrX-156009722-156010137_IL9R    157596     20493   0.0787222 0.141580666
# chrX-156016191-156016823_IL9R    157597     20493   0.0747140 0.165590419
# chrX-156019811-156020191_IL9R    157598     20493   0.0323247 0.585302269
# chrX-156025028-156025591_IL9R    157599     20493  -0.1003445 0.054041307
# chrX-156030021-156030865_IL9R    157600     20493   0.1683037 0.000643542
#                                VarQATAC   VarQRNA               PairName
#                               <numeric> <numeric>            <character>
# chr1-9926-10618_FAM138A        0.780032 0.0597765 chr1-9926-10618_FAM1..
# chr1-15894-16509_FAM138A       0.274651 0.0597765 chr1-15894-16509_FAM..
# chr1-17271-17713_FAM138A       0.338503 0.0597765 chr1-17271-17713_FAM..
# chr1-29230-29495_FAM138A       0.222716 0.0597765 chr1-29230-29495_FAM..
# chr1-115493-115961_FAM138A     0.843997 0.0597765 chr1-115493-115961_F..
# ...                                 ...       ...                    ...
# chrX-156009722-156010137_IL9R 0.0590863  0.349485 chrX-156009722-15601..
# chrX-156016191-156016823_IL9R 0.5508439  0.349485 chrX-156016191-15601..
# chrX-156019811-156020191_IL9R 0.1883376  0.349485 chrX-156019811-15602..
# chrX-156025028-156025591_IL9R 0.4855330  0.349485 chrX-156025028-15602..
# chrX-156030021-156030865_IL9R 0.8127475  0.349485 chrX-156030021-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 3138687 ranges and 7 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * | APITD1-CORT
#         [2]     chr1 10001196-10001745      * |       CASZ1
#         [3]     chr1 10001196-10001745      * |       CENPS
#         [4]     chr1 10001196-10001745      * |      CLSTN1
#         [5]     chr1 10001196-10001745      * |        CORT
#         ...      ...               ...    ... .         ...
#   [3138683]     chrX     989754-991253      * |     SLC25A6
#   [3138684]     chrX   9995827-9996208      * |       CLCN4
#   [3138685]     chrX   9995827-9996208      * |       FAM9B
#   [3138686]     chrX   9995827-9996208      * |       TBL1X
#   [3138687]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..  0.00775952  0.905464
#         [2] chr1-10001196-10001745 chr1-10001196-100017.. -0.06787976  0.212933
#         [3] chr1-10001196-10001745 chr1-10001196-100017.. -0.05437093  0.330969
#         [4] chr1-10001196-10001745 chr1-10001196-100017.. -0.00856967  0.895217
#         [5] chr1-10001196-10001745 chr1-10001196-100017..  0.02389720  0.694848
#         ...                    ...                    ...         ...       ...
#   [3138683]     chrX-989754-991253 chrX-989754-991253_S.. -0.13882537 0.0057679
#   [3138684]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02470933 0.6841444
#   [3138685]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.05067681 0.3687553
#   [3138686]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.00962123 0.8818629
#   [3138687]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03551510 0.5448640
#              VarQATAC   VarQRNA
#             <numeric> <numeric>
#         [1]  0.121796  0.403894
#         [2]  0.121796  0.403064
#         [3]  0.121796  0.533792
#         [4]  0.121796  0.664959
#         [5]  0.121796  0.188796
#         ...       ...       ...
#   [3138683]  0.913065  0.828234
#   [3138684]  0.339911  0.425365
#   [3138685]  0.339911  0.426146
#   [3138686]  0.339911  0.917142
#   [3138687]  0.339911  0.461231
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 3138687 ranges and 7 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * | APITD1-CORT
#         [2]     chr1 10001196-10001745      * |       CASZ1
#         [3]     chr1 10001196-10001745      * |       CENPS
#         [4]     chr1 10001196-10001745      * |      CLSTN1
#         [5]     chr1 10001196-10001745      * |        CORT
#         ...      ...               ...    ... .         ...
#   [3138683]     chrX     989754-991253      * |     SLC25A6
#   [3138684]     chrX   9995827-9996208      * |       CLCN4
#   [3138685]     chrX   9995827-9996208      * |       FAM9B
#   [3138686]     chrX   9995827-9996208      * |       TBL1X
#   [3138687]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..  0.00775952  0.905464
#         [2] chr1-10001196-10001745 chr1-10001196-100017.. -0.06787976  0.212933
#         [3] chr1-10001196-10001745 chr1-10001196-100017.. -0.05437093  0.330969
#         [4] chr1-10001196-10001745 chr1-10001196-100017.. -0.00856967  0.895217
#         [5] chr1-10001196-10001745 chr1-10001196-100017..  0.02389720  0.694848
#         ...                    ...                    ...         ...       ...
#   [3138683]     chrX-989754-991253 chrX-989754-991253_S.. -0.13882537 0.0057679
#   [3138684]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02470933 0.6841444
#   [3138685]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.05067681 0.3687553
#   [3138686]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.00962123 0.8818629
#   [3138687]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03551510 0.5448640
# 3138662 4.775212e-03 0.4712373 0.4253648
# 3138663 5.324533e-01 0.4712373 0.4261455
# 3138664 6.888422e-07 0.4712373 0.9171424
# 3138665 7.644783e-01 0.4712373 0.4612307
# 3138666 5.521721e-02 0.1015990 0.4253648
# 3138667 3.061945e-05 0.1015990 0.4261455
# 3138668 9.866563e-01 0.1015990 0.9171424
# 3138669 9.659557e-01 0.1015990 0.4612307
# 3138670 4.137481e-01 0.3171320 0.4253648
# 3138671 1.370903e-01 0.3171320 0.4261455
# 3138672 3.658880e-01 0.3171320 0.9171424
# 3138673 9.769148e-01 0.3171320 0.4612307
# 3138674 4.758354e-05 0.9130647 0.7429366
# 3138675 3.087044e-01 0.9130647 0.2353487
# 3138676 1.313708e-01 0.9130647 0.5432587
# 3138677 2.923763e-04 0.9130647 0.5998634
# 3138678 5.877578e-02 0.9130647 0.3884741
# 3138679 3.859967e-01 0.9130647 0.5148099
# 3138680 7.630134e-02 0.9130647 0.4362465
# 3138681 1.492249e-05 0.9130647 0.7567950
# 3138682 4.908143e-01 0.9130647 0.5489679
# 3138683 5.767899e-03 0.9130647 0.8282340
# 3138684 6.841444e-01 0.3399112 0.4253648
# 3138685 3.687553e-01 0.3399112 0.4261455
# 3138686 8.818629e-01 0.3399112 0.9171424
# 3138687 5.448640e-01 0.3399112 0.4612307

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       dplyr_1.1.4
#  [3] uwot_0.1.16                       Rsamtools_2.18.0
#  [5] BSgenome.Hsapiens.UCSC.hg38_1.4.5 BSgenome_1.68.0
#  [7] rtracklayer_1.60.1                Biostrings_2.70.1
#  [9] XVector_0.42.0                    genomation_1.34.0
# [11] Signac_1.13.0                     Seurat_5.0.3
# [13] SeuratObject_5.0.1                sp_2.1-4
# [15] rhdf5_2.44.0                      SummarizedExperiment_1.30.2
# [17] Biobase_2.60.0                    MatrixGenerics_1.12.3
# [19] Rcpp_1.0.12                       Matrix_1.6-5
# [21] GenomicRanges_1.54.1              GenomeInfoDb_1.38.1
# [23] IRanges_2.36.0                    S4Vectors_0.40.2
# [25] BiocGenerics_0.48.1               matrixStats_1.3.0
# [27] data.table_1.15.2                 stringr_1.5.1
# [29] plyr_1.8.9                        magrittr_2.0.3
# [31] ggplot2_3.5.1                     gtable_0.3.5
# [33] gtools_3.9.5                      gridExtra_2.3
# [35] ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            withr_3.0.0              fastmap_1.1.1
#  [61] rhdf5filters_1.12.1      fansi_1.0.6              digest_0.6.35
#  [64] R6_2.5.1                 mime_0.12                seqPattern_1.34.0
#  [67] colorspace_2.1-0         Cairo_1.6-2              scattermore_1.2
#  [70] tensor_1.5               spatstat.data_3.0-4      utf8_1.2.4
#  [73] tidyr_1.3.1              generics_0.1.3           httr_1.4.7
#  [76] htmlwidgets_1.6.4        S4Arrays_1.2.1           pkgconfig_2.0.3
#  [79] impute_1.76.0            lmtest_0.9-40            htmltools_0.5.8.1
#  [82] dotCall64_1.1-1          scales_1.3.0             png_0.1-8
#  [85] tzdb_0.4.0               reshape2_1.4.4           rjson_0.2.21
#  [88] uuid_1.2-0               nlme_3.1-164             repr_1.1.7
#  [91] zoo_1.8-12               KernSmooth_2.23-22       miniUI_0.1.1.1
#  [94] restfulr_0.0.15          pillar_1.9.0             vctrs_0.6.5
#  [97] RANN_2.6.1               promises_1.3.0           xtable_1.8-4
# [100] cluster_2.1.6            evaluate_0.23            readr_2.1.5
# [103] cli_3.6.2                compiler_4.3.3           rlang_1.1.3
# [106] crayon_1.5.2             future.apply_1.11.2      labeling_0.4.3
# [109] stringi_1.8.3            gridBase_0.4-7           viridisLite_0.4.2
# [112] deldir_2.0-4             BiocParallel_1.36.0      munsell_0.5.1
# [115] lazyeval_0.2.2           spatstat.geom_3.2-9      IRkernel_1.3.2
# [118] RcppHNSW_0.6.0           hms_1.1.3                patchwork_1.2.0
# [121] bit64_4.0.5              future_1.33.2            Rhdf5lib_1.22.1
# [124] shiny_1.8.1.1            ROCR_1.0-11              igraph_2.0.3
# [127] fastmatch_1.1-4          bit_4.0.5
