# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR.default/ArchR.240527/"

# %%
inputFiles = c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/atac_fragments.tsv.gz")
names(inputFiles) = c("K562_Xu")

# %%
addArchRThreads(threads = 16) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger"| __truncated__
#   .. ..@ hash : chr [1:2] "c8366071805c37835af9f47f43ae7435" "af5268737bf82cc3e7978e6407c893ea"
#   .. ..@ cells: Named chr [1:7821] "AAACAGCCAAGCGATG-1" "AAACAGCCACATGCTA-1" "AAACAGCCACGGTACT-1" "AAACAGCCATAAAGCA-1" ...
#   .. .. ..- attr(*, "names")= chr [1:7821] "K562_Xu_AAACAGCCAAGCGATG-1" "K562_Xu_AAACAGCCACATGCTA-1" "K562_Xu_AAACAGCCACGGTACT-1" "K562_Xu_AAACAGCCATAAAGCA-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Xu"),
  validBarcodes = list(K562_Xu = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-39e262470de58a-Date-2024-05-28_Time-14-51-00.797534.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2024-05-28 14:51:01.275971 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Xu : 1 of 1) Checking if completed file exists!
#
# 2024-05-28 14:51:01.358354 : (K562_Xu : 1 of 1) Arrow Exists! Overriding since force = TRUE!, 0.001 mins elapsed.
#
# (K562_Xu : 1 of 1) Determining Arrow Method to use!
#
# 2024-05-28 14:51:01.828817 : (K562_Xu : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.009 mins elapsed.
#
# 2024-05-28 14:51:01.861661 : (K562_Xu : 1 of 1) Tabix Bed To Temporary File, 0.01 mins elapsed.
#
# 2024-05-28 14:54:00.394591 : (K562_Xu : 1 of 1) Successful creation of Temporary File, 2.985 mins elapsed.
#
# 2024-05-28 14:54:00.401868 : (K562_Xu : 1 of 1) Creating ArrowFile From Temporary File, 2.985 mins elapsed.
#
# 2024-05-28 14:55:16.445302 : (K562_Xu : 1 of 1) Successful creation of Arrow File, 4.253 mins elapsed.
#
# 2024-05-28 14:56:43.144852 : Continuing through after error ggplot for Fragment Size Distribution, 5.698 mins elapsed.
#
#
#
#
# 2024-05-28 14:57:43.406486 : (K562_Xu : 1 of 1) CellStats : Number of Cells Pass Filter = 7699 , 6.702 mins elapsed.
#
# 2024-05-28 14:57:43.485018 : (K562_Xu : 1 of 1) CellStats : Median Frags = 31472 , 6.703 mins elapsed.
#
# 2024-05-28 14:57:43.548291 : (K562_Xu : 1 of 1) CellStats : Median TSS Enrichment = 9.17 , 6.705 mins elapsed.
#
# 2024-05-28 14:57:45.033253 : Continuing through after error ggplot for TSS by Frags, 6.729 mins elapsed.
#
#
#
#
# 2024-05-28 14:57:49.987933 : (K562_Xu : 1 of 1) Adding Additional Feature Counts!, 6.812 mins elapsed.
#
# 2024-05-28 14:58:42.49617 : (K562_Xu : 1 of 1) Removing Fragments from Filtered Cells, 7.687 mins elapsed.
#
# 2024-05-28 14:58:42.567262 : (K562_Xu : 1 of 1) Creating Filtered Arrow File, 7.688 mins elapsed.
#
# 2024-05-28 15:03:07.393065 : (K562_Xu : 1 of 1) Finished Constructing Filtered Arrow File!, 12.102 mins elapsed.
#
# 2024-05-28 15:03:07.682491 : (K562_Xu : 1 of 1) Adding TileMatrix!, 12.107 mins elapsed.
#
# 2024-05-28 15:21:18.764004 : (K562_Xu : 1 of 1) Finished Creating Arrow File, 30.291 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-39e262470de58a-Date-2024-05-28_Time-14-51-00.797534.log

# %%
ArrowFiles
# Out:
# [1] "K562_Xu.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "ArchR", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR.default/ArchR.240527//ArchR' already exists”

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR.default/ArchR.240527/ArchR
# samples(1): K562_Xu
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 7699
# medianTSS(1): 9.17
# medianFrags(1): 31472

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-39e2627e115f74-Date-2024-05-28_Time-15-22-58.681947.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 15:23:02.051269 : Computing Total Across All Features, 0 mins elapsed.
#
# 2024-05-28 15:23:03.577944 : Computing Top Features, 0.026 mins elapsed.
#
# ###########
# 2024-05-28 15:23:07.588073 : Running LSI (1 of 2) on Top Features, 0.093 mins elapsed.
# ###########
#
# 2024-05-28 15:23:07.780427 : Creating Partial Matrix, 0.096 mins elapsed.
#
# 2024-05-28 15:24:21.249403 : Computing LSI, 1.32 mins elapsed.
#
# 2024-05-28 15:25:32.176691 : Identifying Clusters, 2.502 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2024-05-28 15:25:40.521417 : Identified 6 Clusters, 2.642 mins elapsed.
#
# 2024-05-28 15:25:40.537863 : Saving LSI Iteration, 2.642 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2024-05-28 15:25:57.797042 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-39e2627e115f74-Date-2024-05-28_Time-15-22-58.681947.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2024-05-28 15:25:57.798995 : Creating Cluster Matrix on the total Group Features, 2.929 mins elapsed.
#
# 2024-05-28 15:26:17.996476 : Computing Variable Features, 3.266 mins elapsed.
#
# ###########
# 2024-05-28 15:26:18.213938 : Running LSI (2 of 2) on Variable Features, 3.27 mins elapsed.
# ###########
#
# 2024-05-28 15:26:18.248077 : Creating Partial Matrix, 3.27 mins elapsed.
#
# 2024-05-28 15:26:59.178197 : Computing LSI, 3.952 mins elapsed.
#
# 2024-05-28 15:28:08.514776 : Finished Running IterativeLSI, 5.108 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-39e2627de49e39-Date-2024-05-28_Time-15-28-12.271766.log
# If there is an issue, please report to github with logFile!
#
maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5"),
                               c("K562_Xu"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61218 7699
# metadata(0):
# assays(1): counts
# rownames(61218): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(7699): K562_Xu#GTCATGCCAGGATGGC-1 K562_Xu#TATCGCGAGGTTAGAG-1
#   ... K562_Xu#CGTGTTACAGTCTATG-1 K562_Xu#AAGTGAAGTTGCCTCA-1
# colData names(0):

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-39e26263d3997b-Date-2024-05-28_Time-16-41-44.571219.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2024-05-28 16:41:45.358279 :
#
# Overlap Per Sample w/ scATAC : K562_Xu=7699
#
# 2024-05-28 16:41:45.386049 :
#
# 2024-05-28 16:41:51.230783 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# .createArrowGroup : Arrow Group already exists! Dropping Group from ArrowFile! This will take ~10-30 seconds!
#
# .dropGroupsFromArrow : Initializing Temp ArrowFile
#
# .dropGroupsFromArrow : Adding Metadata to Temp ArrowFile
#
# .dropGroupsFromArrow : Adding SubGroups to Temp ArrowFile
#
# .dropGroupsFromArrow : Move Temp ArrowFile to ArrowFile
#
# 2024-05-28 16:44:54.946196 : Adding K562_Xu to GeneExpressionMatrix for Chr (1 of 23)!, 3.062 mins elapsed.
#
# 2024-05-28 16:45:12.257698 : Adding K562_Xu to GeneExpressionMatrix for Chr (2 of 23)!, 3.35 mins elapsed.
#
# 2024-05-28 16:45:28.872474 : Adding K562_Xu to GeneExpressionMatrix for Chr (3 of 23)!, 3.627 mins elapsed.
#
# 2024-05-28 16:45:53.647895 : Adding K562_Xu to GeneExpressionMatrix for Chr (4 of 23)!, 4.04 mins elapsed.
#
# 2024-05-28 16:46:06.280585 : Adding K562_Xu to GeneExpressionMatrix for Chr (5 of 23)!, 4.251 mins elapsed.
#
# 2024-05-28 16:46:22.330844 : Adding K562_Xu to GeneExpressionMatrix for Chr (6 of 23)!, 4.518 mins elapsed.
#
# 2024-05-28 16:46:45.006752 : Adding K562_Xu to GeneExpressionMatrix for Chr (7 of 23)!, 4.896 mins elapsed.
#
# 2024-05-28 16:46:58.877172 : Adding K562_Xu to GeneExpressionMatrix for Chr (8 of 23)!, 5.127 mins elapsed.
#
# 2024-05-28 16:47:14.325395 : Adding K562_Xu to GeneExpressionMatrix for Chr (9 of 23)!, 5.385 mins elapsed.
#
# 2024-05-28 16:47:45.175625 : Adding K562_Xu to GeneExpressionMatrix for Chr (10 of 23)!, 5.899 mins elapsed.
#
# 2024-05-28 16:47:56.330261 : Adding K562_Xu to GeneExpressionMatrix for Chr (11 of 23)!, 6.085 mins elapsed.
#
# 2024-05-28 16:48:20.187584 : Adding K562_Xu to GeneExpressionMatrix for Chr (12 of 23)!, 6.483 mins elapsed.
#
# 2024-05-28 16:48:46.563616 : Adding K562_Xu to GeneExpressionMatrix for Chr (13 of 23)!, 6.922 mins elapsed.
#
# 2024-05-28 16:49:03.478917 : Adding K562_Xu to GeneExpressionMatrix for Chr (14 of 23)!, 7.204 mins elapsed.
#
# 2024-05-28 16:49:17.385377 : Adding K562_Xu to GeneExpressionMatrix for Chr (15 of 23)!, 7.436 mins elapsed.
#
# 2024-05-28 16:49:34.037653 : Adding K562_Xu to GeneExpressionMatrix for Chr (16 of 23)!, 7.713 mins elapsed.
#
# 2024-05-28 16:49:45.952056 : Adding K562_Xu to GeneExpressionMatrix for Chr (17 of 23)!, 7.912 mins elapsed.
#
# 2024-05-28 16:49:56.797148 : Adding K562_Xu to GeneExpressionMatrix for Chr (18 of 23)!, 8.093 mins elapsed.
#
# 2024-05-28 16:50:32.626876 : Adding K562_Xu to GeneExpressionMatrix for Chr (19 of 23)!, 8.69 mins elapsed.
#
# 2024-05-28 16:51:01.694375 : Adding K562_Xu to GeneExpressionMatrix for Chr (20 of 23)!, 9.174 mins elapsed.
#
# 2024-05-28 16:51:14.301415 : Adding K562_Xu to GeneExpressionMatrix for Chr (21 of 23)!, 9.385 mins elapsed.
#
# 2024-05-28 16:51:44.049985 : Adding K562_Xu to GeneExpressionMatrix for Chr (22 of 23)!, 9.88 mins elapsed.
#
# 2024-05-28 16:51:58.828759 : Adding K562_Xu to GeneExpressionMatrix for Chr (23 of 23)!, 10.127 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-39e26263d3997b-Date-2024-05-28_Time-16-41-44.571219.log
#
# Overriding previous entry for Gex_nUMI
#
# Overriding previous entry for Gex_nGenes
#
# Overriding previous entry for Gex_MitoRatio
#
# Overriding previous entry for Gex_RiboRatio

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = 250000,
    threads = 16
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-39e26278689ab-Date-2024-05-28_Time-16-52-37.371029.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 16:52:38.962151 : Getting Available Matrices, 0.026 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2024-05-28 16:52:40.740787 : Filtered Low Prediction Score Cells (0 of 7699, 0), 0.001 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2024-05-28 16:52:40.971346 : Computing KNN, 0.004 mins elapsed.
#
# 2024-05-28 16:52:41.42568 : Identifying Non-Overlapping KNN pairs, 0.012 mins elapsed.
#
# 2024-05-28 16:52:42.903592 : Identified 494 Groupings!, 0.037 mins elapsed.
#
# 2024-05-28 16:52:42.945241 : Getting Group RNA Matrix, 0.037 mins elapsed.
#
# 2024-05-28 16:53:19.785754 : Getting Group ATAC Matrix, 0.651 mins elapsed.
#
# 2024-05-28 16:53:55.147325 : Normalizing Group Matrices, 1.241 mins elapsed.
#
# 2024-05-28 16:54:01.134168 : Finding Peak Gene Pairings, 1.34 mins elapsed.
#
# 2024-05-28 16:54:01.713531 : Computing Correlations, 1.35 mins elapsed.
#
# 2024-05-28 16:54:24.916283 : Completed Peak2Gene Correlations!, 1.737 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-39e26278689ab-Date-2024-05-28_Time-16-52-37.371029.log

# %%
execution_time
# Out:
# Time difference of 1.793499 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 2709966 rows and 7 columns
#                                   idxATAC    idxRNA Correlation         FDR
#                                 <integer> <integer>   <numeric>   <numeric>
# chr1-9926-10618_DDX11L1                 1         1         NaN         NaN
# chr1-15894-16509_DDX11L1                2         1         NaN         NaN
# chr1-17271-17713_DDX11L1                3         1         NaN         NaN
# chr1-29230-29495_DDX11L1                4         1         NaN         NaN
# chr1-115493-115961_DDX11L1              5         1         NaN         NaN
# ...                                   ...       ...         ...         ...
# chrX-156009722-156010137_WASH6P    157596     60641  -0.0416448 5.01059e-01
# chrX-156016191-156016823_WASH6P    157597     60641   0.2302423 2.08369e-06
# chrX-156019811-156020191_WASH6P    157598     60641  -0.2207281 6.00086e-06
# chrX-156025028-156025591_WASH6P    157599     60641  -0.1801910 3.13860e-04
# chrX-156030021-156030865_WASH6P    157600     60641  -0.0141601 8.38876e-01
#                                  VarQATAC   VarQRNA               PairName
#                                 <numeric> <numeric>            <character>
# chr1-9926-10618_DDX11L1          0.780032  0.203179 chr1-9926-10618_DDX1..
# chr1-15894-16509_DDX11L1         0.274651  0.203179 chr1-15894-16509_DDX..
# chr1-17271-17713_DDX11L1         0.338503  0.203179 chr1-17271-17713_DDX..
# chr1-29230-29495_DDX11L1         0.222716  0.203179 chr1-29230-29495_DDX..
# chr1-115493-115961_DDX11L1       0.843997  0.203179 chr1-115493-115961_D..
# ...                                   ...       ...                    ...
# chrX-156009722-156010137_WASH6P 0.0590863  0.836563 chrX-156009722-15601..
# chrX-156016191-156016823_WASH6P 0.5508439  0.836563 chrX-156016191-15601..
# chrX-156019811-156020191_WASH6P 0.1883376  0.836563 chrX-156019811-15602..
# chrX-156025028-156025591_WASH6P 0.4855330  0.836563 chrX-156025028-15602..
# chrX-156030021-156030865_WASH6P 0.8127475  0.836563 chrX-156030021-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 892525 ranges and 7 metadata columns:
#            seqnames            ranges strand |  TargetGene
#               <Rle>         <IRanges>  <Rle> | <character>
#        [1]     chr1 10001196-10001745      * |      CLSTN1
#        [2]     chr1 10001196-10001745      * |    CTNNBIP1
#        [3]     chr1 10001196-10001745      * |       KIF1B
#        [4]     chr1 10001196-10001745      * |        LZIC
#        [5]     chr1 10001196-10001745      * |      NMNAT1
#        ...      ...               ...    ... .         ...
#   [892521]     chrX   9882635-9883318      * |        WWC3
#   [892522]     chrX   9885160-9885475      * |        WWC3
#   [892523]     chrX   9894484-9895274      * |        WWC3
#   [892524]     chrX   9995827-9996208      * |       CLCN4
#   [892525]     chrX   9995827-9996208      * |        WWC3
#                          PeakName               PairName  Correlation
#                       <character>            <character>    <numeric>
#        [1] chr1-10001196-10001745 chr1-10001196-100017..  -0.01429462
#        [2] chr1-10001196-10001745 chr1-10001196-100017..   0.10649691
#        [3] chr1-10001196-10001745 chr1-10001196-100017..  -0.09108861
#        [4] chr1-10001196-10001745 chr1-10001196-100017..  -0.15954638
#        [5] chr1-10001196-10001745 chr1-10001196-100017..   0.00432288
#        ...                    ...                    ...          ...
#   [892521]   chrX-9882635-9883318 chrX-9882635-9883318..  0.018211821
#   [892522]   chrX-9885160-9885475 chrX-9885160-9885475..  0.000889438
#   [892523]   chrX-9894484-9895274 chrX-9894484-9895274..  0.001486225
#   [892524]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.022997327
#   [892525]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.033836087
#                   FDR  VarQATAC   VarQRNA
#             <numeric> <numeric> <numeric>
#        [1] 0.83725029  0.121796  0.876024
#        [2] 0.04768304  0.121796  0.886562
#        [3] 0.09800407  0.121796  0.949193
#        [4] 0.00168475  0.121796  0.897264
#        [5] 0.95337532  0.121796  0.893422
#        ...        ...       ...       ...
#   [892521]   0.789318  0.471237  0.778549
#   [892522]   0.990654  0.101599  0.778549
#   [892523]   0.984310  0.317132  0.778549
#   [892524]   0.729840  0.339911  0.749641
#   [892525]   0.595158  0.339911  0.778549
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 892525 ranges and 7 metadata columns:
#            seqnames            ranges strand |  TargetGene
#               <Rle>         <IRanges>  <Rle> | <character>
#        [1]     chr1 10001196-10001745      * |      CLSTN1
#        [2]     chr1 10001196-10001745      * |    CTNNBIP1
#        [3]     chr1 10001196-10001745      * |       KIF1B
#        [4]     chr1 10001196-10001745      * |        LZIC
#        [5]     chr1 10001196-10001745      * |      NMNAT1
#        ...      ...               ...    ... .         ...
#   [892521]     chrX   9882635-9883318      * |        WWC3
#   [892522]     chrX   9885160-9885475      * |        WWC3
#   [892523]     chrX   9894484-9895274      * |        WWC3
#   [892524]     chrX   9995827-9996208      * |       CLCN4
#   [892525]     chrX   9995827-9996208      * |        WWC3
#                          PeakName               PairName  Correlation
#                       <character>            <character>    <numeric>
#        [1] chr1-10001196-10001745 chr1-10001196-100017..  -0.01429462
#        [2] chr1-10001196-10001745 chr1-10001196-100017..   0.10649691
#        [3] chr1-10001196-10001745 chr1-10001196-100017..  -0.09108861
#        [4] chr1-10001196-10001745 chr1-10001196-100017..  -0.15954638
#        [5] chr1-10001196-10001745 chr1-10001196-100017..   0.00432288
#        ...                    ...                    ...          ...
#   [892521]   chrX-9882635-9883318 chrX-9882635-9883318..  0.018211821
#   [892522]   chrX-9885160-9885475 chrX-9885160-9885475..  0.000889438
#   [892523]   chrX-9894484-9895274 chrX-9894484-9895274..  0.001486225
#   [892524]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.022997327
#   [892525]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.033836087
#                   FDR  VarQATAC   VarQRNA
#             <numeric> <numeric> <numeric>
#        [1] 0.83725029  0.121796  0.876024
#        [2] 0.04768304  0.121796  0.886562
#        [3] 0.09800407  0.121796  0.949193
#        [4] 0.00168475  0.121796  0.897264
#        [5] 0.95337532  0.121796  0.893422
#        ...        ...       ...       ...
#   [892521]   0.789318  0.471237  0.778549
#   [892522]   0.990654  0.101599  0.778549
#   [892523]   0.984310  0.317132  0.778549
#   [892524]   0.729840  0.339911  0.749641
#   [892525]   0.595158  0.339911  0.778549
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqleng
# 892502 0.763521574 0.9693277
# 892503 0.035831218 0.9693277
# 892504 0.433432741 0.9693277
# 892505 0.036357868 0.9693277
# 892506 0.029961929 0.9693277
# 892507 0.037906091 0.9693277
# 892508 0.007722081 0.9693277
# 892509 0.584714467 0.9693277
# 892510 0.032595178 0.9693277
# 892511 0.003826142 0.9693277
# 892512 0.037290609 0.9693277
# 892513 0.048115482 0.9693277
# 892514 0.536230964 0.9693277
# 892515 0.089638325 0.9693277
# 892516 0.149505076 0.9693277
# 892517 0.659003807 0.9693277
# 892518 0.377214467 0.7785492
# 892519 0.270717005 0.7785492
# 892520 0.274917513 0.7785492
# 892521 0.471237310 0.7785492
# 892522 0.101598985 0.7785492
# 892523 0.317131980 0.7785492
# 892524 0.339911168 0.7496413
# 892525 0.339911168 0.7785492

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       uwot_0.1.16
#  [3] Rsamtools_2.18.0                  BSgenome.Hsapiens.UCSC.hg38_1.4.5
#  [5] BSgenome_1.68.0                   rtracklayer_1.60.1
#  [7] Biostrings_2.70.1                 XVector_0.42.0
#  [9] genomation_1.34.0                 Signac_1.13.0
# [11] Seurat_5.0.3                      SeuratObject_5.0.1
# [13] sp_2.1-4                          rhdf5_2.44.0
# [15] SummarizedExperiment_1.30.2       Biobase_2.60.0
# [17] MatrixGenerics_1.12.3             Rcpp_1.0.12
# [19] Matrix_1.6-5                      GenomicRanges_1.54.1
# [21] GenomeInfoDb_1.38.1               IRanges_2.36.0
# [23] S4Vectors_0.40.2                  BiocGenerics_0.48.1
# [25] matrixStats_1.3.0                 data.table_1.15.2
# [27] stringr_1.5.1                     plyr_1.8.9
# [29] magrittr_2.0.3                    ggplot2_3.5.1
# [31] gtable_0.3.5                      gtools_3.9.5
# [33] gridExtra_2.3                     ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22            splines_4.3.3
#   [3] later_1.3.2                 pbdZMQ_0.3-11
#   [5] BiocIO_1.10.0               bitops_1.0-7
#   [7] tibble_3.2.1                polyclip_1.10-6
#   [9] XML_3.99-0.16.1             fastDummies_1.7.3
#  [11] lifecycle_1.0.4             vroom_1.6.5
#  [13] globals_0.16.3              lattice_0.22-6
#  [15] MASS_7.3-60                 plotly_4.10.4
#  [17] plotrix_3.8-4               yaml_2.3.8
#  [19] httpuv_1.6.15               sctransform_0.4.1
#  [21] spam_2.10-0                 spatstat.sparse_3.0-3
#  [23] reticulate_1.36.1           cowplot_1.1.3
#  [25] pbapply_1.7-2               RColorBrewer_1.1-3
#  [27] abind_1.4-5                 zlibbioc_1.48.0
#  [29] Rtsne_0.17                  purrr_1.0.2
#  [31] RCurl_1.98-1.14             GenomeInfoDbData_1.2.11
#  [33] ggrepel_0.9.5               irlba_2.3.5.1
#  [35] listenv_0.9.1               spatstat.utils_3.0-4
#  [37] goftest_1.2-3               RSpectra_0.16-1
#  [39] spatstat.random_3.2-3       fitdistrplus_1.1-11
#  [41] parallelly_1.37.1           leiden_0.4.3.1
#  [43] codetools_0.2-20            DelayedArray_0.26.7
#  [45] RcppRoll_0.3.0              tidyselect_1.2.1
#  [47] farver_2.1.1                base64enc_0.1-3
#  [49] spatstat.explore_3.2-6      GenomicAlignments_1.36.0
#  [51] jsonlite_1.8.8              progressr_0.14.0
#  [53] ggridges_0.5.6              survival_3.6-4
#  [55] tools_4.3.3                 ica_1.0-3
#  [57] glue_1.7.0                  IRdisplay_1.1
#  [59] dplyr_1.1.4                 withr_3.0.0
#  [61] fastmap_1.1.1               rhdf5filters_1.12.1
#  [63] fansi_1.0.6                 digest_0.6.35
#  [65] R6_2.5.1                    mime_0.12
#  [67] seqPattern_1.34.0           colorspace_2.1-0
#  [69] Cairo_1.6-2                 scattermore_1.2
#  [71] tensor_1.5                  spatstat.data_3.0-4
#  [73] utf8_1.2.4                  tidyr_1.3.1
#  [75] generics_0.1.3              httr_1.4.7
#  [77] htmlwidgets_1.6.4           S4Arrays_1.2.1
#  [79] pkgconfig_2.0.3             impute_1.76.0
#  [81] lmtest_0.9-40               SingleCellExperiment_1.22.0
#  [83] htmltools_0.5.8.1           dotCall64_1.1-1
#  [85] scales_1.3.0                png_0.1-8
#  [87] tzdb_0.4.0                  reshape2_1.4.4
#  [89] rjson_0.2.21                uuid_1.2-0
#  [91] nlme_3.1-164                repr_1.1.7
#  [93] zoo_1.8-12                  KernSmooth_2.23-22
#  [95] miniUI_0.1.1.1              restfulr_0.0.15
#  [97] pillar_1.9.0                vctrs_0.6.5
#  [99] RANN_2.6.1                  promises_1.3.0
# [101] xtable_1.8-4                cluster_2.1.6
# [103] evaluate_0.23               readr_2.1.5
# [105] cli_3.6.2                   compiler_4.3.3
# [107] rlang_1.1.3                 crayon_1.5.2
# [109] future.apply_1.11.2         labeling_0.4.3
# [111] stringi_1.8.3               gridBase_0.4-7
# [113] viridisLite_0.4.2           deldir_2.0-4
# [115] BiocParallel_1.36.0         munsell_0.5.1
# [117] lazyeval_0.2.2              spatstat.geom_3.2-9
# [119] IRkernel_1.3.2              RcppHNSW_0.6.0
# [121] hms_1.1.3                   patchwork_1.2.0
# [123] bit64_4.0.5                 future_1.33.2
# [125] Rhdf5lib_1.22.1             shiny_1.8.1.1
# [127] ROCR_1.0-11                 igraph_2.0.3
# [129] fastmatch_1.1-4             bit_4.0.5
