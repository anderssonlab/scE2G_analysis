# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR/ArchR.240527/"

# %%
inputFiles = c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/atac_fragments.tsv.gz")
names(inputFiles) = c("K562_Xu")

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger"| __truncated__
#   .. ..@ hash : chr [1:2] "c8366071805c37835af9f47f43ae7435" "af5268737bf82cc3e7978e6407c893ea"
#   .. ..@ cells: Named chr [1:7821] "AAACAGCCAAGCGATG-1" "AAACAGCCACATGCTA-1" "AAACAGCCACGGTACT-1" "AAACAGCCATAAAGCA-1" ...
#   .. .. ..- attr(*, "names")= chr [1:7821] "K562_Xu_AAACAGCCAAGCGATG-1" "K562_Xu_AAACAGCCACATGCTA-1" "K562_Xu_AAACAGCCACGGTACT-1" "K562_Xu_AAACAGCCATAAAGCA-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Xu"),
  validBarcodes = list(K562_Xu = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-3b662a773aeaae-Date-2024-05-28_Time-18-00-29.013764.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2024-05-28 18:00:30.844397 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Xu : 1 of 1) Determining Arrow Method to use!
#
# 2024-05-28 18:00:31.0243 : (K562_Xu : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.003 mins elapsed.
#
# 2024-05-28 18:00:31.045829 : (K562_Xu : 1 of 1) Tabix Bed To Temporary File, 0.003 mins elapsed.
#
# 2024-05-28 18:03:04.780012 : (K562_Xu : 1 of 1) Successful creation of Temporary File, 2.566 mins elapsed.
#
# 2024-05-28 18:03:04.788317 : (K562_Xu : 1 of 1) Creating ArrowFile From Temporary File, 2.566 mins elapsed.
#
# 2024-05-28 18:05:29.034997 : (K562_Xu : 1 of 1) Successful creation of Arrow File, 4.97 mins elapsed.
#
# 2024-05-28 18:08:02.802891 : Continuing through after error ggplot for Fragment Size Distribution, 7.533 mins elapsed.
#
#
#
#
# 2024-05-28 18:10:05.668981 : (K562_Xu : 1 of 1) CellStats : Number of Cells Pass Filter = 7699 , 9.58 mins elapsed.
#
# 2024-05-28 18:10:05.682117 : (K562_Xu : 1 of 1) CellStats : Median Frags = 31472 , 9.581 mins elapsed.
#
# 2024-05-28 18:10:05.692547 : (K562_Xu : 1 of 1) CellStats : Median TSS Enrichment = 9.17 , 9.581 mins elapsed.
#
# 2024-05-28 18:10:06.68143 : Continuing through after error ggplot for TSS by Frags, 9.597 mins elapsed.
#
#
#
#
# 2024-05-28 18:10:09.719875 : (K562_Xu : 1 of 1) Adding Additional Feature Counts!, 9.648 mins elapsed.
#
# 2024-05-28 18:11:53.167872 : (K562_Xu : 1 of 1) Removing Fragments from Filtered Cells, 11.372 mins elapsed.
#
# 2024-05-28 18:11:53.196707 : (K562_Xu : 1 of 1) Creating Filtered Arrow File, 11.373 mins elapsed.
#
# 2024-05-28 18:15:29.905915 : (K562_Xu : 1 of 1) Finished Constructing Filtered Arrow File!, 14.984 mins elapsed.
#
# 2024-05-28 18:15:30.286379 : (K562_Xu : 1 of 1) Adding TileMatrix!, 14.991 mins elapsed.
#
# 2024-05-28 18:31:42.876489 : (K562_Xu : 1 of 1) Finished Creating Arrow File, 31.201 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-3b662a773aeaae-Date-2024-05-28_Time-18-00-29.013764.log

# %%
ArrowFiles
# Out:
# [1] "K562_Xu.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Xu/3.Genome_wide_prediction/ArchR/ArchR.240527/ArchR
# samples(1): K562_Xu
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 7699
# medianTSS(1): 9.17
# medianFrags(1): 31472

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-3b662a1f4bdac8-Date-2024-05-28_Time-18-32-09.582469.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 18:32:10.068048 : Computing Total Across All Features, 0 mins elapsed.
#
# 2024-05-28 18:32:11.820052 : Computing Top Features, 0.03 mins elapsed.
#
# ###########
# 2024-05-28 18:32:18.120699 : Running LSI (1 of 2) on Top Features, 0.135 mins elapsed.
# ###########
#
# 2024-05-28 18:32:18.159313 : Creating Partial Matrix, 0.135 mins elapsed.
#
# 2024-05-28 18:33:44.488224 : Computing LSI, 1.574 mins elapsed.
#
# 2024-05-28 18:35:31.192318 : Identifying Clusters, 3.352 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2024-05-28 18:35:43.931159 : Identified 6 Clusters, 3.565 mins elapsed.
#
# 2024-05-28 18:35:43.950799 : Saving LSI Iteration, 3.565 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2024-05-28 18:36:04.882752 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-3b662a1f4bdac8-Date-2024-05-28_Time-18-32-09.582469.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2024-05-28 18:36:04.886696 : Creating Cluster Matrix on the total Group Features, 3.914 mins elapsed.
#
# 2024-05-28 18:36:59.491176 : Computing Variable Features, 4.824 mins elapsed.
#
# ###########
# 2024-05-28 18:36:59.904193 : Running LSI (2 of 2) on Variable Features, 4.831 mins elapsed.
# ###########
#
# 2024-05-28 18:37:00.005318 : Creating Partial Matrix, 4.833 mins elapsed.
#
# 2024-05-28 18:37:44.754115 : Computing LSI, 5.578 mins elapsed.
#
# 2024-05-28 18:38:44.422413 : Finished Running IterativeLSI, 6.573 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-3b662a6af84e08-Date-2024-05-28_Time-18-38-48.287483.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 18:38:48.538016 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-05-28 18:38:49.449145 : Adding K562_Xu to PeakMatrix for Chr (1 of 23)!, 0.014 mins elapsed.
#
# 2024-05-28 18:39:15.230196 : Adding K562_Xu to PeakMatrix for Chr (2 of 23)!, 0.444 mins elapsed.
#
# 2024-05-28 18:39:33.416366 : Adding K562_Xu to PeakMatrix for Chr (3 of 23)!, 0.747 mins elapsed.
#
# 2024-05-28 18:39:53.07897 : Adding K562_Xu to PeakMatrix for Chr (4 of 23)!, 1.075 mins elapsed.
#
# 2024-05-28 18:40:04.780922 : Adding K562_Xu to PeakMatrix for Chr (5 of 23)!, 1.27 mins elapsed.
#
# 2024-05-28 18:40:23.681061 : Adding K562_Xu to PeakMatrix for Chr (6 of 23)!, 1.585 mins elapsed.
#
# 2024-05-28 18:40:37.404209 : Adding K562_Xu to PeakMatrix for Chr (7 of 23)!, 1.814 mins elapsed.
#
# 2024-05-28 18:40:50.741004 : Adding K562_Xu to PeakMatrix for Chr (8 of 23)!, 2.036 mins elapsed.
#
# 2024-05-28 18:41:01.424525 : Adding K562_Xu to PeakMatrix for Chr (9 of 23)!, 2.214 mins elapsed.
#
# 2024-05-28 18:41:10.155818 : Adding K562_Xu to PeakMatrix for Chr (10 of 23)!, 2.36 mins elapsed.
#
# 2024-05-28 18:41:19.512117 : Adding K562_Xu to PeakMatrix for Chr (11 of 23)!, 2.515 mins elapsed.
#
# 2024-05-28 18:41:31.698941 : Adding K562_Xu to PeakMatrix for Chr (12 of 23)!, 2.719 mins elapsed.
#
# 2024-05-28 18:41:43.985138 : Adding K562_Xu to PeakMatrix for Chr (13 of 23)!, 2.923 mins elapsed.
#
# 2024-05-28 18:41:52.046577 : Adding K562_Xu to PeakMatrix for Chr (14 of 23)!, 3.058 mins elapsed.
#
# 2024-05-28 18:41:59.043661 : Adding K562_Xu to PeakMatrix for Chr (15 of 23)!, 3.174 mins elapsed.
#
# 2024-05-28 18:42:13.940694 : Adding K562_Xu to PeakMatrix for Chr (16 of 23)!, 3.423 mins elapsed.
#
# 2024-05-28 18:42:28.448273 : Adding K562_Xu to PeakMatrix for Chr (17 of 23)!, 3.664 mins elapsed.
#
# 2024-05-28 18:42:49.259033 : Adding K562_Xu to PeakMatrix for Chr (18 of 23)!, 4.011 mins elapsed.
#
# 2024-05-28 18:43:05.695093 : Adding K562_Xu to PeakMatrix for Chr (19 of 23)!, 4.285 mins elapsed.
#
# 2024-05-28 18:43:24.572832 : Adding K562_Xu to PeakMatrix for Chr (20 of 23)!, 4.6 mins elapsed.
#
# 2024-05-28 18:43:44.616844 : Adding K562_Xu to PeakMatrix for Chr (21 of 23)!, 4.934 mins elapsed.
#
# 2024-05-28 18:44:03.350682 : Adding K562_Xu to PeakMatrix for Chr (22 of 23)!, 5.246 mins elapsed.
#
# 2024-05-28 18:44:43.872446 : Adding K562_Xu to PeakMatrix for Chr (23 of 23)!, 5.921 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-3b662a6af84e08-Date-2024-05-28_Time-18-38-48.287483.log

# %%
seRNA = import10xFeatureMatrix(c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/ArrayExpress/cellranger_res/EMTAB11264_01/outs/filtered_feature_bc_matrix.h5"),
                               c("K562_Xu"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61218 7699
# metadata(0):
# assays(1): counts
# rownames(61218): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(7699): K562_Xu#GTCATGCCAGGATGGC-1 K562_Xu#TATCGCGAGGTTAGAG-1
#   ... K562_Xu#CGTGTTACAGTCTATG-1 K562_Xu#AAGTGAAGTTGCCTCA-1
# colData names(0):

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-3b662a59f8de55-Date-2024-05-28_Time-18-45-56.070928.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2024-05-28 18:45:56.911419 :
#
# Overlap Per Sample w/ scATAC : K562_Xu=7699
#
# 2024-05-28 18:45:56.945461 :
#
# 2024-05-28 18:46:00.266815 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-05-28 18:46:27.755891 : Adding K562_Xu to GeneExpressionMatrix for Chr (1 of 23)!, 0.458 mins elapsed.
#
# 2024-05-28 18:46:46.122029 : Adding K562_Xu to GeneExpressionMatrix for Chr (2 of 23)!, 0.764 mins elapsed.
#
# 2024-05-28 18:46:59.748849 : Adding K562_Xu to GeneExpressionMatrix for Chr (3 of 23)!, 0.991 mins elapsed.
#
# 2024-05-28 18:47:15.241353 : Adding K562_Xu to GeneExpressionMatrix for Chr (4 of 23)!, 1.25 mins elapsed.
#
# 2024-05-28 18:47:28.502854 : Adding K562_Xu to GeneExpressionMatrix for Chr (5 of 23)!, 1.471 mins elapsed.
#
# 2024-05-28 18:47:41.3796 : Adding K562_Xu to GeneExpressionMatrix for Chr (6 of 23)!, 1.685 mins elapsed.
#
# 2024-05-28 18:48:00.24584 : Adding K562_Xu to GeneExpressionMatrix for Chr (7 of 23)!, 2 mins elapsed.
#
# 2024-05-28 18:48:09.036305 : Adding K562_Xu to GeneExpressionMatrix for Chr (8 of 23)!, 2.146 mins elapsed.
#
# 2024-05-28 18:48:16.777535 : Adding K562_Xu to GeneExpressionMatrix for Chr (9 of 23)!, 2.275 mins elapsed.
#
# 2024-05-28 18:48:29.521862 : Adding K562_Xu to GeneExpressionMatrix for Chr (10 of 23)!, 2.488 mins elapsed.
#
# 2024-05-28 18:48:39.193469 : Adding K562_Xu to GeneExpressionMatrix for Chr (11 of 23)!, 2.649 mins elapsed.
#
# 2024-05-28 18:48:58.332867 : Adding K562_Xu to GeneExpressionMatrix for Chr (12 of 23)!, 2.968 mins elapsed.
#
# 2024-05-28 18:49:19.796741 : Adding K562_Xu to GeneExpressionMatrix for Chr (13 of 23)!, 3.325 mins elapsed.
#
# 2024-05-28 18:49:38.886208 : Adding K562_Xu to GeneExpressionMatrix for Chr (14 of 23)!, 3.644 mins elapsed.
#
# 2024-05-28 18:49:55.12443 : Adding K562_Xu to GeneExpressionMatrix for Chr (15 of 23)!, 3.914 mins elapsed.
#
# 2024-05-28 18:50:20.957884 : Adding K562_Xu to GeneExpressionMatrix for Chr (16 of 23)!, 4.345 mins elapsed.
#
# 2024-05-28 18:50:37.530018 : Adding K562_Xu to GeneExpressionMatrix for Chr (17 of 23)!, 4.621 mins elapsed.
#
# 2024-05-28 18:50:50.585563 : Adding K562_Xu to GeneExpressionMatrix for Chr (18 of 23)!, 4.839 mins elapsed.
#
# 2024-05-28 18:51:08.444664 : Adding K562_Xu to GeneExpressionMatrix for Chr (19 of 23)!, 5.136 mins elapsed.
#
# 2024-05-28 18:51:18.541656 : Adding K562_Xu to GeneExpressionMatrix for Chr (20 of 23)!, 5.305 mins elapsed.
#
# 2024-05-28 18:51:43.132144 : Adding K562_Xu to GeneExpressionMatrix for Chr (21 of 23)!, 5.714 mins elapsed.
#
# 2024-05-28 18:52:01.968357 : Adding K562_Xu to GeneExpressionMatrix for Chr (22 of 23)!, 6.028 mins elapsed.
#
# 2024-05-28 18:52:14.556628 : Adding K562_Xu to GeneExpressionMatrix for Chr (23 of 23)!, 6.238 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-3b662a59f8de55-Date-2024-05-28_Time-18-45-56.070928.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-3b662a656f85f-Date-2024-05-28_Time-18-52-34.064537.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 18:52:34.631982 : Getting Available Matrices, 0.009 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2024-05-28 18:52:35.253044 : Filtered Low Prediction Score Cells (0 of 7699, 0), 0.001 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2024-05-28 18:52:35.491454 : Computing KNN, 0.005 mins elapsed.
#
# 2024-05-28 18:52:35.980255 : Identifying Non-Overlapping KNN pairs, 0.013 mins elapsed.
#
# 2024-05-28 18:52:38.329468 : Identified 494 Groupings!, 0.052 mins elapsed.
#
# 2024-05-28 18:52:38.432373 : Getting Group RNA Matrix, 0.054 mins elapsed.
#
# 2024-05-28 18:53:23.782464 : Getting Group ATAC Matrix, 0.809 mins elapsed.
#
# 2024-05-28 18:54:33.00566 : Normalizing Group Matrices, 1.963 mins elapsed.
#
# 2024-05-28 18:54:45.855913 : Finding Peak Gene Pairings, 2.177 mins elapsed.
#
# 2024-05-28 18:54:49.327536 : Computing Correlations, 2.235 mins elapsed.
#
# 2024-05-28 18:56:01.698934 : Completed Peak2Gene Correlations!, 3.441 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-3b662a656f85f-Date-2024-05-28_Time-18-52-34.064537.log

# %%
execution_time
# Out:
# Time difference of 3.46107 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 9876067 rows and 7 columns
#                                   idxATAC    idxRNA Correlation         FDR
#                                 <integer> <integer>   <numeric>   <numeric>
# chr1-9926-10618_DDX11L1                 1         1         NaN         NaN
# chr1-15894-16509_DDX11L1                2         1         NaN         NaN
# chr1-17271-17713_DDX11L1                3         1         NaN         NaN
# chr1-29230-29495_DDX11L1                4         1         NaN         NaN
# chr1-115493-115961_DDX11L1              5         1         NaN         NaN
# ...                                   ...       ...         ...         ...
# chrX-156009722-156010137_WASH6P    157596     60641  -0.0416448 5.04688e-01
# chrX-156016191-156016823_WASH6P    157597     60641   0.2302423 2.21833e-06
# chrX-156019811-156020191_WASH6P    157598     60641  -0.2207281 6.37419e-06
# chrX-156025028-156025591_WASH6P    157599     60641  -0.1801910 3.28380e-04
# chrX-156030021-156030865_WASH6P    157600     60641  -0.0141601 8.40555e-01
#                                  VarQATAC   VarQRNA               PairName
#                                 <numeric> <numeric>            <character>
# chr1-9926-10618_DDX11L1          0.780032  0.203179 chr1-9926-10618_DDX1..
# chr1-15894-16509_DDX11L1         0.274651  0.203179 chr1-15894-16509_DDX..
# chr1-17271-17713_DDX11L1         0.338503  0.203179 chr1-17271-17713_DDX..
# chr1-29230-29495_DDX11L1         0.222716  0.203179 chr1-29230-29495_DDX..
# chr1-115493-115961_DDX11L1       0.843997  0.203179 chr1-115493-115961_D..
# ...                                   ...       ...                    ...
# chrX-156009722-156010137_WASH6P 0.0590863  0.836563 chrX-156009722-15601..
# chrX-156016191-156016823_WASH6P 0.5508439  0.836563 chrX-156016191-15601..
# chrX-156019811-156020191_WASH6P 0.1883376  0.836563 chrX-156019811-15602..
# chrX-156025028-156025591_WASH6P 0.4855330  0.836563 chrX-156025028-15602..
# chrX-156030021-156030865_WASH6P 0.8127475  0.836563 chrX-156030021-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 3002582 ranges and 7 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * |       CASZ1
#         [2]     chr1 10001196-10001745      * |       CENPS
#         [3]     chr1 10001196-10001745      * |      CLSTN1
#         [4]     chr1 10001196-10001745      * |        CORT
#         [5]     chr1 10001196-10001745      * |    CTNNBIP1
#         ...      ...               ...    ... .         ...
#   [3002578]     chrX     989754-991253      * |     SLC25A6
#   [3002579]     chrX   9995827-9996208      * |       CLCN4
#   [3002580]     chrX   9995827-9996208      * |       FAM9B
#   [3002581]     chrX   9995827-9996208      * |       TBL1X
#   [3002582]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..  -0.0688178 0.2342858
#         [2] chr1-10001196-10001745 chr1-10001196-100017..  -0.0591818 0.3176981
#         [3] chr1-10001196-10001745 chr1-10001196-100017..  -0.0142946 0.8389428
#         [4] chr1-10001196-10001745 chr1-10001196-100017..   0.0225982 0.7373946
#         [5] chr1-10001196-10001745 chr1-10001196-100017..   0.1064969 0.0488003
#         ...                    ...                    ...         ...       ...
#   [3002578]     chrX-989754-991253 chrX-989754-991253_S.. -0.13363601 0.0105597
#   [3002579]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02299733 0.7324224
#   [3002580]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.04910040 0.4202742
#   [3002581]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.00676037 0.9268247
#   [3002582]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03383609 0.5984289
#              VarQATAC   VarQRNA
#             <numeric> <numeric>
#         [1]  0.121796  0.731980
#         [2]  0.121796  0.823898
#         [3]  0.121796  0.876024
#         [4]  0.121796  0.504032
#         [5]  0.121796  0.886562
#         ...       ...       ...
#   [3002578]  0.913065  0.939991
#   [3002579]  0.339911  0.749641
#   [3002580]  0.339911  0.749889
#   [3002581]  0.339911  0.969328
#   [3002582]  0.339911  0.778549
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 3002582 ranges and 7 metadata columns:
#             seqnames            ranges strand |  TargetGene
#                <Rle>         <IRanges>  <Rle> | <character>
#         [1]     chr1 10001196-10001745      * |       CASZ1
#         [2]     chr1 10001196-10001745      * |       CENPS
#         [3]     chr1 10001196-10001745      * |      CLSTN1
#         [4]     chr1 10001196-10001745      * |        CORT
#         [5]     chr1 10001196-10001745      * |    CTNNBIP1
#         ...      ...               ...    ... .         ...
#   [3002578]     chrX     989754-991253      * |     SLC25A6
#   [3002579]     chrX   9995827-9996208      * |       CLCN4
#   [3002580]     chrX   9995827-9996208      * |       FAM9B
#   [3002581]     chrX   9995827-9996208      * |       TBL1X
#   [3002582]     chrX   9995827-9996208      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-10001196-10001745 chr1-10001196-100017..  -0.0688178 0.2342858
#         [2] chr1-10001196-10001745 chr1-10001196-100017..  -0.0591818 0.3176981
#         [3] chr1-10001196-10001745 chr1-10001196-100017..  -0.0142946 0.8389428
#         [4] chr1-10001196-10001745 chr1-10001196-100017..   0.0225982 0.7373946
#         [5] chr1-10001196-10001745 chr1-10001196-100017..   0.1064969 0.0488003
#         ...                    ...                    ...         ...       ...
#   [3002578]     chrX-989754-991253 chrX-989754-991253_S.. -0.13363601 0.0105597
#   [3002579]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.02299733 0.7324224
#   [3002580]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.04910040 0.4202742
#   [3002581]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.00676037 0.9268247
#   [3002582]   chrX-9995827-9996208 chrX-9995827-9996208.. -0.03383609 0.5984289
#              VarQATAC   VarQRNA
#             <numeric> <numeric>
#         [1]  0.121796  0.731980
#         [2]  0.121796  0.823898
#         [3]  0.121796  0.876024
#         [4]  0.121796  0.504032
#         [5]  0.121796  0.886562
#         ...       ...       ...
#   [3002578]  0.913065  0.939991
#   [3002579]  0.339911  0.749641
#   [3002580]  0.339911  0.749889
#   [3002581]  0.339911  0.969328
#   [3002582]  0.339911  0.778549
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType Correlation  FDR
# 1       chr1  10001196  10001745 CASZ1      K562     -0.068817825 2.342858e-01
# 2       chr1  10001196  10001745 CENPS      K562     -0.059181759 3.176981e-01
# 3       chr1  10001196  10001745 CLSTN1     K562     -0.014294621 8.389428e-01
# 4       chr1  10001196  10001745 CORT       K562      0.022598211 7.373946e-01
# 5       chr1  10001196  10001745 CTNNBIP1   K562      0.106496908 4.880034e-02
# 6       chr1  10001196  10001745 DFFA       K562      0.042422951 4.956171e-01
# 7       chr1  10001196  10001745 GPR157     K562     -0.086858309 1.194156e-01
# 8       chr1  10001196  10001745 H6PD       K562     -0.001196727 9.875187e-01
# 9       chr1  10001196  10001745 KIF1B      K562     -0.091088613 9.991567e-02
# 10      chr1  10001196  10001745 LZIC       K562     -0.159546378 1.751884e-03
# 11      chr1  10001196  10001745 MIR34AHG   K562     -0.007502661 9.184881e-01
# 12      chr1  10001196  10001745 NMNAT1     K562      0.004322878 9.539125e-01
# 13      chr1  10001196  10001745 PEX14      K562      0.056137342 3.471481e-01
# 14      chr1  10001196  10001745 PGD        K562      0.147430356 4.228699e-03
# 15      chr1  10001196  10001745 PIK3CD     K562      0.023177187 7.301913e-01
# 16      chr1  10001196  10001745 RBP7       K562      0.054345307 3.651221e-01
# 17      chr1  10001196  10001745 SLC25A33   K562     -0.024302008 7.162644e-01
# 18      chr1  10001196  10001745 SPSB1      K562     -0.039989798 5.241425e-01
# 19      chr1  10001196  10001745 TMEM201    K562      0.117927679 2.672138e-02
# 20      chr1  10001196  10001745 UBE4B      K562      0.131352104 1.217519e-02
# 21      chr1 100027917 100029695 AGL        K562     -0.071710089 2.122271e-01
# 22      chr1 100027917 100029695 CDC14A     K562      0.165562879 1.100059e-03
# 23      chr1 100027917 100029695 DBT        K562      0.105295413 5.180491e-02
# 24      chr1 100027917 100029695 DPH5       K562      0.225681627 3.702386e-06
# 25      chr1 100027917 100029695 EXTL2      K562      0.045163313 4.640623e-01
# 26      chr1 100027917 100029695 FRRS1      K562      0.132759872 1.115553e-02
# 27      chr1 100027917 100029695 MFSD14A    K562     -0.039280627 5.325490e-01
# 28      chr1 100027917 100029695 PALMD      K562     -0.086732317 1.200354e-01
# 29      chr1 100027917 100029695 RTCA       K562     -0.304196507 1.002897e-10
# 30      chr1 100027917 100029695 RTCA-AS1   K562     -0.080362254 1.546471e-01
# ⋮       ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 3002553 chrX 9873821   9874426   CLCN4      K562      0.008607732 9.059090e-01
# 3002554 chrX 9873821   9874426   FAM9B      K562      0.133940120 1.036020e-02
# 3002555 chrX 9873821   9874426   TBL1X      K562     -0.071313833 2.151818e-01
# 3002556 chrX 9873821   9874426   WWC3       K562      0.075818343 1.833414e-01
# 3002557 chrX 9882635   9883318   CLCN4      K562      0.140994975 6.557430e-03
# 3002558 chrX 9882635   9883318   FAM9B      K562      0.035062145 5.834624e-01
# 3002559 chrX 9882635   9883318   TBL1X      K562     -0.240022031 7.110168e-07
# 3002560 chrX 9882635   9883318   WWC3       K562      0.018211821 7.914013e-01
# 3002561 chrX 9885160   9885475   CLCN4      K562      0.096051765 8.025452e-02
# 3002562 chrX 9885160   9885475   FAM9B      K562      0.198274909 6.312300e-05
# 3002563 chrX 9885160   9885475   TBL1X      K562     -0.008587374 9.061381e-01
# 3002564 chrX 9885160   9885475   WWC3       K562      0.000889438 9.907219e-01
# 3002565 chrX 9894484   9895274   CLCN4      K562      0.045057792 4.652670e-01
# 3002566 chrX 9894484   9895274   FAM9B      K562      0.077889844 1.698349e-01
# 3002567 chrX 9894484   9895274   TBL1X      K562      0.047548038 4.373081e-01
# 3002568 chrX 9894484   9895274   WWC3       K562      0.001486225 9.844592e-01
# 3002569 chrX  989754    991253   AKAP17A    K562      0.198343384 6.271041e-05
# 3002570 chrX  989754    991253   ASMT       K562     -0.055854766 3.499670e-01
# 3002571 chrX  989754    991253   ASMTL      K562      0.081405657 1.485433e-01
# 3002572 chrX  989754    991253   GTPBP6     K562      0.179360063 3.527567e-04
# 3002573 chrX  989754    991253   IL3RA      K562      0.100229073 6.617092e-02
# 3002574 chrX  989754    991253   LINC00106  K562     -0.049840911 4.122814e-01
# 3002575 chrX  989754    991253   P2RY8      K562      0.092821150 9.266667e-02
# 3002576 chrX  989754    991253   PLCXD1     K562     -0.206150916 2.913559e-05
# 3002577 chrX  989754    991253   PPP2R3B    K562      0.041693386 5.041220e-01
# 3002578 chrX  989754    991253   SLC25A6    K562     -0.133636005 1.055971e-02
# 3002579 chrX 9995827   9996208   CLCN4      K562     -0.022997327 7.324224e-01
# 3002580 chrX 9995827   9996208   FAM9B      K562     -0.049100397 4.202742e-01
# 3002581 chrX 9995827   9996208   TBL1X      K562     -0.006760366 9.268247e-01
# 3002582 chrX 9995827   9996208   WWC3       K562     -0.033836087 5.984289e-01
#         VarQATAC  VarQRNA
# 1       0.1217957 0.7319800
# 2       0.1217957 0.8238980
# 3       0.1217957 0.8760245
# 4       0.1217957 0.5040319
# 5       0.1217957 0.8865619
# 6       0.1217957 0.9596807
# 7       0.1217957 0.7258950
# 8       0.1217957 0.8682080
# 9       0.1217957 0.9491928
# 10      0.1217957 0.8972642
# 11      0.1217957 0.5276463
# 12      0.1217957 0.8934219
# 13      0.1217957 0.9486486
# 14      0.1217957 0.9643476
# 15      0.1217957 0.8606883
# 16      0.1217957 0.5669432
# 17      0.1217957 0.9398592
# 18      0.1217957 0.6957834
# 19      0.1217957 0.8681255
# 20      0.1217957 0.9400076
# 21      0.6677602 0.8960439
# 22      0.6677602 0.9602909
# 23      0.6677602 0.8848469
# 24      0.6677602 0.9318943
# 25      0.6677602 0.8973632
# 26      0.6677602 0.9345987
# 27      0.6677602 0.8022460
# 28      0.6677602 0.8149767
# 29      0.6677602 0.9110503
# 30      0.6677602 0.8555598
# ⋮       ⋮         ⋮
# 3002553 0.2749175 0.7496413
# 3002554 0.2749175 0.7498887
# 3002555 0.2749175 0.9693277
# 3002556 0.2749175 0.7785492
# 3002557 0.4712373 0.7496413
# 3002558 0.4712373 0.7498887
# 3002559 0.4712373 0.9693277
# 3002560 0.4712373 0.7785492
# 3002561 0.1015990 0.7496413
# 3002562 0.1015990 0.7498887
# 3002563 0.1015990 0.9693277
# 3002564 0.1015990 0.7785492
# 3002565 0.3171320 0.7496413
# 3002566 0.3171320 0.7498887
# 3002567 0.3171320 0.9693277
# 3002568 0.3171320 0.7785492
# 3002569 0.9130647 0.9063340
# 3002570 0.9130647 0.5596544
# 3002571 0.9130647 0.8273775
# 3002572 0.9130647 0.8530037
# 3002573 0.9130647 0.7189855
# 3002574 0.9130647 0.8129648
# 3002575 0.9130647 0.7583153
# 3002576 0.9130647 0.9113636
# 3002577 0.9130647 0.8312363
# 3002578 0.9130647 0.9399911
# 3002579 0.3399112 0.7496413
# 3002580 0.3399112 0.7498887
# 3002581 0.3399112 0.9693277
# 3002582 0.3399112 0.7785492

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       uwot_0.1.16
#  [3] Rsamtools_2.18.0                  BSgenome.Hsapiens.UCSC.hg38_1.4.5
#  [5] BSgenome_1.68.0                   rtracklayer_1.60.1
#  [7] Biostrings_2.70.1                 XVector_0.42.0
#  [9] genomation_1.34.0                 Signac_1.13.0
# [11] Seurat_5.0.3                      SeuratObject_5.0.1
# [13] sp_2.1-4                          rhdf5_2.44.0
# [15] SummarizedExperiment_1.30.2       Biobase_2.60.0
# [17] MatrixGenerics_1.12.3             Rcpp_1.0.12
# [19] Matrix_1.6-5                      GenomicRanges_1.54.1
# [21] GenomeInfoDb_1.38.1               IRanges_2.36.0
# [23] S4Vectors_0.40.2                  BiocGenerics_0.48.1
# [25] matrixStats_1.3.0                 data.table_1.15.2
# [27] stringr_1.5.1                     plyr_1.8.9
# [29] magrittr_2.0.3                    ggplot2_3.5.1
# [31] gtable_0.3.5                      gtools_3.9.5
# [33] gridExtra_2.3                     ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            dplyr_1.1.4              withr_3.0.0
#  [61] fastmap_1.1.1            rhdf5filters_1.12.1      fansi_1.0.6
#  [64] digest_0.6.35            R6_2.5.1                 mime_0.12
#  [67] seqPattern_1.34.0        colorspace_2.1-0         Cairo_1.6-2
#  [70] scattermore_1.2          tensor_1.5               spatstat.data_3.0-4
#  [73] utf8_1.2.4               tidyr_1.3.1              generics_0.1.3
#  [76] httr_1.4.7               htmlwidgets_1.6.4        S4Arrays_1.2.1
#  [79] pkgconfig_2.0.3          impute_1.76.0            lmtest_0.9-40
#  [82] htmltools_0.5.8.1        dotCall64_1.1-1          scales_1.3.0
#  [85] png_0.1-8                tzdb_0.4.0               reshape2_1.4.4
#  [88] rjson_0.2.21             uuid_1.2-0               nlme_3.1-164
#  [91] repr_1.1.7               zoo_1.8-12               KernSmooth_2.23-22
#  [94] miniUI_0.1.1.1           restfulr_0.0.15          pillar_1.9.0
#  [97] vctrs_0.6.5              RANN_2.6.1               promises_1.3.0
# [100] xtable_1.8-4             cluster_2.1.6            evaluate_0.23
# [103] readr_2.1.5              cli_3.6.2                compiler_4.3.3
# [106] rlang_1.1.3              crayon_1.5.2             future.apply_1.11.2
# [109] labeling_0.4.3           stringi_1.8.3            gridBase_0.4-7
# [112] viridisLite_0.4.2        deldir_2.0-4             BiocParallel_1.36.0
# [115] munsell_0.5.1            lazyeval_0.2.2           spatstat.geom_3.2-9
# [118] IRkernel_1.3.2           RcppHNSW_0.6.0           hms_1.1.3
# [121] patchwork_1.2.0          bit64_4.0.5              future_1.33.2
# [124] Rhdf5lib_1.22.1          shiny_1.8.1.1            ROCR_1.0-11
# [127] igraph_2.0.3             fastmatch_1.1-4          bit_4.0.5
