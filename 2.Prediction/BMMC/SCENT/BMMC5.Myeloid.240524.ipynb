# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Myeloid/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Myeloid/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Myeloid/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/Myeloid.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.240524/"

# %%
n.cores = 32

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 1M

# %%
pairs.ABC.1M = pairs.ABC[pairs.ABC$distance < 10^6]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.1M

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.1M.chr_rename = as.data.frame(pairs.ABC.1M)[,1:3]
df.pairs.ABC.1M.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.1M),
                                                mcols(pairs.ABC.1M)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.1M.chr_rename = GRanges(df.pairs.ABC.1M.chr_rename)
rm(df.pairs.ABC.1M.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.1M.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.1M.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 3057871 ranges and 3 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100037588-100039165      * |         AGL
#         [2]     chr1 100037588-100039165      * |      CDC14A
#         [3]     chr1 100037588-100039165      * |         DBT
#         [4]     chr1 100037588-100039165      * |        DPH5
#         [5]     chr1 100037588-100039165      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [3057867]     chrX     9995660-9996392      * |       TBL1X
#   [3057868]     chrX     9995660-9996392      * |        WWC3
#   [3057869]     chrX     9997010-9997973      * |       CLCN4
#   [3057870]     chrX     9997010-9997973      * |       TBL1X
#   [3057871]     chrX     9997010-9997973      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-100037588-10003.. chr1-100037588-10003..
#         [2] chr1-100037588-10003.. chr1-100037588-10003..
#         [3] chr1-100037588-10003.. chr1-100037588-10003..
#         [4] chr1-100037588-10003.. chr1-100037588-10003..
#         [5] chr1-100037588-10003.. chr1-100037588-10003..
#         ...                    ...                    ...
#   [3057867]   chrX-9995660-9996392 chrX-9995660-9996392..
#   [3057868]   chrX-9995660-9996392 chrX-9995660-9996392..
#   [3057869]   chrX-9997010-9997973 chrX-9997010-9997973..
#   [3057870]   chrX-9997010-9997973 chrX-9997010-9997973..
#   [3057871]   chrX-9997010-9997973 chrX-9997010-9997973..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_CTATGGCCATAACGGG-1 s1d1_CTATGGCCATAACGGG-1  2157  69   K562      7.676474
# s1d1_ACCACATAGGTGTCCA-1 s1d1_ACCACATAGGTGTCCA-1  2128  64   K562      7.662938
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1_TGCCGGTAGTCGCAAT-1  1920  67   K562      7.560080
# s1d1_CATCCCAGTCTTTATG-1 s1d1_CATCCCAGTCTTTATG-1  3211 127   K562      8.074338
# s1d1_TAGTGAGAGCTGCACA-1 s1d1_TAGTGAGAGCTGCACA-1  3568  85   K562      8.179760
# s1d1_CCTGTTGGTTATAGCG-1 s1d1_CCTGTTGGTTATAGCG-1  4044  42   K562      8.304990
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1_TTTAGCTTCTGGCTTC-1  2728 105   K562      7.911324
# s1d1_TGTGAAACAGGATTAA-1 s1d1_TGTGAAACAGGATTAA-1  2800  86   K562      7.937375
# s1d1_ACCAGGCTCTTGGATA-1 s1d1_ACCAGGCTCTTGGATA-1  1015  94   K562      6.922644
# s1d1_CACAGGGAGACAGGTA-1 s1d1_CACAGGGAGACAGGTA-1  3092  69   K562      8.036573
# s1d1_GCATCCTTCGCTATGG-1 s1d1_GCATCCTTCGCTATGG-1  3112  77   K562      8.043021
# s1d1_TTTAGCTTCTGGCTTC-1 0.03848974
# s1d1_TGTGAAACAGGATTAA-1 0.03071429
# s1d1_ACCAGGCTCTTGGATA-1 0.09261084
# s1d1_CACAGGGAGACAGGTA-1 0.02231565
# s1d1_GCATCCTTCGCTATGG-1 0.02474293
# s1d1_TGCTATGCAGAGGGAG-1 0.02771855
# s1d1_CCCGCAACAAAGCGCA-1 0.01793445
# s1d1_AATCTTGAGAAGCTAG-1 0.04068002
# s1d1_TTGTCCATCATTAGGC-1 0.01922141
# s1d1_TCCAGGATCCTAACGG-1 0.02870264
# s1d1_GGTATGTTCTAACCAA-1 0.02210946
# s1d1_TGGATTCAGTTTCCGC-1 0.01978566
# s1d1_TGCTTGCTCAATCTCT-1 0.03671148
# s1d1_CGATGTCCATACCCGG-1 0.01638350
# s1d1_ACGCCTAAGCGCCTTT-1 0.02843016
# s1d1_GAGTAATAGCTTAACA-1 0.02321263
# s1d1_ATTGGCTAGGGACCTC-1 0.03861643
# s1d1_CCTGTAACATTGTGCA-1 0.03223350
# s1d1_AGATGAAGTGAGGTGA-1 0.03038309
# s1d1_GTTAACGGTAGCTGGT-1 0.05891980
# s1d1_GAACACAAGTAACCAC-1 0.02018927
# s1d1_GGTGCTGGTACTTCAC-1 0.02492136
# s1d1_AGCTGCTCATTGTTGG-1 0.07798165
# s1d1_TCCAGGATCAACAAGG-1 0.02050963
# ⋮                       ⋮
# s4d9_GTTGCTGAGTAATCCA-1 0.05917577
# s4d9_AACTAGTGTTACTTCA-1 0.13608247
# s4d9_TGCTTCCAGTCCTTTG-1 0.09517241
# s4d9_AAGGATCCACAGGATG-1 0.12800447
# s4d9_TGTGCGCAGCCGCAGT-1 0.08185053
# s4d9_CCAGACTCAATCATGT-1 0.02835333
# s4d9_AGTAAGTAGTTAGAGG-1 0.10624315
# s4d9_TGCGGTTCAACAGCCT-1 0.11832061
# s4d9_GATGACTTCGCTAGTG-1 0.11084906
# s4d9_CTAGTCGAGCTATTGA-1 0.06272618
# s4d9_TTATGACCATTTAAGC-1 0.09507640
# s4d9_GTGCTCAAGCAAGATG-1 0.14856106
# s4d9_GGATATTGTGTCACGG-1 0.13317757
# s4d9_TGGCCTGCAATTATGC-1 0.10427136
# s4d9_GAGGGAGCATAACGGG-1 0.14389068
# s4d9_GGTACAAAGTTGCCTC-1 0.11372064
# s4d9_GGAAACTCATAGCTGC-1 0.11659193
# s4d9_AGAAAGGCAATGCCCG-1 0.02143260
# s4d9_CTACAACAGCGAGTAA-1 0.08268734
# s4d9_ACATTGCAGGGTCTAT-1 0.11308204
# s4d9_CTCCAACTCTAACCAA-1 0.11762972
# s4d9_CAGGGCTTCCGCCAAA-1 0.13772455
# s4d9_TAAACAGCACCTAAGC-1 0.11601085
# s4d9_TGGTCCTTCAGTGAAG-1 0.11232063
# s4d9_GGATACTTCTTACTCG-1 0.08683853
# s4d9_ACAGGAATCCGTCCAT-1 0.08165997
# s4d9_TGTGGCCAGCTGGCTA-1 0.13182674
# s4d9_CCGGTTAAGCCTGTTC-1 0.03877005
# s4d9_CAAGCTAGTCAACAAT-1 0.10757212
# s4d9_ACAGGTAAGGTTACGT-1 0.06142506

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            bs = boot::boot(df2, assoc, R = 100, formula = formula, 
                stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.240524//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  saveRDS(pairs.E2G.chr.res,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.res)
}
# Out:
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G.filter2)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 308281 ranges and 11 metadata columns:
#        seqnames              ranges strand |  TargetGene               PeakName
#           <Rle>           <IRanges>  <Rle> | <character>            <character>
#   chr1     chr1 100037588-100039165      * |      CDC14A chr1-100037588-10003..
#   chr1     chr1 100037588-100039165      * |         DBT chr1-100037588-10003..
#   chr1     chr1 100037588-100039165      * |        RTCA chr1-100037588-10003..
#   chr1     chr1 100037588-100039165      * |     SLC30A7 chr1-100037588-10003..
#   chr1     chr1 100037588-100039165      * |     SLC35A3 chr1-100037588-10003..
#    ...      ...                 ...    ... .         ...                    ...
#   chrX     chrX       989778-990654      * |   LINC00106     chrX-989778-990654
#   chrX     chrX       989778-990654      * |       P2RY8     chrX-989778-990654
#   chrX     chrX       989778-990654      * |     SLC25A6     chrX-989778-990654
#   chrX     chrX     9980873-9982164      * |       TBL1X   chrX-9980873-9982164
#   chrX     chrX     9980873-9982164      * |        WWC3   chrX-9980873-9982164
#                      PairName        beta        se         z           p
#                   <character>   <numeric> <numeric> <numeric>   <numeric>
#   chr1 chr1-100037588-10003.. -0.00655958 0.0247863 -0.264646    0.791283
#   chr1 chr1-100037588-10003.. -0.07445145 0.0686082 -1.085169    0.277847
#   chr1 chr1-100037588-10003.. -0.04302875 0.0484076 -0.888884    0.374066
#   chr1 chr1-100037588-10003.. -0.03702472 0.0321837 -1.150417    0.249972
#   chr1 chr1-100037588-10003..  0.04879445 0.0743045  0.656682    0.511385
#    ...                    ...         ...       ...       ...         ...
#   chrX chrX-989778-990654_L..   0.1363353 0.1143497   1.19227 0.233157115
#   chrX chrX-989778-990654_P..   0.0860696 0.0446429   1.92796 0.053860388
#   chrX chrX-989778-990654_S..  -0.1777632 0.0518517  -3.42830 0.000607373
#   chrX chrX-9980873-9982164..   0.0596522 0.0308013   1.93668 0.052784752
#   chrX chrX-9980873-9982164..   0.2456705 0.1066168   2.30424 0.021209285
#        boot_basic_p boot_basic_p.log10      sign boot_basic_p.log10.signed
#           <numeric>          <numeric> <numeric>                 <numeric>
#   chr1         0.70           0.154902        -1                 -0.154902
#   chr1         0.30           0.522879        -1                 -0.522879
#   chr1         0.36           0.443697        -1                 -0.443697
#   chr1         0.34           0.468521        -1                 -0.468521
#   chr1         0.46           0.337242         1                  0.337242
#    ...          ...                ...       ...                       ...
#   chrX         0.12           0.920819         1                  0.920819
#   chrX         0.16           0.795880         1                  0.795880
#   chrX         0.02           1.698970        -1                 -1.698970
#   chrX         0.18           0.744727         1                  0.744727
#   chrX         0.02           1.698970         1                  1.698970
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta         se
# 1      chr1 100037588 100039165 CDC14A     K562     -0.006559583 0.02478630
# 2      chr1 100037588 100039165 DBT        K562     -0.074451450 0.06860818
# 3      chr1 100037588 100039165 RTCA       K562     -0.043028752 0.04840762
# 4      chr1 100037588 100039165 SLC30A7    K562     -0.037024716 0.03218372
# 5      chr1 100037588 100039165 SLC35A3    K562      0.048794453 0.07430455
# 6      chr1 100037588 100039165 TRMT13     K562      0.010845128 0.06453342
# 7      chr1 100046194 100047249 CDC14A     K562     -0.052390027 0.04442907
# 8      chr1 100046194 100047249 DBT        K562     -0.193258829 0.12938392
# 9      chr1 100046194 100047249 RTCA       K562      0.063717924 0.08233341
# 10     chr1 100046194 100047249 SLC30A7    K562     -0.066800541 0.05784502
# 11     chr1 100046194 100047249 SLC35A3    K562     -0.289409320 0.14899701
# 12     chr1 100046194 100047249 TRMT13     K562     -0.235851276 0.12623067
# 13     chr1 100132371 100133496 CDC14A     K562     -0.003262439 0.02542932
# 308265  2.04891643 4.047029e-02 0.20         0.69897000          1
# 308266  0.17488911 8.611668e-01 0.82         0.08618615          1
# 308267 -0.93635654 3.490896e-01 0.68         0.16749109         -1
# 308268  4.14637312 3.377832e-05 0.02         1.69897000          1
# 308269  1.22082661 2.221517e-01 0.36         0.44369750          1
# 308270  0.73528642 4.621651e-01 0.52         0.28399666          1
# 308271 -0.11058285 9.119471e-01 0.94         0.02687215         -1
# 308272  0.39181793 6.951927e-01 0.66         0.18045606          1
# 308273  1.35856617 1.742841e-01 0.12         0.92081875          1
# 308274  1.06640171 2.862421e-01 0.38         0.42021640          1
# 308275 -0.82668140 4.084177e-01 0.66         0.18045606         -1
# 308276  3.89489812 9.824001e-05 0.02         1.69897000          1
# 308277  1.19226561 2.331571e-01 0.12         0.92081875          1
# 308278  1.92795770 5.386039e-02 0.16         0.79588002          1
# 308279 -3.42830032 6.073732e-04 0.02         1.69897000         -1
# 308280  1.93667771 5.278475e-02 0.18         0.74472749          1
# 308281  2.30423804 2.120929e-02 0.02         1.69897000          1
#        boot_basic_p.log10.signed
# 1      -0.15490196
# 2      -0.52287875
# 3      -0.44369750
# 4      -0.46852108
# 5       0.33724217
# 6       0.08618615
# 7      -0.44369750
# 8      -0.79588002
# 9       0.35654732
# 10     -0.52287875
# 11     -1.69897000
# 12     -0.85387196
# 13     -0.10790540
# 14      0.46852108
# 15     -0.09691001
# 16     -1.39794001
# 17     -0.92081875
# 18     -0.10790540
# 19     -0.46852108
# 20     -1.09691001
# 21      0.31875876
# 22      0.69897000
# 23      0.26760624
# 24      1.69897000
# 25      1.39794001
# 26     -0.20760831
# 27     -1.22184875
# 28     -0.37675071
# 29      0.69897000
# 30      0.25181197
# ⋮      ⋮
# 308252 -0.14266750
# 308253  0.22184875
# 308254 -0.08618615
# 308255  0.42021640
# 308256  0.79588002
# 308257  0.69897000
# 308258 -0.04575749
# 308259  1.69897000
# 308260  0.06550155
# 308261  1.22184875
# 308262 -0.09691001
# 308263  0.92081875
# 308264  1.09691001
# 308265  0.69897000
# 308266  0.08618615
# 308267 -0.16749109
# 308268  1.69897000
# 308269  0.44369750
# 308270  0.28399666
# 308271 -0.02687215
# 308272  0.18045606
# 308273  0.92081875
# 308274  0.42021640
# 308275 -0.18045606
# 308276  1.69897000
# 308277  0.92081875
# 308278  0.79588002
# 308279 -1.69897000
# 308280  0.74472749
# 308281  1.69897000

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
# [1] Matrix_1.6-5         GenomicRanges_1.54.1 GenomeInfoDb_1.38.1
# [4] IRanges_2.36.0       S4Vectors_0.40.2     BiocGenerics_0.48.1
# [7] genomation_1.34.0    Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] bit64_4.0.5                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] data.table_1.15.2           hms_1.1.3
#  [71] sp_2.1-4                    utf8_1.2.4
#  [73] XVector_0.42.0              pillar_1.9.0
#  [75] stringr_1.5.1               vroom_1.6.5
#  [77] spam_2.10-0                 IRdisplay_1.1
#  [79] splines_4.3.3               dplyr_1.1.4
#  [81] lattice_0.22-6              bit_4.0.5
#  [83] rtracklayer_1.60.1          tidyselect_1.2.1
#  [85] Biostrings_2.70.1           pbapply_1.7-2
#  [87] knitr_1.46                  gridExtra_2.3
#  [89] SummarizedExperiment_1.30.2 xfun_0.43
#  [91] Biobase_2.60.0              matrixStats_1.3.0
#  [93] stringi_1.8.3               yaml_2.3.8
#  [95] boot_1.3-30                 evaluate_0.23
#  [97] codetools_0.2-20            tibble_3.2.1
#  [99] cli_3.6.2                   IRkernel_1.3.2
# [101] rpart_4.1.23                repr_1.1.7
# [103] munsell_0.5.1               Rcpp_1.0.12
# [105] globals_0.16.3              XML_3.99-0.16.1
# [107] ggplot2_3.5.1               readr_2.1.5
# [109] dotCall64_1.1-1             bitops_1.0-7
# [111] lme4_1.1-35.3               listenv_0.9.1
# [113] scales_1.3.0                SeuratObject_5.0.1
# [115] purrr_1.0.2                 crayon_1.5.2
# [117] rlang_1.1.3                 fastmatch_1.1-4
