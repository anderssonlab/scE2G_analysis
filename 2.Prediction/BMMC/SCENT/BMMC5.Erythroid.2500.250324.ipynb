# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.500.250204/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Erythroid/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/Erythroid.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.2500.250324/"
celltype = "Erythroid"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype  log.nUMI
# s1d1_AGCGCCTAGATGGACA-1 s1d1_AGCGCCTAGATGGACA-1  2307  77   Erythroid  7.743703
# s1d1_CCTGAATAGCTTGCTC-1 s1d1_CCTGAATAGCTTGCTC-1  3907  53   Erythroid  8.270525
# s1d1_GGCTGAGAGTATTGCA-1 s1d1_GGCTGAGAGTATTGCA-1  2159  38   Erythroid  7.677400
# s1d1_GGCAATCGTTAGGACC-1 s1d1_GGCAATCGTTAGGACC-1  1154  30   Erythroid  7.050989
# s1d1_AGTTATGTCTCACTCA-1 s1d1_AGTTATGTCTCACTCA-1  1534  23   Erythroid  7.335634
# s1d1_GTTTGTCGTGAATCGC-1 s1d1_GTTTGTCGTGAATCGC-1  6050 100   Erythroid  8.707814
# s1d1_CGCAAATTCTACTAAG-1 s1d1_CGCAAATTCTACTAAG-1  4517 106   Erythroid  8.415603
# s1d1_GGTTTCCTCTTGGACG-1 s1d1_GGTTTCCTCTTGGACG-1  2323  64   Erythroid  7.750615
# s1d1_AATCAGGAGCTGAGGG-1 s1d1_AATCAGGAGCTGAGGG-1  1067  36   Erythroid  6.972606
# s1d1_TGAGTGAAGTTAGTGC-1 s1d1_TGAGTGAAGTTAGTGC-1  1908  18   Erythroid  7.553811
# s1d1_CTTAGTTTCCTTGCGT-1 s1d1_CTTAGTTTCCTTGCGT-1  5758  55   Erythroid  8.658345
# s1d1_GCCTATTGTTAGGTGC-1 s1d1_GCCTATTGTTAGGTGC-1  1429  25   Erythroid  7.264730
# s1d1_ATTAACCCATTAGCCA-1 s1d1_ATTAACCCATTAGCCA-1 16645 104   Erythroid  9.719865
# s1d1_GTTAACCAGTTATTCC-1 s1d1_GTTAACCAGTTATTCC-1  1017  52   Erythroid  6.924612
# s1d1_GTTTCAGCAGCACGTT-1 s1d1_GTTTCAGCAGCACGTT-1  1314  71   Erythroid  7.180831
# s1d1_AATAACCGTCATTGAG-1 s1d1_AATAACCGTCATTGAG-1   904  38   Erythroid  6.806829
# s1d1_TAGGCTAGTGTAACCA-1 s1d1_TAGGCTAGTGTAACCA-1  1399  26   Erythroid  7.243513
# s1d1_CTTCGCGTCGAGCAAA-1 s1d1_CTTCGCGTCGAGCAAA-1  2079  39   Erythroid  7.639642
# s1d1_TCAGGTCCAAACTCAT-1 s1d1_TCAGGTCCAAACTCAT-1  1072  17   Erythroid  6.977281
# s1d1_ATTTGCAAGGCATTAC-1 s1d1_ATTTGCAAGGCATTAC-1  8812 107   Erythroid  9.083870
# s1d1_CTGGATGTCATAACTG-1 s1d1_CTGGATGTCATAACTG-1  5023  46   Erythroid  8.521783
# s1d1_TCATCCATCCTCATCA-1 s1d1_TCATCCATCCTCATCA-1  1969  77   Erythroid  7.585281
# s1d1_TGCTTAAAGCCGCTAA-1 s1d1_TGCTTAAAGCCGCTAA-1  1828  59   Erythroid  7.510978
# s1d1_CAGCCTTTCCTGTTCA-1 s1d1_CAGCCTTTCCTGTTCA-1  1547  51   Erythroid  7.344073
# s1d1_ACGACTTAGCTACTGG-1 s1d1_ACGACTTAGCTACTGG-1  3573  77   Erythroid  8.181161
# s1d1_CCAGCCTGTTAGGACC-1 s1d1_CCAGCCTGTTAGGACC-1 22831 693   Erythroid 10.035875
# s1d1_CTCTGTTCAAACTGTT-1 s1d1_CTCTGTTCAAACTGTT-1  2923  95   Erythroid  7.980366
# s1d1_GTTTCTAGTCATCATC-1 s1d1_GTTTCTAGTCATCATC-1  3606  38   Erythroid  8.190354
# s1d1_TGATGATGTGCAACTA-1 s1d1_TGATGATGTGCAACTA-1   992  45   Erythroid  6.899723
# s1d1_GCGCTTGCAATCCCTT-1 s1d1_GCGCTTGCAATCCCTT-1  2594  55   Erythroid  7.860956
# ⋮                       ⋮                       ⋮     ⋮     ⋮         ⋮
# s4d9_ATTTGTGAGGCGCACT-1 s4d9_ATTTGTGAGGCGCACT-1 2371   233  Erythroid 7.771067
# s4d9_GGTTAATGTGCAACTA-1 s4d9_GGTTAATGTGCAACTA-1  849     1  Erythroid 6.744059
# s4d9_TATTCGTTCAATGTCA-1 s4d9_TATTCGTTCAATGTCA-1 1183    35  Erythroid 7.075809
# s4d9_CGGAGTCTCCAGGTTG-1 s4d9_CGGAGTCTCCAGGTTG-1  682    42  Erythroid 6.525030
# s4d9_ATGGCTTAGGAGGCAT-1 s4d9_ATGGCTTAGGAGGCAT-1 2095     6  Erythroid 7.647309
# s4d9_GGCTATTAGCACGTTG-1 s4d9_GGCTATTAGCACGTTG-1 5457   821  Erythroid 8.604654
# s4d9_CTCCTAATCGCTAAGT-1 s4d9_CTCCTAATCGCTAAGT-1  599    36  Erythroid 6.395262
# s4d9_GGTTGCATCTGTAATG-1 s4d9_GGTTGCATCTGTAATG-1 6871  1099  Erythroid 8.835065
# s4d9_TTAGCAGGTGAATCGC-1 s4d9_TTAGCAGGTGAATCGC-1 2949   279  Erythroid 7.989221
# s4d9_CTGGTTACACCACAAC-1 s4d9_CTGGTTACACCACAAC-1  588    27  Erythroid 6.376727
# s4d9_GTCGGTTCACGAATTT-1 s4d9_GTCGGTTCACGAATTT-1 1340   168  Erythroid 7.200425
# s4d9_GTGGTTAGTAACTACG-1 s4d9_GTGGTTAGTAACTACG-1  871    36  Erythroid 6.769642
# s4d9_AAGCCTTAGTAAACCC-1 s4d9_AAGCCTTAGTAAACCC-1 1807   125  Erythroid 7.499423
# s4d9_ACCCGTAAGCAATAGG-1 s4d9_ACCCGTAAGCAATAGG-1 3997   520  Erythroid 8.293299
# s4d9_CTCATGACAGCCGCTA-1 s4d9_CTCATGACAGCCGCTA-1 3113   330  Erythroid 8.043342
# s4d9_AAGGCCCTCTAGCGTG-1 s4d9_AAGGCCCTCTAGCGTG-1 2045   145  Erythroid 7.623153
# s4d9_TCTAGCCTCTTTAAGG-1 s4d9_TCTAGCCTCTTTAAGG-1  638    76  Erythroid 6.458338
# s4d9_GCTAAGCGTCTCAGCC-1 s4d9_GCTAAGCGTCTCAGCC-1 1949    80  Erythroid 7.575072
# s4d9_AGTAAGTAGTAAACCC-1 s4d9_AGTAAGTAGTAAACCC-1 1694    59  Erythroid 7.434848
# s4d9_TCCAGGATCACCATTT-1 s4d9_TCCAGGATCACCATTT-1  746    67  Erythroid 6.614726
# s4d9_TAGAGCCGTGAGGTAG-1 s4d9_TAGAGCCGTGAGGTAG-1 1032    91  Erythroid 6.939254
# s4d9_CTCATCATCAATCTCT-1 s4d9_CTCATCATCAATCTCT-1  622    20  Erythroid 6.432940
# s4d9_AGGACGTAGTGCACGC-1 s4d9_AGGACGTAGTGCACGC-1 1142   117  Erythroid 7.040536
# s4d9_TGCTTGCTCATTGTCT-1 s4d9_TGCTTGCTCATTGTCT-1 1897   129  Erythroid 7.548029
# s4d9_TGTAAGCTCGCTAAGT-1 s4d9_TGTAAGCTCGCTAAGT-1 2575   423  Erythroid 7.853605
# s4d9_TATGAAGCATTGTGGC-1 s4d9_TATGAAGCATTGTGGC-1 1430    29  Erythroid 7.265430
# s4d9_CTCACACTCGGGACCT-1 s4d9_CTCACACTCGGGACCT-1 5029   919  Erythroid 8.522976
# s4d9_TCCATCATCGCATTAA-1 s4d9_TCCATCATCGCATTAA-1 1341    59  Erythroid 7.201171
# s4d9_CCAGGATGTATTCGTC-1 s4d9_CCAGGATGTATTCGTC-1  802    40  Erythroid 6.687109
# s4d9_TAGCCGGGTAATAGCT-1 s4d9_TAGCCGGGTAATAGCT-1 2699   455  Erythroid 7.900637
#                         percent.mito
# s1d1_AGCGCCTAGATGGACA-1 0.033376680
# s1d1_CCTGAATAGCTTGCTC-1 0.013565395
# s1d1_GGCTGAGAGTATTGCA-1 0.017600741
# s1d1_GGCAATCGTTAGGACC-1 0.025996534
# s1d1_AGTTATGTCTCACTCA-1 0.014993481
# s1d1_GTTTGTCGTGAATCGC-1 0.016528926
# s1d1_CGCAAATTCTACTAAG-1 0.023466903
# s1d1_GGTTTCCTCTTGGACG-1 0.027550581
# s1d1_AATCAGGAGCTGAGGG-1 0.033739456
# s1d1_TGAGTGAAGTTAGTGC-1 0.009433962
# s1d1_CTTAGTTTCCTTGCGT-1 0.009551928
# s1d1_GCCTATTGTTAGGTGC-1 0.017494752
# s1d1_ATTAACCCATTAGCCA-1 0.006248123
# s1d1_GTTAACCAGTTATTCC-1 0.051130777
# s1d1_GTTTCAGCAGCACGTT-1 0.054033486
# s1d1_AATAACCGTCATTGAG-1 0.042035398
# s1d1_TAGGCTAGTGTAACCA-1 0.018584703
# s1d1_CTTCGCGTCGAGCAAA-1 0.018759019
# s1d1_TCAGGTCCAAACTCAT-1 0.015858209
# s1d1_ATTTGCAAGGCATTAC-1 0.012142533
# s1d1_CTGGATGTCATAACTG-1 0.009157874
# s1d1_TCATCCATCCTCATCA-1 0.039106145
# s1d1_TGCTTAAAGCCGCTAA-1 0.032275711
# s1d1_CAGCCTTTCCTGTTCA-1 0.032967033
# s1d1_ACGACTTAGCTACTGG-1 0.021550518
# s1d1_CCAGCCTGTTAGGACC-1 0.030353467
# s1d1_CTCTGTTCAAACTGTT-1 0.032500855
# s1d1_GTTTCTAGTCATCATC-1 0.010537992
# s1d1_TGATGATGTGCAACTA-1 0.045362903
# s1d1_GCGCTTGCAATCCCTT-1 0.021202776
# ⋮                       ⋮
# s4d9_ATTTGTGAGGCGCACT-1 0.098270772
# s4d9_GGTTAATGTGCAACTA-1 0.001177856
# s4d9_TATTCGTTCAATGTCA-1 0.029585799
# s4d9_CGGAGTCTCCAGGTTG-1 0.061583578
# s4d9_ATGGCTTAGGAGGCAT-1 0.002863962
# s4d9_GGCTATTAGCACGTTG-1 0.150448965
# s4d9_CTCCTAATCGCTAAGT-1 0.060100167
# s4d9_GGTTGCATCTGTAATG-1 0.159947606
# s4d9_TTAGCAGGTGAATCGC-1 0.094608342
# s4d9_CTGGTTACACCACAAC-1 0.045918367
# s4d9_GTCGGTTCACGAATTT-1 0.125373134
# s4d9_GTGGTTAGTAACTACG-1 0.041331803
# s4d9_AAGCCTTAGTAAACCC-1 0.069175429
# s4d9_ACCCGTAAGCAATAGG-1 0.130097573
# s4d9_CTCATGACAGCCGCTA-1 0.106007067
# s4d9_AAGGCCCTCTAGCGTG-1 0.070904645
# s4d9_TCTAGCCTCTTTAAGG-1 0.119122257
# s4d9_GCTAAGCGTCTCAGCC-1 0.041046691
# s4d9_AGTAAGTAGTAAACCC-1 0.034828808
# s4d9_TCCAGGATCACCATTT-1 0.089812332
# s4d9_TAGAGCCGTGAGGTAG-1 0.088178295
# s4d9_CTCATCATCAATCTCT-1 0.032154341
# s4d9_AGGACGTAGTGCACGC-1 0.102451839
# s4d9_TGCTTGCTCATTGTCT-1 0.068002109
# s4d9_TGTAAGCTCGCTAAGT-1 0.164271845
# s4d9_TATGAAGCATTGTGGC-1 0.020279720
# s4d9_CTCACACTCGGGACCT-1 0.182740107
# s4d9_TCCATCATCGCATTAA-1 0.043997017
# s4d9_CCAGGATGTATTCGTC-1 0.049875312
# s4d9_TAGCCGGGTAATAGCT-1 0.168580956

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
                bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.2500.250324//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.05]
  pairs.E2G.chr.keep = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res$PairName]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 227353 ranges and 11 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#   chr1.chr1     chr1 100037580-100039259      * |      CDC14A
#   chr1.chr1     chr1 100132316-100133496      * |       FRRS1
#   chr1.chr1     chr1 100132316-100133496      * |       SASS6
#   chr1.chr1     chr1 100132316-100133496      * |     SLC30A7
#   chr1.chr1     chr1 100132316-100133496      * |     SLC35A3
#         ...      ...                 ...    ... .         ...
#   chrX.chrX     chrX   86047015-86047963      * |         CHM
#   chrX.chrX     chrX     9462938-9463570      * |        WWC3
#   chrX.chrX     chrX     9464719-9466469      * |       CLCN4
#   chrX.chrX     chrX     9464719-9466469      * |        WWC3
#   chrX.chrX     chrX     9515403-9516815      * |        WWC3
#                           PeakName               PairName       beta        se
#                        <character>            <character>  <numeric> <numeric>
#   chr1.chr1 chr1-100037580-10003.. chr1-100037580-10003..   0.105086 0.0344721
#   chr1.chr1 chr1-100132316-10013.. chr1-100132316-10013..   0.182490 0.0595711
#   chr1.chr1 chr1-100132316-10013.. chr1-100132316-10013..   0.116095 0.0399427
#   chr1.chr1 chr1-100132316-10013.. chr1-100132316-10013..   0.132918 0.0446113
#   chr1.chr1 chr1-100132316-10013.. chr1-100132316-10013..   0.241745 0.0811716
#         ...                    ...                    ...        ...       ...
#   chrX.chrX chrX-86047015-86047963 chrX-86047015-860479..  0.2047059 0.1294803
#   chrX.chrX   chrX-9462938-9463570 chrX-9462938-9463570.. -0.0492182 0.1185886
#   chrX.chrX   chrX-9464719-9466469 chrX-9464719-9466469..  0.1199329 0.0789666
#   chrX.chrX   chrX-9464719-9466469 chrX-9464719-9466469.. -0.0290082 0.1110308
#   chrX.chrX   chrX-9515403-9516815 chrX-9515403-9516815..  0.0128740 0.1100168
#                     z          p boot_basic_p boot_basic_p.log10      sign
#             <numeric>  <numeric>    <numeric>          <numeric> <numeric>
#   chr1.chr1   3.04844 0.00230033       0.0336            1.47366         1
#   chr1.chr1   3.06340 0.00218836       0.0104            1.98297         1
#   chr1.chr1   2.90653 0.00365459       0.0128            1.89279         1
#   chr1.chr1   2.97947 0.00288750       0.0200            1.69897         1
#   chr1.chr1   2.97819 0.00289952       0.0040            2.39794         1
#         ...       ...        ...          ...                ...       ...
#   chrX.chrX  1.580982   0.113882         0.18          0.7447275         1
#   chrX.chrX -0.415033   0.678118         0.62          0.2076083        -1
#   chrX.chrX  1.518779   0.128818         0.16          0.7958800         1
#   chrX.chrX -0.261263   0.793890         0.84          0.0757207        -1
#   chrX.chrX  0.117018   0.906846         0.94          0.0268721         1
#             boot_basic_p.log10.signed
#                             <numeric>
#   chr1.chr1                   1.47366
#   chr1.chr1                   1.98297
#   chr1.chr1                   1.89279
#   chr1.chr1                   1.69897
#   chr1.chr1                   2.39794
#         ...                       ...
#   chrX.chrX                 0.7447275
#   chrX.chrX                -0.2076083
#   chrX.chrX                 0.7958800
#   chrX.chrX                -0.0757207
#   chrX.chrX                 0.0268721
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType  beta         se
# 1      chr1 100037580 100039259 CDC14A     Erythroid  0.10508612  0.03447210
# 2      chr1 100132316 100133496 FRRS1      Erythroid  0.18249020  0.05957111
# 3      chr1 100132316 100133496 SASS6      Erythroid  0.11609482  0.03994272
# 4      chr1 100132316 100133496 SLC30A7    Erythroid  0.13291800  0.04461134
# 5      chr1 100132316 100133496 SLC35A3    Erythroid  0.24174477  0.08117160
# 6      chr1 100132316 100133496 TRMT13     Erythroid  0.15286806  0.06636267
# 7      chr1  10032432  10033794 TARDBP     Erythroid -0.09147308  0.04083898
# 8      chr1 100347353 100347658 FRRS1      Erythroid  0.32185229  0.08904832
# 9      chr1 100347353 100347658 SLC35A3    Erythroid  0.32749381  0.11890332
# 10     chr1 100347353 100347658 TRMT13     Erythroid  0.24126094  0.10019948
# 11     chr1 100351187 100353307 AGL        Erythroid  0.28104323  0.07996222
# 12     chr1 100351187 100353307 CDC14A     Erythroid  0.11794228  0.03480881
# 13     chr1 100351187 100353307 FRRS1      Erythroid  0.20709248  0.05862268
# 14     chr1 100351187 100353307 SASS6      Erythroid  0.10442572  0.03896220
# 15     chr1 100351187 100353307 SLC30A7    Erythroid  0.18799270  0.04374372
# 16     chr1 100448032 100449138 AGL        Erythroid  0.25182266  0.11325573
# 17     chr1 100448032 100449138 CDC14A     Erythroid  0.18942015  0.05185362
# 18     chr1 100448032 100449138 SASS6      Erythroid  0.17654001  0.06053763
# 19     chr1 100448032 100449138 SLC30A7    Erythroid  0.21500391  0.06638389
# 20     chr1 100448032 100449138 SLC35A3    Erythroid  0.22717080  0.11740133
# 21     chr1 100448032 100449138 TRMT13     Erythroid  0.35736263  0.09212059
# 22     chr1  10045299  10046692 PEX14      Erythroid  0.16638474  0.06528355
# 23     chr1  10045299  10046692 UBE4B      Erythroid  0.13561514  0.04383399
# 24     chr1 100463619 100464779 FRRS1      Erythroid  0.39538875  0.08671158
# 25     chr1 100463619 100464779 RTCA       Erythroid  0.16752742  0.08065460
# 26     chr1 100463619 100464779 SASS6      Erythroid  0.16777081  0.06263520
# 27     chr1 100463619 100464779 SLC35A3    Erythroid  0.39497408  0.11534807
# 28     chr1  10074828  10075861 KIF1B      Erythroid  0.37444347  0.11372575
# 29     chr1  10074828  10075861 PEX14      Erythroid  0.46128297  0.06274601
# 30     chr1  10074828  10075861 PGD        Erythroid  0.34562638  0.09031840
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮         ⋮            ⋮
# 227324 chrX 77937352  77938643  PGK1       Erythroid  0.019809597 0.07338820
# 227325 chrX 78103592  78104593  ATP7A      Erythroid  0.001213775 0.05041126
# 227326 chrX 78103592  78104593  ATRX       Erythroid  0.010325331 0.02322963
# 227327 chrX 78103592  78104593  COX7B      Erythroid -0.101373141 0.04009358
# 227328 chrX 78103592  78104593  MAGT1      Erythroid  0.002178668 0.04907103
# 227329 chrX 78103592  78104593  PGK1       Erythroid  0.111622275 0.05303673
# 227330 chrX 78138983  78140186  ATP7A      Erythroid -0.070442076 0.06929827
# 227331 chrX 78138983  78140186  ATRX       Erythroid  0.030200487 0.03047265
# 227332 chrX 78138983  78140186  COX7B      Erythroid -0.079725695 0.05255630
# 227333 chrX 78138983  78140186  MAGT1      Erythroid -0.010298022 0.06497605
# 227334 chrX 78138983  78140186  PGK1       Erythroid  0.095607166 0.06782276
# 227335 chrX 80808039  80808674  HMGN5      Erythroid -0.092849496 0.08140973
# 227336 chrX 80808039  80808674  SH3BGRL    Erythroid -0.010585143 0.05122980
# 227337 chrX 80809524  80810377  BRWD3      Erythroid  0.064302018 0.05713579
# 227338 chrX 80809524  80810377  SH3BGRL    Erythroid -0.039896018 0.03549811
# 227339 chrX 81120681  81122316  BRWD3      Erythroid  0.048532692 0.06080756
# 227340 chrX 81120681  81122316  HMGN5      Erythroid -0.046702489 0.05781069
# 227341 chrX 81120681  81122316  SH3BGRL    Erythroid -0.007122379 0.03730419
# 227342 chrX 81201618  81203396  BRWD3      Erythroid  0.011502181 0.06705051
# 227343 chrX 81201618  81203396  HMGN5      Erythroid -0.114788399 0.06460635
# 227344 chrX 81201618  81203396  SH3BGRL    Erythroid -0.019095798 0.04088479
# 227345 chrX 81229043  81229890  BRWD3      Erythroid -0.034782971 0.08628305
# 227346 chrX 81229043  81229890  HMGN5      Erythroid  0.011555782 0.07769104
# 227347 chrX 81229043  81229890  SH3BGRL    Erythroid  0.022212593 0.05087271
# 227348 chrX 85003058  85004592  APOOL      Erythroid  0.067582457 0.09014248
# 227349 chrX 86047015  86047963  CHM        Erythroid  0.204705933 0.12948027
# 227350 chrX  9462938   9463570  WWC3       Erythroid -0.049218189 0.11858863
# 227351 chrX  9464719   9466469  CLCN4      Erythroid  0.119932852 0.07896664
# 227352 chrX  9464719   9466469  WWC3       Erythroid -0.029008229 0.11103082
# 227353 chrX  9515403   9516815  WWC3       Erythroid  0.012873973 0.11001677
#        z           p            boot_basic_p boot_basic_p.log10 sign
# 1       3.048440   2.300331e-03 0.0336       1.473661            1
# 2       3.063401   2.188364e-03 0.0104       1.982967            1
# 3       2.906533   3.654586e-03 0.0128       1.892790            1
# 4       2.979467   2.887503e-03 0.0200       1.698970            1
# 5       2.978194   2.899523e-03 0.0040       2.397940            1
# 6       2.303525   2.124933e-02 0.0496       1.304518            1
# 7      -2.239847   2.510083e-02 0.0328       1.484126           -1
# 8       3.614356   3.010956e-04 0.0008       3.096910            1
# 9       2.754287   5.882025e-03 0.0128       1.892790            1
# 10      2.407806   1.604870e-02 0.0256       1.591760            1
# 11      3.514700   4.402511e-04 0.0032       2.494850            1
# 12      3.388288   7.033030e-04 0.0160       1.795880            1
# 13      3.532634   4.114419e-04 0.0032       2.494850            1
# 14      2.680180   7.358258e-03 0.0200       1.698970            1
# 15      4.297593   1.726631e-05 0.0016       2.795880            1
# 16      2.223487   2.618297e-02 0.0560       1.251812            1
# 17      3.652978   2.592163e-04 0.0064       2.193820            1
# 18      2.916203   3.543198e-03 0.0112       1.950782            1
# 19      3.238796   1.200352e-03 0.0104       1.982967            1
# 20      1.934993   5.299110e-02 0.0472       1.326058            1
# 21      3.879292   1.047610e-04 0.0008       3.096910            1
# 22      2.548647   1.081416e-02 0.0360       1.443697            1
# 23      3.093835   1.975874e-03 0.0136       1.866461            1
# 24      4.559815   5.119872e-06 0.0008       3.096910            1
# 25      2.077097   3.779261e-02 0.0376       1.424812            1
# 26      2.678539   7.394421e-03 0.0288       1.540608            1
# 27      3.424193   6.166278e-04 0.0008       3.096910            1
# 28      3.292513   9.929640e-04 0.0056       2.251812            1
# 29      7.351591   1.958614e-13 0.0008       3.096910            1
# 30      3.826755   1.298436e-04 0.0008       3.096910            1
# ⋮      ⋮           ⋮            ⋮            ⋮                  ⋮
# 227324  0.26992891 0.78721495   0.940        0.02687215          1
# 227325  0.02407746 0.98079082   0.940        0.02687215          1
# 227326  0.44448973 0.65668855   0.760        0.11918641          1
# 227327 -2.52841333 0.01145794   0.076        1.11918641         -1
# 227328  0.04439826 0.96458695   0.940        0.02687215          1
# 227329  2.10462211 0.03532422   0.068        1.16749109          1
# 227330 -1.01650558 0.30938869   0.500        0.30103000         -1
# 227331  0.99106862 0.32165207   0.500        0.30103000          1
# 227332 -1.51695789 0.12927732   0.240        0.61978876         -1
# 227333 -0.15848951 0.87407109   0.960        0.01772877         -1
# 227334  1.40966200 0.15863951   0.160        0.79588002          1
# 227335 -1.14052089 0.25406935   0.300        0.52287875         -1
# 227336 -0.20662083 0.83630599   0.920        0.03621217         -1
# 227337  1.12542457 0.26040916   0.420        0.37675071          1
# 227338 -1.12389136 0.26105912   0.360        0.44369750         -1
# 227339  0.79813577 0.42479171   0.540        0.26760624          1
# 227340 -0.80785206 0.41917575   0.540        0.26760624         -1
# 227341 -0.19092707 0.84858273   0.920        0.03621217         -1
# 227342  0.17154502 0.86379523   0.820        0.08618615          1
# 227343 -1.77673558 0.07561176   0.100        1.00000000         -1
# 227344 -0.46706362 0.64045436   0.960        0.01772877         -1
# 227345 -0.40312636 0.68685527   0.920        0.03621217         -1
# 227346  0.14874021 0.88175863   0.920        0.03621217          1
# 227347  0.43663081 0.66237912   0.580        0.23657201          1
# 227348  0.74972927 0.45341777   0.460        0.33724217          1
# 227349  1.58098164 0.11388224   0.180        0.74472749          1
# 227350 -0.41503295 0.67811778   0.620        0.20760831         -1
# 227351  1.51877865 0.12881822   0.160        0.79588002          1
# 227352 -0.26126286 0.79388981   0.840        0.07572071         -1
# 227353  0.11701828 0.90684557   0.940        0.02687215          1
#        boot_basic_p.log10.signed FDR
# 1       1.473661                 0.17869148
# 2       1.982967                 0.08333526
# 3       1.892790                 0.09575278
# 4       1.698970                 0.12845891
# 5       2.397940                 0.04299211
# 6       1.304518                 0.23727951
# 7      -1.484126                 0.17590589
# 8       3.096910                 0.01236454
# 9       1.892790                 0.09575278
# 10      1.591760                 0.14999064
# 11      2.494850                 0.03655928
# 12      1.795880                 0.11096818
# 13      2.494850                 0.03655928
# 14      1.698970                 0.12845891
# 15      2.795880                 0.02161664
# 16      1.251812                 0.24912472
# 17      2.193820                 0.05989870
# 18      1.950782                 0.08756976
# 19      1.982967                 0.08333526
# 20      1.326058                 0.22813116
# 21      3.096910                 0.01236454
# 22      1.443697                 0.18718600
# 23      1.866461                 0.09966801
# 24      3.096910                 0.01236454
# 25      1.424812                 0.19285895
# 26      1.540608                 0.16168921
# 27      3.096910                 0.01236454
# 28      2.251812                 0.05464278
# 29      3.096910                 0.01236454
# 30      3.096910                 0.01236454
# ⋮      ⋮                         ⋮
# 227324  0.02687215               0.9719343
# 227325  0.02687215               0.9719343
# 227326  0.11918641               0.8965861
# 227327 -1.11918641               0.3018189
# 227328  0.02687215               0.9719343
# 227329  1.16749109               0.2799965
# 227330 -0.30103000               0.7503003
# 227331  0.30103000               0.7503003
# 227332 -0.61978876               0.5225555
# 227333 -0.01772877               0.9792927
# 227334  0.79588002               0.4224224
# 227335 -0.52287875               0.5874805
# 227336 -0.03621217               0.9642928
# 227337  0.37675071               0.6915330
# 227338 -0.44369750               0.6426032
# 227339  0.26760624               0.7760812
# 227340 -0.26760624               0.7760812
# 227341 -0.03621217               0.9642928
# 227342  0.08618615               0.9234850
# 227343 -1.00000000               0.3392873
# 227344 -0.01772877               0.9792927
# 227345 -0.03621217               0.9642928
# 227346  0.03621217               0.9642928
# 227347  0.23657201               0.8006748
# 227348  0.33724217               0.7218203
# 227349  0.74472749               0.4493685
# 227350 -0.20760831               0.8243015
# 227351  0.79588002               0.4224224
# 227352 -0.07572071               0.9324980
# 227353  0.02687215               0.9719343

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
