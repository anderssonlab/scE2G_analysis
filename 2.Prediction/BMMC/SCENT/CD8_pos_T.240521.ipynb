# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/CD8_pos_T/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/CD8_pos_T/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/CD8_pos_T/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/2.seurat_pipeline.240506/RNA_count_matrix/CD8_pos_T.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/CD8_pos_T.240521/"

# %%
n.cores = 8

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 1M

# %%
pairs.ABC.1M = pairs.ABC[pairs.ABC$distance < 10^6]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.1M

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.1M.chr_rename = as.data.frame(pairs.ABC.1M)[,1:3]
df.pairs.ABC.1M.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.1M),
                                                mcols(pairs.ABC.1M)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.1M.chr_rename = GRanges(df.pairs.ABC.1M.chr_rename)
rm(df.pairs.ABC.1M.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.1M.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.1M.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 2510181 ranges and 3 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028543-100029371      * |         AGL
#         [2]     chr1 100028543-100029371      * |      CDC14A
#         [3]     chr1 100028543-100029371      * |         DBT
#         [4]     chr1 100028543-100029371      * |        DPH5
#         [5]     chr1 100028543-100029371      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2510177]     chrX     9995625-9996370      * |       TBL1X
#   [2510178]     chrX     9995625-9996370      * |        WWC3
#   [2510179]     chrX     9997430-9997928      * |       CLCN4
#   [2510180]     chrX     9997430-9997928      * |       TBL1X
#   [2510181]     chrX     9997430-9997928      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-100028543-10002.. chr1-100028543-10002..
#         [2] chr1-100028543-10002.. chr1-100028543-10002..
#         [3] chr1-100028543-10002.. chr1-100028543-10002..
#         [4] chr1-100028543-10002.. chr1-100028543-10002..
#         [5] chr1-100028543-10002.. chr1-100028543-10002..
#         ...                    ...                    ...
#   [2510177]   chrX-9995625-9996370 chrX-9995625-9996370..
#   [2510178]   chrX-9995625-9996370 chrX-9995625-9996370..
#   [2510179]   chrX-9997430-9997928 chrX-9997430-9997928..
#   [2510180]   chrX-9997430-9997928 chrX-9997430-9997928..
#   [2510181]   chrX-9997430-9997928 chrX-9997430-9997928..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI nMito celltype log.nUMI
# s1d1_CCGCACACAGGTTAAA-1 s1d1_CCGCACACAGGTTAAA-1 8311 115   K562     9.025335
# s1d1_TCATTTGGTAATGGAA-1 s1d1_TCATTTGGTAATGGAA-1 1291  20   K562     7.163172
# s1d1_ATGTGAGAGGCGAAAC-1 s1d1_ATGTGAGAGGCGAAAC-1 1126  19   K562     7.026427
# s1d1_CGCTTCTAGTGACCTG-1 s1d1_CGCTTCTAGTGACCTG-1 1697  18   K562     7.436617
# s1d1_GAGCTGCTCTTGTCCA-1 s1d1_GAGCTGCTCTTGTCCA-1 2229  37   K562     7.709308
# s1d1_GTTACTAAGGTGAAGC-1 s1d1_GTTACTAAGGTGAAGC-1 1472  30   K562     7.294377
# s1d1_GCCTTAGAGCTAAGTC-1 s1d1_GCCTTAGAGCTAAGTC-1 1626  39   K562     7.393878
# s1d1_CTTGTAAAGATAAAGC-1 s1d1_CTTGTAAAGATAAAGC-1 2168  38   K562     7.681560
# s1d1_ACGCTTGAGTCATCCC-1 s1d1_ACGCTTGAGTCATCCC-1 1624  39   K562     7.392648
# s1d1_TAGCGCGGTCAATACG-1 s1d1_TAGCGCGGTCAATACG-1 1732  46   K562     7.457032
# s1d1_CTAAAGCTCGCTAAAC-1 s1d1_CTAAAGCTCGCTAAAC-1 1482  17   K562     7.301148
# s1d1_GTGTGTTAGTAGCTTA-1 s1d1_GTGTGTTAGTAGCTTA-1 4515  45   K562     8.415160
# s1d1_CTTGCGCGTTAGGCTA-1 s1d1_CTTGCGCGTTAGGCTA-1 1654  43   K562     7.410952
# s1d1_CCATTGTGTTACATCC-1 s1d1_CCATTGTGTTACATCC-1 1595  17   K562     7.374629
# s1d1_GACCGAACACAATGTT-1 s1d1_GACCGAACACAATGTT-1 2156  34   K562     7.676010
# s1d1_TCATAACCATAATCCG-1 s1d1_TCATAACCATAATCCG-1 3252  55   K562     8.087025
# s1d1_TACGGATTCTGCAACG-1 s1d1_TACGGATTCTGCAACG-1 2791  58   K562     7.934155
# s1d1_GGGCTAACACGAATTT-1 s1d1_GGGCTAACACGAATTT-1 2868  72   K562     7.961370
# s1d1_CGTCCTAGTTGAAGCC-1 s1d1_CGTCCTAGTTGAAGCC-1 2865  46   K562     7.960324
# s1d1_CCATTGTGTAGGTTAT-1 s1d1_CCATTGTGTAGGTTAT-1 2019  35   K562     7.610358
# s1d1_TGCATGAGTATTGTCC-1 s1d1_TGCATGAGTATTGTCC-1 2112  35   K562     7.655391
# s1d1_TGGTTGAGTGAACAAA-1 s1d1_TGGTTGAGTGAACAAA-1  835  43   K562     6.727432
# s1d1_ATGCAAACAAAGGCCA-1 s1d1_ATGCAAACAAAGGCCA-1 2108  32   K562     7.653495
# s1d1_CGTACGGGTTCCTGTG-1 s1d1_CGTACGGGTTCCTGTG-1 1149  21   K562     7.046647
# s1d1_AACTTAGTCGGTTTGG-1 s1d1_AACTTAGTCGGTTTGG-1 1305  22   K562     7.173958
# s1d1_CCCAACCGTCTTACTA-1 s1d1_CCCAACCGTCTTACTA-1 2204  33   K562     7.698029
# s1d1_CTGTTTAGTGAATCGC-1 s1d1_CTGTTTAGTGAATCGC-1 2010  36   K562     7.605890
# s1d1_TCCTCACAGTTAGTGC-1 s1d1_TCCTCACAGTTAGTGC-1  958  13   K562     6.864848
# s1d1_TGTAAGTGTTTGCGCC-1 s1d1_TGTAAGTGTTTGCGCC-1 1931  27   K562     7.565793
# s1d1_TCACTGACAACACCTA-1 s1d1_TCACTGACAACACCTA-1 2425  46   K562     7.793587
# ⋮                       ⋮                       ⋮    ⋮     ⋮        ⋮
# s4d9_TTGGATTCATTGCGAC-1 s4d9_TTGGATTCATTGCGAC-1 1129  59   K562     7.029088
# s4d9_CAAACCGTCCAAATCA-1 s4d9_CAAACCGTCCAAATCA-1  964  53   K562     6.871091
# s4d9_AGAGGAACAGTTAGCC-1 s4d9_AGAGGAACAGTTAGCC-1  883  59   K562     6.783325
# s4d9_GGGCCTAGTGGTGAGA-1 s4d9_GGGCCTAGTGGTGAGA-1  769  25   K562     6.645091
# s4d9_GAGCTGCTCCTTGAGG-1 s4d9_GAGCTGCTCCTTGAGG-1  846  60   K562     6.740519
# s4d9_TTGCATTTCCCTCTAA-1 s4d9_TTGCATTTCCCTCTAA-1  560  22   K562     6.327937
# s4d9_AACATTGTCCCTGGTT-1 s4d9_AACATTGTCCCTGGTT-1 1282  64   K562     7.156177
# s4d9_CTGTTTAGTCACAAAT-1 s4d9_CTGTTTAGTCACAAAT-1  925  61   K562     6.829794
# s4d9_AGGCGGATCACAGCGC-1 s4d9_AGGCGGATCACAGCGC-1  874  73   K562     6.773080
# s4d9_ACCCGCTGTTAGTGAT-1 s4d9_ACCCGCTGTTAGTGAT-1 1180 106   K562     7.073270
# s4d9_TCTCGCCCAGCATGAG-1 s4d9_TCTCGCCCAGCATGAG-1  902   7   K562     6.804615
# s4d9_GGCGTTATCATTTGCT-1 s4d9_GGCGTTATCATTTGCT-1 1009  68   K562     6.916715
# s4d9_CATCACACACGAATCC-1 s4d9_CATCACACACGAATCC-1  957  58   K562     6.863803
# s4d9_CAAGTTATCATTAGCA-1 s4d9_CAAGTTATCATTAGCA-1 2696 171   K562     7.899524
# s4d9_CTTAGGAGTGTTGCAA-1 s4d9_CTTAGGAGTGTTGCAA-1  683  48   K562     6.526495
# s4d9_AACTGTTCAAATTCGT-1 s4d9_AACTGTTCAAATTCGT-1 1147  93   K562     7.044905
# s4d9_CTATGTTTCAATGAGG-1 s4d9_CTATGTTTCAATGAGG-1  905  63   K562     6.807935
# s4d9_CTGCTACTCAGGTCCA-1 s4d9_CTGCTACTCAGGTCCA-1 1234  55   K562     7.118016
# s4d9_GCTTACCTCTCTAGCC-1 s4d9_GCTTACCTCTCTAGCC-1 1002  51   K562     6.909753
# s4d9_AGCATCCCAATCGCAC-1 s4d9_AGCATCCCAATCGCAC-1  722  26   K562     6.582025
# s4d9_ATCCTGACAATAGTCT-1 s4d9_ATCCTGACAATAGTCT-1 1212  55   K562     7.100027
# s4d9_GGTAATTGTACGGTAC-1 s4d9_GGTAATTGTACGGTAC-1 1005  83   K562     6.912743
# s4d9_TTTGTGGCATAAAGCA-1 s4d9_TTTGTGGCATAAAGCA-1  941  78   K562     6.846943
# s4d9_CATCCCAGTCTCACTG-1 s4d9_CATCCCAGTCTCACTG-1 1285  91   K562     7.158514
# s4d9_TACCTCATCATGCGTG-1 s4d9_TACCTCATCATGCGTG-1  995 105   K562     6.902743
# s4d9_TATGGCCCAGGCTACT-1 s4d9_TATGGCCCAGGCTACT-1 1122 161   K562     7.022868
# s4d9_ATTGAAGCACATTGCA-1 s4d9_ATTGAAGCACATTGCA-1  607  49   K562     6.408529
# s4d9_TGAACAACAGTGAACG-1 s4d9_TGAACAACAGTGAACG-1  705  60   K562     6.558198
# s4d9_CGATTCCTCCTGGCTT-1 s4d9_CGATTCCTCCTGGCTT-1  884  37   K562     6.784457
# s4d9_GCTGTACCACCGTTCC-1 s4d9_GCTGTACCACCGTTCC-1  740  98   K562     6.606650
#                         percent.mito
# s1d1_CCGCACACAGGTTAAA-1 0.013837083
# s1d1_TCATTTGGTAATGGAA-1 0.015491867
# s1d1_ATGTGAGAGGCGAAAC-1 0.016873890
# s1d1_CGCTTCTAGTGACCTG-1 0.010606953
# s1d1_GAGCTGCTCTTGTCCA-1 0.016599372
# s1d1_GTTACTAAGGTGAAGC-1 0.020380435
# s1d1_GCCTTAGAGCTAAGTC-1 0.023985240
# s1d1_CTTGTAAAGATAAAGC-1 0.017527675
# s1d1_ACGCTTGAGTCATCCC-1 0.024014778
# s1d1_TAGCGCGGTCAATACG-1 0.026558891
# s1d1_CTAAAGCTCGCTAAAC-1 0.011470985
# s1d1_GTGTGTTAGTAGCTTA-1 0.009966777
# s1d1_CTTGCGCGTTAGGCTA-1 0.025997582
# s1d1_CCATTGTGTTACATCC-1 0.010658307
# s1d1_GACCGAACACAATGTT-1 0.015769944
# s1d1_TCATAACCATAATCCG-1 0.016912669
# s1d1_TACGGATTCTGCAACG-1 0.020781082
# s1d1_GGGCTAACACGAATTT-1 0.025104603
# s1d1_CGTCCTAGTTGAAGCC-1 0.016055846
# s1d1_CCATTGTGTAGGTTAT-1 0.017335315
# s1d1_TGCATGAGTATTGTCC-1 0.016571970
# s1d1_TGGTTGAGTGAACAAA-1 0.051497006
# s1d1_ATGCAAACAAAGGCCA-1 0.015180266
# s1d1_CGTACGGGTTCCTGTG-1 0.018276762
# s1d1_AACTTAGTCGGTTTGG-1 0.016858238
# s1d1_CCCAACCGTCTTACTA-1 0.014972777
# s1d1_CTGTTTAGTGAATCGC-1 0.017910448
# s1d1_TCCTCACAGTTAGTGC-1 0.013569937
# s1d1_TGTAAGTGTTTGCGCC-1 0.013982393
# s1d1_TCACTGACAACACCTA-1 0.018969072
# ⋮                       ⋮
# s4d9_TTGGATTCATTGCGAC-1 0.052258636
# s4d9_CAAACCGTCCAAATCA-1 0.054979253
# s4d9_AGAGGAACAGTTAGCC-1 0.066817667
# s4d9_GGGCCTAGTGGTGAGA-1 0.032509753
# s4d9_GAGCTGCTCCTTGAGG-1 0.070921986
# s4d9_TTGCATTTCCCTCTAA-1 0.039285714
# s4d9_AACATTGTCCCTGGTT-1 0.049921997
# s4d9_CTGTTTAGTCACAAAT-1 0.065945946
# s4d9_AGGCGGATCACAGCGC-1 0.083524027
# s4d9_ACCCGCTGTTAGTGAT-1 0.089830508
# s4d9_TCTCGCCCAGCATGAG-1 0.007760532
# s4d9_GGCGTTATCATTTGCT-1 0.067393459
# s4d9_CATCACACACGAATCC-1 0.060606061
# s4d9_CAAGTTATCATTAGCA-1 0.063427300
# s4d9_CTTAGGAGTGTTGCAA-1 0.070278184
# s4d9_AACTGTTCAAATTCGT-1 0.081081081
# s4d9_CTATGTTTCAATGAGG-1 0.069613260
# s4d9_CTGCTACTCAGGTCCA-1 0.044570502
# s4d9_GCTTACCTCTCTAGCC-1 0.050898204
# s4d9_AGCATCCCAATCGCAC-1 0.036011080
# s4d9_ATCCTGACAATAGTCT-1 0.045379538
# s4d9_GGTAATTGTACGGTAC-1 0.082587065
# s4d9_TTTGTGGCATAAAGCA-1 0.082890542
# s4d9_CATCCCAGTCTCACTG-1 0.070817121
# s4d9_TACCTCATCATGCGTG-1 0.105527638
# s4d9_TATGGCCCAGGCTACT-1 0.143493761
# s4d9_ATTGAAGCACATTGCA-1 0.080724876
# s4d9_TGAACAACAGTGAACG-1 0.085106383
# s4d9_CGATTCCTCCTGGCTT-1 0.041855204
# s4d9_GCTGTACCACCGTTCC-1 0.132432432

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
        if (1) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            bs = boot::boot(df2, assoc, R = 100, formula = formula, 
                stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            if (p0 < 0.1 & bs$t0[1] > 0) {
                bs = boot::boot(df2, assoc, R = 500, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/CD8_pos_T.240521//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")
  
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  saveRDS(pairs.E2G.chr.res,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.res)
}

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G.filter2)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = do.call(c,list.res)

# %%
Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res

# %%
df.output = as.data.frame(pairs.E2G.res)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output

# %%
sessionInfo()
