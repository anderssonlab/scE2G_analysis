# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Dendritic.2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Dendritic.25000.240612/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Dendritic/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/Dendritic.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Dendritic.25000.250329/"
celltype = "Dendritic"

# %%
n.cores = 8

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype  log.nUMI
# s1d1_CGGGCTTAGTTGGGCC-1 s1d1_CGGGCTTAGTTGGGCC-1  4108  69   Dendritic 8.320692
# s1d1_GCGCCTTGTGCATTAG-1 s1d1_GCGCCTTGTGCATTAG-1  4749  99   Dendritic 8.465689
# s1d1_AACCGGCTCAACCAAC-1 s1d1_AACCGGCTCAACCAAC-1  3337  42   Dendritic 8.112827
# s1d1_GCTCTGTTCTTGTCTG-1 s1d1_GCTCTGTTCTTGTCTG-1  3464 367   Dendritic 8.150179
# s1d1_GCGCTTGCAACAGCCT-1 s1d1_GCGCTTGCAACAGCCT-1  7028 249   Dendritic 8.857657
# s1d1_CCTAAAGGTTTACCGT-1 s1d1_CCTAAAGGTTTACCGT-1  3765  68   Dendritic 8.233503
# s1d1_CAGGCTGGTCTAACAG-1 s1d1_CAGGCTGGTCTAACAG-1  3205  57   Dendritic 8.072467
# s1d1_CGCTCCATCGCCTGTT-1 s1d1_CGCTCCATCGCCTGTT-1 10145 243   Dendritic 9.224736
# s1d1_CGATTTGCACTGGCTG-1 s1d1_CGATTTGCACTGGCTG-1  3281  38   Dendritic 8.095904
# s1d1_ATTCACTTCGACAAAG-1 s1d1_ATTCACTTCGACAAAG-1  4339  75   Dendritic 8.375399
# s1d1_ACCTGGTCAAATTCGT-1 s1d1_ACCTGGTCAAATTCGT-1  6141 102   Dendritic 8.722743
# s1d1_CTGCTCCCATCCATCT-1 s1d1_CTGCTCCCATCCATCT-1  8352  88   Dendritic 9.030256
# s1d1_AACCGCTCATGTCAAT-1 s1d1_AACCGCTCATGTCAAT-1  4097  65   Dendritic 8.318010
# s1d1_GTACAATGTCGTAATG-1 s1d1_GTACAATGTCGTAATG-1  4703  89   Dendritic 8.455956
# s1d1_AGCGGATAGGCGAATA-1 s1d1_AGCGGATAGGCGAATA-1  4036 168   Dendritic 8.303009
# s1d1_GGTCAGGAGAAGGTGC-1 s1d1_GGTCAGGAGAAGGTGC-1  2959 105   Dendritic 7.992607
# s1d1_TGGCTATAGAAGCTAG-1 s1d1_TGGCTATAGAAGCTAG-1  4628  86   Dendritic 8.439880
# s1d1_GCTTAAATCCGCCAAA-1 s1d1_GCTTAAATCCGCCAAA-1  7160 284   Dendritic 8.876265
# s1d1_GTGCTCAAGAATGACG-1 s1d1_GTGCTCAAGAATGACG-1  3757  21   Dendritic 8.231376
# s1d1_TAGTGAGAGCGCATTG-1 s1d1_TAGTGAGAGCGCATTG-1  5796 185   Dendritic 8.664923
# s1d1_GAGGAGGCATGGCCTG-1 s1d1_GAGGAGGCATGGCCTG-1  8988 103   Dendritic 9.103646
# s1d1_ACTTACTTCCTCCTAA-1 s1d1_ACTTACTTCCTCCTAA-1  7657 130   Dendritic 8.943376
# s1d1_GATTACGGTCCCGAAG-1 s1d1_GATTACGGTCCCGAAG-1  4452  81   Dendritic 8.401109
# s1d1_CTTCACTCAAGCTTAT-1 s1d1_CTTCACTCAAGCTTAT-1 14509 574   Dendritic 9.582524
# s1d1_GGTGAGTAGGTCCGTA-1 s1d1_GGTGAGTAGGTCCGTA-1  3108  55   Dendritic 8.041735
# s1d1_TACGTTAAGACAACAG-1 s1d1_TACGTTAAGACAACAG-1  4384  76   Dendritic 8.385717
# s1d1_GCATCCTTCGCTCACT-1 s1d1_GCATCCTTCGCTCACT-1 11279 301   Dendritic 9.330698
# s1d1_CGTCAATAGTTCCCGT-1 s1d1_CGTCAATAGTTCCCGT-1  4903 157   Dendritic 8.497603
# s1d1_GATGCTTAGGATAAAC-1 s1d1_GATGCTTAGGATAAAC-1  7071 261   Dendritic 8.863757
# s1d1_TGTGGCGGTCGTAATG-1 s1d1_TGTGGCGGTCGTAATG-1  3209  81   Dendritic 8.073715
# ⋮                       ⋮                       ⋮     ⋮     ⋮         ⋮
# s4d9_GTGATGAAGGTCCGTA-1 s4d9_GTGATGAAGGTCCGTA-1 2284  272   Dendritic 7.733684
# s4d9_GATCAAGAGCGCCTTT-1 s4d9_GATCAAGAGCGCCTTT-1 2346  440   Dendritic 7.760467
# s4d9_GTACGTAGTGTGCAAC-1 s4d9_GTACGTAGTGTGCAAC-1 1658  171   Dendritic 7.413367
# s4d9_TTGGGTTAGGCTGTGC-1 s4d9_TTGGGTTAGGCTGTGC-1 3334  317   Dendritic 8.111928
# s4d9_TAAACAGCAAAGCGGC-1 s4d9_TAAACAGCAAAGCGGC-1 1383  116   Dendritic 7.232010
# s4d9_GATTTGCAGTAGAGGC-1 s4d9_GATTTGCAGTAGAGGC-1 1169  109   Dendritic 7.063904
# s4d9_TAGGAGGGTCCTAATC-1 s4d9_TAGGAGGGTCCTAATC-1 1298  162   Dendritic 7.168580
# s4d9_TCTCGCCCATGTTGTG-1 s4d9_TCTCGCCCATGTTGTG-1  933  145   Dendritic 6.838405
# s4d9_GTTTATCTCTGTGCCT-1 s4d9_GTTTATCTCTGTGCCT-1 2083  188   Dendritic 7.641564
# s4d9_GTTGGCGGTGTTTGAG-1 s4d9_GTTGGCGGTGTTTGAG-1 2055  140   Dendritic 7.628031
# s4d9_ACATCATCAACTGGCT-1 s4d9_ACATCATCAACTGGCT-1 3003  351   Dendritic 8.007367
# s4d9_AGAACCAAGGTATTGC-1 s4d9_AGAACCAAGGTATTGC-1 3663  419   Dendritic 8.206038
# s4d9_TGTGTTAAGCTCCTTA-1 s4d9_TGTGTTAAGCTCCTTA-1 3313   68   Dendritic 8.105609
# s4d9_GATCGAGCAGGAATCG-1 s4d9_GATCGAGCAGGAATCG-1  589   39   Dendritic 6.378426
# s4d9_ATTGTCCGTAATGGAA-1 s4d9_ATTGTCCGTAATGGAA-1 1407   97   Dendritic 7.249215
# s4d9_AGTGCCGGTAATGACT-1 s4d9_AGTGCCGGTAATGACT-1 3003  381   Dendritic 8.007367
# s4d9_TATAACCCATTAAAGG-1 s4d9_TATAACCCATTAAAGG-1 3255  322   Dendritic 8.087948
# s4d9_CGTGCTTTCCTTTACG-1 s4d9_CGTGCTTTCCTTTACG-1 2620  196   Dendritic 7.870930
# s4d9_ACAGGATCATTGTTGG-1 s4d9_ACAGGATCATTGTTGG-1 1967  210   Dendritic 7.584265
# s4d9_GTCAATATCTAACTGA-1 s4d9_GTCAATATCTAACTGA-1 5153  587   Dendritic 8.547334
# s4d9_GTAAGCAAGGACGTAA-1 s4d9_GTAAGCAAGGACGTAA-1 2138  154   Dendritic 7.667626
# s4d9_CCCGCTTCACAACAAA-1 s4d9_CCCGCTTCACAACAAA-1 3031  167   Dendritic 8.016648
# s4d9_AAACCGAAGGACCTTG-1 s4d9_AAACCGAAGGACCTTG-1 4558  769   Dendritic 8.424639
# s4d9_ACCTCACTCTAAGTCA-1 s4d9_ACCTCACTCTAAGTCA-1 2718  379   Dendritic 7.907652
# s4d9_GAAGCTAAGGCAACAA-1 s4d9_GAAGCTAAGGCAACAA-1 3665  256   Dendritic 8.206584
# s4d9_CACTGACCAAATACCT-1 s4d9_CACTGACCAAATACCT-1 3396  168   Dendritic 8.130354
# s4d9_CCTGTATGTGCAATGC-1 s4d9_CCTGTATGTGCAATGC-1 1999  182   Dendritic 7.600402
# s4d9_GTGTGTTAGAAAGCAT-1 s4d9_GTGTGTTAGAAAGCAT-1  844   41   Dendritic 6.738152
# s4d9_GGCTATTAGCTTACTT-1 s4d9_GGCTATTAGCTTACTT-1 2912  356   Dendritic 7.976595
# s4d9_ACACTTGCAACTAGAA-1 s4d9_ACACTTGCAACTAGAA-1 1449   94   Dendritic 7.278629
#                         percent.mito
# s1d1_CGGGCTTAGTTGGGCC-1 0.016796495
# s1d1_GCGCCTTGTGCATTAG-1 0.020846494
# s1d1_AACCGGCTCAACCAAC-1 0.012586155
# s1d1_GCTCTGTTCTTGTCTG-1 0.105946882
# s1d1_GCGCTTGCAACAGCCT-1 0.035429710
# s1d1_CCTAAAGGTTTACCGT-1 0.018061089
# s1d1_CAGGCTGGTCTAACAG-1 0.017784711
# s1d1_CGCTCCATCGCCTGTT-1 0.023952686
# s1d1_CGATTTGCACTGGCTG-1 0.011581835
# s1d1_ATTCACTTCGACAAAG-1 0.017285089
# s1d1_ACCTGGTCAAATTCGT-1 0.016609673
# s1d1_CTGCTCCCATCCATCT-1 0.010536398
# s1d1_AACCGCTCATGTCAAT-1 0.015865267
# s1d1_GTACAATGTCGTAATG-1 0.018924091
# s1d1_AGCGGATAGGCGAATA-1 0.041625372
# s1d1_GGTCAGGAGAAGGTGC-1 0.035484961
# s1d1_TGGCTATAGAAGCTAG-1 0.018582541
# s1d1_GCTTAAATCCGCCAAA-1 0.039664804
# s1d1_GTGCTCAAGAATGACG-1 0.005589566
# s1d1_TAGTGAGAGCGCATTG-1 0.031918565
# s1d1_GAGGAGGCATGGCCTG-1 0.011459724
# s1d1_ACTTACTTCCTCCTAA-1 0.016977929
# s1d1_GATTACGGTCCCGAAG-1 0.018194070
# s1d1_CTTCACTCAAGCTTAT-1 0.039561651
# s1d1_GGTGAGTAGGTCCGTA-1 0.017696268
# s1d1_TACGTTAAGACAACAG-1 0.017335766
# s1d1_GCATCCTTCGCTCACT-1 0.026686763
# s1d1_CGTCAATAGTTCCCGT-1 0.032021212
# s1d1_GATGCTTAGGATAAAC-1 0.036911328
# s1d1_TGTGGCGGTCGTAATG-1 0.025241508
# ⋮                       ⋮
# s4d9_GTGATGAAGGTCCGTA-1 0.11908932
# s4d9_GATCAAGAGCGCCTTT-1 0.18755328
# s4d9_GTACGTAGTGTGCAAC-1 0.10313631
# s4d9_TTGGGTTAGGCTGTGC-1 0.09508098
# s4d9_TAAACAGCAAAGCGGC-1 0.08387563
# s4d9_GATTTGCAGTAGAGGC-1 0.09324209
# s4d9_TAGGAGGGTCCTAATC-1 0.12480740
# s4d9_TCTCGCCCATGTTGTG-1 0.15541265
# s4d9_GTTTATCTCTGTGCCT-1 0.09025444
# s4d9_GTTGGCGGTGTTTGAG-1 0.06812652
# s4d9_ACATCATCAACTGGCT-1 0.11688312
# s4d9_AGAACCAAGGTATTGC-1 0.11438711
# s4d9_TGTGTTAAGCTCCTTA-1 0.02052520
# s4d9_GATCGAGCAGGAATCG-1 0.06621392
# s4d9_ATTGTCCGTAATGGAA-1 0.06894101
# s4d9_AGTGCCGGTAATGACT-1 0.12687313
# s4d9_TATAACCCATTAAAGG-1 0.09892473
# s4d9_CGTGCTTTCCTTTACG-1 0.07480916
# s4d9_ACAGGATCATTGTTGG-1 0.10676157
# s4d9_GTCAATATCTAACTGA-1 0.11391422
# s4d9_GTAAGCAAGGACGTAA-1 0.07202993
# s4d9_CCCGCTTCACAACAAA-1 0.05509733
# s4d9_AAACCGAAGGACCTTG-1 0.16871435
# s4d9_ACCTCACTCTAAGTCA-1 0.13944077
# s4d9_GAAGCTAAGGCAACAA-1 0.06984993
# s4d9_CACTGACCAAATACCT-1 0.04946996
# s4d9_CCTGTATGTGCAATGC-1 0.09104552
# s4d9_GTGTGTTAGAAAGCAT-1 0.04857820
# s4d9_GGCTATTAGCTTACTT-1 0.12225275
# s4d9_ACACTTGCAACTAGAA-1 0.06487233

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 23119 ranges and 11 metadata columns:
#                                   seqnames              ranges strand |
#                                      <Rle>           <IRanges>  <Rle> |
#    chr1-100046477-100047244_SASS6     chr1 100046477-100047244      * |
#      chr1-10066573-10067824_KIF1B     chr1   10066573-10067824      * |
#   chr1-100894613-100896989_CDC14A     chr1 100894613-100896989      * |
#     chr1-101238820-101239071_RTCA     chr1 101238820-101239071      * |
#   chr1-101247540-101248452_CDC14A     chr1 101247540-101248452      * |
#                               ...      ...                 ...    ... .
#          chrX-7926909-7928046_STS     chrX     7926909-7928046      * |
#        chrX-9352376-9353440_TBL1X     chrX     9352376-9353440      * |
#        chrX-9456284-9457059_TBL1X     chrX     9456284-9457059      * |
#        chrX-9676955-9677839_TBL1X     chrX     9676955-9677839      * |
#        chrX-989889-990634_SLC25A6     chrX       989889-990634      * |
#                                    TargetGene               PeakName
#                                   <character>            <character>
#    chr1-100046477-100047244_SASS6       SASS6 chr1-100046477-10004..
#      chr1-10066573-10067824_KIF1B       KIF1B chr1-10066573-10067824
#   chr1-100894613-100896989_CDC14A      CDC14A chr1-100894613-10089..
#     chr1-101238820-101239071_RTCA        RTCA chr1-101238820-10123..
#   chr1-101247540-101248452_CDC14A      CDC14A chr1-101247540-10124..
#                               ...         ...                    ...
#          chrX-7926909-7928046_STS         STS   chrX-7926909-7928046
#        chrX-9352376-9353440_TBL1X       TBL1X   chrX-9352376-9353440
#        chrX-9456284-9457059_TBL1X       TBL1X   chrX-9456284-9457059
#        chrX-9676955-9677839_TBL1X       TBL1X   chrX-9676955-9677839
#        chrX-989889-990634_SLC25A6     SLC25A6     chrX-989889-990634
#                                                 PairName      beta        se
#                                              <character> <numeric> <numeric>
#    chr1-100046477-100047244_SASS6 chr1-100046477-10004..  0.614980 0.2395692
#      chr1-10066573-10067824_KIF1B chr1-10066573-100678..  0.556118 0.1099184
#   chr1-100894613-100896989_CDC14A chr1-100894613-10089..  0.234676 0.0401784
#     chr1-101238820-101239071_RTCA chr1-101238820-10123..  0.585305 0.1638759
#   chr1-101247540-101248452_CDC14A chr1-101247540-10124..  0.291799 0.0697937
#                               ...                    ...       ...       ...
#          chrX-7926909-7928046_STS chrX-7926909-7928046..  0.497851 0.1718793
#        chrX-9352376-9353440_TBL1X chrX-9352376-9353440..  0.372323 0.0925985
#        chrX-9456284-9457059_TBL1X chrX-9456284-9457059..  0.387881 0.1033432
#        chrX-9676955-9677839_TBL1X chrX-9676955-9677839..  0.594999 0.0822171
#        chrX-989889-990634_SLC25A6 chrX-989889-990634_S.. -0.320804 0.0683994
#                                           z           p boot_basic_p
#                                   <numeric>   <numeric>    <numeric>
#    chr1-100046477-100047244_SASS6   2.56703 1.02575e-02      0.00656
#      chr1-10066573-10067824_KIF1B   5.05938 4.20630e-07      0.00008
#   chr1-100894613-100896989_CDC14A   5.84086 5.19315e-09      0.00008
#     chr1-101238820-101239071_RTCA   3.57164 3.54757e-04      0.00072
#   chr1-101247540-101248452_CDC14A   4.18088 2.90387e-05      0.00456
#                               ...       ...         ...          ...
#          chrX-7926909-7928046_STS   2.89651 3.77335e-03      0.00720
#        chrX-9352376-9353440_TBL1X   4.02084 5.79915e-05      0.00040
#        chrX-9456284-9457059_TBL1X   3.75333 1.74502e-04      0.00336
#        chrX-9676955-9677839_TBL1X   7.23692 4.58995e-13      0.00008
#        chrX-989889-990634_SLC25A6  -4.69016 2.72995e-06      0.00360
#                                   boot_basic_p.log10      sign
#                                            <numeric> <numeric>
#    chr1-100046477-100047244_SASS6            2.18310         1
#      chr1-10066573-10067824_KIF1B            4.09691         1
#   chr1-100894613-100896989_CDC14A            4.09691         1
#     chr1-101238820-101239071_RTCA            3.14267         1
#   chr1-101247540-101248452_CDC14A            2.34104         1
#                               ...                ...       ...
#          chrX-7926909-7928046_STS            2.14267         1
#        chrX-9352376-9353440_TBL1X            3.39794         1
#        chrX-9456284-9457059_TBL1X            2.47366         1
#        chrX-9676955-9677839_TBL1X            4.09691         1
#        chrX-989889-990634_SLC25A6            2.44370        -1
#                                   boot_basic_p.log10.signed
#                                                   <numeric>
#    chr1-100046477-100047244_SASS6                   2.18310
#      chr1-10066573-10067824_KIF1B                   4.09691
#   chr1-100894613-100896989_CDC14A                   4.09691
#     chr1-101238820-101239071_RTCA                   3.14267
#   chr1-101247540-101248452_CDC14A                   2.34104
#                               ...                       ...
#          chrX-7926909-7928046_STS                   2.14267
#        chrX-9352376-9353440_TBL1X                   3.39794
#        chrX-9456284-9457059_TBL1X                   2.47366
#        chrX-9676955-9677839_TBL1X                   4.09691
#        chrX-989889-990634_SLC25A6                  -2.44370
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  3312 22247

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 533980 ranges and 11 metadata columns:
#                                   seqnames              ranges strand |
#                                      <Rle>           <IRanges>  <Rle> |
#                    chr1.chr1.chr1     chr1     1001820-1002126      * |
#                    chr1.chr1.chr1     chr1 100712622-100713915      * |
#                    chr1.chr1.chr1     chr1 101025254-101026528      * |
#                    chr1.chr1.chr1     chr1 108557323-108557589      * |
#                    chr1.chr1.chr1     chr1 108956405-108957155      * |
#                               ...      ...                 ...    ... .
#     chrX.chrX-7926909-7928046_STS     chrX     7926909-7928046      * |
#   chrX.chrX-9352376-9353440_TBL1X     chrX     9352376-9353440      * |
#   chrX.chrX-9456284-9457059_TBL1X     chrX     9456284-9457059      * |
#   chrX.chrX-9676955-9677839_TBL1X     chrX     9676955-9677839      * |
#   chrX.chrX-989889-990634_SLC25A6     chrX       989889-990634      * |
#                                    TargetGene               PeakName
#                                   <character>            <character>
#                    chr1.chr1.chr1      CDK11B   chr1-1001820-1002126
#                    chr1.chr1.chr1         AGL chr1-100712622-10071..
#                    chr1.chr1.chr1      CDC14A chr1-101025254-10102..
#                    chr1.chr1.chr1       TAF13 chr1-108557323-10855..
#                    chr1.chr1.chr1     FAM102B chr1-108956405-10895..
#                               ...         ...                    ...
#     chrX.chrX-7926909-7928046_STS         STS   chrX-7926909-7928046
#   chrX.chrX-9352376-9353440_TBL1X       TBL1X   chrX-9352376-9353440
#   chrX.chrX-9456284-9457059_TBL1X       TBL1X   chrX-9456284-9457059
#   chrX.chrX-9676955-9677839_TBL1X       TBL1X   chrX-9676955-9677839
#   chrX.chrX-989889-990634_SLC25A6     SLC25A6     chrX-989889-990634
#                                                 PairName      beta        se
#                                              <character> <numeric> <numeric>
#                    chr1.chr1.chr1 chr1-1001820-1002126..  0.344822 0.1334200
#                    chr1.chr1.chr1 chr1-100712622-10071..  0.488849 0.1783817
#                    chr1.chr1.chr1 chr1-101025254-10102..  0.157311 0.0430656
#                    chr1.chr1.chr1 chr1-108557323-10855..  0.541722 0.1898833
#                    chr1.chr1.chr1 chr1-108956405-10895.. -0.480898 0.1326958
#                               ...                    ...       ...       ...
#     chrX.chrX-7926909-7928046_STS chrX-7926909-7928046..  0.497851 0.1718793
#   chrX.chrX-9352376-9353440_TBL1X chrX-9352376-9353440..  0.372323 0.0925985
#   chrX.chrX-9456284-9457059_TBL1X chrX-9456284-9457059..  0.387881 0.1033432
#   chrX.chrX-9676955-9677839_TBL1X chrX-9676955-9677839..  0.594999 0.0822171
#   chrX.chrX-989889-990634_SLC25A6 chrX-989889-990634_S.. -0.320804 0.0683994
#                                           z           p boot_basic_p
#                                   <numeric>   <numeric>    <numeric>
#                    chr1.chr1.chr1   2.58449 0.009752372      0.01088
#                    chr1.chr1.chr1   2.74047 0.006135227      0.01128
#                    chr1.chr1.chr1   3.65282 0.000259380      0.01024
#                    chr1.chr1.chr1   2.85292 0.004331920      0.01112
#                    chr1.chr1.chr1  -3.62407 0.000290008      0.00912
#                               ...       ...         ...          ...
#     chrX.chrX-7926909-7928046_STS   2.89651 3.77335e-03      0.00720
#   chrX.chrX-9352376-9353440_TBL1X   4.02084 5.79915e-05      0.00040
#   chrX.chrX-9456284-9457059_TBL1X   3.75333 1.74502e-04      0.00336
#   chrX.chrX-9676955-9677839_TBL1X   7.23692 4.58995e-13      0.00008
#   chrX.chrX-989889-990634_SLC25A6  -4.69016 2.72995e-06      0.00360
#                                   boot_basic_p.log10      sign
#                                            <numeric> <numeric>
#                    chr1.chr1.chr1            1.96337         1
#                    chr1.chr1.chr1            1.94769         1
#                    chr1.chr1.chr1            1.98970         1
#                    chr1.chr1.chr1            1.95390         1
#                    chr1.chr1.chr1            2.04001        -1
#                               ...                ...       ...
#     chrX.chrX-7926909-7928046_STS            2.14267         1
#   chrX.chrX-9352376-9353440_TBL1X            3.39794         1
#   chrX.chrX-9456284-9457059_TBL1X            2.47366         1
#   chrX.chrX-9676955-9677839_TBL1X            4.09691         1
#   chrX.chrX-989889-990634_SLC25A6            2.44370        -1
#                                   boot_basic_p.log10.signed
#                                                   <numeric>
#                    chr1.chr1.chr1                   1.96337
#                    chr1.chr1.chr1                   1.94769
#                    chr1.chr1.chr1                   1.98970
#                    chr1.chr1.chr1                   1.95390
#                    chr1.chr1.chr1                  -2.04001
#                               ...                       ...
#     chrX.chrX-7926909-7928046_STS                   2.14267
#   chrX.chrX-9352376-9353440_TBL1X                   3.39794
#   chrX.chrX-9456284-9457059_TBL1X                   2.47366
#   chrX.chrX-9676955-9677839_TBL1X                   4.09691
#   chrX.chrX-989889-990634_SLC25A6                  -2.44370
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType  beta       se
# 1      chr1   1001820   1002126 CDK11B     Dendritic  0.3448225 0.13342005
# 2      chr1 100712622 100713915 AGL        Dendritic  0.4888488 0.17838169
# 3      chr1 101025254 101026528 CDC14A     Dendritic  0.1573107 0.04306560
# 4      chr1 108557323 108557589 TAF13      Dendritic  0.5417223 0.18988329
# 5      chr1 108956405 108957155 FAM102B    Dendritic -0.4808983 0.13269581
# 6      chr1 109397321 109398342 SARS       Dendritic -0.6303272 0.18274499
# 7      chr1 109493723 109494615 TAF13      Dendritic  0.3443703 0.12613283
# 8      chr1 109509030 109510127 STXBP3     Dendritic  0.2988347 0.11037132
# 9      chr1 110726488 110727426 ATP5F1     Dendritic -1.3517732 0.35652418
# 10     chr1 111733128 111734251 CAPZA1     Dendritic  0.1799429 0.06272724
# 11     chr1 111755006 111756410 ATP5F1     Dendritic -0.2758818 0.08674295
# 12     chr1 112369526 112370205 ST7L       Dendritic  0.4001160 0.15139039
# 13     chr1 112465934 112466860 FAM212B    Dendritic -0.6256161 0.16801466
# 14     chr1 112716324 112716556 CAPZA1     Dendritic  0.1711079 0.06148077
# 15     chr1 112809082 112809866 PPM1J      Dendritic  0.5716316 0.25516840
# 16     chr1 114511770 114512099 BCAS2      Dendritic  0.3474101 0.13958384
# 17     chr1  11654306  11655311 VPS13D     Dendritic  0.1745500 0.05810639
# 18     chr1 117605433 117607075 FAM46C     Dendritic  0.4306031 0.12898038
# 19     chr1 117605433 117607075 TTF2       Dendritic -0.3352009 0.10386489
# 20     chr1 117658431 117659156 FAM46C     Dendritic  0.4818567 0.16110740
# 21     chr1  11893852  11894412 DHRS3      Dendritic  0.6224211 0.25107486
# 22     chr1   1212530   1214250 SSU72      Dendritic -0.3516672 0.12246431
# 23     chr1  12601933  12602458 CLCN6      Dendritic  0.5555766 0.24966222
# 24     chr1 146938200 146939423 NOTCH2NL   Dendritic  0.3870141 0.14797002
# 25     chr1 149813197 149813824 ANP32E     Dendritic -0.8584232 0.25112531
# 26     chr1 149927330 149928545 ENSA       Dendritic  0.1848096 0.06130761
# 27     chr1 150163025 150163574 APH1A      Dendritic -0.6882986 0.19524396
# 28     chr1 150551044 150551374 ENSA       Dendritic  0.2544352 0.09106482
# 29     chr1 150567316 150568504 C1orf56    Dendritic -0.6148327 0.20461771
# 30     chr1 150787854 150788376 MRPL9      Dendritic  0.5354815 0.21836832
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮         ⋮          ⋮
# 533951 chrX 71532021  71532456  OGT        Dendritic  0.2102644 0.05983663
# 533952 chrX 71532515  71533413  RPS4X      Dendritic -0.2128586 0.02972288
# 533953 chrX 71618228  71618862  MED12      Dendritic  0.5224386 0.20531058
# 533954 chrX 71622556  71623113  OGT        Dendritic  0.2111964 0.06173990
# 533955 chrX 71623254  71623794  OGT        Dendritic  0.3134607 0.06598015
# 533956 chrX 71636258  71637433  OGT        Dendritic  0.2771188 0.05479168
# 533957 chrX 71670935  71672259  RPS4X      Dendritic -0.5088741 0.04984755
# 533958 chrX 71992462  71993307  OGT        Dendritic  0.3991966 0.06866696
# 533959 chrX 72018186  72019077  RPS4X      Dendritic -0.2715322 0.03455156
# 533960 chrX 72126446  72127050  RPS4X      Dendritic -0.5641430 0.05285749
# 533961 chrX 72180985  72182200  RPS4X      Dendritic -0.2327911 0.02932926
# 533962 chrX 72572192  72573522  RPS4X      Dendritic -0.4426945 0.05117390
# 533963 chrX 73850928  73851948  CHIC1      Dendritic  0.6197965 0.21566615
# 533964 chrX 73850928  73851948  JPX        Dendritic  0.2724590 0.07684503
# 533965 chrX 73850928  73851948  XIST       Dendritic  0.7111402 0.03683705
# 533966 chrX 73943747  73944626  XIST       Dendritic  0.3706783 0.03634364
# 533967 chrX 74293401  74293731  UPRT       Dendritic  0.8268803 0.25081985
# 533968 chrX 74535250  74537422  RLIM       Dendritic  0.2928704 0.09698602
# 533969 chrX 74535250  74537422  UPRT       Dendritic  0.7278234 0.20209976
# 533970 chrX 74550090  74550806  ABCB7      Dendritic  0.3346721 0.10544849
# 533971 chrX 74550090  74550806  XIST       Dendritic  0.3058532 0.04630938
# 533972 chrX 74613876  74615030  ABCB7      Dendritic  0.2295248 0.07814561
# 533973 chrX 77910277  77911191  PGK1       Dendritic -0.3043781 0.07495314
# 533974 chrX 78383329  78384319  CYSLTR1    Dendritic  0.5666954 0.15295374
# 533975 chrX 78944894  78945853  PGK1       Dendritic -0.3579363 0.10316594
# 533976 chrX  7926909   7928046  STS        Dendritic  0.4978505 0.17187927
# 533977 chrX  9352376   9353440  TBL1X      Dendritic  0.3723234 0.09259847
# 533978 chrX  9456284   9457059  TBL1X      Dendritic  0.3878810 0.10334319
# 533979 chrX  9676955   9677839  TBL1X      Dendritic  0.5949988 0.08221715
# 533980 chrX   989889    990634  SLC25A6    Dendritic -0.3208037 0.06839935
#        z          p            boot_basic_p boot_basic_p.log10 sign
# 1       2.584488  0.0097523722 0.01088      1.963371            1
# 2       2.740465  0.0061352273 0.01128      1.947691            1
# 3       3.652816  0.0002593801 0.01024      1.989700            1
# 4       2.852922  0.0043319200 0.01112      1.953895            1
# 5      -3.624065  0.0002900082 0.00912      2.040005           -1
# 6      -3.449217  0.0005622137 0.00392      2.406714           -1
# 7       2.730219  0.0063292197 0.00952      2.021363            1
# 8       2.707539  0.0067784067 0.01224      1.912219            1
# 9      -3.791533  0.0001497202 0.01320      1.879426           -1
# 10      2.868657  0.0041221806 0.00808      2.092589            1
# 11     -3.180452  0.0014704569 0.00720      2.142668           -1
# 12      2.642942  0.0082189157 0.00592      2.227678            1
# 13     -3.723580  0.0001964173 0.00368      2.434152           -1
# 14      2.783113  0.0053840128 0.00952      2.021363            1
# 15      2.240213  0.0250770914 0.01288      1.890084            1
# 16      2.488899  0.0128139338 0.00968      2.014125            1
# 17      3.003972  0.0026647978 0.00848      2.071604            1
# 18      3.338517  0.0008422700 0.00672      2.172631            1
# 19     -3.227278  0.0012497408 0.00952      2.021363           -1
# 20      2.990904  0.0027815321 0.00328      2.484126            1
# 21      2.479026  0.0131741662 0.01152      1.938548            1
# 22     -2.871589  0.0040841330 0.01208      1.917933           -1
# 23      2.225313  0.0260602264 0.00960      2.017729            1
# 24      2.615490  0.0089099527 0.00704      2.152427            1
# 25     -3.418306  0.0006301215 0.00808      2.092589           -1
# 26      3.014464  0.0025743392 0.00904      2.043832            1
# 27     -3.525326  0.0004229618 0.00672      2.172631           -1
# 28      2.794001  0.0052060384 0.00848      2.071604            1
# 29     -3.004787  0.0026576652 0.01592      1.798057           -1
# 30      2.452194  0.0141988099 0.00976      2.010550            1
# ⋮      ⋮          ⋮            ⋮            ⋮                  ⋮
# 533951   3.513974 4.414554e-04 0.00560      2.251812            1
# 533952  -7.161438 7.983490e-13 0.00408      2.389340           -1
# 533953   2.544626 1.093950e-02 0.00728      2.137869            1
# 533954   3.420745 6.244989e-04 0.00352      2.453457            1
# 533955   4.750833 2.025800e-06 0.00008      4.096910            1
# 533956   5.057681 4.243866e-07 0.00008      4.096910            1
# 533957 -10.208607 1.814502e-24 0.00008      4.096910           -1
# 533958   5.813518 6.117343e-09 0.00008      4.096910            1
# 533959  -7.858752 3.879789e-15 0.00416      2.380907           -1
# 533960 -10.672905 1.362970e-26 0.00032      3.494850           -1
# 533961  -7.937162 2.068604e-15 0.00080      3.096910           -1
# 533962  -8.650787 5.114539e-18 0.00144      2.841638           -1
# 533963   2.873870 4.054756e-03 0.00392      2.406714            1
# 533964   3.545564 3.917739e-04 0.00688      2.162412            1
# 533965  19.305026 4.873071e-83 0.00008      4.096910            1
# 533966  10.199260 1.997886e-24 0.00008      4.096910            1
# 533967   3.296710 9.782451e-04 0.00280      2.552842            1
# 533968   3.019717 2.530109e-03 0.00304      2.517126            1
# 533969   3.601308 3.166206e-04 0.00624      2.204815            1
# 533970   3.173797 1.504588e-03 0.00088      3.055517            1
# 533971   6.604562 3.986945e-11 0.00008      4.096910            1
# 533972   2.937142 3.312525e-03 0.00648      2.188425            1
# 533973  -4.060913 4.888125e-05 0.00104      2.982967           -1
# 533974   3.705012 2.113807e-04 0.00008      4.096910            1
# 533975  -3.469520 5.213891e-04 0.00616      2.210419           -1
# 533976   2.896513 3.773352e-03 0.00720      2.142668            1
# 533977   4.020838 5.799148e-05 0.00040      3.397940            1
# 533978   3.753329 1.745015e-04 0.00336      2.473661            1
# 533979   7.236918 4.589945e-13 0.00008      4.096910            1
# 533980  -4.690157 2.729955e-06 0.00360      2.443697           -1
#        boot_basic_p.log10.signed FDR
# 1       1.963371                 0.2257332
# 2       1.947691                 0.2270713
# 3       1.989700                 0.2200845
# 4       1.953895                 0.2257332
# 5      -2.040005                 0.2085073
# 6      -2.406714                 0.1295058
# 7       2.021363                 0.2144118
# 8       1.912219                 0.2349865
# 9      -1.879426                 0.2424265
# 10      2.092589                 0.1936690
# 11     -2.142668                 0.1808399
# 12      2.227678                 0.1619448
# 13     -2.434152                 0.1250586
# 14      2.021363                 0.2144118
# 15      1.890084                 0.2381627
# 16      2.014125                 0.2168447
# 17      2.071604                 0.1993550
# 18      2.172631                 0.1736268
# 19     -2.021363                 0.2144118
# 20      2.484126                 0.1168571
# 21      1.938548                 0.2309189
# 22     -1.917933                 0.2322655
# 23      2.017729                 0.2155680
# 24      2.152427                 0.1785174
# 25     -2.092589                 0.1936690
# 26      2.043832                 0.2074154
# 27     -2.172631                 0.1736268
# 28      2.071604                 0.1993550
# 29     -1.798057                 0.2601370
# 30      2.010550                 0.2179510
# ⋮      ⋮                         ⋮
# 533951  2.251812                 0.156954021
# 533952 -2.389340                 0.132214978
# 533953  2.137869                 0.182001704
# 533954  2.453457                 0.121657579
# 533955  4.096910                 0.009178857
# 533956  4.096910                 0.009178857
# 533957 -4.096910                 0.009178857
# 533958  4.096910                 0.009178857
# 533959 -2.380907                 0.133703912
# 533960 -3.494850                 0.026479715
# 533961 -3.096910                 0.049299942
# 533962 -2.841638                 0.071788927
# 533963  2.406714                 0.129505760
# 533964  2.162412                 0.176040174
# 533965  4.096910                 0.009178857
# 533966  4.096910                 0.009178857
# 533967  2.552842                 0.106598032
# 533968  2.517126                 0.111774372
# 533969  2.204815                 0.166793573
# 533970  3.055517                 0.052497196
# 533971  4.096910                 0.009178857
# 533972  2.188425                 0.170217946
# 533973 -2.982967                 0.058162882
# 533974  4.096910                 0.009178857
# 533975 -2.210419                 0.165541862
# 533976  2.142668                 0.180839887
# 533977  3.397940                 0.030919514
# 533978  2.473661                 0.118325714
# 533979  4.096910                 0.009178857
# 533980 -2.443697                 0.123297287

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
