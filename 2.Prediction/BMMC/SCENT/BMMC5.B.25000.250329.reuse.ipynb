# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.B.2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.B.25000.240612/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/B/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/B.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.B.25000.250329/"
celltype = "B"

# %%
n.cores = 8

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_TAGTTGTCACCCTCAC-1 s1d1_TAGTTGTCACCCTCAC-1  1701  31   B        7.438972
# s1d1_TGGATTGGTTTGCGAA-1 s1d1_TGGATTGGTTTGCGAA-1 16740 295   B        9.725556
# s1d1_GTAAGGTCAATAACCT-1 s1d1_GTAAGGTCAATAACCT-1  2041  52   B        7.621195
# s1d1_GGATTATGTTACATCC-1 s1d1_GGATTATGTTACATCC-1  5014  78   B        8.519989
# s1d1_AACGACAAGTTGTCAA-1 s1d1_AACGACAAGTTGTCAA-1  1477  21   B        7.297768
# s1d1_AGCAATACAATATGGA-1 s1d1_AGCAATACAATATGGA-1  2295  42   B        7.738488
# s1d1_GGGAGTAGTGATTTGG-1 s1d1_GGGAGTAGTGATTTGG-1  2708 106   B        7.903966
# s1d1_CCATAATCATGTCAGC-1 s1d1_CCATAATCATGTCAGC-1  2064  26   B        7.632401
# s1d1_ATCAGGTTCATGACCG-1 s1d1_ATCAGGTTCATGACCG-1  1802  27   B        7.496652
# s1d1_CAGGTCCAGGCTAATC-1 s1d1_CAGGTCCAGGCTAATC-1  1592  33   B        7.372746
# s1d1_TCAGTGAGTGCTCCGT-1 s1d1_TCAGTGAGTGCTCCGT-1  1898  22   B        7.548556
# s1d1_CAAACAACAATAACGA-1 s1d1_CAAACAACAATAACGA-1  1336  24   B        7.197435
# s1d1_ACGCAAGCAATAAGCA-1 s1d1_ACGCAAGCAATAAGCA-1  3027  63   B        8.015327
# s1d1_CATAATCCAGCAGGTA-1 s1d1_CATAATCCAGCAGGTA-1  2195  56   B        7.693937
# s1d1_AAGTCTATCGAGGAGT-1 s1d1_AAGTCTATCGAGGAGT-1  1964  62   B        7.582738
# s1d1_CCTGTTGGTAACAGGG-1 s1d1_CCTGTTGGTAACAGGG-1  2032  52   B        7.616776
# s1d1_CTAGGCGGTGGGAACA-1 s1d1_CTAGGCGGTGGGAACA-1  1969  43   B        7.585281
# s1d1_GGAACCACAGGAACTG-1 s1d1_GGAACCACAGGAACTG-1  1759  46   B        7.472501
# s1d1_GCCTGAGGTTAAGGCC-1 s1d1_GCCTGAGGTTAAGGCC-1  1702  43   B        7.439559
# s1d1_TAGCCTGAGGTTTGCG-1 s1d1_TAGCCTGAGGTTTGCG-1  1634  26   B        7.398786
# s1d1_CCCTGTTAGGATCACT-1 s1d1_CCCTGTTAGGATCACT-1  8507 117   B        9.048645
# s1d1_CCATAATCAAACTAAG-1 s1d1_CCATAATCAAACTAAG-1  1762  41   B        7.474205
# s1d1_TCTGTGACAAATTCGT-1 s1d1_TCTGTGACAAATTCGT-1  1980  38   B        7.590852
# s1d1_AGGGTTGCACATAACT-1 s1d1_AGGGTTGCACATAACT-1  1739  25   B        7.461066
# s1d1_CGTCAATAGTATTGCA-1 s1d1_CGTCAATAGTATTGCA-1  1794  33   B        7.492203
# s1d1_GTCAGGCTCGTGCTTC-1 s1d1_GTCAGGCTCGTGCTTC-1  3914  36   B        8.272315
# s1d1_ACATCAATCGTTTCTG-1 s1d1_ACATCAATCGTTTCTG-1  2695  62   B        7.899153
# s1d1_CTATTACTCCTAAGTA-1 s1d1_CTATTACTCCTAAGTA-1  3200  67   B        8.070906
# s1d1_CCCAATTGTATTGGAT-1 s1d1_CCCAATTGTATTGGAT-1  3783  77   B        8.238273
# s1d1_CGCAATAGTCACACCC-1 s1d1_CGCAATAGTCACACCC-1  6974 221   B        8.849944
# ⋮                       ⋮                       ⋮     ⋮     ⋮        ⋮
# s4d9_GCTAGCTCATCGCTCC-1 s4d9_GCTAGCTCATCGCTCC-1  891   78   B        6.792344
# s4d9_GCTTGACCAATTAACC-1 s4d9_GCTTGACCAATTAACC-1 4931  395   B        8.503297
# s4d9_TTAAGGACAGTTAGCC-1 s4d9_TTAAGGACAGTTAGCC-1 1833  129   B        7.513709
# s4d9_TAGCCTCTCATGTTTC-1 s4d9_TAGCCTCTCATGTTTC-1 1958  170   B        7.579679
# s4d9_ACTTTGTTCTCCATGC-1 s4d9_ACTTTGTTCTCCATGC-1  905   24   B        6.807935
# s4d9_TCTCAATTCATCCTGC-1 s4d9_TCTCAATTCATCCTGC-1 1368  136   B        7.221105
# s4d9_CTATAACCATAGCGAG-1 s4d9_CTATAACCATAGCGAG-1  580   43   B        6.363028
# s4d9_TTTACGAAGGACGTAA-1 s4d9_TTTACGAAGGACGTAA-1  591   41   B        6.381816
# s4d9_TCTCGCCCAAACATAG-1 s4d9_TCTCGCCCAAACATAG-1  795   58   B        6.678342
# s4d9_GGTTCTTGTGAACAAA-1 s4d9_GGTTCTTGTGAACAAA-1  935   76   B        6.840547
# s4d9_GATGGACAGCGGCTGT-1 s4d9_GATGGACAGCGGCTGT-1  512   30   B        6.238325
# s4d9_GAAGTCAAGTGAAGTG-1 s4d9_GAAGTCAAGTGAAGTG-1  988   57   B        6.895683
# s4d9_GATTCATCACCTAATG-1 s4d9_GATTCATCACCTAATG-1  867   67   B        6.765039
# s4d9_AGTAAACAGCCTGGTA-1 s4d9_AGTAAACAGCCTGGTA-1  863   50   B        6.760415
# s4d9_TTGTTCCCAGGGAGCT-1 s4d9_TTGTTCCCAGGGAGCT-1  734   57   B        6.598509
# s4d9_GCGAAGTAGCTGTACG-1 s4d9_GCGAAGTAGCTGTACG-1  562   25   B        6.331502
# s4d9_CACAAGCGTTTCGCCA-1 s4d9_CACAAGCGTTTCGCCA-1 1615  147   B        7.387090
# s4d9_AAACAGCCAAAGGCCA-1 s4d9_AAACAGCCAAAGGCCA-1 1610   90   B        7.383989
# s4d9_TCGCTAACACACTAAT-1 s4d9_TCGCTAACACACTAAT-1 1003   61   B        6.910751
# s4d9_GTCGAAGCACATAACT-1 s4d9_GTCGAAGCACATAACT-1  813   31   B        6.700731
# s4d9_ATGTTCAAGTTATTCC-1 s4d9_ATGTTCAAGTTATTCC-1  869   22   B        6.767343
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9_CTTCAAGCAAAGCGCA-1  793   49   B        6.675823
# s4d9_GCTTTACGTATTCGCT-1 s4d9_GCTTTACGTATTCGCT-1  905   65   B        6.807935
# s4d9_TCAAGCTAGCACCACA-1 s4d9_TCAAGCTAGCACCACA-1  822   23   B        6.711740
# s4d9_GGTCAATTCGATTATG-1 s4d9_GGTCAATTCGATTATG-1 1553  111   B        7.347944
# s4d9_GGTTTAATCTATGACA-1 s4d9_GGTTTAATCTATGACA-1 3206  243   B        8.072779
# s4d9_ACTAATCCAGCAAGAT-1 s4d9_ACTAATCCAGCAAGAT-1 1003   53   B        6.910751
# s4d9_AGCATCCCACAGAACG-1 s4d9_AGCATCCCACAGAACG-1  895   71   B        6.796824
# s4d9_CTATTCAGTTGTGATG-1 s4d9_CTATTCAGTTGTGATG-1 1018   50   B        6.925595
# s4d9_CACTTAAAGTCTGGGC-1 s4d9_CACTTAAAGTCTGGGC-1  889   42   B        6.790097
#                         percent.mito
# s1d1_TAGTTGTCACCCTCAC-1 0.018224574
# s1d1_TGGATTGGTTTGCGAA-1 0.017622461
# s1d1_GTAAGGTCAATAACCT-1 0.025477707
# s1d1_GGATTATGTTACATCC-1 0.015556442
# s1d1_AACGACAAGTTGTCAA-1 0.014218009
# s1d1_AGCAATACAATATGGA-1 0.018300654
# s1d1_GGGAGTAGTGATTTGG-1 0.039143279
# s1d1_CCATAATCATGTCAGC-1 0.012596899
# s1d1_ATCAGGTTCATGACCG-1 0.014983352
# s1d1_CAGGTCCAGGCTAATC-1 0.020728643
# s1d1_TCAGTGAGTGCTCCGT-1 0.011591149
# s1d1_CAAACAACAATAACGA-1 0.017964072
# s1d1_ACGCAAGCAATAAGCA-1 0.020812686
# s1d1_CATAATCCAGCAGGTA-1 0.025512528
# s1d1_AAGTCTATCGAGGAGT-1 0.031568228
# s1d1_CCTGTTGGTAACAGGG-1 0.025590551
# s1d1_CTAGGCGGTGGGAACA-1 0.021838497
# s1d1_GGAACCACAGGAACTG-1 0.026151222
# s1d1_GCCTGAGGTTAAGGCC-1 0.025264395
# s1d1_TAGCCTGAGGTTTGCG-1 0.015911873
# s1d1_CCCTGTTAGGATCACT-1 0.013753380
# s1d1_CCATAATCAAACTAAG-1 0.023269012
# s1d1_TCTGTGACAAATTCGT-1 0.019191919
# s1d1_AGGGTTGCACATAACT-1 0.014376078
# s1d1_CGTCAATAGTATTGCA-1 0.018394649
# s1d1_GTCAGGCTCGTGCTTC-1 0.009197752
# s1d1_ACATCAATCGTTTCTG-1 0.023005566
# s1d1_CTATTACTCCTAAGTA-1 0.020937500
# s1d1_CCCAATTGTATTGGAT-1 0.020354216
# s1d1_CGCAATAGTCACACCC-1 0.031689131
# ⋮                       ⋮
# s4d9_GCTAGCTCATCGCTCC-1 0.08754209
# s4d9_GCTTGACCAATTAACC-1 0.08010546
# s4d9_TTAAGGACAGTTAGCC-1 0.07037643
# s4d9_TAGCCTCTCATGTTTC-1 0.08682329
# s4d9_ACTTTGTTCTCCATGC-1 0.02651934
# s4d9_TCTCAATTCATCCTGC-1 0.09941520
# s4d9_CTATAACCATAGCGAG-1 0.07413793
# s4d9_TTTACGAAGGACGTAA-1 0.06937394
# s4d9_TCTCGCCCAAACATAG-1 0.07295597
# s4d9_GGTTCTTGTGAACAAA-1 0.08128342
# s4d9_GATGGACAGCGGCTGT-1 0.05859375
# s4d9_GAAGTCAAGTGAAGTG-1 0.05769231
# s4d9_GATTCATCACCTAATG-1 0.07727797
# s4d9_AGTAAACAGCCTGGTA-1 0.05793743
# s4d9_TTGTTCCCAGGGAGCT-1 0.07765668
# s4d9_GCGAAGTAGCTGTACG-1 0.04448399
# s4d9_CACAAGCGTTTCGCCA-1 0.09102167
# s4d9_AAACAGCCAAAGGCCA-1 0.05590062
# s4d9_TCGCTAACACACTAAT-1 0.06081755
# s4d9_GTCGAAGCACATAACT-1 0.03813038
# s4d9_ATGTTCAAGTTATTCC-1 0.02531646
# s4d9_CTTCAAGCAAAGCGCA-1 0.06179067
# s4d9_GCTTTACGTATTCGCT-1 0.07182320
# s4d9_TCAAGCTAGCACCACA-1 0.02798054
# s4d9_GGTCAATTCGATTATG-1 0.07147457
# s4d9_GGTTTAATCTATGACA-1 0.07579538
# s4d9_ACTAATCCAGCAAGAT-1 0.05284148
# s4d9_AGCATCCCACAGAACG-1 0.07932961
# s4d9_CTATTCAGTTGTGATG-1 0.04911591
# s4d9_CACTTAAAGTCTGGGC-1 0.04724409

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 10699 ranges and 11 metadata columns:
#                                    seqnames              ranges strand |
#                                       <Rle>           <IRanges>  <Rle> |
#      chr1-1063702-1064446_SLC35E2B     chr1     1063702-1064446      * |
#      chr1-107829027-107830315_VAV3     chr1 107829027-107830315      * |
#     chr1-107896910-107897968_GPSM2     chr1 107896910-107897968      * |
#      chr1-107963563-107966011_VAV3     chr1 107963563-107966011      * |
#   chr1-108074962-108075621_FAM102B     chr1 108074962-108075621      * |
#                                ...      ...                 ...    ... .
#       chrX-71540833-71541769_RPS4X     chrX   71540833-71541769      * |
#       chrX-72100614-72101511_IL2RG     chrX   72100614-72101511      * |
#       chrX-72181037-72182022_RPS4X     chrX   72181037-72182022      * |
#         chrX-9676904-9677777_TBL1X     chrX     9676904-9677777      * |
#         chrX-989777-990609_SLC25A6     chrX       989777-990609      * |
#                                     TargetGene               PeakName
#                                    <character>            <character>
#      chr1-1063702-1064446_SLC35E2B    SLC35E2B   chr1-1063702-1064446
#      chr1-107829027-107830315_VAV3        VAV3 chr1-107829027-10783..
#     chr1-107896910-107897968_GPSM2       GPSM2 chr1-107896910-10789..
#      chr1-107963563-107966011_VAV3        VAV3 chr1-107963563-10796..
#   chr1-108074962-108075621_FAM102B     FAM102B chr1-108074962-10807..
#                                ...         ...                    ...
#       chrX-71540833-71541769_RPS4X       RPS4X chrX-71540833-71541769
#       chrX-72100614-72101511_IL2RG       IL2RG chrX-72100614-72101511
#       chrX-72181037-72182022_RPS4X       RPS4X chrX-72181037-72182022
#         chrX-9676904-9677777_TBL1X       TBL1X   chrX-9676904-9677777
#         chrX-989777-990609_SLC25A6     SLC25A6     chrX-989777-990609
#                                                  PairName       beta        se
#                                               <character>  <numeric> <numeric>
#      chr1-1063702-1064446_SLC35E2B chr1-1063702-1064446.. -0.3727146 0.1185064
#      chr1-107829027-107830315_VAV3 chr1-107829027-10783..  0.1621402 0.0328476
#     chr1-107896910-107897968_GPSM2 chr1-107896910-10789..  0.3527160 0.1033027
#      chr1-107963563-107966011_VAV3 chr1-107963563-10796..  0.0972392 0.0196582
#   chr1-108074962-108075621_FAM102B chr1-108074962-10807..  0.2571862 0.0843067
#                                ...                    ...        ...       ...
#       chrX-71540833-71541769_RPS4X chrX-71540833-715417..  -0.273083 0.0414033
#       chrX-72100614-72101511_IL2RG chrX-72100614-721015..   0.264170 0.0915214
#       chrX-72181037-72182022_RPS4X chrX-72181037-721820..  -0.191834 0.0277238
#         chrX-9676904-9677777_TBL1X chrX-9676904-9677777..   0.212369 0.0539014
#         chrX-989777-990609_SLC25A6 chrX-989777-990609_S..  -0.392312 0.0786841
#                                            z           p boot_basic_p
#                                    <numeric>   <numeric>    <numeric>
#      chr1-1063702-1064446_SLC35E2B  -3.14510 1.66029e-03      0.00456
#      chr1-107829027-107830315_VAV3   4.93613 7.96864e-07      0.00256
#     chr1-107896910-107897968_GPSM2   3.41439 6.39243e-04      0.00288
#      chr1-107963563-107966011_VAV3   4.94649 7.55637e-07      0.00088
#   chr1-108074962-108075621_FAM102B   3.05060 2.28384e-03      0.00752
#                                ...       ...         ...          ...
#       chrX-71540833-71541769_RPS4X  -6.59568 4.23300e-11      0.00192
#       chrX-72100614-72101511_IL2RG   2.88643 3.89644e-03      0.00336
#       chrX-72181037-72182022_RPS4X  -6.91950 4.53253e-12      0.00008
#         chrX-9676904-9677777_TBL1X   3.93995 8.14979e-05      0.00144
#         chrX-989777-990609_SLC25A6  -4.98591 6.16719e-07      0.00072
#                                    boot_basic_p.log10      sign
#                                             <numeric> <numeric>
#      chr1-1063702-1064446_SLC35E2B            2.34104        -1
#      chr1-107829027-107830315_VAV3            2.59176         1
#     chr1-107896910-107897968_GPSM2            2.54061         1
#      chr1-107963563-107966011_VAV3            3.05552         1
#   chr1-108074962-108075621_FAM102B            2.12378         1
#                                ...                ...       ...
#       chrX-71540833-71541769_RPS4X            2.71670        -1
#       chrX-72100614-72101511_IL2RG            2.47366         1
#       chrX-72181037-72182022_RPS4X            4.09691        -1
#         chrX-9676904-9677777_TBL1X            2.84164         1
#         chrX-989777-990609_SLC25A6            3.14267        -1
#                                    boot_basic_p.log10.signed
#                                                    <numeric>
#      chr1-1063702-1064446_SLC35E2B                  -2.34104
#      chr1-107829027-107830315_VAV3                   2.59176
#     chr1-107896910-107897968_GPSM2                   2.54061
#      chr1-107963563-107966011_VAV3                   3.05552
#   chr1-108074962-108075621_FAM102B                   2.12378
#                                ...                       ...
#       chrX-71540833-71541769_RPS4X                  -2.71670
#       chrX-72100614-72101511_IL2RG                   2.47366
#       chrX-72181037-72182022_RPS4X                  -4.09691
#         chrX-9676904-9677777_TBL1X                   2.84164
#         chrX-989777-990609_SLC25A6                  -3.14267
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  1295 10404

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# [1] "chr18"
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# [1] "chr8"
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 158027 ranges and 11 metadata columns:
#                                     seqnames              ranges strand |
#                                        <Rle>           <IRanges>  <Rle> |
#                      chr1.chr1.chr1     chr1 108557323-108557763      * |
#                      chr1.chr1.chr1     chr1 109493711-109494617      * |
#                      chr1.chr1.chr1     chr1 109687239-109688501      * |
#                      chr1.chr1.chr1     chr1 109886551-109888371      * |
#                      chr1.chr1.chr1     chr1 110674152-110675443      * |
#                                 ...      ...                 ...    ... .
#   chrX.chrX-71540833-71541769_RPS4X     chrX   71540833-71541769      * |
#   chrX.chrX-72100614-72101511_IL2RG     chrX   72100614-72101511      * |
#   chrX.chrX-72181037-72182022_RPS4X     chrX   72181037-72182022      * |
#     chrX.chrX-9676904-9677777_TBL1X     chrX     9676904-9677777      * |
#     chrX.chrX-989777-990609_SLC25A6     chrX       989777-990609      * |
#                                      TargetGene               PeakName
#                                     <character>            <character>
#                      chr1.chr1.chr1        VAV3 chr1-108557323-10855..
#                      chr1.chr1.chr1        SARS chr1-109493711-10949..
#                      chr1.chr1.chr1       KCNA3 chr1-109687239-10968..
#                      chr1.chr1.chr1        SARS chr1-109886551-10988..
#                      chr1.chr1.chr1      ATP5F1 chr1-110674152-11067..
#                                 ...         ...                    ...
#   chrX.chrX-71540833-71541769_RPS4X       RPS4X chrX-71540833-71541769
#   chrX.chrX-72100614-72101511_IL2RG       IL2RG chrX-72100614-72101511
#   chrX.chrX-72181037-72182022_RPS4X       RPS4X chrX-72181037-72182022
#     chrX.chrX-9676904-9677777_TBL1X       TBL1X   chrX-9676904-9677777
#     chrX.chrX-989777-990609_SLC25A6     SLC25A6     chrX-989777-990609
#                                                   PairName      beta        se
#                                                <character> <numeric> <numeric>
#                      chr1.chr1.chr1 chr1-108557323-10855.. -0.138704 0.0396123
#                      chr1.chr1.chr1 chr1-109493711-10949.. -0.326867 0.1043259
#                      chr1.chr1.chr1 chr1-109687239-10968..  0.306241 0.1150535
#                      chr1.chr1.chr1 chr1-109886551-10988..  0.336010 0.1098503
#                      chr1.chr1.chr1 chr1-110674152-11067.. -0.313221 0.1047136
#                                 ...                    ...       ...       ...
#   chrX.chrX-71540833-71541769_RPS4X chrX-71540833-715417.. -0.273083 0.0414033
#   chrX.chrX-72100614-72101511_IL2RG chrX-72100614-721015..  0.264170 0.0915214
#   chrX.chrX-72181037-72182022_RPS4X chrX-72181037-721820.. -0.191834 0.0277238
#     chrX.chrX-9676904-9677777_TBL1X chrX-9676904-9677777..  0.212369 0.0539014
#     chrX.chrX-989777-990609_SLC25A6 chrX-989777-990609_S.. -0.392312 0.0786841
#                                             z           p boot_basic_p
#                                     <numeric>   <numeric>    <numeric>
#                      chr1.chr1.chr1  -3.50155 0.000462568      0.01248
#                      chr1.chr1.chr1  -3.13313 0.001729518      0.00272
#                      chr1.chr1.chr1   2.66173 0.007774059      0.01152
#                      chr1.chr1.chr1   3.05880 0.002222237      0.00232
#                      chr1.chr1.chr1  -2.99122 0.002778679      0.00784
#                                 ...       ...         ...          ...
#   chrX.chrX-71540833-71541769_RPS4X  -6.59568 4.23300e-11      0.00192
#   chrX.chrX-72100614-72101511_IL2RG   2.88643 3.89644e-03      0.00336
#   chrX.chrX-72181037-72182022_RPS4X  -6.91950 4.53253e-12      0.00008
#     chrX.chrX-9676904-9677777_TBL1X   3.93995 8.14979e-05      0.00144
#     chrX.chrX-989777-990609_SLC25A6  -4.98591 6.16719e-07      0.00072
#                                     boot_basic_p.log10      sign
#                                              <numeric> <numeric>
#                      chr1.chr1.chr1            1.90379        -1
#                      chr1.chr1.chr1            2.56543        -1
#                      chr1.chr1.chr1            1.93855         1
#                      chr1.chr1.chr1            2.63451         1
#                      chr1.chr1.chr1            2.10568        -1
#                                 ...                ...       ...
#   chrX.chrX-71540833-71541769_RPS4X            2.71670        -1
#   chrX.chrX-72100614-72101511_IL2RG            2.47366         1
#   chrX.chrX-72181037-72182022_RPS4X            4.09691        -1
#     chrX.chrX-9676904-9677777_TBL1X            2.84164         1
#     chrX.chrX-989777-990609_SLC25A6            3.14267        -1
#                                     boot_basic_p.log10.signed
#                                                     <numeric>
#                      chr1.chr1.chr1                  -1.90379
#                      chr1.chr1.chr1                  -2.56543
#                      chr1.chr1.chr1                   1.93855
#                      chr1.chr1.chr1                   2.63451
#                      chr1.chr1.chr1                  -2.10568
#                                 ...                       ...
#   chrX.chrX-71540833-71541769_RPS4X                  -2.71670
#   chrX.chrX-72100614-72101511_IL2RG                   2.47366
#   chrX.chrX-72181037-72182022_RPS4X                  -4.09691
#     chrX.chrX-9676904-9677777_TBL1X                   2.84164
#     chrX.chrX-989777-990609_SLC25A6                  -3.14267
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta       se
# 1      chr1 108557323 108557763 VAV3       B        -0.1387042 0.03961228
# 2      chr1 109493711 109494617 SARS       B        -0.3268668 0.10432590
# 3      chr1 109687239 109688501 KCNA3      B         0.3062413 0.11505355
# 4      chr1 109886551 109888371 SARS       B         0.3360104 0.10985031
# 5      chr1 110674152 110675443 ATP5F1     B        -0.3132212 0.10471365
# 6      chr1 115975857 115977120 CD58       B         0.3209671 0.10499802
# 7      chr1 116794467 116795716 FAM46C     B        -0.5392924 0.12396570
# 8      chr1   1169046   1170287 GNB1       B         0.1777097 0.05947030
# 9      chr1 117595741 117596664 FAM46C     B         0.2789360 0.08380959
# 10     chr1 117654124 117655109 FAM46C     B         0.2637136 0.06430111
# 11     chr1 117656173 117656726 FAM46C     B         0.2662036 0.07802346
# 12     chr1 117658649 117659146 FAM46C     B         0.4152891 0.08642770
# 13     chr1 117664017 117664990 FAM46C     B         0.3375804 0.05402610
# 14     chr1  12208754  12209680 TNFRSF1B   B         0.2794270 0.10061339
# 15     chr1 145932541 145933122 TXNIP      B        -0.1115076 0.02702019
# 16     chr1 149886393 149887199 PRPF3      B         0.1962285 0.06656640
# 17     chr1 149887522 149888659 HIST2H2AC  B         0.2416913 0.05562187
# 18     chr1 149927327 149928548 ARNT       B         0.1911801 0.07067690
# 19     chr1 150009619 150011159 CTSS       B         0.1438846 0.04737995
# 20     chr1 150009619 150011159 MRPS21     B        -0.4626617 0.14806739
# 21     chr1 150560978 150563893 HIST2H2AC  B        -0.1796396 0.05526640
# 22     chr1 150572793 150573956 ENSA       B         0.2152345 0.08389409
# 23     chr1 150611180 150612249 HIST2H2AC  B        -0.4120016 0.09472324
# 24     chr1 151007908 151009092 MCL1       B         0.1448806 0.04042385
# 25     chr1 151070087 151071575 SETDB1     B         0.2321874 0.08247667
# 26     chr1 151198116 151199386 PRPF3      B         0.1863647 0.06931038
# 27     chr1 151443739 151445051 SNX27      B         0.3329690 0.12947202
# 28     chr1 151762884 151764094 PI4KB      B         0.2664319 0.09937225
# 29     chr1 154327513 154327861 TPM3       B        -0.2547809 0.08704865
# 30     chr1 154607511 154608913 RPS27      B        -0.1122852 0.01757484
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮          ⋮
# 157998 chrX 40646881  40648143  MED14      B         0.2012551 0.05458107
# 157999 chrX 41252846  41254192  CASK       B         0.2263976 0.03778661
# 158000 chrX 41252846  41254192  USP9X      B         0.1713377 0.04388851
# 158001 chrX 41332764  41335151  USP9X      B         0.1514360 0.03119045
# 158002 chrX 41441938  41442920  DDX3X      B         0.1937156 0.04663991
# 158003 chrX 44872294  44874123  KDM6A      B         0.1366711 0.02703806
# 158004 chrX 45753425  45754187  KDM6A      B         0.1555121 0.04159502
# 158005 chrX 45762287  45763199  KDM6A      B         0.2303543 0.04543703
# 158006 chrX 45769629  45770609  KDM6A      B         0.1650982 0.04372279
# 158007 chrX 46754538  46755146  SLC9A7     B         0.1900473 0.03724675
# 158008 chrX 46758572  46759848  NDUFB11    B        -0.3146416 0.10191497
# 158009 chrX 46758572  46759848  SLC9A7     B         0.1468885 0.02850926
# 158010 chrX 47128922  47129905  UXT        B        -0.2927010 0.09554043
# 158011 chrX 47658499  47659534  RBM3       B         0.1854484 0.05541875
# 158012 chrX 48918744  48919756  RBM3       B        -0.1919468 0.06104834
# 158013 chrX 48957010  48958840  RBM3       B        -0.1789922 0.05400992
# 158014 chrX 53071574  53072937  PHF8       B         0.2824331 0.07808245
# 158015 chrX 53088058  53089137  TSPYL2     B         0.3378661 0.12329816
# 158016 chrX 54808246  54809386  PHF8       B         0.2921849 0.08113071
# 158017 chrX 65034358  65035667  ZC4H2      B         0.3054525 0.08533762
# 158018 chrX  7109677   7111418  PUDP       B         0.2783751 0.09079148
# 158019 chrX  7109677   7111418  STS        B         0.5341416 0.09975328
# 158020 chrX 71282884  71284184  RPS4X      B        -0.1293047 0.02628135
# 158021 chrX  7147155   7148840  STS        B         0.2348345 0.07022614
# 158022 chrX 71532051  71533404  RPS4X      B        -0.1470278 0.02660887
# 158023 chrX 71540833  71541769  RPS4X      B        -0.2730833 0.04140334
# 158024 chrX 72100614  72101511  IL2RG      B         0.2641698 0.09152141
# 158025 chrX 72181037  72182022  RPS4X      B        -0.1918345 0.02772376
# 158026 chrX  9676904   9677777  TBL1X      B         0.2123689 0.05390139
# 158027 chrX   989777    990609  SLC25A6    B        -0.3923117 0.07868413
#        z         p            boot_basic_p boot_basic_p.log10 sign
# 1      -3.501545 4.625680e-04 0.01248      1.903785           -1
# 2      -3.133132 1.729518e-03 0.00272      2.565431           -1
# 3       2.661728 7.774059e-03 0.01152      1.938548            1
# 4       3.058802 2.222237e-03 0.00232      2.634512            1
# 5      -2.991217 2.778679e-03 0.00784      2.105684           -1
# 6       3.056887 2.236488e-03 0.01080      1.966576            1
# 7      -4.350335 1.359295e-05 0.00304      2.517126           -1
# 8       2.988210 2.806168e-03 0.01008      1.996539            1
# 9       3.328211 8.740554e-04 0.00144      2.841638            1
# 10      4.101229 4.109624e-05 0.00024      3.619789            1
# 11      3.411840 6.452594e-04 0.00656      2.183096            1
# 12      4.805046 1.547155e-06 0.00008      4.096910            1
# 13      6.248469 4.144945e-10 0.00008      4.096910            1
# 14      2.777234 5.482364e-03 0.01128      1.947691            1
# 15     -4.126825 3.678063e-05 0.01168      1.932557           -1
# 16      2.947861 3.199808e-03 0.00672      2.172631            1
# 17      4.345257 1.391130e-05 0.00008      4.096910            1
# 18      2.704987 6.830696e-03 0.01296      1.887395            1
# 19      3.036825 2.390841e-03 0.00688      2.162412            1
# 20     -3.124670 1.780047e-03 0.01048      1.979639           -1
# 21     -3.250432 1.152300e-03 0.00520      2.283997           -1
# 22      2.565550 1.030122e-02 0.01248      1.903785            1
# 23     -4.349530 1.364296e-05 0.00032      3.494850           -1
# 24      3.584036 3.383251e-04 0.01264      1.898253            1
# 25      2.815189 4.874851e-03 0.01248      1.903785            1
# 26      2.688842 7.170031e-03 0.01048      1.979639            1
# 27      2.571745 1.011874e-02 0.01208      1.917933            1
# 28      2.681150 7.336963e-03 0.00896      2.047692            1
# 29     -2.926879 3.423816e-03 0.01024      1.989700           -1
# 30     -6.388974 1.670028e-10 0.01008      1.996539           -1
# ⋮      ⋮         ⋮            ⋮            ⋮                  ⋮
# 157998  3.687269 2.266736e-04 0.00120      2.920819            1
# 157999  5.991476 2.079446e-09 0.00008      4.096910            1
# 158000  3.903930 9.464297e-05 0.00080      3.096910            1
# 158001  4.855205 1.202624e-06 0.00008      4.096910            1
# 158002  4.153430 3.275280e-05 0.00032      3.494850            1
# 158003  5.054769 4.309120e-07 0.00008      4.096910            1
# 158004  3.738720 1.849593e-04 0.00328      2.484126            1
# 158005  5.069748 3.983437e-07 0.00008      4.096910            1
# 158006  3.776021 1.593534e-04 0.00344      2.463442            1
# 158007  5.102387 3.353966e-07 0.00024      3.619789            1
# 158008 -3.087295 2.019869e-03 0.00576      2.239578           -1
# 158009  5.152309 2.572982e-07 0.00008      4.096910            1
# 158010 -3.063635 2.186657e-03 0.00800      2.096910           -1
# 158011  3.346311 8.189456e-04 0.00088      3.055517            1
# 158012 -3.144178 1.665541e-03 0.00272      2.565431           -1
# 158013 -3.314061 9.195131e-04 0.00216      2.665546           -1
# 158014  3.617114 2.979058e-04 0.00072      3.142668            1
# 158015  2.740236 6.139509e-03 0.00424      2.372634            1
# 158016  3.601409 3.164971e-04 0.00144      2.841638            1
# 158017  3.579342 3.444602e-04 0.00528      2.277366            1
# 158018  3.066093 2.168762e-03 0.00464      2.333482            1
# 158019  5.354627 8.573318e-08 0.00008      4.096910            1
# 158020 -4.920018 8.653646e-07 0.00672      2.172631           -1
# 158021  3.343976 8.258686e-04 0.00560      2.251812            1
# 158022 -5.525519 3.285136e-08 0.00320      2.494850           -1
# 158023 -6.595684 4.233001e-11 0.00192      2.716699           -1
# 158024  2.886426 3.896445e-03 0.00336      2.473661            1
# 158025 -6.919496 4.532525e-12 0.00008      4.096910           -1
# 158026  3.939952 8.149791e-05 0.00144      2.841638            1
# 158027 -4.985907 6.167188e-07 0.00072      3.142668           -1
#        boot_basic_p.log10.signed FDR
# 1      -1.903785                 0.157179703
# 2      -2.565431                 0.059181253
# 3       1.938548                 0.150838598
# 4       2.634512                 0.052980150
# 5      -2.105684                 0.118899393
# 6       1.966576                 0.146509709
# 7      -2.517126                 0.063536844
# 8       1.996539                 0.141838336
# 9       2.841638                 0.037762841
# 10      3.619789                 0.009749738
# 11      2.183096                 0.105340628
# 12      4.096910                 0.003855493
# 13      4.096910                 0.003855493
# 14      1.947691                 0.148101077
# 15     -1.932557                 0.152192937
# 16      2.172631                 0.107007400
# 17      4.096910                 0.003855493
# 18      1.887395                 0.158934496
# 19      2.162412                 0.108668242
# 20     -1.979639                 0.142756914
# 21     -2.283997                 0.090340853
# 22      1.903785                 0.157179703
# 23     -3.494850                 0.012179345
# 24      1.898253                 0.157179703
# 25      1.903785                 0.157179703
# 26      1.979639                 0.142756914
# 27      1.917933                 0.153146102
# 28      2.047692                 0.130535809
# 29     -1.989700                 0.141838336
# 30     -1.996539                 0.141838336
# ⋮      ⋮                         ⋮
# 157998  2.920819                 0.033292205
# 157999  4.096910                 0.003855493
# 158000  3.096910                 0.024696542
# 158001  4.096910                 0.003855493
# 158002  3.494850                 0.012179345
# 158003  4.096910                 0.003855493
# 158004  2.484126                 0.066597528
# 158005  4.096910                 0.003855493
# 158006  2.463442                 0.068837898
# 158007  3.619789                 0.009749738
# 158008 -2.239578                 0.096627975
# 158009  4.096910                 0.003855493
# 158010 -2.096910                 0.120504814
# 158011  3.055517                 0.026518642
# 158012 -2.565431                 0.059181253
# 158013 -2.665546                 0.050478900
# 158014  3.142668                 0.022824361
# 158015  2.372634                 0.078883268
# 158016  2.841638                 0.037762841
# 158017  2.277366                 0.091219259
# 158018  2.333482                 0.083809039
# 158019  4.096910                 0.003855493
# 158020 -2.172631                 0.107007400
# 158021  2.251812                 0.094921291
# 158022 -2.494850                 0.065665031
# 158023 -2.716699                 0.046364890
# 158024  2.473661                 0.067760429
# 158025 -4.096910                 0.003855493
# 158026  2.841638                 0.037762841
# 158027 -3.142668                 0.022824361

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
