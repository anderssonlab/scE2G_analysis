# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.25000.240612/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Myeloid/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/Myeloid.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.25000.250329/"
celltype = "Myeloid"

# %%
n.cores = 48

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_CTATGGCCATAACGGG-1 s1d1_CTATGGCCATAACGGG-1  2157  69   Myeloid   7.676474
# s1d1_ACCACATAGGTGTCCA-1 s1d1_ACCACATAGGTGTCCA-1  2128  64   Myeloid   7.662938
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1_TGCCGGTAGTCGCAAT-1  1920  67   Myeloid   7.560080
# s1d1_CATCCCAGTCTTTATG-1 s1d1_CATCCCAGTCTTTATG-1  3211 127   Myeloid   8.074338
# s1d1_TAGTGAGAGCTGCACA-1 s1d1_TAGTGAGAGCTGCACA-1  3568  85   Myeloid   8.179760
# s1d1_CCTGTTGGTTATAGCG-1 s1d1_CCTGTTGGTTATAGCG-1  4044  42   Myeloid   8.304990
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1_TTTAGCTTCTGGCTTC-1  2728 105   Myeloid   7.911324
# s1d1_TGTGAAACAGGATTAA-1 s1d1_TGTGAAACAGGATTAA-1  2800  86   Myeloid   7.937375
# s1d1_ACCAGGCTCTTGGATA-1 s1d1_ACCAGGCTCTTGGATA-1  1015  94   Myeloid   6.922644
# s1d1_CACAGGGAGACAGGTA-1 s1d1_CACAGGGAGACAGGTA-1  3092  69   Myeloid   8.036573
# s1d1_GCATCCTTCGCTATGG-1 s1d1_GCATCCTTCGCTATGG-1  3112  77   Myeloid   8.043021
# s1d1_TGCTATGCAGAGGGAG-1 s1d1_TGCTATGCAGAGGGAG-1  2814  78   Myeloid   7.942362
# s1d1_CCCGCAACAAAGCGCA-1 s1d1_CCCGCAACAAAGCGCA-1  3234  58   Myeloid   8.081475
# s1d1_AATCTTGAGAAGCTAG-1 s1d1_AATCTTGAGAAGCTAG-1  1647  67   Myeloid   7.406711
# s1d1_TTGTCCATCATTAGGC-1 s1d1_TTGTCCATCATTAGGC-1  4110  79   Myeloid   8.321178
# s1d1_TCCAGGATCCTAACGG-1 s1d1_TCCAGGATCCTAACGG-1  3484 100   Myeloid   8.155936
# s1d1_GGTATGTTCTAACCAA-1 s1d1_GGTATGTTCTAACCAA-1  2759  61   Myeloid   7.922624
# s1d1_TGGATTCAGTTTCCGC-1 s1d1_TGGATTCAGTTTCCGC-1  3639  72   Myeloid   8.199464
# s1d1_TGCTTGCTCAATCTCT-1 s1d1_TGCTTGCTCAATCTCT-1  1934  71   Myeloid   7.567346
# s1d1_CGATGTCCATACCCGG-1 s1d1_CGATGTCCATACCCGG-1  3296  54   Myeloid   8.100465
# s1d1_ACGCCTAAGCGCCTTT-1 s1d1_ACGCCTAAGCGCCTTT-1  3236  92   Myeloid   8.082093
# s1d1_GAGTAATAGCTTAACA-1 s1d1_GAGTAATAGCTTAACA-1  4308 100   Myeloid   8.368229
# s1d1_ATTGGCTAGGGACCTC-1 s1d1_ATTGGCTAGGGACCTC-1 22348 863   Myeloid  10.014492
# s1d1_CCTGTAACATTGTGCA-1 s1d1_CCTGTAACATTGTGCA-1  3940 127   Myeloid   8.278936
# s1d1_AGATGAAGTGAGGTGA-1 s1d1_AGATGAAGTGAGGTGA-1  2271  69   Myeloid   7.727976
# s1d1_GTTAACGGTAGCTGGT-1 s1d1_GTTAACGGTAGCTGGT-1  1222  72   Myeloid   7.108244
# s1d1_GAACACAAGTAACCAC-1 s1d1_GAACACAAGTAACCAC-1  3170  64   Myeloid   8.061487
# s1d1_GGTGCTGGTACTTCAC-1 s1d1_GGTGCTGGTACTTCAC-1  4133 103   Myeloid   8.326759
# s1d1_AGCTGCTCATTGTTGG-1 s1d1_AGCTGCTCATTGTTGG-1  1308 102   Myeloid   7.176255
# s1d1_TCCAGGATCAACAAGG-1 s1d1_TCCAGGATCAACAAGG-1  3218  66   Myeloid   8.076515
# ⋮                       ⋮                       ⋮     ⋮     ⋮        ⋮
# s4d9_GTTGCTGAGTAATCCA-1 s4d9_GTTGCTGAGTAATCCA-1 2839  168   Myeloid  7.951207
# s4d9_AACTAGTGTTACTTCA-1 s4d9_AACTAGTGTTACTTCA-1 1455  198   Myeloid  7.282761
# s4d9_TGCTTCCAGTCCTTTG-1 s4d9_TGCTTCCAGTCCTTTG-1 1450  138   Myeloid  7.279319
# s4d9_AAGGATCCACAGGATG-1 s4d9_AAGGATCCACAGGATG-1 1789  229   Myeloid  7.489412
# s4d9_TGTGCGCAGCCGCAGT-1 s4d9_TGTGCGCAGCCGCAGT-1 1686  138   Myeloid  7.430114
# s4d9_CCAGACTCAATCATGT-1 s4d9_CCAGACTCAATCATGT-1 1834   52   Myeloid  7.514255
# s4d9_AGTAAGTAGTTAGAGG-1 s4d9_AGTAAGTAGTTAGAGG-1 1826  194   Myeloid  7.509883
# s4d9_TGCGGTTCAACAGCCT-1 s4d9_TGCGGTTCAACAGCCT-1 1048  124   Myeloid  6.954639
# s4d9_GATGACTTCGCTAGTG-1 s4d9_GATGACTTCGCTAGTG-1  848   94   Myeloid  6.742881
# s4d9_CTAGTCGAGCTATTGA-1 s4d9_CTAGTCGAGCTATTGA-1  829   52   Myeloid  6.720220
# s4d9_TTATGACCATTTAAGC-1 s4d9_TTATGACCATTTAAGC-1 3534  336   Myeloid  8.170186
# s4d9_GTGCTCAAGCAAGATG-1 s4d9_GTGCTCAAGCAAGATG-1 3857  573   Myeloid  8.257645
# s4d9_GGATATTGTGTCACGG-1 s4d9_GGATATTGTGTCACGG-1 2140  285   Myeloid  7.668561
# s4d9_TGGCCTGCAATTATGC-1 s4d9_TGGCCTGCAATTATGC-1 3184  332   Myeloid  8.065894
# s4d9_GAGGGAGCATAACGGG-1 s4d9_GAGGGAGCATAACGGG-1 2488  358   Myeloid  7.819234
# s4d9_GGTACAAAGTTGCCTC-1 s4d9_GGTACAAAGTTGCCTC-1 2427  276   Myeloid  7.794411
# s4d9_GGAAACTCATAGCTGC-1 s4d9_GGAAACTCATAGCTGC-1 1561  182   Myeloid  7.353082
# s4d9_AGAAAGGCAATGCCCG-1 s4d9_AGAAAGGCAATGCCCG-1 1773   38   Myeloid  7.480428
# s4d9_CTACAACAGCGAGTAA-1 s4d9_CTACAACAGCGAGTAA-1 1161   96   Myeloid  7.057037
# s4d9_ACATTGCAGGGTCTAT-1 s4d9_ACATTGCAGGGTCTAT-1 2255  255   Myeloid  7.720905
# s4d9_CTCCAACTCTAACCAA-1 s4d9_CTCCAACTCTAACCAA-1 3392  399   Myeloid  8.129175
# s4d9_CAGGGCTTCCGCCAAA-1 s4d9_CAGGGCTTCCGCCAAA-1 1837  253   Myeloid  7.515889
# s4d9_TAAACAGCACCTAAGC-1 s4d9_TAAACAGCACCTAAGC-1 1474  171   Myeloid  7.295735
# s4d9_TGGTCCTTCAGTGAAG-1 s4d9_TGGTCCTTCAGTGAAG-1 2021  227   Myeloid  7.611348
# s4d9_GGATACTTCTTACTCG-1 s4d9_GGATACTTCTTACTCG-1 2211  192   Myeloid  7.701200
# s4d9_ACAGGAATCCGTCCAT-1 s4d9_ACAGGAATCCGTCCAT-1  747   61   Myeloid  6.616065
# s4d9_TGTGGCCAGCTGGCTA-1 s4d9_TGTGGCCAGCTGGCTA-1 1062  140   Myeloid  6.967909
# s4d9_CCGGTTAAGCCTGTTC-1 s4d9_CCGGTTAAGCCTGTTC-1 1496   58   Myeloid  7.310550
# s4d9_CAAGCTAGTCAACAAT-1 s4d9_CAAGCTAGTCAACAAT-1 1664  179   Myeloid  7.416980
# s4d9_ACAGGTAAGGTTACGT-1 s4d9_ACAGGTAAGGTTACGT-1 1221   75   Myeloid  7.107425
#                         percent.mito
# s1d1_CTATGGCCATAACGGG-1 0.03198887
# s1d1_ACCACATAGGTGTCCA-1 0.03007519
# s1d1_TGCCGGTAGTCGCAAT-1 0.03489583
# s1d1_CATCCCAGTCTTTATG-1 0.03955154
# s1d1_TAGTGAGAGCTGCACA-1 0.02382287
# s1d1_CCTGTTGGTTATAGCG-1 0.01038576
# s1d1_TTTAGCTTCTGGCTTC-1 0.03848974
# s1d1_TGTGAAACAGGATTAA-1 0.03071429
# s1d1_ACCAGGCTCTTGGATA-1 0.09261084
# s1d1_CACAGGGAGACAGGTA-1 0.02231565
# s1d1_GCATCCTTCGCTATGG-1 0.02474293
# s1d1_TGCTATGCAGAGGGAG-1 0.02771855
# s1d1_CCCGCAACAAAGCGCA-1 0.01793445
# s1d1_AATCTTGAGAAGCTAG-1 0.04068002
# s1d1_TTGTCCATCATTAGGC-1 0.01922141
# s1d1_TCCAGGATCCTAACGG-1 0.02870264
# s1d1_GGTATGTTCTAACCAA-1 0.02210946
# s1d1_TGGATTCAGTTTCCGC-1 0.01978566
# s1d1_TGCTTGCTCAATCTCT-1 0.03671148
# s1d1_CGATGTCCATACCCGG-1 0.01638350
# s1d1_ACGCCTAAGCGCCTTT-1 0.02843016
# s1d1_GAGTAATAGCTTAACA-1 0.02321263
# s1d1_ATTGGCTAGGGACCTC-1 0.03861643
# s1d1_CCTGTAACATTGTGCA-1 0.03223350
# s1d1_AGATGAAGTGAGGTGA-1 0.03038309
# s1d1_GTTAACGGTAGCTGGT-1 0.05891980
# s1d1_GAACACAAGTAACCAC-1 0.02018927
# s1d1_GGTGCTGGTACTTCAC-1 0.02492136
# s1d1_AGCTGCTCATTGTTGG-1 0.07798165
# s1d1_TCCAGGATCAACAAGG-1 0.02050963
# ⋮                       ⋮
# s4d9_GTTGCTGAGTAATCCA-1 0.05917577
# s4d9_AACTAGTGTTACTTCA-1 0.13608247
# s4d9_TGCTTCCAGTCCTTTG-1 0.09517241
# s4d9_AAGGATCCACAGGATG-1 0.12800447
# s4d9_TGTGCGCAGCCGCAGT-1 0.08185053
# s4d9_CCAGACTCAATCATGT-1 0.02835333
# s4d9_AGTAAGTAGTTAGAGG-1 0.10624315
# s4d9_TGCGGTTCAACAGCCT-1 0.11832061
# s4d9_GATGACTTCGCTAGTG-1 0.11084906
# s4d9_CTAGTCGAGCTATTGA-1 0.06272618
# s4d9_TTATGACCATTTAAGC-1 0.09507640
# s4d9_GTGCTCAAGCAAGATG-1 0.14856106
# s4d9_GGATATTGTGTCACGG-1 0.13317757
# s4d9_TGGCCTGCAATTATGC-1 0.10427136
# s4d9_GAGGGAGCATAACGGG-1 0.14389068
# s4d9_GGTACAAAGTTGCCTC-1 0.11372064
# s4d9_GGAAACTCATAGCTGC-1 0.11659193
# s4d9_AGAAAGGCAATGCCCG-1 0.02143260
# s4d9_CTACAACAGCGAGTAA-1 0.08268734
# s4d9_ACATTGCAGGGTCTAT-1 0.11308204
# s4d9_CTCCAACTCTAACCAA-1 0.11762972
# s4d9_CAGGGCTTCCGCCAAA-1 0.13772455
# s4d9_TAAACAGCACCTAAGC-1 0.11601085
# s4d9_TGGTCCTTCAGTGAAG-1 0.11232063
# s4d9_GGATACTTCTTACTCG-1 0.08683853
# s4d9_ACAGGAATCCGTCCAT-1 0.08165997
# s4d9_TGTGGCCAGCTGGCTA-1 0.13182674
# s4d9_CCGGTTAAGCCTGTTC-1 0.03877005
# s4d9_CAAGCTAGTCAACAAT-1 0.10757212
# s4d9_ACAGGTAAGGTTACGT-1 0.06142506

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Myeloid.25000.250329//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 36081 ranges and 11 metadata columns:
#                                   seqnames              ranges strand |
#                                      <Rle>           <IRanges>  <Rle> |
#       chr1-1001860-1002126_CDK11B     chr1     1001860-1002126      * |
#      chr1-10022225-10023589_KIF1B     chr1   10022225-10023589      * |
#   chr1-10022225-10023589_SLC25A33     chr1   10022225-10023589      * |
#   chr1-100265575-100266826_CDC14A     chr1 100265575-100266826      * |
#   chr1-10032414-10033799_SLC25A33     chr1   10032414-10033799      * |
#                               ...      ...                 ...    ... .
#    chrX-77899134-77899778_CYSLTR1     chrX   77899134-77899778      * |
#    chrX-81120681-81122301_SH3BGRL     chrX   81120681-81122301      * |
#        chrX-9378667-9379857_TBL1X     chrX     9378667-9379857      * |
#     chrX-96722435-96723511_DIAPH2     chrX   96722435-96723511      * |
#          chrX-989778-990654_IL3RA     chrX       989778-990654      * |
#                                    TargetGene               PeakName
#                                   <character>            <character>
#       chr1-1001860-1002126_CDK11B      CDK11B   chr1-1001860-1002126
#      chr1-10022225-10023589_KIF1B       KIF1B chr1-10022225-10023589
#   chr1-10022225-10023589_SLC25A33    SLC25A33 chr1-10022225-10023589
#   chr1-100265575-100266826_CDC14A      CDC14A chr1-100265575-10026..
#   chr1-10032414-10033799_SLC25A33    SLC25A33 chr1-10032414-10033799
#                               ...         ...                    ...
#    chrX-77899134-77899778_CYSLTR1     CYSLTR1 chrX-77899134-77899778
#    chrX-81120681-81122301_SH3BGRL     SH3BGRL chrX-81120681-81122301
#        chrX-9378667-9379857_TBL1X       TBL1X   chrX-9378667-9379857
#     chrX-96722435-96723511_DIAPH2      DIAPH2 chrX-96722435-96723511
#          chrX-989778-990654_IL3RA       IL3RA     chrX-989778-990654
#                                                 PairName       beta        se
#                                              <character>  <numeric> <numeric>
#       chr1-1001860-1002126_CDK11B chr1-1001860-1002126..   0.168775 0.0655577
#      chr1-10022225-10023589_KIF1B chr1-10022225-100235..   0.127238 0.0430439
#   chr1-10022225-10023589_SLC25A33 chr1-10022225-100235..   0.286707 0.0643334
#   chr1-100265575-100266826_CDC14A chr1-100265575-10026..   0.110917 0.0253869
#   chr1-10032414-10033799_SLC25A33 chr1-10032414-100337..   0.132958 0.0336388
#                               ...                    ...        ...       ...
#    chrX-77899134-77899778_CYSLTR1 chrX-77899134-778997.. -0.4792389 0.0950917
#    chrX-81120681-81122301_SH3BGRL chrX-81120681-811223.. -0.1499563 0.0329712
#        chrX-9378667-9379857_TBL1X chrX-9378667-9379857..  0.1630958 0.0264363
#     chrX-96722435-96723511_DIAPH2 chrX-96722435-967235..  0.0833827 0.0201098
#          chrX-989778-990654_IL3RA chrX-989778-990654_I..  0.3102046 0.0796438
#                                           z           p boot_basic_p
#                                   <numeric>   <numeric>    <numeric>
#       chr1-1001860-1002126_CDK11B   2.57444 1.00401e-02      0.00976
#      chr1-10022225-10023589_KIF1B   2.95600 3.11658e-03      0.00616
#   chr1-10022225-10023589_SLC25A33   4.45657 8.32801e-06      0.00008
#   chr1-100265575-100266826_CDC14A   4.36905 1.24786e-05      0.00080
#   chr1-10032414-10033799_SLC25A33   3.95251 7.73355e-05      0.00208
#                               ...       ...         ...          ...
#    chrX-77899134-77899778_CYSLTR1  -5.03975 4.66132e-07      0.00032
#    chrX-81120681-81122301_SH3BGRL  -4.54809 5.41340e-06      0.00048
#        chrX-9378667-9379857_TBL1X   6.16938 6.85587e-10      0.00008
#     chrX-96722435-96723511_DIAPH2   4.14637 3.37783e-05      0.00208
#          chrX-989778-990654_IL3RA   3.89490 9.82400e-05      0.00016
#                                   boot_basic_p.log10      sign
#                                            <numeric> <numeric>
#       chr1-1001860-1002126_CDK11B            2.01055         1
#      chr1-10022225-10023589_KIF1B            2.21042         1
#   chr1-10022225-10023589_SLC25A33            4.09691         1
#   chr1-100265575-100266826_CDC14A            3.09691         1
#   chr1-10032414-10033799_SLC25A33            2.68194         1
#                               ...                ...       ...
#    chrX-77899134-77899778_CYSLTR1            3.49485        -1
#    chrX-81120681-81122301_SH3BGRL            3.31876        -1
#        chrX-9378667-9379857_TBL1X            4.09691         1
#     chrX-96722435-96723511_DIAPH2            2.68194         1
#          chrX-989778-990654_IL3RA            3.79588         1
#                                   boot_basic_p.log10.signed
#                                                   <numeric>
#       chr1-1001860-1002126_CDK11B                   2.01055
#      chr1-10022225-10023589_KIF1B                   2.21042
#   chr1-10022225-10023589_SLC25A33                   4.09691
#   chr1-100265575-100266826_CDC14A                   3.09691
#   chr1-10032414-10033799_SLC25A33                   2.68194
#                               ...                       ...
#    chrX-77899134-77899778_CYSLTR1                  -3.49485
#    chrX-81120681-81122301_SH3BGRL                  -3.31876
#        chrX-9378667-9379857_TBL1X                   4.09691
#     chrX-96722435-96723511_DIAPH2                   2.68194
#          chrX-989778-990654_IL3RA                   3.79588
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  3486 35150

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 318489 ranges and 11 metadata columns:
#                                       seqnames            ranges strand |
#                                          <Rle>         <IRanges>  <Rle> |
#                        chr1.chr1.chr1     chr1   1012920-1014120      * |
#                        chr1.chr1.chr1     chr1 10147738-10148559      * |
#                        chr1.chr1.chr1     chr1   1019144-1020371      * |
#                        chr1.chr1.chr1     chr1   1038601-1039080      * |
#                        chr1.chr1.chr1     chr1   1058756-1060110      * |
#                                   ...      ...               ...    ... .
#   chrX.chrX-77899134-77899778_CYSLTR1     chrX 77899134-77899778      * |
#   chrX.chrX-81120681-81122301_SH3BGRL     chrX 81120681-81122301      * |
#       chrX.chrX-9378667-9379857_TBL1X     chrX   9378667-9379857      * |
#    chrX.chrX-96722435-96723511_DIAPH2     chrX 96722435-96723511      * |
#         chrX.chrX-989778-990654_IL3RA     chrX     989778-990654      * |
#                                        TargetGene               PeakName
#                                       <character>            <character>
#                        chr1.chr1.chr1      UBE2J2   chr1-1012920-1014120
#                        chr1.chr1.chr1       UBE4B chr1-10147738-10148559
#                        chr1.chr1.chr1        NADK   chr1-1019144-1020371
#                        chr1.chr1.chr1       ISG15   chr1-1038601-1039080
#                        chr1.chr1.chr1        NADK   chr1-1058756-1060110
#                                   ...         ...                    ...
#   chrX.chrX-77899134-77899778_CYSLTR1     CYSLTR1 chrX-77899134-77899778
#   chrX.chrX-81120681-81122301_SH3BGRL     SH3BGRL chrX-81120681-81122301
#       chrX.chrX-9378667-9379857_TBL1X       TBL1X   chrX-9378667-9379857
#    chrX.chrX-96722435-96723511_DIAPH2      DIAPH2 chrX-96722435-96723511
#         chrX.chrX-989778-990654_IL3RA       IL3RA     chrX-989778-990654
#                                                     PairName       beta
#                                                  <character>  <numeric>
#                        chr1.chr1.chr1 chr1-1012920-1014120..   0.152425
#                        chr1.chr1.chr1 chr1-10147738-101485..   0.132616
#                        chr1.chr1.chr1 chr1-1019144-1020371..  -0.104505
#                        chr1.chr1.chr1 chr1-1038601-1039080..  -0.374559
#                        chr1.chr1.chr1 chr1-1058756-1060110..  -0.128388
#                                   ...                    ...        ...
#   chrX.chrX-77899134-77899778_CYSLTR1 chrX-77899134-778997.. -0.4792389
#   chrX.chrX-81120681-81122301_SH3BGRL chrX-81120681-811223.. -0.1499563
#       chrX.chrX-9378667-9379857_TBL1X chrX-9378667-9379857..  0.1630958
#    chrX.chrX-96722435-96723511_DIAPH2 chrX-96722435-967235..  0.0833827
#         chrX.chrX-989778-990654_IL3RA chrX-989778-990654_I..  0.3102046
#                                              se         z           p
#                                       <numeric> <numeric>   <numeric>
#                        chr1.chr1.chr1 0.0620578   2.45618 0.014042137
#                        chr1.chr1.chr1 0.0471038   2.81539 0.004871749
#                        chr1.chr1.chr1 0.0384375  -2.71883 0.006551309
#                        chr1.chr1.chr1 0.1028667  -3.64121 0.000271359
#                        chr1.chr1.chr1 0.0467201  -2.74802 0.005995713
#                                   ...       ...       ...         ...
#   chrX.chrX-77899134-77899778_CYSLTR1 0.0950917  -5.03975 4.66132e-07
#   chrX.chrX-81120681-81122301_SH3BGRL 0.0329712  -4.54809 5.41340e-06
#       chrX.chrX-9378667-9379857_TBL1X 0.0264363   6.16938 6.85587e-10
#    chrX.chrX-96722435-96723511_DIAPH2 0.0201098   4.14637 3.37783e-05
#         chrX.chrX-989778-990654_IL3RA 0.0796438   3.89490 9.82400e-05
#                                       boot_basic_p boot_basic_p.log10      sign
#                                          <numeric>          <numeric> <numeric>
#                        chr1.chr1.chr1      0.01104            1.95703         1
#                        chr1.chr1.chr1      0.01552            1.80911         1
#                        chr1.chr1.chr1      0.01072            1.96981        -1
#                        chr1.chr1.chr1      0.01368            1.86391        -1
#                        chr1.chr1.chr1      0.01160            1.93554        -1
#                                   ...          ...                ...       ...
#   chrX.chrX-77899134-77899778_CYSLTR1      0.00032            3.49485        -1
#   chrX.chrX-81120681-81122301_SH3BGRL      0.00048            3.31876        -1
#       chrX.chrX-9378667-9379857_TBL1X      0.00008            4.09691         1
#    chrX.chrX-96722435-96723511_DIAPH2      0.00208            2.68194         1
#         chrX.chrX-989778-990654_IL3RA      0.00016            3.79588         1
#                                       boot_basic_p.log10.signed
#                                                       <numeric>
#                        chr1.chr1.chr1                   1.95703
#                        chr1.chr1.chr1                   1.80911
#                        chr1.chr1.chr1                  -1.96981
#                        chr1.chr1.chr1                  -1.86391
#                        chr1.chr1.chr1                  -1.93554
#                                   ...                       ...
#   chrX.chrX-77899134-77899778_CYSLTR1                  -3.49485
#   chrX.chrX-81120681-81122301_SH3BGRL                  -3.31876
#       chrX.chrX-9378667-9379857_TBL1X                   4.09691
#    chrX.chrX-96722435-96723511_DIAPH2                   2.68194
#         chrX.chrX-989778-990654_IL3RA                   3.79588
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene  CellType beta        se
# 1      chr1   1012920   1014120 UBE2J2      Myeloid   0.15242525 0.06205776
# 2      chr1  10147738  10148559 UBE4B       Myeloid   0.13261564 0.04710376
# 3      chr1   1019144   1020371 NADK        Myeloid  -0.10450517 0.03843754
# 4      chr1   1038601   1039080 ISG15       Myeloid  -0.37455939 0.10286672
# 5      chr1   1058756   1060110 NADK        Myeloid  -0.12838767 0.04672014
# 6      chr1   1079374   1080601 CDK11B      Myeloid   0.16449572 0.06110268
# 7      chr1 109040911 109042568 CLCC1       Myeloid   0.14251012 0.05488633
# 8      chr1 109091688 109092177 GPSM2       Myeloid   0.28891353 0.10194700
# 9      chr1 109133440 109134866 GPSM2       Myeloid   0.29310711 0.09617894
# 10     chr1 109213476 109214665 SARS        Myeloid   0.21115222 0.07072164
# 11     chr1 109573504 109574558 AHCYL1      Myeloid  -0.27273708 0.09505956
# 12     chr1 109643175 109643836 AMPD2       Myeloid   0.16632329 0.06444675
# 13     chr1 110034075 110035478 LAMTOR5-AS1 Myeloid   0.15030050 0.05475852
# 14     chr1 110068666 110070653 AMPD2       Myeloid   0.15144738 0.05508265
# 15     chr1 110424462 110425171 STRIP1      Myeloid   0.26196256 0.11672272
# 16     chr1 110619222 110620626 RBM15       Myeloid   0.20249370 0.07707231
# 17     chr1 110627679 110628608 CEPT1       Myeloid  -0.14393662 0.05169942
# 18     chr1 110963175 110964482 FAM212B     Myeloid  -0.19962694 0.05904812
# 19     chr1 111139345 111140838 CEPT1       Myeloid  -0.10139644 0.03657225
# 20     chr1 111139345 111140838 FAM212B     Myeloid  -0.24226979 0.06737893
# 21     chr1 111616317 111616816 CEPT1       Myeloid  -0.15529944 0.05521685
# 22     chr1 111738407 111740718 ATP5F1      Myeloid  -0.16005882 0.05621385
# 23     chr1 111738407 111740718 FAM212B     Myeloid  -0.20705799 0.06124127
# 24     chr1   1121806   1123448 GNB1        Myeloid   0.07788593 0.02661965
# 25     chr1 112706534 112707637 FAM212B     Myeloid  -0.34345561 0.09626244
# 26     chr1 113140382 113141992 PTPN22      Myeloid   0.15969368 0.05463950
# 27     chr1 113389901 113391532 PHTF1       Myeloid   0.14690124 0.04562050
# 28     chr1 113389901 113391532 PTPN22      Myeloid   0.11077072 0.03523556
# 29     chr1 113928993 113931084 PHTF1       Myeloid   0.14114251 0.04262542
# 30     chr1 114040080 114041198 PTPN22      Myeloid   0.14492475 0.04467912
# ⋮      ⋮    ⋮         ⋮         ⋮           ⋮        ⋮           ⋮
# 318460 chrX 53071574  53073601  SMC1A       Myeloid   0.19046290 0.05344579
# 318461 chrX 53081843  53082907  SMC1A       Myeloid   0.13253351 0.04073004
# 318462 chrX 53224384  53225810  SMC1A       Myeloid   0.13246754 0.03962539
# 318463 chrX 53280164  53281893  KDM5C       Myeloid   0.27843651 0.09001215
# 318464 chrX 53287345  53288709  SMC1A       Myeloid   0.23446749 0.05263760
# 318465 chrX 53374180  53375241  SMC1A       Myeloid   0.21616396 0.05898753
# 318466 chrX 53421910  53423211  KDM5C       Myeloid   0.19170571 0.04925167
# 318467 chrX 53421910  53423211  SMC1A       Myeloid   0.11762703 0.03621192
# 318468 chrX 54182281  54183769  SMC1A       Myeloid   0.15326493 0.04967353
# 318469 chrX 65997710  65998828  MSN         Myeloid  -0.11387141 0.03133574
# 318470 chrX 71067720  71068957  NHSL2       Myeloid  -0.19718401 0.04503518
# 318471 chrX 71111138  71112478  NHSL2       Myeloid  -0.22457700 0.06742250
# 318472 chrX 71253872  71255695  NHSL2       Myeloid  -0.30942868 0.05915155
# 318473 chrX 71253872  71255695  NONO        Myeloid   0.18692709 0.05182659
# 318474 chrX 71253872  71255695  OGT         Myeloid   0.10905648 0.02955893
# 318475 chrX 71282778  71284216  NONO        Myeloid   0.14348201 0.04543674
# 318476 chrX 71365597  71367182  OGT         Myeloid   0.07541851 0.02416346
# 318477 chrX 71540871  71542054  RPS4X       Myeloid  -0.18319556 0.03024068
# 318478 chrX 72107322  72108644  RPS4X       Myeloid  -0.30474042 0.03040675
# 318479 chrX 72181025  72182115  NHSL2       Myeloid  -0.17016975 0.05128859
# 318480 chrX 73850802  73851931  JPX         Myeloid   0.17253377 0.03542301
# 318481 chrX 73850802  73851931  XIST        Myeloid   0.54370458 0.01779508
# 318482 chrX 73943694  73944847  XIST        Myeloid   0.18747851 0.01836553
# 318483 chrX 74291819  74293013  XIST        Myeloid   0.11040114 0.01830518
# 318484 chrX 74613836  74615059  XIST        Myeloid   0.07637641 0.01694361
# 318485 chrX 77899134  77899778  CYSLTR1     Myeloid  -0.47923887 0.09509173
# 318486 chrX 81120681  81122301  SH3BGRL     Myeloid  -0.14995632 0.03297125
# 318487 chrX  9378667   9379857  TBL1X       Myeloid   0.16309584 0.02643635
# 318488 chrX 96722435  96723511  DIAPH2      Myeloid   0.08338271 0.02010979
# 318489 chrX   989778    990654  IL3RA       Myeloid   0.31020460 0.07964383
#        z          p             boot_basic_p boot_basic_p.log10 sign
# 1       2.456184  0.0140421368  0.01104      1.957031            1
# 2       2.815394  0.0048717487  0.01552      1.809108            1
# 3      -2.718831  0.0065513095  0.01072      1.969805           -1
# 4      -3.641210  0.0002713592  0.01368      1.863914           -1
# 5      -2.748016  0.0059957130  0.01160      1.935542           -1
# 6       2.692120  0.0070999496  0.00712      2.147520            1
# 7       2.596459  0.0094190065  0.01040      1.982967            1
# 8       2.833958  0.0045975345  0.01520      1.818156            1
# 9       3.047519  0.0023073926  0.01088      1.963371            1
# 10      2.985681  0.0028294796  0.00272      2.565431            1
# 11     -2.869118  0.0041161823  0.00992      2.003488           -1
# 12      2.580786  0.0098575594  0.01136      1.944622            1
# 13      2.744787  0.0060550092  0.01104      1.957031            1
# 14      2.749457  0.0059694128  0.01000      2.000000            1
# 15      2.244315  0.0248121302  0.01616      1.791559            1
# 16      2.627321  0.0086060090  0.00832      2.079877            1
# 17     -2.784105  0.0053675675  0.01152      1.938548           -1
# 18     -3.380750  0.0007228823  0.00192      2.716699           -1
# 19     -2.772497  0.0055628110  0.01392      1.856361           -1
# 20     -3.595631  0.0003236058  0.00128      2.892790           -1
# 21     -2.812537  0.0049152311  0.01208      1.917933           -1
# 22     -2.847320  0.0044089029  0.00968      2.014125           -1
# 23     -3.381021  0.0007221707  0.00232      2.634512           -1
# 24      2.925881  0.0034348180  0.00736      2.133122            1
# 25     -3.567909  0.0003598416  0.00232      2.634512           -1
# 26      2.922678  0.0034703502  0.01192      1.923724            1
# 27      3.220071  0.0012815902  0.00984      2.007005            1
# 28      3.143719  0.0016681536  0.00808      2.092589            1
# 29      3.311229  0.0009288722  0.01000      2.000000            1
# 30      3.243680  0.0011799633  0.00920      2.036212            1
# ⋮      ⋮          ⋮             ⋮            ⋮                  ⋮
# 318460   3.563665  3.657126e-04 0.00112      2.950782            1
# 318461   3.253950  1.138123e-03 0.00240      2.619789            1
# 318462   3.342997  8.287887e-04 0.00216      2.665546            1
# 318463   3.093321  1.979296e-03 0.00208      2.681937            1
# 318464   4.454373  8.413885e-06 0.00008      4.096910            1
# 318465   3.664571  2.477537e-04 0.00072      3.142668            1
# 318466   3.892370  9.926981e-05 0.00008      4.096910            1
# 318467   3.248295  1.160986e-03 0.00376      2.424812            1
# 318468   3.085444  2.032482e-03 0.00488      2.311580            1
# 318469  -3.633915  2.791529e-04 0.00360      2.443697           -1
# 318470  -4.378444  1.195299e-05 0.00008      4.096910           -1
# 318471  -3.330891  8.656843e-04 0.00560      2.251812           -1
# 318472  -5.231117  1.684888e-07 0.00008      4.096910           -1
# 318473   3.606779  3.100209e-04 0.00088      3.055517            1
# 318474   3.689459  2.247310e-04 0.00040      3.397940            1
# 318475   3.157841  1.589421e-03 0.00296      2.528708            1
# 318476   3.121180  1.801279e-03 0.00368      2.434152            1
# 318477  -6.057919  1.378942e-09 0.00480      2.318759           -1
# 318478 -10.022132  1.218459e-23 0.00008      4.096910           -1
# 318479  -3.317887  9.070110e-04 0.00368      2.434152           -1
# 318480   4.870669  1.112208e-06 0.00016      3.795880            1
# 318481  30.553648 5.057667e-205 0.00008      4.096910            1
# 318482  10.208175  1.822602e-24 0.00008      4.096910            1
# 318483   6.031141  1.628058e-09 0.00024      3.619789            1
# 318484   4.507683  6.553951e-06 0.00792      2.101275            1
# 318485  -5.039753  4.661319e-07 0.00032      3.494850           -1
# 318486  -4.548094  5.413401e-06 0.00048      3.318759           -1
# 318487   6.169379  6.855870e-10 0.00008      4.096910            1
# 318488   4.146373  3.377832e-05 0.00208      2.681937            1
# 318489   3.894898  9.824001e-05 0.00016      3.795880            1
#        boot_basic_p.log10.signed FDR
# 1       1.957031                 0.09000269
# 2       1.809108                 0.11035832
# 3      -1.969805                 0.08870131
# 4      -1.863914                 0.10151280
# 5      -1.935542                 0.09284460
# 6       2.147520                 0.06637324
# 7       1.982967                 0.08635188
# 8       1.818156                 0.10814084
# 9       1.963371                 0.08987810
# 10      2.565431                 0.03363841
# 11     -2.003488                 0.08506532
# 12      1.944622                 0.09112061
# 13      1.957031                 0.09000269
# 14      2.000000                 0.08567751
# 15      1.791559                 0.11279630
# 16      2.079877                 0.07428107
# 17     -1.938548                 0.09227386
# 18     -2.716699                 0.02617718
# 19     -1.856361                 0.10319515
# 20     -2.892790                 0.01952049
# 21     -1.917933                 0.09412931
# 22     -2.014125                 0.08344539
# 23     -2.634512                 0.03002050
# 24      2.133122                 0.06794038
# 25     -2.634512                 0.03002050
# 26      1.923724                 0.09356087
# 27      2.007005                 0.08453407
# 28      2.092589                 0.07274398
# 29      2.000000                 0.08567751
# 30      2.036212                 0.08017564
# ⋮      ⋮                         ⋮
# 318460  2.950782                 0.017663168
# 318461  2.619789                 0.030759501
# 318462  2.665546                 0.028515492
# 318463  2.681937                 0.027737601
# 318464  4.096910                 0.002128937
# 318465  3.142668                 0.012651003
# 318466  4.096910                 0.002128937
# 318467  2.424812                 0.042366045
# 318468  2.311580                 0.050918173
# 318469 -2.443697                 0.041124835
# 318470 -4.096910                 0.002128937
# 318471 -2.251812                 0.055987519
# 318472 -4.096910                 0.002128937
# 318473  3.055517                 0.014729363
# 318474  3.397940                 0.008014822
# 318475  2.528708                 0.035693149
# 318476  2.434152                 0.041748220
# 318477 -2.318759                 0.050317530
# 318478 -4.096910                 0.002128937
# 318479 -2.434152                 0.041748220
# 318480  3.795880                 0.003831735
# 318481  4.096910                 0.002128937
# 318482  4.096910                 0.002128937
# 318483  3.619789                 0.005347514
# 318484  2.101275                 0.071688537
# 318485 -3.494850                 0.006722723
# 318486 -3.318759                 0.009255598
# 318487  4.096910                 0.002128937
# 318488  2.681937                 0.027737601
# 318489  3.795880                 0.003831735

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
