# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.2500.240606/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/Erythroid/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/Erythroid.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.25000.240612/"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_AGCGCCTAGATGGACA-1 s1d1_AGCGCCTAGATGGACA-1  2307  77   K562      7.743703
# s1d1_CCTGAATAGCTTGCTC-1 s1d1_CCTGAATAGCTTGCTC-1  3907  53   K562      8.270525
# s1d1_GGCTGAGAGTATTGCA-1 s1d1_GGCTGAGAGTATTGCA-1  2159  38   K562      7.677400
# s1d1_GGCAATCGTTAGGACC-1 s1d1_GGCAATCGTTAGGACC-1  1154  30   K562      7.050989
# s1d1_AGTTATGTCTCACTCA-1 s1d1_AGTTATGTCTCACTCA-1  1534  23   K562      7.335634
# s1d1_GTTTGTCGTGAATCGC-1 s1d1_GTTTGTCGTGAATCGC-1  6050 100   K562      8.707814
# s1d1_CGCAAATTCTACTAAG-1 s1d1_CGCAAATTCTACTAAG-1  4517 106   K562      8.415603
# s1d1_GGTTTCCTCTTGGACG-1 s1d1_GGTTTCCTCTTGGACG-1  2323  64   K562      7.750615
# s1d1_AATCAGGAGCTGAGGG-1 s1d1_AATCAGGAGCTGAGGG-1  1067  36   K562      6.972606
# s4d9_TAGCCGGGTAATAGCT-1 s4d9_TAGCCGGGTAATAGCT-1 2699   455  K562     7.900637
#                         percent.mito
# s1d1_AGCGCCTAGATGGACA-1 0.033376680
# s1d1_CCTGAATAGCTTGCTC-1 0.013565395
# s1d1_GGCTGAGAGTATTGCA-1 0.017600741
# s1d1_GGCAATCGTTAGGACC-1 0.025996534
# s1d1_AGTTATGTCTCACTCA-1 0.014993481
# s1d1_GTTTGTCGTGAATCGC-1 0.016528926
# s1d1_CGCAAATTCTACTAAG-1 0.023466903
# s1d1_GGTTTCCTCTTGGACG-1 0.027550581
# s1d1_AATCAGGAGCTGAGGG-1 0.033739456
# s1d1_TGAGTGAAGTTAGTGC-1 0.009433962
# s1d1_CTTAGTTTCCTTGCGT-1 0.009551928
# s1d1_GCCTATTGTTAGGTGC-1 0.017494752
# s1d1_ATTAACCCATTAGCCA-1 0.006248123
# s1d1_GTTAACCAGTTATTCC-1 0.051130777
# s1d1_GTTTCAGCAGCACGTT-1 0.054033486
# s1d1_AATAACCGTCATTGAG-1 0.042035398
# s1d1_TAGGCTAGTGTAACCA-1 0.018584703
# s1d1_CTTCGCGTCGAGCAAA-1 0.018759019
# s1d1_TCAGGTCCAAACTCAT-1 0.015858209
# s1d1_ATTTGCAAGGCATTAC-1 0.012142533
# s1d1_CTGGATGTCATAACTG-1 0.009157874
# s1d1_TCATCCATCCTCATCA-1 0.039106145
# s1d1_TGCTTAAAGCCGCTAA-1 0.032275711
# s1d1_CAGCCTTTCCTGTTCA-1 0.032967033
# s1d1_ACGACTTAGCTACTGG-1 0.021550518
# s1d1_CCAGCCTGTTAGGACC-1 0.030353467
# s1d1_CTCTGTTCAAACTGTT-1 0.032500855
# s1d1_GTTTCTAGTCATCATC-1 0.010537992
# s1d1_TGATGATGTGCAACTA-1 0.045362903
# s1d1_GCGCTTGCAATCCCTT-1 0.021202776
# ⋮                       ⋮
# s4d9_ATTTGTGAGGCGCACT-1 0.098270772
# s4d9_GGTTAATGTGCAACTA-1 0.001177856
# s4d9_TATTCGTTCAATGTCA-1 0.029585799
# s4d9_CGGAGTCTCCAGGTTG-1 0.061583578
# s4d9_ATGGCTTAGGAGGCAT-1 0.002863962
# s4d9_GGCTATTAGCACGTTG-1 0.150448965
# s4d9_CTCCTAATCGCTAAGT-1 0.060100167
# s4d9_GGTTGCATCTGTAATG-1 0.159947606
# s4d9_TTAGCAGGTGAATCGC-1 0.094608342
# s4d9_CTGGTTACACCACAAC-1 0.045918367
# s4d9_GTCGGTTCACGAATTT-1 0.125373134
# s4d9_GTGGTTAGTAACTACG-1 0.041331803
# s4d9_AAGCCTTAGTAAACCC-1 0.069175429
# s4d9_ACCCGTAAGCAATAGG-1 0.130097573
# s4d9_CTCATGACAGCCGCTA-1 0.106007067
# s4d9_AAGGCCCTCTAGCGTG-1 0.070904645
# s4d9_TCTAGCCTCTTTAAGG-1 0.119122257
# s4d9_GCTAAGCGTCTCAGCC-1 0.041046691
# s4d9_AGTAAGTAGTAAACCC-1 0.034828808
# s4d9_TCCAGGATCACCATTT-1 0.089812332
# s4d9_TAGAGCCGTGAGGTAG-1 0.088178295
# s4d9_CTCATCATCAATCTCT-1 0.032154341
# s4d9_AGGACGTAGTGCACGC-1 0.102451839
# s4d9_TGCTTGCTCATTGTCT-1 0.068002109
# s4d9_TGTAAGCTCGCTAAGT-1 0.164271845
# s4d9_TATGAAGCATTGTGGC-1 0.020279720
# s4d9_CTCACACTCGGGACCT-1 0.182740107
# s4d9_TCCATCATCGCATTAA-1 0.043997017
# s4d9_CCAGGATGTATTCGTC-1 0.049875312
# s4d9_TAGCCGGGTAATAGCT-1 0.168580956

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)
# Out:
# Warning message in dir.create(paste(dir.output, "chr", sep = "/"), recursive = T):
# “'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.Erythroid.25000.240612//chr' already exists”

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep = pairs.E2G.chr[!pairs.E2G.chr %in% pairs.E2G.chr.res]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 51758 ranges and 11 metadata columns:
#                       seqnames              ranges strand |  TargetGene
#                          <Rle>           <IRanges>  <Rle> | <character>
#   chr1.chr1.chr1.chr1     chr1 100132316-100133496      * |     SLC35A3
#   chr1.chr1.chr1.chr1     chr1 100347353-100347658      * |       FRRS1
#   chr1.chr1.chr1.chr1     chr1 100351187-100353307      * |         AGL
#   chr1.chr1.chr1.chr1     chr1 100351187-100353307      * |       FRRS1
#   chr1.chr1.chr1.chr1     chr1 100351187-100353307      * |     SLC30A7
#                   ...      ...                 ...    ... .         ...
#   chrX.chrX.chrX.chrX     chrX   81229043-81229890      * |       BRWD3
#   chrX.chrX.chrX.chrX     chrX   81229043-81229890      * |       HMGN5
#   chrX.chrX.chrX.chrX     chrX   81229043-81229890      * |     SH3BGRL
#   chrX.chrX.chrX.chrX     chrX   85003058-85004592      * |       APOOL
#   chrX.chrX.chrX.chrX     chrX   86047015-86047963      * |         CHM
#                                     PeakName               PairName       beta
#                                  <character>            <character>  <numeric>
#   chr1.chr1.chr1.chr1 chr1-100132316-10013.. chr1-100132316-10013..   0.241745
#   chr1.chr1.chr1.chr1 chr1-100347353-10034.. chr1-100347353-10034..   0.321852
#   chr1.chr1.chr1.chr1 chr1-100351187-10035.. chr1-100351187-10035..   0.281043
#   chr1.chr1.chr1.chr1 chr1-100351187-10035.. chr1-100351187-10035..   0.207092
#   chr1.chr1.chr1.chr1 chr1-100351187-10035.. chr1-100351187-10035..   0.187993
#                   ...                    ...                    ...        ...
#   chrX.chrX.chrX.chrX chrX-81229043-81229890 chrX-81229043-812298.. -0.0347830
#   chrX.chrX.chrX.chrX chrX-81229043-81229890 chrX-81229043-812298..  0.0115558
#   chrX.chrX.chrX.chrX chrX-81229043-81229890 chrX-81229043-812298..  0.0222126
#   chrX.chrX.chrX.chrX chrX-85003058-85004592 chrX-85003058-850045..  0.0675825
#   chrX.chrX.chrX.chrX chrX-86047015-86047963 chrX-86047015-860479..  0.2047059
#                              se         z           p boot_basic_p
#                       <numeric> <numeric>   <numeric>    <numeric>
#   chr1.chr1.chr1.chr1 0.0811716   2.97819 2.89952e-03      0.00664
#   chr1.chr1.chr1.chr1 0.0890483   3.61436 3.01096e-04      0.00176
#   chr1.chr1.chr1.chr1 0.0799622   3.51470 4.40251e-04      0.00432
#   chr1.chr1.chr1.chr1 0.0586227   3.53263 4.11442e-04      0.00240
#   chr1.chr1.chr1.chr1 0.0437437   4.29759 1.72663e-05      0.00056
#                   ...       ...       ...         ...          ...
#   chrX.chrX.chrX.chrX 0.0862830 -0.403126    0.686855         0.76
#   chrX.chrX.chrX.chrX 0.0776910  0.148740    0.881759         0.84
#   chrX.chrX.chrX.chrX 0.0508727  0.436631    0.662379         0.68
#   chrX.chrX.chrX.chrX 0.0901425  0.749729    0.453418         0.50
#   chrX.chrX.chrX.chrX 0.1294803  1.580982    0.113882         0.16
#                       boot_basic_p.log10      sign boot_basic_p.log10.signed
#                                <numeric> <numeric>                 <numeric>
#   chr1.chr1.chr1.chr1            2.17783         1                   2.17783
#   chr1.chr1.chr1.chr1            2.75449         1                   2.75449
#   chr1.chr1.chr1.chr1            2.36452         1                   2.36452
#   chr1.chr1.chr1.chr1            2.61979         1                   2.61979
#   chr1.chr1.chr1.chr1            3.25181         1                   3.25181
#                   ...                ...       ...                       ...
#   chrX.chrX.chrX.chrX          0.1191864        -1                -0.1191864
#   chrX.chrX.chrX.chrX          0.0757207         1                 0.0757207
#   chrX.chrX.chrX.chrX          0.1674911         1                 0.1674911
#   chrX.chrX.chrX.chrX          0.3010300         1                 0.3010300
#   chrX.chrX.chrX.chrX          0.7958800         1                 0.7958800
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#       chr  start     end       TargetGene CellType beta         se
# 1     chr1 100132316 100133496 SLC35A3    K562     0.2417448    0.08117160
# 2     chr1 100347353 100347658 FRRS1      K562     0.3218523    0.08904832
# 3     chr1 100351187 100353307 AGL        K562     0.2810432    0.07996222
# 4     chr1 100351187 100353307 FRRS1      K562     0.2070925    0.05862268
# 5     chr1 100351187 100353307 SLC30A7    K562     0.1879927    0.04374372
# 6     chr1 100448032 100449138 SASS6      K562     0.1765400    0.06053763
# 7     chr1 100448032 100449138 TRMT13     K562     0.3573626    0.09212059
# 8     chr1 100463619 100464779 FRRS1      K562     0.3953888    0.08671158
# 9     chr1 100463619 100464779 SLC35A3    K562     0.3949741    0.11534807
# 10    chr1  10074828  10075861 KIF1B      K562     0.3744435    0.11372575
# 11    chr1  10074828  10075861 PEX14      K562     0.4612830    0.06274601
# 12    chr1  10074828  10075861 PGD        K562     0.3456264    0.09031840
# 13    chr1  10074828  10075861 SLC25A33   K562     0.5115972    0.09462313
# 14    chr1  10074828  10075861 SRM        K562     0.4096626    0.08789140
# 15    chr1  10074828  10075861 UBE4B      K562     0.1876323    0.04639096
# 16    chr1 100894669 100897037 CDC14A     K562     0.1732225    0.03570324
# 17    chr1 101025260 101026359 SLC30A7    K562     0.2088390    0.05048097
# 51743 -1.01650558 0.30938869   0.40         0.39794001         -1
# 51744  0.99106862 0.32165207   0.36         0.44369750          1
# 51745 -1.51695789 0.12927732   0.24         0.61978876         -1
# 51746 -0.15848951 0.87407109   0.94         0.02687215         -1
# 51747  1.40966200 0.15863951   0.14         0.85387196          1
# 51748  0.79813577 0.42479171   0.52         0.28399666          1
# 51749 -0.80785206 0.41917575   0.50         0.30103000         -1
# 51750 -0.19092707 0.84858273   0.92         0.03621217         -1
# 51751  0.17154502 0.86379523   0.88         0.05551733          1
# 51752 -1.77673558 0.07561176   0.20         0.69897000         -1
# 51753 -0.46706362 0.64045436   0.76         0.11918641         -1
# 51754 -0.40312636 0.68685527   0.76         0.11918641         -1
# 51755  0.14874021 0.88175863   0.84         0.07572071          1
# 51756  0.43663081 0.66237912   0.68         0.16749109          1
# 51757  0.74972927 0.45341777   0.50         0.30103000          1
# 51758  1.58098164 0.11388224   0.16         0.79588002          1
#       boot_basic_p.log10.signed
# 1     2.177832
# 2     2.754487
# 3     2.364516
# 4     2.619789
# 5     3.251812
# 6     2.084073
# 7     3.318759
# 8     4.096910
# 9     3.142668
# 10    2.494850
# 11    4.096910
# 12    3.795880
# 13    4.096910
# 14    4.096910
# 15    2.649752
# 16    3.096910
# 17    2.982967
# 18    4.096910
# 19    2.540608
# 20    4.096910
# 21    4.096910
# 22    2.982967
# 23    2.297569
# 24    2.735182
# 25    2.051587
# 26    3.494850
# 27    2.167491
# 28    2.239578
# 29    2.003488
# 30    2.040005
# ⋮     ⋮
# 51729  0.13076828
# 51730 -0.25181197
# 51731 -0.39794001
# 51732 -0.74472749
# 51733  0.01772877
# 51734  0.18045606
# 51735 -0.23657201
# 51736  0.03621217
# 51737 -0.23657201
# 51738  0.44369750
# 51739 -0.13076828
# 51740 -0.55284197
# 51741  0.10790540
# 51742 -0.35654732
# 51743 -0.39794001
# 51744  0.44369750
# 51745 -0.61978876
# 51746 -0.02687215
# 51747  0.85387196
# 51748  0.28399666
# 51749 -0.30103000
# 51750 -0.03621217
# 51751  0.05551733
# 51752 -0.69897000
# 51753 -0.11918641
# 51754 -0.11918641
# 51755  0.07572071
# 51756  0.16749109
# 51757  0.30103000
# 51758  0.79588002

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
# [1] Matrix_1.6-5         GenomicRanges_1.54.1 GenomeInfoDb_1.38.1
# [4] IRanges_2.36.0       S4Vectors_0.40.2     BiocGenerics_0.48.1
# [7] genomation_1.34.0    Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] htmlTable_2.4.2             backports_1.4.1
#  [43] BiocParallel_1.36.0         R.utils_2.12.3
#  [45] MASS_7.3-60                 DelayedArray_0.26.7
#  [47] rjson_0.2.21                tools_4.3.3
#  [49] foreign_0.8-86              future.apply_1.11.2
#  [51] nnet_7.3-19                 R.oo_1.26.0
#  [53] glue_1.7.0                  restfulr_0.0.15
#  [55] nlme_3.1-164                pbdZMQ_0.3-11
#  [57] checkmate_2.3.1             gridBase_0.4-7
#  [59] cluster_2.1.6               reshape2_1.4.4
#  [61] generics_0.1.3              gtable_0.3.5
#  [63] BSgenome_1.68.0             tzdb_0.4.0
#  [65] R.methodsS3_1.8.2           tidyr_1.3.1
#  [67] seqPattern_1.34.0           data.table_1.15.2
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               dplyr_1.1.4
#  [79] lattice_0.22-6              rtracklayer_1.60.1
#  [81] tidyselect_1.2.1            Biostrings_2.70.1
#  [83] pbapply_1.7-2               knitr_1.46
#  [85] gridExtra_2.3               SummarizedExperiment_1.30.2
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
