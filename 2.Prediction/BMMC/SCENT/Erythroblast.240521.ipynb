# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/Erythroblast/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/Erythroblast/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC/Erythroblast/Kendall/atac_matrix.csv.gz"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/2.seurat_pipeline.240506/RNA_count_matrix/Erythroblast.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/Erythroblast.240521/"

# %%
n.cores = 32

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 1M

# %%
pairs.ABC.1M = pairs.ABC[pairs.ABC$distance < 10^6]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.1M

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.1M.chr_rename = as.data.frame(pairs.ABC.1M)[,1:3]
df.pairs.ABC.1M.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.1M),
                                                mcols(pairs.ABC.1M)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.1M.chr_rename = GRanges(df.pairs.ABC.1M.chr_rename)
rm(df.pairs.ABC.1M.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.1M.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.1M.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 3357441 ranges and 3 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100020589-100020894      * |         AGL
#         [2]     chr1 100020589-100020894      * |      CDC14A
#         [3]     chr1 100020589-100020894      * |         DBT
#         [4]     chr1 100020589-100020894      * |       EXTL2
#         [5]     chr1 100020589-100020894      * |       FRRS1
#         ...      ...                 ...    ... .         ...
#   [3357437]     chrX     9995615-9996429      * |       TBL1X
#   [3357438]     chrX     9995615-9996429      * |        WWC3
#   [3357439]     chrX     9997681-9997915      * |       CLCN4
#   [3357440]     chrX     9997681-9997915      * |       TBL1X
#   [3357441]     chrX     9997681-9997915      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-100020589-10002.. chr1-100020589-10002..
#         [2] chr1-100020589-10002.. chr1-100020589-10002..
#         [3] chr1-100020589-10002.. chr1-100020589-10002..
#         [4] chr1-100020589-10002.. chr1-100020589-10002..
#         [5] chr1-100020589-10002.. chr1-100020589-10002..
#         ...                    ...                    ...
#   [3357437]   chrX-9995615-9996429 chrX-9995615-9996429..
#   [3357438]   chrX-9995615-9996429 chrX-9995615-9996429..
#   [3357439]   chrX-9997681-9997915 chrX-9997681-9997915..
#   [3357440]   chrX-9997681-9997915 chrX-9997681-9997915..
#   [3357441]   chrX-9997681-9997915 chrX-9997681-9997915..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = read.csv(path.matrix.atac_count,
                       row.names = 1,
                       check.names = F)
matrix.atac = Matrix(as.matrix(matrix.atac), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_AGCGCCTAGATGGACA-1 s1d1_AGCGCCTAGATGGACA-1  2307  77   K562      7.743703
# s1d1_CCTGAATAGCTTGCTC-1 s1d1_CCTGAATAGCTTGCTC-1  3907  53   K562      8.270525
# s1d1_GGCTGAGAGTATTGCA-1 s1d1_GGCTGAGAGTATTGCA-1  2159  38   K562      7.677400
# s1d1_GTTTGTCGTGAATCGC-1 s1d1_GTTTGTCGTGAATCGC-1  6050 100   K562      8.707814
# s1d1_CGCAAATTCTACTAAG-1 s1d1_CGCAAATTCTACTAAG-1  4517 106   K562      8.415603
# s1d1_GGTTTCCTCTTGGACG-1 s1d1_GGTTTCCTCTTGGACG-1  2323  64   K562      7.750615
# s1d1_CTTAGTTTCCTTGCGT-1 s1d1_CTTAGTTTCCTTGCGT-1  5758  55   K562      8.658345
# s1d1_ATTAACCCATTAGCCA-1 s1d1_ATTAACCCATTAGCCA-1 16645 104   K562      9.719865
# s1d1_AATAACCGTCATTGAG-1 s1d1_AATAACCGTCATTGAG-1   904  38   K562      6.806829
# s1d1_TAGGCTAGTGTAACCA-1 s1d1_TAGGCTAGTGTAACCA-1  1399  26   K562      7.243513
# s1d1_CTTCGCGTCGAGCAAA-1 s1d1_CTTCGCGTCGAGCAAA-1  2079  39   K562      7.639642
# s1d1_ATTTGCAAGGCATTAC-1 s1d1_ATTTGCAAGGCATTAC-1  8812 107   K562      9.083870
# s1d1_CTGGATGTCATAACTG-1 s1d1_CTGGATGTCATAACTG-1  5023  46   K562      8.521783
# s1d1_TCATCCATCCTCATCA-1 s1d1_TCATCCATCCTCATCA-1  1969  77   K562      7.585281
# s1d1_ACGACTTAGCTACTGG-1 s1d1_ACGACTTAGCTACTGG-1  3573  77   K562      8.181161
# s1d1_CCAGCCTGTTAGGACC-1 s1d1_CCAGCCTGTTAGGACC-1 22831 693   K562     10.035875
# s1d1_CTCTGTTCAAACTGTT-1 s1d1_CTCTGTTCAAACTGTT-1  2923  95   K562      7.980366
# s1d1_GTTTCTAGTCATCATC-1 s1d1_GTTTCTAGTCATCATC-1  3606  38   K562      8.190354
# s1d1_GCGCTTGCAATCCCTT-1 s1d1_GCGCTTGCAATCCCTT-1  2594  55   K562      7.860956
# s1d1_CAGCAAGCAATGAATG-1 s1d1_CAGCAAGCAATGAATG-1  2353  55   K562      7.763446
# s1d1_TAAGTGCTCTGTGAGT-1 s1d1_TAAGTGCTCTGTGAGT-1  2699  26   K562      7.900637
# s1d1_CTAAGTCAGGCTGTGC-1 s1d1_CTAAGTCAGGCTGTGC-1  3074  43   K562      8.030735
# s1d1_AGCATCCCATGTTGCA-1 s1d1_AGCATCCCATGTTGCA-1  2046  47   K562      7.623642
# s1d1_GGCTTAAGTGGTTATG-1 s1d1_GGCTTAAGTGGTTATG-1  3057  59   K562      8.025189
# s1d1_CCAACCAAGGCGAATA-1 s1d1_CCAACCAAGGCGAATA-1  2857  68   K562      7.957527
# s1d1_CTGTTAAAGGTCCAAT-1 s1d1_CTGTTAAAGGTCCAAT-1  5473 102   K562      8.607582
# s1d1_AGTTGCGTCAGTATTG-1 s1d1_AGTTGCGTCAGTATTG-1  9338 217   K562      9.141847
# s1d1_TAGTCAATCGGCTAGC-1 s1d1_TAGTCAATCGGCTAGC-1  2513  42   K562      7.829233
# s1d1_AATGCGCGTGGTTAGC-1 s1d1_AATGCGCGTGGTTAGC-1  1901  23   K562      7.550135
# s1d1_ATCACCCTCTGTGCAG-1 s1d1_ATCACCCTCTGTGCAG-1  4696 164   K562      8.454466
# ⋮                       ⋮                       ⋮     ⋮     ⋮        ⋮
# s4d9_GAGCTAGCAAGTGAAC-1 s4d9_GAGCTAGCAAGTGAAC-1  642   30   K562     6.464588
# s4d9_AATCATGTCGGTCATG-1 s4d9_AATCATGTCGGTCATG-1 2967  119   K562     7.995307
# s4d9_GCGAAGTAGTAACAGG-1 s4d9_GCGAAGTAGTAACAGG-1 1146   23   K562     7.044033
# s4d9_AGCTTAATCACATTGA-1 s4d9_AGCTTAATCACATTGA-1 4741  431   K562     8.464003
# s4d9_TGTGTGAGTTGTCCAT-1 s4d9_TGTGTGAGTTGTCCAT-1 1087   46   K562     6.991177
# s4d9_GACTATTCAGGTTAAA-1 s4d9_GACTATTCAGGTTAAA-1 3105  304   K562     8.040769
# s4d9_ATTAGGTGTATTGTGG-1 s4d9_ATTAGGTGTATTGTGG-1 1020   23   K562     6.927558
# s4d9_GACCTCAAGCCTTAAA-1 s4d9_GACCTCAAGCCTTAAA-1 2545  120   K562     7.841886
# s4d9_ACCACACCAATAGCAA-1 s4d9_ACCACACCAATAGCAA-1 2242  166   K562     7.715124
# s4d9_TAGGTTATCGCTATAA-1 s4d9_TAGGTTATCGCTATAA-1 1100   30   K562     7.003065
# s4d9_ACGAAGTCATAGCGAG-1 s4d9_ACGAAGTCATAGCGAG-1  794   59   K562     6.677083
# s4d9_CACGCAATCGATAACC-1 s4d9_CACGCAATCGATAACC-1 1461   26   K562     7.286876
# s4d9_CGAGGTGAGCTATGAC-1 s4d9_CGAGGTGAGCTATGAC-1 1814  124   K562     7.503290
# s4d9_ACGCCTTTCCTAGTCC-1 s4d9_ACGCCTTTCCTAGTCC-1 1234   92   K562     7.118016
# s4d9_TTTAAGCCACGTTACA-1 s4d9_TTTAAGCCACGTTACA-1 1246   37   K562     7.127694
# s4d9_ACGAACAAGCGGGCAA-1 s4d9_ACGAACAAGCGGGCAA-1 1417   85   K562     7.256297
# s4d9_GTTACAGGTAACCTAG-1 s4d9_GTTACAGGTAACCTAG-1 1067   60   K562     6.972606
# s4d9_CCGGTAGGTAATAGCT-1 s4d9_CCGGTAGGTAATAGCT-1  878   34   K562     6.777647
# s4d9_CGCACACAGGATCCGC-1 s4d9_CGCACACAGGATCCGC-1  950   95   K562     6.856462
# s4d9_CTACCTCAGCACAGGG-1 s4d9_CTACCTCAGCACAGGG-1 1789  185   K562     7.489412
# s4d9_TATGGGCGTCATCCTG-1 s4d9_TATGGGCGTCATCCTG-1  622   16   K562     6.432940
# s4d9_ACTAACTCAGGTTCAC-1 s4d9_ACTAACTCAGGTTCAC-1 2636  154   K562     7.877018
# s4d9_CTCCTAATCGCTAAGT-1 s4d9_CTCCTAATCGCTAAGT-1  599   36   K562     6.395262
# s4d9_GTGGTTAGTAACTACG-1 s4d9_GTGGTTAGTAACTACG-1  871   36   K562     6.769642
# s4d9_AAGCCTTAGTAAACCC-1 s4d9_AAGCCTTAGTAAACCC-1 1807  125   K562     7.499423
# s4d9_CTCATGACAGCCGCTA-1 s4d9_CTCATGACAGCCGCTA-1 3113  330   K562     8.043342
# s4d9_TAGAGCCGTGAGGTAG-1 s4d9_TAGAGCCGTGAGGTAG-1 1032   91   K562     6.939254
# s4d9_AGGACGTAGTGCACGC-1 s4d9_AGGACGTAGTGCACGC-1 1142  117   K562     7.040536
# s4d9_TGCTTGCTCATTGTCT-1 s4d9_TGCTTGCTCATTGTCT-1 1897  129   K562     7.548029
# s4d9_TATGAAGCATTGTGGC-1 s4d9_TATGAAGCATTGTGGC-1 1430   29   K562     7.265430
#                         percent.mito
# s1d1_AGCGCCTAGATGGACA-1 0.033376680
# s1d1_CCTGAATAGCTTGCTC-1 0.013565395
# s1d1_GGCTGAGAGTATTGCA-1 0.017600741
# s1d1_GTTTGTCGTGAATCGC-1 0.016528926
# s1d1_CGCAAATTCTACTAAG-1 0.023466903
# s1d1_GGTTTCCTCTTGGACG-1 0.027550581
# s1d1_CTTAGTTTCCTTGCGT-1 0.009551928
# s1d1_ATTAACCCATTAGCCA-1 0.006248123
# s1d1_AATAACCGTCATTGAG-1 0.042035398
# s1d1_TAGGCTAGTGTAACCA-1 0.018584703
# s1d1_CTTCGCGTCGAGCAAA-1 0.018759019
# s1d1_ATTTGCAAGGCATTAC-1 0.012142533
# s1d1_CTGGATGTCATAACTG-1 0.009157874
# s1d1_TCATCCATCCTCATCA-1 0.039106145
# s1d1_ACGACTTAGCTACTGG-1 0.021550518
# s1d1_CCAGCCTGTTAGGACC-1 0.030353467
# s1d1_CTCTGTTCAAACTGTT-1 0.032500855
# s1d1_GTTTCTAGTCATCATC-1 0.010537992
# s1d1_GCGCTTGCAATCCCTT-1 0.021202776
# s1d1_CAGCAAGCAATGAATG-1 0.023374416
# s1d1_TAAGTGCTCTGTGAGT-1 0.009633197
# s1d1_CTAAGTCAGGCTGTGC-1 0.013988289
# s1d1_AGCATCCCATGTTGCA-1 0.022971652
# s1d1_GGCTTAAGTGGTTATG-1 0.019299967
# s1d1_CCAACCAAGGCGAATA-1 0.023801190
# s1d1_CTGTTAAAGGTCCAAT-1 0.018636945
# s1d1_AGTTGCGTCAGTATTG-1 0.023238381
# s1d1_TAGTCAATCGGCTAGC-1 0.016713092
# s1d1_AATGCGCGTGGTTAGC-1 0.012098895
# s1d1_ATCACCCTCTGTGCAG-1 0.034923339
# ⋮                       ⋮
# s4d9_GAGCTAGCAAGTGAAC-1 0.04672897
# s4d9_AATCATGTCGGTCATG-1 0.04010785
# s4d9_GCGAAGTAGTAACAGG-1 0.02006981
# s4d9_AGCTTAATCACATTGA-1 0.09090909
# s4d9_TGTGTGAGTTGTCCAT-1 0.04231831
# s4d9_GACTATTCAGGTTAAA-1 0.09790660
# s4d9_ATTAGGTGTATTGTGG-1 0.02254902
# s4d9_GACCTCAAGCCTTAAA-1 0.04715128
# s4d9_ACCACACCAATAGCAA-1 0.07404103
# s4d9_TAGGTTATCGCTATAA-1 0.02727273
# s4d9_ACGAAGTCATAGCGAG-1 0.07430730
# s4d9_CACGCAATCGATAACC-1 0.01779603
# s4d9_CGAGGTGAGCTATGAC-1 0.06835722
# s4d9_ACGCCTTTCCTAGTCC-1 0.07455429
# s4d9_TTTAAGCCACGTTACA-1 0.02969502
# s4d9_ACGAACAAGCGGGCAA-1 0.05998589
# s4d9_GTTACAGGTAACCTAG-1 0.05623243
# s4d9_CCGGTAGGTAATAGCT-1 0.03872437
# s4d9_CGCACACAGGATCCGC-1 0.10000000
# s4d9_CTACCTCAGCACAGGG-1 0.10340973
# s4d9_TATGGGCGTCATCCTG-1 0.02572347
# s4d9_ACTAACTCAGGTTCAC-1 0.05842185
# s4d9_CTCCTAATCGCTAAGT-1 0.06010017
# s4d9_GTGGTTAGTAACTACG-1 0.04133180
# s4d9_AAGCCTTAGTAAACCC-1 0.06917543
# s4d9_CTCATGACAGCCGCTA-1 0.10600707
# s4d9_TAGAGCCGTGAGGTAG-1 0.08817829
# s4d9_AGGACGTAGTGCACGC-1 0.10245184
# s4d9_TGCTTGCTCATTGTCT-1 0.06800211
# s4d9_TATGAAGCATTGTGGC-1 0.02027972

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
        if (1) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            bs = boot::boot(df2, assoc, R = 100, formula = formula, 
                stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            if (p0 < 0.1 & bs$t0[1] > 0) {
                bs = boot::boot(df2, assoc, R = 500, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")
  
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  saveRDS(pairs.E2G.chr.res,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.res)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G.filter2)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = do.call(c,list.res)

# %%
Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res

# %%
df.output = as.data.frame(pairs.E2G.res)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output

# %%
sessionInfo()
