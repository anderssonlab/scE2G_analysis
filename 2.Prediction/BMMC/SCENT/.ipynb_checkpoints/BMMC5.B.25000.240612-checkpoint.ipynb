# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.B.500.240604/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/B/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/B.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.B.2500.240606/"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_TAGTTGTCACCCTCAC-1 s1d1_TAGTTGTCACCCTCAC-1  1701  31   K562     7.438972
# s1d1_TGGATTGGTTTGCGAA-1 s1d1_TGGATTGGTTTGCGAA-1 16740 295   K562     9.725556
# s1d1_GTAAGGTCAATAACCT-1 s1d1_GTAAGGTCAATAACCT-1  2041  52   K562     7.621195
# s1d1_GGATTATGTTACATCC-1 s1d1_GGATTATGTTACATCC-1  5014  78   K562     8.519989
# s1d1_AACGACAAGTTGTCAA-1 s1d1_AACGACAAGTTGTCAA-1  1477  21   K562     7.297768
# s1d1_AGCAATACAATATGGA-1 s1d1_AGCAATACAATATGGA-1  2295  42   K562     7.738488
# s1d1_GGGAGTAGTGATTTGG-1 s1d1_GGGAGTAGTGATTTGG-1  2708 106   K562     7.903966
# s1d1_CCATAATCATGTCAGC-1 s1d1_CCATAATCATGTCAGC-1  2064  26   K562     7.632401
# s1d1_ATCAGGTTCATGACCG-1 s1d1_ATCAGGTTCATGACCG-1  1802  27   K562     7.496652
# s1d1_CAGGTCCAGGCTAATC-1 s1d1_CAGGTCCAGGCTAATC-1  1592  33   K562     7.372746
# s1d1_TCAGTGAGTGCTCCGT-1 s1d1_TCAGTGAGTGCTCCGT-1  1898  22   K562     7.548556
# s1d1_CAAACAACAATAACGA-1 s1d1_CAAACAACAATAACGA-1  1336  24   K562     7.197435
# s1d1_ACGCAAGCAATAAGCA-1 s1d1_ACGCAAGCAATAAGCA-1  3027  63   K562     8.015327
# s1d1_CATAATCCAGCAGGTA-1 s1d1_CATAATCCAGCAGGTA-1  2195  56   K562     7.693937
# s1d1_AAGTCTATCGAGGAGT-1 s1d1_AAGTCTATCGAGGAGT-1  1964  62   K562     7.582738
# s1d1_CCTGTTGGTAACAGGG-1 s1d1_CCTGTTGGTAACAGGG-1  2032  52   K562     7.616776
# s1d1_CTAGGCGGTGGGAACA-1 s1d1_CTAGGCGGTGGGAACA-1  1969  43   K562     7.585281
# s1d1_GGAACCACAGGAACTG-1 s1d1_GGAACCACAGGAACTG-1  1759  46   K562     7.472501
# s1d1_GCCTGAGGTTAAGGCC-1 s1d1_GCCTGAGGTTAAGGCC-1  1702  43   K562     7.439559
# s1d1_TAGCCTGAGGTTTGCG-1 s1d1_TAGCCTGAGGTTTGCG-1  1634  26   K562     7.398786
# s1d1_CCCTGTTAGGATCACT-1 s1d1_CCCTGTTAGGATCACT-1  8507 117   K562     9.048645
# s1d1_CCATAATCAAACTAAG-1 s1d1_CCATAATCAAACTAAG-1  1762  41   K562     7.474205
# s1d1_TCTGTGACAAATTCGT-1 s1d1_TCTGTGACAAATTCGT-1  1980  38   K562     7.590852
# s1d1_AGGGTTGCACATAACT-1 s1d1_AGGGTTGCACATAACT-1  1739  25   K562     7.461066
# s1d1_CGTCAATAGTATTGCA-1 s1d1_CGTCAATAGTATTGCA-1  1794  33   K562     7.492203
# s1d1_GTCAGGCTCGTGCTTC-1 s1d1_GTCAGGCTCGTGCTTC-1  3914  36   K562     8.272315
# s1d1_ACATCAATCGTTTCTG-1 s1d1_ACATCAATCGTTTCTG-1  2695  62   K562     7.899153
# s1d1_CTATTACTCCTAAGTA-1 s1d1_CTATTACTCCTAAGTA-1  3200  67   K562     8.070906
# s1d1_CCCAATTGTATTGGAT-1 s1d1_CCCAATTGTATTGGAT-1  3783  77   K562     8.238273
# s1d1_CGCAATAGTCACACCC-1 s1d1_CGCAATAGTCACACCC-1  6974 221   K562     8.849944
# ⋮                       ⋮                       ⋮     ⋮     ⋮        ⋮
# s4d9_GCTAGCTCATCGCTCC-1 s4d9_GCTAGCTCATCGCTCC-1  891   78   K562     6.792344
# s4d9_GCTTGACCAATTAACC-1 s4d9_GCTTGACCAATTAACC-1 4931  395   K562     8.503297
# s4d9_TTAAGGACAGTTAGCC-1 s4d9_TTAAGGACAGTTAGCC-1 1833  129   K562     7.513709
# s4d9_TAGCCTCTCATGTTTC-1 s4d9_TAGCCTCTCATGTTTC-1 1958  170   K562     7.579679
# s4d9_ACTTTGTTCTCCATGC-1 s4d9_ACTTTGTTCTCCATGC-1  905   24   K562     6.807935
# s4d9_TCTCAATTCATCCTGC-1 s4d9_TCTCAATTCATCCTGC-1 1368  136   K562     7.221105
# s4d9_CTATAACCATAGCGAG-1 s4d9_CTATAACCATAGCGAG-1  580   43   K562     6.363028
# s4d9_TTTACGAAGGACGTAA-1 s4d9_TTTACGAAGGACGTAA-1  591   41   K562     6.381816
# s4d9_TCTCGCCCAAACATAG-1 s4d9_TCTCGCCCAAACATAG-1  795   58   K562     6.678342
# s4d9_GGTTCTTGTGAACAAA-1 s4d9_GGTTCTTGTGAACAAA-1  935   76   K562     6.840547
# s4d9_GATGGACAGCGGCTGT-1 s4d9_GATGGACAGCGGCTGT-1  512   30   K562     6.238325
# s4d9_GAAGTCAAGTGAAGTG-1 s4d9_GAAGTCAAGTGAAGTG-1  988   57   K562     6.895683
# s4d9_GATTCATCACCTAATG-1 s4d9_GATTCATCACCTAATG-1  867   67   K562     6.765039
# s4d9_AGTAAACAGCCTGGTA-1 s4d9_AGTAAACAGCCTGGTA-1  863   50   K562     6.760415
# s4d9_TTGTTCCCAGGGAGCT-1 s4d9_TTGTTCCCAGGGAGCT-1  734   57   K562     6.598509
# s4d9_GCGAAGTAGCTGTACG-1 s4d9_GCGAAGTAGCTGTACG-1  562   25   K562     6.331502
# s4d9_CACAAGCGTTTCGCCA-1 s4d9_CACAAGCGTTTCGCCA-1 1615  147   K562     7.387090
# s4d9_AAACAGCCAAAGGCCA-1 s4d9_AAACAGCCAAAGGCCA-1 1610   90   K562     7.383989
# s4d9_TCGCTAACACACTAAT-1 s4d9_TCGCTAACACACTAAT-1 1003   61   K562     6.910751
# s4d9_GTCGAAGCACATAACT-1 s4d9_GTCGAAGCACATAACT-1  813   31   K562     6.700731
# s4d9_ATGTTCAAGTTATTCC-1 s4d9_ATGTTCAAGTTATTCC-1  869   22   K562     6.767343
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9_CTTCAAGCAAAGCGCA-1  793   49   K562     6.675823
# s4d9_GCTTTACGTATTCGCT-1 s4d9_GCTTTACGTATTCGCT-1  905   65   K562     6.807935
# s4d9_TCAAGCTAGCACCACA-1 s4d9_TCAAGCTAGCACCACA-1  822   23   K562     6.711740
# s4d9_GGTCAATTCGATTATG-1 s4d9_GGTCAATTCGATTATG-1 1553  111   K562     7.347944
# s4d9_GGTTTAATCTATGACA-1 s4d9_GGTTTAATCTATGACA-1 3206  243   K562     8.072779
# s4d9_ACTAATCCAGCAAGAT-1 s4d9_ACTAATCCAGCAAGAT-1 1003   53   K562     6.910751
# s4d9_AGCATCCCACAGAACG-1 s4d9_AGCATCCCACAGAACG-1  895   71   K562     6.796824
# s4d9_CTATTCAGTTGTGATG-1 s4d9_CTATTCAGTTGTGATG-1 1018   50   K562     6.925595
# s4d9_CACTTAAAGTCTGGGC-1 s4d9_CACTTAAAGTCTGGGC-1  889   42   K562     6.790097
#                         percent.mito
# s1d1_TAGTTGTCACCCTCAC-1 0.018224574
# s1d1_TGGATTGGTTTGCGAA-1 0.017622461
# s1d1_GTAAGGTCAATAACCT-1 0.025477707
# s1d1_GGATTATGTTACATCC-1 0.015556442
# s1d1_AACGACAAGTTGTCAA-1 0.014218009
# s1d1_AGCAATACAATATGGA-1 0.018300654
# s1d1_GGGAGTAGTGATTTGG-1 0.039143279
# s1d1_CCATAATCATGTCAGC-1 0.012596899
# s1d1_ATCAGGTTCATGACCG-1 0.014983352
# s1d1_CAGGTCCAGGCTAATC-1 0.020728643
# s1d1_TCAGTGAGTGCTCCGT-1 0.011591149
# s1d1_CAAACAACAATAACGA-1 0.017964072
# s1d1_ACGCAAGCAATAAGCA-1 0.020812686
# s1d1_CATAATCCAGCAGGTA-1 0.025512528
# s1d1_AAGTCTATCGAGGAGT-1 0.031568228
# s1d1_CCTGTTGGTAACAGGG-1 0.025590551
# s1d1_CTAGGCGGTGGGAACA-1 0.021838497
# s1d1_GGAACCACAGGAACTG-1 0.026151222
# s1d1_GCCTGAGGTTAAGGCC-1 0.025264395
# s1d1_TAGCCTGAGGTTTGCG-1 0.015911873
# s1d1_CCCTGTTAGGATCACT-1 0.013753380
# s1d1_CCATAATCAAACTAAG-1 0.023269012
# s1d1_TCTGTGACAAATTCGT-1 0.019191919
# s1d1_AGGGTTGCACATAACT-1 0.014376078
# s1d1_CGTCAATAGTATTGCA-1 0.018394649
# s1d1_GTCAGGCTCGTGCTTC-1 0.009197752
# s1d1_ACATCAATCGTTTCTG-1 0.023005566
# s1d1_CTATTACTCCTAAGTA-1 0.020937500
# s1d1_CCCAATTGTATTGGAT-1 0.020354216
# s1d1_CGCAATAGTCACACCC-1 0.031689131
# ⋮                       ⋮
# s4d9_GCTAGCTCATCGCTCC-1 0.08754209
# s4d9_GCTTGACCAATTAACC-1 0.08010546
# s4d9_TTAAGGACAGTTAGCC-1 0.07037643
# s4d9_TAGCCTCTCATGTTTC-1 0.08682329
# s4d9_ACTTTGTTCTCCATGC-1 0.02651934
# s4d9_TCTCAATTCATCCTGC-1 0.09941520
# s4d9_CTATAACCATAGCGAG-1 0.07413793
# s4d9_TTTACGAAGGACGTAA-1 0.06937394
# s4d9_TCTCGCCCAAACATAG-1 0.07295597
# s4d9_GGTTCTTGTGAACAAA-1 0.08128342
# s4d9_GATGGACAGCGGCTGT-1 0.05859375
# s4d9_GAAGTCAAGTGAAGTG-1 0.05769231
# s4d9_GATTCATCACCTAATG-1 0.07727797
# s4d9_AGTAAACAGCCTGGTA-1 0.05793743
# s4d9_TTGTTCCCAGGGAGCT-1 0.07765668
# s4d9_GCGAAGTAGCTGTACG-1 0.04448399
# s4d9_CACAAGCGTTTCGCCA-1 0.09102167
# s4d9_AAACAGCCAAAGGCCA-1 0.05590062
# s4d9_TCGCTAACACACTAAT-1 0.06081755
# s4d9_GTCGAAGCACATAACT-1 0.03813038
# s4d9_ATGTTCAAGTTATTCC-1 0.02531646
# s4d9_CTTCAAGCAAAGCGCA-1 0.06179067
# s4d9_GCTTTACGTATTCGCT-1 0.07182320
# s4d9_TCAAGCTAGCACCACA-1 0.02798054
# s4d9_GGTCAATTCGATTATG-1 0.07147457
# s4d9_GGTTTAATCTATGACA-1 0.07579538
# s4d9_ACTAATCCAGCAAGAT-1 0.05284148
# s4d9_AGCATCCCACAGAACG-1 0.07932961
# s4d9_CTATTCAGTTGTGATG-1 0.04911591
# s4d9_CACTTAAAGTCTGGGC-1 0.04724409

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
                bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.05]
  pairs.E2G.chr.keep = pairs.E2G.chr[!pairs.E2G.chr %in% pairs.E2G.chr.res]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# [1] "chr13"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 64079 ranges and 11 metadata columns:
#                  seqnames              ranges strand |  TargetGene
#                     <Rle>           <IRanges>  <Rle> | <character>
#   chr1.chr1.chr1     chr1 100184418-100185306      * |         AGL
#   chr1.chr1.chr1     chr1 100949328-100950217      * |      CDC14A
#   chr1.chr1.chr1     chr1 101127580-101129049      * |      TRMT13
#   chr1.chr1.chr1     chr1 101235454-101237644      * |      CDC14A
#   chr1.chr1.chr1     chr1   10428101-10428351      * |       KIF1B
#              ...      ...                 ...    ... .         ...
#   chrX.chrX.chrX     chrX     9340823-9342272      * |        WWC3
#   chrX.chrX.chrX     chrX     9464454-9466552      * |       CLCN4
#   chrX.chrX.chrX     chrX     9464454-9466552      * |       TBL1X
#   chrX.chrX.chrX     chrX     9464454-9466552      * |        WWC3
#   chrX.chrX.chrX     chrX   96683820-96685600      * |      DIAPH2
#                                PeakName               PairName        beta
#                             <character>            <character>   <numeric>
#   chr1.chr1.chr1 chr1-100184418-10018.. chr1-100184418-10018..    0.256371
#   chr1.chr1.chr1 chr1-100949328-10095.. chr1-100949328-10095..    0.158381
#   chr1.chr1.chr1 chr1-101127580-10112.. chr1-101127580-10112..   -0.345318
#   chr1.chr1.chr1 chr1-101235454-10123.. chr1-101235454-10123..    0.127452
#   chr1.chr1.chr1 chr1-10428101-10428351 chr1-10428101-104283..    0.277835
#              ...                    ...                    ...         ...
#   chrX.chrX.chrX   chrX-9340823-9342272 chrX-9340823-9342272.. -0.05856063
#   chrX.chrX.chrX   chrX-9464454-9466552 chrX-9464454-9466552.. -0.10276203
#   chrX.chrX.chrX   chrX-9464454-9466552 chrX-9464454-9466552..  0.09741123
#   chrX.chrX.chrX   chrX-9464454-9466552 chrX-9464454-9466552.. -0.04274077
#   chrX.chrX.chrX chrX-96683820-96685600 chrX-96683820-966856..  0.00207447
#                         se          z          p boot_basic_p
#                  <numeric>  <numeric>  <numeric>    <numeric>
#   chr1.chr1.chr1 0.1275434    2.01007 0.04442427       0.0616
#   chr1.chr1.chr1 0.0650920    2.43318 0.01496686       0.0408
#   chr1.chr1.chr1 0.1299416   -2.65749 0.00787247       0.0400
#   chr1.chr1.chr1 0.0443397    2.87445 0.00404731       0.0216
#   chr1.chr1.chr1 0.1109319    2.50456 0.01226053       0.0288
#              ...       ...        ...        ...          ...
#   chrX.chrX.chrX 0.0778344 -0.7523749  0.4518256         0.38
#   chrX.chrX.chrX 0.1048929 -0.9796850  0.3272416         0.50
#   chrX.chrX.chrX 0.0463408  2.1020636  0.0355477         0.12
#   chrX.chrX.chrX 0.0858581 -0.4978071  0.6186200         0.68
#   chrX.chrX.chrX 0.0312259  0.0664343  0.9470320         0.98
#                  boot_basic_p.log10      sign boot_basic_p.log10.signed
#                           <numeric> <numeric>                 <numeric>
#   chr1.chr1.chr1            1.21042         1                   1.21042
#   chr1.chr1.chr1            1.38934         1                   1.38934
#   chr1.chr1.chr1            1.39794        -1                  -1.39794
#   chr1.chr1.chr1            1.66555         1                   1.66555
#   chr1.chr1.chr1            1.54061         1                   1.54061
#              ...                ...       ...                       ...
#   chrX.chrX.chrX         0.42021640        -1               -0.42021640
#   chrX.chrX.chrX         0.30103000        -1               -0.30103000
#   chrX.chrX.chrX         0.92081875         1                0.92081875
#   chrX.chrX.chrX         0.16749109        -1               -0.16749109
#   chrX.chrX.chrX         0.00877392         1                0.00877392
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#       chr  start     end       TargetGene CellType beta         se
# 1     chr1 100184418 100185306 AGL        K562      0.25637057  0.12754340
# 2     chr1 100949328 100950217 CDC14A     K562      0.15838060  0.06509202
# 3     chr1 101127580 101129049 TRMT13     K562     -0.34531849  0.12994156
# 4     chr1 101235454 101237644 CDC14A     K562      0.12745242  0.04433975
# 5     chr1  10428101  10428351 KIF1B      K562      0.27783519  0.11093193
# 6     chr1  10494537  10495746 PEX14      K562      0.13250559  0.06666716
# 7     chr1   1058559   1060138 GNB1       K562      0.09744853  0.03700676
# 8     chr1   1063702   1064446 SLC35E2B   K562     -0.37271462  0.11850638
# 9     chr1   1068464   1070398 SSU72      K562     -0.17439776  0.08350311
# 10    chr1 107738803 107739921 PRPF38B    K562      0.18222110  0.08132160
# 11    chr1 107829027 107830315 SLC25A24   K562     -0.35349172  0.15188790
# 12    chr1 107829027 107830315 VAV3       K562      0.16214021  0.03284761
# 13    chr1 107896910 107897968 GPSM2      K562      0.35271596  0.10330268
# 14    chr1 107963563 107966011 GPSM2      K562      0.21169566  0.08672361
# 15    chr1 107963563 107966011 VAV3       K562      0.09723924  0.01965823
# 16    chr1 108043611 108044696 SLC25A24   K562      0.24755192  0.11030899
# 17    chr1 108043611 108044696 VAV3       K562      0.10987916  0.03121951
# 18    chr1 108074962 108075621 FAM102B    K562      0.25718619  0.08430672
# 19    chr1 108074962 108075621 VAV3       K562      0.15576896  0.02647599
# 20    chr1 108557323 108557763 VAV3       K562     -0.13870422  0.03961228
# 21    chr1 108561777 108562032 WDR47      K562      0.29604146  0.12550458
# 22    chr1 108660817 108661730 WDR47      K562      0.19567193  0.08726147
# 23    chr1  10866219  10867639 KIF1B      K562      0.47181440  0.10775259
# 24    chr1 108862542 108863532 GPSM2      K562      0.30866322  0.11682856
# 25    chr1 108862542 108863532 VAV3       K562      0.14863545  0.02777427
# 26    chr1 108876584 108877719 STXBP3     K562      0.13756227  0.06343833
# 27    chr1 109041339 109042580 STXBP3     K562      0.24309832  0.06096155
# 28    chr1 109090203 109091284 FAM102B    K562      0.15634727  0.06741901
# 29    chr1 109112118 109114353 WDR47      K562      0.21212999  0.09321056
# 30    chr1 109263281 109264508 FAM102B    K562      0.38698435  0.09887616
# ⋮     ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 64050 chrX 78957265  78958430  P2RY10     K562      0.136402818 0.10291453
# 64051 chrX 78957265  78958430  PGK1       K562      0.164206554 0.10865259
# 64052 chrX 79107733  79108624  CYSLTR1    K562      0.023499132 0.13034338
# 64053 chrX 79107733  79108624  GPR174     K562     -0.034415713 0.13017028
# 64054 chrX 79107733  79108624  P2RY10     K562     -0.157646600 0.11085834
# 64055 chrX 79138701  79139378  CYSLTR1    K562      0.076782194 0.11329213
# 64056 chrX 79138701  79139378  GPR174     K562     -0.048405495 0.11681370
# 64057 chrX 79138701  79139378  P2RY10     K562      0.163075420 0.08526536
# 64058 chrX 79144104  79144809  CYSLTR1    K562      0.100547828 0.13306577
# 64059 chrX 79144104  79144809  GPR174     K562      0.163246138 0.12638819
# 64060 chrX 79144104  79144809  P2RY10     K562     -0.190348789 0.11876365
# 64061 chrX 79258741  79259779  CYSLTR1    K562     -0.001668005 0.11654387
# 64062 chrX 79258741  79259779  GPR174     K562      0.170199583 0.10654274
# 64063 chrX 79258741  79259779  P2RY10     K562     -0.027516199 0.09223220
# 64064 chrX  7926925   7927960  PUDP       K562     -0.067030810 0.07113528
# 64065 chrX  7926925   7927960  STS        K562     -0.065056024 0.08627081
# 64066 chrX 80807881  80808694  BRWD3      K562      0.104282581 0.06660950
# 64067 chrX 80807881  80808694  SH3BGRL    K562      0.038503276 0.05467894
# 64068 chrX 81120662  81122326  BRWD3      K562     -0.032880206 0.07268962
# 64069 chrX 81120662  81122326  SH3BGRL    K562     -0.028834310 0.05814057
# 64070 chrX 81201570  81202895  BRWD3      K562      0.015376438 0.06521366
# 64071 chrX 81201570  81202895  SH3BGRL    K562      0.002540734 0.05250593
# 64072 chrX 86047038  86048245  CHM        K562      0.077912675 0.08839424
# 64073 chrX  9340823   9342272  CLCN4      K562      0.008828121 0.09080060
# 64074 chrX  9340823   9342272  TBL1X      K562      0.088874415 0.04250987
# 64075 chrX  9340823   9342272  WWC3       K562     -0.058560631 0.07783438
# 64076 chrX  9464454   9466552  CLCN4      K562     -0.102762031 0.10489293
# 64077 chrX  9464454   9466552  TBL1X      K562      0.097411228 0.04634076
# 64078 chrX  9464454   9466552  WWC3       K562     -0.042740770 0.08585809
# 64079 chrX 96683820  96685600  DIAPH2     K562      0.002074469 0.03122586
#       z           p            boot_basic_p boot_basic_p.log10 sign
# 1      2.010065   4.442427e-02 0.0616       1.210419            1
# 2      2.433180   1.496686e-02 0.0408       1.389340            1
# 3     -2.657491   7.872475e-03 0.0400       1.397940           -1
# 4      2.874451   4.047308e-03 0.0216       1.665546            1
# 5      2.504556   1.226053e-02 0.0288       1.540608            1
# 6      1.987569   4.685935e-02 0.0600       1.221849            1
# 7      2.633263   8.456880e-03 0.0240       1.619789            1
# 8     -3.145102   1.660291e-03 0.0024       2.619789           -1
# 9     -2.088518   3.675111e-02 0.0392       1.406714           -1
# 10     2.240747   2.504250e-02 0.0400       1.397940            1
# 11    -2.327320   1.994825e-02 0.0376       1.424812           -1
# 12     4.936134   7.968643e-07 0.0040       2.397940            1
# 13     3.414393   6.392427e-04 0.0032       2.494850            1
# 14     2.441038   1.464510e-02 0.0320       1.494850            1
# 15     4.946490   7.556368e-07 0.0016       2.795880            1
# 16     2.244168   2.482159e-02 0.0368       1.434152            1
# 17     3.519567   4.322519e-04 0.0104       1.982967            1
# 18     3.050601   2.283835e-03 0.0080       2.096910            1
# 19     5.883405   4.019107e-09 0.0008       3.096910            1
# 20    -3.501545   4.625680e-04 0.0128       1.892790           -1
# 21     2.358810   1.833365e-02 0.0152       1.818156            1
# 22     2.242363   2.493789e-02 0.0584       1.233587            1
# 23     4.378683   1.193988e-05 0.0008       3.096910            1
# 24     2.642019   8.241354e-03 0.0144       1.841638            1
# 25     5.351553   8.720260e-08 0.0008       3.096910            1
# 26     2.168441   3.012516e-02 0.0296       1.528708            1
# 27     3.987732   6.670795e-05 0.0008       3.096910            1
# 28     2.319038   2.039296e-02 0.0440       1.356547            1
# 29     2.275815   2.285709e-02 0.0528       1.277366            1
# 30     3.913829   9.084406e-05 0.0008       3.096910            1
# ⋮     ⋮           ⋮            ⋮            ⋮                  ⋮
# 64050  1.32539900 0.18503885   0.24         0.619788758         1
# 64051  1.51129903 0.13071228   0.10         1.000000000         1
# 64052  0.18028636 0.85692777   0.66         0.180456064         1
# 64053 -0.26438994 0.79147946   0.84         0.075720714        -1
# 64054 -1.42205446 0.15501044   0.32         0.494850022        -1
# 64055  0.67773632 0.49793890   0.38         0.420216403         1
# 64056 -0.41438202 0.67859435   0.82         0.086186148        -1
# 64057  1.91256346 0.05580396   0.10         1.000000000         1
# 64058  0.75562504 0.44987404   0.54         0.267606240         1
# 64059  1.29162496 0.19648706   0.24         0.619788758         1
# 64060 -1.60275298 0.10898920   0.14         0.853871964        -1
# 64061 -0.01431225 0.98858087   0.92         0.036212173        -1
# 64062  1.59747705 0.11015941   0.12         0.920818754         1
# 64063 -0.29833613 0.76544663   0.84         0.075720714        -1
# 64064 -0.94230049 0.34603882   0.42         0.376750710        -1
# 64065 -0.75409078 0.45079471   0.46         0.337242168        -1
# 64066  1.56558127 0.11744668   0.12         0.920818754         1
# 64067  0.70417016 0.48132681   0.56         0.251811973         1
# 64068 -0.45233703 0.65102620   0.76         0.119186408        -1
# 64069 -0.49594132 0.61993582   0.58         0.236572006        -1
# 64070  0.23578555 0.81359908   0.84         0.075720714         1
# 64071  0.04838946 0.96140586   0.94         0.026872146         1
# 64072  0.88142249 0.37808919   0.62         0.207608311         1
# 64073  0.09722537 0.92254743   0.84         0.075720714         1
# 64074  2.09067699 0.03655703   0.18         0.744727495         1
# 64075 -0.75237490 0.45182563   0.38         0.420216403        -1
# 64076 -0.97968501 0.32724163   0.50         0.301029996        -1
# 64077  2.10206358 0.03554771   0.12         0.920818754         1
# 64078 -0.49780711 0.61862001   0.68         0.167491087        -1
# 64079  0.06643432 0.94703205   0.98         0.008773924         1
#       boot_basic_p.log10.signed
# 1      1.210419
# 2      1.389340
# 3     -1.397940
# 4      1.665546
# 5      1.540608
# 6      1.221849
# 7      1.619789
# 8     -2.619789
# 9     -1.406714
# 10     1.397940
# 11    -1.424812
# 12     2.397940
# 13     2.494850
# 14     1.494850
# 15     2.795880
# 16     1.434152
# 17     1.982967
# 18     2.096910
# 19     3.096910
# 20    -1.892790
# 21     1.818156
# 22     1.233587
# 23     3.096910
# 24     1.841638
# 25     3.096910
# 26     1.528708
# 27     3.096910
# 28     1.356547
# 29     1.277366
# 30     3.096910
# ⋮     ⋮
# 64050  0.619788758
# 64051  1.000000000
# 64052  0.180456064
# 64053 -0.075720714
# 64054 -0.494850022
# 64055  0.420216403
# 64056 -0.086186148
# 64057  1.000000000
# 64058  0.267606240
# 64059  0.619788758
# 64060 -0.853871964
# 64061 -0.036212173
# 64062  0.920818754
# 64063 -0.075720714
# 64064 -0.376750710
# 64065 -0.337242168
# 64066  0.920818754
# 64067  0.251811973
# 64068 -0.119186408
# 64069 -0.236572006
# 64070  0.075720714
# 64071  0.026872146
# 64072  0.207608311
# 64073  0.075720714
# 64074  0.744727495
# 64075 -0.420216403
# 64076 -0.301029996
# 64077  0.920818754
# 64078 -0.167491087
# 64079  0.008773924

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
# [1] Matrix_1.6-5         GenomicRanges_1.54.1 GenomeInfoDb_1.38.1
# [4] IRanges_2.36.0       S4Vectors_0.40.2     BiocGenerics_0.48.1
# [7] genomation_1.34.0    Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] htmlTable_2.4.2             backports_1.4.1
#  [43] BiocParallel_1.36.0         R.utils_2.12.3
#  [45] MASS_7.3-60                 DelayedArray_0.26.7
#  [47] rjson_0.2.21                tools_4.3.3
#  [49] foreign_0.8-86              future.apply_1.11.2
#  [51] nnet_7.3-19                 R.oo_1.26.0
#  [53] glue_1.7.0                  restfulr_0.0.15
#  [55] nlme_3.1-164                pbdZMQ_0.3-11
#  [57] checkmate_2.3.1             gridBase_0.4-7
#  [59] cluster_2.1.6               reshape2_1.4.4
#  [61] generics_0.1.3              gtable_0.3.5
#  [63] BSgenome_1.68.0             tzdb_0.4.0
#  [65] R.methodsS3_1.8.2           tidyr_1.3.1
#  [67] seqPattern_1.34.0           data.table_1.15.2
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               dplyr_1.1.4
#  [79] lattice_0.22-6              rtracklayer_1.60.1
#  [81] tidyselect_1.2.1            Biostrings_2.70.1
#  [83] pbapply_1.7-2               knitr_1.46
#  [85] gridExtra_2.3               SummarizedExperiment_1.30.2
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
