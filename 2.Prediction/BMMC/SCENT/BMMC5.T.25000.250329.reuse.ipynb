# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
library(data.table)
library(dplyr)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     shift
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.T.2500.250324/pairs.E2G.res.rds"
path.pairs.E2G.reuse = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.T.25000.240612/pairs.E2G.res.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_BMMC5/T/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/3.merge_cell_type.240522/RNA_count_matrix/T.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/SCENT/BMMC5.T.25000.250329/"
celltype = "T"

# %%
n.cores = 32

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %%
pairs.E2G.reuse = readRDS(path.pairs.E2G.reuse)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
matrix.rna.rename = map_gene_names(matrix.rna,gene_gtf_path, abc_genes_path)

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = celltype)
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                         cell                    nUMI  nMito celltype log.nUMI
# s1d1_CCGCACACAGGTTAAA-1 s1d1_CCGCACACAGGTTAAA-1  8311 115   T        9.025335
# s1d1_TCATTTGGTAATGGAA-1 s1d1_TCATTTGGTAATGGAA-1  1291  20   T        7.163172
# s1d1_GACTTAGGTTGCGCGA-1 s1d1_GACTTAGGTTGCGCGA-1  1182  17   T        7.074963
# s1d1_GCCTTACTCGTTACAA-1 s1d1_GCCTTACTCGTTACAA-1 10154  98   T        9.225623
# s1d1_TGTCCTGGTCAATGTG-1 s1d1_TGTCCTGGTCAATGTG-1  1844  21   T        7.519692
# s1d1_AGAATCGAGAAAGGAA-1 s1d1_AGAATCGAGAAAGGAA-1  4293  78   T        8.364741
# s1d1_ATGTGAGAGGCGAAAC-1 s1d1_ATGTGAGAGGCGAAAC-1  1126  19   T        7.026427
# s1d1_CGCTTCTAGTGACCTG-1 s1d1_CGCTTCTAGTGACCTG-1  1697  18   T        7.436617
# s1d1_GAGCTGCTCTTGTCCA-1 s1d1_GAGCTGCTCTTGTCCA-1  2229  37   T        7.709308
# s1d1_TAGTCAATCGTGCTTC-1 s1d1_TAGTCAATCGTGCTTC-1  1613  39   T        7.385851
# s1d1_GTTACTAAGGTGAAGC-1 s1d1_GTTACTAAGGTGAAGC-1  1472  30   T        7.294377
# s1d1_AGGAACGGTTTGTCTA-1 s1d1_AGGAACGGTTTGTCTA-1  2665  24   T        7.887959
# s1d1_CTAGTAATCGTGCTAG-1 s1d1_CTAGTAATCGTGCTAG-1  2157  36   T        7.676474
# s1d1_GCCTTAGAGCTAAGTC-1 s1d1_GCCTTAGAGCTAAGTC-1  1626  39   T        7.393878
# s1d1_TAGCGCGGTTGCAATG-1 s1d1_TAGCGCGGTTGCAATG-1  1799  26   T        7.494986
# s1d1_AGCAAATAGAATGACG-1 s1d1_AGCAAATAGAATGACG-1  3431  45   T        8.140607
# s1d1_AAGCCTCCAGGAATCG-1 s1d1_AAGCCTCCAGGAATCG-1  2557  27   T        7.846590
# s1d1_GTCAATATCTGGCAAT-1 s1d1_GTCAATATCTGGCAAT-1  1444  21   T        7.275172
# s1d1_CCGGTTAAGGTAACGA-1 s1d1_CCGGTTAAGGTAACGA-1  2398  37   T        7.782390
# s1d1_TGTTGCACAGTCTATG-1 s1d1_TGTTGCACAGTCTATG-1  1802  21   T        7.496652
# s1d1_GTATGTTCAGCATGAG-1 s1d1_GTATGTTCAGCATGAG-1  2288  31   T        7.735433
# s1d1_GTTTAGCAGCTTCCCG-1 s1d1_GTTTAGCAGCTTCCCG-1  2008  43   T        7.604894
# s1d1_CTTGTAAAGATAAAGC-1 s1d1_CTTGTAAAGATAAAGC-1  2168  38   T        7.681560
# s1d1_TAGTCAATCAGCACGC-1 s1d1_TAGTCAATCAGCACGC-1  5199  42   T        8.556222
# s1d1_GGTGAGCCAATATACC-1 s1d1_GGTGAGCCAATATACC-1  2804  69   T        7.938802
# s1d1_CCGCTAGCATCTTGAG-1 s1d1_CCGCTAGCATCTTGAG-1  2683  37   T        7.894691
# s1d1_ACGCTTGAGTCATCCC-1 s1d1_ACGCTTGAGTCATCCC-1  1624  39   T        7.392648
# s1d1_TCTTGTCCAATCGCAC-1 s1d1_TCTTGTCCAATCGCAC-1  2671  25   T        7.890208
# s1d1_TAGCGCGGTCAATACG-1 s1d1_TAGCGCGGTCAATACG-1  1732  46   T        7.457032
# s1d1_CAGCTATAGACAAACG-1 s1d1_CAGCTATAGACAAACG-1  2415  21   T        7.789455
# ⋮                       ⋮                       ⋮     ⋮     ⋮        ⋮
# s4d9_AACTGTTCAAATTCGT-1 s4d9_AACTGTTCAAATTCGT-1 1147   93   T        7.044905
# s4d9_CTATGTTTCAATGAGG-1 s4d9_CTATGTTTCAATGAGG-1  905   63   T        6.807935
# s4d9_AGGTCTTAGCGCCTAA-1 s4d9_AGGTCTTAGCGCCTAA-1  970   65   T        6.877296
# s4d9_TACTGGCCAGCAACAG-1 s4d9_TACTGGCCAGCAACAG-1 1235  126   T        7.118826
# s4d9_CTGCTACTCAGGTCCA-1 s4d9_CTGCTACTCAGGTCCA-1 1234   55   T        7.118016
# s4d9_CTGTGTGAGGGCTTAT-1 s4d9_CTGTGTGAGGGCTTAT-1  783   72   T        6.663133
# s4d9_GCTTACCTCTCTAGCC-1 s4d9_GCTTACCTCTCTAGCC-1 1002   51   T        6.909753
# s4d9_AGCATCCCAATCGCAC-1 s4d9_AGCATCCCAATCGCAC-1  722   26   T        6.582025
# s4d9_ATCCTGACAATAGTCT-1 s4d9_ATCCTGACAATAGTCT-1 1212   55   T        7.100027
# s4d9_TTGCTCTCAGTACCGT-1 s4d9_TTGCTCTCAGTACCGT-1 1238  141   T        7.121252
# s4d9_GGGTCAACAACTAACT-1 s4d9_GGGTCAACAACTAACT-1 2372  200   T        7.771489
# s4d9_GGTAATTGTACGGTAC-1 s4d9_GGTAATTGTACGGTAC-1 1005   83   T        6.912743
# s4d9_TTTGTGGCATAAAGCA-1 s4d9_TTTGTGGCATAAAGCA-1  941   78   T        6.846943
# s4d9_CATCCCAGTCTCACTG-1 s4d9_CATCCCAGTCTCACTG-1 1285   91   T        7.158514
# s4d9_CCTTAGTGTCAGGAAG-1 s4d9_CCTTAGTGTCAGGAAG-1  858   83   T        6.754604
# s4d9_CCAATATCAATTGAGA-1 s4d9_CCAATATCAATTGAGA-1 3861  266   T        8.258681
# s4d9_GACAATACATAATTGC-1 s4d9_GACAATACATAATTGC-1  684   29   T        6.527958
# s4d9_AGTCAATGTTCGCGCT-1 s4d9_AGTCAATGTTCGCGCT-1  926   85   T        6.830874
# s4d9_TCTAGCGAGCCACATG-1 s4d9_TCTAGCGAGCCACATG-1 1710  138   T        7.444249
# s4d9_ACGAAGTCACGAACAG-1 s4d9_ACGAAGTCACGAACAG-1  795   63   T        6.678342
# s4d9_GGTCCGTAGCACAGAA-1 s4d9_GGTCCGTAGCACAGAA-1 1239   78   T        7.122060
# s4d9_ATGACAACATGAATAG-1 s4d9_ATGACAACATGAATAG-1 1590  148   T        7.371489
# s4d9_TACCTCATCATGCGTG-1 s4d9_TACCTCATCATGCGTG-1  995  105   T        6.902743
# s4d9_TATGGCCCAGGCTACT-1 s4d9_TATGGCCCAGGCTACT-1 1122  161   T        7.022868
# s4d9_TGTGGAGCAGAAATGC-1 s4d9_TGTGGAGCAGAAATGC-1  569   24   T        6.343880
# s4d9_ATTGAAGCACATTGCA-1 s4d9_ATTGAAGCACATTGCA-1  607   49   T        6.408529
# s4d9_TGAACAACAGTGAACG-1 s4d9_TGAACAACAGTGAACG-1  705   60   T        6.558198
# s4d9_CGATTCCTCCTGGCTT-1 s4d9_CGATTCCTCCTGGCTT-1  884   37   T        6.784457
# s4d9_AAACCGCGTTTGAGGC-1 s4d9_AAACCGCGTTTGAGGC-1  777   80   T        6.655440
# s4d9_GCTGTACCACCGTTCC-1 s4d9_GCTGTACCACCGTTCC-1  740   98   T        6.606650
#                         percent.mito
# s1d1_CCGCACACAGGTTAAA-1 0.013837083
# s1d1_TCATTTGGTAATGGAA-1 0.015491867
# s1d1_GACTTAGGTTGCGCGA-1 0.014382403
# s1d1_GCCTTACTCGTTACAA-1 0.009651369
# s1d1_TGTCCTGGTCAATGTG-1 0.011388286
# s1d1_AGAATCGAGAAAGGAA-1 0.018169113
# s1d1_ATGTGAGAGGCGAAAC-1 0.016873890
# s1d1_CGCTTCTAGTGACCTG-1 0.010606953
# s1d1_GAGCTGCTCTTGTCCA-1 0.016599372
# s1d1_TAGTCAATCGTGCTTC-1 0.024178549
# s1d1_GTTACTAAGGTGAAGC-1 0.020380435
# s1d1_AGGAACGGTTTGTCTA-1 0.009005629
# s1d1_CTAGTAATCGTGCTAG-1 0.016689847
# s1d1_GCCTTAGAGCTAAGTC-1 0.023985240
# s1d1_TAGCGCGGTTGCAATG-1 0.014452474
# s1d1_AGCAAATAGAATGACG-1 0.013115710
# s1d1_AAGCCTCCAGGAATCG-1 0.010559249
# s1d1_GTCAATATCTGGCAAT-1 0.014542936
# s1d1_CCGGTTAAGGTAACGA-1 0.015429525
# s1d1_TGTTGCACAGTCTATG-1 0.011653718
# s1d1_GTATGTTCAGCATGAG-1 0.013548951
# s1d1_GTTTAGCAGCTTCCCG-1 0.021414343
# s1d1_CTTGTAAAGATAAAGC-1 0.017527675
# s1d1_TAGTCAATCAGCACGC-1 0.008078477
# s1d1_GGTGAGCCAATATACC-1 0.024607703
# s1d1_CCGCTAGCATCTTGAG-1 0.013790533
# s1d1_ACGCTTGAGTCATCCC-1 0.024014778
# s1d1_TCTTGTCCAATCGCAC-1 0.009359790
# s1d1_TAGCGCGGTCAATACG-1 0.026558891
# s1d1_CAGCTATAGACAAACG-1 0.008695652
# ⋮                       ⋮
# s4d9_AACTGTTCAAATTCGT-1 0.08108108
# s4d9_CTATGTTTCAATGAGG-1 0.06961326
# s4d9_AGGTCTTAGCGCCTAA-1 0.06701031
# s4d9_TACTGGCCAGCAACAG-1 0.10202429
# s4d9_CTGCTACTCAGGTCCA-1 0.04457050
# s4d9_CTGTGTGAGGGCTTAT-1 0.09195402
# s4d9_GCTTACCTCTCTAGCC-1 0.05089820
# s4d9_AGCATCCCAATCGCAC-1 0.03601108
# s4d9_ATCCTGACAATAGTCT-1 0.04537954
# s4d9_TTGCTCTCAGTACCGT-1 0.11389338
# s4d9_GGGTCAACAACTAACT-1 0.08431703
# s4d9_GGTAATTGTACGGTAC-1 0.08258706
# s4d9_TTTGTGGCATAAAGCA-1 0.08289054
# s4d9_CATCCCAGTCTCACTG-1 0.07081712
# s4d9_CCTTAGTGTCAGGAAG-1 0.09673660
# s4d9_CCAATATCAATTGAGA-1 0.06889407
# s4d9_GACAATACATAATTGC-1 0.04239766
# s4d9_AGTCAATGTTCGCGCT-1 0.09179266
# s4d9_TCTAGCGAGCCACATG-1 0.08070175
# s4d9_ACGAAGTCACGAACAG-1 0.07924528
# s4d9_GGTCCGTAGCACAGAA-1 0.06295400
# s4d9_ATGACAACATGAATAG-1 0.09308176
# s4d9_TACCTCATCATGCGTG-1 0.10552764
# s4d9_TATGGCCCAGGCTACT-1 0.14349376
# s4d9_TGTGGAGCAGAAATGC-1 0.04217926
# s4d9_ATTGAAGCACATTGCA-1 0.08072488
# s4d9_TGAACAACAGTGAACG-1 0.08510638
# s4d9_CGATTCCTCCTGGCTT-1 0.04185520
# s4d9_AAACCGCGTTTGAGGC-1 0.10296010
# s4d9_GCTGTACCACCGTTCC-1 0.13243243

# %% [markdown]
# RUN SCENT prediction

# %%
RhpcBLASctl::blas_set_num_threads(1)
Sys.setenv(OPENBLAS_NUM_THREADS=1)
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        # nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        # nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        # if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            # bs = boot::boot(df2, assoc, R = 100, formula = formula, 
            #     stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            # p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
                bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
                  stype = "i", 
                  # parallel = "multicore", ncpus = ncores)
                  parallel = "no", ncpus = 1)
                # p0 = basic_p(bs$t0[1], bs$t[, 1])
                p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        # }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G)))
chr.run = chr.run[!chr.run %in% chr.done]

# %% [markdown]
# Filter genes which can be reused

# %%
map_gene_names_reuse <- function(gene_gtf_path, abc_genes_path){
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()
    abc_genes.reuse = abc_genes[abc_genes$abc_name == abc_genes$gene_ref_name,]
	return(abc_genes.reuse)
}

# %%
abc_genes.reuse = map_gene_names_reuse(gene_gtf_path, abc_genes_path)

# %%
dim(abc_genes.reuse)
abc_genes.reuse
# Out:
# [1] 19669     3
#       abc_name  Ensembl_ID      gene_ref_name
# 1     FAM138A   ENSG00000237613 FAM138A
# 2     FAM138F   ENSG00000282591 FAM138F
# 3     OR4F5     ENSG00000186092 OR4F5
# 4     FAM87B    ENSG00000177757 FAM87B
# 5     LINC00115 ENSG00000225880 LINC00115
# 6     LINC01128 ENSG00000228794 LINC01128
# 7     FAM41C    ENSG00000230368 FAM41C
# 8     SAMD11    ENSG00000187634 SAMD11
# 9     NOC2L     ENSG00000188976 NOC2L
# 10    KLHL17    ENSG00000187961 KLHL17
# 11    PLEKHN1   ENSG00000187583 PLEKHN1
# 12    PERM1     ENSG00000187642 PERM1
# 13    HES4      ENSG00000188290 HES4
# 14    ISG15     ENSG00000187608 ISG15
# 15    AGRN      ENSG00000188157 AGRN
# 16    RNF223    ENSG00000237330 RNF223
# 17    C1orf159  ENSG00000131591 C1orf159
# 18    LINC01342 ENSG00000223823 LINC01342
# 19    TTLL10    ENSG00000162571 TTLL10
# 20    TNFRSF18  ENSG00000186891 TNFRSF18
# 21    TNFRSF4   ENSG00000186827 TNFRSF4
# 22    SDF4      ENSG00000078808 SDF4
# 23    B3GALT6   ENSG00000176022 B3GALT6
# 24    C1QTNF12  ENSG00000184163 C1QTNF12
# 25    UBE2J2    ENSG00000160087 UBE2J2
# 26    SCNN1D    ENSG00000162572 SCNN1D
# 27    ACAP3     ENSG00000131584 ACAP3
# 28    PUSL1     ENSG00000169972 PUSL1
# 29    INTS11    ENSG00000127054 INTS11
# 30    CPTP      ENSG00000224051 CPTP
# ⋮     ⋮         ⋮               ⋮
# 19640 NA        NA              NA
# 19641 TTTY12    ENSG00000237048 TTTY12
# 19642 NA        NA              NA
# 19643 TTTY18    ENSG00000233699 TTTY18
# 19644 TTTY19    ENSG00000232419 TTTY19
# 19645 TTTY11    ENSG00000180910 TTTY11
# 19646 TSPY10    ENSG00000236424 TSPY10
# 19647 TSPY4     ENSG00000233803 TSPY4
# 19648 TSPY8     ENSG00000229549 TSPY8
# 19649 FAM197Y5  ENSG00000225516 FAM197Y5
# 19650 TSPY3     ENSG00000228927 TSPY3
# 19651 TSPY1     ENSG00000258992 TSPY1
# 19652 TTTY22    ENSG00000224075 TTTY22
# 19653 NA        NA              NA
# 19654 USP9Y     ENSG00000114374 USP9Y
# 19655 DDX3Y     ENSG00000067048 DDX3Y
# 19656 UTY       ENSG00000183878 UTY
# 19657 TMSB4Y    ENSG00000154620 TMSB4Y
# 19658 NLGN4Y    ENSG00000165246 NLGN4Y
# 19659 TTTY14    ENSG00000176728 TTTY14
# 19660 CD24      ENSG00000272398 CD24
# 19661 KDM5D     ENSG00000012817 KDM5D
# 19662 TTTY10    ENSG00000229236 TTTY10
# 19663 EIF1AY    ENSG00000198692 EIF1AY
# 19664 RPS4Y2    ENSG00000280969 RPS4Y2
# 19665 PRORY     ENSG00000183146 PRORY
# 19666 TTTY13    ENSG00000184991 TTTY13
# 19667 TTTY5     ENSG00000215560 TTTY5
# 19668 DAZ1      ENSG00000188120 DAZ1
# 19669 DAZ2      ENSG00000205944 DAZ2

# %%
pairs.E2G.reuse.25000 = pairs.E2G.reuse[pairs.E2G.reuse$boot_basic_p < 0.01 & 
                                        pairs.E2G.reuse$TargetGene %in% abc_genes.reuse$gene_ref_name]

# %%
names(pairs.E2G.reuse.25000) = pairs.E2G.reuse.25000$PairName

# %%
pairs.E2G.reuse.25000
# Out:
# GRanges object with 12424 ranges and 11 metadata columns:
#                                    seqnames              ranges strand |
#                                       <Rle>           <IRanges>  <Rle> |
#    chr1-100028395-100029373_CDC14A     chr1 100028395-100029373      * |
#   chr1-100037580-100039288_SLC30A7     chr1 100037580-100039288      * |
#   chr1-100265625-100266816_SLC30A7     chr1 100265625-100266816      * |
#    chr1-100396517-100397404_CDC14A     chr1 100396517-100397404      * |
#    chr1-100400356-100400858_CDC14A     chr1 100400356-100400858      * |
#                                ...      ...                 ...    ... .
#      chrX-79143980-79144825_GPR174     chrX   79143980-79144825      * |
#      chrX-79143980-79144825_P2RY10     chrX   79143980-79144825      * |
#          chrX-7926938-7928018_PUDP     chrX     7926938-7928018      * |
#       chrX-79366484-79367788_ITM2A     chrX   79366484-79367788      * |
#           chrX-989839-990623_P2RY8     chrX       989839-990623      * |
#                                     TargetGene               PeakName
#                                    <character>            <character>
#    chr1-100028395-100029373_CDC14A      CDC14A chr1-100028395-10002..
#   chr1-100037580-100039288_SLC30A7     SLC30A7 chr1-100037580-10003..
#   chr1-100265625-100266816_SLC30A7     SLC30A7 chr1-100265625-10026..
#    chr1-100396517-100397404_CDC14A      CDC14A chr1-100396517-10039..
#    chr1-100400356-100400858_CDC14A      CDC14A chr1-100400356-10040..
#                                ...         ...                    ...
#      chrX-79143980-79144825_GPR174      GPR174 chrX-79143980-79144825
#      chrX-79143980-79144825_P2RY10      P2RY10 chrX-79143980-79144825
#          chrX-7926938-7928018_PUDP        PUDP   chrX-7926938-7928018
#       chrX-79366484-79367788_ITM2A       ITM2A chrX-79366484-79367788
#           chrX-989839-990623_P2RY8       P2RY8     chrX-989839-990623
#                                                  PairName       beta        se
#                                               <character>  <numeric> <numeric>
#    chr1-100028395-100029373_CDC14A chr1-100028395-10002.. -0.3224262 0.0256319
#   chr1-100037580-100039288_SLC30A7 chr1-100037580-10003.. -0.0983429 0.0291697
#   chr1-100265625-100266816_SLC30A7 chr1-100265625-10026.. -0.0978716 0.0319503
#    chr1-100396517-100397404_CDC14A chr1-100396517-10039.. -0.1061372 0.0213137
#    chr1-100400356-100400858_CDC14A chr1-100400356-10040..  0.1155541 0.0190766
#                                ...                    ...        ...       ...
#      chrX-79143980-79144825_GPR174 chrX-79143980-791448..   0.199071 0.0471255
#      chrX-79143980-79144825_P2RY10 chrX-79143980-791448..   0.253802 0.0627591
#          chrX-7926938-7928018_PUDP chrX-7926938-7928018..   0.196672 0.0514937
#       chrX-79366484-79367788_ITM2A chrX-79366484-793677..   0.132024 0.0460446
#           chrX-989839-990623_P2RY8 chrX-989839-990623_P..   0.125710 0.0282553
#                                            z           p boot_basic_p
#                                    <numeric>   <numeric>    <numeric>
#    chr1-100028395-100029373_CDC14A -12.57909 2.75171e-36      0.00008
#   chr1-100037580-100039288_SLC30A7  -3.37141 7.47839e-04      0.00376
#   chr1-100265625-100266816_SLC30A7  -3.06324 2.18954e-03      0.00944
#    chr1-100396517-100397404_CDC14A  -4.97976 6.36629e-07      0.00184
#    chr1-100400356-100400858_CDC14A   6.05736 1.38374e-09      0.00016
#                                ...       ...         ...          ...
#      chrX-79143980-79144825_GPR174   4.22428 2.39708e-05      0.00024
#      chrX-79143980-79144825_P2RY10   4.04407 5.25316e-05      0.00040
#          chrX-7926938-7928018_PUDP   3.81935 1.33805e-04      0.00232
#       chrX-79366484-79367788_ITM2A   2.86730 4.13994e-03      0.00896
#           chrX-989839-990623_P2RY8   4.44907 8.62429e-06      0.00064
#                                    boot_basic_p.log10      sign
#                                             <numeric> <numeric>
#    chr1-100028395-100029373_CDC14A            4.09691        -1
#   chr1-100037580-100039288_SLC30A7            2.42481        -1
#   chr1-100265625-100266816_SLC30A7            2.02503        -1
#    chr1-100396517-100397404_CDC14A            2.73518        -1
#    chr1-100400356-100400858_CDC14A            3.79588         1
#                                ...                ...       ...
#      chrX-79143980-79144825_GPR174            3.61979         1
#      chrX-79143980-79144825_P2RY10            3.39794         1
#          chrX-7926938-7928018_PUDP            2.63451         1
#       chrX-79366484-79367788_ITM2A            2.04769         1
#           chrX-989839-990623_P2RY8            3.19382         1
#                                    boot_basic_p.log10.signed
#                                                    <numeric>
#    chr1-100028395-100029373_CDC14A                  -4.09691
#   chr1-100037580-100039288_SLC30A7                  -2.42481
#   chr1-100265625-100266816_SLC30A7                  -2.02503
#    chr1-100396517-100397404_CDC14A                  -2.73518
#    chr1-100400356-100400858_CDC14A                   3.79588
#                                ...                       ...
#      chrX-79143980-79144825_GPR174                   3.61979
#      chrX-79143980-79144825_P2RY10                   3.39794
#          chrX-7926938-7928018_PUDP                   2.63451
#       chrX-79366484-79367788_ITM2A                   2.04769
#           chrX-989839-990623_P2RY8                   3.19382
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
table(pairs.E2G[pairs.E2G$boot_basic_p < 0.01]$PairName %in% pairs.E2G.reuse.25000$PairName)
# Out:
# FALSE  TRUE
#  1429 12104

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr = pairs.E2G[seqnames(pairs.E2G) == chr.tmp]
  pairs.E2G.chr.res.0 = pairs.E2G.chr[!is.na(pairs.E2G.chr$boot_basic_p) & pairs.E2G.chr$boot_basic_p < 0.01]
  pairs.E2G.chr.keep.0 = pairs.E2G.chr[!pairs.E2G.chr$PairName %in% pairs.E2G.chr.res.0$PairName]
  pairs.E2G.chr.res = pairs.E2G.chr.res.0[!pairs.E2G.chr.res.0$PairName %in% pairs.E2G.reuse.25000$PairName]
  pairs.E2G.chr.keep.1 = pairs.E2G.reuse.25000[pairs.E2G.reuse.25000$PairName %in% pairs.E2G.chr.res.0$PairName]

  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(min(n.cores,floor(length(pairs.E2G.chr.res)/2))))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna.rename[rownames(matrix.rna.rename) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(min(n.cores,floor(length(pairs.E2G.chr.res)/2)))
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  pairs.E2G.chr.merge = c(pairs.E2G.chr.res,
                          pairs.E2G.chr.keep.0,
                          pairs.E2G.chr.keep.1)
  saveRDS(pairs.E2G.chr.merge,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.merge)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# [1] "chr22"
# [1] "chr3"
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 178378 ranges and 11 metadata columns:
#                                      seqnames              ranges strand |
#                                         <Rle>           <IRanges>  <Rle> |
#                       chr1.chr1.chr1     chr1   10472047-10472925      * |
#                       chr1.chr1.chr1     chr1     1068602-1070146      * |
#                       chr1.chr1.chr1     chr1     1068602-1070146      * |
#                       chr1.chr1.chr1     chr1 108876586-108877518      * |
#                       chr1.chr1.chr1     chr1 109090240-109091248      * |
#                                  ...      ...                 ...    ... .
#   chrX.chrX-79143980-79144825_GPR174     chrX   79143980-79144825      * |
#   chrX.chrX-79143980-79144825_P2RY10     chrX   79143980-79144825      * |
#       chrX.chrX-7926938-7928018_PUDP     chrX     7926938-7928018      * |
#    chrX.chrX-79366484-79367788_ITM2A     chrX   79366484-79367788      * |
#        chrX.chrX-989839-990623_P2RY8     chrX       989839-990623      * |
#                                       TargetGene               PeakName
#                                      <character>            <character>
#                       chr1.chr1.chr1        MTOR chr1-10472047-10472925
#                       chr1.chr1.chr1       CCNL2   chr1-1068602-1070146
#                       chr1.chr1.chr1      UBE2J2   chr1-1068602-1070146
#                       chr1.chr1.chr1        SARS chr1-108876586-10887..
#                       chr1.chr1.chr1        SARS chr1-109090240-10909..
#                                  ...         ...                    ...
#   chrX.chrX-79143980-79144825_GPR174      GPR174 chrX-79143980-79144825
#   chrX.chrX-79143980-79144825_P2RY10      P2RY10 chrX-79143980-79144825
#       chrX.chrX-7926938-7928018_PUDP        PUDP   chrX-7926938-7928018
#    chrX.chrX-79366484-79367788_ITM2A       ITM2A chrX-79366484-79367788
#        chrX.chrX-989839-990623_P2RY8       P2RY8     chrX-989839-990623
#                                                    PairName       beta
#                                                 <character>  <numeric>
#                       chr1.chr1.chr1 chr1-10472047-104729..  0.1176348
#                       chr1.chr1.chr1 chr1-1068602-1070146..  0.0909999
#                       chr1.chr1.chr1 chr1-1068602-1070146..  0.1248543
#                       chr1.chr1.chr1 chr1-108876586-10887.. -0.1553135
#                       chr1.chr1.chr1 chr1-109090240-10909.. -0.1745243
#                                  ...                    ...        ...
#   chrX.chrX-79143980-79144825_GPR174 chrX-79143980-791448..   0.199071
#   chrX.chrX-79143980-79144825_P2RY10 chrX-79143980-791448..   0.253802
#       chrX.chrX-7926938-7928018_PUDP chrX-7926938-7928018..   0.196672
#    chrX.chrX-79366484-79367788_ITM2A chrX-79366484-793677..   0.132024
#        chrX.chrX-989839-990623_P2RY8 chrX-989839-990623_P..   0.125710
#                                             se         z           p
#                                      <numeric> <numeric>   <numeric>
#                       chr1.chr1.chr1 0.0431170   2.72827  0.00636674
#                       chr1.chr1.chr1 0.0354513   2.56690  0.01026122
#                       chr1.chr1.chr1 0.0524908   2.37860  0.01737874
#                       chr1.chr1.chr1 0.0500014  -3.10618  0.00189519
#                       chr1.chr1.chr1 0.0503497  -3.46625  0.00052778
#                                  ...       ...       ...         ...
#   chrX.chrX-79143980-79144825_GPR174 0.0471255   4.22428 2.39708e-05
#   chrX.chrX-79143980-79144825_P2RY10 0.0627591   4.04407 5.25316e-05
#       chrX.chrX-7926938-7928018_PUDP 0.0514937   3.81935 1.33805e-04
#    chrX.chrX-79366484-79367788_ITM2A 0.0460446   2.86730 4.13994e-03
#        chrX.chrX-989839-990623_P2RY8 0.0282553   4.44907 8.62429e-06
#                                      boot_basic_p boot_basic_p.log10      sign
#                                         <numeric>          <numeric> <numeric>
#                       chr1.chr1.chr1      0.01248            1.90379         1
#                       chr1.chr1.chr1      0.01096            1.96019         1
#                       chr1.chr1.chr1      0.01744            1.75845         1
#                       chr1.chr1.chr1      0.00432            2.36452        -1
#                       chr1.chr1.chr1      0.00168            2.77469        -1
#                                  ...          ...                ...       ...
#   chrX.chrX-79143980-79144825_GPR174      0.00024            3.61979         1
#   chrX.chrX-79143980-79144825_P2RY10      0.00040            3.39794         1
#       chrX.chrX-7926938-7928018_PUDP      0.00232            2.63451         1
#    chrX.chrX-79366484-79367788_ITM2A      0.00896            2.04769         1
#        chrX.chrX-989839-990623_P2RY8      0.00064            3.19382         1
#                                      boot_basic_p.log10.signed
#                                                      <numeric>
#                       chr1.chr1.chr1                   1.90379
#                       chr1.chr1.chr1                   1.96019
#                       chr1.chr1.chr1                   1.75845
#                       chr1.chr1.chr1                  -2.36452
#                       chr1.chr1.chr1                  -2.77469
#                                  ...                       ...
#   chrX.chrX-79143980-79144825_GPR174                   3.61979
#   chrX.chrX-79143980-79144825_P2RY10                   3.39794
#       chrX.chrX-7926938-7928018_PUDP                   2.63451
#    chrX.chrX-79366484-79367788_ITM2A                   2.04769
#        chrX.chrX-989839-990623_P2RY8                   3.19382
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = celltype
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
df.output[,"FDR"] = p.adjust(df.output$boot_basic_p, method = "BH")
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta        se
# 1      chr1  10472047  10472925 MTOR       T         0.11763475 0.04311697
# 2      chr1   1068602   1070146 CCNL2      T         0.09099986 0.03545127
# 3      chr1   1068602   1070146 UBE2J2     T         0.12485432 0.05249078
# 4      chr1 108876586 108877518 SARS       T        -0.15531347 0.05000137
# 5      chr1 109090240 109091248 SARS       T        -0.17452433 0.05034967
# 6      chr1 109112425 109113207 SARS       T        -0.17145047 0.06221128
# 7      chr1 109509105 109510395 PRPF38B    T         0.08755525 0.03254829
# 8      chr1 110034187 110035304 SARS       T        -0.12992930 0.04566235
# 9      chr1 110067432 110070739 SARS       T        -0.26112445 0.08037993
# 10     chr1   1115794   1117004 GNB1       T        -0.06285462 0.02133789
# 11     chr1 112955287 112957773 RSBN1      T         0.07550597 0.02698245
# 12     chr1 113072606 113073714 CAPZA1     T         0.05599538 0.01934645
# 13     chr1 114581280 114582191 BCAS2      T         0.10805847 0.03391093
# 14     chr1 116769278 116771061 ATP1A1-AS1 T         0.18569955 0.06064615
# 15     chr1 117605435 117607187 FAM46C     T         0.08482604 0.02434543
# 16     chr1 117664067 117664996 FAM46C     T         0.13272370 0.02652074
# 17     chr1   1208007   1209278 AURKAIP1   T         0.15667901 0.05973869
# 18     chr1   1307526   1309040 CDK11A     T         0.14214061 0.05421756
# 19     chr1   1324250   1325420 FAAP20     T         0.13359827 0.05112200
# 20     chr1   1374775   1375847 GNB1       T        -0.06310953 0.02160884
# 21     chr1 149812070 149812898 ANP32E     T        -0.14750073 0.05222261
# 22     chr1 150281278 150282872 GABPB2     T        -0.15162481 0.05105834
# 23     chr1 150321115 150322119 HIST2H2AC  T         0.14945022 0.03610603
# 24     chr1 150611241 150612172 HIST2H2AC  T         0.13973368 0.03518024
# 25     chr1 150696928 150697785 ANP32E     T        -0.13025781 0.04591322
# 26     chr1 151070094 151071575 S100A10    T        -0.07985733 0.02385796
# 27     chr1 151189591 151190598 ANP32E     T        -0.14891026 0.05259147
# 28     chr1 151189591 151190598 CDC42SE1   T        -0.08071204 0.02969488
# 29     chr1 151539706 151541054 THEM4      T         0.11813424 0.04174975
# 30     chr1 151830417 151831289 GABPB2     T        -0.25022620 0.08075115
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮           ⋮
# 178349 chrX 53093660  53094661  KANTR      T         0.15471426 0.04643949
# 178350 chrX 56563180  56564442  FAAH2      T         0.15573591 0.04046940
# 178351 chrX 56763790  56765067  FAAH2      T         0.22799549 0.04762455
# 178352 chrX 57286229  57287313  FAAH2      T         0.74275536 0.04684384
# 178353 chrX 63350437  63351748  LINC01278  T         0.21211769 0.05394994
# 178354 chrX 65034333  65035732  ZC4H2      T         0.22030486 0.06225646
# 178355 chrX 71282807  71284213  RPS4X      T        -0.05628280 0.01015719
# 178356 chrX 71492086  71493442  RPS4X      T        -0.14961291 0.01866598
# 178357 chrX 71531990  71533413  RPS4X      T        -0.11445623 0.01031652
# 178358 chrX 71533787  71534599  RPS4X      T        -0.12345569 0.01719360
# 178359 chrX 71606583  71607522  RPS4X      T        -0.18585275 0.02043378
# 178360 chrX 71992294  71993343  RPS4X      T        -0.14773378 0.01379169
# 178361 chrX 72094664  72095635  NHSL2      T         0.42410893 0.08666172
# 178362 chrX 72100053  72101383  IL2RG      T         0.08599776 0.03075296
# 178363 chrX 72100053  72101383  NHSL2      T         0.35263488 0.06144119
# 178364 chrX 72105266  72105936  IL2RG      T         0.11108451 0.03457503
# 178365 chrX 72105266  72105936  NHSL2      T         0.39356617 0.06784290
# 178366 chrX 72105266  72105936  RPS4X      T         0.09813075 0.01258710
# 178367 chrX 72168801  72169653  NHSL2      T         0.27727553 0.07141617
# 178368 chrX 73943785  73944836  JPX        T         0.13737579 0.03138170
# 178369 chrX 73943785  73944836  XIST       T         0.20007566 0.02129127
# 178370 chrX 77910239  77911080  COX7B      T         0.11678013 0.03815568
# 178371 chrX 78516886  78517757  P2RY10     T         0.16782811 0.05539054
# 178372 chrX 78944827  78945872  GPR174     T         0.15227828 0.04370583
# 178373 chrX 78944827  78945872  P2RY10     T         0.18633110 0.05814440
# 178374 chrX 79143980  79144825  GPR174     T         0.19907124 0.04712551
# 178375 chrX 79143980  79144825  P2RY10     T         0.25380199 0.06275908
# 178376 chrX  7926938   7928018  PUDP       T         0.19667221 0.05149367
# 178377 chrX 79366484  79367788  ITM2A      T         0.13202357 0.04604460
# 178378 chrX   989839    990623  P2RY8      T         0.12570977 0.02825529
#        z          p            boot_basic_p boot_basic_p.log10 sign
# 1       2.728270  6.366742e-03 0.01248      1.903785            1
# 2       2.566900  1.026122e-02 0.01096      1.960189            1
# 3       2.378595  1.737874e-02 0.01744      1.758454            1
# 4      -3.106184  1.895185e-03 0.00432      2.364516           -1
# 5      -3.466246  5.277804e-04 0.00168      2.774691           -1
# 6      -2.755939  5.852395e-03 0.01032      1.986320           -1
# 7       2.690010  7.144980e-03 0.01008      1.996539            1
# 8      -2.845436  4.435066e-03 0.00880      2.055517           -1
# 9      -3.248627  1.159633e-03 0.00328      2.484126           -1
# 10     -2.945681  3.222444e-03 0.01136      1.944622           -1
# 11      2.798336  5.136658e-03 0.00840      2.075721            1
# 12      2.894349  3.799454e-03 0.00784      2.105684            1
# 13      3.186538  1.439867e-03 0.00736      2.133122            1
# 14      3.062017  2.198510e-03 0.01096      1.960189            1
# 15      3.484270  4.934822e-04 0.00288      2.540608            1
# 16      5.004525  5.600002e-07 0.00008      4.096910            1
# 17      2.622739  8.722596e-03 0.01016      1.993106            1
# 18      2.621671  8.749989e-03 0.00920      2.036212            1
# 19      2.613322  8.966675e-03 0.01352      1.869023            1
# 20     -2.920542  3.494236e-03 0.01152      1.938548           -1
# 21     -2.824461  4.736021e-03 0.00872      2.059484           -1
# 22     -2.969639  2.981502e-03 0.00640      2.193820           -1
# 23      4.139204  3.485133e-05 0.00008      4.096910            1
# 24      3.971936  7.129082e-05 0.00040      3.397940            1
# 25     -2.837044  4.553337e-03 0.01048      1.979639           -1
# 26     -3.347199  8.163251e-04 0.00936      2.028724           -1
# 27     -2.831453  4.633707e-03 0.01048      1.979639           -1
# 28     -2.718045  6.566882e-03 0.01136      1.944622           -1
# 29      2.829579  4.660926e-03 0.00992      2.003488            1
# 30     -3.098732  1.943504e-03 0.00952      2.021363           -1
# ⋮      ⋮          ⋮            ⋮            ⋮                  ⋮
# 178349   3.331523 8.637202e-04 0.00312      2.505845            1
# 178350   3.848239 1.189700e-04 0.00832      2.079877            1
# 178351   4.787352 1.689960e-06 0.00104      2.982967            1
# 178352  15.855988 1.278026e-56 0.00008      4.096910            1
# 178353   3.931750 8.432961e-05 0.00312      2.505845            1
# 178354   3.538667 4.021531e-04 0.00432      2.364516            1
# 178355  -5.541178 3.004432e-08 0.00656      2.183096           -1
# 178356  -8.015270 1.098952e-15 0.00080      3.096910           -1
# 178357 -11.094462 1.334600e-28 0.00008      4.096910           -1
# 178358  -7.180327 6.954466e-13 0.00064      3.193820           -1
# 178359  -9.095370 9.426482e-20 0.00008      4.096910           -1
# 178360 -10.711800 8.960223e-27 0.00008      4.096910           -1
# 178361   4.893844 9.888519e-07 0.00008      4.096910            1
# 178362   2.796406 5.167446e-03 0.00824      2.084073            1
# 178363   5.739389 9.501888e-09 0.00008      4.096910            1
# 178364   3.212854 1.314231e-03 0.00232      2.634512            1
# 178365   5.801140 6.586538e-09 0.00008      4.096910            1
# 178366   7.796137 6.383127e-15 0.00008      4.096910            1
# 178367   3.882531 1.033746e-04 0.00032      3.494850            1
# 178368   4.377576 1.200063e-05 0.00016      3.795880            1
# 178369   9.397076 5.610052e-21 0.00008      4.096910            1
# 178370   3.060622 2.208775e-03 0.00416      2.380907            1
# 178371   3.029906 2.446302e-03 0.00856      2.067526            1
# 178372   3.484164 4.936766e-04 0.00280      2.552842            1
# 178373   3.204626 1.352379e-03 0.00688      2.162412            1
# 178374   4.224278 2.397082e-05 0.00024      3.619789            1
# 178375   4.044068 5.253164e-05 0.00040      3.397940            1
# 178376   3.819347 1.338052e-04 0.00232      2.634512            1
# 178377   2.867297 4.139937e-03 0.00896      2.047692            1
# 178378   4.449070 8.624294e-06 0.00064      3.193820            1
#        boot_basic_p.log10.signed FDR
# 1       1.903785                 0.153464068
# 2       1.960189                 0.143605060
# 3       1.758454                 0.184305084
# 4      -2.364516                 0.075808456
# 5      -2.774691                 0.038583113
# 6      -1.986320                 0.138370344
# 7       1.996539                 0.138370344
# 8      -2.055517                 0.124650711
# 9      -2.484126                 0.062428493
# 10     -1.944622                 0.145395284
# 11      2.075721                 0.120467535
# 12      2.105684                 0.114648592
# 13      2.133122                 0.109743549
# 14      1.960189                 0.143605060
# 15      2.540608                 0.056847255
# 16      4.096910                 0.003214742
# 17      1.993106                 0.138370344
# 18      2.036212                 0.129035823
# 19      1.869023                 0.158744981
# 20     -1.938548                 0.147242373
# 21     -2.059484                 0.123851912
# 22     -2.193820                 0.099556920
# 23      4.096910                 0.003214742
# 24      3.397940                 0.012720842
# 25     -1.979639                 0.139278903
# 26     -2.028724                 0.130622601
# 27     -1.979639                 0.139278903
# 28     -1.944622                 0.145395284
# 29      2.003488                 0.136620581
# 30     -2.021363                 0.132245040
# ⋮      ⋮                         ⋮
# 178349  2.505845                 0.060251095
# 178350  2.079877                 0.119685884
# 178351  2.982967                 0.026850936
# 178352  4.096910                 0.003214742
# 178353  2.505845                 0.060251095
# 178354  2.364516                 0.075808456
# 178355 -2.183096                 0.101189872
# 178356 -3.096910                 0.021913759
# 178357 -4.096910                 0.003214742
# 178358 -3.193820                 0.018434026
# 178359 -4.096910                 0.003214742
# 178360 -4.096910                 0.003214742
# 178361  4.096910                 0.003214742
# 178362  2.084073                 0.118812927
# 178363  4.096910                 0.003214742
# 178364  2.634512                 0.048749789
# 178365  4.096910                 0.003214742
# 178366  4.096910                 0.003214742
# 178367  3.494850                 0.010609844
# 178368  3.795880                 0.005910226
# 178369  4.096910                 0.003214742
# 178370  2.380907                 0.073916972
# 178371  2.067526                 0.122202135
# 178372  2.552842                 0.055724467
# 178373  2.162412                 0.104650860
# 178374  3.619789                 0.008350053
# 178375  3.397940                 0.012720842
# 178376  2.634512                 0.048749789
# 178377  2.047692                 0.126385172
# 178378  3.193820                 0.018434026

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] dplyr_1.1.4          data.table_1.15.2    Matrix_1.6-5
#  [4] GenomicRanges_1.54.1 GenomeInfoDb_1.38.1  IRanges_2.36.0
#  [7] S4Vectors_0.40.2     BiocGenerics_0.48.1  genomation_1.34.0
# [10] Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] withr_3.0.0                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] hms_1.1.3                   sp_2.1-4
#  [71] utf8_1.2.4                  XVector_0.42.0
#  [73] pillar_1.9.0                stringr_1.5.1
#  [75] spam_2.10-0                 IRdisplay_1.1
#  [77] splines_4.3.3               lattice_0.22-6
#  [79] rtracklayer_1.60.1          tidyselect_1.2.1
#  [81] Biostrings_2.70.1           pbapply_1.7-2
#  [83] knitr_1.46                  gridExtra_2.3
#  [85] SummarizedExperiment_1.30.2 RhpcBLASctl_0.23-42
#  [87] xfun_0.43                   Biobase_2.60.0
#  [89] matrixStats_1.3.0           stringi_1.8.3
#  [91] yaml_2.3.8                  boot_1.3-30
#  [93] evaluate_0.23               codetools_0.2-20
#  [95] tibble_3.2.1                cli_3.6.2
#  [97] IRkernel_1.3.2              rpart_4.1.23
#  [99] repr_1.1.7                  munsell_0.5.1
# [101] Rcpp_1.0.12                 globals_0.16.3
# [103] XML_3.99-0.16.1             ggplot2_3.5.1
# [105] readr_2.1.5                 dotCall64_1.1-1
# [107] bitops_1.0-7                lme4_1.1-35.3
# [109] listenv_0.9.1               scales_1.3.0
# [111] SeuratObject_5.0.1          purrr_1.0.2
# [113] crayon_1.5.2                rlang_1.1.3
# [115] fastmatch_1.1-4
