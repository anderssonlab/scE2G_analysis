# %%
library(cicero)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
# Loading required package: monocle3
#
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘monocle3’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     exprs, fData, fData<-, pData, pData<-
#
#
# Loading required package: Gviz
#
# Loading required package: grid
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'sp'
#
#
# The following object is masked from 'package:IRanges':
#
#     %over%
#
#
# 'SeuratObject' was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall 'SeuratObject' as the ABI
# for R may have changed
#
# 'SeuratObject' was built with package 'Matrix' 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     intersect
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following object is masked from 'package:IRanges':
#
#     intersect
#
#
# The following object is masked from 'package:S4Vectors':
#
#     intersect
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     intersect
#
#
# The following object is masked from 'package:base':
#
#     intersect
#
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     subtract
#
#
# Warning message:
# "replacing previous import 'Biostrings::pattern' by 'grid::pattern' when loading 'genomation'"
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/5.merge_peaks_from_5_super_groups.240524/obj.seurat.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/5.merge_peaks_from_5_super_groups.240524/matrix.atac.5_super_groups.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/5.merge_peaks_from_5_super_groups.240524/pairs.rds"
path.TSS1kb = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Neighborhoods/GeneList.TSS1kb.bed"
path.chrom.sizes = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/ENCODE_rE2G/ABC/reference/hg38/GRCh38_EBV.chrom.sizes.tsv"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/Cicero/BMMC5.merge.240524/"

# %%
distance_constraint = 1000000 
window = 2000000

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac_count = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac_count)
rm(matrix.atac_count)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import TSS1kb regions

# %%
bed.TSS1kb = readGeneric(path.TSS1kb,
                         header = F,
                         keep.all.metadata = T)
bed.TSS1kb
# Out:
# GRanges object with 20666 ranges and 3 metadata columns:
#           seqnames            ranges strand |          V4        V5          V6
#              <Rle>         <IRanges>  <Rle> | <character> <integer> <character>
#       [1]     chr1       35581-36581      * |     FAM138A         0           -
#       [2]     chr1       35581-36581      * |     FAM138F         0           -
#       [3]     chr1       68590-69590      * |       OR4F5         0           +
#       [4]     chr1     816870-817870      * |      FAM87B         0           +
#       [5]     chr1     827022-828022      * |   LINC00115         0           -
#       ...      ...               ...    ... .         ...       ...         ...
#   [20662]     chrY 21385860-21386860      * |       PRORY         0           -
#   [20663]     chrY 21594166-21595166      * |      TTTY13         0           -
#   [20664]     chrY 22298376-22299376      * |       TTTY5         0           -
#   [20665]     chrY 23198592-23199592      * |        DAZ1         0           -
#   [20666]     chrY 23218956-23219956      * |        DAZ2         0           +
#   -------
#   seqinfo: 24 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Create a Cicero CDS

# %%
cellinfo = obj.seurat@meta.data[colnames(matrix.atac),]
cellinfo[,"cell"] = rownames(cellinfo)
cellinfo
# Out:
#                         orig.ident nCount_RNA nFeature_RNA barcode
# s1d1_TAGTTGTCACCCTCAC-1 s1d1        1701      1121         TAGTTGTCACCCTCAC-1
# s1d1_CTATGGCCATAACGGG-1 s1d1        2157      1277         CTATGGCCATAACGGG-1
# s1d1_CCGCACACAGGTTAAA-1 s1d1        8311      3589         CCGCACACAGGTTAAA-1
# s1d1_TCATTTGGTAATGGAA-1 s1d1        1291       887         TCATTTGGTAATGGAA-1
# s1d1_ACCACATAGGTGTCCA-1 s1d1        2128      1337         ACCACATAGGTGTCCA-1
# s1d1_TGGATTGGTTTGCGAA-1 s1d1       16740      4729         TGGATTGGTTTGCGAA-1
# s1d1_GACTTAGGTTGCGCGA-1 s1d1        1182       876         GACTTAGGTTGCGCGA-1
# s1d1_GCCTTACTCGTTACAA-1 s1d1       10154      4021         GCCTTACTCGTTACAA-1
# s1d1_GTAAGGTCAATAACCT-1 s1d1        2041      1264         GTAAGGTCAATAACCT-1
# s1d1_AGCGCCTAGATGGACA-1 s1d1        2307      1210         AGCGCCTAGATGGACA-1
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1        1920      1227         TGCCGGTAGTCGCAAT-1
# s1d1_CCTGAATAGCTTGCTC-1 s1d1        3907      1408         CCTGAATAGCTTGCTC-1
# s1d1_CATCCCAGTCTTTATG-1 s1d1        3211      1670         CATCCCAGTCTTTATG-1
# s1d1_GGCTGAGAGTATTGCA-1 s1d1        2159      1063         GGCTGAGAGTATTGCA-1
# s1d1_TAGTGAGAGCTGCACA-1 s1d1        3568      1984         TAGTGAGAGCTGCACA-1
# s1d1_GGATTATGTTACATCC-1 s1d1        5014      2443         GGATTATGTTACATCC-1
# s1d1_CCTGTTGGTTATAGCG-1 s1d1        4044      2074         CCTGTTGGTTATAGCG-1
# s1d1_GGCAATCGTTAGGACC-1 s1d1        1154       417         GGCAATCGTTAGGACC-1
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1        2728      1514         TTTAGCTTCTGGCTTC-1
# s1d1_AACGACAAGTTGTCAA-1 s1d1        1477       999         AACGACAAGTTGTCAA-1
# s1d1_AGCAATACAATATGGA-1 s1d1        2295      1258         AGCAATACAATATGGA-1
# s1d1_AGTTATGTCTCACTCA-1 s1d1        1534       360         AGTTATGTCTCACTCA-1
# s1d1_TGTCCTGGTCAATGTG-1 s1d1        1844      1195         TGTCCTGGTCAATGTG-1
# s1d1_GTTTGTCGTGAATCGC-1 s1d1        6050      1741         GTTTGTCGTGAATCGC-1
# s1d1_AGAATCGAGAAAGGAA-1 s1d1        4293      2318         AGAATCGAGAAAGGAA-1
# s1d1_TGTGAAACAGGATTAA-1 s1d1        2800      1522         TGTGAAACAGGATTAA-1
# s1d1_CGCAAATTCTACTAAG-1 s1d1        4517      1798         CGCAAATTCTACTAAG-1
# s1d1_GGGAGTAGTGATTTGG-1 s1d1        2708      1443         GGGAGTAGTGATTTGG-1
# s1d1_ATGTGAGAGGCGAAAC-1 s1d1        1126       794         ATGTGAGAGGCGAAAC-1
# s1d1_GGTTTCCTCTTGGACG-1 s1d1        2323       852         GGTTTCCTCTTGGACG-1
# ⋮                       ⋮          ⋮          ⋮            ⋮
# s4d9_TCCATCATCGCATTAA-1 s4d9       1341        670         TCCATCATCGCATTAA-1
# s4d9_TCTAGCGAGCCACATG-1 s4d9       1710       1114         TCTAGCGAGCCACATG-1
# s4d9_GTCGAAGCACATAACT-1 s4d9        813        614         GTCGAAGCACATAACT-1
# s4d9_CCGGTTAAGCCTGTTC-1 s4d9       1496       1027         CCGGTTAAGCCTGTTC-1
# s4d9_ATGTTCAAGTTATTCC-1 s4d9        869        601         ATGTTCAAGTTATTCC-1
# s4d9_CCAGGATGTATTCGTC-1 s4d9        802        507         CCAGGATGTATTCGTC-1
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9        793        579         CTTCAAGCAAAGCGCA-1
# s4d9_ACGAAGTCACGAACAG-1 s4d9        795        576         ACGAAGTCACGAACAG-1
# s4d9_GGTCCGTAGCACAGAA-1 s4d9       1239        894         GGTCCGTAGCACAGAA-1
# s4d9_GCTTTACGTATTCGCT-1 s4d9        905        627         GCTTTACGTATTCGCT-1
# s4d9_TCAAGCTAGCACCACA-1 s4d9        822        663         TCAAGCTAGCACCACA-1
# s4d9_GGTCAATTCGATTATG-1 s4d9       1553        999         GGTCAATTCGATTATG-1
# s4d9_ATGACAACATGAATAG-1 s4d9       1590       1043         ATGACAACATGAATAG-1
# s4d9_TAGCCGGGTAATAGCT-1 s4d9       2699       1506         TAGCCGGGTAATAGCT-1
# s4d9_TACCTCATCATGCGTG-1 s4d9        995        686         TACCTCATCATGCGTG-1
# s4d9_CAAGCTAGTCAACAAT-1 s4d9       1664       1053         CAAGCTAGTCAACAAT-1
# s4d9_TATGGCCCAGGCTACT-1 s4d9       1122        727         TATGGCCCAGGCTACT-1
# s4d9_ACAGGTAAGGTTACGT-1 s4d9       1221        849         ACAGGTAAGGTTACGT-1
# s4d9_TGTGGAGCAGAAATGC-1 s4d9        569        434         TGTGGAGCAGAAATGC-1
# s4d9_GGTTTAATCTATGACA-1 s4d9       3206       1769         GGTTTAATCTATGACA-1
# s4d9_ACTAATCCAGCAAGAT-1 s4d9       1003        707         ACTAATCCAGCAAGAT-1
# s4d9_AGCATCCCACAGAACG-1 s4d9        895        618         AGCATCCCACAGAACG-1
# s4d9_ATTGAAGCACATTGCA-1 s4d9        607        490         ATTGAAGCACATTGCA-1
# s4d9_CTATTCAGTTGTGATG-1 s4d9       1018        713         CTATTCAGTTGTGATG-1
# s4d9_TGAACAACAGTGAACG-1 s4d9        705        502         TGAACAACAGTGAACG-1
# s4d9_CGATTCCTCCTGGCTT-1 s4d9        884        671         CGATTCCTCCTGGCTT-1
# s4d9_AAACCGCGTTTGAGGC-1 s4d9        777        557         AAACCGCGTTTGAGGC-1
# s4d9_GCTGTACCACCGTTCC-1 s4d9        740        527         GCTGTACCACCGTTCC-1
# s4d9_ACACTTGCAACTAGAA-1 s4d9       1449        956         ACACTTGCAACTAGAA-1
# s4d9_CACTTAAAGTCTGGGC-1 s4d9        889        638         CACTTAAAGTCTGGGC-1
#                         gex_barcode        atac_barcode       is_cell
# s1d1_TAGTTGTCACCCTCAC-1 TAGTTGTCACCCTCAC-1 GGACAACGTAAGTGGC-1 1
# s1d1_CTATGGCCATAACGGG-1 CTATGGCCATAACGGG-1 CAACCTGGTCCTCCCA-1 1
# s1d1_CCGCACACAGGTTAAA-1 CCGCACACAGGTTAAA-1 GAACCGGGTTAACACC-1 1
# s1d1_TCATTTGGTAATGGAA-1 TCATTTGGTAATGGAA-1 CCGCAAGCAGGTTCTT-1 1
# s1d1_ACCACATAGGTGTCCA-1 ACCACATAGGTGTCCA-1 GGTTACCTCCTCACGG-1 1
# s1d1_TGGATTGGTTTGCGAA-1 TGGATTGGTTTGCGAA-1 CAACATGCACCTGGCT-1 1
# s1d1_GACTTAGGTTGCGCGA-1 GACTTAGGTTGCGCGA-1 TTAGGATCACTAGCTT-1 1
# s1d1_GCCTTACTCGTTACAA-1 GCCTTACTCGTTACAA-1 CTAGCCTAGTGCAACG-1 1
# s1d1_GTAAGGTCAATAACCT-1 GTAAGGTCAATAACCT-1 TCAACCGGTCGAGGCA-1 1
# s1d1_AGCGCCTAGATGGACA-1 AGCGCCTAGATGGACA-1 ATGTTGTTCTCAAGAA-1 1
# s1d1_TGCCGGTAGTCGCAAT-1 TGCCGGTAGTCGCAAT-1 ACCAACCTCAGGCCAA-1 1
# s1d1_CCTGAATAGCTTGCTC-1 CCTGAATAGCTTGCTC-1 CGGTGAATCCTAATCG-1 1
# s1d1_CATCCCAGTCTTTATG-1 CATCCCAGTCTTTATG-1 CAGCTAACAGGCCTCT-1 1
# s1d1_GGCTGAGAGTATTGCA-1 GGCTGAGAGTATTGCA-1 CCGTTCCTCCAGCTCG-1 1
# s1d1_TAGTGAGAGCTGCACA-1 TAGTGAGAGCTGCACA-1 GTGGCTTTCGCATTTG-1 1
# s1d1_GGATTATGTTACATCC-1 GGATTATGTTACATCC-1 CGTTACTCAACAACAT-1 1
# s1d1_CCTGTTGGTTATAGCG-1 CCTGTTGGTTATAGCG-1 GTTTGAGCATTCAGGA-1 1
# s1d1_GGCAATCGTTAGGACC-1 GGCAATCGTTAGGACC-1 GGTCCCTCACGCTAGG-1 1
# s1d1_TTTAGCTTCTGGCTTC-1 TTTAGCTTCTGGCTTC-1 GCTGATGAGTCAGGAT-1 1
# s1d1_AACGACAAGTTGTCAA-1 AACGACAAGTTGTCAA-1 CAAGGTGTCACCTGGT-1 1
# s1d1_AGCAATACAATATGGA-1 AGCAATACAATATGGA-1 AAGACCAGTGCAATAG-1 1
# s1d1_AGTTATGTCTCACTCA-1 AGTTATGTCTCACTCA-1 CACGGTAAGCCTTTCT-1 1
# s1d1_TGTCCTGGTCAATGTG-1 TGTCCTGGTCAATGTG-1 ACAGCACCACCTGTAT-1 1
# s1d1_GTTTGTCGTGAATCGC-1 GTTTGTCGTGAATCGC-1 AAGGAACCAAATACCG-1 1
# s1d1_AGAATCGAGAAAGGAA-1 AGAATCGAGAAAGGAA-1 ATGTGCCTCACTCGCG-1 1
# s1d1_TGTGAAACAGGATTAA-1 TGTGAAACAGGATTAA-1 ACCCGTAGTAGAGGCT-1 1
# s1d1_CGCAAATTCTACTAAG-1 CGCAAATTCTACTAAG-1 TTCTGGCAGAAGGACA-1 1
# s1d1_GGGAGTAGTGATTTGG-1 GGGAGTAGTGATTTGG-1 CGGTACGCACTAAGGC-1 1
# s1d1_ATGTGAGAGGCGAAAC-1 ATGTGAGAGGCGAAAC-1 TACTACGTCACGCCCA-1 1
# s1d1_GGTTTCCTCTTGGACG-1 GGTTTCCTCTTGGACG-1 CGTATTTAGAATCACA-1 1
# ⋮                       ⋮                  ⋮                  ⋮
# s4d9_TCCATCATCGCATTAA-1 TCCATCATCGCATTAA-1 CATATAGAGCTAGTTT-1 1
# s4d9_TCTAGCGAGCCACATG-1 TCTAGCGAGCCACATG-1 GTCCTAATCTTGTTGG-1 1
# s4d9_GTCGAAGCACATAACT-1 GTCGAAGCACATAACT-1 CTGTGCAGTTTCCGGA-1 1
# s4d9_CCGGTTAAGCCTGTTC-1 CCGGTTAAGCCTGTTC-1 TGAATCTTCGACATTT-1 1
# s4d9_ATGTTCAAGTTATTCC-1 ATGTTCAAGTTATTCC-1 AAACTAGTCATGAAGC-1 1
# s4d9_CCAGGATGTATTCGTC-1 CCAGGATGTATTCGTC-1 GCTTGAACACTAATCC-1 1
# s4d9_CTTCAAGCAAAGCGCA-1 CTTCAAGCAAAGCGCA-1 CCATTAAGTTGCTCCT-1 1
# s4d9_ACGAAGTCACGAACAG-1 ACGAAGTCACGAACAG-1 AAGGCTAGTCACACTG-1 1
# s4d9_GGTCCGTAGCACAGAA-1 GGTCCGTAGCACAGAA-1 TCGCTAATCTTAAGGA-1 1
# s4d9_GCTTTACGTATTCGCT-1 GCTTTACGTATTCGCT-1 CCTGAAACAGGATGGA-1 1
# s4d9_TCAAGCTAGCACCACA-1 TCAAGCTAGCACCACA-1 TATATGCTCTAACTGT-1 1
# s4d9_GGTCAATTCGATTATG-1 GGTCAATTCGATTATG-1 CTGAGCAAGGAACAAG-1 1
# s4d9_ATGACAACATGAATAG-1 ATGACAACATGAATAG-1 GCTTAACGTTATCCGG-1 1
# s4d9_TAGCCGGGTAATAGCT-1 TAGCCGGGTAATAGCT-1 TACCGCCCATGAGCCG-1 1
# s4d9_TACCTCATCATGCGTG-1 TACCTCATCATGCGTG-1 ATAGTCAAGCTAATCT-1 1
# s4d9_CAAGCTAGTCAACAAT-1 CAAGCTAGTCAACAAT-1 CTTATTGCACTAAGCA-1 1
# s4d9_TATGGCCCAGGCTACT-1 TATGGCCCAGGCTACT-1 AAAGGAAGTTTGTAGC-1 1
# s4d9_ACAGGTAAGGTTACGT-1 ACAGGTAAGGTTACGT-1 GCCTTAATCTAATCCG-1 1
# s4d9_TGTGGAGCAGAAATGC-1 TGTGGAGCAGAAATGC-1 CCTTAAAGTTATGGGA-1 1
# s4d9_GGTTTAATCTATGACA-1 GGTTTAATCTATGACA-1 TGTGGTGAGTTACGAA-1 1
# s4d9_ACTAATCCAGCAAGAT-1 ACTAATCCAGCAAGAT-1 CGCTAATGTTTACTGA-1 1
# s4d9_AGCATCCCACAGAACG-1 AGCATCCCACAGAACG-1 GGCTTGCGTATTCAGC-1 1
# s4d9_ATTGAAGCACATTGCA-1 ATTGAAGCACATTGCA-1 GGTTCGCGTTAAGTGG-1 1
# s4d9_CTATTCAGTTGTGATG-1 CTATTCAGTTGTGATG-1 TTCCGGCCAAGTCCTT-1 1
# s4d9_TGAACAACAGTGAACG-1 TGAACAACAGTGAACG-1 CTGAATCGTATGTTGC-1 1
# s4d9_CGATTCCTCCTGGCTT-1 CGATTCCTCCTGGCTT-1 GCTCGTTAGTCACTCA-1 1
# s4d9_AAACCGCGTTTGAGGC-1 AAACCGCGTTTGAGGC-1 AATAGCTCACCAAAGC-1 1
# s4d9_GCTGTACCACCGTTCC-1 GCTGTACCACCGTTCC-1 AAGTGGCGTTAGTGCT-1 1
# s4d9_ACACTTGCAACTAGAA-1 ACACTTGCAACTAGAA-1 TAGTGAGGTTAACTGC-1 1
# s4d9_CACTTAAAGTCTGGGC-1 CACTTAAAGTCTGGGC-1 GGTGTGATCCCAGTAC-1 1
#                         excluded_reason gex_raw_reads gex_mapped_reads ⋯ QCMeds
# s1d1_TAGTTGTCACCCTCAC-1 0                13548         13091           ⋯ False
# s1d1_CTATGGCCATAACGGG-1 0                12415         11865           ⋯ False
# s1d1_CCGCACACAGGTTAAA-1 0                64631         62125           ⋯ False
# s1d1_TCATTTGGTAATGGAA-1 0                 8873          8544           ⋯ False
# s1d1_ACCACATAGGTGTCCA-1 0                14880         14353           ⋯ False
# s1d1_TGGATTGGTTTGCGAA-1 0               126119        122017           ⋯ False
# s1d1_GACTTAGGTTGCGCGA-1 0                 8982          8675           ⋯ False
# s1d1_GCCTTACTCGTTACAA-1 0                69068         65936           ⋯ False
# s1d1_GTAAGGTCAATAACCT-1 0                16490         15900           ⋯ False
# s1d1_AGCGCCTAGATGGACA-1 0                15889         15317           ⋯ False
# s1d1_TGCCGGTAGTCGCAAT-1 0                12074         11538           ⋯ False
# s1d1_CCTGAATAGCTTGCTC-1 0                27563         26717           ⋯ False
# s1d1_CATCCCAGTCTTTATG-1 0                20421         19551           ⋯ False
# s1d1_GGCTGAGAGTATTGCA-1 0                16109         15620           ⋯ False
# s1d1_TAGTGAGAGCTGCACA-1 0                24146         23110           ⋯ False
# s1d1_GGATTATGTTACATCC-1 0                35911         34851           ⋯ False
# s1d1_CCTGTTGGTTATAGCG-1 0                25163         24266           ⋯ False
# s1d1_GGCAATCGTTAGGACC-1 0                 8963          8601           ⋯ False
# s1d1_TTTAGCTTCTGGCTTC-1 0                21335         20249           ⋯ False
# s1d1_AACGACAAGTTGTCAA-1 0                12149         11701           ⋯ False
# s1d1_AGCAATACAATATGGA-1 0                17987         17425           ⋯ False
# s1d1_AGTTATGTCTCACTCA-1 0                10588         10305           ⋯ False
# s1d1_TGTCCTGGTCAATGTG-1 0                12780         12312           ⋯ False
# s1d1_GTTTGTCGTGAATCGC-1 0                42260         40991           ⋯ False
# s1d1_AGAATCGAGAAAGGAA-1 0                36170         34940           ⋯ False
# s1d1_TGTGAAACAGGATTAA-1 0                18318         17568           ⋯ False
# s1d1_CGCAAATTCTACTAAG-1 0                34358         33280           ⋯ False
# s1d1_GGGAGTAGTGATTTGG-1 0                20699         20067           ⋯ False
# s1d1_ATGTGAGAGGCGAAAC-1 0                 5512          5271           ⋯ False
# s1d1_GGTTTCCTCTTGGACG-1 0                17534         16999           ⋯ False
# ⋮                       ⋮               ⋮             ⋮                ⋱ ⋮
# s4d9_TCCATCATCGCATTAA-1 0               28614         26828            ⋯ False
# s4d9_TCTAGCGAGCCACATG-1 0               37319         35181            ⋯ False
# s4d9_GTCGAAGCACATAACT-1 0               15004         14070            ⋯ False
# s4d9_CCGGTTAAGCCTGTTC-1 0               28961         27146            ⋯ False
# s4d9_ATGTTCAAGTTATTCC-1 0               24251         22736            ⋯ False
# s4d9_CCAGGATGTATTCGTC-1 0               18261         17154            ⋯ False
# s4d9_CTTCAAGCAAAGCGCA-1 0               15635         14655            ⋯ False
# s4d9_ACGAAGTCACGAACAG-1 0               18106         16888            ⋯ False
# s4d9_GGTCCGTAGCACAGAA-1 0               24762         23304            ⋯ False
# s4d9_GCTTTACGTATTCGCT-1 0               18647         17498            ⋯ False
# s4d9_TCAAGCTAGCACCACA-1 0               18776         17603            ⋯ False
# s4d9_GGTCAATTCGATTATG-1 0               33367         31403            ⋯ False
# s4d9_ATGACAACATGAATAG-1 0               39303         36731            ⋯ False
# s4d9_TAGCCGGGTAATAGCT-1 0               59786         56144            ⋯ False
# s4d9_TACCTCATCATGCGTG-1 0               26143         24507            ⋯ False
# s4d9_CAAGCTAGTCAACAAT-1 0               38048         35481            ⋯ False
# s4d9_TATGGCCCAGGCTACT-1 0               23914         22412            ⋯ False
# s4d9_ACAGGTAAGGTTACGT-1 0               24786         23162            ⋯ False
# s4d9_TGTGGAGCAGAAATGC-1 0               10996         10398            ⋯ False
# s4d9_GGTTTAATCTATGACA-1 0               65199         61191            ⋯ False
# s4d9_ACTAATCCAGCAAGAT-1 0               23201         21704            ⋯ False
# s4d9_AGCATCCCACAGAACG-1 0               19724         18503            ⋯ False
# s4d9_ATTGAAGCACATTGCA-1 0               17561         16154            ⋯ False
# s4d9_CTATTCAGTTGTGATG-1 0               23396         21772            ⋯ False
# s4d9_TGAACAACAGTGAACG-1 0               15775         14756            ⋯ False
# s4d9_CGATTCCTCCTGGCTT-1 0               15990         14851            ⋯ False
# s4d9_AAACCGCGTTTGAGGC-1 0               17517         16536            ⋯ False
# s4d9_GCTGTACCACCGTTCC-1 0               15921         14931            ⋯ False
# s4d9_ACACTTGCAACTAGAA-1 0               24183         22660            ⋯ False
# s4d9_CACTTAAAGTCTGGGC-1 0               19433         18214            ⋯ False
#                         DonorSmoker rename                  nCount_ATAC_empty
# s1d1_TAGTTGTCACCCTCAC-1 Nonsmoker   s1d1_TAGTTGTCACCCTCAC-1 0
# s1d1_CTATGGCCATAACGGG-1 Nonsmoker   s1d1_CTATGGCCATAACGGG-1 0
# s1d1_CCGCACACAGGTTAAA-1 Nonsmoker   s1d1_CCGCACACAGGTTAAA-1 0
# s1d1_TCATTTGGTAATGGAA-1 Nonsmoker   s1d1_TCATTTGGTAATGGAA-1 0
# s1d1_ACCACATAGGTGTCCA-1 Nonsmoker   s1d1_ACCACATAGGTGTCCA-1 0
# s1d1_TGGATTGGTTTGCGAA-1 Nonsmoker   s1d1_TGGATTGGTTTGCGAA-1 0
# s1d1_GACTTAGGTTGCGCGA-1 Nonsmoker   s1d1_GACTTAGGTTGCGCGA-1 0
# s1d1_GCCTTACTCGTTACAA-1 Nonsmoker   s1d1_GCCTTACTCGTTACAA-1 0
# s1d1_GTAAGGTCAATAACCT-1 Nonsmoker   s1d1_GTAAGGTCAATAACCT-1 0
# s1d1_AGCGCCTAGATGGACA-1 Nonsmoker   s1d1_AGCGCCTAGATGGACA-1 0
# s1d1_TGCCGGTAGTCGCAAT-1 Nonsmoker   s1d1_TGCCGGTAGTCGCAAT-1 0
# s1d1_CCTGAATAGCTTGCTC-1 Nonsmoker   s1d1_CCTGAATAGCTTGCTC-1 0
# s1d1_CATCCCAGTCTTTATG-1 Nonsmoker   s1d1_CATCCCAGTCTTTATG-1 0
# s1d1_GGCTGAGAGTATTGCA-1 Nonsmoker   s1d1_GGCTGAGAGTATTGCA-1 0
# s1d1_TAGTGAGAGCTGCACA-1 Nonsmoker   s1d1_TAGTGAGAGCTGCACA-1 0
# s1d1_GGATTATGTTACATCC-1 Nonsmoker   s1d1_GGATTATGTTACATCC-1 0
# s1d1_CCTGTTGGTTATAGCG-1 Nonsmoker   s1d1_CCTGTTGGTTATAGCG-1 0
# s1d1_GGCAATCGTTAGGACC-1 Nonsmoker   s1d1_GGCAATCGTTAGGACC-1 0
# s1d1_TTTAGCTTCTGGCTTC-1 Nonsmoker   s1d1_TTTAGCTTCTGGCTTC-1 0
# s1d1_AACGACAAGTTGTCAA-1 Nonsmoker   s1d1_AACGACAAGTTGTCAA-1 0
# s1d1_AGCAATACAATATGGA-1 Nonsmoker   s1d1_AGCAATACAATATGGA-1 0
# s1d1_AGTTATGTCTCACTCA-1 Nonsmoker   s1d1_AGTTATGTCTCACTCA-1 0
# s1d1_TGTCCTGGTCAATGTG-1 Nonsmoker   s1d1_TGTCCTGGTCAATGTG-1 0
# s1d1_GTTTGTCGTGAATCGC-1 Nonsmoker   s1d1_GTTTGTCGTGAATCGC-1 0
# s1d1_AGAATCGAGAAAGGAA-1 Nonsmoker   s1d1_AGAATCGAGAAAGGAA-1 0
# s1d1_TGTGAAACAGGATTAA-1 Nonsmoker   s1d1_TGTGAAACAGGATTAA-1 0
# s1d1_CGCAAATTCTACTAAG-1 Nonsmoker   s1d1_CGCAAATTCTACTAAG-1 0
# s1d1_GGGAGTAGTGATTTGG-1 Nonsmoker   s1d1_GGGAGTAGTGATTTGG-1 0
# s1d1_ATGTGAGAGGCGAAAC-1 Nonsmoker   s1d1_ATGTGAGAGGCGAAAC-1 0
# s1d1_GGTTTCCTCTTGGACG-1 Nonsmoker   s1d1_GGTTTCCTCTTGGACG-1 0
# ⋮                       ⋮           ⋮                       ⋮
# s4d9_TCCATCATCGCATTAA-1 Nonsmoker   s4d9_TCCATCATCGCATTAA-1 0
# s4d9_TCTAGCGAGCCACATG-1 Nonsmoker   s4d9_TCTAGCGAGCCACATG-1 0
# s4d9_GTCGAAGCACATAACT-1 Nonsmoker   s4d9_GTCGAAGCACATAACT-1 0
# s4d9_CCGGTTAAGCCTGTTC-1 Nonsmoker   s4d9_CCGGTTAAGCCTGTTC-1 0
# s4d9_ATGTTCAAGTTATTCC-1 Nonsmoker   s4d9_ATGTTCAAGTTATTCC-1 0
# s4d9_CCAGGATGTATTCGTC-1 Nonsmoker   s4d9_CCAGGATGTATTCGTC-1 0
# s4d9_CTTCAAGCAAAGCGCA-1 Nonsmoker   s4d9_CTTCAAGCAAAGCGCA-1 0
# s4d9_ACGAAGTCACGAACAG-1 Nonsmoker   s4d9_ACGAAGTCACGAACAG-1 0
# s4d9_GGTCCGTAGCACAGAA-1 Nonsmoker   s4d9_GGTCCGTAGCACAGAA-1 0
# s4d9_GCTTTACGTATTCGCT-1 Nonsmoker   s4d9_GCTTTACGTATTCGCT-1 0
# s4d9_TCAAGCTAGCACCACA-1 Nonsmoker   s4d9_TCAAGCTAGCACCACA-1 0
# s4d9_GGTCAATTCGATTATG-1 Nonsmoker   s4d9_GGTCAATTCGATTATG-1 0
# s4d9_ATGACAACATGAATAG-1 Nonsmoker   s4d9_ATGACAACATGAATAG-1 0
# s4d9_TAGCCGGGTAATAGCT-1 Nonsmoker   s4d9_TAGCCGGGTAATAGCT-1 0
# s4d9_TACCTCATCATGCGTG-1 Nonsmoker   s4d9_TACCTCATCATGCGTG-1 0
# s4d9_CAAGCTAGTCAACAAT-1 Nonsmoker   s4d9_CAAGCTAGTCAACAAT-1 0
# s4d9_TATGGCCCAGGCTACT-1 Nonsmoker   s4d9_TATGGCCCAGGCTACT-1 0
# s4d9_ACAGGTAAGGTTACGT-1 Nonsmoker   s4d9_ACAGGTAAGGTTACGT-1 0
# s4d9_TGTGGAGCAGAAATGC-1 Nonsmoker   s4d9_TGTGGAGCAGAAATGC-1 0
# s4d9_GGTTTAATCTATGACA-1 Nonsmoker   s4d9_GGTTTAATCTATGACA-1 0
# s4d9_ACTAATCCAGCAAGAT-1 Nonsmoker   s4d9_ACTAATCCAGCAAGAT-1 0
# s4d9_AGCATCCCACAGAACG-1 Nonsmoker   s4d9_AGCATCCCACAGAACG-1 0
# s4d9_ATTGAAGCACATTGCA-1 Nonsmoker   s4d9_ATTGAAGCACATTGCA-1 0
# s4d9_CTATTCAGTTGTGATG-1 Nonsmoker   s4d9_CTATTCAGTTGTGATG-1 0
# s4d9_TGAACAACAGTGAACG-1 Nonsmoker   s4d9_TGAACAACAGTGAACG-1 0
# s4d9_CGATTCCTCCTGGCTT-1 Nonsmoker   s4d9_CGATTCCTCCTGGCTT-1 0
# s4d9_AAACCGCGTTTGAGGC-1 Nonsmoker   s4d9_AAACCGCGTTTGAGGC-1 0
# s4d9_GCTGTACCACCGTTCC-1 Nonsmoker   s4d9_GCTGTACCACCGTTCC-1 0
# s4d9_ACACTTGCAACTAGAA-1 Nonsmoker   s4d9_ACACTTGCAACTAGAA-1 0
# s4d9_CACTTAAAGTCTGGGC-1 Nonsmoker   s4d9_CACTTAAAGTCTGGGC-1 0
#                         nFeature_ATAC_empty cell_type.rename
# s1d1_TAGTTGTCACCCTCAC-1 0                   Naive_CD20_pos_B
# s1d1_CTATGGCCATAACGGG-1 0                   CD14_pos_Mono
# s1d1_CCGCACACAGGTTAAA-1 0                   CD8_pos_T
# s1d1_TCATTTGGTAATGGAA-1 0                   CD8_pos_T
# s1d1_ACCACATAGGTGTCCA-1 0                   CD16_pos_Mono
# s1d1_TGGATTGGTTTGCGAA-1 0                   B1_B
# s1d1_GACTTAGGTTGCGCGA-1 0                   CD4_pos_T_naive
# s1d1_GCCTTACTCGTTACAA-1 0                   CD4_pos_T_activated
# s1d1_GTAAGGTCAATAACCT-1 0                   B1_B
# s1d1_AGCGCCTAGATGGACA-1 0                   Erythroblast
# s1d1_TGCCGGTAGTCGCAAT-1 0                   CD14_pos_Mono
# s1d1_CCTGAATAGCTTGCTC-1 0                   Erythroblast
# s1d1_CATCCCAGTCTTTATG-1 0                   CD14_pos_Mono
# s1d1_GGCTGAGAGTATTGCA-1 0                   Erythroblast
# s1d1_TAGTGAGAGCTGCACA-1 0                   CD14_pos_Mono
# s1d1_GGATTATGTTACATCC-1 0                   Transitional_B
# s1d1_CCTGTTGGTTATAGCG-1 0                   CD16_pos_Mono
# s1d1_GGCAATCGTTAGGACC-1 0                   Normoblast
# s1d1_TTTAGCTTCTGGCTTC-1 0                   CD14_pos_Mono
# s1d1_AACGACAAGTTGTCAA-1 0                   B1_B
# s1d1_AGCAATACAATATGGA-1 0                   Naive_CD20_pos_B
# s1d1_AGTTATGTCTCACTCA-1 0                   Normoblast
# s1d1_TGTCCTGGTCAATGTG-1 0                   CD4_pos_T_activated
# s1d1_GTTTGTCGTGAATCGC-1 0                   Erythroblast
# s1d1_AGAATCGAGAAAGGAA-1 0                   CD4_pos_T_activated
# s1d1_TGTGAAACAGGATTAA-1 0                   CD14_pos_Mono
# s1d1_CGCAAATTCTACTAAG-1 0                   Erythroblast
# s1d1_GGGAGTAGTGATTTGG-1 0                   B1_B
# s1d1_ATGTGAGAGGCGAAAC-1 0                   CD8_pos_T
# s1d1_GGTTTCCTCTTGGACG-1 0                   Erythroblast
# ⋮                       ⋮                   ⋮
# s4d9_TCCATCATCGCATTAA-1 0                   Normoblast
# s4d9_TCTAGCGAGCCACATG-1 0                   CD4_pos_T_naive
# s4d9_GTCGAAGCACATAACT-1 0                   Naive_CD20_pos_B
# s4d9_CCGGTTAAGCCTGTTC-1 0                   G_M_prog
# s4d9_ATGTTCAAGTTATTCC-1 0                   Transitional_B
# s4d9_CCAGGATGTATTCGTC-1 0                   Proerythroblast
# s4d9_CTTCAAGCAAAGCGCA-1 0                   Transitional_B
# s4d9_ACGAAGTCACGAACAG-1 0                   CD8_pos_T_naive
# s4d9_GGTCCGTAGCACAGAA-1 0                   CD4_pos_T_naive
# s4d9_GCTTTACGTATTCGCT-1 0                   Transitional_B
# s4d9_TCAAGCTAGCACCACA-1 0                   Transitional_B
# s4d9_GGTCAATTCGATTATG-1 0                   Transitional_B
# s4d9_ATGACAACATGAATAG-1 0                   CD8_pos_T_naive
# s4d9_TAGCCGGGTAATAGCT-1 0                   Proerythroblast
# s4d9_TACCTCATCATGCGTG-1 0                   CD8_pos_T
# s4d9_CAAGCTAGTCAACAAT-1 0                   G_M_prog
# s4d9_TATGGCCCAGGCTACT-1 0                   CD8_pos_T
# s4d9_ACAGGTAAGGTTACGT-1 0                   CD16_pos_Mono
# s4d9_TGTGGAGCAGAAATGC-1 0                   CD4_pos_T_activated
# s4d9_GGTTTAATCTATGACA-1 0                   Naive_CD20_pos_B
# s4d9_ACTAATCCAGCAAGAT-1 0                   Naive_CD20_pos_B
# s4d9_AGCATCCCACAGAACG-1 0                   Naive_CD20_pos_B
# s4d9_ATTGAAGCACATTGCA-1 0                   CD8_pos_T
# s4d9_CTATTCAGTTGTGATG-1 0                   Naive_CD20_pos_B
# s4d9_TGAACAACAGTGAACG-1 0                   CD8_pos_T
# s4d9_CGATTCCTCCTGGCTT-1 0                   CD8_pos_T
# s4d9_AAACCGCGTTTGAGGC-1 0                   CD8_pos_T_naive
# s4d9_GCTGTACCACCGTTCC-1 0                   CD8_pos_T
# s4d9_ACACTTGCAACTAGAA-1 0                   cDC2
# s4d9_CACTTAAAGTCTGGGC-1 0                   Naive_CD20_pos_B
#                         cell_type.merged nCount_ATAC nFeature_ATAC
# s1d1_TAGTTGTCACCCTCAC-1 B                 4287        3758
# s1d1_CTATGGCCATAACGGG-1 Myeloid           9970        8298
# s1d1_CCGCACACAGGTTAAA-1 T                 4970        4246
# s1d1_TCATTTGGTAATGGAA-1 T                 3066        2783
# s1d1_ACCACATAGGTGTCCA-1 Myeloid           1917        1714
# s1d1_TGGATTGGTTTGCGAA-1 B                 3040        2839
# s1d1_GACTTAGGTTGCGCGA-1 T                 5022        4437
# s1d1_GCCTTACTCGTTACAA-1 T                28730       16709
# s1d1_GTAAGGTCAATAACCT-1 B                 8234        6611
# s1d1_AGCGCCTAGATGGACA-1 Erythroid         9839        7137
# s1d1_TGCCGGTAGTCGCAAT-1 Myeloid            590         584
# s1d1_CCTGAATAGCTTGCTC-1 Erythroid         6893        5279
# s1d1_CATCCCAGTCTTTATG-1 Myeloid            773         760
# s1d1_GGCTGAGAGTATTGCA-1 Erythroid         5608        4351
# s1d1_TAGTGAGAGCTGCACA-1 Myeloid          14504       11103
# s1d1_GGATTATGTTACATCC-1 B                10323        8576
# s1d1_CCTGTTGGTTATAGCG-1 Myeloid           7396        6341
# s1d1_GGCAATCGTTAGGACC-1 Erythroid         2446        2082
# s1d1_TTTAGCTTCTGGCTTC-1 Myeloid           1241        1214
# s1d1_AACGACAAGTTGTCAA-1 B                 8405        6814
# s1d1_AGCAATACAATATGGA-1 B                 5616        4689
# s1d1_AGTTATGTCTCACTCA-1 Erythroid         1674        1446
# s1d1_TGTCCTGGTCAATGTG-1 T                 2036        1926
# s1d1_GTTTGTCGTGAATCGC-1 Erythroid        14589       10275
# s1d1_AGAATCGAGAAAGGAA-1 T                14004       10236
# s1d1_TGTGAAACAGGATTAA-1 Myeloid           2895        2738
# s1d1_CGCAAATTCTACTAAG-1 Erythroid        10674        8695
# s1d1_GGGAGTAGTGATTTGG-1 B                 3374        3115
# s1d1_ATGTGAGAGGCGAAAC-1 T                 4539        3899
# s1d1_GGTTTCCTCTTGGACG-1 Erythroid         1452        1282
# ⋮                       ⋮                ⋮           ⋮
# s4d9_TCCATCATCGCATTAA-1 Erythroid         8682        6207
# s4d9_TCTAGCGAGCCACATG-1 T                 7428        5981
# s4d9_GTCGAAGCACATAACT-1 B                 6324        5218
# s4d9_CCGGTTAAGCCTGTTC-1 Myeloid          11351        9258
# s4d9_ATGTTCAAGTTATTCC-1 B                 6967        5771
# s4d9_CCAGGATGTATTCGTC-1 Erythroid         9355        6990
# s4d9_CTTCAAGCAAAGCGCA-1 B                16030       11796
# s4d9_ACGAAGTCACGAACAG-1 T                 7102        5719
# s4d9_GGTCCGTAGCACAGAA-1 T                 5618        4741
# s4d9_GCTTTACGTATTCGCT-1 B                 6720        5650
# s4d9_TCAAGCTAGCACCACA-1 B                 7144        6072
# s4d9_GGTCAATTCGATTATG-1 B                 7272        5982
# s4d9_ATGACAACATGAATAG-1 T                 5771        4830
# s4d9_TAGCCGGGTAATAGCT-1 Erythroid         6563        5907
# s4d9_TACCTCATCATGCGTG-1 T                17146       13175
# s4d9_CAAGCTAGTCAACAAT-1 Myeloid          10897        9032
# s4d9_TATGGCCCAGGCTACT-1 T                 2864        2578
# s4d9_ACAGGTAAGGTTACGT-1 Myeloid          11635        9282
# s4d9_TGTGGAGCAGAAATGC-1 T                 6541        5100
# s4d9_GGTTTAATCTATGACA-1 B                19935       14149
# s4d9_ACTAATCCAGCAAGAT-1 B                 3658        3302
# s4d9_AGCATCCCACAGAACG-1 B                 3494        3094
# s4d9_ATTGAAGCACATTGCA-1 T                 2499        2375
# s4d9_CTATTCAGTTGTGATG-1 B                 2563        2368
# s4d9_TGAACAACAGTGAACG-1 T                 5991        5006
# s4d9_CGATTCCTCCTGGCTT-1 T                 5540        4630
# s4d9_AAACCGCGTTTGAGGC-1 T                 7513        6071
# s4d9_GCTGTACCACCGTTCC-1 T                 6792        5339
# s4d9_ACACTTGCAACTAGAA-1 Dendritic        16556       13021
# s4d9_CACTTAAAGTCTGGGC-1 B                 4754        4047
#                         cell
# s1d1_TAGTTGTCACCCTCAC-1 s1d1_TAGTTGTCACCCTCAC-1
# s1d1_CTATGGCCATAACGGG-1 s1d1_CTATGGCCATAACGGG-1
# s1d1_CCGCACACAGGTTAAA-1 s1d1_CCGCACACAGGTTAAA-1
# s1d1_TCATTTGGTAATGGAA-1 s1d1_TCATTTGGTAATGGAA-1
# s1d1_ACCACATAGGTGTCCA-1 s1d1_ACCACATAGGTGTCCA-1
# s1d1_TGGATTGGTTTGCGAA-1 s1d1_TGGATTGGTTTGCGAA-1
# s1d1_GACTTAGGTTGCGCGA-1 s1d1_GACTTAGGTTGCGCGA-1
# s1d1_GCCTTACTCGTTACAA-1 s1d1_GCCTTACTCGTTACAA-1
# s1d1_GTAAGGTCAATAACCT-1 s1d1_GTAAGGTCAATAACCT-1
# s1d1_AGCGCCTAGATGGACA-1 s1d1_AGCGCCTAGATGGACA-1
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1_TGCCGGTAGTCGCAAT-1
# s1d1_CCTGAATAGCTTGCTC-1 s1d1_CCTGAATAGCTTGCTC-1
# s1d1_CATCCCAGTCTTTATG-1 s1d1_CATCCCAGTCTTTATG-1
# s1d1_GGCTGAGAGTATTGCA-1 s1d1_GGCTGAGAGTATTGCA-1
# s1d1_TAGTGAGAGCTGCACA-1 s1d1_TAGTGAGAGCTGCACA-1
# s1d1_GGATTATGTTACATCC-1 s1d1_GGATTATGTTACATCC-1
# s1d1_CCTGTTGGTTATAGCG-1 s1d1_CCTGTTGGTTATAGCG-1
# s1d1_GGCAATCGTTAGGACC-1 s1d1_GGCAATCGTTAGGACC-1
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1_TTTAGCTTCTGGCTTC-1
# s1d1_AACGACAAGTTGTCAA-1 s1d1_AACGACAAGTTGTCAA-1
# s1d1_AGCAATACAATATGGA-1 s1d1_AGCAATACAATATGGA-1
# s1d1_AGTTATGTCTCACTCA-1 s1d1_AGTTATGTCTCACTCA-1
# s1d1_TGTCCTGGTCAATGTG-1 s1d1_TGTCCTGGTCAATGTG-1
# s1d1_GTTTGTCGTGAATCGC-1 s1d1_GTTTGTCGTGAATCGC-1
# s1d1_AGAATCGAGAAAGGAA-1 s1d1_AGAATCGAGAAAGGAA-1
# s1d1_TGTGAAACAGGATTAA-1 s1d1_TGTGAAACAGGATTAA-1
# s1d1_CGCAAATTCTACTAAG-1 s1d1_CGCAAATTCTACTAAG-1
# s1d1_GGGAGTAGTGATTTGG-1 s1d1_GGGAGTAGTGATTTGG-1
# s1d1_ATGTGAGAGGCGAAAC-1 s1d1_ATGTGAGAGGCGAAAC-1
# s1d1_GGTTTCCTCTTGGACG-1 s1d1_GGTTTCCTCTTGGACG-1
# ⋮                       ⋮
# s4d9_TCCATCATCGCATTAA-1 s4d9_TCCATCATCGCATTAA-1
# s4d9_TCTAGCGAGCCACATG-1 s4d9_TCTAGCGAGCCACATG-1
# s4d9_GTCGAAGCACATAACT-1 s4d9_GTCGAAGCACATAACT-1
# s4d9_CCGGTTAAGCCTGTTC-1 s4d9_CCGGTTAAGCCTGTTC-1
# s4d9_ATGTTCAAGTTATTCC-1 s4d9_ATGTTCAAGTTATTCC-1
# s4d9_CCAGGATGTATTCGTC-1 s4d9_CCAGGATGTATTCGTC-1
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9_CTTCAAGCAAAGCGCA-1
# s4d9_ACGAAGTCACGAACAG-1 s4d9_ACGAAGTCACGAACAG-1
# s4d9_GGTCCGTAGCACAGAA-1 s4d9_GGTCCGTAGCACAGAA-1
# s4d9_GCTTTACGTATTCGCT-1 s4d9_GCTTTACGTATTCGCT-1
# s4d9_TCAAGCTAGCACCACA-1 s4d9_TCAAGCTAGCACCACA-1
# s4d9_GGTCAATTCGATTATG-1 s4d9_GGTCAATTCGATTATG-1
# s4d9_ATGACAACATGAATAG-1 s4d9_ATGACAACATGAATAG-1
# s4d9_TAGCCGGGTAATAGCT-1 s4d9_TAGCCGGGTAATAGCT-1
# s4d9_TACCTCATCATGCGTG-1 s4d9_TACCTCATCATGCGTG-1
# s4d9_CAAGCTAGTCAACAAT-1 s4d9_CAAGCTAGTCAACAAT-1
# s4d9_TATGGCCCAGGCTACT-1 s4d9_TATGGCCCAGGCTACT-1
# s4d9_ACAGGTAAGGTTACGT-1 s4d9_ACAGGTAAGGTTACGT-1
# s4d9_TGTGGAGCAGAAATGC-1 s4d9_TGTGGAGCAGAAATGC-1
# s4d9_GGTTTAATCTATGACA-1 s4d9_GGTTTAATCTATGACA-1
# s4d9_ACTAATCCAGCAAGAT-1 s4d9_ACTAATCCAGCAAGAT-1
# s4d9_AGCATCCCACAGAACG-1 s4d9_AGCATCCCACAGAACG-1
# s4d9_ATTGAAGCACATTGCA-1 s4d9_ATTGAAGCACATTGCA-1
# s4d9_CTATTCAGTTGTGATG-1 s4d9_CTATTCAGTTGTGATG-1
# s4d9_TGAACAACAGTGAACG-1 s4d9_TGAACAACAGTGAACG-1
# s4d9_CGATTCCTCCTGGCTT-1 s4d9_CGATTCCTCCTGGCTT-1
# s4d9_AAACCGCGTTTGAGGC-1 s4d9_AAACCGCGTTTGAGGC-1
# s4d9_GCTGTACCACCGTTCC-1 s4d9_GCTGTACCACCGTTCC-1
# s4d9_ACACTTGCAACTAGAA-1 s4d9_ACACTTGCAACTAGAA-1
# s4d9_CACTTAAAGTCTGGGC-1 s4d9_CACTTAAAGTCTGGGC-1

# %%
peakinfo = do.call(rbind,
                   strsplit(rownames(matrix.atac),"-"))
peakinfo = as.data.frame(peakinfo)
names(peakinfo) <- c("chr", "bp1", "bp2")
peakinfo$site_name <- paste(peakinfo$chr, peakinfo$bp1, peakinfo$bp2, sep="-")
row.names(peakinfo) <- peakinfo$site_name                   
peakinfo
# Out:
#                          chr  bp1       bp2       site_name
# chr1-10010-10512         chr1 10010     10512     chr1-10010-10512
# chr1-115495-115916       chr1 115495    115916    chr1-115495-115916
# chr1-180477-181904       chr1 180477    181904    chr1-180477-181904
# chr1-191243-191960       chr1 191243    191960    chr1-191243-191960
# chr1-267886-268118       chr1 267886    268118    chr1-267886-268118
# chr1-271197-271546       chr1 271197    271546    chr1-271197-271546
# chr1-586097-586303       chr1 586097    586303    chr1-586097-586303
# chr1-778320-779291       chr1 778320    779291    chr1-778320-779291
# chr1-796038-796388       chr1 796038    796388    chr1-796038-796388
# chr1-804829-805016       chr1 804829    805016    chr1-804829-805016
# chr1-816214-816457       chr1 816214    816457    chr1-816214-816457
# chr1-816880-817577       chr1 816880    817577    chr1-816880-817577
# chr1-819827-822457       chr1 819827    822457    chr1-819827-822457
# chr1-826749-827849       chr1 826749    827849    chr1-826749-827849
# chr1-830028-830375       chr1 830028    830375    chr1-830028-830375
# chr1-838229-838634       chr1 838229    838634    chr1-838229-838634
# chr1-841368-842046       chr1 841368    842046    chr1-841368-842046
# chr1-842625-843354       chr1 842625    843354    chr1-842625-843354
# chr1-844012-844977       chr1 844012    844977    chr1-844012-844977
# chr1-854881-855777       chr1 854881    855777    chr1-854881-855777
# chr1-856161-856854       chr1 856161    856854    chr1-856161-856854
# chr1-858025-859114       chr1 858025    859114    chr1-858025-859114
# chr1-860182-861191       chr1 860182    861191    chr1-860182-861191
# chr1-861626-862103       chr1 861626    862103    chr1-861626-862103
# chr1-865370-866333       chr1 865370    866333    chr1-865370-866333
# chr1-869566-870266       chr1 869566    870266    chr1-869566-870266
# chr1-874934-875929       chr1 874934    875929    chr1-874934-875929
# chr1-876327-877943       chr1 876327    877943    chr1-876327-877943
# chr1-890738-891027       chr1 890738    891027    chr1-890738-891027
# chr1-897172-899131       chr1 897172    899131    chr1-897172-899131
# ⋮                        ⋮    ⋮         ⋮         ⋮
# chrX-155767156-155768286 chrX 155767156 155768286 chrX-155767156-155768286
# chrX-155768434-155768881 chrX 155768434 155768881 chrX-155768434-155768881
# chrX-155819868-155820464 chrX 155819868 155820464 chrX-155819868-155820464
# chrX-155841085-155842216 chrX 155841085 155842216 chrX-155841085-155842216
# chrX-155843146-155843399 chrX 155843146 155843399 chrX-155843146-155843399
# chrX-155862332-155862700 chrX 155862332 155862700 chrX-155862332-155862700
# chrX-155874570-155875050 chrX 155874570 155875050 chrX-155874570-155875050
# chrX-155880697-155881969 chrX 155880697 155881969 chrX-155880697-155881969
# chrX-155886540-155887106 chrX 155886540 155887106 chrX-155886540-155887106
# chrX-155888112-155888537 chrX 155888112 155888537 chrX-155888112-155888537
# chrX-155889435-155889637 chrX 155889435 155889637 chrX-155889435-155889637
# chrX-155891176-155891892 chrX 155891176 155891892 chrX-155891176-155891892
# chrX-155893500-155894026 chrX 155893500 155894026 chrX-155893500-155894026
# chrX-155898861-155899591 chrX 155898861 155899591 chrX-155898861-155899591
# chrX-155923307-155923526 chrX 155923307 155923526 chrX-155923307-155923526
# chrX-155938235-155938480 chrX 155938235 155938480 chrX-155938235-155938480
# chrX-155966915-155967385 chrX 155966915 155967385 chrX-155966915-155967385
# chrX-155968152-155968557 chrX 155968152 155968557 chrX-155968152-155968557
# chrX-155997207-155998084 chrX 155997207 155998084 chrX-155997207-155998084
# chrX-156000341-156000798 chrX 156000341 156000798 chrX-156000341-156000798
# chrX-156001164-156002051 chrX 156001164 156002051 chrX-156001164-156002051
# chrX-156002480-156003316 chrX 156002480 156003316 chrX-156002480-156003316
# chrX-156003527-156004711 chrX 156003527 156004711 chrX-156003527-156004711
# chrX-156005198-156005567 chrX 156005198 156005567 chrX-156005198-156005567
# chrX-156006506-156006778 chrX 156006506 156006778 chrX-156006506-156006778
# chrX-156008487-156008683 chrX 156008487 156008683 chrX-156008487-156008683
# chrX-156008873-156009316 chrX 156008873 156009316 chrX-156008873-156009316
# chrX-156019835-156020122 chrX 156019835 156020122 chrX-156019835-156020122
# chrX-156029840-156030373 chrX 156029840 156030373 chrX-156029840-156030373
# chrX-156030498-156030725 chrX 156030498 156030725 chrX-156030498-156030725

# %%
input_cds <-  suppressWarnings(new_cell_data_set(matrix.atac,
                               cell_metadata = cellinfo,
                               gene_metadata = peakinfo))

# %%
input_cds <- monocle3::detect_genes(input_cds)
#Ensure there are no peaks included with zero reads
input_cds <- input_cds[Matrix::rowSums(exprs(input_cds)) != 0,]

# %%
set.seed(2017)
input_cds <- detect_genes(input_cds)
input_cds <- estimate_size_factors(input_cds)
input_cds <- preprocess_cds(input_cds, method = "LSI")
input_cds <- reduce_dimension(input_cds, reduction_method = 'UMAP', 
                              preprocess_method = "LSI")
# Out:
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'

# %%
plot_cells(input_cds)
# Out:
# No trajectory to plot. Has learn_graph() been called yet?
#
# cluster not found in colData(cds), cells will not be colored
#
# cluster_cells() has not been called yet, can't color cells by cluster
# plot without title

# %%
umap_coords <- reducedDims(input_cds)$UMAP
cicero_cds <- make_cicero_cds(input_cds, reduced_coordinates = umap_coords)
# Out:
# Overlap QC metrics:
# Cells per bin: 50
# Maximum shared cells bin-bin: 44
# Mean shared cells bin-bin: 0.0437364264773822
# Median shared cells bin-bin: 0

# %% [markdown]
# Run Cicero

# %%
human.hg38.genome = read.table(path.chrom.sizes,
                               header = F)
human.hg38.genome
# Out:
#     V1                     V2
# 1   chr1                   248956422
# 2   chr2                   242193529
# 3   chr3                   198295559
# 4   chr4                   190214555
# 5   chr5                   181538259
# 6   chr6                   170805979
# 7   chr7                   159345973
# 8   chr8                   145138636
# 9   chr9                   138394717
# 10  chr10                  133797422
# 11  chr11                  135086622
# 12  chr12                  133275309
# 13  chr13                  114364328
# 14  chr14                  107043718
# 15  chr15                  101991189
# 16  chr16                   90338345
# 17  chr17                   83257441
# 18  chr18                   80373285
# 19  chr19                   58617616
# 20  chr20                   64444167
# 21  chr21                   46709983
# 22  chr22                   50818468
# 23  chrX                   156040895
# 24  chrY                    57227415
# 25  chrM                       16569
# 26  chr1_GL383518v1_alt       182439
# 27  chr1_GL383519v1_alt       110268
# 28  chr1_GL383520v2_alt       366580
# 29  chr1_KI270706v1_random    175055
# 30  chr1_KI270707v1_random     32032
# ⋮   ⋮                      ⋮
# 427 chrUn_KI270579v1        31033
# 428 chrUn_KI270580v1         1553
# 429 chrUn_KI270581v1         7046
# 430 chrUn_KI270582v1         6504
# 431 chrUn_KI270583v1         1400
# 432 chrUn_KI270584v1         4513
# 433 chrUn_KI270587v1         2969
# 434 chrUn_KI270588v1         6158
# 435 chrUn_KI270589v1        44474
# 436 chrUn_KI270590v1         4685
# 437 chrUn_KI270591v1         5796
# 438 chrUn_KI270593v1         3041
# 439 chrUn_KI270741v1       157432
# 440 chrUn_KI270742v1       186739
# 441 chrUn_KI270743v1       210658
# 442 chrUn_KI270744v1       168472
# 443 chrUn_KI270745v1        41891
# 444 chrUn_KI270746v1        66486
# 445 chrUn_KI270747v1       198735
# 446 chrUn_KI270748v1        93321
# 447 chrUn_KI270749v1       158759
# 448 chrUn_KI270750v1       148850
# 449 chrUn_KI270751v1       150742
# 450 chrUn_KI270752v1        27745
# 451 chrUn_KI270753v1        62944
# 452 chrUn_KI270754v1        40191
# 453 chrUn_KI270755v1        36723
# 454 chrUn_KI270756v1        79590
# 455 chrUn_KI270757v1        71251
# 456 chrEBV                 171823

# %%
start_time <- Sys.time()
distance_parameters <- estimate_distance_parameter(cicero_cds, 
                                                   window = window, 
                                                   maxit = 100, 
                                                   sample_num = 100, 
                                                   distance_constraint = distance_constraint,
                                                   distance_parameter_convergence = 1e-22, 
                                                   genomic_coords = human.hg38.genome)
mean_distance_parameter <- mean(unlist(distance_parameters))
end_time <- Sys.time()
execution_time1 <- end_time - start_time

# %%
mean_distance_parameter
# Out:
# [1] 0.1664406

# %%
execution_time1
# Out:
# Time difference of 17.37929 mins

# %%
start_time <- Sys.time()
cicero_out <- generate_cicero_models(cicero_cds, 
                                     distance_parameter = mean_distance_parameter, 
                                     window = window, 
                                     genomic_coords = human.hg38.genome)
end_time <- Sys.time()
execution_time2 <- end_time - start_time

# %%
execution_time2
# Out:
# Time difference of 1.529042 hours

# %%
start_time <- Sys.time()
all_cons <- assemble_connections(cicero_out, 
                                 silent = FALSE)
end_time <- Sys.time()
execution_time3 <- end_time - start_time
# Out:
# [1] "Successful cicero models:  1460"
# [1] "Other models: "
#
#   Too many elements in range Zero or one element in range
#                         1287                          837
# [1] "Models with errors:  0"

# %%
execution_time3
# Out:
# Time difference of 40.12556 secs

# %% [markdown]
# Assign coaccess to E2G pairs

# %%
all_cons0 = all_cons
all_cons0[is.na(all_cons0[,"coaccess"]),"coaccess"] = 0
bed.peakinfo <- makeGRangesFromDataFrame(peakinfo, 
                                         keep.extra.columns = TRUE,
                                         start.field="bp1",
                                         end.field="bp2")
overlap.res = findOverlaps(bed.peakinfo[all_cons0[,"Peak1"]],
                           bed.TSS1kb)
df.overlap = as.data.frame(overlap.res)
all_cons0.E2G = all_cons0[df.overlap$queryHits,]
all_cons0.E2G[,"Gene"] = bed.TSS1kb[df.overlap$subjectHits]$V4
all_cons0.E2G[,"PairName"] = paste(all_cons0.E2G[,"Peak2"],all_cons0.E2G[,"Gene"],sep = "_")
all_cons0.E2G.sort = all_cons0.E2G[order(all_cons0.E2G[,"coaccess"],decreasing = T),]
all_cons0.E2G.uniq = all_cons0.E2G.sort[!duplicated(all_cons0.E2G.sort$PairName),]
rownames(all_cons0.E2G.uniq) = all_cons0.E2G.uniq$PairName
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% all_cons0.E2G.uniq$PairName]
pairs.E2G.res$coaccess = all_cons0.E2G.uniq[pairs.E2G.res$PairName,"coaccess"]

# %% [markdown]
# Save results

# %%
dir.create(dir.output,recursive = T)
saveRDS(all_cons,
        paste(dir.output,"all_cons.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "coaccess")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 534506 ranges and 4 metadata columns:
#            seqnames              ranges strand |  TargetGene
#               <Rle>           <IRanges>  <Rle> | <character>
#        [1]     chr1 101000038-101001294      * |        DPH5
#        [2]     chr1 101000038-101001294      * |       S1PR1
#        [3]     chr1 101002563-101003452      * |        DPH5
#        [4]     chr1 101002563-101003452      * |       S1PR1
#        [5]     chr1 101004010-101006276      * |        DPH5
#        ...      ...                 ...    ... .         ...
#   [534502]     chrX     9988628-9989100      * |       TBL1X
#   [534503]     chrX     9995615-9996434      * |     SHROOM2
#   [534504]     chrX     9995615-9996434      * |       TBL1X
#   [534505]     chrX     9997010-9998101      * |     SHROOM2
#   [534506]     chrX     9997010-9998101      * |       TBL1X
#                          PeakName               PairName   coaccess
#                       <character>            <character>  <numeric>
#        [1] chr1-101000038-10100.. chr1-101000038-10100.. -0.0426758
#        [2] chr1-101000038-10100.. chr1-101000038-10100.. -0.1136109
#        [3] chr1-101002563-10100.. chr1-101002563-10100.. -0.1376740
#        [4] chr1-101002563-10100.. chr1-101002563-10100.. -0.3081202
#        [5] chr1-101004010-10100.. chr1-101004010-10100.. -0.0820702
#        ...                    ...                    ...        ...
#   [534502]   chrX-9988628-9989100 chrX-9988628-9989100..  0.0000000
#   [534503]   chrX-9995615-9996434 chrX-9995615-9996434..  0.0000000
#   [534504]   chrX-9995615-9996434 chrX-9995615-9996434.. -0.0316794
#   [534505]   chrX-9997010-9998101 chrX-9997010-9998101..  0.0000000
#   [534506]   chrX-9997010-9998101 chrX-9997010-9998101..  0.0012155
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#        chr  start     end       TargetGene CellType coaccess
# 1      chr1 101000038 101001294 DPH5       K562     -0.042675778
# 2      chr1 101000038 101001294 S1PR1      K562     -0.113610937
# 3      chr1 101002563 101003452 DPH5       K562     -0.137674032
# 4      chr1 101002563 101003452 S1PR1      K562     -0.308120189
# 5      chr1 101004010 101006276 DPH5       K562     -0.082070153
# 6      chr1 101004010 101006276 S1PR1      K562     -0.222230597
# 7      chr1 101006586 101006993 DPH5       K562     -0.050437849
# 8      chr1 101006586 101006993 S1PR1      K562     -0.123074856
# 9      chr1 101016916 101017450 DPH5       K562     -0.042091161
# 10     chr1 101016916 101017450 S1PR1      K562     -0.082413347
# 11     chr1 101022399 101022580 DPH5       K562     -0.102660354
# 12     chr1 101022399 101022580 S1PR1      K562     -0.208642816
# 13     chr1 101025248 101026564 S1PR1      K562      0.336565637
# 14     chr1 101030937 101031344 DPH5       K562     -0.022096779
# 15     chr1 101030937 101031344 S1PR1      K562     -0.034077917
# 16     chr1 101035803 101036054 DPH5       K562      0.000000000
# 17     chr1 101035803 101036054 S1PR1      K562      0.000000000
# 18     chr1 101040579 101041727 DPH5       K562     -0.022305385
# 19     chr1 101040579 101041727 S1PR1      K562      0.076834177
# 20     chr1 101044309 101044693 DPH5       K562      0.000000000
# 21     chr1 101044309 101044693 S1PR1      K562      0.000000000
# 22     chr1 101050883 101051255 DPH5       K562     -0.002522712
# 23     chr1 101050883 101051255 S1PR1      K562      0.059832297
# 24     chr1 101051500 101052553 DPH5       K562     -0.009057932
# 25     chr1 101051500 101052553 S1PR1      K562      0.214831022
# 26     chr1 101052852 101053250 DPH5       K562     -0.003604442
# 27     chr1 101052852 101053250 S1PR1      K562      0.085488173
# 28     chr1 101059981 101060827 DPH5       K562     -0.019391356
# 29     chr1 101059981 101060827 S1PR1      K562     -0.060873193
# 30     chr1 101061976 101062183 DPH5       K562      0.000000000
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮
# 534477 chrX 9900578   9901123   TBL1X      K562      0.000000000
# 534478 chrX 9901278   9901585   TBL1X      K562      0.000000000
# 534479 chrX 9907571   9907909   TBL1X      K562      0.000000000
# 534480 chrX 9912433   9912622   TBL1X      K562      0.000000000
# 534481 chrX 9939963   9940261   TBL1X      K562     -0.013558924
# 534482 chrX 9940378   9941046   SHROOM2    K562      0.000000000
# 534483 chrX 9940378   9941046   TBL1X      K562     -0.021297477
# 534484 chrX 9941188   9941740   SHROOM2    K562      0.000000000
# 534485 chrX 9941188   9941740   TBL1X      K562      0.001628812
# 534486 chrX 9941865   9942829   SHROOM2    K562      0.000000000
# 534487 chrX 9941865   9942829   TBL1X      K562      0.028887202
# 534488 chrX 9943483   9943742   TBL1X      K562      0.007647239
# 534489 chrX 9948460   9948659   TBL1X      K562      0.000000000
# 534490 chrX 9953347   9953723   SHROOM2    K562      0.000000000
# 534491 chrX 9953347   9953723   TBL1X      K562      0.007076783
# 534492 chrX 9958190   9958752   SHROOM2    K562      0.000000000
# 534493 chrX 9958190   9958752   TBL1X      K562      0.000000000
# 534494 chrX 9961691   9962068   TBL1X      K562      0.000000000
# 534495 chrX 9980873   9982187   SHROOM2    K562      0.000000000
# 534496 chrX 9980873   9982187   TBL1X      K562      0.065669308
# 534497 chrX 9983489   9983743   TBL1X      K562      0.008122716
# 534498 chrX 9986538   9987289   SHROOM2    K562      0.000000000
# 534499 chrX 9986538   9987289   TBL1X      K562      0.051765446
# 534500 chrX 9987345   9987562   TBL1X      K562      0.020117541
# 534501 chrX 9988628   9989100   SHROOM2    K562      0.000000000
# 534502 chrX 9988628   9989100   TBL1X      K562      0.000000000
# 534503 chrX 9995615   9996434   SHROOM2    K562      0.000000000
# 534504 chrX 9995615   9996434   TBL1X      K562     -0.031679432
# 534505 chrX 9997010   9998101   SHROOM2    K562      0.000000000
# 534506 chrX 9997010   9998101   TBL1X      K562      0.001215505

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ggplot2_3.5.1               Matrix_1.6-5
#  [3] genomation_1.34.0           magrittr_2.0.3
#  [5] Signac_1.13.0               Seurat_5.0.3
#  [7] SeuratObject_5.0.1          sp_2.1-4
#  [9] cicero_1.3.9                Gviz_1.44.2
# [11] monocle3_1.3.7              SingleCellExperiment_1.22.0
# [13] SummarizedExperiment_1.30.2 GenomicRanges_1.54.1
# [15] GenomeInfoDb_1.38.1         IRanges_2.36.0
# [17] S4Vectors_0.40.2            MatrixGenerics_1.12.3
# [19] matrixStats_1.3.0           Biobase_2.60.0
# [21] BiocGenerics_0.48.1
#
# loaded via a namespace (and not attached):
#   [1] ProtGenerics_1.32.0      spatstat.sparse_3.0-3    bitops_1.0-7
#   [4] httr_1.4.7               RColorBrewer_1.1-3       repr_1.1.7
#   [7] tools_4.3.3              sctransform_0.4.1        backports_1.4.1
#  [10] utf8_1.2.4               R6_2.5.1                 uwot_0.1.16
#  [13] lazyeval_0.2.2           withr_3.0.0              prettyunits_1.2.0
#  [16] gridExtra_2.3            progressr_0.14.0         cli_3.6.2
#  [19] Cairo_1.6-2              spatstat.explore_3.2-6   fastDummies_1.7.3
#  [22] labeling_0.4.3           spatstat.data_3.0-4      readr_2.1.5
#  [25] ggridges_0.5.6           pbapply_1.7-2            Rsamtools_2.18.0
#  [28] pbdZMQ_0.3-11            foreign_0.8-86           dichromat_2.0-0.1
#  [31] parallelly_1.37.1        plotrix_3.8-4            BSgenome_1.68.0
#  [34] impute_1.76.0            VGAM_1.1-10              rstudioapi_0.16.0
#  [37] RSQLite_2.3.6            FNN_1.1.4                generics_0.1.3
#  [40] BiocIO_1.10.0            vroom_1.6.5              ica_1.0-3
#  [43] spatstat.random_3.2-3    dplyr_1.1.4              interp_1.1-6
#  [46] fansi_1.0.6              abind_1.4-5              lifecycle_1.0.4
#  [49] yaml_2.3.8               BiocFileCache_2.8.0      Rtsne_0.17
#  [52] blob_1.2.4               promises_1.3.0           crayon_1.5.2
#  [55] miniUI_0.1.1.1           lattice_0.22-6           cowplot_1.1.3
#  [58] GenomicFeatures_1.52.2   KEGGREST_1.40.1          pillar_1.9.0
#  [61] knitr_1.46               rjson_0.2.21             boot_1.3-30
#  [64] future.apply_1.11.2      codetools_0.2-20         fastmatch_1.1-4
#  [67] leiden_0.4.3.1           glue_1.7.0               data.table_1.15.2
#  [70] vctrs_0.6.5              png_0.1-8                spam_2.10-0
#  [73] gtable_0.3.5             assertthat_0.2.1         cachem_1.0.8
#  [76] xfun_0.43                S4Arrays_1.2.1           mime_0.12
#  [79] survival_3.6-4           RcppRoll_0.3.0           fitdistrplus_1.1-11
#  [82] ROCR_1.0-11              nlme_3.1-164             bit64_4.0.5
#  [85] progress_1.2.3           filelock_1.0.3           RcppAnnoy_0.0.22
#  [88] irlba_2.3.5.1            KernSmooth_2.23-22       rpart_4.1.23
#  [91] colorspace_2.1-0         DBI_1.2.2                Hmisc_5.1-2
#  [94] seqPattern_1.34.0        nnet_7.3-19              tidyselect_1.2.1
#  [97] bit_4.0.5                compiler_4.3.3           curl_5.1.0
# [100] htmlTable_2.4.2          xml2_1.3.6               DelayedArray_0.26.7
# [103] plotly_4.10.4            rtracklayer_1.60.1       checkmate_2.3.1
# [106] scales_1.3.0             lmtest_0.9-40            rappdirs_0.3.3
# [109] goftest_1.2-3            stringr_1.5.1            digest_0.6.35
# [112] spatstat.utils_3.0-4     minqa_1.2.6              rmarkdown_2.26
# [115] XVector_0.42.0           htmltools_0.5.8.1        pkgconfig_2.0.3
# [118] jpeg_0.1-10              base64enc_0.1-3          lme4_1.1-35.3
# [121] dbplyr_2.5.0             fastmap_1.1.1            ensembldb_2.24.1
# [124] rlang_1.1.3              htmlwidgets_1.6.4        shiny_1.8.1.1
# [127] farver_2.1.1             zoo_1.8-12               jsonlite_1.8.8
# [130] BiocParallel_1.36.0      VariantAnnotation_1.46.0 RCurl_1.98-1.14
# [133] Formula_1.2-5            GenomeInfoDbData_1.2.11  dotCall64_1.1-1
# [136] patchwork_1.2.0          IRkernel_1.3.2           munsell_0.5.1
# [139] Rcpp_1.0.12              reticulate_1.36.1        stringi_1.8.3
# [142] zlibbioc_1.48.0          MASS_7.3-60              plyr_1.8.9
# [145] parallel_4.3.3           listenv_0.9.1            ggrepel_0.9.5
# [148] deldir_2.0-4             Biostrings_2.70.1        IRdisplay_1.1
# [151] splines_4.3.3            tensor_1.5               hms_1.1.3
# [154] igraph_2.0.3             uuid_1.2-0               spatstat.geom_3.2-9
# [157] RcppHNSW_0.6.0           reshape2_1.4.4           biomaRt_2.56.1
# [160] XML_3.99-0.16.1          evaluate_0.23            latticeExtra_0.6-30
# [163] biovizBase_1.48.0        tzdb_0.4.0               nloptr_2.0.3
# [166] httpuv_1.6.15            RANN_2.6.1               tidyr_1.3.1
# [169] purrr_1.0.2              polyclip_1.10-6          future_1.33.2
# [172] scattermore_1.2          gridBase_0.4-7           xtable_1.8-4
# [175] restfulr_0.0.15          AnnotationFilter_1.24.0  RSpectra_0.16-1
# [178] later_1.3.2              glasso_1.11              viridisLite_0.4.2
# [181] tibble_3.2.1             memoise_2.0.1            AnnotationDbi_1.64.1
# [184] GenomicAlignments_1.36.0 cluster_2.1.6            globals_0.16.3
