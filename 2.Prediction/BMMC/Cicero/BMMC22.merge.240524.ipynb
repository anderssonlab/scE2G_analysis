# %%
library(cicero)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
# Loading required package: monocle3
#
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘monocle3’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     exprs, fData, fData<-, pData, pData<-
#
#
# Loading required package: Gviz
#
# Loading required package: grid
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'sp'
#
#
# The following object is masked from 'package:IRanges':
#
#     %over%
#
#
# 'SeuratObject' was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall 'SeuratObject' as the ABI
# for R may have changed
#
# 'SeuratObject' was built with package 'Matrix' 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     intersect
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following object is masked from 'package:IRanges':
#
#     intersect
#
#
# The following object is masked from 'package:S4Vectors':
#
#     intersect
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     intersect
#
#
# The following object is masked from 'package:base':
#
#     intersect
#
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     subtract
#
#
# Warning message:
# "replacing previous import 'Biostrings::pattern' by 'grid::pattern' when loading 'genomation'"
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/4.merge_peaks_from_22_cell_types.240523/obj.seurat.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/4.merge_peaks_from_22_cell_types.240523/matrix.atac.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/1.prepare_data/4.merge_peaks_from_22_cell_types.240523/pairs.rds"
path.TSS1kb = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Xu/K562/Neighborhoods/GeneList.TSS1kb.bed"
path.chrom.sizes = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/ENCODE_rE2G/ABC/reference/hg38/GRCh38_EBV.chrom.sizes.tsv"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/Cicero/BMMC22.merge.240524/"

# %%
distance_constraint = 1000000 
window = 2000000

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac_count = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac_count)
rm(matrix.atac_count)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readRDS(path.pairs.E2G)

# %% [markdown]
# Import TSS1kb regions

# %%
bed.TSS1kb = readGeneric(path.TSS1kb,
                         header = F,
                         keep.all.metadata = T)
bed.TSS1kb
# Out:
# GRanges object with 20666 ranges and 3 metadata columns:
#           seqnames            ranges strand |          V4        V5          V6
#              <Rle>         <IRanges>  <Rle> | <character> <integer> <character>
#       [1]     chr1       35581-36581      * |     FAM138A         0           -
#       [2]     chr1       35581-36581      * |     FAM138F         0           -
#       [3]     chr1       68590-69590      * |       OR4F5         0           +
#       [4]     chr1     816870-817870      * |      FAM87B         0           +
#       [5]     chr1     827022-828022      * |   LINC00115         0           -
#       ...      ...               ...    ... .         ...       ...         ...
#   [20662]     chrY 21385860-21386860      * |       PRORY         0           -
#   [20663]     chrY 21594166-21595166      * |      TTTY13         0           -
#   [20664]     chrY 22298376-22299376      * |       TTTY5         0           -
#   [20665]     chrY 23198592-23199592      * |        DAZ1         0           -
#   [20666]     chrY 23218956-23219956      * |        DAZ2         0           +
#   -------
#   seqinfo: 24 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Create a Cicero CDS

# %%
cellinfo = obj.seurat@meta.data
cellinfo[,"cell"] = cellinfo[,"sample_barcode"]
cellinfo
# Out:
#                         orig.ident nCount_RNA nFeature_RNA barcode
# s1d1_TAGTTGTCACCCTCAC-1 s1d1        1701      1121         TAGTTGTCACCCTCAC-1
# s1d1_CTATGGCCATAACGGG-1 s1d1        2157      1277         CTATGGCCATAACGGG-1
# s1d1_CCGCACACAGGTTAAA-1 s1d1        8311      3589         CCGCACACAGGTTAAA-1
# s1d1_TCATTTGGTAATGGAA-1 s1d1        1291       887         TCATTTGGTAATGGAA-1
# s1d1_ACCACATAGGTGTCCA-1 s1d1        2128      1337         ACCACATAGGTGTCCA-1
# s1d1_TGGATTGGTTTGCGAA-1 s1d1       16740      4729         TGGATTGGTTTGCGAA-1
# s1d1_GTGAGCGAGTAAAGGT-1 s1d1        4396      2382         GTGAGCGAGTAAAGGT-1
# s1d1_GACTTAGGTTGCGCGA-1 s1d1        1182       876         GACTTAGGTTGCGCGA-1
# s1d1_GCCTTACTCGTTACAA-1 s1d1       10154      4021         GCCTTACTCGTTACAA-1
# s1d1_GTAAGGTCAATAACCT-1 s1d1        2041      1264         GTAAGGTCAATAACCT-1
# s1d1_AGCGCCTAGATGGACA-1 s1d1        2307      1210         AGCGCCTAGATGGACA-1
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1        1920      1227         TGCCGGTAGTCGCAAT-1
# s1d1_CCTGAATAGCTTGCTC-1 s1d1        3907      1408         CCTGAATAGCTTGCTC-1
# s1d1_CATCCCAGTCTTTATG-1 s1d1        3211      1670         CATCCCAGTCTTTATG-1
# s1d1_GGCTGAGAGTATTGCA-1 s1d1        2159      1063         GGCTGAGAGTATTGCA-1
# s1d1_TAGTGAGAGCTGCACA-1 s1d1        3568      1984         TAGTGAGAGCTGCACA-1
# s1d1_TTACCTGTCTATGACA-1 s1d1        2445      1521         TTACCTGTCTATGACA-1
# s1d1_GGATTATGTTACATCC-1 s1d1        5014      2443         GGATTATGTTACATCC-1
# s1d1_CCTGTTGGTTATAGCG-1 s1d1        4044      2074         CCTGTTGGTTATAGCG-1
# s1d1_GGCAATCGTTAGGACC-1 s1d1        1154       417         GGCAATCGTTAGGACC-1
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1        2728      1514         TTTAGCTTCTGGCTTC-1
# s1d1_AACGACAAGTTGTCAA-1 s1d1        1477       999         AACGACAAGTTGTCAA-1
# s1d1_AGCAATACAATATGGA-1 s1d1        2295      1258         AGCAATACAATATGGA-1
# s1d1_AATTTGCCATAATGAG-1 s1d1        2825      1684         AATTTGCCATAATGAG-1
# s1d1_AGTTATGTCTCACTCA-1 s1d1        1534       360         AGTTATGTCTCACTCA-1
# s1d1_TGTCCTGGTCAATGTG-1 s1d1        1844      1195         TGTCCTGGTCAATGTG-1
# s1d1_TGTATCGCAGCTCATA-1 s1d1        1262       873         TGTATCGCAGCTCATA-1
# s1d1_GTTTGTCGTGAATCGC-1 s1d1        6050      1741         GTTTGTCGTGAATCGC-1
# s1d1_CCAGGAACAATGCGCT-1 s1d1        1303       874         CCAGGAACAATGCGCT-1
# s1d1_AGAATCGAGAAAGGAA-1 s1d1        4293      2318         AGAATCGAGAAAGGAA-1
# ⋮                       ⋮          ⋮          ⋮            ⋮
# s4d9_ATGTTCAAGTTATTCC-1 s4d9        869        601         ATGTTCAAGTTATTCC-1
# s4d9_CCAGGATGTATTCGTC-1 s4d9        802        507         CCAGGATGTATTCGTC-1
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9        793        579         CTTCAAGCAAAGCGCA-1
# s4d9_ACGAAGTCACGAACAG-1 s4d9        795        576         ACGAAGTCACGAACAG-1
# s4d9_GGTCCGTAGCACAGAA-1 s4d9       1239        894         GGTCCGTAGCACAGAA-1
# s4d9_GGTTGACGTGAGAAAC-1 s4d9        857        625         GGTTGACGTGAGAAAC-1
# s4d9_GCTTTACGTATTCGCT-1 s4d9        905        627         GCTTTACGTATTCGCT-1
# s4d9_GATTACTCACCTAAGC-1 s4d9       2609       1611         GATTACTCACCTAAGC-1
# s4d9_TCAAGCTAGCACCACA-1 s4d9        822        663         TCAAGCTAGCACCACA-1
# s4d9_GGTCAATTCGATTATG-1 s4d9       1553        999         GGTCAATTCGATTATG-1
# s4d9_ATGACAACATGAATAG-1 s4d9       1590       1043         ATGACAACATGAATAG-1
# s4d9_TAGCCGGGTAATAGCT-1 s4d9       2699       1506         TAGCCGGGTAATAGCT-1
# s4d9_TACCTCATCATGCGTG-1 s4d9        995        686         TACCTCATCATGCGTG-1
# s4d9_CAAGCTAGTCAACAAT-1 s4d9       1664       1053         CAAGCTAGTCAACAAT-1
# s4d9_TATGGCCCAGGCTACT-1 s4d9       1122        727         TATGGCCCAGGCTACT-1
# s4d9_ACAGGTAAGGTTACGT-1 s4d9       1221        849         ACAGGTAAGGTTACGT-1
# s4d9_TGTGGAGCAGAAATGC-1 s4d9        569        434         TGTGGAGCAGAAATGC-1
# s4d9_GGTTTAATCTATGACA-1 s4d9       3206       1769         GGTTTAATCTATGACA-1
# s4d9_ACTAATCCAGCAAGAT-1 s4d9       1003        707         ACTAATCCAGCAAGAT-1
# s4d9_TAGTGAGAGCACAGGG-1 s4d9        723        529         TAGTGAGAGCACAGGG-1
# s4d9_AGCATCCCACAGAACG-1 s4d9        895        618         AGCATCCCACAGAACG-1
# s4d9_ATTGAAGCACATTGCA-1 s4d9        607        490         ATTGAAGCACATTGCA-1
# s4d9_CTATTCAGTTGTGATG-1 s4d9       1018        713         CTATTCAGTTGTGATG-1
# s4d9_TGAACAACAGTGAACG-1 s4d9        705        502         TGAACAACAGTGAACG-1
# s4d9_CGATTCCTCCTGGCTT-1 s4d9        884        671         CGATTCCTCCTGGCTT-1
# s4d9_AAACCGCGTTTGAGGC-1 s4d9        777        557         AAACCGCGTTTGAGGC-1
# s4d9_TGACTTAAGTTCCCGT-1 s4d9       1025        717         TGACTTAAGTTCCCGT-1
# s4d9_GCTGTACCACCGTTCC-1 s4d9        740        527         GCTGTACCACCGTTCC-1
# s4d9_ACACTTGCAACTAGAA-1 s4d9       1449        956         ACACTTGCAACTAGAA-1
# s4d9_CACTTAAAGTCTGGGC-1 s4d9        889        638         CACTTAAAGTCTGGGC-1
#                         gex_barcode        atac_barcode       is_cell
# s1d1_TAGTTGTCACCCTCAC-1 TAGTTGTCACCCTCAC-1 GGACAACGTAAGTGGC-1 1
# s1d1_CTATGGCCATAACGGG-1 CTATGGCCATAACGGG-1 CAACCTGGTCCTCCCA-1 1
# s1d1_CCGCACACAGGTTAAA-1 CCGCACACAGGTTAAA-1 GAACCGGGTTAACACC-1 1
# s1d1_TCATTTGGTAATGGAA-1 TCATTTGGTAATGGAA-1 CCGCAAGCAGGTTCTT-1 1
# s1d1_ACCACATAGGTGTCCA-1 ACCACATAGGTGTCCA-1 GGTTACCTCCTCACGG-1 1
# s1d1_TGGATTGGTTTGCGAA-1 TGGATTGGTTTGCGAA-1 CAACATGCACCTGGCT-1 1
# s1d1_GTGAGCGAGTAAAGGT-1 GTGAGCGAGTAAAGGT-1 TAAAGCATCTAAGCGG-1 1
# s1d1_GACTTAGGTTGCGCGA-1 GACTTAGGTTGCGCGA-1 TTAGGATCACTAGCTT-1 1
# s1d1_GCCTTACTCGTTACAA-1 GCCTTACTCGTTACAA-1 CTAGCCTAGTGCAACG-1 1
# s1d1_GTAAGGTCAATAACCT-1 GTAAGGTCAATAACCT-1 TCAACCGGTCGAGGCA-1 1
# s1d1_AGCGCCTAGATGGACA-1 AGCGCCTAGATGGACA-1 ATGTTGTTCTCAAGAA-1 1
# s1d1_TGCCGGTAGTCGCAAT-1 TGCCGGTAGTCGCAAT-1 ACCAACCTCAGGCCAA-1 1
# s1d1_CCTGAATAGCTTGCTC-1 CCTGAATAGCTTGCTC-1 CGGTGAATCCTAATCG-1 1
# s1d1_CATCCCAGTCTTTATG-1 CATCCCAGTCTTTATG-1 CAGCTAACAGGCCTCT-1 1
# s1d1_GGCTGAGAGTATTGCA-1 GGCTGAGAGTATTGCA-1 CCGTTCCTCCAGCTCG-1 1
# s1d1_TAGTGAGAGCTGCACA-1 TAGTGAGAGCTGCACA-1 GTGGCTTTCGCATTTG-1 1
# s1d1_TTACCTGTCTATGACA-1 TTACCTGTCTATGACA-1 TTCAGTTAGTTACGAA-1 1
# s1d1_GGATTATGTTACATCC-1 GGATTATGTTACATCC-1 CGTTACTCAACAACAT-1 1
# s1d1_CCTGTTGGTTATAGCG-1 CCTGTTGGTTATAGCG-1 GTTTGAGCATTCAGGA-1 1
# s1d1_GGCAATCGTTAGGACC-1 GGCAATCGTTAGGACC-1 GGTCCCTCACGCTAGG-1 1
# s1d1_TTTAGCTTCTGGCTTC-1 TTTAGCTTCTGGCTTC-1 GCTGATGAGTCAGGAT-1 1
# s1d1_AACGACAAGTTGTCAA-1 AACGACAAGTTGTCAA-1 CAAGGTGTCACCTGGT-1 1
# s1d1_AGCAATACAATATGGA-1 AGCAATACAATATGGA-1 AAGACCAGTGCAATAG-1 1
# s1d1_AATTTGCCATAATGAG-1 AATTTGCCATAATGAG-1 CGTAAAGGTCCCAGAC-1 1
# s1d1_AGTTATGTCTCACTCA-1 AGTTATGTCTCACTCA-1 CACGGTAAGCCTTTCT-1 1
# s1d1_TGTCCTGGTCAATGTG-1 TGTCCTGGTCAATGTG-1 ACAGCACCACCTGTAT-1 1
# s1d1_TGTATCGCAGCTCATA-1 TGTATCGCAGCTCATA-1 TCGATTAGTTCAAGCT-1 1
# s1d1_GTTTGTCGTGAATCGC-1 GTTTGTCGTGAATCGC-1 AAGGAACCAAATACCG-1 1
# s1d1_CCAGGAACAATGCGCT-1 CCAGGAACAATGCGCT-1 GCGGTAGGTTTCACCC-1 1
# s1d1_AGAATCGAGAAAGGAA-1 AGAATCGAGAAAGGAA-1 ATGTGCCTCACTCGCG-1 1
# ⋮                       ⋮                  ⋮                  ⋮
# s4d9_ATGTTCAAGTTATTCC-1 ATGTTCAAGTTATTCC-1 AAACTAGTCATGAAGC-1 1
# s4d9_CCAGGATGTATTCGTC-1 CCAGGATGTATTCGTC-1 GCTTGAACACTAATCC-1 1
# s4d9_CTTCAAGCAAAGCGCA-1 CTTCAAGCAAAGCGCA-1 CCATTAAGTTGCTCCT-1 1
# s4d9_ACGAAGTCACGAACAG-1 ACGAAGTCACGAACAG-1 AAGGCTAGTCACACTG-1 1
# s4d9_GGTCCGTAGCACAGAA-1 GGTCCGTAGCACAGAA-1 TCGCTAATCTTAAGGA-1 1
# s4d9_GGTTGACGTGAGAAAC-1 GGTTGACGTGAGAAAC-1 CTGCAGGCAAACGCGT-1 1
# s4d9_GCTTTACGTATTCGCT-1 GCTTTACGTATTCGCT-1 CCTGAAACAGGATGGA-1 1
# s4d9_GATTACTCACCTAAGC-1 GATTACTCACCTAAGC-1 ATGCTTAGTATCGCTG-1 1
# s4d9_TCAAGCTAGCACCACA-1 TCAAGCTAGCACCACA-1 TATATGCTCTAACTGT-1 1
# s4d9_GGTCAATTCGATTATG-1 GGTCAATTCGATTATG-1 CTGAGCAAGGAACAAG-1 1
# s4d9_ATGACAACATGAATAG-1 ATGACAACATGAATAG-1 GCTTAACGTTATCCGG-1 1
# s4d9_TAGCCGGGTAATAGCT-1 TAGCCGGGTAATAGCT-1 TACCGCCCATGAGCCG-1 1
# s4d9_TACCTCATCATGCGTG-1 TACCTCATCATGCGTG-1 ATAGTCAAGCTAATCT-1 1
# s4d9_CAAGCTAGTCAACAAT-1 CAAGCTAGTCAACAAT-1 CTTATTGCACTAAGCA-1 1
# s4d9_TATGGCCCAGGCTACT-1 TATGGCCCAGGCTACT-1 AAAGGAAGTTTGTAGC-1 1
# s4d9_ACAGGTAAGGTTACGT-1 ACAGGTAAGGTTACGT-1 GCCTTAATCTAATCCG-1 1
# s4d9_TGTGGAGCAGAAATGC-1 TGTGGAGCAGAAATGC-1 CCTTAAAGTTATGGGA-1 1
# s4d9_GGTTTAATCTATGACA-1 GGTTTAATCTATGACA-1 TGTGGTGAGTTACGAA-1 1
# s4d9_ACTAATCCAGCAAGAT-1 ACTAATCCAGCAAGAT-1 CGCTAATGTTTACTGA-1 1
# s4d9_TAGTGAGAGCACAGGG-1 TAGTGAGAGCACAGGG-1 GTGGCTTTCCAATTGT-1 1
# s4d9_AGCATCCCACAGAACG-1 AGCATCCCACAGAACG-1 GGCTTGCGTATTCAGC-1 1
# s4d9_ATTGAAGCACATTGCA-1 ATTGAAGCACATTGCA-1 GGTTCGCGTTAAGTGG-1 1
# s4d9_CTATTCAGTTGTGATG-1 CTATTCAGTTGTGATG-1 TTCCGGCCAAGTCCTT-1 1
# s4d9_TGAACAACAGTGAACG-1 TGAACAACAGTGAACG-1 CTGAATCGTATGTTGC-1 1
# s4d9_CGATTCCTCCTGGCTT-1 CGATTCCTCCTGGCTT-1 GCTCGTTAGTCACTCA-1 1
# s4d9_AAACCGCGTTTGAGGC-1 AAACCGCGTTTGAGGC-1 AATAGCTCACCAAAGC-1 1
# s4d9_TGACTTAAGTTCCCGT-1 TGACTTAAGTTCCCGT-1 GAACGATTCCTAATGT-1 1
# s4d9_GCTGTACCACCGTTCC-1 GCTGTACCACCGTTCC-1 AAGTGGCGTTAGTGCT-1 1
# s4d9_ACACTTGCAACTAGAA-1 ACACTTGCAACTAGAA-1 TAGTGAGGTTAACTGC-1 1
# s4d9_CACTTAAAGTCTGGGC-1 CACTTAAAGTCTGGGC-1 GGTGTGATCCCAGTAC-1 1
#                         excluded_reason gex_raw_reads gex_mapped_reads ⋯
# s1d1_TAGTTGTCACCCTCAC-1 0                13548         13091           ⋯
# s1d1_CTATGGCCATAACGGG-1 0                12415         11865           ⋯
# s1d1_CCGCACACAGGTTAAA-1 0                64631         62125           ⋯
# s1d1_TCATTTGGTAATGGAA-1 0                 8873          8544           ⋯
# s1d1_ACCACATAGGTGTCCA-1 0                14880         14353           ⋯
# s1d1_TGGATTGGTTTGCGAA-1 0               126119        122017           ⋯
# s1d1_GTGAGCGAGTAAAGGT-1 0                29874         28904           ⋯
# s1d1_GACTTAGGTTGCGCGA-1 0                 8982          8675           ⋯
# s1d1_GCCTTACTCGTTACAA-1 0                69068         65936           ⋯
# s1d1_GTAAGGTCAATAACCT-1 0                16490         15900           ⋯
# s1d1_AGCGCCTAGATGGACA-1 0                15889         15317           ⋯
# s1d1_TGCCGGTAGTCGCAAT-1 0                12074         11538           ⋯
# s1d1_CCTGAATAGCTTGCTC-1 0                27563         26717           ⋯
# s1d1_CATCCCAGTCTTTATG-1 0                20421         19551           ⋯
# s1d1_GGCTGAGAGTATTGCA-1 0                16109         15620           ⋯
# s1d1_TAGTGAGAGCTGCACA-1 0                24146         23110           ⋯
# s1d1_TTACCTGTCTATGACA-1 0                18479         17814           ⋯
# s1d1_GGATTATGTTACATCC-1 0                35911         34851           ⋯
# s1d1_CCTGTTGGTTATAGCG-1 0                25163         24266           ⋯
# s1d1_GGCAATCGTTAGGACC-1 0                 8963          8601           ⋯
# s1d1_TTTAGCTTCTGGCTTC-1 0                21335         20249           ⋯
# s1d1_AACGACAAGTTGTCAA-1 0                12149         11701           ⋯
# s1d1_AGCAATACAATATGGA-1 0                17987         17425           ⋯
# s1d1_AATTTGCCATAATGAG-1 0                20918         20272           ⋯
# s1d1_AGTTATGTCTCACTCA-1 0                10588         10305           ⋯
# s1d1_TGTCCTGGTCAATGTG-1 0                12780         12312           ⋯
# s1d1_TGTATCGCAGCTCATA-1 0                 9368          9087           ⋯
# s1d1_GTTTGTCGTGAATCGC-1 0                42260         40991           ⋯
# s1d1_CCAGGAACAATGCGCT-1 0                10546         10117           ⋯
# s1d1_AGAATCGAGAAAGGAA-1 0                36170         34940           ⋯
# ⋮                       ⋮               ⋮             ⋮                ⋱
# s4d9_ATGTTCAAGTTATTCC-1 0               24251         22736            ⋯
# s4d9_CCAGGATGTATTCGTC-1 0               18261         17154            ⋯
# s4d9_CTTCAAGCAAAGCGCA-1 0               15635         14655            ⋯
# s4d9_ACGAAGTCACGAACAG-1 0               18106         16888            ⋯
# s4d9_GGTCCGTAGCACAGAA-1 0               24762         23304            ⋯
# s4d9_GGTTGACGTGAGAAAC-1 0               14983         14001            ⋯
# s4d9_GCTTTACGTATTCGCT-1 0               18647         17498            ⋯
# s4d9_GATTACTCACCTAAGC-1 0               58782         55108            ⋯
# s4d9_TCAAGCTAGCACCACA-1 0               18776         17603            ⋯
# s4d9_GGTCAATTCGATTATG-1 0               33367         31403            ⋯
# s4d9_ATGACAACATGAATAG-1 0               39303         36731            ⋯
# s4d9_TAGCCGGGTAATAGCT-1 0               59786         56144            ⋯
# s4d9_TACCTCATCATGCGTG-1 0               26143         24507            ⋯
# s4d9_CAAGCTAGTCAACAAT-1 0               38048         35481            ⋯
# s4d9_TATGGCCCAGGCTACT-1 0               23914         22412            ⋯
# s4d9_ACAGGTAAGGTTACGT-1 0               24786         23162            ⋯
# s4d9_TGTGGAGCAGAAATGC-1 0               10996         10398            ⋯
# s4d9_GGTTTAATCTATGACA-1 0               65199         61191            ⋯
# s4d9_ACTAATCCAGCAAGAT-1 0               23201         21704            ⋯
# s4d9_TAGTGAGAGCACAGGG-1 0               15134         14205            ⋯
# s4d9_AGCATCCCACAGAACG-1 0               19724         18503            ⋯
# s4d9_ATTGAAGCACATTGCA-1 0               17561         16154            ⋯
# s4d9_CTATTCAGTTGTGATG-1 0               23396         21772            ⋯
# s4d9_TGAACAACAGTGAACG-1 0               15775         14756            ⋯
# s4d9_CGATTCCTCCTGGCTT-1 0               15990         14851            ⋯
# s4d9_AAACCGCGTTTGAGGC-1 0               17517         16536            ⋯
# s4d9_TGACTTAAGTTCCCGT-1 0               19505         18447            ⋯
# s4d9_GCTGTACCACCGTTCC-1 0               15921         14931            ⋯
# s4d9_ACACTTGCAACTAGAA-1 0               24183         22660            ⋯
# s4d9_CACTTAAAGTCTGGGC-1 0               19433         18214            ⋯
#                         DonorGender QCMeds DonorSmoker rename
# s1d1_TAGTTGTCACCCTCAC-1 Male        False  Nonsmoker   s1d1_TAGTTGTCACCCTCAC-1
# s1d1_CTATGGCCATAACGGG-1 Male        False  Nonsmoker   s1d1_CTATGGCCATAACGGG-1
# s1d1_CCGCACACAGGTTAAA-1 Male        False  Nonsmoker   s1d1_CCGCACACAGGTTAAA-1
# s1d1_TCATTTGGTAATGGAA-1 Male        False  Nonsmoker   s1d1_TCATTTGGTAATGGAA-1
# s1d1_ACCACATAGGTGTCCA-1 Male        False  Nonsmoker   s1d1_ACCACATAGGTGTCCA-1
# s1d1_TGGATTGGTTTGCGAA-1 Male        False  Nonsmoker   s1d1_TGGATTGGTTTGCGAA-1
# s1d1_GTGAGCGAGTAAAGGT-1 Male        False  Nonsmoker   s1d1_GTGAGCGAGTAAAGGT-1
# s1d1_GACTTAGGTTGCGCGA-1 Male        False  Nonsmoker   s1d1_GACTTAGGTTGCGCGA-1
# s1d1_GCCTTACTCGTTACAA-1 Male        False  Nonsmoker   s1d1_GCCTTACTCGTTACAA-1
# s1d1_GTAAGGTCAATAACCT-1 Male        False  Nonsmoker   s1d1_GTAAGGTCAATAACCT-1
# s1d1_AGCGCCTAGATGGACA-1 Male        False  Nonsmoker   s1d1_AGCGCCTAGATGGACA-1
# s1d1_TGCCGGTAGTCGCAAT-1 Male        False  Nonsmoker   s1d1_TGCCGGTAGTCGCAAT-1
# s1d1_CCTGAATAGCTTGCTC-1 Male        False  Nonsmoker   s1d1_CCTGAATAGCTTGCTC-1
# s1d1_CATCCCAGTCTTTATG-1 Male        False  Nonsmoker   s1d1_CATCCCAGTCTTTATG-1
# s1d1_GGCTGAGAGTATTGCA-1 Male        False  Nonsmoker   s1d1_GGCTGAGAGTATTGCA-1
# s1d1_TAGTGAGAGCTGCACA-1 Male        False  Nonsmoker   s1d1_TAGTGAGAGCTGCACA-1
# s1d1_TTACCTGTCTATGACA-1 Male        False  Nonsmoker   s1d1_TTACCTGTCTATGACA-1
# s1d1_GGATTATGTTACATCC-1 Male        False  Nonsmoker   s1d1_GGATTATGTTACATCC-1
# s1d1_CCTGTTGGTTATAGCG-1 Male        False  Nonsmoker   s1d1_CCTGTTGGTTATAGCG-1
# s1d1_GGCAATCGTTAGGACC-1 Male        False  Nonsmoker   s1d1_GGCAATCGTTAGGACC-1
# s1d1_TTTAGCTTCTGGCTTC-1 Male        False  Nonsmoker   s1d1_TTTAGCTTCTGGCTTC-1
# s1d1_AACGACAAGTTGTCAA-1 Male        False  Nonsmoker   s1d1_AACGACAAGTTGTCAA-1
# s1d1_AGCAATACAATATGGA-1 Male        False  Nonsmoker   s1d1_AGCAATACAATATGGA-1
# s1d1_AATTTGCCATAATGAG-1 Male        False  Nonsmoker   s1d1_AATTTGCCATAATGAG-1
# s1d1_AGTTATGTCTCACTCA-1 Male        False  Nonsmoker   s1d1_AGTTATGTCTCACTCA-1
# s1d1_TGTCCTGGTCAATGTG-1 Male        False  Nonsmoker   s1d1_TGTCCTGGTCAATGTG-1
# s1d1_TGTATCGCAGCTCATA-1 Male        False  Nonsmoker   s1d1_TGTATCGCAGCTCATA-1
# s1d1_GTTTGTCGTGAATCGC-1 Male        False  Nonsmoker   s1d1_GTTTGTCGTGAATCGC-1
# s1d1_CCAGGAACAATGCGCT-1 Male        False  Nonsmoker   s1d1_CCAGGAACAATGCGCT-1
# s1d1_AGAATCGAGAAAGGAA-1 Male        False  Nonsmoker   s1d1_AGAATCGAGAAAGGAA-1
# ⋮                       ⋮           ⋮      ⋮           ⋮
# s4d9_ATGTTCAAGTTATTCC-1 Male        False  Nonsmoker   s4d9_ATGTTCAAGTTATTCC-1
# s4d9_CCAGGATGTATTCGTC-1 Male        False  Nonsmoker   s4d9_CCAGGATGTATTCGTC-1
# s4d9_CTTCAAGCAAAGCGCA-1 Male        False  Nonsmoker   s4d9_CTTCAAGCAAAGCGCA-1
# s4d9_ACGAAGTCACGAACAG-1 Male        False  Nonsmoker   s4d9_ACGAAGTCACGAACAG-1
# s4d9_GGTCCGTAGCACAGAA-1 Male        False  Nonsmoker   s4d9_GGTCCGTAGCACAGAA-1
# s4d9_GGTTGACGTGAGAAAC-1 Male        False  Nonsmoker   s4d9_GGTTGACGTGAGAAAC-1
# s4d9_GCTTTACGTATTCGCT-1 Male        False  Nonsmoker   s4d9_GCTTTACGTATTCGCT-1
# s4d9_GATTACTCACCTAAGC-1 Male        False  Nonsmoker   s4d9_GATTACTCACCTAAGC-1
# s4d9_TCAAGCTAGCACCACA-1 Male        False  Nonsmoker   s4d9_TCAAGCTAGCACCACA-1
# s4d9_GGTCAATTCGATTATG-1 Male        False  Nonsmoker   s4d9_GGTCAATTCGATTATG-1
# s4d9_ATGACAACATGAATAG-1 Male        False  Nonsmoker   s4d9_ATGACAACATGAATAG-1
# s4d9_TAGCCGGGTAATAGCT-1 Male        False  Nonsmoker   s4d9_TAGCCGGGTAATAGCT-1
# s4d9_TACCTCATCATGCGTG-1 Male        False  Nonsmoker   s4d9_TACCTCATCATGCGTG-1
# s4d9_CAAGCTAGTCAACAAT-1 Male        False  Nonsmoker   s4d9_CAAGCTAGTCAACAAT-1
# s4d9_TATGGCCCAGGCTACT-1 Male        False  Nonsmoker   s4d9_TATGGCCCAGGCTACT-1
# s4d9_ACAGGTAAGGTTACGT-1 Male        False  Nonsmoker   s4d9_ACAGGTAAGGTTACGT-1
# s4d9_TGTGGAGCAGAAATGC-1 Male        False  Nonsmoker   s4d9_TGTGGAGCAGAAATGC-1
# s4d9_GGTTTAATCTATGACA-1 Male        False  Nonsmoker   s4d9_GGTTTAATCTATGACA-1
# s4d9_ACTAATCCAGCAAGAT-1 Male        False  Nonsmoker   s4d9_ACTAATCCAGCAAGAT-1
# s4d9_TAGTGAGAGCACAGGG-1 Male        False  Nonsmoker   s4d9_TAGTGAGAGCACAGGG-1
# s4d9_AGCATCCCACAGAACG-1 Male        False  Nonsmoker   s4d9_AGCATCCCACAGAACG-1
# s4d9_ATTGAAGCACATTGCA-1 Male        False  Nonsmoker   s4d9_ATTGAAGCACATTGCA-1
# s4d9_CTATTCAGTTGTGATG-1 Male        False  Nonsmoker   s4d9_CTATTCAGTTGTGATG-1
# s4d9_TGAACAACAGTGAACG-1 Male        False  Nonsmoker   s4d9_TGAACAACAGTGAACG-1
# s4d9_CGATTCCTCCTGGCTT-1 Male        False  Nonsmoker   s4d9_CGATTCCTCCTGGCTT-1
# s4d9_AAACCGCGTTTGAGGC-1 Male        False  Nonsmoker   s4d9_AAACCGCGTTTGAGGC-1
# s4d9_TGACTTAAGTTCCCGT-1 Male        False  Nonsmoker   s4d9_TGACTTAAGTTCCCGT-1
# s4d9_GCTGTACCACCGTTCC-1 Male        False  Nonsmoker   s4d9_GCTGTACCACCGTTCC-1
# s4d9_ACACTTGCAACTAGAA-1 Male        False  Nonsmoker   s4d9_ACACTTGCAACTAGAA-1
# s4d9_CACTTAAAGTCTGGGC-1 Male        False  Nonsmoker   s4d9_CACTTAAAGTCTGGGC-1
#                         nCount_ATAC_empty nFeature_ATAC_empty
# s1d1_TAGTTGTCACCCTCAC-1 0                 0
# s1d1_CTATGGCCATAACGGG-1 0                 0
# s1d1_CCGCACACAGGTTAAA-1 0                 0
# s1d1_TCATTTGGTAATGGAA-1 0                 0
# s1d1_ACCACATAGGTGTCCA-1 0                 0
# s1d1_TGGATTGGTTTGCGAA-1 0                 0
# s1d1_GTGAGCGAGTAAAGGT-1 0                 0
# s1d1_GACTTAGGTTGCGCGA-1 0                 0
# s1d1_GCCTTACTCGTTACAA-1 0                 0
# s1d1_GTAAGGTCAATAACCT-1 0                 0
# s1d1_AGCGCCTAGATGGACA-1 0                 0
# s1d1_TGCCGGTAGTCGCAAT-1 0                 0
# s1d1_CCTGAATAGCTTGCTC-1 0                 0
# s1d1_CATCCCAGTCTTTATG-1 0                 0
# s1d1_GGCTGAGAGTATTGCA-1 0                 0
# s1d1_TAGTGAGAGCTGCACA-1 0                 0
# s1d1_TTACCTGTCTATGACA-1 0                 0
# s1d1_GGATTATGTTACATCC-1 0                 0
# s1d1_CCTGTTGGTTATAGCG-1 0                 0
# s1d1_GGCAATCGTTAGGACC-1 0                 0
# s1d1_TTTAGCTTCTGGCTTC-1 0                 0
# s1d1_AACGACAAGTTGTCAA-1 0                 0
# s1d1_AGCAATACAATATGGA-1 0                 0
# s1d1_AATTTGCCATAATGAG-1 0                 0
# s1d1_AGTTATGTCTCACTCA-1 0                 0
# s1d1_TGTCCTGGTCAATGTG-1 0                 0
# s1d1_TGTATCGCAGCTCATA-1 0                 0
# s1d1_GTTTGTCGTGAATCGC-1 0                 0
# s1d1_CCAGGAACAATGCGCT-1 0                 0
# s1d1_AGAATCGAGAAAGGAA-1 0                 0
# ⋮                       ⋮                 ⋮
# s4d9_ATGTTCAAGTTATTCC-1 0                 0
# s4d9_CCAGGATGTATTCGTC-1 0                 0
# s4d9_CTTCAAGCAAAGCGCA-1 0                 0
# s4d9_ACGAAGTCACGAACAG-1 0                 0
# s4d9_GGTCCGTAGCACAGAA-1 0                 0
# s4d9_GGTTGACGTGAGAAAC-1 0                 0
# s4d9_GCTTTACGTATTCGCT-1 0                 0
# s4d9_GATTACTCACCTAAGC-1 0                 0
# s4d9_TCAAGCTAGCACCACA-1 0                 0
# s4d9_GGTCAATTCGATTATG-1 0                 0
# s4d9_ATGACAACATGAATAG-1 0                 0
# s4d9_TAGCCGGGTAATAGCT-1 0                 0
# s4d9_TACCTCATCATGCGTG-1 0                 0
# s4d9_CAAGCTAGTCAACAAT-1 0                 0
# s4d9_TATGGCCCAGGCTACT-1 0                 0
# s4d9_ACAGGTAAGGTTACGT-1 0                 0
# s4d9_TGTGGAGCAGAAATGC-1 0                 0
# s4d9_GGTTTAATCTATGACA-1 0                 0
# s4d9_ACTAATCCAGCAAGAT-1 0                 0
# s4d9_TAGTGAGAGCACAGGG-1 0                 0
# s4d9_AGCATCCCACAGAACG-1 0                 0
# s4d9_ATTGAAGCACATTGCA-1 0                 0
# s4d9_CTATTCAGTTGTGATG-1 0                 0
# s4d9_TGAACAACAGTGAACG-1 0                 0
# s4d9_CGATTCCTCCTGGCTT-1 0                 0
# s4d9_AAACCGCGTTTGAGGC-1 0                 0
# s4d9_TGACTTAAGTTCCCGT-1 0                 0
# s4d9_GCTGTACCACCGTTCC-1 0                 0
# s4d9_ACACTTGCAACTAGAA-1 0                 0
# s4d9_CACTTAAAGTCTGGGC-1 0                 0
#                         cell_type.rename    nCount_ATAC nFeature_ATAC
# s1d1_TAGTTGTCACCCTCAC-1 Naive_CD20_pos_B     4516        3979
# s1d1_CTATGGCCATAACGGG-1 CD14_pos_Mono       11117        9348
# s1d1_CCGCACACAGGTTAAA-1 CD8_pos_T            5234        4499
# s1d1_TCATTTGGTAATGGAA-1 CD8_pos_T            3266        2977
# s1d1_ACCACATAGGTGTCCA-1 CD16_pos_Mono        2044        1829
# s1d1_TGGATTGGTTTGCGAA-1 B1_B                 3213        3008
# s1d1_GTGAGCGAGTAAAGGT-1 Lymph_prog          14198       11444
# s1d1_GACTTAGGTTGCGCGA-1 CD4_pos_T_naive      5375        4778
# s1d1_GCCTTACTCGTTACAA-1 CD4_pos_T_activated 30509       18255
# s1d1_GTAAGGTCAATAACCT-1 B1_B                 8648        6978
# s1d1_AGCGCCTAGATGGACA-1 Erythroblast        10409        7640
# s1d1_TGCCGGTAGTCGCAAT-1 CD14_pos_Mono         660         654
# s1d1_CCTGAATAGCTTGCTC-1 Erythroblast         7233        5602
# s1d1_CATCCCAGTCTTTATG-1 CD14_pos_Mono         847         834
# s1d1_GGCTGAGAGTATTGCA-1 Erythroblast         5898        4622
# s1d1_TAGTGAGAGCTGCACA-1 CD14_pos_Mono       15510       12029
# s1d1_TTACCTGTCTATGACA-1 NK                   1254        1214
# s1d1_GGATTATGTTACATCC-1 Transitional_B      11167        9353
# s1d1_CCTGTTGGTTATAGCG-1 CD16_pos_Mono        7871        6780
# s1d1_GGCAATCGTTAGGACC-1 Normoblast           2618        2238
# s1d1_TTTAGCTTCTGGCTTC-1 CD14_pos_Mono        1309        1281
# s1d1_AACGACAAGTTGTCAA-1 B1_B                 8894        7261
# s1d1_AGCAATACAATATGGA-1 Naive_CD20_pos_B     5821        4875
# s1d1_AATTTGCCATAATGAG-1 NK                   1287        1231
# s1d1_AGTTATGTCTCACTCA-1 Normoblast           1778        1547
# s1d1_TGTCCTGGTCAATGTG-1 CD4_pos_T_activated  2196        2085
# s1d1_TGTATCGCAGCTCATA-1 NK                   2142        1901
# s1d1_GTTTGTCGTGAATCGC-1 Erythroblast        15679       11274
# s1d1_CCAGGAACAATGCGCT-1 ILC                  4906        4171
# s1d1_AGAATCGAGAAAGGAA-1 CD4_pos_T_activated 14930       11089
# ⋮                       ⋮                   ⋮           ⋮
# s4d9_ATGTTCAAGTTATTCC-1 Transitional_B       7279        6040
# s4d9_CCAGGATGTATTCGTC-1 Proerythroblast     10135        7638
# s4d9_CTTCAAGCAAAGCGCA-1 Transitional_B      16954       12565
# s4d9_ACGAAGTCACGAACAG-1 CD8_pos_T_naive      7425        6010
# s4d9_GGTCCGTAGCACAGAA-1 CD4_pos_T_naive      5869        4971
# s4d9_GGTTGACGTGAGAAAC-1 Lymph_prog            675         655
# s4d9_GCTTTACGTATTCGCT-1 Transitional_B       7017        5920
# s4d9_GATTACTCACCTAAGC-1 HSC                 20603       15558
# s4d9_TCAAGCTAGCACCACA-1 Transitional_B       7479        6376
# s4d9_GGTCAATTCGATTATG-1 Transitional_B       7611        6275
# s4d9_ATGACAACATGAATAG-1 CD8_pos_T_naive      6029        5062
# s4d9_TAGCCGGGTAATAGCT-1 Proerythroblast      7267        6585
# s4d9_TACCTCATCATGCGTG-1 CD8_pos_T           18441       14305
# s4d9_CAAGCTAGTCAACAAT-1 G_M_prog            11847        9868
# s4d9_TATGGCCCAGGCTACT-1 CD8_pos_T            3004        2711
# s4d9_ACAGGTAAGGTTACGT-1 CD16_pos_Mono       12316        9882
# s4d9_TGTGGAGCAGAAATGC-1 CD4_pos_T_activated  6788        5311
# s4d9_GGTTTAATCTATGACA-1 Naive_CD20_pos_B    21206       15224
# s4d9_ACTAATCCAGCAAGAT-1 Naive_CD20_pos_B     3845        3480
# s4d9_TAGTGAGAGCACAGGG-1 NK                   5478        4496
# s4d9_AGCATCCCACAGAACG-1 Naive_CD20_pos_B     3654        3248
# s4d9_ATTGAAGCACATTGCA-1 CD8_pos_T            2739        2609
# s4d9_CTATTCAGTTGTGATG-1 Naive_CD20_pos_B     2664        2466
# s4d9_TGAACAACAGTGAACG-1 CD8_pos_T            6371        5358
# s4d9_CGATTCCTCCTGGCTT-1 CD8_pos_T            5797        4859
# s4d9_AAACCGCGTTTGAGGC-1 CD8_pos_T_naive      7885        6399
# s4d9_TGACTTAAGTTCCCGT-1 Lymph_prog          10495        8386
# s4d9_GCTGTACCACCGTTCC-1 CD8_pos_T            6995        5503
# s4d9_ACACTTGCAACTAGAA-1 cDC2                18057       14308
# s4d9_CACTTAAAGTCTGGGC-1 Naive_CD20_pos_B     4916        4196
#                         cell
# s1d1_TAGTTGTCACCCTCAC-1 s1d1_TAGTTGTCACCCTCAC-1
# s1d1_CTATGGCCATAACGGG-1 s1d1_CTATGGCCATAACGGG-1
# s1d1_CCGCACACAGGTTAAA-1 s1d1_CCGCACACAGGTTAAA-1
# s1d1_TCATTTGGTAATGGAA-1 s1d1_TCATTTGGTAATGGAA-1
# s1d1_ACCACATAGGTGTCCA-1 s1d1_ACCACATAGGTGTCCA-1
# s1d1_TGGATTGGTTTGCGAA-1 s1d1_TGGATTGGTTTGCGAA-1
# s1d1_GTGAGCGAGTAAAGGT-1 s1d1_GTGAGCGAGTAAAGGT-1
# s1d1_GACTTAGGTTGCGCGA-1 s1d1_GACTTAGGTTGCGCGA-1
# s1d1_GCCTTACTCGTTACAA-1 s1d1_GCCTTACTCGTTACAA-1
# s1d1_GTAAGGTCAATAACCT-1 s1d1_GTAAGGTCAATAACCT-1
# s1d1_AGCGCCTAGATGGACA-1 s1d1_AGCGCCTAGATGGACA-1
# s1d1_TGCCGGTAGTCGCAAT-1 s1d1_TGCCGGTAGTCGCAAT-1
# s1d1_CCTGAATAGCTTGCTC-1 s1d1_CCTGAATAGCTTGCTC-1
# s1d1_CATCCCAGTCTTTATG-1 s1d1_CATCCCAGTCTTTATG-1
# s1d1_GGCTGAGAGTATTGCA-1 s1d1_GGCTGAGAGTATTGCA-1
# s1d1_TAGTGAGAGCTGCACA-1 s1d1_TAGTGAGAGCTGCACA-1
# s1d1_TTACCTGTCTATGACA-1 s1d1_TTACCTGTCTATGACA-1
# s1d1_GGATTATGTTACATCC-1 s1d1_GGATTATGTTACATCC-1
# s1d1_CCTGTTGGTTATAGCG-1 s1d1_CCTGTTGGTTATAGCG-1
# s1d1_GGCAATCGTTAGGACC-1 s1d1_GGCAATCGTTAGGACC-1
# s1d1_TTTAGCTTCTGGCTTC-1 s1d1_TTTAGCTTCTGGCTTC-1
# s1d1_AACGACAAGTTGTCAA-1 s1d1_AACGACAAGTTGTCAA-1
# s1d1_AGCAATACAATATGGA-1 s1d1_AGCAATACAATATGGA-1
# s1d1_AATTTGCCATAATGAG-1 s1d1_AATTTGCCATAATGAG-1
# s1d1_AGTTATGTCTCACTCA-1 s1d1_AGTTATGTCTCACTCA-1
# s1d1_TGTCCTGGTCAATGTG-1 s1d1_TGTCCTGGTCAATGTG-1
# s1d1_TGTATCGCAGCTCATA-1 s1d1_TGTATCGCAGCTCATA-1
# s1d1_GTTTGTCGTGAATCGC-1 s1d1_GTTTGTCGTGAATCGC-1
# s1d1_CCAGGAACAATGCGCT-1 s1d1_CCAGGAACAATGCGCT-1
# s1d1_AGAATCGAGAAAGGAA-1 s1d1_AGAATCGAGAAAGGAA-1
# ⋮                       ⋮
# s4d9_ATGTTCAAGTTATTCC-1 s4d9_ATGTTCAAGTTATTCC-1
# s4d9_CCAGGATGTATTCGTC-1 s4d9_CCAGGATGTATTCGTC-1
# s4d9_CTTCAAGCAAAGCGCA-1 s4d9_CTTCAAGCAAAGCGCA-1
# s4d9_ACGAAGTCACGAACAG-1 s4d9_ACGAAGTCACGAACAG-1
# s4d9_GGTCCGTAGCACAGAA-1 s4d9_GGTCCGTAGCACAGAA-1
# s4d9_GGTTGACGTGAGAAAC-1 s4d9_GGTTGACGTGAGAAAC-1
# s4d9_GCTTTACGTATTCGCT-1 s4d9_GCTTTACGTATTCGCT-1
# s4d9_GATTACTCACCTAAGC-1 s4d9_GATTACTCACCTAAGC-1
# s4d9_TCAAGCTAGCACCACA-1 s4d9_TCAAGCTAGCACCACA-1
# s4d9_GGTCAATTCGATTATG-1 s4d9_GGTCAATTCGATTATG-1
# s4d9_ATGACAACATGAATAG-1 s4d9_ATGACAACATGAATAG-1
# s4d9_TAGCCGGGTAATAGCT-1 s4d9_TAGCCGGGTAATAGCT-1
# s4d9_TACCTCATCATGCGTG-1 s4d9_TACCTCATCATGCGTG-1
# s4d9_CAAGCTAGTCAACAAT-1 s4d9_CAAGCTAGTCAACAAT-1
# s4d9_TATGGCCCAGGCTACT-1 s4d9_TATGGCCCAGGCTACT-1
# s4d9_ACAGGTAAGGTTACGT-1 s4d9_ACAGGTAAGGTTACGT-1
# s4d9_TGTGGAGCAGAAATGC-1 s4d9_TGTGGAGCAGAAATGC-1
# s4d9_GGTTTAATCTATGACA-1 s4d9_GGTTTAATCTATGACA-1
# s4d9_ACTAATCCAGCAAGAT-1 s4d9_ACTAATCCAGCAAGAT-1
# s4d9_TAGTGAGAGCACAGGG-1 s4d9_TAGTGAGAGCACAGGG-1
# s4d9_AGCATCCCACAGAACG-1 s4d9_AGCATCCCACAGAACG-1
# s4d9_ATTGAAGCACATTGCA-1 s4d9_ATTGAAGCACATTGCA-1
# s4d9_CTATTCAGTTGTGATG-1 s4d9_CTATTCAGTTGTGATG-1
# s4d9_TGAACAACAGTGAACG-1 s4d9_TGAACAACAGTGAACG-1
# s4d9_CGATTCCTCCTGGCTT-1 s4d9_CGATTCCTCCTGGCTT-1
# s4d9_AAACCGCGTTTGAGGC-1 s4d9_AAACCGCGTTTGAGGC-1
# s4d9_TGACTTAAGTTCCCGT-1 s4d9_TGACTTAAGTTCCCGT-1
# s4d9_GCTGTACCACCGTTCC-1 s4d9_GCTGTACCACCGTTCC-1
# s4d9_ACACTTGCAACTAGAA-1 s4d9_ACACTTGCAACTAGAA-1
# s4d9_CACTTAAAGTCTGGGC-1 s4d9_CACTTAAAGTCTGGGC-1

# %%
peakinfo = do.call(rbind,
                   strsplit(rownames(matrix.atac),"-"))
peakinfo = as.data.frame(peakinfo)
names(peakinfo) <- c("chr", "bp1", "bp2")
peakinfo$site_name <- paste(peakinfo$chr, peakinfo$bp1, peakinfo$bp2, sep="-")
row.names(peakinfo) <- peakinfo$site_name                   
peakinfo
# Out:
#                          chr  bp1       bp2       site_name
# chr1-10010-10536         chr1 10010     10536     chr1-10010-10536
# chr1-96496-96699         chr1 96496     96699     chr1-96496-96699
# chr1-115495-115930       chr1 115495    115930    chr1-115495-115930
# chr1-180470-181899       chr1 180470    181899    chr1-180470-181899
# chr1-184379-184607       chr1 184379    184607    chr1-184379-184607
# chr1-191236-191973       chr1 191236    191973    chr1-191236-191973
# chr1-267886-268118       chr1 267886    268118    chr1-267886-268118
# chr1-271197-271553       chr1 271197    271553    chr1-271197-271553
# chr1-586027-586306       chr1 586027    586306    chr1-586027-586306
# chr1-605379-605695       chr1 605379    605695    chr1-605379-605695
# chr1-778304-779323       chr1 778304    779323    chr1-778304-779323
# chr1-796031-796407       chr1 796031    796407    chr1-796031-796407
# chr1-804807-805042       chr1 804807    805042    chr1-804807-805042
# chr1-814585-814832       chr1 814585    814832    chr1-814585-814832
# chr1-815534-815725       chr1 815534    815725    chr1-815534-815725
# chr1-816023-816461       chr1 816023    816461    chr1-816023-816461
# chr1-816835-817594       chr1 816835    817594    chr1-816835-817594
# chr1-818650-819170       chr1 818650    819170    chr1-818650-819170
# chr1-819795-822596       chr1 819795    822596    chr1-819795-822596
# chr1-826649-827853       chr1 826649    827853    chr1-826649-827853
# chr1-830004-830379       chr1 830004    830379    chr1-830004-830379
# chr1-832562-832734       chr1 832562    832734    chr1-832562-832734
# chr1-836303-836684       chr1 836303    836684    chr1-836303-836684
# chr1-837638-838721       chr1 837638    838721    chr1-837638-838721
# chr1-839629-839833       chr1 839629    839833    chr1-839629-839833
# chr1-841220-842390       chr1 841220    842390    chr1-841220-842390
# chr1-842621-843449       chr1 842621    843449    chr1-842621-843449
# chr1-843780-844989       chr1 843780    844989    chr1-843780-844989
# chr1-848089-848239       chr1 848089    848239    chr1-848089-848239
# chr1-854881-855778       chr1 854881    855778    chr1-854881-855778
# ⋮                        ⋮    ⋮         ⋮         ⋮
# chrX-155927445-155927948 chrX 155927445 155927948 chrX-155927445-155927948
# chrX-155938224-155938507 chrX 155938224 155938507 chrX-155938224-155938507
# chrX-155951166-155951449 chrX 155951166 155951449 chrX-155951166-155951449
# chrX-155952672-155952822 chrX 155952672 155952822 chrX-155952672-155952822
# chrX-155952829-155952979 chrX 155952829 155952979 chrX-155952829-155952979
# chrX-155966710-155967410 chrX 155966710 155967410 chrX-155966710-155967410
# chrX-155968050-155968637 chrX 155968050 155968637 chrX-155968050-155968637
# chrX-155968977-155969200 chrX 155968977 155969200 chrX-155968977-155969200
# chrX-155971774-155971961 chrX 155971774 155971961 chrX-155971774-155971961
# chrX-155972269-155972688 chrX 155972269 155972688 chrX-155972269-155972688
# chrX-155975756-155976213 chrX 155975756 155976213 chrX-155975756-155976213
# chrX-155979734-155979884 chrX 155979734 155979884 chrX-155979734-155979884
# chrX-155982516-155982877 chrX 155982516 155982877 chrX-155982516-155982877
# chrX-155990617-155990947 chrX 155990617 155990947 chrX-155990617-155990947
# chrX-155993356-155993506 chrX 155993356 155993506 chrX-155993356-155993506
# chrX-155995337-155995905 chrX 155995337 155995905 chrX-155995337-155995905
# chrX-155996386-155996536 chrX 155996386 155996536 chrX-155996386-155996536
# chrX-155997198-155998251 chrX 155997198 155998251 chrX-155997198-155998251
# chrX-155998799-155999092 chrX 155998799 155999092 chrX-155998799-155999092
# chrX-156000231-156002121 chrX 156000231 156002121 chrX-156000231-156002121
# chrX-156002433-156003233 chrX 156002433 156003233 chrX-156002433-156003233
# chrX-156003794-156004532 chrX 156003794 156004532 chrX-156003794-156004532
# chrX-156005248-156005865 chrX 156005248 156005865 chrX-156005248-156005865
# chrX-156006455-156006819 chrX 156006455 156006819 chrX-156006455-156006819
# chrX-156008444-156008742 chrX 156008444 156008742 chrX-156008444-156008742
# chrX-156008869-156009386 chrX 156008869 156009386 chrX-156008869-156009386
# chrX-156019809-156020162 chrX 156019809 156020162 chrX-156019809-156020162
# chrX-156025098-156025397 chrX 156025098 156025397 chrX-156025098-156025397
# chrX-156029831-156030380 chrX 156029831 156030380 chrX-156029831-156030380
# chrX-156030497-156030869 chrX 156030497 156030869 chrX-156030497-156030869

# %%
input_cds <-  suppressWarnings(new_cell_data_set(matrix.atac,
                               cell_metadata = cellinfo,
                               gene_metadata = peakinfo))

# %%
input_cds <- monocle3::detect_genes(input_cds)
#Ensure there are no peaks included with zero reads
input_cds <- input_cds[Matrix::rowSums(exprs(input_cds)) != 0,]

# %%
set.seed(2017)
input_cds <- detect_genes(input_cds)
input_cds <- estimate_size_factors(input_cds)
input_cds <- preprocess_cds(input_cds, method = "LSI")
input_cds <- reduce_dimension(input_cds, reduction_method = 'UMAP', 
                              preprocess_method = "LSI")
# Out:
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'

# %%
plot_cells(input_cds)
# Out:
# No trajectory to plot. Has learn_graph() been called yet?
#
# cluster not found in colData(cds), cells will not be colored
#
# cluster_cells() has not been called yet, can't color cells by cluster
# plot without title

# %%
umap_coords <- reducedDims(input_cds)$UMAP
cicero_cds <- make_cicero_cds(input_cds, reduced_coordinates = umap_coords)
# Out:
# Overlap QC metrics:
# Cells per bin: 50
# Maximum shared cells bin-bin: 44
# Mean shared cells bin-bin: 0.0356488213562238
# Median shared cells bin-bin: 0

# %% [markdown]
# Run Cicero

# %%
human.hg38.genome = read.table(path.chrom.sizes,
                               header = F)
human.hg38.genome
# Out:
#     V1                     V2
# 1   chr1                   248956422
# 2   chr2                   242193529
# 3   chr3                   198295559
# 4   chr4                   190214555
# 5   chr5                   181538259
# 6   chr6                   170805979
# 7   chr7                   159345973
# 8   chr8                   145138636
# 9   chr9                   138394717
# 10  chr10                  133797422
# 11  chr11                  135086622
# 12  chr12                  133275309
# 13  chr13                  114364328
# 14  chr14                  107043718
# 15  chr15                  101991189
# 16  chr16                   90338345
# 17  chr17                   83257441
# 18  chr18                   80373285
# 19  chr19                   58617616
# 20  chr20                   64444167
# 21  chr21                   46709983
# 22  chr22                   50818468
# 23  chrX                   156040895
# 24  chrY                    57227415
# 25  chrM                       16569
# 26  chr1_GL383518v1_alt       182439
# 27  chr1_GL383519v1_alt       110268
# 28  chr1_GL383520v2_alt       366580
# 29  chr1_KI270706v1_random    175055
# 30  chr1_KI270707v1_random     32032
# ⋮   ⋮                      ⋮
# 427 chrUn_KI270579v1        31033
# 428 chrUn_KI270580v1         1553
# 429 chrUn_KI270581v1         7046
# 430 chrUn_KI270582v1         6504
# 431 chrUn_KI270583v1         1400
# 432 chrUn_KI270584v1         4513
# 433 chrUn_KI270587v1         2969
# 434 chrUn_KI270588v1         6158
# 435 chrUn_KI270589v1        44474
# 436 chrUn_KI270590v1         4685
# 437 chrUn_KI270591v1         5796
# 438 chrUn_KI270593v1         3041
# 439 chrUn_KI270741v1       157432
# 440 chrUn_KI270742v1       186739
# 441 chrUn_KI270743v1       210658
# 442 chrUn_KI270744v1       168472
# 443 chrUn_KI270745v1        41891
# 444 chrUn_KI270746v1        66486
# 445 chrUn_KI270747v1       198735
# 446 chrUn_KI270748v1        93321
# 447 chrUn_KI270749v1       158759
# 448 chrUn_KI270750v1       148850
# 449 chrUn_KI270751v1       150742
# 450 chrUn_KI270752v1        27745
# 451 chrUn_KI270753v1        62944
# 452 chrUn_KI270754v1        40191
# 453 chrUn_KI270755v1        36723
# 454 chrUn_KI270756v1        79590
# 455 chrUn_KI270757v1        71251
# 456 chrEBV                 171823

# %%
start_time <- Sys.time()
distance_parameters <- estimate_distance_parameter(cicero_cds, 
                                                   window = window, 
                                                   maxit = 100, 
                                                   sample_num = 100, 
                                                   distance_constraint = distance_constraint,
                                                   distance_parameter_convergence = 1e-22, 
                                                   genomic_coords = human.hg38.genome)
mean_distance_parameter <- mean(unlist(distance_parameters))
end_time <- Sys.time()
execution_time1 <- end_time - start_time

# %%
mean_distance_parameter
# Out:
# [1] 0.02257346

# %%
execution_time1
# Out:
# Time difference of 27.8098 mins

# %%
start_time <- Sys.time()
cicero_out <- generate_cicero_models(cicero_cds, 
                                     distance_parameter = mean_distance_parameter, 
                                     window = window, 
                                     genomic_coords = human.hg38.genome)
end_time <- Sys.time()
execution_time2 <- end_time - start_time

# %%
execution_time2
# Out:
# Time difference of 1.980224 hours

# %%
start_time <- Sys.time()
all_cons <- assemble_connections(cicero_out, 
                                 silent = FALSE)
end_time <- Sys.time()
execution_time3 <- end_time - start_time

# %%
execution_time3
# Out:
# Time difference of 20.4398 secs

# %% [markdown]
# Assign coaccess to E2G pairs

# %%
all_cons0 = all_cons
all_cons0[is.na(all_cons0[,"coaccess"]),"coaccess"] = 0
bed.peakinfo <- makeGRangesFromDataFrame(peakinfo, 
                                         keep.extra.columns = TRUE,
                                         start.field="bp1",
                                         end.field="bp2")
overlap.res = findOverlaps(bed.peakinfo[all_cons0[,"Peak1"]],
                           bed.TSS1kb)
df.overlap = as.data.frame(overlap.res)
all_cons0.E2G = all_cons0[df.overlap$queryHits,]
all_cons0.E2G[,"Gene"] = bed.TSS1kb[df.overlap$subjectHits]$V4
all_cons0.E2G[,"PairName"] = paste(all_cons0.E2G[,"Peak2"],all_cons0.E2G[,"Gene"],sep = "_")
all_cons0.E2G.sort = all_cons0.E2G[order(all_cons0.E2G[,"coaccess"],decreasing = T),]
all_cons0.E2G.uniq = all_cons0.E2G.sort[!duplicated(all_cons0.E2G.sort$PairName),]
rownames(all_cons0.E2G.uniq) = all_cons0.E2G.uniq$PairName
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% all_cons0.E2G.uniq$PairName]
pairs.E2G.res$coaccess = all_cons0.E2G.uniq[pairs.E2G.res$PairName,"coaccess"]

# %% [markdown]
# Save results

# %%
dir.create(dir.output,recursive = T)
saveRDS(all_cons,
        paste(dir.output,"all_cons.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "coaccess")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# Warning message in dir.create(dir.output, recursive = T):
# "'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/BMMC/2.Genome_wide_prediction/Cicero/BMMC22.merge.240524' already exists"
# GRanges object with 185687 ranges and 4 metadata columns:
#            seqnames              ranges strand |  TargetGene
#               <Rle>           <IRanges>  <Rle> | <character>
#        [1]     chr1 101000030-101001218      * |        DPH5
#        [2]     chr1 101000030-101001218      * |       OLFM3
#        [3]     chr1 101000030-101001218      * |       S1PR1
#        [4]     chr1 101002009-101003180      * |        DPH5
#        [5]     chr1 101002009-101003180      * |       OLFM3
#        ...      ...                 ...    ... .         ...
#   [185683]     chrX   97673637-97673813      * |      DIAPH2
#   [185684]     chrX   99980528-99980848      * |       CSTF2
#   [185685]     chrX   99980528-99980848      * |      PCDH19
#   [185686]     chrX   99980528-99980848      * |      TSPAN6
#   [185687]     chrX   99980528-99980848      * |        XKRX
#                          PeakName               PairName   coaccess
#                       <character>            <character>  <numeric>
#        [1] chr1-101000030-10100.. chr1-101000030-10100.. -0.0893432
#        [2] chr1-101000030-10100.. chr1-101000030-10100..  0.0872276
#        [3] chr1-101000030-10100.. chr1-101000030-10100.. -0.1625866
#        [4] chr1-101002009-10100.. chr1-101002009-10100.. -0.1657282
#        [5] chr1-101002009-10100.. chr1-101002009-10100..  0.0422347
#        ...                    ...                    ...        ...
#   [185683] chrX-97673637-97673813 chrX-97673637-976738..          0
#   [185684] chrX-99980528-99980848 chrX-99980528-999808..          0
#   [185685] chrX-99980528-99980848 chrX-99980528-999808..          0
#   [185686] chrX-99980528-99980848 chrX-99980528-999808..          0
#   [185687] chrX-99980528-99980848 chrX-99980528-999808..          0
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#        chr  start     end       TargetGene CellType coaccess
# 1      chr1 101000030 101001218 DPH5       K562     -0.089343208
# 2      chr1 101000030 101001218 OLFM3      K562      0.087227610
# 3      chr1 101000030 101001218 S1PR1      K562     -0.162586558
# 4      chr1 101002009 101003180 DPH5       K562     -0.165728168
# 5      chr1 101002009 101003180 OLFM3      K562      0.042234735
# 6      chr1 101002009 101003180 S1PR1      K562     -0.307406450
# 7      chr1 101003962 101006260 DPH5       K562     -0.034375883
# 8      chr1 101003962 101006260 S1PR1      K562     -0.189646556
# 9      chr1 101006528 101006996 DPH5       K562     -0.050587625
# 10     chr1 101006528 101006996 S1PR1      K562     -0.126028446
# 11     chr1 101016916 101017453 DPH5       K562     -0.128564503
# 12     chr1 101016916 101017453 S1PR1      K562     -0.153141047
# 13     chr1 101022396 101022617 DPH5       K562     -0.175273756
# 14     chr1 101022396 101022617 S1PR1      K562     -0.251640238
# 15     chr1 101025141 101026570 OLFM3      K562     -0.127537843
# 16     chr1 101025141 101026570 S1PR1      K562      0.387920206
# 17     chr1 101030887 101031466 DPH5       K562     -0.086328786
# 18     chr1 101030887 101031466 OLFM3      K562      0.060837961
# 19     chr1 101030887 101031466 S1PR1      K562     -0.090277931
# 20     chr1 101032854 101033237 DPH5       K562     -0.020594775
# 21     chr1 101032854 101033237 S1PR1      K562     -0.034847343
# 22     chr1 101035698 101036057 DPH5       K562     -0.018527314
# 23     chr1 101035698 101036057 S1PR1      K562      0.014080189
# 24     chr1 101040428 101041806 DPH5       K562     -0.056824053
# 25     chr1 101040428 101041806 S1PR1      K562      0.058654637
# 26     chr1 101043738 101044243 DPH5       K562     -0.041193951
# 27     chr1 101043738 101044243 OLFM3      K562      0.036254777
# 28     chr1 101043738 101044243 S1PR1      K562      0.006422547
# 29     chr1 101044299 101044710 DPH5       K562     -0.039282756
# 30     chr1 101044299 101044710 S1PR1      K562     -0.048505424
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮
# 185658 chrX 97389680  97390475  DIAPH2     K562      0.0401531490
# 185659 chrX 97390902  97391148  DIAPH2     K562     -0.0005813637
# 185660 chrX 97397490  97397672  DIAPH2     K562      0.0024826617
# 185661 chrX 97397896  97398607  DIAPH2     K562      0.0308489309
# 185662 chrX 97399404  97399730  DIAPH2     K562      0.0170713065
# 185663 chrX 97399873  97400023  DIAPH2     K562      0.0031723713
# 185664 chrX 97401399  97401796  DIAPH2     K562      0.0000000000
# 185665 chrX 97406270  97406472  DIAPH2     K562      0.0437878151
# 185666 chrX 97419057  97419226  DIAPH2     K562      0.0000000000
# 185667 chrX 97430150  97430300  DIAPH2     K562      0.0000000000
# 185668 chrX 97457980  97458256  DIAPH2     K562      0.0000000000
# 185669 chrX 97471053  97471563  DIAPH2     K562      0.0000000000
# 185670 chrX 97477362  97477512  DIAPH2     K562      0.0000000000
# 185671 chrX 97497874  97498441  DIAPH2     K562      0.0854890146
# 185672 chrX 97508495  97508940  DIAPH2     K562      0.0054128689
# 185673 chrX 97525708  97525953  DIAPH2     K562      0.0000000000
# 185674 chrX 97527771  97528156  DIAPH2     K562      0.0536122826
# 185675 chrX 97529414  97530281  DIAPH2     K562      0.0258648500
# 185676 chrX 97538993  97539239  DIAPH2     K562      0.0000000000
# 185677 chrX 97563190  97564918  DIAPH2     K562      0.2787838784
# 185678 chrX 97597846  97598471  DIAPH2     K562     -0.0025714805
# 185679 chrX 97607404  97607564  DIAPH2     K562      0.0000000000
# 185680 chrX 97617007  97617692  DIAPH2     K562      0.0701233414
# 185681 chrX 97639611  97639951  DIAPH2     K562      0.0000000000
# 185682 chrX 97665676  97665984  DIAPH2     K562      0.0000000000
# 185683 chrX 97673637  97673813  DIAPH2     K562      0.0000000000
# 185684 chrX 99980528  99980848  CSTF2      K562      0.0000000000
# 185685 chrX 99980528  99980848  PCDH19     K562      0.0000000000
# 185686 chrX 99980528  99980848  TSPAN6     K562      0.0000000000
# 185687 chrX 99980528  99980848  XKRX       K562      0.0000000000

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ggplot2_3.5.1               Matrix_1.6-5
#  [3] genomation_1.34.0           magrittr_2.0.3
#  [5] Signac_1.13.0               Seurat_5.0.3
#  [7] SeuratObject_5.0.1          sp_2.1-4
#  [9] cicero_1.3.9                Gviz_1.44.2
# [11] monocle3_1.3.7              SingleCellExperiment_1.22.0
# [13] SummarizedExperiment_1.30.2 GenomicRanges_1.54.1
# [15] GenomeInfoDb_1.38.1         IRanges_2.36.0
# [17] S4Vectors_0.40.2            MatrixGenerics_1.12.3
# [19] matrixStats_1.3.0           Biobase_2.60.0
# [21] BiocGenerics_0.48.1
#
# loaded via a namespace (and not attached):
#   [1] ProtGenerics_1.32.0      spatstat.sparse_3.0-3    bitops_1.0-7
#   [4] httr_1.4.7               RColorBrewer_1.1-3       repr_1.1.7
#   [7] tools_4.3.3              sctransform_0.4.1        backports_1.4.1
#  [10] utf8_1.2.4               R6_2.5.1                 uwot_0.1.16
#  [13] lazyeval_0.2.2           withr_3.0.0              prettyunits_1.2.0
#  [16] gridExtra_2.3            progressr_0.14.0         cli_3.6.2
#  [19] Cairo_1.6-2              spatstat.explore_3.2-6   fastDummies_1.7.3
#  [22] labeling_0.4.3           spatstat.data_3.0-4      readr_2.1.5
#  [25] ggridges_0.5.6           pbapply_1.7-2            Rsamtools_2.18.0
#  [28] pbdZMQ_0.3-11            foreign_0.8-86           dichromat_2.0-0.1
#  [31] parallelly_1.37.1        plotrix_3.8-4            BSgenome_1.68.0
#  [34] impute_1.76.0            VGAM_1.1-10              rstudioapi_0.16.0
#  [37] RSQLite_2.3.6            FNN_1.1.4                generics_0.1.3
#  [40] BiocIO_1.10.0            vroom_1.6.5              ica_1.0-3
#  [43] spatstat.random_3.2-3    dplyr_1.1.4              interp_1.1-6
#  [46] fansi_1.0.6              abind_1.4-5              lifecycle_1.0.4
#  [49] yaml_2.3.8               BiocFileCache_2.8.0      Rtsne_0.17
#  [52] blob_1.2.4               promises_1.3.0           crayon_1.5.2
#  [55] miniUI_0.1.1.1           lattice_0.22-6           cowplot_1.1.3
#  [58] GenomicFeatures_1.52.2   KEGGREST_1.40.1          pillar_1.9.0
#  [61] knitr_1.46               rjson_0.2.21             boot_1.3-30
#  [64] future.apply_1.11.2      codetools_0.2-20         fastmatch_1.1-4
#  [67] leiden_0.4.3.1           glue_1.7.0               data.table_1.15.2
#  [70] vctrs_0.6.5              png_0.1-8                spam_2.10-0
#  [73] gtable_0.3.5             assertthat_0.2.1         cachem_1.0.8
#  [76] xfun_0.43                S4Arrays_1.2.1           mime_0.12
#  [79] survival_3.6-4           RcppRoll_0.3.0           fitdistrplus_1.1-11
#  [82] ROCR_1.0-11              nlme_3.1-164             bit64_4.0.5
#  [85] progress_1.2.3           filelock_1.0.3           RcppAnnoy_0.0.22
#  [88] irlba_2.3.5.1            KernSmooth_2.23-22       rpart_4.1.23
#  [91] colorspace_2.1-0         DBI_1.2.2                Hmisc_5.1-2
#  [94] seqPattern_1.34.0        nnet_7.3-19              tidyselect_1.2.1
#  [97] bit_4.0.5                compiler_4.3.3           curl_5.1.0
# [100] htmlTable_2.4.2          xml2_1.3.6               DelayedArray_0.26.7
# [103] plotly_4.10.4            rtracklayer_1.60.1       checkmate_2.3.1
# [106] scales_1.3.0             lmtest_0.9-40            rappdirs_0.3.3
# [109] goftest_1.2-3            stringr_1.5.1            digest_0.6.35
# [112] spatstat.utils_3.0-4     minqa_1.2.6              rmarkdown_2.26
# [115] XVector_0.42.0           htmltools_0.5.8.1        pkgconfig_2.0.3
# [118] jpeg_0.1-10              base64enc_0.1-3          lme4_1.1-35.3
# [121] dbplyr_2.5.0             fastmap_1.1.1            ensembldb_2.24.1
# [124] rlang_1.1.3              htmlwidgets_1.6.4        shiny_1.8.1.1
# [127] farver_2.1.1             zoo_1.8-12               jsonlite_1.8.8
# [130] BiocParallel_1.36.0      VariantAnnotation_1.46.0 RCurl_1.98-1.14
# [133] Formula_1.2-5            GenomeInfoDbData_1.2.11  dotCall64_1.1-1
# [136] patchwork_1.2.0          IRkernel_1.3.2           munsell_0.5.1
# [139] Rcpp_1.0.12              reticulate_1.36.1        stringi_1.8.3
# [142] zlibbioc_1.48.0          MASS_7.3-60              plyr_1.8.9
# [145] parallel_4.3.3           listenv_0.9.1            ggrepel_0.9.5
# [148] deldir_2.0-4             Biostrings_2.70.1        IRdisplay_1.1
# [151] splines_4.3.3            tensor_1.5               hms_1.1.3
# [154] igraph_2.0.3             uuid_1.2-0               spatstat.geom_3.2-9
# [157] RcppHNSW_0.6.0           reshape2_1.4.4           biomaRt_2.56.1
# [160] XML_3.99-0.16.1          evaluate_0.23            latticeExtra_0.6-30
# [163] biovizBase_1.48.0        tzdb_0.4.0               nloptr_2.0.3
# [166] httpuv_1.6.15            RANN_2.6.1               tidyr_1.3.1
# [169] purrr_1.0.2              polyclip_1.10-6          future_1.33.2
# [172] scattermore_1.2          gridBase_0.4-7           xtable_1.8-4
# [175] restfulr_0.0.15          AnnotationFilter_1.24.0  RSpectra_0.16-1
# [178] later_1.3.2              glasso_1.11              viridisLite_0.4.2
# [181] tibble_3.2.1             memoise_2.0.1            AnnotationDbi_1.64.1
# [184] GenomicAlignments_1.36.0 cluster_2.1.6            globals_0.16.3
