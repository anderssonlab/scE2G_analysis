# %%
library(SCENT)
library(Signac)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(parallel)
# Out:
# Warning message:
# “replacing previous import ‘Hmisc::capitalize’ by ‘R.utils::capitalize’ when loading ‘SCENT’”
# Loading required package: grid
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘Matrix’
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/PBMC/Mono.multiome_7features/Kendall/Pairs.tsv.gz"
path.pairs.ABC = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/PBMC/Mono.multiome_7features/Predictions/EnhancerPredictionsAllPutative.tsv.gz"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240617/sc-E2G/test/results/PBMC/Mono.multiome_7features/Kendall/atac_matrix.rds"
path.matrix.rna_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/PBMC/1.prepare_data/1.seurat_pipeline.240620/RNA_count_matrix/Mono.rna_count_matrix.csv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/PBMC/2.Genome_wide_prediction/SCENT/PBMC.Mono.100.240624/"

# %%
n.cores = 16

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import ABC results

# %%
pairs.ABC = readGeneric(path.pairs.ABC,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Filter ABC results which distance < 1M

# %%
pairs.ABC.1M = pairs.ABC[pairs.ABC$distance < 10^6]

# %% [markdown]
# Filter E-G pairs overlaping with pairs.ABC.1M

# %%
df.pairs.E2G.chr_rename = as.data.frame(pairs.E2G)[,1:3]
df.pairs.E2G.chr_rename[,"seqnames"] = paste(seqnames(pairs.E2G),
                                             mcols(pairs.E2G)[,"TargetGene"],
                                             sep = "_")
pairs.E2G.chr_rename = GRanges(df.pairs.E2G.chr_rename)
rm(df.pairs.E2G.chr_rename)

df.pairs.ABC.1M.chr_rename = as.data.frame(pairs.ABC.1M)[,1:3]
df.pairs.ABC.1M.chr_rename[,"seqnames"] = paste(seqnames(pairs.ABC.1M),
                                                mcols(pairs.ABC.1M)[,"TargetGene"],
                                                sep = "_")
pairs.ABC.1M.chr_rename = GRanges(df.pairs.ABC.1M.chr_rename)
rm(df.pairs.ABC.1M.chr_rename)

pairs.E2G.filter = pairs.E2G[countOverlaps(pairs.E2G.chr_rename,
                                           pairs.ABC.1M.chr_rename) > 0]
rm(pairs.E2G.chr_rename)
rm(pairs.ABC.1M.chr_rename)
pairs.E2G.filter
# Out:
# GRanges object with 2883618 ranges and 3 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028733-100029241      * |         AGL
#         [2]     chr1 100028733-100029241      * |      CDC14A
#         [3]     chr1 100028733-100029241      * |         DBT
#         [4]     chr1 100028733-100029241      * |        DPH5
#         [5]     chr1 100028733-100029241      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2883614]     chrX     9986620-9987289      * |       TBL1X
#   [2883615]     chrX     9986620-9987289      * |        WWC3
#   [2883616]     chrX     9995651-9996434      * |       CLCN4
#   [2883617]     chrX     9995651-9996434      * |       TBL1X
#   [2883618]     chrX     9995651-9996434      * |        WWC3
#                           PeakName               PairName
#                        <character>            <character>
#         [1] chr1-100028733-10002.. chr1-100028733-10002..
#         [2] chr1-100028733-10002.. chr1-100028733-10002..
#         [3] chr1-100028733-10002.. chr1-100028733-10002..
#         [4] chr1-100028733-10002.. chr1-100028733-10002..
#         [5] chr1-100028733-10002.. chr1-100028733-10002..
#         ...                    ...                    ...
#   [2883614]   chrX-9986620-9987289 chrX-9986620-9987289..
#   [2883615]   chrX-9986620-9987289 chrX-9986620-9987289..
#   [2883616]   chrX-9995651-9996434 chrX-9995651-9996434..
#   [2883617]   chrX-9995651-9996434 chrX-9995651-9996434..
#   [2883618]   chrX-9995651-9996434 chrX-9995651-9996434..
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac = readRDS(path.matrix.atac_count)
matrix.atac = BinarizeCounts(matrix.atac)

# %% [markdown]
# Import RNA matrix

# %%
matrix.rna = read.csv(path.matrix.rna_count,
                      row.names = 1,
                      check.names = F)
matrix.rna = Matrix(as.matrix(matrix.rna), sparse = TRUE)
matrix.rna = matrix.rna[,colnames(matrix.atac)]
matrix.rna = matrix.rna[rowSums(matrix.rna) > 0,]

# %%
pairs.E2G.filter2 = pairs.E2G.filter[pairs.E2G.filter$TargetGene %in% rownames(matrix.rna) &
                                     pairs.E2G.filter$PeakName %in% rownames(matrix.atac)]

# %% [markdown]
# Prepare SCENT meta data

# %%
meta.data = data.frame(cell = colnames(matrix.rna),
                       nUMI = colSums(matrix.rna),
                       nMito = colSums(matrix.rna[grep("MT-",rownames(matrix.rna)),]),
                       celltype = "K562")
meta.data[,"log.nUMI"] = log(meta.data[,"nUMI"])
meta.data[,"percent.mito"] = meta.data[,"nMito"] / meta.data[,"nUMI"]
meta.data
# Out:
#                                   cell                              nUMI nMito
# Multiome10x_05_AAACAGCCAACAACAA-1 Multiome10x_05_AAACAGCCAACAACAA-1 2924 530
# Multiome10x_05_AAACAGCCATCCTAGA-1 Multiome10x_05_AAACAGCCATCCTAGA-1 4553 608
# Multiome10x_05_AAACATGCAAAGGTAC-1 Multiome10x_05_AAACATGCAAAGGTAC-1 3957 547
# Multiome10x_05_AAACATGCAAATTCGT-1 Multiome10x_05_AAACATGCAAATTCGT-1 3975 460
# Multiome10x_05_AAACATGCAGGACCAA-1 Multiome10x_05_AAACATGCAGGACCAA-1 2856 404
# Multiome10x_05_AAACCAACAACTAACT-1 Multiome10x_05_AAACCAACAACTAACT-1 4542 513
# Multiome10x_05_AAACCAACAGGTTTGC-1 Multiome10x_05_AAACCAACAGGTTTGC-1 3794 588
# Multiome10x_05_AAACCAACATGTTTGG-1 Multiome10x_05_AAACCAACATGTTTGG-1 3298 447
# Multiome10x_05_AAACCGCGTCAATACG-1 Multiome10x_05_AAACCGCGTCAATACG-1 5035 879
# Multiome10x_05_AAACCGCGTGATTTGG-1 Multiome10x_05_AAACCGCGTGATTTGG-1 6257 553
# Multiome10x_05_AAACCGGCAATTTAGC-1 Multiome10x_05_AAACCGGCAATTTAGC-1 4658 541
# Multiome10x_05_AAACGGATCGTTAACA-1 Multiome10x_05_AAACGGATCGTTAACA-1 3043 425
# Multiome10x_05_AAACGTACACTAGGTC-1 Multiome10x_05_AAACGTACACTAGGTC-1 3781 569
# Multiome10x_05_AAACGTACATTGTGGC-1 Multiome10x_05_AAACGTACATTGTGGC-1 9150 993
# Multiome10x_05_AAAGCACCAGCTTAAT-1 Multiome10x_05_AAAGCACCAGCTTAAT-1 4365 627
# Multiome10x_05_AAAGCCCGTCCTTTAA-1 Multiome10x_05_AAAGCCCGTCCTTTAA-1 1768 270
# Multiome10x_05_AAAGCGGGTGCTCACC-1 Multiome10x_05_AAAGCGGGTGCTCACC-1 6802 816
# Multiome10x_05_AAAGCTTGTACCCACC-1 Multiome10x_05_AAAGCTTGTACCCACC-1 6157 749
# Multiome10x_05_AAAGCTTGTTAAGGTT-1 Multiome10x_05_AAAGCTTGTTAAGGTT-1 5286 809
# Multiome10x_05_AAAGGACGTTGGGTTA-1 Multiome10x_05_AAAGGACGTTGGGTTA-1 3836 393
# Multiome10x_05_AAAGGCTCAAGGTGCA-1 Multiome10x_05_AAAGGCTCAAGGTGCA-1 3931 434
# Multiome10x_05_AAAGGCTCACCAACCG-1 Multiome10x_05_AAAGGCTCACCAACCG-1 3266 384
# Multiome10x_05_AAAGGCTCATGCATAT-1 Multiome10x_05_AAAGGCTCATGCATAT-1 2297 264
# Multiome10x_05_AAAGGTTAGAACAAGT-1 Multiome10x_05_AAAGGTTAGAACAAGT-1 5726 687
# Multiome10x_05_AAATCCGGTTACAACG-1 Multiome10x_05_AAATCCGGTTACAACG-1 3893 350
# Multiome10x_05_AAATGCCTCACTAGGT-1 Multiome10x_05_AAATGCCTCACTAGGT-1 3456 497
# Multiome10x_05_AAATGCCTCATGGCTG-1 Multiome10x_05_AAATGCCTCATGGCTG-1 3272 421
# Multiome10x_05_AAATGCCTCCCGCCTA-1 Multiome10x_05_AAATGCCTCCCGCCTA-1 6446 733
# Multiome10x_05_AAATGGCCAATTAGCT-1 Multiome10x_05_AAATGGCCAATTAGCT-1 5144 502
# Multiome10x_05_AAATGGCCACGTAAGG-1 Multiome10x_05_AAATGGCCACGTAAGG-1 4382 502
# ⋮                                 ⋮                                 ⋮    ⋮
# Multiome10x_06_TTTAGGATCTGGCAAT-1 Multiome10x_06_TTTAGGATCTGGCAAT-1 3690  570
# Multiome10x_06_TTTATGGAGGGCTAAA-1 Multiome10x_06_TTTATGGAGGGCTAAA-1 2822  301
# Multiome10x_06_TTTCATCAGTCATTAG-1 Multiome10x_06_TTTCATCAGTCATTAG-1 6012  852
# Multiome10x_06_TTTCCACCAAATTGCT-1 Multiome10x_06_TTTCCACCAAATTGCT-1 2985  341
# Multiome10x_06_TTTCCACCAAGCTAAA-1 Multiome10x_06_TTTCCACCAAGCTAAA-1 2251  287
# Multiome10x_06_TTTCCACCAGATTCAT-1 Multiome10x_06_TTTCCACCAGATTCAT-1 2102  316
# Multiome10x_06_TTTCCACCATCATGGC-1 Multiome10x_06_TTTCCACCATCATGGC-1 8027 1078
# Multiome10x_06_TTTCCGGGTTGTCCAT-1 Multiome10x_06_TTTCCGGGTTGTCCAT-1 3188  449
# Multiome10x_06_TTTCCGGGTTTGCGAA-1 Multiome10x_06_TTTCCGGGTTTGCGAA-1 4065  500
# Multiome10x_06_TTTCCTGAGAGGGACT-1 Multiome10x_06_TTTCCTGAGAGGGACT-1 4614  460
# Multiome10x_06_TTTCTTGCAGCAAGTG-1 Multiome10x_06_TTTCTTGCAGCAAGTG-1 4173  633
# Multiome10x_06_TTTGACCGTTGGCGTG-1 Multiome10x_06_TTTGACCGTTGGCGTG-1 5291  583
# Multiome10x_06_TTTGACTTCGGCCAGT-1 Multiome10x_06_TTTGACTTCGGCCAGT-1 5115  679
# Multiome10x_06_TTTGAGTCATGAGTTT-1 Multiome10x_06_TTTGAGTCATGAGTTT-1 4864  513
# Multiome10x_06_TTTGCATTCAGGAACA-1 Multiome10x_06_TTTGCATTCAGGAACA-1 5340  864
# Multiome10x_06_TTTGCATTCCCGCATT-1 Multiome10x_06_TTTGCATTCCCGCATT-1 4743  467
# Multiome10x_06_TTTGCATTCGCCTGTT-1 Multiome10x_06_TTTGCATTCGCCTGTT-1 5497  893
# Multiome10x_06_TTTGCATTCGTACCGA-1 Multiome10x_06_TTTGCATTCGTACCGA-1 4694  463
# Multiome10x_06_TTTGGCTGTAATCGCA-1 Multiome10x_06_TTTGGCTGTAATCGCA-1 6734  791
# Multiome10x_06_TTTGGCTGTTAGAGCC-1 Multiome10x_06_TTTGGCTGTTAGAGCC-1 6082  683
# Multiome10x_06_TTTGGCTGTTAGGTGC-1 Multiome10x_06_TTTGGCTGTTAGGTGC-1 7732 1260
# Multiome10x_06_TTTGGTAAGCTAAAGG-1 Multiome10x_06_TTTGGTAAGCTAAAGG-1 3357  527
# Multiome10x_06_TTTGGTAAGGTCGATT-1 Multiome10x_06_TTTGGTAAGGTCGATT-1 3985  439
# Multiome10x_06_TTTGGTGCACGTTACA-1 Multiome10x_06_TTTGGTGCACGTTACA-1 9683 1307
# Multiome10x_06_TTTGGTGCACTTCATC-1 Multiome10x_06_TTTGGTGCACTTCATC-1 4649  514
# Multiome10x_06_TTTGTCCCAAGCTACC-1 Multiome10x_06_TTTGTCCCAAGCTACC-1 4890  623
# Multiome10x_06_TTTGTCCCAGGACCAA-1 Multiome10x_06_TTTGTCCCAGGACCAA-1 4616  523
# Multiome10x_06_TTTGTCTAGCCTCTGT-1 Multiome10x_06_TTTGTCTAGCCTCTGT-1 4488  663
# Multiome10x_06_TTTGTGTTCGTTTCCA-1 Multiome10x_06_TTTGTGTTCGTTTCCA-1 4462  557
# Multiome10x_06_TTTGTTGGTACCGAAC-1 Multiome10x_06_TTTGTTGGTACCGAAC-1 1606  181
#                                   celltype log.nUMI percent.mito
# Multiome10x_05_AAACAGCCAACAACAA-1 K562     7.980708 0.18125855
# Multiome10x_05_AAACAGCCATCCTAGA-1 K562     8.423542 0.13353833
# Multiome10x_05_AAACATGCAAAGGTAC-1 K562     8.283241 0.13823604
# Multiome10x_05_AAACATGCAAATTCGT-1 K562     8.287780 0.11572327
# Multiome10x_05_AAACATGCAGGACCAA-1 K562     7.957177 0.14145658
# Multiome10x_05_AAACCAACAACTAACT-1 K562     8.421123 0.11294584
# Multiome10x_05_AAACCAACAGGTTTGC-1 K562     8.241176 0.15498155
# Multiome10x_05_AAACCAACATGTTTGG-1 K562     8.101072 0.13553669
# Multiome10x_05_AAACCGCGTCAATACG-1 K562     8.524169 0.17457795
# Multiome10x_05_AAACCGCGTGATTTGG-1 K562     8.741456 0.08838101
# Multiome10x_05_AAACCGGCAATTTAGC-1 K562     8.446341 0.11614427
# Multiome10x_05_AAACGGATCGTTAACA-1 K562     8.020599 0.13966480
# Multiome10x_05_AAACGTACACTAGGTC-1 K562     8.237744 0.15048929
# Multiome10x_05_AAACGTACATTGTGGC-1 K562     9.121509 0.10852459
# Multiome10x_05_AAAGCACCAGCTTAAT-1 K562     8.381373 0.14364261
# Multiome10x_05_AAAGCCCGTCCTTTAA-1 K562     7.477604 0.15271493
# Multiome10x_05_AAAGCGGGTGCTCACC-1 K562     8.824972 0.11996472
# Multiome10x_05_AAAGCTTGTACCCACC-1 K562     8.725345 0.12165015
# Multiome10x_05_AAAGCTTGTTAAGGTT-1 K562     8.572817 0.15304578
# Multiome10x_05_AAAGGACGTTGGGTTA-1 K562     8.252185 0.10245047
# Multiome10x_05_AAAGGCTCAAGGTGCA-1 K562     8.276649 0.11040448
# Multiome10x_05_AAAGGCTCACCAACCG-1 K562     8.091321 0.11757502
# Multiome10x_05_AAAGGCTCATGCATAT-1 K562     7.739359 0.11493252
# Multiome10x_05_AAAGGTTAGAACAAGT-1 K562     8.652772 0.11997904
# Multiome10x_05_AAATCCGGTTACAACG-1 K562     8.266935 0.08990496
# Multiome10x_05_AAATGCCTCACTAGGT-1 K562     8.147867 0.14380787
# Multiome10x_05_AAATGCCTCATGGCTG-1 K562     8.093157 0.12866748
# Multiome10x_05_AAATGCCTCCCGCCTA-1 K562     8.771215 0.11371393
# Multiome10x_05_AAATGGCCAATTAGCT-1 K562     8.545586 0.09758942
# Multiome10x_05_AAATGGCCACGTAAGG-1 K562     8.385261 0.11455956
# ⋮                                 ⋮        ⋮        ⋮
# Multiome10x_06_TTTAGGATCTGGCAAT-1 K562     8.213382 0.15447154
# Multiome10x_06_TTTATGGAGGGCTAAA-1 K562     7.945201 0.10666194
# Multiome10x_06_TTTCATCAGTCATTAG-1 K562     8.701513 0.14171657
# Multiome10x_06_TTTCCACCAAATTGCT-1 K562     8.001355 0.11423786
# Multiome10x_06_TTTCCACCAAGCTAAA-1 K562     7.719130 0.12749889
# Multiome10x_06_TTTCCACCAGATTCAT-1 K562     7.650645 0.15033302
# Multiome10x_06_TTTCCACCATCATGGC-1 K562     8.990566 0.13429675
# Multiome10x_06_TTTCCGGGTTGTCCAT-1 K562     8.067149 0.14084065
# Multiome10x_06_TTTCCGGGTTTGCGAA-1 K562     8.310169 0.12300123
# Multiome10x_06_TTTCCTGAGAGGGACT-1 K562     8.436850 0.09969658
# Multiome10x_06_TTTCTTGCAGCAAGTG-1 K562     8.336390 0.15168943
# Multiome10x_06_TTTGACCGTTGGCGTG-1 K562     8.573763 0.11018711
# Multiome10x_06_TTTGACTTCGGCCAGT-1 K562     8.539933 0.13274682
# Multiome10x_06_TTTGAGTCATGAGTTT-1 K562     8.489616 0.10546875
# Multiome10x_06_TTTGCATTCAGGAACA-1 K562     8.582981 0.16179775
# Multiome10x_06_TTTGCATTCCCGCATT-1 K562     8.464425 0.09846089
# Multiome10x_06_TTTGCATTCGCCTGTT-1 K562     8.611958 0.16245225
# Multiome10x_06_TTTGCATTCGTACCGA-1 K562     8.454040 0.09863656
# Multiome10x_06_TTTGGCTGTAATCGCA-1 K562     8.814925 0.11746362
# Multiome10x_06_TTTGGCTGTTAGAGCC-1 K562     8.713089 0.11229859
# Multiome10x_06_TTTGGCTGTTAGGTGC-1 K562     8.953123 0.16295913
# Multiome10x_06_TTTGGTAAGCTAAAGG-1 K562     8.118803 0.15698540
# Multiome10x_06_TTTGGTAAGGTCGATT-1 K562     8.290293 0.11016311
# Multiome10x_06_TTTGGTGCACGTTACA-1 K562     9.178127 0.13497883
# Multiome10x_06_TTTGGTGCACTTCATC-1 K562     8.444407 0.11056141
# Multiome10x_06_TTTGTCCCAAGCTACC-1 K562     8.494948 0.12740286
# Multiome10x_06_TTTGTCCCAGGACCAA-1 K562     8.437284 0.11330156
# Multiome10x_06_TTTGTCTAGCCTCTGT-1 K562     8.409162 0.14772727
# Multiome10x_06_TTTGTGTTCGTTTCCA-1 K562     8.403352 0.12483191
# Multiome10x_06_TTTGTTGGTACCGAAC-1 K562     7.381502 0.11270237

# %% [markdown]
# RUN SCENT prediction

# %%
SCENT_algorithm.modified = function (object, 
                                     # celltype, 
                                     # ncores, 
                                     # regr = "poisson", 
                                     # bin = TRUE) 
                                     regr = "poisson") {
    res <- data.frame()
    for (n in 1:nrow(object@peak.info)) {        
        gene <- object@peak.info[n, 1]
        this_peak <- object@peak.info[n, 2]
        atac_target <- data.frame(cell = colnames(object@atac), 
            atac = object@atac[this_peak, ])
        # if (bin) {
        #     atac_target[atac_target$atac > 0, ]$atac <- 1
        # }
        mrna_target <- object@rna[gene, ]
        df <- data.frame(cell = names(mrna_target), exprs = as.numeric(mrna_target))
        df <- merge(df, atac_target, by = "cell")
        df <- merge(df, object@meta.data, by = "cell")
        # df2 <- df[df[[object@celltypes]] == celltype, ]
        df2 <- df
        nonzero_m <- length(df2$exprs[df2$exprs > 0])/length(df2$exprs)
        nonzero_a <- length(df2$atac[df2$atac > 0])/length(df2$atac)
        if (nonzero_m > 0.05 & nonzero_a > 0.05) {
            res_var <- "exprs"
            pred_var <- c("atac", object@covariates)
            formula <- as.formula(paste(res_var, paste(pred_var, 
                collapse = "+"), sep = "~"))
            if (regr == "poisson") {
                base = glm(formula, family = "poisson", data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_poisson
                assoc <- SCENT::assoc_poisson
            }
            else if (regr == "negbin") {
                base = glm.nb(formula, data = df2)
                coefs <- summary(base)$coefficients["atac", ]
                # assoc <- assoc_negbin
                assoc <- SCENT::assoc_negbin
            }
            bs = boot::boot(df2, assoc, R = 100, formula = formula, 
                stype = "i", parallel = "no", ncpus = 1)
            # p0 = basic_p(bs$t0[1], bs$t[, 1])
            p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # if (p0 < 0.1) {
            #     bs = boot::boot(df2, assoc, R = 500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.05) {
            #     bs = boot::boot(df2, assoc, R = 2500, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.01) {
            #     bs = boot::boot(df2, assoc, R = 25000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            # if (p0 < 0.001) {
            #     bs = boot::boot(df2, assoc, R = 50000, formula = formula, 
            #       stype = "i", 
            #       # parallel = "multicore", ncpus = ncores)
            #       parallel = "no", ncpus = 1)
            #     # p0 = basic_p(bs$t0[1], bs$t[, 1])
            #     p0 = SCENT::basic_p(bs$t0[1], bs$t[, 1])
            # }
            out <- data.frame(gene = gene, peak = this_peak, 
                beta = coefs[1], se = coefs[2], z = coefs[3], 
                p = coefs[4], boot_basic_p = p0)           
            res <- rbind(res, out)
        }
    }
    object@SCENT.result <- res
    return(object)
}

# %%
dir.create(paste(dir.output,"chr",sep = "/"),recursive = T)

# %%
chr.done = dir(paste(dir.output,"chr",sep = "/"))
chr.run = as.character(unique(seqnames(pairs.E2G.filter2)))
chr.run = chr.run[!chr.run %in% chr.done]

# %%
for(chr.tmp in chr.run){
  print(chr.tmp)
  pairs.E2G.chr.res = pairs.E2G.filter2[seqnames(pairs.E2G.filter2) == chr.tmp]
  gene_peak.chr = as.data.frame(mcols(pairs.E2G.chr.res)[,c("TargetGene","PeakName")])
  list.gene_peak.chr <- split(gene_peak.chr, seq_len(n.cores))
  
  list.obj.SCENT.chr <- lapply(list.gene_peak.chr, function(gene_peak.tmp) {
    obj.SCENT.tmp <- CreateSCENTObj(
      rna = matrix.rna[rownames(matrix.rna) %in% gene_peak.tmp$TargetGene,],
      atac = matrix.atac[rownames(matrix.atac) %in% gene_peak.tmp$PeakName,], 
      meta.data = meta.data,
      peak.info = gene_peak.tmp,
      covariates = c("log.nUMI","percent.mito"), 
      celltypes = "celltype"
    )
  })
  
  cl <- makeCluster(n.cores)
  clusterExport(cl, varlist=c("SCENT_algorithm.modified"))
  list.SCENT.result.chr <- parLapply(cl, list.obj.SCENT.chr, function(obj.SCENT.tmp) {
    obj.SCENT.tmp <- SCENT_algorithm.modified(object = obj.SCENT.tmp)
    return(obj.SCENT.tmp@SCENT.result)
  })
  stopCluster(cl)
  
  
  df.SCENT.result.chr = do.call(rbind,list.SCENT.result.chr)
  rownames(df.SCENT.result.chr) = paste(df.SCENT.result.chr$peak,
                                        df.SCENT.result.chr$gene,
                                        sep = "_")

  pairs.E2G.chr.res = pairs.E2G.chr.res[pairs.E2G.chr.res$PairName %in% rownames(df.SCENT.result.chr)]
  mcols(pairs.E2G.chr.res)[,c("beta","se","z","p","boot_basic_p")] = 
    df.SCENT.result.chr[pairs.E2G.chr.res$PairName,c("beta","se","z","p","boot_basic_p")]
  pairs.E2G.chr.res$boot_basic_p.log10 = -log10(pairs.E2G.chr.res$boot_basic_p)
  pairs.E2G.chr.res$sign = 1
  pairs.E2G.chr.res$sign[pairs.E2G.chr.res$beta < 0] = -1
  pairs.E2G.chr.res$boot_basic_p.log10.signed = pairs.E2G.chr.res$boot_basic_p.log10 * pairs.E2G.chr.res$sign
  saveRDS(pairs.E2G.chr.res,
          paste(dir.output,"chr",chr.tmp,sep = "/"))
  rm (pairs.E2G.chr.res)
}
# Out:
# [1] "chr1"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr10"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr11"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr12"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr13"
# [1] "chr14"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr15"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr16"
# [1] "chr17"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr18"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr19"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr2"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr20"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr21"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr22"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr3"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr4"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr5"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr6"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr7"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr8"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chr9"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”
# [1] "chrX"
# Warning message in split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...):
# “data length is not a multiple of split variable”

# %% [markdown]
# Merge results

# %%
chr.merge = as.character(unique(seqnames(pairs.E2G.filter2)))
list.res = list()
for(chr.tmp in chr.merge){
    list.res[[chr.tmp]] = readRDS(paste(dir.output,"chr",chr.tmp,sep = "/"))
}
pairs.E2G.res = unlist(as(list.res, "GRangesList"))

# %% [markdown]
# Save results

# %%
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
pairs.E2G.res
# Out:
# GRanges object with 551240 ranges and 11 metadata columns:
#        seqnames              ranges strand |  TargetGene               PeakName
#           <Rle>           <IRanges>  <Rle> | <character>            <character>
#   chr1     chr1 100037721-100039259      * |         AGL chr1-100037721-10003..
#   chr1     chr1 100037721-100039259      * |      CDC14A chr1-100037721-10003..
#   chr1     chr1 100037721-100039259      * |         DBT chr1-100037721-10003..
#   chr1     chr1 100037721-100039259      * |        RTCA chr1-100037721-10003..
#   chr1     chr1 100037721-100039259      * |     SLC30A7 chr1-100037721-10003..
#    ...      ...                 ...    ... .         ...                    ...
#   chrX     chrX     9980996-9982061      * |        WWC3   chrX-9980996-9982061
#   chrX     chrX     9986620-9987289      * |       TBL1X   chrX-9986620-9987289
#   chrX     chrX     9986620-9987289      * |        WWC3   chrX-9986620-9987289
#   chrX     chrX     9995651-9996434      * |       TBL1X   chrX-9995651-9996434
#   chrX     chrX     9995651-9996434      * |        WWC3   chrX-9995651-9996434
#                      PairName        beta        se         z           p
#                   <character>   <numeric> <numeric> <numeric>   <numeric>
#   chr1 chr1-100037721-10003..   0.0925782 0.1250820  0.740140 4.59215e-01
#   chr1 chr1-100037721-10003..   0.2074688 0.0383411  5.411127 6.26295e-08
#   chr1 chr1-100037721-10003..   0.0324195 0.1241070  0.261223 7.93921e-01
#   chr1 chr1-100037721-10003..  -0.0589519 0.0903330 -0.652607 5.14010e-01
#   chr1 chr1-100037721-10003..   0.0824857 0.0546362  1.509726 1.31113e-01
#    ...                    ...         ...       ...       ...         ...
#   chrX chrX-9980996-9982061.. -0.17289270 0.1663643 -1.039242  0.29869234
#   chrX chrX-9986620-9987289.. -0.00337306 0.0391088 -0.086248  0.93126928
#   chrX chrX-9986620-9987289.. -0.09104390 0.1392237 -0.653940  0.51315056
#   chrX chrX-9995651-9996434.. -0.06487646 0.0501665 -1.293223  0.19593411
#   chrX chrX-9995651-9996434..  0.43038442 0.1388367  3.099933  0.00193564
#        boot_basic_p boot_basic_p.log10      sign boot_basic_p.log10.signed
#           <numeric>          <numeric> <numeric>                 <numeric>
#   chr1         0.46          0.3372422         1                 0.3372422
#   chr1         0.02          1.6989700         1                 1.6989700
#   chr1         0.88          0.0555173         1                 0.0555173
#   chr1         0.70          0.1549020        -1                -0.1549020
#   chr1         0.18          0.7447275         1                 0.7447275
#    ...          ...                ...       ...                       ...
#   chrX         0.46          0.3372422        -1                -0.3372422
#   chrX         0.88          0.0555173        -1                -0.0555173
#   chrX         0.62          0.2076083        -1                -0.2076083
#   chrX         0.32          0.4948500        -1                -0.4948500
#   chrX         0.02          1.6989700         1                 1.6989700
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %%
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "beta","se","z","p","boot_basic_p",
                         "boot_basic_p.log10",
                         "sign",
                         "boot_basic_p.log10.signed")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
df.output
# Out:
#        chr  start     end       TargetGene CellType beta         se
# 1      chr1 100037721 100039259 AGL        K562      0.092578239 0.12508204
# 2      chr1 100037721 100039259 CDC14A     K562      0.207468768 0.03834114
# 3      chr1 100037721 100039259 DBT        K562      0.032419538 0.12410698
# 4      chr1 100037721 100039259 RTCA       K562     -0.058951904 0.09033296
# 5      chr1 100037721 100039259 SLC30A7    K562      0.082485655 0.05463617
# 6      chr1 100037721 100039259 SLC35A3    K562      0.110268517 0.10456767
# 7      chr1 100037721 100039259 TRMT13     K562      0.105155654 0.10541193
# 8      chr1 100046129 100047652 AGL        K562     -0.212871152 0.16184103
# 9      chr1 100046129 100047652 CDC14A     K562      0.073638214 0.04414768
# 10     chr1 100046129 100047652 DBT        K562      0.187548227 0.14558004
# 11     chr1 100046129 100047652 RTCA       K562     -0.190637296 0.11905430
# 12     chr1 100046129 100047652 SLC30A7    K562      0.071834543 0.06678500
# 13     chr1 100046129 100047652 SLC35A3    K562      0.144999176 0.12513975
# 14     chr1 100046129 100047652 TRMT13     K562     -0.018137747 0.13040112
# 15     chr1 100051301 100052036 AGL        K562     -0.250938359 0.27436763
# 16     chr1 100051301 100052036 CDC14A     K562      0.199487701 0.06738810
# 17     chr1 100051301 100052036 DBT        K562      0.193889802 0.22717452
# 18     chr1 100051301 100052036 RTCA       K562     -0.009818696 0.18001104
# 19     chr1 100051301 100052036 SLC30A7    K562      0.080184057 0.10476964
# 20     chr1 100051301 100052036 SLC35A3    K562      0.235880348 0.18739266
# 21     chr1 100051301 100052036 TRMT13     K562      0.305279773 0.18214643
# 22     chr1 100132480 100133471 AGL        K562      0.277702756 0.12386390
# 23     chr1 100132480 100133471 CDC14A     K562      0.173499351 0.03722873
# 24     chr1 100132480 100133471 DBT        K562      0.110372773 0.12322413
# 25     chr1 100132480 100133471 RTCA       K562      0.062692784 0.09000099
# 26     chr1 100132480 100133471 SLC30A7    K562      0.028176247 0.05428187
# 27     chr1 100132480 100133471 SLC35A3    K562      0.163691338 0.10363963
# 28     chr1 100132480 100133471 TRMT13     K562      0.069282063 0.10407216
# 29     chr1   1001804   1002126 ACAP3      K562     -0.020116346 0.12061933
# 30     chr1   1001804   1002126 AURKAIP1   K562     -0.119082380 0.07313714
# ⋮      ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 551211 chrX  9454093   9454721  TBL1X      K562     -0.028334912 0.04429454
# 551212 chrX  9454093   9454721  WWC3       K562     -0.239875815 0.16641125
# 551213 chrX  9456340   9457052  TBL1X      K562      0.051983708 0.03316682
# 551214 chrX  9456340   9457052  WWC3       K562      0.045555687 0.11325086
# 551215 chrX  9462929   9463778  TBL1X      K562     -0.046520466 0.02775853
# 551216 chrX  9462929   9463778  WWC3       K562      0.029987813 0.09429655
# 551217 chrX  9464706   9466470  TBL1X      K562      0.068312498 0.02825617
# 551218 chrX  9464706   9466470  WWC3       K562     -0.120483905 0.10148452
# 551219 chrX 96424687  96425840  DIAPH2     K562      0.009857294 0.03083780
# 551220 chrX 96684306  96686193  DIAPH2     K562      0.009721945 0.01962169
# 551221 chrX 96722586  96723509  DIAPH2     K562      0.083627150 0.03184887
# 551222 chrX  9676951   9677783  TBL1X      K562     -0.043268284 0.04164054
# 551223 chrX  9676951   9677783  WWC3       K562      0.322283520 0.12405774
# 551224 chrX 97563511  97564035  DIAPH2     K562      0.008765846 0.03270718
# 551225 chrX 97564150  97564955  DIAPH2     K562      0.122906853 0.03504469
# 551226 chrX   989889    990626  AKAP17A    K562     -0.003435638 0.07368274
# 551227 chrX   989889    990626  ASMTL      K562     -0.050596003 0.09024158
# 551228 chrX   989889    990626  CSF2RA     K562     -0.060073282 0.04113152
# 551229 chrX   989889    990626  GTPBP6     K562      0.157033934 0.10281674
# 551230 chrX   989889    990626  IL3RA      K562     -0.094595975 0.06135152
# 551231 chrX   989889    990626  LINC00106  K562     -0.062347539 0.17147511
# 551232 chrX   989889    990626  P2RY8      K562      0.141660351 0.04977595
# 551233 chrX   989889    990626  PLCXD1     K562      0.255327945 0.12699521
# 551234 chrX   989889    990626  SLC25A6    K562     -0.070778918 0.03072393
# 551235 chrX  9980996   9982061  TBL1X      K562      0.012447161 0.04437460
# 551236 chrX  9980996   9982061  WWC3       K562     -0.172892701 0.16636428
# 551237 chrX  9986620   9987289  TBL1X      K562     -0.003373059 0.03910884
# 551238 chrX  9986620   9987289  WWC3       K562     -0.091043896 0.13922366
# 551239 chrX  9995651   9996434  TBL1X      K562     -0.064876465 0.05016651
# 551240 chrX  9995651   9996434  WWC3       K562      0.430384421 0.13883668
#        z           p            boot_basic_p boot_basic_p.log10 sign
# 1       0.74014013 4.592150e-01 0.46         0.337242168         1
# 2       5.41112665 6.262946e-08 0.02         1.698970004         1
# 3       0.26122252 7.939209e-01 0.88         0.055517328         1
# 4      -0.65260680 5.140098e-01 0.70         0.154901960        -1
# 5       1.50972614 1.311133e-01 0.18         0.744727495         1
# 6       1.05451822 2.916457e-01 0.30         0.522878745         1
# 7       0.99756877 3.184885e-01 0.42         0.376750710         1
# 8      -1.31531017 1.884057e-01 0.06         1.221848750        -1
# 9       1.66799752 9.531622e-02 0.24         0.619788758         1
# 10      1.28828255 1.976476e-01 0.12         0.920818754         1
# 11     -1.60126342 1.093186e-01 0.12         0.920818754        -1
# 12      1.07560886 2.821022e-01 0.32         0.494850022         1
# 13      1.15869797 2.465793e-01 0.22         0.657577319         1
# 14     -0.13909196 8.893775e-01 0.80         0.096910013        -1
# 15     -0.91460627 3.603984e-01 0.46         0.337242168        -1
# 16      2.96028093 3.073586e-03 0.06         1.221848750         1
# 17      0.85348394 3.933910e-01 0.38         0.420216403         1
# 18     -0.05454497 9.565010e-01 0.90         0.045757491        -1
# 19      0.76533672 4.440711e-01 0.38         0.420216403         1
# 20      1.25874911 2.081210e-01 0.16         0.795880017         1
# 21      1.67601298 9.373565e-02 0.10         1.000000000         1
# 22      2.24199919 2.496142e-02 0.08         1.096910013         1
# 23      4.66036173 3.156541e-06 0.02         1.698970004         1
# 24      0.89570746 3.704090e-01 0.48         0.318758763         1
# 25      0.69657886 4.860664e-01 0.42         0.376750710         1
# 26      0.51907289 6.037099e-01 0.60         0.221848750         1
# 27      1.57942809 1.142379e-01 0.16         0.795880017         1
# 28      0.66571177 5.055953e-01 0.62         0.207608311         1
# 29     -0.16677548 8.675467e-01 0.98         0.008773924        -1
# 30     -1.62820676 1.034811e-01 0.06         1.221848750        -1
# ⋮      ⋮           ⋮            ⋮            ⋮                  ⋮
# 551211 -0.63969315 0.5223721093 0.60         0.22184875         -1
# 551212 -1.44146394 0.1494536568 0.20         0.69897000         -1
# 551213  1.56734095 0.1170350174 0.26         0.58502665          1
# 551214  0.40225466 0.6874966218 0.78         0.10790540          1
# 551215 -1.67589832 0.0937581113 0.20         0.69897000         -1
# 551216  0.31801603 0.7504727812 0.92         0.03621217          1
# 551217  2.41761307 0.0156226794 0.04         1.39794001          1
# 551218 -1.18721457 0.2351429941 0.20         0.69897000         -1
# 551219  0.31964969 0.7492339009 0.96         0.01772877          1
# 551220  0.49546927 0.6202689061 0.70         0.15490196          1
# 551221  2.62574951 0.0086458416 0.12         0.92081875          1
# 551222 -1.03909024 0.2987627675 0.50         0.30103000         -1
# 551223  2.59785088 0.0093809222 0.02         1.69897000          1
# 551224  0.26800987 0.7886917204 0.94         0.02687215          1
# 551225  3.50714612 0.0004529404 0.02         1.69897000          1
# 551226 -0.04662744 0.9628101610 0.96         0.01772877         -1
# 551227 -0.56067286 0.5750205709 0.62         0.20760831         -1
# 551228 -1.46051684 0.1441480817 0.18         0.74472749         -1
# 551229  1.52731881 0.1266817551 0.20         0.69897000          1
# 551230 -1.54186847 0.1231055582 0.22         0.65757732         -1
# 551231 -0.36359527 0.7161602616 0.70         0.15490196         -1
# 551232  2.84595988 0.0044277774 0.02         1.69897000          1
# 551233  2.01053216 0.0443748964 0.04         1.39794001          1
# 551234 -2.30370665 0.0212391163 0.02         1.69897000         -1
# 551235  0.28050197 0.7790924149 0.84         0.07572071          1
# 551236 -1.03924170 0.2986923401 0.46         0.33724217         -1
# 551237 -0.08624799 0.9312692795 0.88         0.05551733         -1
# 551238 -0.65393985 0.5131505599 0.62         0.20760831         -1
# 551239 -1.29322253 0.1959341070 0.32         0.49485002         -1
# 551240  3.09993320 0.0019356429 0.02         1.69897000          1
#        boot_basic_p.log10.signed
# 1       0.337242168
# 2       1.698970004
# 3       0.055517328
# 4      -0.154901960
# 5       0.744727495
# 6       0.522878745
# 7       0.376750710
# 8      -1.221848750
# 9       0.619788758
# 10      0.920818754
# 11     -0.920818754
# 12      0.494850022
# 13      0.657577319
# 14     -0.096910013
# 15     -0.337242168
# 16      1.221848750
# 17      0.420216403
# 18     -0.045757491
# 19      0.420216403
# 20      0.795880017
# 21      1.000000000
# 22      1.096910013
# 23      1.698970004
# 24      0.318758763
# 25      0.376750710
# 26      0.221848750
# 27      0.795880017
# 28      0.207608311
# 29     -0.008773924
# 30     -1.221848750
# ⋮      ⋮
# 551211 -0.22184875
# 551212 -0.69897000
# 551213  0.58502665
# 551214  0.10790540
# 551215 -0.69897000
# 551216  0.03621217
# 551217  1.39794001
# 551218 -0.69897000
# 551219  0.01772877
# 551220  0.15490196
# 551221  0.92081875
# 551222 -0.30103000
# 551223  1.69897000
# 551224  0.02687215
# 551225  1.69897000
# 551226 -0.01772877
# 551227 -0.20760831
# 551228 -0.74472749
# 551229  0.69897000
# 551230 -0.65757732
# 551231 -0.15490196
# 551232  1.69897000
# 551233  1.39794001
# 551234 -1.69897000
# 551235  0.07572071
# 551236 -0.33724217
# 551237 -0.05551733
# 551238 -0.20760831
# 551239 -0.49485002
# 551240  1.69897000

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
# [1] Matrix_1.6-5         GenomicRanges_1.54.1 GenomeInfoDb_1.38.1
# [4] IRanges_2.36.0       S4Vectors_0.40.2     BiocGenerics_0.48.1
# [7] genomation_1.34.0    Signac_1.13.0        SCENT_1.0.0
#
# loaded via a namespace (and not attached):
#   [1] rstudioapi_0.16.0           jsonlite_1.8.8
#   [3] magrittr_2.0.3              nloptr_2.0.3
#   [5] rmarkdown_2.26              BiocIO_1.10.0
#   [7] zlibbioc_1.48.0             vctrs_0.6.5
#   [9] minqa_1.2.6                 Rsamtools_2.18.0
#  [11] RCurl_1.98-1.14             base64enc_0.1-3
#  [13] RcppRoll_0.3.0              htmltools_0.5.8.1
#  [15] S4Arrays_1.2.1              plotrix_3.8-4
#  [17] Formula_1.2-5               parallelly_1.37.1
#  [19] KernSmooth_2.23-22          htmlwidgets_1.6.4
#  [21] plyr_1.8.9                  impute_1.76.0
#  [23] uuid_1.2-0                  GenomicAlignments_1.36.0
#  [25] lifecycle_1.0.4             pkgconfig_2.0.3
#  [27] R6_2.5.1                    fastmap_1.1.1
#  [29] GenomeInfoDbData_1.2.11     MatrixGenerics_1.12.3
#  [31] future_1.33.2               digest_0.6.35
#  [33] colorspace_2.1-0            patchwork_1.2.0
#  [35] irlba_2.3.5.1               Hmisc_5.1-2
#  [37] progressr_0.14.0            fansi_1.0.6
#  [39] abind_1.4-5                 compiler_4.3.3
#  [41] bit64_4.0.5                 htmlTable_2.4.2
#  [43] backports_1.4.1             BiocParallel_1.36.0
#  [45] R.utils_2.12.3              MASS_7.3-60
#  [47] DelayedArray_0.26.7         rjson_0.2.21
#  [49] tools_4.3.3                 foreign_0.8-86
#  [51] future.apply_1.11.2         nnet_7.3-19
#  [53] R.oo_1.26.0                 glue_1.7.0
#  [55] restfulr_0.0.15             nlme_3.1-164
#  [57] pbdZMQ_0.3-11               checkmate_2.3.1
#  [59] gridBase_0.4-7              cluster_2.1.6
#  [61] reshape2_1.4.4              generics_0.1.3
#  [63] gtable_0.3.5                BSgenome_1.68.0
#  [65] tzdb_0.4.0                  R.methodsS3_1.8.2
#  [67] tidyr_1.3.1                 seqPattern_1.34.0
#  [69] data.table_1.15.2           hms_1.1.3
#  [71] sp_2.1-4                    utf8_1.2.4
#  [73] XVector_0.42.0              pillar_1.9.0
#  [75] stringr_1.5.1               vroom_1.6.5
#  [77] spam_2.10-0                 IRdisplay_1.1
#  [79] splines_4.3.3               dplyr_1.1.4
#  [81] lattice_0.22-6              bit_4.0.5
#  [83] rtracklayer_1.60.1          tidyselect_1.2.1
#  [85] Biostrings_2.70.1           pbapply_1.7-2
#  [87] knitr_1.46                  gridExtra_2.3
#  [89] SummarizedExperiment_1.30.2 xfun_0.43
#  [91] Biobase_2.60.0              matrixStats_1.3.0
#  [93] stringi_1.8.3               yaml_2.3.8
#  [95] boot_1.3-30                 evaluate_0.23
#  [97] codetools_0.2-20            tibble_3.2.1
#  [99] cli_3.6.2                   IRkernel_1.3.2
# [101] rpart_4.1.23                repr_1.1.7
# [103] munsell_0.5.1               Rcpp_1.0.12
# [105] globals_0.16.3              XML_3.99-0.16.1
# [107] ggplot2_3.5.1               readr_2.1.5
# [109] dotCall64_1.1-1             bitops_1.0-7
# [111] lme4_1.1-35.3               listenv_0.9.1
# [113] scales_1.3.0                SeuratObject_5.0.1
# [115] purrr_1.0.2                 crayon_1.5.2
# [117] rlang_1.1.3                 fastmatch_1.1-4
