# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Wang/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/3.Genome_wide_prediction/ArchR/ArchR.240527/"

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/geo/cellranger_res/GSE1"| __truncated__
#   .. ..@ hash : chr [1:2] "ed3e8fdfffa0e7cea75003307869d5ce" "124adcbdbfec73546f348dde2eb879e6"
#   .. ..@ cells: Named chr [1:4574] "AAACAGCCAATGCCCG-1" "AAACAGCCACCCTCAC-1" "AAACAGCCACCTACTT-1" "AAACATGCAACTAACT-1" ...
#   .. .. ..- attr(*, "names")= chr [1:4574] "K562_Wang_AAACAGCCAATGCCCG-1" "K562_Wang_AAACAGCCACCCTCAC-1" "K562_Wang_AAACAGCCACCTACTT-1" "K562_Wang_AAACATGCAACTAACT-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Wang"),
  validBarcodes = list(K562_Wang = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-3c80575d26d158-Date-2024-05-28_Time-18-50-28.820233.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2024-05-28 18:50:30.09031 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Wang : 1 of 1) Checking if completed file exists!
#
# 2024-05-28 18:50:30.172183 : (K562_Wang : 1 of 1) Arrow Exists! Overriding since not completed!, 0.001 mins elapsed.
#
# (K562_Wang : 1 of 1) Determining Arrow Method to use!
#
# 2024-05-28 18:50:30.198182 : (K562_Wang : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.002 mins elapsed.
#
# 2024-05-28 18:50:30.214916 : (K562_Wang : 1 of 1) Tabix Bed To Temporary File, 0.002 mins elapsed.
#
# 2024-05-28 18:53:39.261284 : (K562_Wang : 1 of 1) Successful creation of Temporary File, 3.153 mins elapsed.
#
# 2024-05-28 18:53:39.272116 : (K562_Wang : 1 of 1) Creating ArrowFile From Temporary File, 3.153 mins elapsed.
#
# 2024-05-28 18:54:44.15498 : (K562_Wang : 1 of 1) Successful creation of Arrow File, 4.234 mins elapsed.
#
# 2024-05-28 18:56:11.727367 : Continuing through after error ggplot for Fragment Size Distribution, 5.694 mins elapsed.
#
#
#
#
# 2024-05-28 18:57:47.083572 : (K562_Wang : 1 of 1) CellStats : Number of Cells Pass Filter = 4551 , 7.283 mins elapsed.
#
# 2024-05-28 18:57:47.092448 : (K562_Wang : 1 of 1) CellStats : Median Frags = 15951 , 7.283 mins elapsed.
#
# 2024-05-28 18:57:47.099999 : (K562_Wang : 1 of 1) CellStats : Median TSS Enrichment = 13.899 , 7.284 mins elapsed.
#
# 2024-05-28 18:57:48.293373 : Continuing through after error ggplot for TSS by Frags, 7.303 mins elapsed.
#
#
#
#
# 2024-05-28 18:57:52.580179 : (K562_Wang : 1 of 1) Adding Additional Feature Counts!, 7.375 mins elapsed.
#
# 2024-05-28 18:59:12.908159 : (K562_Wang : 1 of 1) Removing Fragments from Filtered Cells, 8.714 mins elapsed.
#
# 2024-05-28 18:59:12.97818 : (K562_Wang : 1 of 1) Creating Filtered Arrow File, 8.715 mins elapsed.
#
# 2024-05-28 19:02:07.771921 : (K562_Wang : 1 of 1) Finished Constructing Filtered Arrow File!, 11.628 mins elapsed.
#
# 2024-05-28 19:02:08.265391 : (K562_Wang : 1 of 1) Adding TileMatrix!, 11.636 mins elapsed.
#
# 2024-05-28 19:12:00.918307 : (K562_Wang : 1 of 1) Finished Creating Arrow File, 21.514 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-3c80575d26d158-Date-2024-05-28_Time-18-50-28.820233.log

# %%
ArrowFiles
# Out:
# [1] "K562_Wang.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/3.Genome_wide_prediction/ArchR/ArchR.240527/ArchR
# samples(1): K562_Wang
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 4551
# medianTSS(1): 13.899
# medianFrags(1): 15951

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-3c80571b1728b-Date-2024-05-28_Time-19-12-27.95085.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 19:12:28.566463 : Computing Total Across All Features, 0.001 mins elapsed.
#
# 2024-05-28 19:12:30.548668 : Computing Top Features, 0.034 mins elapsed.
#
# ###########
# 2024-05-28 19:12:36.840114 : Running LSI (1 of 2) on Top Features, 0.138 mins elapsed.
# ###########
#
# 2024-05-28 19:12:36.859751 : Creating Partial Matrix, 0.139 mins elapsed.
#
# 2024-05-28 19:13:01.770733 : Computing LSI, 0.554 mins elapsed.
#
# 2024-05-28 19:14:18.278727 : Identifying Clusters, 1.829 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2024-05-28 19:14:22.885335 : Identified 6 Clusters, 1.906 mins elapsed.
#
# 2024-05-28 19:14:23.041499 : Saving LSI Iteration, 1.908 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2024-05-28 19:14:39.307737 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-3c80571b1728b-Date-2024-05-28_Time-19-12-27.95085.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2024-05-28 19:14:39.310633 : Creating Cluster Matrix on the total Group Features, 2.18 mins elapsed.
#
# 2024-05-28 19:15:01.955666 : Computing Variable Features, 2.557 mins elapsed.
#
# ###########
# 2024-05-28 19:15:02.154548 : Running LSI (2 of 2) on Variable Features, 2.56 mins elapsed.
# ###########
#
# 2024-05-28 19:15:02.172288 : Creating Partial Matrix, 2.561 mins elapsed.
#
# 2024-05-28 19:15:21.511918 : Computing LSI, 2.883 mins elapsed.
#
# 2024-05-28 19:16:25.943018 : Finished Running IterativeLSI, 3.957 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-3c80571fb84ebd-Date-2024-05-28_Time-19-16-30.042286.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 19:16:30.3338 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-05-28 19:16:31.136252 : Adding K562_Wang to PeakMatrix for Chr (1 of 23)!, 0.012 mins elapsed.
#
# 2024-05-28 19:16:44.10738 : Adding K562_Wang to PeakMatrix for Chr (2 of 23)!, 0.228 mins elapsed.
#
# 2024-05-28 19:16:54.605701 : Adding K562_Wang to PeakMatrix for Chr (3 of 23)!, 0.403 mins elapsed.
#
# 2024-05-28 19:17:04.624481 : Adding K562_Wang to PeakMatrix for Chr (4 of 23)!, 0.57 mins elapsed.
#
# 2024-05-28 19:17:22.049528 : Adding K562_Wang to PeakMatrix for Chr (5 of 23)!, 0.86 mins elapsed.
#
# 2024-05-28 19:17:32.898325 : Adding K562_Wang to PeakMatrix for Chr (6 of 23)!, 1.041 mins elapsed.
#
# 2024-05-28 19:17:45.334627 : Adding K562_Wang to PeakMatrix for Chr (7 of 23)!, 1.248 mins elapsed.
#
# 2024-05-28 19:18:06.190256 : Adding K562_Wang to PeakMatrix for Chr (8 of 23)!, 1.596 mins elapsed.
#
# 2024-05-28 19:18:19.207753 : Adding K562_Wang to PeakMatrix for Chr (9 of 23)!, 1.813 mins elapsed.
#
# 2024-05-28 19:18:37.359697 : Adding K562_Wang to PeakMatrix for Chr (10 of 23)!, 2.116 mins elapsed.
#
# 2024-05-28 19:18:50.540892 : Adding K562_Wang to PeakMatrix for Chr (11 of 23)!, 2.335 mins elapsed.
#
# 2024-05-28 19:19:02.639353 : Adding K562_Wang to PeakMatrix for Chr (12 of 23)!, 2.537 mins elapsed.
#
# 2024-05-28 19:19:13.884811 : Adding K562_Wang to PeakMatrix for Chr (13 of 23)!, 2.724 mins elapsed.
#
# 2024-05-28 19:19:22.575994 : Adding K562_Wang to PeakMatrix for Chr (14 of 23)!, 2.869 mins elapsed.
#
# 2024-05-28 19:19:31.196914 : Adding K562_Wang to PeakMatrix for Chr (15 of 23)!, 3.013 mins elapsed.
#
# 2024-05-28 19:19:39.576416 : Adding K562_Wang to PeakMatrix for Chr (16 of 23)!, 3.152 mins elapsed.
#
# 2024-05-28 19:19:49.044834 : Adding K562_Wang to PeakMatrix for Chr (17 of 23)!, 3.31 mins elapsed.
#
# 2024-05-28 19:19:59.973506 : Adding K562_Wang to PeakMatrix for Chr (18 of 23)!, 3.492 mins elapsed.
#
# 2024-05-28 19:20:07.223331 : Adding K562_Wang to PeakMatrix for Chr (19 of 23)!, 3.613 mins elapsed.
#
# 2024-05-28 19:20:16.0961 : Adding K562_Wang to PeakMatrix for Chr (20 of 23)!, 3.761 mins elapsed.
#
# 2024-05-28 19:20:24.097595 : Adding K562_Wang to PeakMatrix for Chr (21 of 23)!, 3.895 mins elapsed.
#
# 2024-05-28 19:20:45.543568 : Adding K562_Wang to PeakMatrix for Chr (22 of 23)!, 4.252 mins elapsed.
#
# 2024-05-28 19:20:51.495075 : Adding K562_Wang to PeakMatrix for Chr (23 of 23)!, 4.351 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-3c80571fb84ebd-Date-2024-05-28_Time-19-16-30.042286.log

# %%
seRNA = import10xFeatureMatrix(c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/geo/cellranger_res/GSE162798_01/outs/raw_feature_bc_matrix.h5"),
                               c("K562_Wang"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61218 4551
# metadata(0):
# assays(1): counts
# rownames(61218): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(4551): K562_Wang#CCTATATTCAATGAGG-1
#   K562_Wang#TGTGGCTCATTTAAGC-1 ... K562_Wang#AGGATATAGTGAACGA-1
#   K562_Wang#GACTAATGTGAACAAA-1
# colData names(0):

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-3c80575f1acd1f-Date-2024-05-28_Time-19-26-17.40754.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2024-05-28 19:26:32.952991 :
#
# Overlap Per Sample w/ scATAC : K562_Wang=4551
#
# 2024-05-28 19:26:33.016258 :
#
# 2024-05-28 19:26:35.227806 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2024-05-28 19:26:55.323408 : Adding K562_Wang to GeneExpressionMatrix for Chr (1 of 23)!, 0.335 mins elapsed.
#
# 2024-05-28 19:27:05.750248 : Adding K562_Wang to GeneExpressionMatrix for Chr (2 of 23)!, 0.509 mins elapsed.
#
# 2024-05-28 19:27:12.968711 : Adding K562_Wang to GeneExpressionMatrix for Chr (3 of 23)!, 0.629 mins elapsed.
#
# 2024-05-28 19:27:24.260461 : Adding K562_Wang to GeneExpressionMatrix for Chr (4 of 23)!, 0.817 mins elapsed.
#
# 2024-05-28 19:27:37.093963 : Adding K562_Wang to GeneExpressionMatrix for Chr (5 of 23)!, 1.031 mins elapsed.
#
# 2024-05-28 19:27:49.309856 : Adding K562_Wang to GeneExpressionMatrix for Chr (6 of 23)!, 1.235 mins elapsed.
#
# 2024-05-28 19:28:00.425489 : Adding K562_Wang to GeneExpressionMatrix for Chr (7 of 23)!, 1.42 mins elapsed.
#
# 2024-05-28 19:28:07.861628 : Adding K562_Wang to GeneExpressionMatrix for Chr (8 of 23)!, 1.544 mins elapsed.
#
# 2024-05-28 19:28:16.130427 : Adding K562_Wang to GeneExpressionMatrix for Chr (9 of 23)!, 1.682 mins elapsed.
#
# 2024-05-28 19:28:26.743841 : Adding K562_Wang to GeneExpressionMatrix for Chr (10 of 23)!, 1.859 mins elapsed.
#
# 2024-05-28 19:28:33.702533 : Adding K562_Wang to GeneExpressionMatrix for Chr (11 of 23)!, 1.975 mins elapsed.
#
# 2024-05-28 19:28:41.762078 : Adding K562_Wang to GeneExpressionMatrix for Chr (12 of 23)!, 2.109 mins elapsed.
#
# 2024-05-28 19:28:52.573751 : Adding K562_Wang to GeneExpressionMatrix for Chr (13 of 23)!, 2.289 mins elapsed.
#
# 2024-05-28 19:29:01.955247 : Adding K562_Wang to GeneExpressionMatrix for Chr (14 of 23)!, 2.445 mins elapsed.
#
# 2024-05-28 19:29:09.611126 : Adding K562_Wang to GeneExpressionMatrix for Chr (15 of 23)!, 2.573 mins elapsed.
#
# 2024-05-28 19:29:19.856093 : Adding K562_Wang to GeneExpressionMatrix for Chr (16 of 23)!, 2.744 mins elapsed.
#
# 2024-05-28 19:29:30.89771 : Adding K562_Wang to GeneExpressionMatrix for Chr (17 of 23)!, 2.928 mins elapsed.
#
# 2024-05-28 19:29:49.667424 : Adding K562_Wang to GeneExpressionMatrix for Chr (18 of 23)!, 3.241 mins elapsed.
#
# 2024-05-28 19:30:06.775272 : Adding K562_Wang to GeneExpressionMatrix for Chr (19 of 23)!, 3.526 mins elapsed.
#
# 2024-05-28 19:30:14.320469 : Adding K562_Wang to GeneExpressionMatrix for Chr (20 of 23)!, 3.652 mins elapsed.
#
# 2024-05-28 19:30:21.521462 : Adding K562_Wang to GeneExpressionMatrix for Chr (21 of 23)!, 3.772 mins elapsed.
#
# 2024-05-28 19:30:33.441983 : Adding K562_Wang to GeneExpressionMatrix for Chr (22 of 23)!, 3.97 mins elapsed.
#
# 2024-05-28 19:30:42.061423 : Adding K562_Wang to GeneExpressionMatrix for Chr (23 of 23)!, 4.114 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-3c80575f1acd1f-Date-2024-05-28_Time-19-26-17.40754.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-3c805747fe9924-Date-2024-05-28_Time-19-30-53.352292.log
# If there is an issue, please report to github with logFile!
#
# 2024-05-28 19:30:53.721764 : Getting Available Matrices, 0.006 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2024-05-28 19:30:54.357637 : Filtered Low Prediction Score Cells (0 of 4551, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2024-05-28 19:30:54.60557 : Computing KNN, 0.005 mins elapsed.
#
# 2024-05-28 19:30:55.035003 : Identifying Non-Overlapping KNN pairs, 0.012 mins elapsed.
#
# 2024-05-28 19:30:57.465465 : Identified 500 Groupings!, 0.052 mins elapsed.
#
# 2024-05-28 19:30:57.539551 : Getting Group RNA Matrix, 0.054 mins elapsed.
#
# 2024-05-28 19:31:28.253423 : Getting Group ATAC Matrix, 0.565 mins elapsed.
#
# 2024-05-28 19:32:10.974232 : Normalizing Group Matrices, 1.277 mins elapsed.
#
# 2024-05-28 19:32:22.728278 : Finding Peak Gene Pairings, 1.473 mins elapsed.
#
# 2024-05-28 19:32:25.518572 : Computing Correlations, 1.52 mins elapsed.
#
# 2024-05-28 19:33:00.084572 : Completed Peak2Gene Correlations!, 2.096 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-3c805747fe9924-Date-2024-05-28_Time-19-30-53.352292.log

# %%
execution_time
# Out:
# Time difference of 2.112789 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 9186338 rows and 7 columns
#                                   idxATAC    idxRNA Correlation        FDR
#                                 <integer> <integer>   <numeric>  <numeric>
# chr1-10076-10384_DDX11L1                1         1         NaN        NaN
# chr1-115531-115905_DDX11L1              2         1         NaN        NaN
# chr1-138931-139302_DDX11L1              3         1         NaN        NaN
# chr1-180745-181204_DDX11L1              4         1         NaN        NaN
# chr1-181343-181653_DDX11L1              5         1         NaN        NaN
# ...                                   ...       ...         ...        ...
# chrX-156001062-156001946_WASH6P    153711     60642  -0.1041707 0.06097910
# chrX-156002345-156003202_WASH6P    153712     60642  -0.1424233 0.00719054
# chrX-156025240-156025503_WASH6P    153713     60642   0.0274520 0.68742435
# chrX-156029994-156030343_WASH6P    153714     60642  -0.0625612 0.30017836
# chrX-156030510-156030708_WASH6P    153715     60642  -0.0208697 0.76715413
#                                  VarQATAC   VarQRNA               PairName
#                                 <numeric> <numeric>            <character>
# chr1-10076-10384_DDX11L1        0.1690987  0.175423 chr1-10076-10384_DDX..
# chr1-115531-115905_DDX11L1      0.7556712  0.175423 chr1-115531-115905_D..
# chr1-138931-139302_DDX11L1      0.1692613  0.175423 chr1-138931-139302_D..
# chr1-180745-181204_DDX11L1      0.3299808  0.175423 chr1-180745-181204_D..
# chr1-181343-181653_DDX11L1      0.0189702  0.175423 chr1-181343-181653_D..
# ...                                   ...       ...                    ...
# chrX-156001062-156001946_WASH6P 0.9059949  0.747947 chrX-156001062-15600..
# chrX-156002345-156003202_WASH6P 0.8314478  0.747947 chrX-156002345-15600..
# chrX-156025240-156025503_WASH6P 0.0233679  0.747947 chrX-156025240-15602..
# chrX-156029994-156030343_WASH6P 0.1616563  0.747947 chrX-156029994-15603..
# chrX-156030510-156030708_WASH6P 0.0420128  0.747947 chrX-156030510-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 2682148 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028738-100029317      * |         AGL
#         [2]     chr1 100028738-100029317      * |      CDC14A
#         [3]     chr1 100028738-100029317      * |         DBT
#         [4]     chr1 100028738-100029317      * |        DPH5
#         [5]     chr1 100028738-100029317      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2682144]     chrX     9940445-9940756      * |       TBL1X
#   [2682145]     chrX     9940445-9940756      * |        WWC3
#   [2682146]     chrX     9995833-9996097      * |       FAM9B
#   [2682147]     chrX     9995833-9996097      * |       TBL1X
#   [2682148]     chrX     9995833-9996097      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028738-10002.. chr1-100028738-10002..  0.08290680
#         [2] chr1-100028738-10002.. chr1-100028738-10002.. -0.00388962
#         [3] chr1-100028738-10002.. chr1-100028738-10002.. -0.03954558
#         [4] chr1-100028738-10002.. chr1-100028738-10002..  0.12867291
#         [5] chr1-100028738-10002.. chr1-100028738-10002..  0.07805155
#         ...                    ...                    ...         ...
#   [2682144]   chrX-9940445-9940756 chrX-9940445-9940756..   0.0713229
#   [2682145]   chrX-9940445-9940756 chrX-9940445-9940756..  -0.0417370
#   [2682146]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0923530
#   [2682147]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0602284
#   [2682148]   chrX-9995833-9996097 chrX-9995833-9996097..  -0.1536144
#                    FDR  VarQATAC   VarQRNA
#              <numeric> <numeric> <numeric>
#         [1]  0.1505776  0.292489  0.925002
#         [2]  0.9603717  0.292489  0.932588
#         [3]  0.5418395  0.292489  0.895501
#         [4]  0.0167797  0.292489  0.962287
#         [5]  0.1802258  0.292489  0.904423
#         ...        ...       ...       ...
#   [2682144] 0.22759920 0.0117815  0.961561
#   [2682145] 0.51635551 0.0117815  0.729297
#   [2682146] 0.10322628 0.1573366  0.742390
#   [2682147] 0.32153881 0.1573366  0.961561
#   [2682148] 0.00337019 0.1573366  0.729297
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 2682148 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028738-100029317      * |         AGL
#         [2]     chr1 100028738-100029317      * |      CDC14A
#         [3]     chr1 100028738-100029317      * |         DBT
#         [4]     chr1 100028738-100029317      * |        DPH5
#         [5]     chr1 100028738-100029317      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2682144]     chrX     9940445-9940756      * |       TBL1X
#   [2682145]     chrX     9940445-9940756      * |        WWC3
#   [2682146]     chrX     9995833-9996097      * |       FAM9B
#   [2682147]     chrX     9995833-9996097      * |       TBL1X
#   [2682148]     chrX     9995833-9996097      * |        WWC3
#                           PeakName               PairName Correlation
#                        <character>            <character>   <numeric>
#         [1] chr1-100028738-10002.. chr1-100028738-10002..  0.08290680
#         [2] chr1-100028738-10002.. chr1-100028738-10002.. -0.00388962
#         [3] chr1-100028738-10002.. chr1-100028738-10002.. -0.03954558
#         [4] chr1-100028738-10002.. chr1-100028738-10002..  0.12867291
#         [5] chr1-100028738-10002.. chr1-100028738-10002..  0.07805155
#         ...                    ...                    ...         ...
#   [2682144]   chrX-9940445-9940756 chrX-9940445-9940756..   0.0713229
#   [2682145]   chrX-9940445-9940756 chrX-9940445-9940756..  -0.0417370
#   [2682146]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0923530
#   [2682147]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0602284
#   [2682148]   chrX-9995833-9996097 chrX-9995833-9996097..  -0.1536144
#                    FDR  VarQATAC   VarQRNA
#              <numeric> <numeric> <numeric>
#         [1]  0.1505776  0.292489  0.925002
#         [2]  0.9603717  0.292489  0.932588
#         [3]  0.5418395  0.292489  0.895501
#         [4]  0.0167797  0.292489  0.962287
#         [5]  0.1802258  0.292489  0.904423
#         ...        ...       ...       ...
#   [2682144] 0.22759920 0.0117815  0.961561
#   [2682145] 0.51635551 0.0117815  0.729297
#   [2682146] 0.10322628 0.1573366  0.742390
#   [2682147] 0.32153881 0.1573366  0.961561
#   [2682148] 0.00337019 0.1573366  0.729297
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType Correlation  FDR
# 1       chr1 100028738 100029317 AGL        K562      0.082906800 1.505776e-01
# 2       chr1 100028738 100029317 CDC14A     K562     -0.003889625 9.603717e-01
# 3       chr1 100028738 100029317 DBT        K562     -0.039545578 5.418395e-01
# 4       chr1 100028738 100029317 DPH5       K562      0.128672909 1.677968e-02
# 5       chr1 100028738 100029317 EXTL2      K562      0.078051552 1.802258e-01
# 6       chr1 100028738 100029317 FRRS1      K562     -0.065572357 2.738561e-01
# 7       chr1 100028738 100029317 LRRC39     K562      0.056337737 3.588633e-01
# 8       chr1 100028738 100029317 MFSD14A    K562     -0.005087204 9.477435e-01
# 9       chr1 100028738 100029317 PALMD      K562      0.032802045 6.222892e-01
# 10      chr1 100028738 100029317 PLPPR4     K562     -0.094508788 9.420628e-02
# 11      chr1 100028738 100029317 RTCA       K562     -0.010058551 8.934256e-01
# 12      chr1 100028738 100029317 RTCA-AS1   K562     -0.075672771 1.961247e-01
# 13      chr1 100028738 100029317 SASS6      K562     -0.088854663 1.192420e-01
# 14      chr1 100028738 100029317 SLC30A7    K562      0.249093005 3.582587e-07
# 15      chr1 100028738 100029317 SLC35A3    K562      0.042560324 5.068749e-01
# 16      chr1 100028738 100029317 TRMT13     K562      0.086166997 1.327415e-01
# 17      chr1 100029410 100029652 AGL        K562     -0.016839971 8.152046e-01
# 18      chr1 100029410 100029652 CDC14A     K562     -0.064536939 2.827486e-01
# 19      chr1 100029410 100029652 DBT        K562      0.012192055 8.692723e-01
# 20      chr1 100029410 100029652 DPH5       K562     -0.232894082 2.417375e-06
# 21      chr1 100029410 100029652 EXTL2      K562     -0.063137549 2.950216e-01
# 22      chr1 100029410 100029652 FRRS1      K562      0.051137477 4.120575e-01
# 23      chr1 100029410 100029652 LRRC39     K562     -0.100881662 7.103815e-02
# 24      chr1 100029410 100029652 MFSD14A    K562      0.089945715 1.140651e-01
# 25      chr1 100029410 100029652 PALMD      K562     -0.301279114 2.610872e-10
# 26      chr1 100029410 100029652 PLPPR4     K562     -0.145431391 5.900640e-03
# 27      chr1 100029410 100029652 RTCA       K562     -0.066478941 2.662290e-01
# 28      chr1 100029410 100029652 RTCA-AS1   K562      0.106145545 5.551586e-02
# 29      chr1 100029410 100029652 SASS6      K562      0.043281989 4.986315e-01
# 30      chr1 100029410 100029652 SLC30A7    K562     -0.077523921 1.836709e-01
# ⋮       ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 2682119 chrX 9864063   9864529   TBL1X      K562     -0.134536397 1.182160e-02
# 2682120 chrX 9864063   9864529   WWC3       K562      0.059750607 3.259814e-01
# 2682121 chrX 9874033   9874283   FAM9B      K562      0.008523009 9.104992e-01
# 2682122 chrX 9874033   9874283   TBL1X      K562     -0.033587384 6.128026e-01
# 2682123 chrX 9874033   9874283   WWC3       K562      0.128130018 1.731907e-02
# 2682124 chrX 9882684   9883146   FAM9B      K562      0.068502657 2.496158e-01
# 2682125 chrX 9882684   9883146   TBL1X      K562      0.207537878 3.546735e-05
# 2682126 chrX 9882684   9883146   WWC3       K562      0.159513776 2.205520e-03
# 2682127 chrX 9885199   9885463   FAM9B      K562     -0.038930104 5.490508e-01
# 2682128 chrX 9885199   9885463   TBL1X      K562     -0.084464016 1.418425e-01
# 2682129 chrX 9885199   9885463   WWC3       K562     -0.021615045 7.581625e-01
# 2682130 chrX 9894498   9895136   FAM9B      K562      0.004873002 9.500066e-01
# 2682131 chrX 9894498   9895136   TBL1X      K562     -0.044210815 4.880776e-01
# 2682132 chrX 9894498   9895136   WWC3       K562     -0.110464629 4.492812e-02
# 2682133 chrX  989856    990611   AKAP17A    K562      0.202370537 5.867100e-05
# 2682134 chrX  989856    990611   ASMT       K562      0.150014567 4.330031e-03
# 2682135 chrX  989856    990611   ASMTL      K562      0.062047800 3.047912e-01
# 2682136 chrX  989856    990611   GTPBP6     K562      0.235511395 1.794449e-06
# 2682137 chrX  989856    990611   IL3RA      K562      0.051200460 4.113921e-01
# 2682138 chrX  989856    990611   LINC00106  K562     -0.266193356 4.037615e-08
# 2682139 chrX  989856    990611   P2RY8      K562      0.088304457 1.219240e-01
# 2682140 chrX  989856    990611   PLCXD1     K562      0.039455208 5.428984e-01
# 2682141 chrX  989856    990611   PPP2R3B    K562     -0.338252206 5.420773e-13
# 2682142 chrX  989856    990611   SLC25A6    K562      0.107295662 5.252387e-02
# 2682143 chrX 9940445   9940756   FAM9B      K562     -0.048685373 4.382877e-01
# 2682144 chrX 9940445   9940756   TBL1X      K562      0.071322869 2.275992e-01
# 2682145 chrX 9940445   9940756   WWC3       K562     -0.041737007 5.163555e-01
# 2682146 chrX 9995833   9996097   FAM9B      K562      0.092353010 1.032263e-01
# 2682147 chrX 9995833   9996097   TBL1X      K562      0.060228355 3.215388e-01
# 2682148 chrX 9995833   9996097   WWC3       K562     -0.153614422 3.370193e-03
#         VarQATAC   VarQRNA
# 1       0.2924893  0.9250025
# 2       0.2924893  0.9325880
# 3       0.2924893  0.8955015
# 4       0.2924893  0.9622869
# 5       0.2924893  0.9044227
# 6       0.2924893  0.9496224
# 7       0.2924893  0.8245111
# 8       0.2924893  0.7122291
# 9       0.2924893  0.9181920
# 10      0.2924893  0.4712246
# 11      0.2924893  0.9081660
# 12      0.2924893  0.8708816
# 13      0.2924893  0.9631279
# 14      0.2924893  0.9426965
# 15      0.2924893  0.8714422
# 16      0.2924893  0.8893011
# 17      0.0143057  0.9250025
# 18      0.0143057  0.9325880
# 19      0.0143057  0.8955015
# 20      0.0143057  0.9622869
# 21      0.0143057  0.9044227
# 22      0.0143057  0.9496224
# 23      0.0143057  0.8245111
# 24      0.0143057  0.7122291
# 25      0.0143057  0.9181920
# 26      0.0143057  0.4712246
# 27      0.0143057  0.9081660
# 28      0.0143057  0.8708816
# 29      0.0143057  0.9631279
# 30      0.0143057  0.9426965
# ⋮       ⋮          ⋮
# 2682119 0.51134892 0.9615613
# 2682120 0.51134892 0.7292965
# 2682121 0.03608626 0.7423898
# 2682122 0.03608626 0.9615613
# 2682123 0.03608626 0.7292965
# 2682124 0.27314185 0.7423898
# 2682125 0.27314185 0.9615613
# 2682126 0.27314185 0.7292965
# 2682127 0.10931269 0.7423898
# 2682128 0.10931269 0.9615613
# 2682129 0.10931269 0.7292965
# 2682130 0.35031715 0.7423898
# 2682131 0.35031715 0.9615613
# 2682132 0.35031715 0.7292965
# 2682133 0.94445565 0.8853765
# 2682134 0.94445565 0.4829656
# 2682135 0.94445565 0.8360377
# 2682136 0.94445565 0.8321295
# 2682137 0.94445565 0.7017084
# 2682138 0.94445565 0.8020184
# 2682139 0.94445565 0.7812407
# 2682140 0.94445565 0.9003661
# 2682141 0.94445565 0.8416774
# 2682142 0.94445565 0.9426305
# 2682143 0.01178154 0.7423898
# 2682144 0.01178154 0.9615613
# 2682145 0.01178154 0.7292965
# 2682146 0.15733663 0.7423898
# 2682147 0.15733663 0.9615613
# 2682148 0.15733663 0.7292965

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       uwot_0.1.16
#  [3] Rsamtools_2.18.0                  BSgenome.Hsapiens.UCSC.hg38_1.4.5
#  [5] BSgenome_1.68.0                   rtracklayer_1.60.1
#  [7] Biostrings_2.70.1                 XVector_0.42.0
#  [9] genomation_1.34.0                 Signac_1.13.0
# [11] Seurat_5.0.3                      SeuratObject_5.0.1
# [13] sp_2.1-4                          rhdf5_2.44.0
# [15] SummarizedExperiment_1.30.2       Biobase_2.60.0
# [17] MatrixGenerics_1.12.3             Rcpp_1.0.12
# [19] Matrix_1.6-5                      GenomicRanges_1.54.1
# [21] GenomeInfoDb_1.38.1               IRanges_2.36.0
# [23] S4Vectors_0.40.2                  BiocGenerics_0.48.1
# [25] matrixStats_1.3.0                 data.table_1.15.2
# [27] stringr_1.5.1                     plyr_1.8.9
# [29] magrittr_2.0.3                    ggplot2_3.5.1
# [31] gtable_0.3.5                      gtools_3.9.5
# [33] gridExtra_2.3                     ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            dplyr_1.1.4              withr_3.0.0
#  [61] fastmap_1.1.1            rhdf5filters_1.12.1      fansi_1.0.6
#  [64] digest_0.6.35            R6_2.5.1                 mime_0.12
#  [67] seqPattern_1.34.0        colorspace_2.1-0         Cairo_1.6-2
#  [70] scattermore_1.2          tensor_1.5               spatstat.data_3.0-4
#  [73] utf8_1.2.4               tidyr_1.3.1              generics_0.1.3
#  [76] httr_1.4.7               htmlwidgets_1.6.4        S4Arrays_1.2.1
#  [79] pkgconfig_2.0.3          impute_1.76.0            lmtest_0.9-40
#  [82] htmltools_0.5.8.1        dotCall64_1.1-1          scales_1.3.0
#  [85] png_0.1-8                tzdb_0.4.0               reshape2_1.4.4
#  [88] rjson_0.2.21             uuid_1.2-0               nlme_3.1-164
#  [91] repr_1.1.7               zoo_1.8-12               KernSmooth_2.23-22
#  [94] miniUI_0.1.1.1           restfulr_0.0.15          pillar_1.9.0
#  [97] vctrs_0.6.5              RANN_2.6.1               promises_1.3.0
# [100] xtable_1.8-4             cluster_2.1.6            evaluate_0.23
# [103] readr_2.1.5              cli_3.6.2                compiler_4.3.3
# [106] rlang_1.1.3              crayon_1.5.2             future.apply_1.11.2
# [109] labeling_0.4.3           stringi_1.8.3            gridBase_0.4-7
# [112] viridisLite_0.4.2        deldir_2.0-4             BiocParallel_1.36.0
# [115] munsell_0.5.1            lazyeval_0.2.2           spatstat.geom_3.2-9
# [118] IRkernel_1.3.2           RcppHNSW_0.6.0           hms_1.1.3
# [121] patchwork_1.2.0          bit64_4.0.5              future_1.33.2
# [124] Rhdf5lib_1.22.1          shiny_1.8.1.1            ROCR_1.0-11
# [127] igraph_2.0.3             fastmatch_1.1-4          bit_4.0.5
