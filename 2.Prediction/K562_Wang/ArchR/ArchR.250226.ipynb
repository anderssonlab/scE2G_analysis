# %%
library(ArchR)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.3.3
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.5
#
# 	Loading Package : gtable v0.3.5
#
# 	Loading Package : ggplot2 v3.5.1
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.9
#
# 	Loading Package : stringr v1.5.1
#
# 	Loading Package : data.table v1.15.2
#
# 	Loading Package : matrixStats v1.3.0
#
# 	Loading Package : S4Vectors v0.40.2
#
# 	Loading Package : GenomicRanges v1.54.1
#
# 	Loading Package : BiocGenerics v0.48.1
#
# 	Loading Package : Matrix v1.6.5
#
# 	Loading Package : Rcpp v1.0.12
#
# 	Loading Package : SummarizedExperiment v1.30.2
#
# 	Loading Package : rhdf5 v2.44.0
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘sp’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# ‘SeuratObject’ was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall ‘SeuratObject’ as the ABI
# for R may have changed
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
#
# Attaching package: ‘Seurat’
#
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘Biostrings::pattern’ by ‘grid::pattern’ when loading ‘genomation’”

# %% [markdown]
# Specify file path

# %%
gene_gtf_path = "/maps/projects/ralab/data/genome/hg38/gencode.v43.chr_patch_hapl_scaff.annotation.gtf"
abc_genes_path = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/241203/scE2G/ENCODE_rE2G/ABC/reference/hg38/CollapsedGeneBounds.hg38.TSS500bp.bed"
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/1.prepare_data/1.seurat_pipeline.240507/obj.seurat.qc.rds"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_Wang/K562/Kendall/Pairs.tsv.gz"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/3.Genome_wide_prediction/ArchR_250226/ArchR.250226/"

# %%
n.cores = 16
maxDist = 1000000

# %%
addArchRThreads(threads = n.cores) 
addArchRGenome("hg38")
# Out:
# Setting default number of Parallel threads to 16.
#
# Setting default genome to Hg38.

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Create an ArchRProject

# %%
str(Fragments(obj.seurat))
# Out:
# List of 1
#  $ :Formal class 'Fragment' [package "Signac"] with 3 slots
#   .. ..@ path : chr "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/geo/cellranger_res/GSE1"| __truncated__
#   .. ..@ hash : chr [1:2] "ed3e8fdfffa0e7cea75003307869d5ce" "124adcbdbfec73546f348dde2eb879e6"
#   .. ..@ cells: Named chr [1:4574] "AAACAGCCAATGCCCG-1" "AAACAGCCACCCTCAC-1" "AAACAGCCACCTACTT-1" "AAACATGCAACTAACT-1" ...
#   .. .. ..- attr(*, "names")= chr [1:4574] "K562_Wang_AAACAGCCAATGCCCG-1" "K562_Wang_AAACAGCCACCCTCAC-1" "K562_Wang_AAACAGCCACCTACTT-1" "K562_Wang_AAACATGCAACTAACT-1" ...

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = c(Fragments(obj.seurat)[[1]]@path),
  sampleNames = c("K562_Wang"),
  validBarcodes = list(K562_Wang = unname(Fragments(obj.seurat)[[1]]@cells)),
  addTileMat = T,
  addGeneScoreMat = F,
  force = T
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-2a52567c171baa-Date-2025-02-26_Time-14-48-49.211254.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2025-02-26 14:48:49.697407 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# (K562_Wang : 1 of 1) Determining Arrow Method to use!
#
# 2025-02-26 14:48:49.764073 : (K562_Wang : 1 of 1) Reading In Fragments from inputFiles (readMethod = tabix), 0.001 mins elapsed.
#
# 2025-02-26 14:48:49.774087 : (K562_Wang : 1 of 1) Tabix Bed To Temporary File, 0.001 mins elapsed.
#
# 2025-02-26 14:50:03.289682 : (K562_Wang : 1 of 1) Successful creation of Temporary File, 1.227 mins elapsed.
#
# 2025-02-26 14:50:03.298966 : (K562_Wang : 1 of 1) Creating ArrowFile From Temporary File, 1.227 mins elapsed.
#
# 2025-02-26 14:50:33.374936 : (K562_Wang : 1 of 1) Successful creation of Arrow File, 1.728 mins elapsed.
#
# 2025-02-26 14:50:54.766449 : Continuing through after error ggplot for Fragment Size Distribution, 2.084 mins elapsed.
#
#
#
#
# 2025-02-26 14:51:26.674739 : (K562_Wang : 1 of 1) CellStats : Number of Cells Pass Filter = 4551 , 2.616 mins elapsed.
#
# 2025-02-26 14:51:26.681231 : (K562_Wang : 1 of 1) CellStats : Median Frags = 15951 , 2.616 mins elapsed.
#
# 2025-02-26 14:51:26.689396 : (K562_Wang : 1 of 1) CellStats : Median TSS Enrichment = 13.899 , 2.617 mins elapsed.
#
# 2025-02-26 14:51:28.127735 : Continuing through after error ggplot for TSS by Frags, 2.641 mins elapsed.
#
#
#
#
# 2025-02-26 14:51:31.364013 : (K562_Wang : 1 of 1) Adding Additional Feature Counts!, 2.694 mins elapsed.
#
# 2025-02-26 14:51:56.585064 : (K562_Wang : 1 of 1) Removing Fragments from Filtered Cells, 3.115 mins elapsed.
#
# 2025-02-26 14:51:56.599586 : (K562_Wang : 1 of 1) Creating Filtered Arrow File, 3.115 mins elapsed.
#
# 2025-02-26 14:53:10.621516 : (K562_Wang : 1 of 1) Finished Constructing Filtered Arrow File!, 4.349 mins elapsed.
#
# 2025-02-26 14:53:10.841158 : (K562_Wang : 1 of 1) Adding TileMatrix!, 4.352 mins elapsed.
#
# 2025-02-26 14:57:31.64037 : (K562_Wang : 1 of 1) Finished Creating Arrow File, 8.699 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-2a52567c171baa-Date-2025-02-26_Time-14-48-49.211254.log

# %%
ArrowFiles
# Out:
# [1] "K562_Wang.arrow"

# %%
dir.create(paste(dir.output,"ArchR",sep="/"),recursive = T)

# %%
obj.ArchR <- ArchRProject(
  ArrowFiles = ArrowFiles, 
  outputDirectory = paste(dir.output,"ArchR",sep="/"),
  copyArrows = TRUE 
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Validating Arrows...
#
# Getting SampleNames...
#
# 1
#
#
# Copying ArrowFiles to Ouptut Directory! If you want to save disk space set copyArrows = FALSE
#
# 1
#
#
# Getting Cell Metadata...
#
# 1
#
#
# Merging Cell Metadata...
#
# Initializing ArchRProject...
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
obj.ArchR
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_Wang/3.Genome_wide_prediction/ArchR_250226/ArchR.250226/ArchR
# samples(1): K562_Wang
# sampleColData names(1): ArrowFiles
# cellColData names(13): Sample TSSEnrichment ... nDiFrags BlacklistRatio
# numberOfCells(1): 4551
# medianTSS(1): 13.899
# medianFrags(1): 15951

# %%
obj.ArchR = addIterativeLSI(
    ArchRProj = obj.ArchR,
    useMatrix = "TileMatrix", 
    name = "IterativeLSI"
)
# Out:
# Checking Inputs...
#
# ArchR logging to : ArchRLogs/ArchR-addIterativeLSI-2a52565921cd7e-Date-2025-02-26_Time-14-57-40.372031.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 14:57:41.014359 : Computing Total Across All Features, 0 mins elapsed.
#
# 2025-02-26 14:57:42.121436 : Computing Top Features, 0.019 mins elapsed.
#
# ###########
# 2025-02-26 14:57:45.072613 : Running LSI (1 of 2) on Top Features, 0.068 mins elapsed.
# ###########
#
# 2025-02-26 14:57:45.086149 : Creating Partial Matrix, 0.068 mins elapsed.
#
# 2025-02-26 14:57:59.726903 : Computing LSI, 0.312 mins elapsed.
#
# 2025-02-26 14:58:38.496402 : Identifying Clusters, 0.958 mins elapsed.
#
# Warning message:
# “Data is of class matrix. Coercing to dgCMatrix.”
# 2025-02-26 14:58:43.473487 : Identified 6 Clusters, 1.041 mins elapsed.
#
# 2025-02-26 14:58:43.489659 : Saving LSI Iteration, 1.042 mins elapsed.
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by ‘spam’
# ************************************************************
# 2025-02-26 14:58:58.568446 : ERROR Found in .saveIteration for
# LogFile = ArchRLogs/ArchR-addIterativeLSI-2a52565921cd7e-Date-2025-02-26_Time-14-57-40.372031.log
#
# <simpleError in g$grobs[[legend]]: no such index at level 2
# >
#
# ************************************************************
# 2025-02-26 14:58:58.570436 : Creating Cluster Matrix on the total Group Features, 1.293 mins elapsed.
#
# 2025-02-26 14:59:16.951706 : Computing Variable Features, 1.599 mins elapsed.
#
# ###########
# 2025-02-26 14:59:17.136908 : Running LSI (2 of 2) on Variable Features, 1.602 mins elapsed.
# ###########
#
# 2025-02-26 14:59:17.219321 : Creating Partial Matrix, 1.604 mins elapsed.
#
# 2025-02-26 14:59:32.772078 : Computing LSI, 1.863 mins elapsed.
#
# 2025-02-26 15:00:09.969709 : Finished Running IterativeLSI, 2.483 mins elapsed.

# %%
obj.ArchR = addPeakSet(obj.ArchR,
                       peakSet = reduce(pairs.E2G))

# %%
obj.ArchR = addPeakMatrix(obj.ArchR)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-2a5256127da5d6-Date-2025-02-26_Time-15-00-17.811932.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 15:00:18.044651 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 15:00:18.788761 : Adding K562_Wang to PeakMatrix for Chr (1 of 23)!, 0.012 mins elapsed.
#
# 2025-02-26 15:00:30.942185 : Adding K562_Wang to PeakMatrix for Chr (2 of 23)!, 0.214 mins elapsed.
#
# 2025-02-26 15:00:38.731667 : Adding K562_Wang to PeakMatrix for Chr (3 of 23)!, 0.344 mins elapsed.
#
# 2025-02-26 15:00:46.256022 : Adding K562_Wang to PeakMatrix for Chr (4 of 23)!, 0.469 mins elapsed.
#
# 2025-02-26 15:00:53.816314 : Adding K562_Wang to PeakMatrix for Chr (5 of 23)!, 0.595 mins elapsed.
#
# 2025-02-26 15:01:00.992153 : Adding K562_Wang to PeakMatrix for Chr (6 of 23)!, 0.715 mins elapsed.
#
# 2025-02-26 15:01:08.770417 : Adding K562_Wang to PeakMatrix for Chr (7 of 23)!, 0.845 mins elapsed.
#
# 2025-02-26 15:01:15.93715 : Adding K562_Wang to PeakMatrix for Chr (8 of 23)!, 0.964 mins elapsed.
#
# 2025-02-26 15:01:21.919728 : Adding K562_Wang to PeakMatrix for Chr (9 of 23)!, 1.064 mins elapsed.
#
# 2025-02-26 15:01:28.498098 : Adding K562_Wang to PeakMatrix for Chr (10 of 23)!, 1.173 mins elapsed.
#
# 2025-02-26 15:01:35.095934 : Adding K562_Wang to PeakMatrix for Chr (11 of 23)!, 1.283 mins elapsed.
#
# 2025-02-26 15:01:44.644716 : Adding K562_Wang to PeakMatrix for Chr (12 of 23)!, 1.443 mins elapsed.
#
# 2025-02-26 15:01:52.000415 : Adding K562_Wang to PeakMatrix for Chr (13 of 23)!, 1.565 mins elapsed.
#
# 2025-02-26 15:01:58.637954 : Adding K562_Wang to PeakMatrix for Chr (14 of 23)!, 1.676 mins elapsed.
#
# 2025-02-26 15:02:04.880145 : Adding K562_Wang to PeakMatrix for Chr (15 of 23)!, 1.78 mins elapsed.
#
# 2025-02-26 15:02:11.570413 : Adding K562_Wang to PeakMatrix for Chr (16 of 23)!, 1.891 mins elapsed.
#
# 2025-02-26 15:02:18.28038 : Adding K562_Wang to PeakMatrix for Chr (17 of 23)!, 2.003 mins elapsed.
#
# 2025-02-26 15:02:25.518059 : Adding K562_Wang to PeakMatrix for Chr (18 of 23)!, 2.124 mins elapsed.
#
# 2025-02-26 15:02:30.773291 : Adding K562_Wang to PeakMatrix for Chr (19 of 23)!, 2.211 mins elapsed.
#
# 2025-02-26 15:02:38.109254 : Adding K562_Wang to PeakMatrix for Chr (20 of 23)!, 2.334 mins elapsed.
#
# 2025-02-26 15:02:44.343987 : Adding K562_Wang to PeakMatrix for Chr (21 of 23)!, 2.438 mins elapsed.
#
# 2025-02-26 15:02:53.994424 : Adding K562_Wang to PeakMatrix for Chr (22 of 23)!, 2.598 mins elapsed.
#
# 2025-02-26 15:03:01.377013 : Adding K562_Wang to PeakMatrix for Chr (23 of 23)!, 2.721 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-2a5256127da5d6-Date-2025-02-26_Time-15-00-17.811932.log

# %%
seRNA = import10xFeatureMatrix(c("/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/processed/10x_multiome_230720/geo/cellranger_res/GSE162798_01/outs/raw_feature_bc_matrix.h5"),
                               c("K562_Wang"))
# Out:
# Importing Feature Matrix 1 of 1
#
# Re-ordering RNA matricies for consistency.

# %%
seRNA = seRNA[,rownames(obj.ArchR@cellColData)]

# %%
seRNA
# Out:
# class: RangedSummarizedExperiment
# dim: 61218 4551
# metadata(0):
# assays(1): counts
# rownames(61218): DDX11L1 MIR6859-1 ... RNA5-8SN5 ENSG00000273937
# rowData names(5): feature_type genome id interval name
# colnames(4551): K562_Wang#CCTATATTCAATGAGG-1
#   K562_Wang#TGTGGCTCATTTAAGC-1 ... K562_Wang#AGGATATAGTGAACGA-1
#   K562_Wang#GACTAATGTGAACAAA-1
# colData names(0):

# %% [markdown]
# Map gene names

# %%
extract_attributes <- function(gtf_attributes, att_of_interest){
  att <- unlist(strsplit(gtf_attributes, " "))
  if(att_of_interest %in% att){
    return(gsub("\"|;","", att[which(att %in% att_of_interest)+1]))
  } else {
    return(NA)}
}
map_gene_names <- function(rna_matrix, gene_gtf_path, abc_genes_path){
    library(dplyr)
    library(data.table)
    
	gene_ref <- fread(gene_gtf_path, header = FALSE, sep = "\t") %>%
		setNames(c("chr","source","type","start","end","score","strand","phase","attributes")) %>%
		dplyr::filter(type == "gene")
	gene_ref$gene_ref_name <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_name"))
	gene_ref$Ensembl_ID <- unlist(lapply(gene_ref$attributes, extract_attributes, "gene_id"))
	gene_ref <- dplyr::select(gene_ref, gene_ref_name, Ensembl_ID) %>%
		mutate(Ensembl_ID = sub("\\.\\d+$", "", Ensembl_ID)) %>% # remove decimal digits 
		distinct()
	
	abc_genes <- fread(abc_genes_path, col.names = c("chr", "start", "end", "name", "score", "strand", "Ensembl_ID", "gene_type")) %>%
		dplyr::select(name, Ensembl_ID) %>%
		rename(abc_name = name) %>%
		left_join(gene_ref, by = "Ensembl_ID") %>%
		group_by(Ensembl_ID) %>% # remove cases where multiple genes map to one ensembl ID
		filter(n() == 1) %>%
		ungroup()

	gene_key <- abc_genes$abc_name
	names(gene_key) <- abc_genes$gene_ref_name

	# remove genes not in our gene universe	
	row_sub <- intersect(rownames(rna_matrix), names(gene_key)) # gene ref names
	rna_matrix_filt <- rna_matrix[row_sub,] # still gene ref names
	rownames(rna_matrix_filt) <- gene_key[row_sub] # converted to abc names

	return(rna_matrix_filt)
}

# %%
seRNA.rename = map_gene_names(seRNA,gene_gtf_path, abc_genes_path)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:Biostrings’:
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from ‘package:XVector’:
#
#     slice
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:gridExtra’:
#
#     combine
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
obj.ArchR = addGeneExpressionMatrix(obj.ArchR,
                                    seRNA = seRNA.rename,
                                    strictMatch = T)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a52565acb9b06-Date-2025-02-26_Time-15-03-49.799199.log
# If there is an issue, please report to github with logFile!
#
# Overlap w/ scATAC = 1
#
# 2025-02-26 15:03:50.32429 :
#
# Overlap Per Sample w/ scATAC : K562_Wang=4551
#
# 2025-02-26 15:03:50.336121 :
#
# 2025-02-26 15:03:52.88409 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2025-02-26 15:03:53.694549 : Adding K562_Wang to GeneExpressionMatrix for Chr (1 of 23)!, 0.014 mins elapsed.
#
# 2025-02-26 15:04:00.017695 : Adding K562_Wang to GeneExpressionMatrix for Chr (2 of 23)!, 0.119 mins elapsed.
#
# 2025-02-26 15:04:05.048598 : Adding K562_Wang to GeneExpressionMatrix for Chr (3 of 23)!, 0.203 mins elapsed.
#
# 2025-02-26 15:04:12.569874 : Adding K562_Wang to GeneExpressionMatrix for Chr (4 of 23)!, 0.328 mins elapsed.
#
# 2025-02-26 15:04:19.773825 : Adding K562_Wang to GeneExpressionMatrix for Chr (5 of 23)!, 0.448 mins elapsed.
#
# 2025-02-26 15:04:25.220606 : Adding K562_Wang to GeneExpressionMatrix for Chr (6 of 23)!, 0.539 mins elapsed.
#
# 2025-02-26 15:04:32.296193 : Adding K562_Wang to GeneExpressionMatrix for Chr (7 of 23)!, 0.657 mins elapsed.
#
# 2025-02-26 15:04:37.361938 : Adding K562_Wang to GeneExpressionMatrix for Chr (8 of 23)!, 0.741 mins elapsed.
#
# 2025-02-26 15:04:42.34223 : Adding K562_Wang to GeneExpressionMatrix for Chr (9 of 23)!, 0.824 mins elapsed.
#
# 2025-02-26 15:04:49.965047 : Adding K562_Wang to GeneExpressionMatrix for Chr (10 of 23)!, 0.951 mins elapsed.
#
# 2025-02-26 15:04:54.856775 : Adding K562_Wang to GeneExpressionMatrix for Chr (11 of 23)!, 1.033 mins elapsed.
#
# 2025-02-26 15:04:59.811157 : Adding K562_Wang to GeneExpressionMatrix for Chr (12 of 23)!, 1.115 mins elapsed.
#
# 2025-02-26 15:05:07.039864 : Adding K562_Wang to GeneExpressionMatrix for Chr (13 of 23)!, 1.236 mins elapsed.
#
# 2025-02-26 15:05:13.308235 : Adding K562_Wang to GeneExpressionMatrix for Chr (14 of 23)!, 1.34 mins elapsed.
#
# 2025-02-26 15:05:21.219947 : Adding K562_Wang to GeneExpressionMatrix for Chr (15 of 23)!, 1.472 mins elapsed.
#
# 2025-02-26 15:05:30.765077 : Adding K562_Wang to GeneExpressionMatrix for Chr (16 of 23)!, 1.631 mins elapsed.
#
# 2025-02-26 15:05:37.556681 : Adding K562_Wang to GeneExpressionMatrix for Chr (17 of 23)!, 1.745 mins elapsed.
#
# 2025-02-26 15:05:43.284647 : Adding K562_Wang to GeneExpressionMatrix for Chr (18 of 23)!, 1.84 mins elapsed.
#
# 2025-02-26 15:05:49.984863 : Adding K562_Wang to GeneExpressionMatrix for Chr (19 of 23)!, 1.952 mins elapsed.
#
# 2025-02-26 15:05:54.871717 : Adding K562_Wang to GeneExpressionMatrix for Chr (20 of 23)!, 2.033 mins elapsed.
#
# 2025-02-26 15:05:59.572073 : Adding K562_Wang to GeneExpressionMatrix for Chr (21 of 23)!, 2.111 mins elapsed.
#
# 2025-02-26 15:06:06.502748 : Adding K562_Wang to GeneExpressionMatrix for Chr (22 of 23)!, 2.227 mins elapsed.
#
# 2025-02-26 15:06:11.090966 : Adding K562_Wang to GeneExpressionMatrix for Chr (23 of 23)!, 2.303 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGeneExpressionMatrix-2a52565acb9b06-Date-2025-02-26_Time-15-03-49.799199.log

# %% [markdown]
# Run ArchR prediction

# %%
start_time <- Sys.time()
obj.ArchR = addPeak2GeneLinks(
    ArchRProj = obj.ArchR,
    reducedDims = "IterativeLSI",
    useMatrix = "GeneExpressionMatrix",
    maxDist = maxDist,
    threads = n.cores
)
end_time <- Sys.time()
execution_time <- end_time - start_time
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeak2GeneLinks-2a525674881716-Date-2025-02-26_Time-15-06-17.529598.log
# If there is an issue, please report to github with logFile!
#
# 2025-02-26 15:06:17.842516 : Getting Available Matrices, 0.005 mins elapsed.
#
# No predictionScore found. Continuing without predictionScore!
#
# 2025-02-26 15:06:18.175507 : Filtered Low Prediction Score Cells (0 of 4551, 0), 0 mins elapsed.
#
# Filtering 1 dims correlated > 0.75 to log10(depth + 1)
#
# 2025-02-26 15:06:18.276014 : Computing KNN, 0.002 mins elapsed.
#
# 2025-02-26 15:06:18.735977 : Identifying Non-Overlapping KNN pairs, 0.01 mins elapsed.
#
# 2025-02-26 15:06:20.576406 : Identified 500 Groupings!, 0.04 mins elapsed.
#
# 2025-02-26 15:06:20.617809 : Getting Group RNA Matrix, 0.041 mins elapsed.
#
# 2025-02-26 15:06:37.158858 : Getting Group ATAC Matrix, 0.317 mins elapsed.
#
# 2025-02-26 15:06:59.080997 : Normalizing Group Matrices, 0.682 mins elapsed.
#
# 2025-02-26 15:07:04.50558 : Finding Peak Gene Pairings, 0.773 mins elapsed.
#
# 2025-02-26 15:07:05.30347 : Computing Correlations, 0.786 mins elapsed.
#
# 2025-02-26 15:07:20.528713 : Completed Peak2Gene Correlations!, 1.04 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeak2GeneLinks-2a525674881716-Date-2025-02-26_Time-15-06-17.529598.log

# %%
execution_time
# Out:
# Time difference of 1.050559 mins

# %%
p2g = metadata(obj.ArchR@peakSet)$Peak2GeneLinks

# %%
metadata(p2g)[[1]]$PeakName = paste(seqnames(metadata(p2g)[[1]]),
                                    ranges(metadata(p2g)[[1]]),sep="-")

# %%
p2g$PairName = paste(metadata(p2g)[[1]][p2g$idxATAC]$PeakName,
                     metadata(p2g)[[2]][p2g$idxRNA]$name,
                     sep = "_")

# %%
rownames(p2g) = p2g$PairName
p2g
# Out:
# DataFrame with 3608501 rows and 7 columns
#                                 idxATAC    idxRNA Correlation         FDR
#                               <integer> <integer>   <numeric>   <numeric>
# chr1-10076-10384_FAM138A              1         1         NaN         NaN
# chr1-115531-115905_FAM138A            2         1         NaN         NaN
# chr1-138931-139302_FAM138A            3         1         NaN         NaN
# chr1-180745-181204_FAM138A            4         1         NaN         NaN
# chr1-181343-181653_FAM138A            5         1         NaN         NaN
# ...                                 ...       ...         ...         ...
# chrX-156001062-156001946_IL9R    153711     20494   0.2027357 3.94427e-05
# chrX-156002345-156003202_IL9R    153712     20494   0.1766650 4.21111e-04
# chrX-156025240-156025503_IL9R    153713     20494   0.0708646 2.07143e-01
# chrX-156029994-156030343_IL9R    153714     20494  -0.0323022 6.03283e-01
# chrX-156030510-156030708_IL9R    153715     20494  -0.0169088 7.98782e-01
#                                VarQATAC   VarQRNA               PairName
#                               <numeric> <numeric>            <character>
# chr1-10076-10384_FAM138A      0.1690987 0.0507466 chr1-10076-10384_FAM..
# chr1-115531-115905_FAM138A    0.7556712 0.0507466 chr1-115531-115905_F..
# chr1-138931-139302_FAM138A    0.1692613 0.0507466 chr1-138931-139302_F..
# chr1-180745-181204_FAM138A    0.3299808 0.0507466 chr1-180745-181204_F..
# chr1-181343-181653_FAM138A    0.0189702 0.0507466 chr1-181343-181653_F..
# ...                                 ...       ...                    ...
# chrX-156001062-156001946_IL9R 0.9059949  0.382307 chrX-156001062-15600..
# chrX-156002345-156003202_IL9R 0.8314478  0.382307 chrX-156002345-15600..
# chrX-156025240-156025503_IL9R 0.0233679  0.382307 chrX-156025240-15602..
# chrX-156029994-156030343_IL9R 0.1616563  0.382307 chrX-156029994-15603..
# chrX-156030510-156030708_IL9R 0.0420128  0.382307 chrX-156030510-15603..

# %%
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% p2g$PairName]
mcols(pairs.E2G.res)[,c("Correlation","FDR","VarQATAC","VarQRNA")] = p2g[pairs.E2G.res$PairName,c("Correlation","FDR","VarQATAC","VarQRNA")]

# %%
pairs.E2G.res
# Out:
# GRanges object with 2803268 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028738-100029317      * |         AGL
#         [2]     chr1 100028738-100029317      * |      CDC14A
#         [3]     chr1 100028738-100029317      * |         DBT
#         [4]     chr1 100028738-100029317      * |        DPH5
#         [5]     chr1 100028738-100029317      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2803264]     chrX     9940445-9940756      * |       TBL1X
#   [2803265]     chrX     9940445-9940756      * |        WWC3
#   [2803266]     chrX     9995833-9996097      * |       FAM9B
#   [2803267]     chrX     9995833-9996097      * |       TBL1X
#   [2803268]     chrX     9995833-9996097      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-100028738-10002.. chr1-100028738-10002..   0.0785478 0.1562845
#         [2] chr1-100028738-10002.. chr1-100028738-10002..  -0.0101480 0.8825721
#         [3] chr1-100028738-10002.. chr1-100028738-10002..  -0.0432920 0.4702945
#         [4] chr1-100028738-10002.. chr1-100028738-10002..   0.1266586 0.0150749
#         [5] chr1-100028738-10002.. chr1-100028738-10002..   0.0730293 0.1917841
#         ...                    ...                    ...         ...       ...
#   [2803264]   chrX-9940445-9940756 chrX-9940445-9940756..   0.0745559 0.1814526
#   [2803265]   chrX-9940445-9940756 chrX-9940445-9940756..  -0.0420563 0.4846622
#   [2803266]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0920342 0.0898625
#   [2803267]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0564851 0.3293163
#   [2803268]   chrX-9995833-9996097 chrX-9995833-9996097..  -0.1545007 0.0023940
#              VarQATAC   VarQRNA
#             <numeric> <numeric>
#         [1]  0.292489  0.798966
#         [2]  0.292489  0.804626
#         [3]  0.292489  0.716942
#         [4]  0.292489  0.900117
#         [5]  0.292489  0.744364
#         ...       ...       ...
#   [2803264] 0.0117815  0.892652
#   [2803265] 0.0117815  0.406314
#   [2803266] 0.1573366  0.420172
#   [2803267] 0.1573366  0.892652
#   [2803268] 0.1573366  0.406314
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Save results

# %%
saveRDS(obj.ArchR,
        paste(dir.output,"obj.ArchR.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "Correlation",
                         "FDR",
                         "VarQATAC",
                         "VarQRNA")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# GRanges object with 2803268 ranges and 7 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028738-100029317      * |         AGL
#         [2]     chr1 100028738-100029317      * |      CDC14A
#         [3]     chr1 100028738-100029317      * |         DBT
#         [4]     chr1 100028738-100029317      * |        DPH5
#         [5]     chr1 100028738-100029317      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [2803264]     chrX     9940445-9940756      * |       TBL1X
#   [2803265]     chrX     9940445-9940756      * |        WWC3
#   [2803266]     chrX     9995833-9996097      * |       FAM9B
#   [2803267]     chrX     9995833-9996097      * |       TBL1X
#   [2803268]     chrX     9995833-9996097      * |        WWC3
#                           PeakName               PairName Correlation       FDR
#                        <character>            <character>   <numeric> <numeric>
#         [1] chr1-100028738-10002.. chr1-100028738-10002..   0.0785478 0.1562845
#         [2] chr1-100028738-10002.. chr1-100028738-10002..  -0.0101480 0.8825721
#         [3] chr1-100028738-10002.. chr1-100028738-10002..  -0.0432920 0.4702945
#         [4] chr1-100028738-10002.. chr1-100028738-10002..   0.1266586 0.0150749
#         [5] chr1-100028738-10002.. chr1-100028738-10002..   0.0730293 0.1917841
#         ...                    ...                    ...         ...       ...
#   [2803264]   chrX-9940445-9940756 chrX-9940445-9940756..   0.0745559 0.1814526
#   [2803265]   chrX-9940445-9940756 chrX-9940445-9940756..  -0.0420563 0.4846622
#   [2803266]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0920342 0.0898625
#   [2803267]   chrX-9995833-9996097 chrX-9995833-9996097..   0.0564851 0.3293163
#   [2803268]   chrX-9995833-9996097 chrX-9995833-9996097..  -0.1545007 0.0023940
#              VarQATAC   VarQRNA
#             <numeric> <numeric>
#         [1]  0.292489  0.798966
#         [2]  0.292489  0.804626
#         [3]  0.292489  0.716942
#         [4]  0.292489  0.900117
#         [5]  0.292489  0.744364
#         ...       ...       ...
#   [2803264] 0.0117815  0.892652
#   [2803265] 0.0117815  0.406314
#   [2803266] 0.1573366  0.420172
#   [2803267] 0.1573366  0.892652
#   [2803268] 0.1573366  0.406314
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType Correlation  FDR
# 1       chr1 100028738 100029317 AGL        K562      0.078547814 1.562845e-01
# 2       chr1 100028738 100029317 CDC14A     K562     -0.010147960 8.825721e-01
# 3       chr1 100028738 100029317 DBT        K562     -0.043291982 4.702945e-01
# 4       chr1 100028738 100029317 DPH5       K562      0.126658591 1.507493e-02
# 5       chr1 100028738 100029317 EXTL2      K562      0.073029257 1.917841e-01
# 6       chr1 100028738 100029317 FRRS1      K562     -0.070390730 2.106054e-01
# 7       chr1 100028738 100029317 LRRC39     K562      0.054417442 3.497189e-01
# 8       chr1 100028738 100029317 MFSD14A    K562     -0.006558291 9.254416e-01
# 9       chr1 100028738 100029317 PALMD      K562      0.032048465 6.065120e-01
# 10      chr1 100028738 100029317 PLPPR4     K562     -0.094822031 7.940056e-02
# 11      chr1 100028738 100029317 RTCA       K562     -0.015177726 8.205285e-01
# 12      chr1 100028738 100029317 RTCA-AS1   K562     -0.076268292 1.703323e-01
# 13      chr1 100028738 100029317 SASS6      K562     -0.092018877 8.992333e-02
# 14      chr1 100028738 100029317 SLC30A7    K562      0.242729147 5.096125e-07
# 15      chr1 100028738 100029317 SLC35A3    K562      0.037842545 5.348336e-01
# 16      chr1 100028738 100029317 TRMT13     K562      0.081494068 1.394223e-01
# 17      chr1 100029410 100029652 AGL        K562     -0.019793479 7.622929e-01
# 18      chr1 100029410 100029652 CDC14A     K562     -0.070635686 2.088023e-01
# 19      chr1 100029410 100029652 DBT        K562      0.012598462 8.525403e-01
# 20      chr1 100029410 100029652 DPH5       K562     -0.233695830 1.473402e-06
# 21      chr1 100029410 100029652 EXTL2      K562     -0.065704927 2.469354e-01
# 22      chr1 100029410 100029652 FRRS1      K562      0.045809225 4.415628e-01
# 23      chr1 100029410 100029652 LRRC39     K562     -0.102253754 5.610481e-02
# 24      chr1 100029410 100029652 MFSD14A    K562      0.089044000 1.022856e-01
# 25      chr1 100029410 100029652 PALMD      K562     -0.301849317 1.488568e-10
# 26      chr1 100029410 100029652 PLPPR4     K562     -0.145532768 4.513512e-03
# 27      chr1 100029410 100029652 RTCA       K562     -0.069798139 2.149792e-01
# 28      chr1 100029410 100029652 RTCA-AS1   K562      0.105090081 4.883099e-02
# 29      chr1 100029410 100029652 SASS6      K562      0.038630780 5.253219e-01
# 30      chr1 100029410 100029652 SLC30A7    K562     -0.082578060 1.335438e-01
# ⋮       ⋮    ⋮         ⋮         ⋮          ⋮        ⋮            ⋮
# 2803239 chrX 9864063   9864529   TBL1X      K562     -0.132060587 1.086291e-02
# 2803240 chrX 9864063   9864529   WWC3       K562      0.059899400 2.971978e-01
# 2803241 chrX 9874033   9874283   FAM9B      K562      0.010235225 8.815172e-01
# 2803242 chrX 9874033   9874283   TBL1X      K562     -0.026983064 6.706844e-01
# 2803243 chrX 9874033   9874283   WWC3       K562      0.129753423 1.251778e-02
# 2803244 chrX 9882684   9883146   FAM9B      K562      0.070174841 2.121953e-01
# 2803245 chrX 9882684   9883146   TBL1X      K562      0.204683710 3.256565e-05
# 2803246 chrX 9882684   9883146   WWC3       K562      0.159862033 1.608991e-03
# 2803247 chrX 9885199   9885463   FAM9B      K562     -0.039101809 5.197063e-01
# 2803248 chrX 9885199   9885463   TBL1X      K562     -0.085110828 1.205360e-01
# 2803249 chrX 9885199   9885463   WWC3       K562     -0.022742719 7.248081e-01
# 2803250 chrX 9894498   9895136   FAM9B      K562      0.003652618 9.591882e-01
# 2803251 chrX 9894498   9895136   TBL1X      K562     -0.051243269 3.823236e-01
# 2803252 chrX 9894498   9895136   WWC3       K562     -0.110918108 3.629741e-02
# 2803253 chrX  989856    990611   AKAP17A    K562      0.202442629 4.058665e-05
# 2803254 chrX  989856    990611   ASMT       K562      0.149247950 3.486628e-03
# 2803255 chrX  989856    990611   ASMTL      K562      0.061122430 2.861070e-01
# 2803256 chrX  989856    990611   GTPBP6     K562      0.231942160 1.800711e-06
# 2803257 chrX  989856    990611   IL3RA      K562      0.048867239 4.077065e-01
# 2803258 chrX  989856    990611   LINC00106  K562     -0.267271597 2.249642e-08
# 2803259 chrX  989856    990611   P2RY8      K562      0.088440034 1.049511e-01
# 2803260 chrX  989856    990611   PLCXD1     K562      0.037820031 5.351016e-01
# 2803261 chrX  989856    990611   PPP2R3B    K562     -0.342588803 1.495773e-13
# 2803262 chrX  989856    990611   SLC25A6    K562      0.102993546 5.412816e-02
# 2803263 chrX 9940445   9940756   FAM9B      K562     -0.049341842 4.025928e-01
# 2803264 chrX 9940445   9940756   TBL1X      K562      0.074555909 1.814526e-01
# 2803265 chrX 9940445   9940756   WWC3       K562     -0.042056278 4.846622e-01
# 2803266 chrX 9995833   9996097   FAM9B      K562      0.092034219 8.986252e-02
# 2803267 chrX 9995833   9996097   TBL1X      K562      0.056485087 3.293163e-01
# 2803268 chrX 9995833   9996097   WWC3       K562     -0.154500741 2.393998e-03
#         VarQATAC   VarQRNA
# 1       0.2924893  0.7989656
# 2       0.2924893  0.8046257
# 3       0.2924893  0.7169415
# 4       0.2924893  0.9001171
# 5       0.2924893  0.7443642
# 6       0.2924893  0.8625451
# 7       0.2924893  0.5480628
# 8       0.2924893  0.3859666
# 9       0.2924893  0.7882795
# 10      0.2924893  0.1753684
# 11      0.2924893  0.7514882
# 12      0.2924893  0.6602908
# 13      0.2924893  0.8987996
# 14      0.2924893  0.8388797
# 15      0.2924893  0.6553138
# 16      0.2924893  0.6979604
# 17      0.0143057  0.7989656
# 18      0.0143057  0.8046257
# 19      0.0143057  0.7169415
# 20      0.0143057  0.9001171
# 21      0.0143057  0.7443642
# 22      0.0143057  0.8625451
# 23      0.0143057  0.5480628
# 24      0.0143057  0.3859666
# 25      0.0143057  0.7882795
# 26      0.0143057  0.1753684
# 27      0.0143057  0.7514882
# 28      0.0143057  0.6602908
# 29      0.0143057  0.8987996
# 30      0.0143057  0.8388797
# ⋮       ⋮          ⋮
# 2803239 0.51134892 0.8926515
# 2803240 0.51134892 0.4063140
# 2803241 0.03608626 0.4201718
# 2803242 0.03608626 0.8926515
# 2803243 0.03608626 0.4063140
# 2803244 0.27314185 0.4201718
# 2803245 0.27314185 0.8926515
# 2803246 0.27314185 0.4063140
# 2803247 0.10931269 0.4201718
# 2803248 0.10931269 0.8926515
# 2803249 0.10931269 0.4063140
# 2803250 0.35031715 0.4201718
# 2803251 0.35031715 0.8926515
# 2803252 0.35031715 0.4063140
# 2803253 0.94445565 0.6909827
# 2803254 0.94445565 0.1842978
# 2803255 0.94445565 0.5703621
# 2803256 0.94445565 0.5604079
# 2803257 0.94445565 0.3749878
# 2803258 0.94445565 0.5051722
# 2803259 0.94445565 0.4737972
# 2803260 0.94445565 0.7363131
# 2803261 0.94445565 0.5828535
# 2803262 0.94445565 0.8420025
# 2803263 0.01178154 0.4201718
# 2803264 0.01178154 0.8926515
# 2803265 0.01178154 0.4063140
# 2803266 0.15733663 0.4201718
# 2803267 0.15733663 0.8926515
# 2803268 0.15733663 0.4063140

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.10 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# Random number generation:
#  RNG:     L'Ecuyer-CMRG
#  Normal:  Inversion
#  Sample:  Rejection
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] nabor_0.5.0                       dplyr_1.1.4
#  [3] uwot_0.1.16                       Rsamtools_2.18.0
#  [5] BSgenome.Hsapiens.UCSC.hg38_1.4.5 BSgenome_1.68.0
#  [7] rtracklayer_1.60.1                Biostrings_2.70.1
#  [9] XVector_0.42.0                    genomation_1.34.0
# [11] Signac_1.13.0                     Seurat_5.0.3
# [13] SeuratObject_5.0.1                sp_2.1-4
# [15] rhdf5_2.44.0                      SummarizedExperiment_1.30.2
# [17] Biobase_2.60.0                    MatrixGenerics_1.12.3
# [19] Rcpp_1.0.12                       Matrix_1.6-5
# [21] GenomicRanges_1.54.1              GenomeInfoDb_1.38.1
# [23] IRanges_2.36.0                    S4Vectors_0.40.2
# [25] BiocGenerics_0.48.1               matrixStats_1.3.0
# [27] data.table_1.15.2                 stringr_1.5.1
# [29] plyr_1.8.9                        magrittr_2.0.3
# [31] ggplot2_3.5.1                     gtable_0.3.5
# [33] gtools_3.9.5                      gridExtra_2.3
# [35] ArchR_1.0.2
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.22         splines_4.3.3            later_1.3.2
#   [4] pbdZMQ_0.3-11            BiocIO_1.10.0            bitops_1.0-7
#   [7] tibble_3.2.1             polyclip_1.10-6          XML_3.99-0.16.1
#  [10] fastDummies_1.7.3        lifecycle_1.0.4          vroom_1.6.5
#  [13] globals_0.16.3           lattice_0.22-6           MASS_7.3-60
#  [16] plotly_4.10.4            plotrix_3.8-4            yaml_2.3.8
#  [19] httpuv_1.6.15            sctransform_0.4.1        spam_2.10-0
#  [22] spatstat.sparse_3.0-3    reticulate_1.36.1        cowplot_1.1.3
#  [25] pbapply_1.7-2            RColorBrewer_1.1-3       abind_1.4-5
#  [28] zlibbioc_1.48.0          Rtsne_0.17               purrr_1.0.2
#  [31] RCurl_1.98-1.14          GenomeInfoDbData_1.2.11  ggrepel_0.9.5
#  [34] irlba_2.3.5.1            listenv_0.9.1            spatstat.utils_3.0-4
#  [37] goftest_1.2-3            RSpectra_0.16-1          spatstat.random_3.2-3
#  [40] fitdistrplus_1.1-11      parallelly_1.37.1        leiden_0.4.3.1
#  [43] codetools_0.2-20         DelayedArray_0.26.7      RcppRoll_0.3.0
#  [46] tidyselect_1.2.1         farver_2.1.1             base64enc_0.1-3
#  [49] spatstat.explore_3.2-6   GenomicAlignments_1.36.0 jsonlite_1.8.8
#  [52] progressr_0.14.0         ggridges_0.5.6           survival_3.6-4
#  [55] tools_4.3.3              ica_1.0-3                glue_1.7.0
#  [58] IRdisplay_1.1            withr_3.0.0              fastmap_1.1.1
#  [61] rhdf5filters_1.12.1      fansi_1.0.6              digest_0.6.35
#  [64] R6_2.5.1                 mime_0.12                seqPattern_1.34.0
#  [67] colorspace_2.1-0         Cairo_1.6-2              scattermore_1.2
#  [70] tensor_1.5               spatstat.data_3.0-4      utf8_1.2.4
#  [73] tidyr_1.3.1              generics_0.1.3           httr_1.4.7
#  [76] htmlwidgets_1.6.4        S4Arrays_1.2.1           pkgconfig_2.0.3
#  [79] impute_1.76.0            lmtest_0.9-40            htmltools_0.5.8.1
#  [82] dotCall64_1.1-1          scales_1.3.0             png_0.1-8
#  [85] tzdb_0.4.0               reshape2_1.4.4           rjson_0.2.21
#  [88] uuid_1.2-0               nlme_3.1-164             repr_1.1.7
#  [91] zoo_1.8-12               KernSmooth_2.23-22       miniUI_0.1.1.1
#  [94] restfulr_0.0.15          pillar_1.9.0             vctrs_0.6.5
#  [97] RANN_2.6.1               promises_1.3.0           xtable_1.8-4
# [100] cluster_2.1.6            evaluate_0.23            readr_2.1.5
# [103] cli_3.6.2                compiler_4.3.3           rlang_1.1.3
# [106] crayon_1.5.2             future.apply_1.11.2      labeling_0.4.3
# [109] stringi_1.8.3            gridBase_0.4-7           viridisLite_0.4.2
# [112] deldir_2.0-4             BiocParallel_1.36.0      munsell_0.5.1
# [115] lazyeval_0.2.2           spatstat.geom_3.2-9      IRkernel_1.3.2
# [118] RcppHNSW_0.6.0           hms_1.1.3                patchwork_1.2.0
# [121] bit64_4.0.5              future_1.33.2            Rhdf5lib_1.22.1
# [124] shiny_1.8.1.1            ROCR_1.0-11              igraph_2.0.3
# [127] fastmatch_1.1-4          bit_4.0.5
