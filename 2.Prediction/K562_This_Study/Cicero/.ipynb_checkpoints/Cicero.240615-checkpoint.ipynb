# %%
library(cicero)
library(Seurat)
library(Signac)
library(magrittr)
library(genomation)
library(GenomicRanges)
library(Matrix)
library(ggplot2)
# Out:
# Loading required package: monocle3
#
# Loading required package: Biobase
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# The following object is masked from ‘package:Biobase’:
#
#     rowMedians
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
#
# Attaching package: ‘monocle3’
#
#
# The following objects are masked from ‘package:Biobase’:
#
#     exprs, fData, fData<-, pData, pData<-
#
#
# Loading required package: Gviz
#
# Loading required package: grid
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: 'sp'
#
#
# The following object is masked from 'package:IRanges':
#
#     %over%
#
#
# 'SeuratObject' was built under R 4.3.2 but the current version is
# 4.3.3; it is recomended that you reinstall 'SeuratObject' as the ABI
# for R may have changed
#
# 'SeuratObject' was built with package 'Matrix' 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall 'SeuratObject' as
# the ABI for 'Matrix' may have changed
#
#
# Attaching package: 'SeuratObject'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     intersect
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following object is masked from 'package:IRanges':
#
#     intersect
#
#
# The following object is masked from 'package:S4Vectors':
#
#     intersect
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     intersect
#
#
# The following object is masked from 'package:base':
#
#     intersect
#
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:SummarizedExperiment':
#
#     Assays
#
#
#
# Attaching package: 'magrittr'
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     subtract
#
#
# Warning message:
# "replacing previous import 'Biostrings::pattern' by 'grid::pattern' when loading 'genomation'"
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand

# %% [markdown]
# Specify file path

# %%
path.seurat = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_IGVF/1.prepare_data/1.import_IGVF_processed_data.240508/obj.seurat.rds"
path.matrix.atac_count = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_IGVF/K562/Kendall/atac_matrix.csv.gz"
path.pairs.E2G = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_IGVF/K562/Kendall/Pairs.tsv.gz"
path.TSS1kb = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/test/results_K562_IGVF/K562/Neighborhoods//GeneList.TSS1kb.bed"
path.chrom.sizes = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/software/scE2G_pipeline/240508/sc-E2G/ENCODE_rE2G/ABC/reference/hg38/GRCh38_EBV.chrom.sizes.tsv"
dir.output = "/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_IGVF/3.Genome_wide_prediction/Cicero/Cicero.240525/"

# %%
distance_constraint = 1000000 
window = 2000000

# %% [markdown]
# Import seurat object

# %%
obj.seurat = readRDS(path.seurat)

# %% [markdown]
# Import ATAC matrix

# %%
matrix.atac_count = read.csv(path.matrix.atac_count,
                             row.names = 1,
                             check.names = F)
matrix.atac_count = Matrix(as.matrix(matrix.atac_count), sparse = TRUE)
matrix.atac = BinarizeCounts(matrix.atac_count)
rm(matrix.atac_count)

# %% [markdown]
# Import candidate E-G pairs

# %%
pairs.E2G = readGeneric(path.pairs.E2G,
                        header = T,
                        keep.all.metadata = T)

# %% [markdown]
# Import TSS1kb regions

# %%
bed.TSS1kb = readGeneric(path.TSS1kb,
                         header = F,
                         keep.all.metadata = T)
bed.TSS1kb
# Out:
# GRanges object with 20666 ranges and 3 metadata columns:
#           seqnames            ranges strand |          V4        V5          V6
#              <Rle>         <IRanges>  <Rle> | <character> <integer> <character>
#       [1]     chr1       35581-36581      * |     FAM138A         0           -
#       [2]     chr1       35581-36581      * |     FAM138F         0           -
#       [3]     chr1       68590-69590      * |       OR4F5         0           +
#       [4]     chr1     816870-817870      * |      FAM87B         0           +
#       [5]     chr1     827022-828022      * |   LINC00115         0           -
#       ...      ...               ...    ... .         ...       ...         ...
#   [20662]     chrY 21385860-21386860      * |       PRORY         0           -
#   [20663]     chrY 21594166-21595166      * |      TTTY13         0           -
#   [20664]     chrY 22298376-22299376      * |       TTTY5         0           -
#   [20665]     chrY 23198592-23199592      * |        DAZ1         0           -
#   [20666]     chrY 23218956-23219956      * |        DAZ2         0           +
#   -------
#   seqinfo: 24 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# Create a Cicero CDS

# %%
cellinfo = obj.seurat@meta.data
cellinfo[,"cell"] = rownames(cellinfo)
cellinfo
# Out:
#                          orig.ident    nCount_RNA nFeature_RNA nCount_ATAC
# e10l1_AAACCAGGTCACAGGG-1 SeuratProject 13033      4205         15412
# e10l1_AAACCGCCAAGGAATA-1 SeuratProject 16605      4976          6217
# e10l1_AAACCGCCAGCCGGTA-1 SeuratProject  8953      3654          1819
# e10l1_AAACCGGTCAAGGAAG-1 SeuratProject  6886      3325          1511
# e10l1_AAACGAACAACGTGGT-1 SeuratProject 22478      5638         18765
# e10l1_AAACGGGCAAGGGAGC-1 SeuratProject 10625      3496          4354
# e10l1_AAACGGTTCCCAAAGG-1 SeuratProject  8800      2943          9173
# e10l1_AAACTAGTCCTGTGAC-1 SeuratProject  7365      3128          9659
# e10l1_AAACTAGTCGAAGCAT-1 SeuratProject 10650      3718          7689
# e10l1_AAACTAGTCGCTTGAC-1 SeuratProject 10031      3977          9560
# e10l1_AAACTCGCAAGCGCTG-1 SeuratProject 14714      4453          8300
# e10l1_AAACTCGCAGCAAGTC-1 SeuratProject 12288      3801         12342
# e10l1_AAAGCCAGTTAGCTAC-1 SeuratProject  9592      3941          4147
# e10l1_AAAGCCAGTTAGTTTG-1 SeuratProject 19576      5255          3343
# e10l1_AAAGCGAAGACTCCTA-1 SeuratProject 14304      4690          7353
# e10l1_AAAGCGAAGCTTATCG-1 SeuratProject 15916      4829          3733
# e10l1_AAAGCGAAGGCTAGCA-1 SeuratProject  7450      3359          5900
# e10l1_AAAGCGAAGTGCACCT-1 SeuratProject 10455      4032         15235
# e10l1_AAAGGCGCACTGGGAT-1 SeuratProject 10041      3890          2066
# e10l2_TTTAGGCGTGCTCATG-1   504         0.5031156  0.4968844   1
# e10l2_TTTATCCGTTAAGGAT-1  2490         0.5243922  0.4756078   7
# e10l2_TTTCAAGGTGAAACAT-1  3717         0.6536342  0.3463658   1
# e10l2_TTTCAAGGTGAGGACT-1   541         0.5032558  0.4967442   7
# e10l2_TTTCAGTAGATGAAGG-1  4870         0.4579196  0.5420804   1
# e10l2_TTTCAGTAGCTATCGC-1  2569         0.4919384  0.5080616   7
# e10l2_TTTCAGTAGTTACATC-1  3290         0.5832063  0.4167937   1
# e10l2_TTTCCGGCAGGCAACT-1  1585         0.5884003  0.4115997   1
# e10l2_TTTCCTGGTCACTCAG-1   915         0.5448297  0.4551703   7
# e10l2_TTTCCTGGTCGTAATC-1  9216         0.5714482  0.4285518   1
# e10l2_TTTCCTGGTGCGTAAA-1  9502         0.6007722  0.3992278   1
# e10l2_TTTCTCATCACATTAC-1  1067         0.7412473  0.2587527   1
# e10l2_TTTCTCATCGCCTAAC-1  6073         0.4830662  0.5169338   7
# e10l2_TTTCTTGTCGCGAGTA-1  6900         0.4770973  0.5229027   1
# e10l2_TTTGCTCTCTTGTCGA-1  1534         0.5801811  0.4198189   1
# e10l2_TTTGCTGAGATTCACT-1  3183         0.7335752  0.2664248   7
# e10l2_TTTGGAGCACGGATCG-1  4298         0.5078737  0.4921263   1
# e10l2_TTTGGAGCATGCTCCA-1  9821         0.5564466  0.4435534   7
# e10l2_TTTGGCCAGTTTCACG-1  1161         0.5365469  0.4634531   1
# e10l2_TTTGGTTAGCAACCCT-1   664         0.8342308  0.1657692   1
# e10l2_TTTGTCGAGGATGCGC-1 11993         0.5074293  0.4925707   1
# e10l2_TTTGTCGAGTCCCGCA-1   637         0.5327736  0.4672264   7
# e10l2_TTTGTGAGTATAGCTC-1  8937         0.4863765  0.5136235   1
# e10l2_TTTGTGAGTTAGCGTT-1  5378         0.5975498  0.4024502   1
# e10l2_TTTGTGAGTTCCGGAC-1 10529         0.3778687  0.6221313   7
#                          seurat_clusters lane ⋯ wsnn_res.0.5 final_annotation
# e10l1_AAACCAGGTCACAGGG-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAACCGCCAAGGAATA-1 6               1    ⋯ 1            k562_crispri
# e10l1_AAACCGCCAGCCGGTA-1 2               1    ⋯ 1            k562_crispri
# e10l1_AAACCGGTCAAGGAAG-1 7               1    ⋯ 1            k562_crispri
# e10l1_AAACGAACAACGTGGT-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAACGGGCAAGGGAGC-1 4               1    ⋯ 1            k562_crispri
# e10l1_AAACGGTTCCCAAAGG-1 5               1    ⋯ 1            k562_crispri
# e10l1_AAACTAGTCCTGTGAC-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAACTAGTCGAAGCAT-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAACTAGTCGCTTGAC-1 3               1    ⋯ 1            k562_crispri
# e10l1_AAACTCGCAAGCGCTG-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAACTCGCAGCAAGTC-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGCCAGTTAGCTAC-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGCCAGTTAGTTTG-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGCGAAGACTCCTA-1 3               1    ⋯ 1            k562_crispri
# e10l1_AAAGCGAAGCTTATCG-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAAGCGAAGGCTAGCA-1 3               1    ⋯ 1            k562_crispri
# e10l1_AAAGCGAAGTGCACCT-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGGCGCACTGGGAT-1 2               1    ⋯ 1            k562_crispri
# e10l1_AAAGGCGCAGCCAAAC-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGGCGCAGCTCGAG-1 3               1    ⋯ 1            k562_crispri
# e10l1_AAAGGCTTCCACTAAT-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAAGGCTTCCTAAATC-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAAGGGATCGCTCAAC-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAAGTCATCCAGCTAC-1 0               1    ⋯ 1            k562_crispri
# e10l1_AAAGTCATCGAAGTTA-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAAGTCATCGCTAATT-1 4               1    ⋯ 10           k562_crispri
# e10l1_AAATAGGCAGCACGAT-1 6               1    ⋯ 1            k562_crispri
# e10l1_AAATCCTTCATTCAGT-1 1               1    ⋯ 1            k562_crispri
# e10l1_AAATCGATCGCCCGTA-1 5               1    ⋯ 1            k562_crispri
# ⋮                        ⋮               ⋮    ⋱ ⋮            ⋮
# e10l2_TTTACTGCAGTAATCG-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTACTGCAGTATTGG-1 5               2    ⋯ 1            k562_crispri
# e10l2_TTTAGCTAGGGACTTG-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTAGCTAGTTGCAGG-1 0               2    ⋯ 1            k562_crispri
# e10l2_TTTAGGCGTGCACGCT-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTAGGCGTGCTCATG-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTATCCGTTAAGGAT-1 5               2    ⋯ 1            k562_crispri
# e10l2_TTTCAAGGTGAAACAT-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTCAAGGTGAGGACT-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTCAGTAGATGAAGG-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTCAGTAGCTATCGC-1 3               2    ⋯ 1            k562_crispri
# e10l2_TTTCAGTAGTTACATC-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTCCGGCAGGCAACT-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTCCTGGTCACTCAG-1 3               2    ⋯ 1            k562_crispri
# e10l2_TTTCCTGGTCGTAATC-1 1               2    ⋯ 1            k562_crispri
# e10l2_TTTCCTGGTGCGTAAA-1 0               2    ⋯ 1            k562_crispri
# e10l2_TTTCTCATCACATTAC-1 6               2    ⋯ 1            k562_crispri
# e10l2_TTTCTCATCGCCTAAC-1 4               2    ⋯ 1            k562_crispri
# e10l2_TTTCTTGTCGCGAGTA-1 1               2    ⋯ 1            k562_crispri
# e10l2_TTTGCTCTCTTGTCGA-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTGCTGAGATTCACT-1 4               2    ⋯ 10           k562_crispri
# e10l2_TTTGGAGCACGGATCG-1 0               2    ⋯ 1            k562_crispri
# e10l2_TTTGGAGCATGCTCCA-1 4               2    ⋯ 10           k562_crispri
# e10l2_TTTGGCCAGTTTCACG-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTGGTTAGCAACCCT-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTGTCGAGGATGCGC-1 0               2    ⋯ 1            k562_crispri
# e10l2_TTTGTCGAGTCCCGCA-1 2               2    ⋯ 1            k562_crispri
# e10l2_TTTGTGAGTATAGCTC-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTGTGAGTTAGCGTT-1 7               2    ⋯ 1            k562_crispri
# e10l2_TTTGTGAGTTCCGGAC-1 3               2    ⋯ 1            k562_crispri
#                          nucleosome_signal nucleosome_percentile TSS.enrichment
# e10l1_AAACCAGGTCACAGGG-1 0.8270572         0.89                  4.805054
# e10l1_AAACCGCCAAGGAATA-1 0.7057143         0.62                  5.927762
# e10l1_AAACCGCCAGCCGGTA-1 0.5480769         0.20                  4.886639
# e10l1_AAACCGGTCAAGGAAG-1 0.7195122         0.66                  5.790128
# e10l1_AAACGAACAACGTGGT-1 0.9204082         0.97                  4.267810
# e10l1_AAACGGGCAAGGGAGC-1 0.6598361         0.49                  5.762177
# e10l1_AAACGGTTCCCAAAGG-1 0.6490486         0.45                  5.285174
# e10l1_AAACTAGTCCTGTGAC-1 0.7928437         0.84                  4.347055
# e10l1_AAACTAGTCGAAGCAT-1 0.5561905         0.22                  5.001816
# e10l1_AAACTAGTCGCTTGAC-1 0.4171322         0.04                  6.583027
# e10l1_AAACTCGCAAGCGCTG-1 0.6443595         0.44                  4.533928
# e10l1_AAACTCGCAGCAAGTC-1 0.6719858         0.52                  4.785506
# e10l1_AAAGCCAGTTAGCTAC-1 0.7250000         0.68                  5.700085
# e10l1_AAAGCCAGTTAGTTTG-1 0.7970297         0.85                  4.250588
# e10l1_AAAGCGAAGACTCCTA-1 0.5970874         0.31                  7.006477
# e10l1_AAAGCGAAGCTTATCG-1 0.5411255         0.19                  6.959707
# e10l1_AAAGCGAAGGCTAGCA-1 0.5324675         0.17                  6.417743
# e10l1_AAAGCGAAGTGCACCT-1 0.7409382         0.72                  4.616322
# e10l1_AAAGGCGCACTGGGAT-1 0.8229167         0.89                  4.824161
# e10l1_AAAGGCGCAGCCAAAC-1 0.6131387         0.35                  5.265466
# e10l1_AAAGGCGCAGCTCGAG-1 0.7067834         0.62                  5.164436
# e10l1_AAAGGCTTCCACTAAT-1 0.7925926         0.84                  5.191345
# e10l1_AAAGGCTTCCTAAATC-1 0.4915730         0.10                  5.794206
# e10l1_AAAGGGATCGCTCAAC-1 1.0156431         0.99                  4.329369
# e10l1_AAAGTCATCCAGCTAC-1 0.5299807         0.17                  5.985982
# e10l1_AAACCGGTCAAGGAAG-1 0.74           2               7
# e10l1_AAACGAACAACGTGGT-1 0.08           12              0
# e10l1_AAACGGGCAAGGGAGC-1 0.73           0               4
# e10l1_AAACGGTTCCCAAAGG-1 0.51           0               5
# e10l1_AAACTAGTCCTGTGAC-1 0.09           0               0
# e10l1_AAACTAGTCGAAGCAT-1 0.35           5               1
# e10l1_AAACTAGTCGCTTGAC-1 0.91           0               3
# e10l1_AAACTCGCAAGCGCTG-1 0.14           2               0
# e10l1_AAACTCGCAGCAAGTC-1 0.24           2               1
# e10l1_AAAGCCAGTTAGCTAC-1 0.70           3               1
# e10l1_AAAGCCAGTTAGTTTG-1 0.07           8               1
# e10l1_AAAGCGAAGACTCCTA-1 0.95           0               3
# e10l1_AAAGCGAAGCTTATCG-1 0.95           12              0
# e10l1_AAAGCGAAGGCTAGCA-1 0.89           4               3
# e10l1_AAAGCGAAGTGCACCT-1 0.17           3               1
# e10l1_AAAGGCGCACTGGGAT-1 0.26           11              2
# e10l1_AAAGGCGCAGCCAAAC-1 0.50           3               1
# e10l1_AAAGGCGCAGCTCGAG-1 0.44           0               3
# e10l1_AAAGGCTTCCACTAAT-1 0.45           3               0
# e10l1_AAAGGCTTCCTAAATC-1 0.74           2               0
# e10l1_AAAGGGATCGCTCAAC-1 0.09           12              0
# e10l1_AAAGTCATCCAGCTAC-1 0.80           4               0
# e10l1_AAAGTCATCGAAGTTA-1 0.33           1               1
# e10l1_AAAGTCATCGCTAATT-1 0.33           6               4
# e10l1_AAATAGGCAGCACGAT-1 0.54           11              6
# e10l1_AAATCCTTCATTCAGT-1 0.45           3               1
# e10l1_AAATCGATCGCCCGTA-1 0.93           0               5
# ⋮                        ⋮              ⋮               ⋮
# e10l2_TTTACTGCAGTAATCG-1 0.89           1               2
# e10l2_TTTACTGCAGTATTGG-1 0.65           12              5
# e10l2_TTTAGCTAGGGACTTG-1 0.65           12              2
# e10l2_TTTAGCTAGTTGCAGG-1 0.28           2               0
# e10l2_TTTAGGCGTGCACGCT-1 0.82           8               7
# e10l2_TTTAGGCGTGCTCATG-1 0.87           7               2
# e10l2_TTTATCCGTTAAGGAT-1 0.92           0               5
# e10l2_TTTCAAGGTGAAACAT-1 0.93           2               7
# e10l2_TTTCAAGGTGAGGACT-1 0.04           1               2
# e10l2_TTTCAGTAGATGAAGG-1 0.51           8               7
# e10l2_TTTCAGTAGCTATCGC-1 0.67           0               3
# e10l2_TTTCAGTAGTTACATC-1 0.15           5               7
# e10l2_TTTCCGGCAGGCAACT-1 0.56           5               2
# e10l2_TTTCCTGGTCACTCAG-1 0.95           0               3
# e10l2_TTTCCTGGTCGTAATC-1 0.09           10              1
# e10l2_TTTCCTGGTGCGTAAA-1 0.85           2               0
# e10l2_TTTCTCATCACATTAC-1 0.40           4               6
# e10l2_TTTCTCATCGCCTAAC-1 0.74           6               4
# e10l2_TTTCTTGTCGCGAGTA-1 0.80           3               1
# e10l2_TTTGCTCTCTTGTCGA-1 0.03           3               2
# e10l2_TTTGCTGAGATTCACT-1 0.58           6               4
# e10l2_TTTGGAGCACGGATCG-1 0.88           10              0
# e10l2_TTTCCTGGTCGTAATC-1 TTTCCTGGTCGTAATC-1 e10l2_TTTCCTGGTCGTAATC-1
# e10l2_TTTCCTGGTGCGTAAA-1 TTTCCTGGTGCGTAAA-1 e10l2_TTTCCTGGTGCGTAAA-1
# e10l2_TTTCTCATCACATTAC-1 TTTCTCATCACATTAC-1 e10l2_TTTCTCATCACATTAC-1
# e10l2_TTTCTCATCGCCTAAC-1 TTTCTCATCGCCTAAC-1 e10l2_TTTCTCATCGCCTAAC-1
# e10l2_TTTCTTGTCGCGAGTA-1 TTTCTTGTCGCGAGTA-1 e10l2_TTTCTTGTCGCGAGTA-1
# e10l2_TTTGCTCTCTTGTCGA-1 TTTGCTCTCTTGTCGA-1 e10l2_TTTGCTCTCTTGTCGA-1
# e10l2_TTTGCTGAGATTCACT-1 TTTGCTGAGATTCACT-1 e10l2_TTTGCTGAGATTCACT-1
# e10l2_TTTGGAGCACGGATCG-1 TTTGGAGCACGGATCG-1 e10l2_TTTGGAGCACGGATCG-1
# e10l2_TTTGGAGCATGCTCCA-1 TTTGGAGCATGCTCCA-1 e10l2_TTTGGAGCATGCTCCA-1
# e10l2_TTTGGCCAGTTTCACG-1 TTTGGCCAGTTTCACG-1 e10l2_TTTGGCCAGTTTCACG-1
# e10l2_TTTGGTTAGCAACCCT-1 TTTGGTTAGCAACCCT-1 e10l2_TTTGGTTAGCAACCCT-1
# e10l2_TTTGTCGAGGATGCGC-1 TTTGTCGAGGATGCGC-1 e10l2_TTTGTCGAGGATGCGC-1
# e10l2_TTTGTCGAGTCCCGCA-1 TTTGTCGAGTCCCGCA-1 e10l2_TTTGTCGAGTCCCGCA-1
# e10l2_TTTGTGAGTATAGCTC-1 TTTGTGAGTATAGCTC-1 e10l2_TTTGTGAGTATAGCTC-1
# e10l2_TTTGTGAGTTAGCGTT-1 TTTGTGAGTTAGCGTT-1 e10l2_TTTGTGAGTTAGCGTT-1
# e10l2_TTTGTGAGTTCCGGAC-1 TTTGTGAGTTCCGGAC-1 e10l2_TTTGTGAGTTCCGGAC-1

# %%
peakinfo = do.call(rbind,
                   strsplit(rownames(matrix.atac),"-"))
peakinfo = as.data.frame(peakinfo)
names(peakinfo) <- c("chr", "bp1", "bp2")
peakinfo$site_name <- paste(peakinfo$chr, peakinfo$bp1, peakinfo$bp2, sep="-")
row.names(peakinfo) <- peakinfo$site_name                   
peakinfo
# Out:
#                          chr  bp1       bp2       site_name
# chr1-10002583-10003163   chr1 10002583  10003163  chr1-10002583-10003163
# chr1-100028213-100029660 chr1 100028213 100029660 chr1-100028213-100029660
# chr1-100034608-100034758 chr1 100034608 100034758 chr1-100034608-100034758
# chr1-100036849-100037181 chr1 100036849 100037181 chr1-100036849-100037181
# chr1-100037737-100039006 chr1 100037737 100039006 chr1-100037737-100039006
# chr1-100044679-100044954 chr1 100044679 100044954 chr1-100044679-100044954
# chr1-100045126-100045559 chr1 100045126 100045559 chr1-100045126-100045559
# chr1-100046129-100046586 chr1 100046129 100046586 chr1-100046129-100046586
# chrX-98573452-98574121   chrX 98573452  98574121  chrX-98573452-98574121
# chrX-9864068-9864411     chrX 9864068   9864411   chrX-9864068-9864411
# chrX-9873736-9874288     chrX 9873736   9874288   chrX-9873736-9874288
# chrX-9882537-9883461     chrX 9882537   9883461   chrX-9882537-9883461
# chrX-9885193-9885478     chrX 9885193   9885478   chrX-9885193-9885478
# chrX-9894528-9895197     chrX 9894528   9895197   chrX-9894528-9895197
# chrX-989766-990624       chrX 989766    990624    chrX-989766-990624
# chrX-99372004-99372431   chrX 99372004  99372431  chrX-99372004-99372431
# chrX-9940388-9940697     chrX 9940388   9940697   chrX-9940388-9940697
# chrX-9995829-9996183     chrX 9995829   9996183   chrX-9995829-9996183

# %%
input_cds <-  suppressWarnings(new_cell_data_set(matrix.atac,
                               cell_metadata = cellinfo,
                               gene_metadata = peakinfo))

# %%
input_cds <- monocle3::detect_genes(input_cds)
#Ensure there are no peaks included with zero reads
input_cds <- input_cds[Matrix::rowSums(exprs(input_cds)) != 0,]

# %%
set.seed(2017)
input_cds <- detect_genes(input_cds)
input_cds <- estimate_size_factors(input_cds)
input_cds <- preprocess_cds(input_cds, method = "LSI")
input_cds <- reduce_dimension(input_cds, reduction_method = 'UMAP', 
                              preprocess_method = "LSI")
# Out:
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'
#
# Found more than one class "dist" in cache; using the first, from namespace 'BiocGenerics'
#
# Also defined by 'spam'

# %%
plot_cells(input_cds)
# Out:
# No trajectory to plot. Has learn_graph() been called yet?
#
# cluster not found in colData(cds), cells will not be colored
#
# cluster_cells() has not been called yet, can't color cells by cluster
# plot without title

# %%
umap_coords <- reducedDims(input_cds)$UMAP
cicero_cds <- make_cicero_cds(input_cds, reduced_coordinates = umap_coords)
# Out:
# Overlap QC metrics:
# Cells per bin: 50
# Maximum shared cells bin-bin: 44
# Mean shared cells bin-bin: 0.400807175248772
# Median shared cells bin-bin: 0

# %% [markdown]
# Run Cicero

# %%
human.hg38.genome = read.table(path.chrom.sizes,
                               header = F)
human.hg38.genome
# Out:
#     V1                     V2
# 1   chr1                   248956422
# 2   chr2                   242193529
# 3   chr3                   198295559
# 4   chr4                   190214555
# 5   chr5                   181538259
# 6   chr6                   170805979
# 7   chr7                   159345973
# 8   chr8                   145138636
# 9   chr9                   138394717
# 10  chr10                  133797422
# 11  chr11                  135086622
# 12  chr12                  133275309
# 13  chr13                  114364328
# 14  chr14                  107043718
# 15  chr15                  101991189
# 16  chr16                   90338345
# 17  chr17                   83257441
# 18  chr18                   80373285
# 19  chr19                   58617616
# 20  chr20                   64444167
# 21  chr21                   46709983
# 22  chr22                   50818468
# 23  chrX                   156040895
# 24  chrY                    57227415
# 25  chrM                       16569
# 26  chr1_GL383518v1_alt       182439
# 27  chr1_GL383519v1_alt       110268
# 28  chr1_GL383520v2_alt       366580
# 29  chr1_KI270706v1_random    175055
# 30  chr1_KI270707v1_random     32032
# ⋮   ⋮                      ⋮
# 427 chrUn_KI270579v1        31033
# 428 chrUn_KI270580v1         1553
# 429 chrUn_KI270581v1         7046
# 430 chrUn_KI270582v1         6504
# 431 chrUn_KI270583v1         1400
# 432 chrUn_KI270584v1         4513
# 433 chrUn_KI270587v1         2969
# 434 chrUn_KI270588v1         6158
# 435 chrUn_KI270589v1        44474
# 436 chrUn_KI270590v1         4685
# 437 chrUn_KI270591v1         5796
# 438 chrUn_KI270593v1         3041
# 439 chrUn_KI270741v1       157432
# 440 chrUn_KI270742v1       186739
# 441 chrUn_KI270743v1       210658
# 442 chrUn_KI270744v1       168472
# 443 chrUn_KI270745v1        41891
# 444 chrUn_KI270746v1        66486
# 445 chrUn_KI270747v1       198735
# 446 chrUn_KI270748v1        93321
# 447 chrUn_KI270749v1       158759
# 448 chrUn_KI270750v1       148850
# 449 chrUn_KI270751v1       150742
# 450 chrUn_KI270752v1        27745
# 451 chrUn_KI270753v1        62944
# 452 chrUn_KI270754v1        40191
# 453 chrUn_KI270755v1        36723
# 454 chrUn_KI270756v1        79590
# 455 chrUn_KI270757v1        71251
# 456 chrEBV                 171823

# %%
start_time <- Sys.time()
distance_parameters <- estimate_distance_parameter(cicero_cds, 
                                                   window = window, 
                                                   maxit = 100, 
                                                   sample_num = 100, 
                                                   distance_constraint = distance_constraint,
                                                   distance_parameter_convergence = 1e-22, 
                                                   genomic_coords = human.hg38.genome)
mean_distance_parameter <- mean(unlist(distance_parameters))
end_time <- Sys.time()
execution_time1 <- end_time - start_time

# %%
mean_distance_parameter
# Out:
# [1] 0.24859

# %%
execution_time1
# Out:
# Time difference of 7.351843 mins

# %%
start_time <- Sys.time()
cicero_out <- generate_cicero_models(cicero_cds, 
                                     distance_parameter = mean_distance_parameter, 
                                     window = window, 
                                     genomic_coords = human.hg38.genome)
end_time <- Sys.time()
execution_time2 <- end_time - start_time

# %%
execution_time2
# Out:
# Time difference of 1.003475 hours

# %%
start_time <- Sys.time()
all_cons <- assemble_connections(cicero_out, 
                                 silent = FALSE)
end_time <- Sys.time()
execution_time3 <- end_time - start_time

# %%
execution_time3
# Out:
# Time difference of 45.38506 secs

# %% [markdown]
# Assign coaccess to E2G pairs

# %%
all_cons0 = all_cons
all_cons0[is.na(all_cons0[,"coaccess"]),"coaccess"] = 0
bed.peakinfo <- makeGRangesFromDataFrame(peakinfo, 
                                         keep.extra.columns = TRUE,
                                         start.field="bp1",
                                         end.field="bp2")
overlap.res = findOverlaps(bed.peakinfo[all_cons0[,"Peak1"]],
                           bed.TSS1kb)
df.overlap = as.data.frame(overlap.res)
all_cons0.E2G = all_cons0[df.overlap$queryHits,]
all_cons0.E2G[,"Gene"] = bed.TSS1kb[df.overlap$subjectHits]$V4
all_cons0.E2G[,"PairName"] = paste(all_cons0.E2G[,"Peak2"],all_cons0.E2G[,"Gene"],sep = "_")
all_cons0.E2G.sort = all_cons0.E2G[order(all_cons0.E2G[,"coaccess"],decreasing = T),]
all_cons0.E2G.uniq = all_cons0.E2G.sort[!duplicated(all_cons0.E2G.sort$PairName),]
rownames(all_cons0.E2G.uniq) = all_cons0.E2G.uniq$PairName
pairs.E2G.res = pairs.E2G[pairs.E2G$PairName %in% all_cons0.E2G.uniq$PairName]
pairs.E2G.res$coaccess = all_cons0.E2G.uniq[pairs.E2G.res$PairName,"coaccess"]

# %% [markdown]
# Save results

# %%
dir.create(dir.output,recursive = T)
saveRDS(all_cons,
        paste(dir.output,"all_cons.rds",sep = "/"))
saveRDS(pairs.E2G.res,
        paste(dir.output,"pairs.E2G.res.rds",sep = "/"))
df.output = as.data.frame(pairs.E2G.res,row.names = NULL)
colnames(df.output)[1] = "chr"
df.output[,"CellType"] = "K562"
df.output = df.output[,c("chr",
                         "start",
                         "end",
                         "TargetGene",
                         "CellType",
                         "coaccess")]
data.table::fwrite(df.output,
                   file = paste(dir.output,"pairs.E2G.res.tsv.gz",sep = "/"),
                   row.names = F,
                   quote = F,
                   sep = "\t")
pairs.E2G.res
df.output
# Out:
# Warning message in dir.create(dir.output, recursive = T):
# "'/maps/projects/ralab_nnfc-AUDIT/people/lpm537/project/E2G/analysis/E2G_240503/data/K562_IGVF/3.Genome_wide_prediction/Cicero/Cicero.240525' already exists"
# GRanges object with 1237241 ranges and 4 metadata columns:
#             seqnames              ranges strand |  TargetGene
#                <Rle>           <IRanges>  <Rle> | <character>
#         [1]     chr1 100028213-100029660      * |         AGL
#         [2]     chr1 100028213-100029660      * |      CDC14A
#         [3]     chr1 100028213-100029660      * |         DBT
#         [4]     chr1 100028213-100029660      * |        DPH5
#         [5]     chr1 100028213-100029660      * |       EXTL2
#         ...      ...                 ...    ... .         ...
#   [1237237]     chrX     9940388-9940697      * |        WWC3
#   [1237238]     chrX     9995829-9996183      * |       CLCN4
#   [1237239]     chrX     9995829-9996183      * |       FAM9B
#   [1237240]     chrX     9995829-9996183      * |       TBL1X
#   [1237241]     chrX     9995829-9996183      * |        WWC3
#                           PeakName               PairName     coaccess
#                        <character>            <character>    <numeric>
#         [1] chr1-100028213-10002.. chr1-100028213-10002.. -0.001782530
#         [2] chr1-100028213-10002.. chr1-100028213-10002.. -0.017304514
#         [3] chr1-100028213-10002.. chr1-100028213-10002.. -0.001533299
#         [4] chr1-100028213-10002.. chr1-100028213-10002.. -0.001075744
#         [5] chr1-100028213-10002.. chr1-100028213-10002..  0.000966639
#         ...                    ...                    ...          ...
#   [1237237]   chrX-9940388-9940697 chrX-9940388-9940697..  0.00000e+00
#   [1237238]   chrX-9995829-9996183 chrX-9995829-9996183.. -7.41777e-08
#   [1237239]   chrX-9995829-9996183 chrX-9995829-9996183.. -2.85930e-06
#   [1237240]   chrX-9995829-9996183 chrX-9995829-9996183.. -5.89631e-07
#   [1237241]   chrX-9995829-9996183 chrX-9995829-9996183.. -6.24998e-06
#   -------
#   seqinfo: 23 sequences from an unspecified genome; no seqlengths
#         chr  start     end       TargetGene CellType coaccess
# 1       chr1 100028213 100029660 AGL        K562     -1.782530e-03
# 2       chr1 100028213 100029660 CDC14A     K562     -1.730451e-02
# 3       chr1 100028213 100029660 DBT        K562     -1.533299e-03
# 4       chr1 100028213 100029660 DPH5       K562     -1.075744e-03
# 5       chr1 100028213 100029660 EXTL2      K562      9.666388e-04
# 6       chr1 100028213 100029660 FRRS1      K562     -1.490550e-03
# 7       chr1 100028213 100029660 LRRC39     K562     -1.586776e-05
# 8       chr1 100028213 100029660 MFSD14A    K562     -1.499884e-02
# 1237235 chrX  9940388   9940697  FAM9B      K562      0.000000e+00
# 1237236 chrX  9940388   9940697  TBL1X      K562      0.000000e+00
# 1237237 chrX  9940388   9940697  WWC3       K562      0.000000e+00
# 1237238 chrX  9995829   9996183  CLCN4      K562     -7.417771e-08
# 1237239 chrX  9995829   9996183  FAM9B      K562     -2.859305e-06
# 1237240 chrX  9995829   9996183  TBL1X      K562     -5.896308e-07
# 1237241 chrX  9995829   9996183  WWC3       K562     -6.249978e-06

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux 8.9 (Ootpa)
#
# Matrix products: default
# BLAS/LAPACK: /maps/projects/ralab/people/lpm537/software/anaconda3/envs/Notebook_E2G_240505/lib/libopenblasp-r0.3.27.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Copenhagen
# tzcode source: system (glibc)
#
# attached base packages:
# [1] grid      stats4    stats     graphics  grDevices utils     datasets
# [8] methods   base
#
# other attached packages:
#  [1] ggplot2_3.5.1               Matrix_1.6-5
#  [3] genomation_1.34.0           magrittr_2.0.3
#  [5] Signac_1.13.0               Seurat_5.0.3
#  [7] SeuratObject_5.0.1          sp_2.1-4
#  [9] cicero_1.3.9                Gviz_1.44.2
# [11] monocle3_1.3.7              SingleCellExperiment_1.22.0
# [13] SummarizedExperiment_1.30.2 GenomicRanges_1.54.1
# [15] GenomeInfoDb_1.38.1         IRanges_2.36.0
# [17] S4Vectors_0.40.2            MatrixGenerics_1.12.3
# [19] matrixStats_1.3.0           Biobase_2.60.0
# [21] BiocGenerics_0.48.1
#
# loaded via a namespace (and not attached):
#   [1] ProtGenerics_1.32.0      spatstat.sparse_3.0-3    bitops_1.0-7
#   [4] httr_1.4.7               RColorBrewer_1.1-3       repr_1.1.7
#   [7] tools_4.3.3              sctransform_0.4.1        backports_1.4.1
#  [10] utf8_1.2.4               R6_2.5.1                 uwot_0.1.16
#  [13] lazyeval_0.2.2           withr_3.0.0              prettyunits_1.2.0
#  [16] gridExtra_2.3            progressr_0.14.0         cli_3.6.2
#  [19] Cairo_1.6-2              spatstat.explore_3.2-6   fastDummies_1.7.3
#  [22] labeling_0.4.3           spatstat.data_3.0-4      readr_2.1.5
#  [25] ggridges_0.5.6           pbapply_1.7-2            Rsamtools_2.18.0
#  [28] pbdZMQ_0.3-11            foreign_0.8-86           dichromat_2.0-0.1
#  [31] parallelly_1.37.1        plotrix_3.8-4            BSgenome_1.68.0
#  [34] impute_1.76.0            VGAM_1.1-10              rstudioapi_0.16.0
#  [37] RSQLite_2.3.6            FNN_1.1.4                generics_0.1.3
#  [40] BiocIO_1.10.0            vroom_1.6.5              ica_1.0-3
#  [43] spatstat.random_3.2-3    dplyr_1.1.4              interp_1.1-6
#  [46] fansi_1.0.6              abind_1.4-5              lifecycle_1.0.4
#  [49] yaml_2.3.8               BiocFileCache_2.8.0      Rtsne_0.17
#  [52] blob_1.2.4               promises_1.3.0           crayon_1.5.2
#  [55] miniUI_0.1.1.1           lattice_0.22-6           cowplot_1.1.3
#  [58] GenomicFeatures_1.52.2   KEGGREST_1.40.1          pillar_1.9.0
#  [61] knitr_1.46               rjson_0.2.21             boot_1.3-30
#  [64] future.apply_1.11.2      codetools_0.2-20         fastmatch_1.1-4
#  [67] leiden_0.4.3.1           glue_1.7.0               data.table_1.15.2
#  [70] vctrs_0.6.5              png_0.1-8                spam_2.10-0
#  [73] gtable_0.3.5             assertthat_0.2.1         cachem_1.0.8
#  [76] xfun_0.43                S4Arrays_1.2.1           mime_0.12
#  [79] survival_3.6-4           RcppRoll_0.3.0           fitdistrplus_1.1-11
#  [82] ROCR_1.0-11              nlme_3.1-164             bit64_4.0.5
#  [85] progress_1.2.3           filelock_1.0.3           RcppAnnoy_0.0.22
#  [88] irlba_2.3.5.1            KernSmooth_2.23-22       rpart_4.1.23
#  [91] colorspace_2.1-0         DBI_1.2.2                Hmisc_5.1-2
#  [94] seqPattern_1.34.0        nnet_7.3-19              tidyselect_1.2.1
#  [97] bit_4.0.5                compiler_4.3.3           curl_5.1.0
# [100] htmlTable_2.4.2          xml2_1.3.6               DelayedArray_0.26.7
# [103] plotly_4.10.4            rtracklayer_1.60.1       checkmate_2.3.1
# [106] scales_1.3.0             lmtest_0.9-40            rappdirs_0.3.3
# [109] goftest_1.2-3            stringr_1.5.1            digest_0.6.35
# [112] spatstat.utils_3.0-4     minqa_1.2.6              rmarkdown_2.26
# [115] XVector_0.42.0           htmltools_0.5.8.1        pkgconfig_2.0.3
# [118] jpeg_0.1-10              base64enc_0.1-3          lme4_1.1-35.3
# [121] dbplyr_2.5.0             fastmap_1.1.1            ensembldb_2.24.1
# [124] rlang_1.1.3              htmlwidgets_1.6.4        shiny_1.8.1.1
# [127] farver_2.1.1             zoo_1.8-12               jsonlite_1.8.8
# [130] BiocParallel_1.36.0      VariantAnnotation_1.46.0 RCurl_1.98-1.14
# [133] Formula_1.2-5            GenomeInfoDbData_1.2.11  dotCall64_1.1-1
# [136] patchwork_1.2.0          IRkernel_1.3.2           munsell_0.5.1
# [139] Rcpp_1.0.12              reticulate_1.36.1        stringi_1.8.3
# [142] zlibbioc_1.48.0          MASS_7.3-60              plyr_1.8.9
# [145] parallel_4.3.3           listenv_0.9.1            ggrepel_0.9.5
# [148] deldir_2.0-4             Biostrings_2.70.1        IRdisplay_1.1
# [151] splines_4.3.3            tensor_1.5               hms_1.1.3
# [154] igraph_2.0.3             uuid_1.2-0               spatstat.geom_3.2-9
# [157] RcppHNSW_0.6.0           reshape2_1.4.4           biomaRt_2.56.1
# [160] XML_3.99-0.16.1          evaluate_0.23            latticeExtra_0.6-30
# [163] biovizBase_1.48.0        tzdb_0.4.0               nloptr_2.0.3
# [166] httpuv_1.6.15            RANN_2.6.1               tidyr_1.3.1
# [169] purrr_1.0.2              polyclip_1.10-6          future_1.33.2
# [172] scattermore_1.2          gridBase_0.4-7           xtable_1.8-4
# [175] restfulr_0.0.15          AnnotationFilter_1.24.0  RSpectra_0.16-1
# [178] later_1.3.2              glasso_1.11              viridisLite_0.4.2
# [181] tibble_3.2.1             memoise_2.0.1            AnnotationDbi_1.64.1
# [184] GenomicAlignments_1.36.0 cluster_2.1.6            globals_0.16.3
